# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 38.91 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 38.2 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.5 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=a4f99c7e89af931db2f3b4f3519b909c7dbb4912e6fd9dee10b7844f14dcf278
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lidnxwww/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 15.82 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.18 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  5.84
# Time taken to evaluate the square roots needed:  0.1
# Time for significant indices evaluation:  1.9875089500000058
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 7.93 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  6.68
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  37.48 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.83 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.16 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.47 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709566
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632568
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325682
#
#
# HOMO-LUMO gap: 2.64310792816706 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.21 seconds
#
#
#
# Density matrix difference norm:  43.34767137041606
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999994743899805
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709439
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316064
# Coulomb Energy                   501.1198589452473
# Exchange-Correlation Energy      -62.5998011282692
# --------------------------------------------------
# Total Energy                    -340.0652765782360
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851497915
#
#
# HOMO-LUMO gap: 0.004902711060924159 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  28.61247171884549
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00009840286508
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456810
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785959
# Coulomb Energy                   293.3088657954305
# Exchange-Correlation Energy      -37.4191110537734
# --------------------------------------------------
# Total Energy                    -355.5094553813045
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803068553
#
#
# HOMO-LUMO gap: 0.040361476987044814 au
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  21.394016787364993
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445384
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275386
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458431
# Coulomb Energy                   367.2127830476448
# Exchange-Correlation Energy      -44.5841010136094
# --------------------------------------------------
# Total Energy                    -380.5867878035367
# --------------------------------------------------
#
#
#
# Energy difference :  25.077332422232132
#
#
# HOMO-LUMO gap: 0.01804857114308968 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  5.197480933689805
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000687474082
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703787
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754532
# Coulomb Energy                   364.3533796551040
# Exchange-Correlation Energy      -44.5594485029978
# --------------------------------------------------
# Total Energy                    -378.6274635986957
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048409252
#
#
# HOMO-LUMO gap: 0.0849358228474485 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  4.779285269951654
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001287711403
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186494
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180462
# Coulomb Energy                   368.1554971681545
# Exchange-Correlation Energy      -45.0868782881896
# --------------------------------------------------
# Total Energy                    -381.1270633765149
# --------------------------------------------------
#
#
#
# Energy difference :  2.499599777819128
#
#
# HOMO-LUMO gap: 0.14183855738628887 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5205766173123941
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089467
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233248
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990148
# Coulomb Energy                   369.0647619107180
# Exchange-Correlation Energy      -45.1368862216099
# --------------------------------------------------
# Total Energy                    -381.2275584910781
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456327309
#
#
# HOMO-LUMO gap: 0.1351472390946407 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.3315886778248286
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000011665971485
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176767
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774502
# Coulomb Energy                   369.6340156607467
# Exchange-Correlation Energy      -45.2090855965855
# --------------------------------------------------
# Total Energy                    -381.2508898319417
# --------------------------------------------------
#
#
#
# Energy difference :  0.023331340863535388
#
#
# HOMO-LUMO gap: 0.019732057382434193 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5818251308674487
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008617005534
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110740
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893464
# Coulomb Energy                   374.0898923937870
# Exchange-Correlation Energy      -45.7569321945892
# --------------------------------------------------
# Total Energy                    -381.3827647784061
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646444975
#
#
# HOMO-LUMO gap: 0.1260448122145658 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.4584549614620949
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767311
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524608
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358398
# Coulomb Energy                   377.3880704578808
# Exchange-Correlation Energy      -46.1034837100256
# --------------------------------------------------
# Total Energy                    -381.4206849246423
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623616069
#
#
# HOMO-LUMO gap: 0.16627348986202453 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.14506886517000503
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000757902089
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358447
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690208
# Coulomb Energy                   377.1736811284894
# Exchange-Correlation Energy      -46.0748895148567
# --------------------------------------------------
# Total Energy                    -381.4268823090678
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384425490782
#
#
# HOMO-LUMO gap: 0.1812607411263163 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.055748849988957454
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000742519871
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179369
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114283
# Coulomb Energy                   377.1977734128232
# Exchange-Correlation Energy      -46.0810670348477
# --------------------------------------------------
# Total Energy                    -381.4272916844097
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753419169843
#
#
# HOMO-LUMO gap: 0.18111025828110422 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.02562530605155208
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503725406
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006527
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114221
# Coulomb Energy                   377.1502888734900
# Exchange-Correlation Energy      -46.0776486461292
# --------------------------------------------------
# Total Energy                    -381.4274184177463
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333657176045
#
#
# HOMO-LUMO gap: 0.18068395565679446 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.00843252643370568
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750035487
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167563
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298572
# Coulomb Energy                   377.1545462611534
# Exchange-Correlation Energy      -46.0767747067595
# --------------------------------------------------
# Total Energy                    -381.4274393883816
# --------------------------------------------------
#
#
#
# Energy difference :  2.097063531891763e-05
#
#
# HOMO-LUMO gap: 0.18067053575024486 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0018444600039795873
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007500250724
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068206
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736969
# Coulomb Energy                   377.1524231958055
# Exchange-Correlation Energy      -46.0765296383168
# --------------------------------------------------
# Total Energy                    -381.4274391315114
# --------------------------------------------------
#
#
#
# Energy difference :  2.5687012339403736e-07
#
#
# HOMO-LUMO gap: 0.18064597252289083 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0011511413608224677
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074989492
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206445
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789345
# Coulomb Energy                   377.1549870542088
# Exchange-Correlation Energy      -46.0768423766160
# --------------------------------------------------
# Total Energy                    -381.4274396199938
# --------------------------------------------------
#
#
#
# Energy difference :  4.884823283646256e-07
#
#
# HOMO-LUMO gap: 0.18064256438837292 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.0001054327930830991
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836627
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081815
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075858
# Coulomb Energy                   377.1556791349423
# Exchange-Correlation Energy      -46.0769272993466
# --------------------------------------------------
# Total Energy                    -381.4274396208766
# --------------------------------------------------
#
#
#
# Energy difference :  8.827782949083485e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743962087656
# -------------------------------------
#
#
#
# Time taken : 67.61 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.63
# Density Fitting                         1.64
#     DF (gamma)                          0.7
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.59
# DIIS                                    0.69
# KS matrix diagonalization               0.66
# One electron Integrals (S, T, Vnuc)     15.82
# Coulomb Integrals (2c2e + 3c2e)         37.48
# Grids construction                      0.83
# Exchange-Correlation Term               4.01
# Misc.                                   3.85
# Complete SCF                            67.61

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.07 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.02
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0032018179999795393
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.06
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  1.6 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.94 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.87 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00135664103416
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091871
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371787
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645300004
# --------------------------------------------------
#
#
#
# Energy difference :  185.4474645300004
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# HOMO-LUMO gap: 1.7654343749560577 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.18 seconds
#
#
#
# Density matrix difference norm:  66.88358764205269
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084647
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437603
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987505707
# Coulomb Energy                  1272.5954275689458
# Exchange-Correlation Energy     -125.2198694441748
# --------------------------------------------------
# Total Energy                    -680.0789187511866
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422118623
#
#
# HOMO-LUMO gap: 0.00040456056757331993 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  39.275229644338765
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0012017584456
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692494484
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666727316
# Coulomb Energy                   861.6558693046919
# Exchange-Correlation Energy      -75.4419310839626
# --------------------------------------------------
# Total Energy                    -709.3563182387555
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487568914
#
#
# HOMO-LUMO gap: 0.027815605001320208 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  28.147358564317813
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663976
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672035558
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170659720
# Coulomb Energy                  1000.6400676118394
# Exchange-Correlation Energy      -87.3507096616565
# --------------------------------------------------
# Total Energy                    -733.7433460701689
# --------------------------------------------------
#
#
#
# Energy difference :  24.38702783141332
#
#
# HOMO-LUMO gap: 0.007352227196832151 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  18.103053983076332
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642285
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026564671
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102957747
# Coulomb Energy                  1039.7254935641690
# Exchange-Correlation Energy      -89.9717584580962
# --------------------------------------------------
# Total Energy                    -689.6320111373875
# --------------------------------------------------
#
#
#
# Energy difference :  44.11133493278135
#
#
# HOMO-LUMO gap: 0.010701793705975099 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  13.03426010369553
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576004
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022386540
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597333
# Coulomb Energy                  1004.3417767419372
# Exchange-Correlation Energy      -89.2334391642862
# --------------------------------------------------
# Total Energy                    -749.6400714840375
# --------------------------------------------------
#
#
#
# Energy difference :  60.00806034665004
#
#
# HOMO-LUMO gap: 0.025771351286289677 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  7.653358064507691
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554304
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132844636
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410279
# Coulomb Energy                   997.3319760641116
# Exchange-Correlation Energy      -89.6717481072318
# --------------------------------------------------
# Total Energy                    -755.2352624693240
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985286422
#
#
# HOMO-LUMO gap: 0.003568479525449114 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  6.3097383350165845
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567737
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204419900
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857162120
# Coulomb Energy                  1009.6464766739817
# Exchange-Correlation Energy      -89.9069114779707
# --------------------------------------------------
# Total Energy                    -755.2788234125352
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094321121873
#
#
# HOMO-LUMO gap: 0.009175061883485165 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  8.0571327174702
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00050300163971
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153725962
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119321899
# Coulomb Energy                  1035.0050622424742
# Exchange-Correlation Energy      -92.6658378595124
# --------------------------------------------------
# Total Energy                    -747.5712329402127
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472322522
#
#
# HOMO-LUMO gap: 0.11766237194142701 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  7.715013428993826
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306778
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903694217
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992830959
# Coulomb Energy                  1048.9988443897034
# Exchange-Correlation Energy      -94.9610811404293
# --------------------------------------------------
# Total Energy                    -761.7908817198193
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779606587
#
#
# HOMO-LUMO gap: 0.010925426636446661 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  6.790315749230431
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377903
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412181426
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466859979
# Coulomb Energy                  1013.7508689108977
# Exchange-Correlation Energy      -90.9428726052341
# --------------------------------------------------
# Total Energy                    -756.2816521092491
# --------------------------------------------------
#
#
#
# Energy difference :  5.5092296105701735
#
#
# HOMO-LUMO gap: 0.14929732694144204 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  6.534633252582585
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202663
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716100128
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461509793
# Coulomb Energy                  1025.7750806784939
# Exchange-Correlation Energy      -92.2703810887855
# --------------------------------------------------
# Total Energy                    -762.7969797520932
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327642844113
#
#
# HOMO-LUMO gap: 0.13352697867597868 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.5338338749004992
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000063433206
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534048
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792903085
# Coulomb Energy                  1024.7461321399942
# Exchange-Correlation Energy      -92.1885648748862
# --------------------------------------------------
# Total Energy                    -762.8402252807564
# --------------------------------------------------
#
#
#
# Energy difference :  0.04324552866319209
#
#
# HOMO-LUMO gap: 0.11056223799223426 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.3602713359566877
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916642
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590206429
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517294736
# Coulomb Energy                  1023.6379077075852
# Exchange-Correlation Energy      -92.0697499682028
# --------------------------------------------------
# Total Energy                    -762.8490034345547
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153798289168
#
#
# HOMO-LUMO gap: 0.0860035327246979 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.3252988568170403
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680044
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240863809
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261722305
# Coulomb Energy                  1024.4836887100921
# Exchange-Correlation Energy      -92.1371699397533
# --------------------------------------------------
# Total Energy                    -762.8531330265798
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592025151396
#
#
# HOMO-LUMO gap: 0.11636080747649111 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.15534224620110032
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000074350361
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117168804
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900055895
# Coulomb Energy                  1024.5663100626039
# Exchange-Correlation Energy      -92.1605267750456
# --------------------------------------------------
# Total Energy                    -762.8605923065006
# --------------------------------------------------
#
#
#
# Energy difference :  0.00745927992079487
#
#
# HOMO-LUMO gap: 0.12269239243644006 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.04060711223517441
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000722186559
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080747
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362754
# Coulomb Energy                  1024.7015706722598
# Exchange-Correlation Energy      -92.1773633390789
# --------------------------------------------------
# Total Energy                    -762.8609189213864
# --------------------------------------------------
#
#
#
# Energy difference :  0.00032661488580743026
#
#
# HOMO-LUMO gap: 0.11742913475980148 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.019703163530997124
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471094
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348738873
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569717
# Coulomb Energy                  1024.5590092023936
# Exchange-Correlation Energy      -92.1602830990715
# --------------------------------------------------
# Total Energy                    -762.8609667963615
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497505276406e-05
#
#
# HOMO-LUMO gap: 0.11815573488866005 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.008211499893330216
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163932
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862464
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811800
# Coulomb Energy                  1024.5676148746763
# Exchange-Correlation Energy      -92.1612728329157
# --------------------------------------------------
# Total Energy                    -762.8609882460735
# --------------------------------------------------
#
#
#
# Energy difference :  2.1449711994137033e-05
#
#
# HOMO-LUMO gap: 0.11842571032204016 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0019148361613634344
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786604
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971868
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346348
# Coulomb Energy                  1024.5642249369632
# Exchange-Correlation Energy      -92.1610088236044
# --------------------------------------------------
# Total Energy                    -762.8609886319612
# --------------------------------------------------
#
#
#
# Energy difference :  3.858876880258322e-07
#
#
# HOMO-LUMO gap: 0.11835771606493033 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0010776396184422603
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816396
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020399
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743415
# Coulomb Energy                  1024.5683629999303
# Exchange-Correlation Energy      -92.1613819110204
# --------------------------------------------------
# Total Energy                    -762.8609888215565
# --------------------------------------------------
#
#
#
# Energy difference :  1.895953118946636e-07
#
#
# HOMO-LUMO gap: 0.1183711833854561 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0005041312664478305
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785557
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158167
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323432
# Coulomb Energy                  1024.5701171428780
# Exchange-Correlation Energy      -92.1615907612837
# --------------------------------------------------
# Total Energy                    -762.8609888846474
# --------------------------------------------------
#
#
#
# Energy difference :  6.30909653409617e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846474
# -------------------------------------
#
#
#
# Time taken : 10.39 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           1.9
# Density Fitting                         0.39
#     DF (gamma)                          0.13
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.15
# DIIS                                    0.08
# KS matrix diagonalization               0.23
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         1.6
# Grids construction                      0.94
# Exchange-Correlation Term               3.41
# Misc.                                   1.8
# Complete SCF                            10.39

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.16 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.04
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007335694999994757
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.05 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.19
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  5.7 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.58 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.38 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.04 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718097
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355750
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973741
# --------------------------------------------------
#
#
#
# Energy difference :  374.9303338973741
#
#
# HOMO-LUMO gap: 1.8502864435407624 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 0.5 seconds
#
#
#
# Density matrix difference norm:  107.82844284432893
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999855877294
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067072
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391765569
# Coulomb Energy                  3537.3287033060387
# Exchange-Correlation Energy     -250.6110528162010
# --------------------------------------------------
# Total Energy                   -1359.8923755096512
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122771
#
#
# HOMO-LUMO gap: 0.0021139216448499143 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  57.367070219175
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512904
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256495017
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810813104
# Coulomb Energy                  2705.3966179577765
# Exchange-Correlation Energy     -151.8752804393627
# --------------------------------------------------
# Total Energy                   -1419.0480632191156
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770946447
#
#
# HOMO-LUMO gap: 0.01974072374025393 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  48.04719016381726
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001717849239
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823848594
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892855229
# Coulomb Energy                  3071.8764250114259
# Exchange-Correlation Energy     -174.7460035329377
# --------------------------------------------------
# Total Energy                   -1362.4047277901859
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542892973
#
#
# HOMO-LUMO gap: 0.014747714724147057 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  40.92570828251636
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158716
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198127091
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571582414
# Coulomb Energy                  3051.7165832276446
# Exchange-Correlation Energy     -176.2007428393657
# --------------------------------------------------
# Total Energy                   -1378.8564784355272
# --------------------------------------------------
#
#
#
# Energy difference :  16.451750645341235
#
#
# HOMO-LUMO gap: 0.012539973801935306 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  26.932582172119247
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863944
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022786313
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850554778
# Coulomb Energy                  3003.5375755725090
# Exchange-Correlation Energy     -179.3125720191274
# --------------------------------------------------
# Total Energy                   -1523.5033698391107
# --------------------------------------------------
#
#
#
# Energy difference :  144.6468914035836
#
#
# HOMO-LUMO gap: 0.0030874947609343777 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  13.423370100257783
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488927
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332561853
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671360231
# Coulomb Energy                  2977.4795296015418
# Exchange-Correlation Energy     -178.1026352539681
# --------------------------------------------------
# Total Energy                   -1499.0865279419268
# --------------------------------------------------
#
#
#
# Energy difference :  24.416841897183986
#
#
# HOMO-LUMO gap: 0.031814612726460606 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  12.444575042408506
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146538
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885442300
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462462086
# Coulomb Energy                  3000.9261851726737
# Exchange-Correlation Energy     -180.8962339957857
# --------------------------------------------------
# Total Energy                   -1522.7463472904724
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348545625
#
#
# HOMO-LUMO gap: 0.012952412902293174 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  6.016412544065345
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00012192201393
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025156878
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516681907
# Coulomb Energy                  3041.7824359802030
# Exchange-Correlation Energy     -185.1339645332822
# --------------------------------------------------
# Total Energy                   -1523.4476355699139
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794415418
#
#
# HOMO-LUMO gap: 0.021473549809822856 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  6.2227517052227626
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99995948810567
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888913860
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569991658
# Coulomb Energy                  3063.1248487684197
# Exchange-Correlation Energy     -185.9132949764629
# --------------------------------------------------
# Total Energy                   -1521.9201342696006
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013003133608
#
#
# HOMO-LUMO gap: 0.07988335372946315 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  4.4348485236233985
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846703
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733679970
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444890102
# Coulomb Energy                  3048.3985990983283
# Exchange-Correlation Energy     -185.3448733864825
# --------------------------------------------------
# Total Energy                   -1525.5849593364792
# --------------------------------------------------
#
#
#
# Energy difference :  3.6648250668786204
#
#
# HOMO-LUMO gap: 0.11911980736809455 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.833513309991518
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000381243774
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577373062
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794606
# Coulomb Energy                  3044.2765927793798
# Exchange-Correlation Energy     -184.7849150214389
# --------------------------------------------------
# Total Energy                   -1525.7423647692422
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543276297103
#
#
# HOMO-LUMO gap: 0.10914385151691515 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.437820333605236
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733324
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238684360
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349461
# Coulomb Energy                  3039.9455617679823
# Exchange-Correlation Energy     -184.3161788613710
# --------------------------------------------------
# Total Energy                   -1525.7678971962168
# --------------------------------------------------
#
#
#
# Energy difference :  0.025532426974677946
#
#
# HOMO-LUMO gap: 0.08055636124741997 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.2795602287781217
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976173
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464905851
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862115876
# Coulomb Energy                  3041.4914846757033
# Exchange-Correlation Energy     -184.5235703798656
# --------------------------------------------------
# Total Energy                   -1525.7860021524980
# --------------------------------------------------
#
#
#
# Energy difference :  0.018104956281149498
#
#
# HOMO-LUMO gap: 0.03553321190303271 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.20188173701094397
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000406842974
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555701812
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365256987
# Coulomb Energy                  3040.7248454918813
# Exchange-Correlation Energy     -184.4775892871778
# --------------------------------------------------
# Total Energy                   -1525.7891190091173
# --------------------------------------------------
#
#
#
# Energy difference :  0.003116856619271857
#
#
# HOMO-LUMO gap: 0.044870894865976146 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.07625293104790874
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396572362
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379110256
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553102941
# Coulomb Energy                  3040.4560830346313
# Exchange-Correlation Energy     -184.4308753791002
# --------------------------------------------------
# Total Energy                   -1525.7902311145385
# --------------------------------------------------
#
#
#
# Energy difference :  0.001112105421270826
#
#
# HOMO-LUMO gap: 0.0528566413678032 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.028372083614088498
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003947131023
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669641688
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980799
# Coulomb Energy                  3040.4602645949894
# Exchange-Correlation Energy     -184.4309026475805
# --------------------------------------------------
# Total Energy                   -1525.7903707880173
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967347877041902
#
#
# HOMO-LUMO gap: 0.04994812744079791 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.012785251241968835
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505607
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931423
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318343
# Coulomb Energy                  3040.4067159125907
# Exchange-Correlation Energy     -184.4260067735682
# --------------------------------------------------
# Total Energy                   -1525.7903870916243
# --------------------------------------------------
#
#
#
# Energy difference :  1.630360702620237e-05
#
#
# HOMO-LUMO gap: 0.05083365573097029 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.0060400214333556435
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112016
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856955034
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920928
# Coulomb Energy                  3040.4581957845312
# Exchange-Correlation Energy     -184.4326037898921
# --------------------------------------------------
# Total Energy                   -1525.7903978781105
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786486200231593e-05
#
#
# HOMO-LUMO gap: 0.050686035896576956 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.001965540750479022
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378534
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801126955
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451638
# Coulomb Energy                  3040.4659355248746
# Exchange-Correlation Energy     -184.4328301188927
# --------------------------------------------------
# Total Energy                   -1525.7903988308885
# --------------------------------------------------
#
#
#
# Energy difference :  9.527780093776528e-07
#
#
# HOMO-LUMO gap: 0.05071262125661151 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.0010394322906425542
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780368
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447974
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272611350
# Coulomb Energy                  3040.4701320976405
# Exchange-Correlation Energy     -184.4333553536753
# --------------------------------------------------
# Total Energy                   -1525.7903988090343
# --------------------------------------------------
#
#
#
# Energy difference :  2.1854248188901693e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090343
# -------------------------------------
#
#
#
# Time taken : 32.35 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.42
# Density Fitting                         0.99
#     DF (gamma)                          0.36
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.45
# DIIS                                    0.11
# KS matrix diagonalization               0.41
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         5.7
# Grids construction                      4.58
# Exchange-Correlation Term               9.33
# Misc.                                   3.74
# Complete SCF                            32.35

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.11 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.28 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.07
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.016986010999971768
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.09 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.44
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  14.02 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 15.97 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 20.79 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.2 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  320.00291984078206
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004515
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513774
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513774
#
#
# HOMO-LUMO gap: 1.3453174761632165 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  144.01406386862337
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999672071532
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016245248
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642078617
# Coulomb Energy                  7102.4006978646357
# Exchange-Correlation Energy     -401.0386878050703
# --------------------------------------------------
# Total Energy                   -2175.7881061964836
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705451062
#
#
# HOMO-LUMO gap: 0.003632652817036619 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  71.99427239655762
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247207
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645627858
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936058
# Coulomb Energy                  5771.7138319758415
# Exchange-Correlation Energy     -243.8524720616922
# --------------------------------------------------
# Total Energy                   -2274.5129129944162
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679793262
#
#
# HOMO-LUMO gap: 0.004964611535121344 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  58.100701489654334
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00214404156077
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804043523
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573472036
# Coulomb Energy                  6321.7172809541644
# Exchange-Correlation Energy     -278.3781618573602
# --------------------------------------------------
# Total Energy                   -2158.4748827997282
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019468796
#
#
# HOMO-LUMO gap: 0.014474030560502615 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  53.369975492303695
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00180767720957
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768212215
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230006819
# Coulomb Energy                  6361.2336350666583
# Exchange-Correlation Energy     -281.9436333440973
# --------------------------------------------------
# Total Energy                   -2182.5642309373643
# --------------------------------------------------
#
#
#
# Energy difference :  24.08934813763608
#
#
# HOMO-LUMO gap: 0.008841693993979188 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  42.83901509486862
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009908414894
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446997081
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382081525
# Coulomb Energy                  6294.5110601806919
# Exchange-Correlation Energy     -283.9707682331765
# --------------------------------------------------
# Total Energy                   -2345.8009933834273
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676244606304
#
#
# HOMO-LUMO gap: 0.007160714255554007 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  32.18186260043885
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9997863855179
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019081180
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650763562
# Coulomb Energy                  6214.1516556250917
# Exchange-Correlation Energy     -284.6344014151562
# --------------------------------------------------
# Total Energy                   -2343.5239614612110
# --------------------------------------------------
#
#
#
# Energy difference :  2.277031922216338
#
#
# HOMO-LUMO gap: 0.0024503750121980944 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  33.32333313965249
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156511
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115045751
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996834594
# Coulomb Energy                  6284.6237009928509
# Exchange-Correlation Energy     -286.3084442723899
# --------------------------------------------------
# Total Energy                   -2352.7413339400400
# --------------------------------------------------
#
#
#
# Energy difference :  9.21737247882902
#
#
# HOMO-LUMO gap: 0.006673318416298063 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  26.0982819155999
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026797845874
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383597392
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896529821
# Coulomb Energy                  6418.8046173095699
# Exchange-Correlation Energy     -305.3162932881926
# --------------------------------------------------
# Total Energy                   -2410.9382035247654
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686958472539
#
#
# HOMO-LUMO gap: 0.007960539580509504 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  17.53469864240849
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057345305
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201897847
# Coulomb Energy                  6329.9135850896437
# Exchange-Correlation Energy     -297.7524519062919
# --------------------------------------------------
# Total Energy                   -2373.3942312007784
# --------------------------------------------------
#
#
#
# Energy difference :  37.543972323986964
#
#
# HOMO-LUMO gap: 0.013997838540082769 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  16.42070464508867
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998237983229
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814727320
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928356360
# Coulomb Energy                  6324.0705156652666
# Exchange-Correlation Energy     -296.6169927427815
# --------------------------------------------------
# Total Energy                   -2423.4444445539966
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335321817
#
#
# HOMO-LUMO gap: 0.005801716886773695 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  17.913629073847922
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082557727933
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871578256
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553257664
# Coulomb Energy                  6269.4959589825003
# Exchange-Correlation Energy     -292.3687260435935
# --------------------------------------------------
# Total Energy                   -2388.5334777325361
# --------------------------------------------------
#
#
#
# Energy difference :  34.91096682146053
#
#
# HOMO-LUMO gap: 0.011739724626587802 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  18.86481092823599
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008953428889
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999712880
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986963570
# Coulomb Energy                  6304.9912271445592
# Exchange-Correlation Energy     -292.7049362975549
# --------------------------------------------------
# Total Energy                   -2419.7690892673108
# --------------------------------------------------
#
#
#
# Energy difference :  31.235611534774762
#
#
# HOMO-LUMO gap: 0.001699592570239189 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  14.268938603155409
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001543150053
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930753656
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204765782
# Coulomb Energy                  6279.2250589781816
# Exchange-Correlation Energy     -293.0502585458465
# --------------------------------------------------
# Total Energy                   -2419.7439510058393
# --------------------------------------------------
#
#
#
# Energy difference :  0.025138261471511214
#
#
# HOMO-LUMO gap: 0.0058464311914744604 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  12.512861011349134
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002651218395
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104138468
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140341630
# Coulomb Energy                  6304.4543925154267
# Exchange-Correlation Energy     -294.2073055524057
# --------------------------------------------------
# Total Energy                   -2431.0698882560482
# --------------------------------------------------
#
#
#
# Energy difference :  11.32593725020888
#
#
# HOMO-LUMO gap: 0.016452349508622677 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  10.313139444218328
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775217
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763846430
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614151561
# Coulomb Energy                  6320.4324015817401
# Exchange-Correlation Energy     -296.9899338045611
# --------------------------------------------------
# Total Energy                   -2429.5155260316933
# --------------------------------------------------
#
#
#
# Energy difference :  1.554362224354918
#
#
# HOMO-LUMO gap: 0.005064351012750212 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  8.08497266953513
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00009764058916
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466427508
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611198552
# Coulomb Energy                  6316.3510406859650
# Exchange-Correlation Energy     -296.7435745383222
# --------------------------------------------------
# Total Energy                   -2437.9484982146396
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972182946287
#
#
# HOMO-LUMO gap: 0.05893038867537516 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  4.102604850278836
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011810611755
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611029991021
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451733180
# Coulomb Energy                  6313.1881517235443
# Exchange-Correlation Energy     -295.9055099897085
# --------------------------------------------------
# Total Energy                   -2441.0025949313340
# --------------------------------------------------
#
#
#
# Energy difference :  3.054096716694403
#
#
# HOMO-LUMO gap: 0.005337250525693851 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 1.06 seconds
#
#
#
# Density matrix difference norm:  6.254076481162272
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361987
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051754377
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545137384
# Coulomb Energy                  6280.4277633990660
# Exchange-Correlation Energy     -293.2139724474187
# --------------------------------------------------
# Total Energy                   -2436.9286385494379
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956381896096
#
#
# HOMO-LUMO gap: 0.011871839727822416 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  7.413375410952906
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002633558746
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726554809957
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918805226
# Coulomb Energy                  6298.7681987306532
# Exchange-Correlation Energy     -294.0996241343149
# --------------------------------------------------
# Total Energy                   -2439.1315678435203
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292940824234
#
#
# HOMO-LUMO gap: 0.10362999798091621 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  4.188397589522632
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001162436133
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485028299
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696466903
# Coulomb Energy                  6305.6013415991783
# Exchange-Correlation Energy     -295.1700654131106
# --------------------------------------------------
# Total Energy                   -2441.2043815094585
# --------------------------------------------------
#
#
#
# Energy difference :  2.072813665938156
#
#
# HOMO-LUMO gap: 0.030358347409667863 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  1.0881186801020848
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00010584350065
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355833125
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042565156
# Coulomb Energy                  6306.4146008177713
# Exchange-Correlation Energy     -295.1986114170119
# --------------------------------------------------
# Total Energy                   -2441.2281207654241
# --------------------------------------------------
#
#
#
# Energy difference :  0.023739255965665507
#
#
# HOMO-LUMO gap: 0.10156738660100223 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.6147083204502654
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011386478906
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391423012
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706645348
# Coulomb Energy                  6305.3788664347921
# Exchange-Correlation Energy     -295.1059315049788
# --------------------------------------------------
# Total Energy                   -2441.3391123873389
# --------------------------------------------------
#
#
#
# Energy difference :  0.11099162191476353
#
#
# HOMO-LUMO gap: 0.12914420503366855 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.22866753065222306
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001129709716
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680215909713
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454824665
# Coulomb Energy                  6306.4753103290950
# Exchange-Correlation Energy     -295.2425453759002
# --------------------------------------------------
# Total Energy                   -2441.3433899946958
# --------------------------------------------------
#
#
#
# Energy difference :  0.004277607356925728
#
#
# HOMO-LUMO gap: 0.11914092708015714 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.13316828782675635
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924006
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663317244
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009434044
# Coulomb Energy                  6305.4375957430548
# Exchange-Correlation Energy     -295.1178679619689
# --------------------------------------------------
# Total Energy                   -2441.3482164466204
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451924600406
#
#
# HOMO-LUMO gap: 0.0775860996136681 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.16794684415580782
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011918273225
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810482655
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356955344
# Coulomb Energy                  6304.4474550038667
# Exchange-Correlation Energy     -294.9863691584100
# --------------------------------------------------
# Total Energy                   -2441.3482383466599
# --------------------------------------------------
#
#
#
# Energy difference :  2.1900039428146556e-05
#
#
# HOMO-LUMO gap: 0.08220407417022232 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.08195634544631693
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011761289034
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560662231
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184227848
# Coulomb Energy                  6305.2666287319889
# Exchange-Correlation Energy     -295.0991774795089
# --------------------------------------------------
# Total Energy                   -2441.3500652303437
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836838615243
#
#
# HOMO-LUMO gap: 0.08681393248123329 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.030947649977293216
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711136
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449608883
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969467043
# Coulomb Energy                  6305.1999901383879
# Exchange-Correlation Energy     -295.0882138897823
# --------------------------------------------------
# Total Energy                   -2441.3501506049652
# --------------------------------------------------
#
#
#
# Energy difference :  8.537462144886376e-05
#
#
# HOMO-LUMO gap: 0.08605512219194543 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.01535942010687501
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011741243856
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082986641
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754509104
# Coulomb Energy                  6305.1611656009600
# Exchange-Correlation Energy     -295.0851653175708
# --------------------------------------------------
# Total Energy                   -2441.3502114037501
# --------------------------------------------------
#
#
#
# Energy difference :  6.079878494347213e-05
#
#
# HOMO-LUMO gap: 0.08610559555055299 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.005850728266073882
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173080263
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341358024
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624064697
# Coulomb Energy                  6305.1739654234225
# Exchange-Correlation Energy     -295.0859344062351
# --------------------------------------------------
# Total Energy                   -2441.3502195515302
# --------------------------------------------------
#
#
#
# Energy difference :  8.147780135914218e-06
#
#
# HOMO-LUMO gap: 0.08627753380274392 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0022687655623265758
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730379316
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171300867
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318232
# Coulomb Energy                  6305.1767750459767
# Exchange-Correlation Energy     -295.0862921108161
# --------------------------------------------------
# Total Energy                   -2441.3502203024891
# --------------------------------------------------
#
#
#
# Energy difference :  7.509588613174856e-07
#
#
# HOMO-LUMO gap: 0.08629954674315521 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0014216232797952403
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161183
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335500927
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841015629
# Coulomb Energy                  6305.1678310989028
# Exchange-Correlation Energy     -295.0851232567571
# --------------------------------------------------
# Total Energy                   -2441.3502204457691
# --------------------------------------------------
#
#
#
# Energy difference :  1.4327997632790357e-07
#
#
# HOMO-LUMO gap: 0.08625864034206024 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0007905213596902721
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000117319267
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319180
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598402
# Coulomb Energy                  6305.1716231999053
# Exchange-Correlation Energy     -295.0855737005004
# --------------------------------------------------
# Total Energy                   -2441.3502206120593
# --------------------------------------------------
#
#
#
# Energy difference :  1.6629019228275865e-07
#
#
# HOMO-LUMO gap: 0.08626853544518331 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.00028632021569607435
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731389475
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851890720
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651371475
# Coulomb Energy                  6305.1740152928433
# Exchange-Correlation Energy     -295.0859370217385
# --------------------------------------------------
# Total Energy                   -2441.3502206202047
# --------------------------------------------------
#
#
#
# Energy difference :  8.145434549078345e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206202047
# -------------------------------------
#
#
#
# Time taken : 93.55 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           20.99
# Density Fitting                         3.48
#     DF (gamma)                          1.12
#     DF (coeff)                          0.14
#     DF (Jtri)                           1.84
# DIIS                                    0.25
# KS matrix diagonalization               1.24
# One electron Integrals (S, T, Vnuc)     0.11
# Coulomb Integrals (2c2e + 3c2e)         14.02
# Grids construction                      15.97
# Exchange-Correlation Term               30.12
# Misc.                                   7.38
# Complete SCF                            93.55

# %% [markdown]
# ### Benchmark #4 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.16 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.47 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.12
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.03761173999998846
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.16 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.93
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  31.64 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 48.99 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 53.85 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.09 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00086590367766
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182646
# Exchange-Correlation Energy     -158.3094688039744
# --------------------------------------------------
# Total Energy                    -881.4876584497488
# --------------------------------------------------
#
#
#
# Energy difference :  881.4876584497488
#
#
# HOMO-LUMO gap: 0.6897308990669448 au
# HOMO-LUMO gap: 18.768 eV
#
#
# Time taken for the previous iteration: 2.64 seconds
#
#
#
# Density matrix difference norm:  177.4118335697671
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994638079414
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3704438290006
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5625483778222
# Coulomb Energy                 12707.6655166372402
# Exchange-Correlation Energy     -589.0109863900016
# --------------------------------------------------
# Total Energy                   -3195.6961127770173
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2084543272686
#
#
# HOMO-LUMO gap: 0.002621088547672956 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  86.10072559735109
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00067184576307
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.0784549149612
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9542974310098
# Coulomb Energy                 10864.6104283837922
# Exchange-Correlation Energy     -358.7264210078106
# --------------------------------------------------
# Total Energy                   -3357.7828976810470
# --------------------------------------------------
#
#
#
# Energy difference :  162.08678490402963
#
#
# HOMO-LUMO gap: 0.0025322925276032703 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  65.13264429183545
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00008159556387
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9266970306853
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4589790563591
# Coulomb Energy                 11125.2421950897642
# Exchange-Correlation Energy     -407.6867498868939
# --------------------------------------------------
# Total Energy                   -3374.4550203445324
# --------------------------------------------------
#
#
#
# Energy difference :  16.672122663485425
#
#
# HOMO-LUMO gap: 0.004414389958014769 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  63.85668121082955
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995348429839
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.2877136080897
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.8757373778171
# Coulomb Energy                 12063.6748125273807
# Exchange-Correlation Energy     -415.0710986786356
# --------------------------------------------------
# Total Energy                   -3056.3510099546056
# --------------------------------------------------
#
#
#
# Energy difference :  318.10401038992677
#
#
# HOMO-LUMO gap: 0.0066441473365403125 au
# HOMO-LUMO gap: 0.181 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  54.59169061259599
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002691352941
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.5088611897954
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.3924608743846
# Coulomb Energy                 11512.9997141051936
# Exchange-Correlation Energy     -417.4553406800692
# --------------------------------------------------
# Total Energy                   -3536.1147744633654
# --------------------------------------------------
#
#
#
# Energy difference :  479.7637645087598
#
#
# HOMO-LUMO gap: 0.0010123615003165025 au
# HOMO-LUMO gap: 0.028 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  51.11495004718471
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9997429477986
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.1797883141953
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.7800541101315
# Coulomb Energy                 11567.1010375806218
# Exchange-Correlation Energy     -419.4337655480624
# --------------------------------------------------
# Total Energy                   -3074.2752097445828
# --------------------------------------------------
#
#
#
# Energy difference :  461.83956471878264
#
#
# HOMO-LUMO gap: 0.00469747168965573 au
# HOMO-LUMO gap: 0.128 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  44.74482645557587
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99965507497245
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.4126884147481
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6364207739666
# Coulomb Energy                 11495.5483931944582
# Exchange-Correlation Energy     -423.7795770218284
# --------------------------------------------------
# Total Energy                   -3532.5501990412286
# --------------------------------------------------
#
#
#
# Energy difference :  458.2749892966458
#
#
# HOMO-LUMO gap: 0.0004633975977318544 au
# HOMO-LUMO gap: 0.013 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  20.712738433883164
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999545434493
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.2739432969247
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.0351193153779
# Coulomb Energy                 11580.0530324235006
# Exchange-Correlation Energy     -439.2769213936846
# --------------------------------------------------
# Total Energy                   -3535.0054605248097
# --------------------------------------------------
#
#
#
# Energy difference :  2.4552614835811255
#
#
# HOMO-LUMO gap: 0.0076028978269829794 au
# HOMO-LUMO gap: 0.207 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  17.82978163369711
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002510939662
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28135.5805667562745
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3632.4560410659492
# Coulomb Energy                 11640.5650664325003
# Exchange-Correlation Energy     -443.9779460015567
# --------------------------------------------------
# Total Energy                   -3536.0801528324573
# --------------------------------------------------
#
#
#
# Energy difference :  1.0746923076476378
#
#
# HOMO-LUMO gap: 0.004336285694745798 au
# HOMO-LUMO gap: 0.118 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  21.750787716301694
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000097649701
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27873.9019924414533
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3557.6224523312862
# Coulomb Energy                 11493.5519512111459
# Exchange-Correlation Energy     -433.3671342115261
# --------------------------------------------------
# Total Energy                   -3485.6374706836268
# --------------------------------------------------
#
#
#
# Energy difference :  50.4426821488305
#
#
# HOMO-LUMO gap: 0.0179997827934604 au
# HOMO-LUMO gap: 0.490 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  18.30482000838419
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00012189863753
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28089.3481558540443
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3573.7337556686743
# Coulomb Energy                 11601.6672611034155
# Exchange-Correlation Energy     -437.8374210853353
# --------------------------------------------------
# Total Energy                   -3581.3273077403665
# --------------------------------------------------
#
#
#
# Energy difference :  95.68983705673963
#
#
# HOMO-LUMO gap: 0.00980988546970921 au
# HOMO-LUMO gap: 0.267 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  15.603590952176082
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000084455461
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27851.1830276676083
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3504.4630744103360
# Coulomb Energy                 11481.6334491235757
# Exchange-Correlation Energy     -426.3111912575116
# --------------------------------------------------
# Total Energy                   -3520.9404429642836
# --------------------------------------------------
#
#
#
# Energy difference :  60.3868647760828
#
#
# HOMO-LUMO gap: 0.0012824830333525855 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  15.43406995385409
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99987880334277
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27993.2533756708908
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3536.1983080971859
# Coulomb Energy                 11535.6719765538619
# Exchange-Correlation Energy     -432.7365139115404
# --------------------------------------------------
# Total Energy                   -3583.6623525044615
# --------------------------------------------------
#
#
#
# Energy difference :  62.721909540177876
#
#
# HOMO-LUMO gap: 0.004883606537561841 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  4.995181881591587
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00002517018714
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27981.3353300624221
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9571899845896
# Coulomb Energy                 11529.5195448956583
# Exchange-Correlation Energy     -431.6645539248618
# --------------------------------------------------
# Total Energy                   -3583.0658966801111
# --------------------------------------------------
#
#
#
# Energy difference :  0.5964558243504143
#
#
# HOMO-LUMO gap: 0.047205148488494456 au
# HOMO-LUMO gap: 1.285 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  4.204244624970053
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00002943939165
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27999.1239636996725
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.4625398659609
# Coulomb Energy                 11537.2109868197531
# Exchange-Correlation Energy     -433.3658591833899
# --------------------------------------------------
# Total Energy                   -3585.3590437704261
# --------------------------------------------------
#
#
#
# Energy difference :  2.2931470903149602
#
#
# HOMO-LUMO gap: 0.10565060581388072 au
# HOMO-LUMO gap: 2.875 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.9287339138884593
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000198744154
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1956996791268
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.6973773603231
# Coulomb Energy                 11540.9990077032598
# Exchange-Correlation Energy     -433.6709884726599
# --------------------------------------------------
# Total Energy                   -3585.7130506612793
# --------------------------------------------------
#
#
#
# Energy difference :  0.3540068908532703
#
#
# HOMO-LUMO gap: 0.08160177747255404 au
# HOMO-LUMO gap: 2.220 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.4709949236727431
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001543753876
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27997.2512007375699
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3537.3766041928466
# Coulomb Energy                 11536.7451394825184
# Exchange-Correlation Energy     -433.0466479800895
# --------------------------------------------------
# Total Energy                   -3585.7188526153714
# --------------------------------------------------
#
#
#
# Energy difference :  0.005801954092021333
#
#
# HOMO-LUMO gap: 0.09622541470702817 au
# HOMO-LUMO gap: 2.618 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.2534565688330063
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001674477966
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.5564264282766
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5447394757525
# Coulomb Energy                 11540.2918406389508
# Exchange-Correlation Energy     -433.4718308594118
# --------------------------------------------------
# Total Energy                   -3585.7344247460624
# --------------------------------------------------
#
#
#
# Energy difference :  0.015572130690998165
#
#
# HOMO-LUMO gap: 0.10308245697326643 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.10396164385865134
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001728845274
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6842592924368
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6972363175955
# Coulomb Energy                 11539.1501777849444
# Exchange-Correlation Energy     -433.3563238661242
# --------------------------------------------------
# Total Energy                   -3585.7359166290971
# --------------------------------------------------
#
#
#
# Energy difference :  0.0014918830347596668
#
#
# HOMO-LUMO gap: 0.10375679440998092 au
# HOMO-LUMO gap: 2.823 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.04580934956675784
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163999441
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0103516758245
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8693000461340
# Coulomb Energy                 11539.3276465300842
# Exchange-Correlation Energy     -433.3803352187931
# --------------------------------------------------
# Total Energy                   -3585.7364878914759
# --------------------------------------------------
#
#
#
# Energy difference :  0.0005712623787985649
#
#
# HOMO-LUMO gap: 0.10309625430470609 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.029554320906140324
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163506748
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8156482100094
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7421797901443
# Coulomb Energy                 11539.2423484056399
# Exchange-Correlation Energy     -433.3626933872962
# --------------------------------------------------
# Total Energy                   -3585.7365609745975
# --------------------------------------------------
#
#
#
# Energy difference :  7.308312160603236e-05
#
#
# HOMO-LUMO gap: 0.10314551102118329 au
# HOMO-LUMO gap: 2.807 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.017959400048003227
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000161248511
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0456961203272
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8499452673273
# Coulomb Energy                 11539.3793324480102
# Exchange-Correlation Energy     -433.3773972593573
# --------------------------------------------------
# Total Energy                   -3585.7365632374258
# --------------------------------------------------
#
#
#
# Energy difference :  2.262828274979256e-06
#
#
# HOMO-LUMO gap: 0.10320225770345587 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.010130198011831753
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162381156
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9409515347143
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096975089552
# Coulomb Energy                 11539.3092434358186
# Exchange-Correlation Energy     -433.3718359108015
# --------------------------------------------------
# Total Energy                   -3585.7365940738218
# --------------------------------------------------
#
#
#
# Energy difference :  3.083639603573829e-05
#
#
# HOMO-LUMO gap: 0.1032623378463739 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.0030654454662070083
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162908748
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9648930367184
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8217790803292
# Coulomb Energy                 11539.3227881265593
# Exchange-Correlation Energy     -433.3735230060607
# --------------------------------------------------
# Total Energy                   -3585.7365964089677
# --------------------------------------------------
#
#
#
# Energy difference :  2.3351458366960287e-06
#
#
# HOMO-LUMO gap: 0.10324998823649667 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.0010174384115492808
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000016275485
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9526818541854
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8145317572653
# Coulomb Energy                 11539.3168310503206
# Exchange-Correlation Energy     -433.3725300790771
# --------------------------------------------------
# Total Energy                   -3585.7365966987545
# --------------------------------------------------
#
#
#
# Energy difference :  2.897868398576975e-07
#
#
# HOMO-LUMO gap: 0.1032360609897731 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.00037633001323376166
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001627333916
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9484625881305
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8126747894744
# Coulomb Energy                 11539.3142180581817
# Exchange-Correlation Energy     -433.3722793838203
# --------------------------------------------------
# Total Energy                   -3585.7365966973721
# --------------------------------------------------
#
#
#
# Energy difference :  1.382431946694851e-09
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596697372
# -------------------------------------
#
#
#
# Time taken : 203.03 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           53.94
# Density Fitting                         4.9
#     DF (gamma)                          1.62
#     DF (coeff)                          0.14
#     DF (Jtri)                           2.49
# DIIS                                    0.5
# KS matrix diagonalization               1.99
# One electron Integrals (S, T, Vnuc)     0.16
# Coulomb Integrals (2c2e + 3c2e)         31.64
# Grids construction                      48.99
# Exchange-Correlation Term               54.98
# Misc.                                   5.93
# Complete SCF                            203.03

# %% [markdown]
# ## Dynamic Precision On

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.02 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.03 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0007571060000373109
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.03
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.66 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.3 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.56 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.02 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.00036
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709559
# Exchange-Correlation Energy      -16.0363521575928
# --------------------------------------------------
# Total Energy                     -93.1572674613903
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726746139035
#
#
# HOMO-LUMO gap: 2.643230907565348 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.03 seconds
#
#
#
# Density matrix difference norm:  43.34737619555102
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065057091786
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632825303972
# Coulomb Energy                   501.1179471569614
# Exchange-Correlation Energy      -62.5998191833496
# --------------------------------------------------
# Total Energy                    -340.0671181610463
# --------------------------------------------------
#
#
#
# Energy difference :  246.90985069965592
#
#
# HOMO-LUMO gap: 0.004895022244832237 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  28.6122351178116
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000103
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015698822030
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404485376361
# Coulomb Energy                   293.3105498762691
# Exchange-Correlation Energy      -37.4191246032715
# --------------------------------------------------
# Total Energy                    -355.5117190274458
# --------------------------------------------------
#
#
#
# Energy difference :  15.444600866399526
#
#
# HOMO-LUMO gap: 0.04090739403861976 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  21.394359863558986
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6801885014215
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079075502337
# Coulomb Energy                   367.2116009574117
# Exchange-Correlation Energy      -44.5831069946289
# --------------------------------------------------
# Total Energy                    -380.5858099442814
# --------------------------------------------------
#
#
#
# Energy difference :  25.074090916835644
#
#
# HOMO-LUMO gap: 0.018045886670271113 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  5.193654584595105
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853091437980
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987272575055
# Coulomb Energy                   364.3594810690279
# Exchange-Correlation Energy      -44.5593376159668
# --------------------------------------------------
# Total Energy                    -378.6284613891079
# --------------------------------------------------
#
#
#
# Energy difference :  1.957348555173553
#
#
# HOMO-LUMO gap: 0.08497524067676011 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  4.776043862261576
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113206578665
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536884928258
# Coulomb Energy                   368.1595743595658
# Exchange-Correlation Energy      -45.0864944458008
# --------------------------------------------------
# Total Energy                    -381.1265752071522
# --------------------------------------------------
#
#
#
# Energy difference :  2.4981138180443168
#
#
# HOMO-LUMO gap: 0.1415334419529675 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5199018409380655
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759596179665
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620346900061
# Coulomb Energy                   369.0651771886137
# Exchange-Correlation Energy      -45.1361885070801
# --------------------------------------------------
# Total Energy                    -381.2269592023032
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038399515099172
#
#
# HOMO-LUMO gap: 0.13505775586789368 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.3314180487714345
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685675927105
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352796433354
# Coulomb Energy                   369.6332836147054
# Exchange-Correlation Energy      -45.2082176208496
# --------------------------------------------------
# Total Energy                    -381.2502449113959
# --------------------------------------------------
#
#
#
# Energy difference :  0.02328570909270411
#
#
# HOMO-LUMO gap: 0.019481785628195417 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5819568575603696
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471003749786
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753305507266
# Coulomb Energy                   374.0875566303236
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611925295
# --------------------------------------------------
#
#
#
# Energy difference :  0.13181628113363786
#
#
# HOMO-LUMO gap: 0.1260206028673171 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.45972180966436393
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167220502075
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482882177571
# Coulomb Energy                   377.3936789835882
# Exchange-Correlation Energy      -46.1032218933105
# --------------------------------------------------
# Total Energy                    -381.4199996980491
# --------------------------------------------------
#
#
#
# Energy difference :  0.037938505519605314
#
#
# HOMO-LUMO gap: 0.16611335836171678 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.14506608197973142
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6773853124541
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4956800494425
# Coulomb Energy                   377.1713347422637
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261849805306
# --------------------------------------------------
#
#
#
# Energy difference :  0.006185282481510512
#
#
# HOMO-LUMO gap: 0.18109759450152488 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.05597222743245701
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466847521755
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5464934880602
# Coulomb Energy                   377.1955765820829
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266051366882
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004201561575882806
#
#
# HOMO-LUMO gap: 0.18093185581848173 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.025624236735057704
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6790963044441
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228702866757
# Coulomb Energy                   377.1480797572158
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267301905501
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012505386189332057
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050740102773896 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.008409527737975623
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749483557
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758561710762
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145457199121
# Coulomb Energy                   377.1522579825735
# Exchange-Correlation Energy      -46.0763602020217
# --------------------------------------------------
# Total Energy                    -381.4274356264889
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007054359387552722
#
#
# HOMO-LUMO gap: 0.1805594802035723 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.002642070162370202
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503220885
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547018762967
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032841210963
# Coulomb Energy                   377.1410362410171
# Exchange-Correlation Energy      -46.0750324272110
# --------------------------------------------------
# Total Energy                    -381.4274368972708
# --------------------------------------------------
#
#
#
# Energy difference :  1.2707819223578554e-06
#
#
# HOMO-LUMO gap: 0.18056589277638752 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.0017678577828647614
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749796219
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715734084783
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117333671189
# Coulomb Energy                   377.1506245998462
# Exchange-Correlation Energy      -46.0761995168087
# --------------------------------------------------
# Total Energy                    -381.4274379141984
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169276265514782e-06
#
#
# HOMO-LUMO gap: 0.18057813394079641 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.0018263201030401211
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749434343
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890928902599
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201140686536
# Coulomb Energy                   377.1610735625143
# Exchange-Correlation Energy      -46.0775108681124
# --------------------------------------------------
# Total Energy                    -381.4274390830808
# --------------------------------------------------
#
#
#
# Energy difference :  1.168882363344892e-06
#
#
# HOMO-LUMO gap: 0.1806905241191542 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0015079010419393937
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749797207
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793134395730
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150712631819
# Coulomb Energy                   377.1557639882258
# Exchange-Correlation Energy      -46.0769384184011
# --------------------------------------------------
# Total Energy                    -381.4274395624429
# --------------------------------------------------
#
#
#
# Energy difference :  4.793620860255032e-07
#
#
# HOMO-LUMO gap: 0.1806442426997871 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0004667745443684885
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749830364
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995676825
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900943654
# Coulomb Energy                   377.1550630849266
# Exchange-Correlation Energy      -46.0768702738874
# --------------------------------------------------
# Total Energy                    -381.4274396181544
# --------------------------------------------------
#
#
#
# Energy difference :  5.5711552704451606e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743961815444
# -------------------------------------
#
#
#
# Time taken : 8.0 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.59
# Density Fitting                         0.22
#     DF (gamma)                          0.07
#     DF (coeff)                          0.06
#     DF (Jtri)                           0.07
# DIIS                                    0.09
# KS matrix diagonalization               0.17
# One electron Integrals (S, T, Vnuc)     0.02
# Coulomb Integrals (2c2e + 3c2e)         0.66
# Grids construction                      0.3
# Exchange-Correlation Term               5.0
# Misc.                                   0.95
# Complete SCF                            8.0

# %% [markdown]
# ### Benchmark #5 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.07 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.02
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0031047329999864814
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.06
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  1.55 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.97 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.85 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091871
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371791
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120583
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961205834
#
#
# HOMO-LUMO gap: 1.765506846853691 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.15 seconds
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Density matrix difference norm:  66.88323621963103
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816190541108
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207667032923
# Coulomb Energy                  1272.5916580546036
# Exchange-Correlation Energy     -125.2197875976562
# --------------------------------------------------
# Total Energy                    -680.0824357766392
# --------------------------------------------------
#
#
#
# Energy difference :  494.6338161645808
#
#
# HOMO-LUMO gap: 0.0003950011727171243 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  39.27352499723653
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00123
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671433349673
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861190137541
# Coulomb Energy                   861.6520441623134
# Exchange-Correlation Energy      -75.4418258666992
# --------------------------------------------------
# Total Energy                    -709.3642599083673
# --------------------------------------------------
#
#
#
# Energy difference :  29.281824131728172
#
#
# HOMO-LUMO gap: 0.027815450819430952 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  28.145155581076423
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982803832469
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525456748254
# Coulomb Energy                  1000.6416364368741
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464596250185
# --------------------------------------------------
#
#
#
# Energy difference :  24.382199716651144
#
#
# HOMO-LUMO gap: 0.006873749881573535 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  18.10141834313481
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394527851624
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643187419814
# Coulomb Energy                  1039.7364542095504
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035005987230
# --------------------------------------------------
#
#
#
# Energy difference :  44.14295902629544
#
#
# HOMO-LUMO gap: 0.009401448614770366 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  13.030477987715479
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9282389259406
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4698006524382
# Coulomb Energy                  1004.3617280007685
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228912062833
# --------------------------------------------------
#
#
#
# Energy difference :  60.01939060756024
#
#
# HOMO-LUMO gap: 0.024324072238723002 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  7.651670854473983
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2544021126960
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338936837765
# Coulomb Energy                   997.3405126595253
# Exchange-Correlation Energy      -89.6696014404297
# --------------------------------------------------
# Total Energy                    -755.2430510925919
# --------------------------------------------------
#
#
#
# Energy difference :  5.62015988630867
#
#
# HOMO-LUMO gap: 0.001291144604705391 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  6.531101616772365
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00024
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9936579820919
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455789648775
# Coulomb Energy                  1008.9226915946189
# Exchange-Correlation Energy      -89.8105392456055
# --------------------------------------------------
# Total Energy                    -754.8293805509692
# --------------------------------------------------
#
#
#
# Energy difference :  0.4136705416227642
#
#
# HOMO-LUMO gap: 0.015385820590551477 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  7.342496665081079
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6262624591955
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2044952018840
# Coulomb Energy                  1033.2839477035870
# Exchange-Correlation Energy      -92.8136062622070
# --------------------------------------------------
# Total Energy                    -754.2448796986994
# --------------------------------------------------
#
#
#
# Energy difference :  0.5845008522697981
#
#
# HOMO-LUMO gap: 0.21170875276172113 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  6.051894841145897
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9768678306514
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1052029884540
# Coulomb Energy                  1046.8939537716690
# Exchange-Correlation Energy      -94.6927185058594
# --------------------------------------------------
# Total Energy                    -761.9638834591558
# --------------------------------------------------
#
#
#
# Energy difference :  7.719003760456417
#
#
# HOMO-LUMO gap: 0.021091309546645995 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  4.592875660610385
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186855995906
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7141199965264
# Coulomb Energy                  1016.5841277024902
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8409669786547
# --------------------------------------------------
#
#
#
# Energy difference :  2.1229164805010896
#
#
# HOMO-LUMO gap: 0.08795039070406525 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  4.1999895481057195
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5723515211639
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4484787544261
# Coulomb Energy                  1025.9225300386840
# Exchange-Correlation Energy      -92.2370071411133
# --------------------------------------------------
# Total Energy                    -762.7318037519351
# --------------------------------------------------
#
#
#
# Energy difference :  2.890836773280398
#
#
# HOMO-LUMO gap: 0.14484204659634464 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.908746490944468
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899373570759
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303494845884
# Coulomb Energy                  1024.4799986332991
# Exchange-Correlation Energy      -92.1533355712891
# --------------------------------------------------
# Total Energy                    -762.8263786932453
# --------------------------------------------------
#
#
#
# Energy difference :  0.09457494131015665
#
#
# HOMO-LUMO gap: 0.09120404031679878 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.3386027843452742
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063892320035
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273756101023
# Coulomb Energy                  1024.8155177525762
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565118248468
# --------------------------------------------------
#
#
#
# Energy difference :  0.030133131601587593
#
#
# HOMO-LUMO gap: 0.10812689188164717 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.1334222564574074
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7708255821544
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490595663788
# Coulomb Energy                  1024.3963949184620
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586794112341
# --------------------------------------------------
#
#
#
# Energy difference :  0.0021675863872587797
#
#
# HOMO-LUMO gap: 0.11558371275268736 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.05240839356068907
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028429110360
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1554026276490
# Coulomb Energy                  1024.6505254722638
# Exchange-Correlation Energy      -92.1691741943359
# --------------------------------------------------
# Total Energy                    -762.8595428882272
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008634769931177289
#
#
# HOMO-LUMO gap: 0.11553038776447574 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.014069154512155692
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000182668064
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543966683543
# Coulomb Energy                  1024.5347567239819
# Exchange-Correlation Energy      -92.1552658081055
# --------------------------------------------------
# Total Energy                    -762.8595845653435
# --------------------------------------------------
#
#
#
# Energy difference :  4.1677116314531304e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.11964639501902684 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.015807679634366217
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745386903
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0804004061397
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978111223710
# Coulomb Energy                  1024.5775782367564
# Exchange-Correlation Energy      -92.1624890120984
# --------------------------------------------------
# Total Energy                    -762.8609539418790
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013693765354219067
#
#
# HOMO-LUMO gap: 0.11847998783943478 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.008700647363477705
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741300212
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328883401889
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722859236798
# Coulomb Energy                  1024.5524823629689
# Exchange-Correlation Energy      -92.1594115638129
# --------------------------------------------------
# Total Energy                    -762.8609855001214
# --------------------------------------------------
#
#
#
# Energy difference :  3.1558242426399374e-05
#
#
# HOMO-LUMO gap: 0.11834733111850755 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.002054169493805261
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000073980724
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503357175853
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805127357858
# Coulomb Energy                  1024.5630588206211
# Exchange-Correlation Energy      -92.1607682715480
# --------------------------------------------------
# Total Energy                    -762.8609863154945
# --------------------------------------------------
#
#
#
# Energy difference :  8.153731414495269e-07
#
#
# HOMO-LUMO gap: 0.11844996057150241 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0022801328581614324
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742287065
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365090791593
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734627329417
# Coulomb Energy                  1024.5553051028264
# Exchange-Correlation Energy      -92.1597918827559
# --------------------------------------------------
# Total Energy                    -762.8609870089153
# --------------------------------------------------
#
#
#
# Energy difference :  6.934208158781985e-07
#
#
# HOMO-LUMO gap: 0.11849896270743125 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.0021211572562577787
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742172217
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510304663958
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0798004672702
# Coulomb Energy                  1024.5646273398493
# Exchange-Correlation Energy      -92.1609318640493
# --------------------------------------------------
# Total Energy                    -762.8609884060938
# --------------------------------------------------
#
#
#
# Energy difference :  1.3971784937893972e-06
#
#
# HOMO-LUMO gap: 0.11838531428731466 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0014188420508463742
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000007416201
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635535001097
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852197539878
# Coulomb Energy                  1024.5726718594947
# Exchange-Correlation Energy      -92.1618730905871
# --------------------------------------------------
# Total Energy                    -762.8609888599822
# --------------------------------------------------
#
#
#
# Energy difference :  4.538883331406396e-07
#
#
# HOMO-LUMO gap: 0.11838275557346406 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.00032235394540679766
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041699
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571689786198
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822984330870
# Coulomb Energy                  1024.5687892173967
# Exchange-Correlation Energy      -92.1614536795818
# --------------------------------------------------
# Total Energy                    -762.8609888904859
# --------------------------------------------------
#
#
#
# Energy difference :  3.0503770176437683e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904859
# -------------------------------------
#
#
#
# Time taken : 10.17 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           1.88
# Density Fitting                         0.43
#     DF (gamma)                          0.14
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.17
# DIIS                                    0.09
# KS matrix diagonalization               0.25
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         1.55
# Grids construction                      0.97
# Exchange-Correlation Term               3.26
# Misc.                                   1.7
# Complete SCF                            10.17

# %% [markdown]
# ### Benchmark #6 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.16 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.04
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.006798425000056341
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.05 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.19
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  5.51 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.53 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.4 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718097
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355654
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929923027
# --------------------------------------------------
#
#
#
# Energy difference :  374.93249299230274
#
#
# HOMO-LUMO gap: 1.8503196838147606 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.36 seconds
#
#
#
# Density matrix difference norm:  107.82808353552362
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99991
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876188968105
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682530428334
# Coulomb Energy                  3537.3220770014173
# Exchange-Correlation Energy     -250.6110534667969
# --------------------------------------------------
# Total Energy                   -1359.8986984886947
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662054963919
#
#
# HOMO-LUMO gap: 0.002113825247706036 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  57.36505416258305
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4340335147090
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0383080574086
# Coulomb Energy                  2705.4087422800521
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539415194389
# --------------------------------------------------
#
#
#
# Energy difference :  59.15524303074426
#
#
# HOMO-LUMO gap: 0.019742742607512645 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  48.04762292536172
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987116212684
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516938079263
# Coulomb Energy                  3071.8807201685959
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010080621320
# --------------------------------------------------
#
#
#
# Energy difference :  56.65293345730697
#
#
# HOMO-LUMO gap: 0.01467917140780238 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  40.921696800250025
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335726475689
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1621057021232
# Coulomb Energy                  3051.7270378193962
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347975024199
# --------------------------------------------------
#
#
#
# Energy difference :  16.43378944028791
#
#
# HOMO-LUMO gap: 0.012567419835385146 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  26.92676159252317
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983918894379
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7495000529243
# Coulomb Energy                  3003.5484969678082
# Exchange-Correlation Energy     -179.3104858398438
# --------------------------------------------------
# Total Energy                   -1523.5012368778889
# --------------------------------------------------
#
#
#
# Energy difference :  144.66643937546905
#
#
# HOMO-LUMO gap: 0.003218285314101824 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  13.414513662609815
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4197475743376
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319697596252
# Coulomb Energy                  2977.4926697267888
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856687250366
# --------------------------------------------------
#
#
#
# Energy difference :  24.415568152852302
#
#
# HOMO-LUMO gap: 0.03183004681662007 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.4 seconds
#
#
#
# Density matrix difference norm:  12.436601110504814
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381470853805
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8447123317148
# Coulomb Energy                  3000.9338231401553
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434614351923
# --------------------------------------------------
#
#
#
# Energy difference :  23.657792710155718
#
#
# HOMO-LUMO gap: 0.012963531903643383 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  6.013463086994332
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677557267318
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553318751658
# Coulomb Energy                  3041.7902022681014
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430861756550
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996247404626956
#
#
# HOMO-LUMO gap: 0.021491348647942485 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  6.216630559546396
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4700202761142
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196777512531
# Coulomb Energy                  3063.1283373882738
# Exchange-Correlation Energy     -185.9102478027344
# --------------------------------------------------
# Total Energy                   -1521.9226091086607
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204770669943173
#
#
# HOMO-LUMO gap: 0.07962865709635751 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.4 seconds
#
#
#
# Density matrix difference norm:  4.429026100365442
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505370185820
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1095173460728
# Coulomb Energy                  3048.3900579271985
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820314156254
# --------------------------------------------------
#
#
#
# Energy difference :  3.659422306964643
#
#
# HOMO-LUMO gap: 0.1194797736804394 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.8332695746966787
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524605852957
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100338674152
# Coulomb Energy                  3044.2746784035348
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396901770448
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765876141949775
#
#
# HOMO-LUMO gap: 0.10915540887000383 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.4379669442828183
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333939583874
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380161886545
# Coulomb Energy                  3039.9319352616540
# Exchange-Correlation Energy     -184.3113555908203
# --------------------------------------------------
# Total Energy                   -1525.7651542682370
# --------------------------------------------------
#
#
#
# Energy difference :  0.02546409119213422
#
#
# HOMO-LUMO gap: 0.08049522905774603 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.2802183843375206
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675763475283
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0129080251713
# Coulomb Energy                  3041.4808612120805
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832825423093
# --------------------------------------------------
#
#
#
# Energy difference :  0.018128274072296335
#
#
# HOMO-LUMO gap: 0.0353620567726743 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.20216531884068206
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152401155050
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773316134749
# Coulomb Energy                  3040.7150970455350
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864189686061
# --------------------------------------------------
#
#
#
# Energy difference :  0.003136426296805439
#
#
# HOMO-LUMO gap: 0.044774025817885935 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  0.07633458017834983
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0313036039261
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161859315805
# Coulomb Energy                  3040.4442116180312
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875164961129
# --------------------------------------------------
#
#
#
# Energy difference :  0.0010975275067721668
#
#
# HOMO-LUMO gap: 0.05279091743381986 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.02843969431337263
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299917723405
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078714780676
# Coulomb Energy                  3040.4514273386303
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877001259567
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018362984383202274
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.04989297130180767 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  0.012831195691521495
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963120318
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444087644306
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722321732212
# Coulomb Energy                  3040.3964168716966
# Exchange-Correlation Energy     -184.4242563052176
# --------------------------------------------------
# Total Energy                   -1525.7903721940702
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026720681134975166
#
#
# HOMO-LUMO gap: 0.050552999279554284 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.005300213130836611
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960684964
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993370841112
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002784775116
# Coulomb Energy                  3040.4277542151935
# Exchange-Correlation Energy     -184.4287293810157
# --------------------------------------------------
# Total Energy                   -1525.7903899417602
# --------------------------------------------------
#
#
#
# Energy difference :  1.7747689980751602e-05
#
#
# HOMO-LUMO gap: 0.050459044233664985 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.0021062218838101784
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961671854
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9999061758936
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3974020403116
# Coulomb Energy                  3040.4311719384846
# Exchange-Correlation Energy     -184.4287047193854
# --------------------------------------------------
# Total Energy                   -1525.7903930858206
# --------------------------------------------------
#
#
#
# Energy difference :  3.1440604288945906e-06
#
#
# HOMO-LUMO gap: 0.0506593778279123 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.004881209089429082
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960053465
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796096849817
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345405717943
# Coulomb Energy                  3040.4795288818445
# Exchange-Correlation Energy     -184.4344979838645
# --------------------------------------------------
# Total Energy                   -1525.7903943845463
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987256923224777e-06
#
#
# HOMO-LUMO gap: 0.05063331094884688 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.004003368160769397
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962935483
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308468308003
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102273404478
# Coulomb Energy                  3040.4520265662231
# Exchange-Correlation Energy     -184.4314495095360
# --------------------------------------------------
# Total Energy                   -1525.7903986030033
# --------------------------------------------------
#
#
#
# Energy difference :  4.218456979288021e-06
#
#
# HOMO-LUMO gap: 0.05065921627830558 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.0009812018067767811
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962317666
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462827339943
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170934609190
# Coulomb Energy                  3040.4616022400432
# Exchange-Correlation Energy     -184.4324557143912
# --------------------------------------------------
# Total Energy                   -1525.7903989167617
# --------------------------------------------------
#
#
#
# Energy difference :  3.1375839171232656e-07
#
#
# HOMO-LUMO gap: 0.050679423308131744 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.00024609586736573674
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332772
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503258331200
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622938648
# Coulomb Energy                  3040.4641306053090
# Exchange-Correlation Energy     -184.4327098344122
# --------------------------------------------------
# Total Energy                   -1525.7903989376973
# --------------------------------------------------
#
#
#
# Energy difference :  2.0935658540111035e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989376973
# -------------------------------------
#
#
#
# Time taken : 31.09 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.43
# Density Fitting                         1.08
#     DF (gamma)                          0.38
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.5
# DIIS                                    0.13
# KS matrix diagonalization               0.47
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         5.51
# Grids construction                      4.53
# Exchange-Correlation Term               8.37
# Misc.                                   3.5
# Complete SCF                            31.09

# %% [markdown]
# ### Benchmark #7 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.11 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.29 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.08
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.016607088999990083
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.1 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.45
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  14.18 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.02 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 21.01 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.06 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004606
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456261
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456261
#
#
# HOMO-LUMO gap: 1.345331101589149 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  144.0136743540893
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771597330946
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873905123974
# Coulomb Energy                  7102.3908458305332
# Exchange-Correlation Energy     -401.0388183593750
# --------------------------------------------------
# Total Energy                   -2175.7976205889236
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159029432974
#
#
# HOMO-LUMO gap: 0.0036323831818066976 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  71.99222269531427
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00244
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8538160768330
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349319386492
# Coulomb Energy                  5771.7158370925463
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171586731085
# --------------------------------------------------
#
#
#
# Energy difference :  98.71953808418493
#
#
# HOMO-LUMO gap: 0.004971745600421906 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  58.102779325032046
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372907643123
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733425438983
# Coulomb Energy                  6321.7309070517285
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4681336311178
# --------------------------------------------------
#
#
#
# Energy difference :  116.04902504199072
#
#
# HOMO-LUMO gap: 0.014407087436466542 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  53.368643149714025
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688987328413
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515700264871
# Coulomb Energy                  6361.2922997100204
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5266497790790
# --------------------------------------------------
#
#
#
# Energy difference :  24.0585161479612
#
#
# HOMO-LUMO gap: 0.008931171906196439 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  42.83082798286265
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057537953573
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112591106786
# Coulomb Energy                  6294.4822962416201
# Exchange-Correlation Energy     -283.9661560058594
# --------------------------------------------------
# Total Energy                   -2345.8382332883029
# --------------------------------------------------
#
#
#
# Energy difference :  163.31158350922396
#
#
# HOMO-LUMO gap: 0.006906513519156471 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  32.166212630841116
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2174254826205
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029738044416
# Coulomb Energy                  6214.1441110868200
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5590341280094
# --------------------------------------------------
#
#
#
# Energy difference :  2.2791991602935013
#
#
# HOMO-LUMO gap: 0.002470220957697125 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  33.32020784951436
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828362592543
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271611419544
# Coulomb Energy                  6284.7514071438072
# Exchange-Correlation Energy     -286.3058471679688
# --------------------------------------------------
# Total Energy                   -2352.5699939808474
# --------------------------------------------------
#
#
#
# Energy difference :  9.010959852837914
#
#
# HOMO-LUMO gap: 0.006021525672609163 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  26.099237578025917
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2103815467744
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3782309051503
# Coulomb Energy                  6418.6992253978733
# Exchange-Correlation Energy     -305.3439025878906
# --------------------------------------------------
# Total Energy                   -2411.0367066710278
# --------------------------------------------------
#
#
#
# Energy difference :  58.46671269018043
#
#
# HOMO-LUMO gap: 0.005609150703721519 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 0.75 seconds
#
#
#
# Density matrix difference norm:  17.530067244707976
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0003
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3139128527800
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3751105961660
# Coulomb Energy                  6329.8757240980649
# Exchange-Correlation Energy     -297.7131958007812
# --------------------------------------------------
# Total Energy                   -2373.3361527987163
# --------------------------------------------------
#
#
#
# Energy difference :  37.7005538723115
#
#
# HOMO-LUMO gap: 0.017134814257292214 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  16.398002254783492
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4105069887992
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3499478882873
# Coulomb Energy                  6323.6499374163468
# Exchange-Correlation Energy     -296.5715942382812
# --------------------------------------------------
# Total Energy                   -2423.5420947618313
# --------------------------------------------------
#
#
#
# Energy difference :  50.20594196311504
#
#
# HOMO-LUMO gap: 0.006509556914105763 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  17.89684082512928
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006531984742
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1969890777091
# Coulomb Energy                  6269.6532055037669
# Exchange-Correlation Energy     -292.3520812988281
# --------------------------------------------------
# Total Energy                   -2388.4624187552117
# --------------------------------------------------
#
#
#
# Energy difference :  35.07967600661959
#
#
# HOMO-LUMO gap: 0.011360309946574554 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  18.875158944420953
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4053318936822
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783026176088
# Coulomb Energy                  6305.1514407028926
# Exchange-Correlation Energy     -292.6976928710938
# --------------------------------------------------
# Total Energy                   -2419.6331602836590
# --------------------------------------------------
#
#
#
# Energy difference :  31.17074152844725
#
#
# HOMO-LUMO gap: 0.0019314221168444529 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  14.237438147346761
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00018
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7535823100261
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6442475440026
# Coulomb Energy                  6277.9125073250207
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7449264952329
# --------------------------------------------------
#
#
#
# Energy difference :  0.11176621157392219
#
#
# HOMO-LUMO gap: 0.00827221481078251 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  12.511476358660289
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8345403005678
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119802242357
# Coulomb Energy                  6304.6095876009585
# Exchange-Correlation Energy     -294.2061462402344
# --------------------------------------------------
# Total Energy                   -2430.9789975549938
# --------------------------------------------------
#
#
#
# Energy difference :  11.234071059760936
#
#
# HOMO-LUMO gap: 0.017657699233665183 au
# HOMO-LUMO gap: 0.480 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  10.321258849450292
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0493852360196
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2894851467540
# Coulomb Energy                  6320.8567470611288
# Exchange-Correlation Energy     -297.0249023437500
# --------------------------------------------------
# Total Energy                   -2429.4879342112727
# --------------------------------------------------
#
#
#
# Energy difference :  1.49106334372118
#
#
# HOMO-LUMO gap: 0.006403736226773815 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  8.082503324000188
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4245340768121
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0827700459122
# Coulomb Energy                  6316.7247620840481
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382638428779
# --------------------------------------------------
#
#
#
# Energy difference :  8.4503296316052
#
#
# HOMO-LUMO gap: 0.06629536903663165 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  4.08855314116665
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3820115807284
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5873323565688
# Coulomb Energy                  6313.2562827327856
# Exchange-Correlation Energy     -295.9056701660156
# --------------------------------------------------
# Total Energy                   -2441.0039454967755
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656816538976273
#
#
# HOMO-LUMO gap: 0.002521495832180906 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  4.342374310343458
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00003
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2994786703839
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1403923874832
# Coulomb Energy                  6287.7383582944476
# Exchange-Correlation Energy     -293.7503051757812
# --------------------------------------------------
# Total Energy                   -2439.7309120036189
# --------------------------------------------------
#
#
#
# Energy difference :  1.2730334931566176
#
#
# HOMO-LUMO gap: 0.020615465721078377 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  4.259500894060006
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7093783391647
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.2003353736195
# Coulomb Energy                  6303.8950528556088
# Exchange-Correlation Energy     -294.9480895996094
# --------------------------------------------------
# Total Energy                   -2441.1219585489307
# --------------------------------------------------
#
#
#
# Energy difference :  1.3910465453118377
#
#
# HOMO-LUMO gap: 0.12298795957432211 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.7427051078034874
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0212328959897
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5251586026475
# Coulomb Energy                  6307.0129980889360
# Exchange-Correlation Energy     -295.2851562500000
# --------------------------------------------------
# Total Energy                   -2441.3281112937912
# --------------------------------------------------
#
#
#
# Energy difference :  0.20615274486044655
#
#
# HOMO-LUMO gap: 0.08869505748202516 au
# HOMO-LUMO gap: 2.414 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.4773194376005116
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4118861313727
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7993123743099
# Coulomb Energy                  6304.8714552406655
# Exchange-Correlation Energy     -295.0263061523438
# --------------------------------------------------
# Total Energy                   -2441.3273035081256
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008077856655290816
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.1063934526565049 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.2704401249790839
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001152696
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5571342915555
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4796722110959
# Coulomb Energy                  6304.2835011681309
# Exchange-Correlation Energy     -294.9927296145428
# --------------------------------------------------
# Total Energy                   -2441.3465693662565
# --------------------------------------------------
#
#
#
# Energy difference :  0.01926585813089332
#
#
# HOMO-LUMO gap: 0.10571386154460927 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.11904629256516268
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001155221663
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9908724617508
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6072231834105
# Coulomb Energy                  6305.7416972902301
# Exchange-Correlation Energy     -295.1471421205446
# --------------------------------------------------
# Total Energy                   -2441.3489729480389
# --------------------------------------------------
#
#
#
# Energy difference :  0.0024035817823460093
#
#
# HOMO-LUMO gap: 0.10235724428914947 au
# HOMO-LUMO gap: 2.785 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.057747599746784097
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001161612908
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1768934022512
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2273007752733
# Coulomb Energy                  6305.2554189294351
# Exchange-Correlation Energy     -295.0958084939488
# --------------------------------------------------
# Total Energy                   -2441.3498610308761
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008880828372639371
#
#
# HOMO-LUMO gap: 0.08312504758027535 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.06379367140651249
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011775945705
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6232108083459
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9394155476048
# Coulomb Energy                  6304.9498894156059
# Exchange-Correlation Energy     -295.0562044040356
# --------------------------------------------------
# Total Energy                   -2441.3499890885560
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001280576798308175
#
#
# HOMO-LUMO gap: 0.0854384610849205 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.033184594505876304
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171908399
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1939365553735
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2382335392613
# Coulomb Energy                  6305.2623542046804
# Exchange-Correlation Energy     -295.0969181187420
# --------------------------------------------------
# Total Energy                   -2441.3501457695602
# --------------------------------------------------
#
#
#
# Energy difference :  0.00015668100422772113
#
#
# HOMO-LUMO gap: 0.08549172639309516 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.016472079179525822
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011743759353
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9922459316240
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1354449394344
# Coulomb Energy                  6305.1488949152827
# Exchange-Correlation Energy     -295.0824228912074
# --------------------------------------------------
# Total Energy                   -2441.3502078074998
# --------------------------------------------------
#
#
#
# Energy difference :  6.203793964232318e-05
#
#
# HOMO-LUMO gap: 0.086099223632749 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.00737575794968681
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173440076
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0613362508811
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745580668999
# Coulomb Energy                  6305.1842218055890
# Exchange-Correlation Energy     -295.0877827983621
# --------------------------------------------------
# Total Energy                   -2441.3502180161404
# --------------------------------------------------
#
#
#
# Energy difference :  1.0208640560449567e-05
#
#
# HOMO-LUMO gap: 0.08618072904001789 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.0029303435060195897
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203817
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0439401522381
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630735398785
# Coulomb Energy                  6305.1767420229262
# Exchange-Correlation Energy     -295.0862170621477
# --------------------------------------------------
# Total Energy                   -2441.3502204909655
# --------------------------------------------------
#
#
#
# Energy difference :  2.4748251234996133e-06
#
#
# HOMO-LUMO gap: 0.08626975720965377 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.000801654398616945
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173088262
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357831363781
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591877001429
# Coulomb Energy                  6305.1719551030910
# Exchange-Correlation Energy     -295.0857014229354
# --------------------------------------------------
# Total Energy                   -2441.3502205954646
# --------------------------------------------------
#
#
#
# Energy difference :  1.0449912224430591e-07
#
#
# HOMO-LUMO gap: 0.08626926964727624 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.000471298562929602
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173170967
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0329993930063
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576315449192
# Coulomb Energy                  6305.1705214888207
# Exchange-Correlation Energy     -295.0854954067910
# --------------------------------------------------
# Total Energy                   -2441.3502206054418
# --------------------------------------------------
#
#
#
# Energy difference :  9.977156878449023e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.350220605442
# -------------------------------------
#
#
#
# Time taken : 83.41 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.07
# Density Fitting                         3.04
#     DF (gamma)                          1.0
#     DF (coeff)                          0.13
#     DF (Jtri)                           1.55
# DIIS                                    0.23
# KS matrix diagonalization               1.16
# One electron Integrals (S, T, Vnuc)     0.11
# Coulomb Integrals (2c2e + 3c2e)         14.18
# Grids construction                      16.02
# Exchange-Correlation Term               21.84
# Misc.                                   5.75
# Complete SCF                            83.41

# %% [markdown]
# ### Benchmark #8 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.16 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.47 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.12
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04117618199995832
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.16 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.93
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  31.99 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 49.18 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 54.55 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.09 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0009
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182501
# Exchange-Correlation Energy     -158.3137817382812
# --------------------------------------------------
# Total Energy                    -881.4919713840700
# --------------------------------------------------
#
#
#
# Energy difference :  881.49197138407
#
#
# HOMO-LUMO gap: 0.6897604976007914 au
# HOMO-LUMO gap: 18.769 eV
#
#
# Time taken for the previous iteration: 1.75 seconds
#
#
#
# Density matrix difference norm:  177.41135709997567
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3344840564459
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5272569818490
# Coulomb Energy                 12707.6510784191723
# Exchange-Correlation Energy     -589.0113525390625
# --------------------------------------------------
# Total Energy                   -3195.7102487675656
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2182773834957
#
#
# HOMO-LUMO gap: 0.002627364007994515 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  86.0964532867837
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.1088815395160
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9652342493487
# Coulomb Energy                 10864.6201446992745
# Exchange-Correlation Energy     -358.7289123535156
# --------------------------------------------------
# Total Energy                   -3357.7951625174846
# --------------------------------------------------
#
#
#
# Energy difference :  162.084913749919
#
#
# HOMO-LUMO gap: 0.002510718731416294 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.4 seconds
#
#
#
# Density matrix difference norm:  65.13148166845217
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9476791048291
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4635751965329
# Coulomb Energy                 11125.2508226196660
# Exchange-Correlation Energy     -407.6778564453125
# --------------------------------------------------
# Total Energy                   -3374.4538853070208
# --------------------------------------------------
#
#
#
# Energy difference :  16.658722789536114
#
#
# HOMO-LUMO gap: 0.00442193559423823 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 1.4 seconds
#
#
#
# Density matrix difference norm:  63.85793837123074
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99948
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.3725903286468
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.9140517836672
# Coulomb Energy                 12063.8292728331762
# Exchange-Correlation Energy     -415.0684814453125
# --------------------------------------------------
# Total Energy                   -3056.2404947301929
# --------------------------------------------------
#
#
#
# Energy difference :  318.2133905768278
#
#
# HOMO-LUMO gap: 0.007367215366098176 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  54.581880377120605
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00027
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.6404066632604
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.4169434926598
# Coulomb Energy                 11513.0422496873416
# Exchange-Correlation Energy     -417.4490356445312
# --------------------------------------------------
# Total Energy                   -3536.1729967008687
# --------------------------------------------------
#
#
#
# Energy difference :  479.93250197067573
#
#
# HOMO-LUMO gap: 0.0017439541395528257 au
# HOMO-LUMO gap: 0.047 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  51.20536489651932
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99976
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.0687758215608
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.9091604413070
# Coulomb Energy                 11567.9585176634864
# Exchange-Correlation Energy     -419.4385681152344
# --------------------------------------------------
# Total Energy                   -3073.1824134050785
# --------------------------------------------------
#
#
#
# Energy difference :  462.9905832957902
#
#
# HOMO-LUMO gap: 0.007103832713943908 au
# HOMO-LUMO gap: 0.193 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  44.852130099220254
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.9583110016756
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6779246779720
# Coulomb Energy                 11495.7950838395063
# Exchange-Correlation Energy     -423.7618408203125
# --------------------------------------------------
# Total Energy                   -3532.7898908775860
# --------------------------------------------------
#
#
#
# Energy difference :  459.6074774725075
#
#
# HOMO-LUMO gap: 0.0009113495745176059 au
# HOMO-LUMO gap: 0.025 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  20.646759496542245
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.8278788344105
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.3205544450698
# Coulomb Energy                 11578.8361956139379
# Exchange-Correlation Energy     -439.3336791992188
# --------------------------------------------------
# Total Energy                   -3536.5475555477005
# --------------------------------------------------
#
#
#
# Energy difference :  3.7576646701145364
#
#
# HOMO-LUMO gap: 0.0035937143314764552 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  20.827654318423598
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28136.7936725959589
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3618.6113726266699
# Coulomb Energy                 11689.0063184735445
# Exchange-Correlation Energy     -441.3366394042969
# --------------------------------------------------
# Total Energy                   -3500.0553684731185
# --------------------------------------------------
#
#
#
# Energy difference :  36.492187074582034
#
#
# HOMO-LUMO gap: 0.010380961070860756 au
# HOMO-LUMO gap: 0.282 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  22.19507974572189
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00018
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27870.4745813540903
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3570.0730182198376
# Coulomb Energy                 11460.1694603415071
# Exchange-Correlation Energy     -435.4844665527344
# --------------------------------------------------
# Total Energy                   -3505.2593169185566
# --------------------------------------------------
#
#
#
# Energy difference :  5.203948445438073
#
#
# HOMO-LUMO gap: 0.010542835423418245 au
# HOMO-LUMO gap: 0.287 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  15.724658612980198
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00037
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28102.6569615888293
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3578.5287865417231
# Coulomb Energy                 11610.6807523453044
# Exchange-Correlation Energy     -438.4918518066406
# --------------------------------------------------
# Total Energy                   -3581.4820220815200
# --------------------------------------------------
#
#
#
# Energy difference :  76.2227051629634
#
#
# HOMO-LUMO gap: 0.00017192035864389138 au
# HOMO-LUMO gap: 0.005 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  13.539539787415958
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00003
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27853.4781879431976
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3502.6987656225488
# Coulomb Energy                 11468.0644355423683
# Exchange-Correlation Energy     -426.0701293945312
# --------------------------------------------------
# Total Energy                   -3538.3278637458880
# --------------------------------------------------
#
#
#
# Energy difference :  43.15415833563202
#
#
# HOMO-LUMO gap: 0.05016828595871599 au
# HOMO-LUMO gap: 1.365 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  12.95830736750483
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27988.0329187581956
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3531.7491490753955
# Coulomb Energy                 11533.2271216711779
# Exchange-Correlation Energy     -432.4118957519531
# --------------------------------------------------
# Total Energy                   -3585.0112913366520
# --------------------------------------------------
#
#
#
# Energy difference :  46.68342759076404
#
#
# HOMO-LUMO gap: 0.0036231653894904375 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  1.9542960222010415
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27979.4416412528008
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9404297473016
# Coulomb Energy                 11525.5549608188339
# Exchange-Correlation Energy     -431.9876403808594
# --------------------------------------------------
# Total Energy                   -3585.4766386406027
# --------------------------------------------------
#
#
#
# Energy difference :  0.46534730395069346
#
#
# HOMO-LUMO gap: 0.09753494441224664 au
# HOMO-LUMO gap: 2.654 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  1.1219888381874237
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1275432541006
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.5838639158919
# Coulomb Energy                 11540.9983284151167
# Exchange-Correlation Energy     -433.6155700683594
# --------------------------------------------------
# Total Energy                   -3585.7036685645307
# --------------------------------------------------
#
#
#
# Energy difference :  0.22702992392805754
#
#
# HOMO-LUMO gap: 0.08536883213858176 au
# HOMO-LUMO gap: 2.323 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  0.4126167296632268
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99988
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.1875401194702
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6539068032489
# Coulomb Energy                 11539.6997231278783
# Exchange-Correlation Energy     -433.3433532714844
# --------------------------------------------------
# Total Energy                   -3585.7200110329031
# --------------------------------------------------
#
#
#
# Energy difference :  0.016342468372386065
#
#
# HOMO-LUMO gap: 0.1021484256327548 au
# HOMO-LUMO gap: 2.780 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  0.2016885170932799
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.1504034159516
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.9009713572987
# Coulomb Energy                 11539.4368869501723
# Exchange-Correlation Energy     -433.3742370605469
# --------------------------------------------------
# Total Energy                   -3585.7295297421042
# --------------------------------------------------
#
#
#
# Energy difference :  0.009518709201074671
#
#
# HOMO-LUMO gap: 0.1025733064316002 au
# HOMO-LUMO gap: 2.791 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  0.05775174179932747
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00003
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8317576723857
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7516245715856
# Coulomb Energy                 11539.2455392447046
# Exchange-Correlation Energy     -433.3528137207031
# --------------------------------------------------
# Total Energy                   -3585.7301551498767
# --------------------------------------------------
#
#
#
# Energy difference :  0.0006254077725316165
#
# Switching to double precision for XC evaluation after 19 iterations!
#
#
# HOMO-LUMO gap: 0.1033354044144975 au
# HOMO-LUMO gap: 2.812 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.015769883692848884
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001636761505
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9545946227408
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8364959072860
# Coulomb Energy                 11539.2948766936552
# Exchange-Correlation Energy     -433.3705846055585
# --------------------------------------------------
# Total Energy                   -3585.7365542004372
# --------------------------------------------------
#
#
#
# Energy difference :  0.006399050560503383
#
#
# HOMO-LUMO gap: 0.10329784184276342 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0064455579794094
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162383572
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0156452089504
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8623354377760
# Coulomb Energy                 11539.3354518235283
# Exchange-Correlation Energy     -433.3759719868539
# --------------------------------------------------
# Total Energy                   -3585.7365775075759
# --------------------------------------------------
#
#
#
# Energy difference :  2.3307138690142892e-05
#
#
# HOMO-LUMO gap: 0.1032873891911694 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.006735309999157158
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001633563517
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8541773075885
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7751103441642
# Coulomb Energy                 11539.2503942649710
# Exchange-Correlation Energy     -433.3651644022439
# --------------------------------------------------
# Total Energy                   -3585.7365846737757
# --------------------------------------------------
#
#
#
# Energy difference :  7.166199793573469e-06
#
#
# HOMO-LUMO gap: 0.10339318021708208 au
# HOMO-LUMO gap: 2.813 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.006381246150509911
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163661416
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0188864634256
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8510852557097
# Coulomb Energy                 11539.3506531143757
# Exchange-Correlation Energy     -433.3766944425539
# --------------------------------------------------
# Total Energy                   -3585.7365901089743
# --------------------------------------------------
#
#
#
# Energy difference :  5.435198545455933e-06
#
#
# HOMO-LUMO gap: 0.10323532090998361 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.004683908829608198
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162695086
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9570314253178
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8162429800632
# Coulomb Energy                 11539.3195237419859
# Exchange-Correlation Energy     -433.3725841393324
# --------------------------------------------------
# Total Energy                   -3585.7365964156797
# --------------------------------------------------
#
#
#
# Energy difference :  6.306705472525209e-06
#
#
# HOMO-LUMO gap: 0.1032422400382505 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0011011663650290378
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001627911354
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9495946520328
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8136273105752
# Coulomb Energy                 11539.3144497654648
# Exchange-Correlation Energy     -433.3723315226114
# --------------------------------------------------
# Total Energy                   -3585.7365966716843
# --------------------------------------------------
#
#
#
# Energy difference :  2.5600456865504384e-07
#
#
# HOMO-LUMO gap: 0.10324196569510621 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.00045338790427492184
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001626829476
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9509904413353
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8139667055329
# Coulomb Energy                 11539.3156257348310
# Exchange-Correlation Energy     -433.3724511331432
# --------------------------------------------------
# Total Energy                   -3585.7365967071910
# --------------------------------------------------
#
#
#
# Energy difference :  3.550667315721512e-08
#
# SCF Converged after 26 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596707191
# -------------------------------------
#
#
#
# Time taken : 186.11 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           54.64
# Density Fitting                         4.69
#     DF (gamma)                          1.54
#     DF (coeff)                          0.12
#     DF (Jtri)                           2.41
# DIIS                                    0.47
# KS matrix diagonalization               1.89
# One electron Integrals (S, T, Vnuc)     0.16
# Coulomb Integrals (2c2e + 3c2e)         31.99
# Grids construction                      49.18
# Exchange-Correlation Term               35.83
# Misc.                                   7.26
# Complete SCF                            186.11
