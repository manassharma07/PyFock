# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 38.52 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 38.4 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.4 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=7e9aeefde0e6768d3116b8b6ab060ff133b68f5093287807b15f7c0d15f5aa2d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qpk4o8e1/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 15.72 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.41 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  5.81
# Time taken to evaluate the square roots needed:  0.1
# Time for significant indices evaluation:  2.020233616000013
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 7.94 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  6.79
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  37.92 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.78 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.1 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.5 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709560
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632574
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325736
#
#
# HOMO-LUMO gap: 2.6431079281671104 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.38 seconds
#
#
#
# Density matrix difference norm:  43.34767137041527
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.99999474389979
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709353
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339315979
# Coulomb Energy                   501.1198589452446
# Exchange-Correlation Energy      -62.5998011282688
# --------------------------------------------------
# Total Energy                    -340.0652765782380
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851498065
#
#
# HOMO-LUMO gap: 0.00490271106093032 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  28.612471718843935
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00009840286508
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456756
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785913
# Coulomb Energy                   293.3088657954298
# Exchange-Correlation Energy      -37.4191110537731
# --------------------------------------------------
# Total Energy                    -355.5094553813041
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803066052
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# HOMO-LUMO gap: 0.0403614769877709 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  21.394016787364812
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000022524453854
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275605
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458546
# Coulomb Energy                   367.2127830476564
# Exchange-Correlation Energy      -44.5841010136108
# --------------------------------------------------
# Total Energy                    -380.5867878035366
# --------------------------------------------------
#
#
#
# Energy difference :  25.07733242223253
#
#
# HOMO-LUMO gap: 0.01804857114311595 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  5.1974809336903
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000006874740826
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703978
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754621
# Coulomb Energy                   364.3533796551171
# Exchange-Correlation Energy      -44.5594485029999
# --------------------------------------------------
# Total Energy                    -378.6274635986950
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048416073
#
#
# HOMO-LUMO gap: 0.08493582284751397 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  4.779285269952129
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001287711405
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186624
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180492
# Coulomb Energy                   368.1554971681643
# Exchange-Correlation Energy      -45.0868782881906
# --------------------------------------------------
# Total Energy                    -381.1270633765158
# --------------------------------------------------
#
#
#
# Energy difference :  2.4995997778208334
#
#
# HOMO-LUMO gap: 0.1418385573857474 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5205766173122931
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089467
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233343
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990177
# Coulomb Energy                   369.0647619107250
# Exchange-Correlation Energy      -45.1368862216106
# --------------------------------------------------
# Total Energy                    -381.2275584910788
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456293203
#
#
# HOMO-LUMO gap: 0.13514723909461085 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.33158867782579626
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597148
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176953
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774596
# Coulomb Energy                   369.6340156607566
# Exchange-Correlation Energy      -45.2090855965867
# --------------------------------------------------
# Total Energy                    -381.2508898319422
# --------------------------------------------------
#
#
#
# Energy difference :  0.023331340863478545
#
#
# HOMO-LUMO gap: 0.01973205738300502 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5818251308658824
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000861700553
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110890
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893545
# Coulomb Energy                   374.0898923937952
# Exchange-Correlation Energy      -45.7569321945902
# --------------------------------------------------
# Total Energy                    -381.3827647784061
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646382447
#
#
# HOMO-LUMO gap: 0.1260448122142957 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.4584549614587674
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767308
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524483
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358300
# Coulomb Energy                   377.3880704578779
# Exchange-Correlation Energy      -46.1034837100250
# --------------------------------------------------
# Total Energy                    -381.4206849246417
# --------------------------------------------------
#
#
#
# Energy difference :  0.0379201462356491
#
#
# HOMO-LUMO gap: 0.16627348986211607 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.14506886517168968
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007579020895
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358586
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690308
# Coulomb Energy                   377.1736811284944
# Exchange-Correlation Energy      -46.0748895148574
# --------------------------------------------------
# Total Energy                    -381.4268823090673
# --------------------------------------------------
#
#
#
# Energy difference :  0.0061973844256044686
#
#
# HOMO-LUMO gap: 0.1812607411265039 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.05574884998850362
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000742519872
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179447
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114343
# Coulomb Energy                   377.1977734128252
# Exchange-Correlation Energy      -46.0810670348481
# --------------------------------------------------
# Total Energy                    -381.4272916844097
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753424285751
#
#
# HOMO-LUMO gap: 0.18111025828115102 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.025625306051921867
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750372541
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006480
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114193
# Coulomb Energy                   377.1502888734870
# Exchange-Correlation Energy      -46.0776486461288
# --------------------------------------------------
# Total Energy                    -381.4274184177470
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333725388147
#
#
# HOMO-LUMO gap: 0.18068395565675785 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.008432526434092365
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007500354876
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167520
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298547
# Coulomb Energy                   377.1545462611514
# Exchange-Correlation Energy      -46.0767747067592
# --------------------------------------------------
# Total Energy                    -381.4274393883816
# --------------------------------------------------
#
#
#
# Energy difference :  2.0970634579953185e-05
#
#
# HOMO-LUMO gap: 0.18067053575015388 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0018444600039995882
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750025072
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068115
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736901
# Coulomb Energy                   377.1524231958029
# Exchange-Correlation Energy      -46.0765296383165
# --------------------------------------------------
# Total Energy                    -381.4274391315114
# --------------------------------------------------
#
#
#
# Energy difference :  2.5687012339403736e-07
#
#
# HOMO-LUMO gap: 0.18064597252291442 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.001151141360801214
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749894921
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206436
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789325
# Coulomb Energy                   377.1549870542097
# Exchange-Correlation Energy      -46.0768423766160
# --------------------------------------------------
# Total Energy                    -381.4274396199939
# --------------------------------------------------
#
#
#
# Energy difference :  4.884824420514633e-07
#
#
# HOMO-LUMO gap: 0.18064256438840864 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.00010543279368298684
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836628
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081865
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075889
# Coulomb Energy                   377.1556791349443
# Exchange-Correlation Energy      -46.0769272993469
# --------------------------------------------------
# Total Energy                    -381.4274396208768
# --------------------------------------------------
#
#
#
# Energy difference :  8.828919817460701e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396208768
# -------------------------------------
#
#
#
# Time taken : 68.06 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.6
# Density Fitting                         1.7
#     DF (gamma)                          0.74
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.6
# DIIS                                    0.76
# KS matrix diagonalization               0.66
# One electron Integrals (S, T, Vnuc)     15.72
# Coulomb Integrals (2c2e + 3c2e)         37.92
# Grids construction                      0.78
# Exchange-Correlation Term               4.06
# Misc.                                   3.87
# Complete SCF                            68.06

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.08 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.003275905000009516
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.06
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  1.57 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.96 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.88 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00135664103416
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091871
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371788
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645300003
# --------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Energy difference :  185.44746453000027
#
#
# HOMO-LUMO gap: 1.7654343749559738 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.18 seconds
#
#
#
# Density matrix difference norm:  66.88358764205309
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084651
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437666
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987505768
# Coulomb Energy                  1272.5954275689492
# Exchange-Correlation Energy     -125.2198694441752
# --------------------------------------------------
# Total Energy                    -680.0789187511841
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422118384
#
#
# HOMO-LUMO gap: 0.0004045605675452868 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  39.27522964434415
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0012017584456
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692493943
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666727087
# Coulomb Energy                   861.6558693046422
# Exchange-Correlation Energy      -75.4419310839583
# --------------------------------------------------
# Total Energy                    -709.3563182387697
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487585626
#
#
# HOMO-LUMO gap: 0.0278156050006938 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  28.147358564323543
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663972
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672036513
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170660079
# Coulomb Energy                  1000.6400676118873
# Exchange-Correlation Energy      -87.3507096616596
# --------------------------------------------------
# Total Energy                    -733.7433460701837
# --------------------------------------------------
#
#
#
# Energy difference :  24.387027831414002
#
#
# HOMO-LUMO gap: 0.007352227195900465 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  18.103053983070673
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642287
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026564530
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102957918
# Coulomb Energy                  1039.7254935641924
# Exchange-Correlation Energy      -89.9717584580981
# --------------------------------------------------
# Total Energy                    -689.6320111373350
# --------------------------------------------------
#
#
#
# Energy difference :  44.11133493284876
#
#
# HOMO-LUMO gap: 0.01070179370362466 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  13.03426010369208
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576009
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022386967
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597623
# Coulomb Energy                  1004.3417767419821
# Exchange-Correlation Energy      -89.2334391642901
# --------------------------------------------------
# Total Energy                    -749.6400714840108
# --------------------------------------------------
#
#
#
# Energy difference :  60.00806034667585
#
#
# HOMO-LUMO gap: 0.025771351283185487 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  7.653358064508601
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554303
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132844031
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767409816
# Coulomb Energy                   997.3319760640744
# Exchange-Correlation Energy      -89.6717481072264
# --------------------------------------------------
# Total Energy                    -755.2352624693416
# --------------------------------------------------
#
#
#
# Energy difference :  5.59519098533076
#
#
# HOMO-LUMO gap: 0.00356847952042616 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  6.309738335087281
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567741
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204414834
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857161052
# Coulomb Energy                  1009.6464766736935
# Exchange-Correlation Energy      -89.9069114779350
# --------------------------------------------------
# Total Energy                    -755.2788234123877
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094304614544
#
#
# HOMO-LUMO gap: 0.00917506188608641 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  8.057132717381819
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0005030016397
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153727440
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119322847
# Coulomb Energy                  1035.0050622425583
# Exchange-Correlation Energy      -92.6658378595319
# --------------------------------------------------
# Total Energy                    -747.5712329402013
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472186439
#
#
# HOMO-LUMO gap: 0.1176623719399156 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  7.715013429004897
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306776
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903700806
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992834066
# Coulomb Energy                  1048.9988443901343
# Exchange-Correlation Energy      -94.9610811404738
# --------------------------------------------------
# Total Energy                    -761.7908817197813
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779579984
#
#
# HOMO-LUMO gap: 0.010925426636449145 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  6.790315749371499
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377906
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412178074
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466859319
# Coulomb Energy                  1013.7508689108829
# Exchange-Correlation Energy      -90.9428726052265
# --------------------------------------------------
# Total Energy                    -756.2816521089874
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229610793909
#
#
# HOMO-LUMO gap: 0.14929732696092668 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  6.53463325273254
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202657
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716106467
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461512624
# Coulomb Energy                  1025.7750806788811
# Exchange-Correlation Energy      -92.2703810888298
# --------------------------------------------------
# Total Energy                    -762.7969797521012
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327643113778
#
#
# HOMO-LUMO gap: 0.13352697865932495 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.5338338749099604
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332059
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179533952
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792902815
# Coulomb Energy                  1024.7461321400076
# Exchange-Correlation Energy      -92.1885648748845
# --------------------------------------------------
# Total Energy                    -762.8402252807584
# --------------------------------------------------
#
#
#
# Energy difference :  0.043245528657280374
#
#
# HOMO-LUMO gap: 0.1105622379911107 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.36027133595590444
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916639
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590204164
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517293623
# Coulomb Energy                  1023.6379077074530
# Exchange-Correlation Energy      -92.0697499681890
# --------------------------------------------------
# Total Energy                    -762.8490034345582
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153799767097
#
#
# HOMO-LUMO gap: 0.08600353272984408 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.32529885676743125
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680045
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240862936
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261721950
# Coulomb Energy                  1024.4836887100319
# Exchange-Correlation Energy      -92.1371699397493
# --------------------------------------------------
# Total Energy                    -762.8531330265837
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592025492457
#
#
# HOMO-LUMO gap: 0.11636080747513233 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.1553422461680662
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503608
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117169236
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900056089
# Coulomb Energy                  1024.5663100626316
# Exchange-Correlation Energy      -92.1605267750485
# --------------------------------------------------
# Total Energy                    -762.8605923064993
# --------------------------------------------------
#
#
#
# Energy difference :  0.007459279915565276
#
#
# HOMO-LUMO gap: 0.12269239243493388 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.04060711223069667
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000072218656
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080560
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362635
# Coulomb Energy                  1024.7015706722516
# Exchange-Correlation Energy      -92.1773633390780
# --------------------------------------------------
# Total Energy                    -762.8609189213869
# --------------------------------------------------
#
#
#
# Energy difference :  0.00032661488762641966
#
#
# HOMO-LUMO gap: 0.11742913475982944 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.01970316352735622
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471097
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348739237
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569875
# Coulomb Energy                  1024.5590092024165
# Exchange-Correlation Energy      -92.1602830990741
# --------------------------------------------------
# Total Energy                    -762.8609667963617
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497482539038e-05
#
#
# HOMO-LUMO gap: 0.11815573488896393 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.008211499893469618
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163932
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862569
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811861
# Coulomb Energy                  1024.5676148746829
# Exchange-Correlation Energy      -92.1612728329165
# --------------------------------------------------
# Total Energy                    -762.8609882460723
# --------------------------------------------------
#
#
#
# Energy difference :  2.144971062989498e-05
#
#
# HOMO-LUMO gap: 0.11842571032167964 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.0019148361621403223
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786602
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971491
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346063
# Coulomb Energy                  1024.5642249369525
# Exchange-Correlation Energy      -92.1610088236025
# --------------------------------------------------
# Total Energy                    -762.8609886319609
# --------------------------------------------------
#
#
#
# Energy difference :  3.8588859752053395e-07
#
#
# HOMO-LUMO gap: 0.1183577160647852 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0010776396175967945
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816393
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020013
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743115
# Coulomb Energy                  1024.5683629999191
# Exchange-Correlation Energy      -92.1613819110186
# --------------------------------------------------
# Total Energy                    -762.8609888215572
# --------------------------------------------------
#
#
#
# Energy difference :  1.8959622138936538e-07
#
#
# HOMO-LUMO gap: 0.11837118338545198 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.21 seconds
#
#
#
# Density matrix difference norm:  0.0005041312669114253
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785557
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591157995
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323286
# Coulomb Energy                  1024.5701171428743
# Exchange-Correlation Energy      -92.1615907612830
# --------------------------------------------------
# Total Energy                    -762.8609888846479
# --------------------------------------------------
#
#
#
# Energy difference :  6.309073796728626e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846479
# -------------------------------------
#
#
#
# Time taken : 10.53 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           1.91
# Density Fitting                         0.4
#     DF (gamma)                          0.14
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.16
# DIIS                                    0.08
# KS matrix diagonalization               0.23
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         1.57
# Grids construction                      0.96
# Exchange-Correlation Term               3.52
# Misc.                                   1.81
# Complete SCF                            10.53

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.17 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007809717999975874
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.19
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  5.6 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.61 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.53 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.05 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718097
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355691
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973800
# --------------------------------------------------
#
#
#
# Energy difference :  374.93033389738
#
#
# HOMO-LUMO gap: 1.8502864435414081 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 0.51 seconds
#
#
#
# Density matrix difference norm:  107.82844284433116
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99998558772936
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067654
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391766197
# Coulomb Energy                  3537.3287033060610
# Exchange-Correlation Energy     -250.6110528162047
# --------------------------------------------------
# Total Energy                   -1359.8923755096271
# --------------------------------------------------
#
#
#
# Energy difference :  984.962041612247
#
#
# HOMO-LUMO gap: 0.0021139216450606346 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  57.36707021916712
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512899
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256498828
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810812778
# Coulomb Energy                  2705.3966179581685
# Exchange-Correlation Energy     -151.8752804393625
# --------------------------------------------------
# Total Energy                   -1419.0480632191366
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770950949
#
#
# HOMO-LUMO gap: 0.019740723744248317 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  48.04719016376253
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00017178492396
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823851978
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892858155
# Coulomb Energy                  3071.8764250119348
# Exchange-Correlation Energy     -174.7460035329914
# --------------------------------------------------
# Total Energy                   -1362.4047277897771
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542935947
#
#
# HOMO-LUMO gap: 0.014747714720340574 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  40.925708282345134
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158718
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198121534
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571579328
# Coulomb Energy                  3051.7165832264232
# Exchange-Correlation Energy     -176.2007428393284
# --------------------------------------------------
# Total Energy                   -1378.8564784364630
# --------------------------------------------------
#
#
#
# Energy difference :  16.451750646685923
#
#
# HOMO-LUMO gap: 0.012539973804066185 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  26.93258217205877
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863938
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022788305
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850553723
# Coulomb Energy                  3003.5375755727791
# Exchange-Correlation Energy     -179.3125720191360
# --------------------------------------------------
# Total Energy                   -1523.5033698391535
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140269047
#
#
# HOMO-LUMO gap: 0.0030874947569098157 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  13.423370100241495
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002680348893
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332557715
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671359683
# Coulomb Energy                  2977.4795296009297
# Exchange-Correlation Energy     -178.1026352539472
# --------------------------------------------------
# Total Energy                   -1499.0865279421587
# --------------------------------------------------
#
#
#
# Energy difference :  24.41684189699481
#
#
# HOMO-LUMO gap: 0.031814612724246585 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  12.444575042373971
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146527
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885439726
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462461074
# Coulomb Energy                  3000.9261851724723
# Exchange-Correlation Energy     -180.8962339957659
# --------------------------------------------------
# Total Energy                   -1522.7463472904956
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348336896
#
#
# HOMO-LUMO gap: 0.012952412901999617 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  6.016412544000535
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001219220139
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025153322
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516680604
# Coulomb Energy                  3041.7824359799515
# Exchange-Correlation Energy     -185.1339645332609
# --------------------------------------------------
# Total Energy                   -1523.4476355699198
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794242614
#
#
# HOMO-LUMO gap: 0.02147354980959018 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  6.222751705219408
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99995948810573
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888919735
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569994513
# Coulomb Energy                  3063.1248487687571
# Exchange-Correlation Energy     -185.9132949765001
# --------------------------------------------------
# Total Energy                   -1521.9201342696033
# --------------------------------------------------
#
#
#
# Energy difference :  1.527501300316544
#
#
# HOMO-LUMO gap: 0.07988335372980039 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  4.434848523622631
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846697
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733682862
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444891659
# Coulomb Energy                  3048.3985990984847
# Exchange-Correlation Energy     -185.3448733865034
# --------------------------------------------------
# Total Energy                   -1525.5849593364755
# --------------------------------------------------
#
#
#
# Energy difference :  3.664825066872254
#
#
# HOMO-LUMO gap: 0.119119807369228 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.8335133099925291
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003812437743
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577373481
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794819
# Coulomb Energy                  3044.2765927794067
# Exchange-Correlation Energy     -184.7849150214426
# --------------------------------------------------
# Total Energy                   -1525.7423647692408
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543276524477
#
#
# HOMO-LUMO gap: 0.10914385151731248 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.4378203336009934
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733324
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238684542
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349502
# Coulomb Energy                  3039.9455617679992
# Exchange-Correlation Energy     -184.3161788613723
# --------------------------------------------------
# Total Energy                   -1525.7678971962164
# --------------------------------------------------
#
#
#
# Energy difference :  0.02553242697558744
#
#
# HOMO-LUMO gap: 0.0805563612478282 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  0.27956022877767106
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976176
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906560
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116260
# Coulomb Energy                  3041.4914846757406
# Exchange-Correlation Energy     -184.5235703798701
# --------------------------------------------------
# Total Energy                   -1525.7860021524971
# --------------------------------------------------
#
#
#
# Energy difference :  0.01810495628069475
#
#
# HOMO-LUMO gap: 0.03553321190270478 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.20188173701107237
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004068429735
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555702604
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365257678
# Coulomb Energy                  3040.7248454918945
# Exchange-Correlation Energy     -184.4775892871821
# --------------------------------------------------
# Total Energy                   -1525.7891190091168
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031168566197266045
#
#
# HOMO-LUMO gap: 0.044870894866836486 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.07625293104452001
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003965723621
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379110793
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103617
# Coulomb Energy                  3040.4560830346200
# Exchange-Correlation Energy     -184.4308753791023
# --------------------------------------------------
# Total Energy                   -1525.7902311145390
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011121054221803206
#
#
# HOMO-LUMO gap: 0.0528566413681642 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.02837208361937365
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003947131026
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669643771
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903982257
# Coulomb Energy                  3040.4602645950554
# Exchange-Correlation Energy     -184.4309026475907
# --------------------------------------------------
# Total Energy                   -1525.7903707880241
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348513688194
#
#
# HOMO-LUMO gap: 0.04994812744100442 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.012785251241654307
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505604
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931341
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318421
# Coulomb Energy                  3040.4067159125725
# Exchange-Correlation Energy     -184.4260067735660
# --------------------------------------------------
# Total Energy                   -1525.7903870916243
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303600204992108e-05
#
#
# HOMO-LUMO gap: 0.05083365573049904 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.006040021430829912
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112007
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954406
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920562
# Coulomb Energy                  3040.4581957844980
# Exchange-Correlation Energy     -184.4326037898879
# --------------------------------------------------
# Total Energy                   -1525.7903978781128
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786488473968348e-05
#
#
# HOMO-LUMO gap: 0.050686035896161746 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.0019655407486169185
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396237854
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801127300
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451883
# Coulomb Energy                  3040.4659355248864
# Exchange-Correlation Energy     -184.4328301188947
# --------------------------------------------------
# Total Energy                   -1525.7903988308876
# --------------------------------------------------
#
#
#
# Energy difference :  9.527748261461966e-07
#
#
# HOMO-LUMO gap: 0.050712621256445614 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.0010394322928826698
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780368
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447847
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272611438
# Coulomb Energy                  3040.4701320976205
# Exchange-Correlation Energy     -184.4333553536755
# --------------------------------------------------
# Total Energy                   -1525.7903988090343
# --------------------------------------------------
#
#
#
# Energy difference :  2.185333869419992e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090343
# -------------------------------------
#
#
#
# Time taken : 32.72 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.57
# Density Fitting                         0.98
#     DF (gamma)                          0.37
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.44
# DIIS                                    0.11
# KS matrix diagonalization               0.42
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         5.6
# Grids construction                      4.61
# Exchange-Correlation Term               9.46
# Misc.                                   3.9
# Complete SCF                            32.72

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.11 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.3 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.07
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.017203969000036068
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.1 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.44
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  14.37 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.05 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 21.08 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.21 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  320.00291984078206
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004606
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513683
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513683
#
#
# HOMO-LUMO gap: 1.3453174761634967 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.02 seconds
#
#
#
# Density matrix difference norm:  144.01406386862897
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999672071531
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016247540
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642080877
# Coulomb Energy                  7102.4006978647049
# Exchange-Correlation Energy     -401.0386878050836
# --------------------------------------------------
# Total Energy                   -2175.7881061964308
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450625
#
#
# HOMO-LUMO gap: 0.0036326528168172945 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  71.99427239658667
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247206
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645626367
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936015
# Coulomb Energy                  5771.7138319756477
# Exchange-Correlation Energy     -243.8524720616915
# --------------------------------------------------
# Total Energy                   -2274.5129129944644
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679803357
#
#
# HOMO-LUMO gap: 0.004964611535118665 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  58.10070148951932
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0021440415607
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804070153
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573471149
# Coulomb Energy                  6321.7172809549966
# Exchange-Correlation Energy     -278.3781618573794
# --------------------------------------------------
# Total Energy                   -2158.4748828016682
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019279621
#
#
# HOMO-LUMO gap: 0.014474030572585866 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  53.3699754920444
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00180767720946
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768217435
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230013659
# Coulomb Energy                  6361.2336350683472
# Exchange-Correlation Energy     -281.9436333442065
# --------------------------------------------------
# Total Energy                   -2182.5642309356226
# --------------------------------------------------
#
#
#
# Energy difference :  24.089348133954445
#
#
# HOMO-LUMO gap: 0.008841693998676042 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  42.83901509473329
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009908414895
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446991788
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382082353
# Coulomb Energy                  6294.5110601778233
# Exchange-Correlation Energy     -283.9707682331690
# --------------------------------------------------
# Total Energy                   -2345.8009933856738
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676245005117
#
#
# HOMO-LUMO gap: 0.007160714239806479 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  32.181862600116325
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9997863855179
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019082053
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650759369
# Coulomb Energy                  6214.1516556234019
# Exchange-Correlation Energy     -284.6344014150916
# --------------------------------------------------
# Total Energy                   -2343.5239614633429
# --------------------------------------------------
#
#
#
# Energy difference :  2.2770319223309343
#
#
# HOMO-LUMO gap: 0.0024503750084183817 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  33.32333314001191
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156513
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115032854
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996837513
# Coulomb Energy                  6284.6237009979886
# Exchange-Correlation Energy     -286.3084442723896
# --------------------------------------------------
# Total Energy                   -2352.7413339333216
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372469978727
#
#
# HOMO-LUMO gap: 0.006673318403191852 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  26.098281916047114
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026797845857
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383744476
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896585741
# Coulomb Energy                  6418.8046173133753
# Exchange-Correlation Energy     -305.3162932892109
# --------------------------------------------------
# Total Energy                   -2410.9382035310955
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686959777391
#
#
# HOMO-LUMO gap: 0.0079605395423573 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  17.53469864233028
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057112784
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201775283
# Coulomb Energy                  6329.9135850793391
# Exchange-Correlation Energy     -297.7524519047859
# --------------------------------------------------
# Total Energy                   -2373.3942311985829
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397233251257
#
#
# HOMO-LUMO gap: 0.013997838645142674 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  16.420704644494432
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982379832323
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814477318
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928265128
# Coulomb Energy                  6324.0705156442482
# Exchange-Correlation Energy     -296.6169927412379
# --------------------------------------------------
# Total Energy                   -2423.4444445575928
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335900983
#
#
# HOMO-LUMO gap: 0.005801716911325208 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  17.913629073496736
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082557727933
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871579002
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553223067
# Coulomb Energy                  6269.4959589854807
# Exchange-Correlation Energy     -292.3687260431010
# --------------------------------------------------
# Total Energy                   -2388.5334777326007
# --------------------------------------------------
#
#
#
# Energy difference :  34.9109668249921
#
#
# HOMO-LUMO gap: 0.01173972470495542 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  18.864810929001894
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00089534288895
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999710279
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986950337
# Coulomb Energy                  6304.9912271498815
# Exchange-Correlation Energy     -292.7049362976326
# --------------------------------------------------
# Total Energy                   -2419.7690892631308
# --------------------------------------------------
#
#
#
# Energy difference :  31.23561153053015
#
#
# HOMO-LUMO gap: 0.0016995925903103837 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  14.268938599580895
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015431500464
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930215545
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204646010
# Coulomb Energy                  6279.2250589340629
# Exchange-Correlation Energy     -293.0502585434106
# --------------------------------------------------
# Total Energy                   -2419.7439510056874
# --------------------------------------------------
#
#
#
# Energy difference :  0.02513825744335918
#
#
# HOMO-LUMO gap: 0.005846431270636207 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  12.51286101048026
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026512183956
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104149582
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140347419
# Coulomb Energy                  6304.4543925187863
# Exchange-Correlation Energy     -294.2073055525611
# --------------------------------------------------
# Total Energy                   -2431.0698882533779
# --------------------------------------------------
#
#
#
# Energy difference :  11.32593724769049
#
#
# HOMO-LUMO gap: 0.016452349703858726 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  10.313139445031279
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999159977518
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763789022
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614265507
# Coulomb Energy                  6320.4324015687353
# Exchange-Correlation Energy     -296.9899338061856
# --------------------------------------------------
# Total Energy                   -2429.5155260291876
# --------------------------------------------------
#
#
#
# Energy difference :  1.5543622241902995
#
#
# HOMO-LUMO gap: 0.005064351206253231 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  8.084972669952533
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00009764058916
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466714763
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611260462
# Coulomb Energy                  6316.3510407108788
# Exchange-Correlation Energy     -296.7435745394065
# --------------------------------------------------
# Total Energy                   -2437.9484982133436
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972184155915
#
#
# HOMO-LUMO gap: 0.0589303889366075 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 1.07 seconds
#
#
#
# Density matrix difference norm:  4.1026048500120496
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011810611767
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030021108
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451747027
# Coulomb Energy                  6313.1881517254087
# Exchange-Correlation Energy     -295.9055099898929
# --------------------------------------------------
# Total Energy                   -2441.0025949312776
# --------------------------------------------------
#
#
#
# Energy difference :  3.054096717934044
#
#
# HOMO-LUMO gap: 0.0053372503199767 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  6.254076480913102
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001236198699
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051502720
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545151454
# Coulomb Energy                  6280.4277633666725
# Exchange-Correlation Energy     -293.2139724471659
# --------------------------------------------------
# Total Energy                   -2436.9286385550049
# --------------------------------------------------
#
#
#
# Energy difference :  4.07395637627269
#
#
# HOMO-LUMO gap: 0.0118718400310147 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  7.41337541139175
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026335587523
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726555158602
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918925616
# Coulomb Energy                  6298.7681987559608
# Exchange-Correlation Energy     -294.0996241359605
# --------------------------------------------------
# Total Energy                   -2439.1315678426836
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292876786712
#
#
# HOMO-LUMO gap: 0.10362999786235373 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  4.188397590151572
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001162436132
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634484992283
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696447845
# Coulomb Energy                  6305.6013415974785
# Exchange-Correlation Energy     -295.1700654128234
# --------------------------------------------------
# Total Energy                   -2441.2043815091738
# --------------------------------------------------
#
#
#
# Energy difference :  2.0728136664902195
#
#
# HOMO-LUMO gap: 0.030358347401180673 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  1.0881186801896465
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00010584350065
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355876708
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042582523
# Coulomb Energy                  6306.4146008206781
# Exchange-Correlation Energy     -295.1986114172742
# --------------------------------------------------
# Total Energy                   -2441.2281207654005
# --------------------------------------------------
#
#
#
# Energy difference :  0.023739256226690486
#
#
# HOMO-LUMO gap: 0.10156738657388123 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.6147083203235699
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000113864789
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391385796
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706623130
# Coulomb Energy                  6305.3788664330568
# Exchange-Correlation Energy     -295.1059315047097
# --------------------------------------------------
# Total Energy                   -2441.3391123873043
# --------------------------------------------------
#
#
#
# Energy difference :  0.11099162190384959
#
#
# HOMO-LUMO gap: 0.12914420521827033 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.22866753118758743
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001129709715
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680216078115
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454900003
# Coulomb Energy                  6306.4753103395024
# Exchange-Correlation Energy     -295.2425453769587
# --------------------------------------------------
# Total Energy                   -2441.3433899946531
# --------------------------------------------------
#
#
#
# Energy difference :  0.0042776073487402755
#
#
# HOMO-LUMO gap: 0.11914092728959244 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.13316828808307685
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663356298
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009451024
# Coulomb Energy                  6305.4375957455277
# Exchange-Correlation Energy     -295.1178679622196
# --------------------------------------------------
# Total Energy                   -2441.3482164466050
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451951885247
#
#
# HOMO-LUMO gap: 0.07758609961871256 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.16794684474731486
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011918273236
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810410732
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356921866
# Coulomb Energy                  6304.4474549995448
# Exchange-Correlation Energy     -294.9863691579221
# --------------------------------------------------
# Total Energy                   -2441.3482383466489
# --------------------------------------------------
#
#
#
# Energy difference :  2.1900043975620065e-05
#
#
# HOMO-LUMO gap: 0.08220407414784203 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.08195634573856371
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001176128904
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560684932
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184239885
# Coulomb Energy                  6305.2666287332122
# Exchange-Correlation Energy     -295.0991774796628
# --------------------------------------------------
# Total Energy                   -2441.3500652303410
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836920469766
#
#
# HOMO-LUMO gap: 0.08681393247093964 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.030947650129975815
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711137
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449611739
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969469385
# Coulomb Energy                  6305.1999901384588
# Exchange-Correlation Energy     -295.0882138897994
# --------------------------------------------------
# Total Energy                   -2441.3501506049615
# --------------------------------------------------
#
#
#
# Energy difference :  8.537462053936906e-05
#
#
# HOMO-LUMO gap: 0.08605512218971079 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.015359420164935054
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011741243856
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082988842
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754510869
# Coulomb Energy                  6305.1611656010136
# Exchange-Correlation Energy     -295.0851653175865
# --------------------------------------------------
# Total Energy                   -2441.3502114037565
# --------------------------------------------------
#
#
#
# Energy difference :  6.079879494791385e-05
#
#
# HOMO-LUMO gap: 0.08610559554935464 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.005850728317022762
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173080262
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341358551
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624065161
# Coulomb Energy                  6305.1739654234298
# Exchange-Correlation Energy     -295.0859344062403
# --------------------------------------------------
# Total Energy                   -2441.3502195515357
# --------------------------------------------------
#
#
#
# Energy difference :  8.147779226419516e-06
#
#
# HOMO-LUMO gap: 0.0862775338023031 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.002268765576423115
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173037933
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171301868
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927319105
# Coulomb Energy                  6305.1767750459840
# Exchange-Correlation Energy     -295.0862921108219
# --------------------------------------------------
# Total Energy                   -2441.3502203025000
# --------------------------------------------------
#
#
#
# Energy difference :  7.509643182856962e-07
#
#
# HOMO-LUMO gap: 0.08629954674376364 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0014216232894785025
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161184
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335499727
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841015083
# Coulomb Energy                  6305.1678310988254
# Exchange-Correlation Energy     -295.0851232567482
# --------------------------------------------------
# Total Energy                   -2441.3502204457718
# --------------------------------------------------
#
#
#
# Energy difference :  1.432717908755876e-07
#
#
# HOMO-LUMO gap: 0.08625864034241498 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0007905213641774546
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173192669
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319544
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598757
# Coulomb Energy                  6305.1716231999108
# Exchange-Correlation Energy     -295.0855737005020
# --------------------------------------------------
# Total Energy                   -2441.3502206120556
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628382581984624e-07
#
#
# HOMO-LUMO gap: 0.08626853544518058 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.00028632021423646224
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731389486
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851889228
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651370216
# Coulomb Energy                  6305.1740152928060
# Exchange-Correlation Energy     -295.0859370217310
# --------------------------------------------------
# Total Energy                   -2441.3502206202129
# --------------------------------------------------
#
#
#
# Energy difference :  8.157257980201393e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.350220620213
# -------------------------------------
#
#
#
# Time taken : 94.33 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.28
# Density Fitting                         3.44
#     DF (gamma)                          1.13
#     DF (coeff)                          0.13
#     DF (Jtri)                           1.79
# DIIS                                    0.25
# KS matrix diagonalization               1.24
# One electron Integrals (S, T, Vnuc)     0.11
# Coulomb Integrals (2c2e + 3c2e)         14.37
# Grids construction                      16.05
# Exchange-Correlation Term               30.32
# Misc.                                   7.26
# Complete SCF                            94.33

# %% [markdown]
# ### Benchmark #4 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.16 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.47 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.12
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04037151699998276
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.17 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.94
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  31.62 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 49.26 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 54.58 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.09 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00086590367766
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182665
# Exchange-Correlation Energy     -158.3094688039744
# --------------------------------------------------
# Total Energy                    -881.4876584497470
# --------------------------------------------------
#
#
#
# Energy difference :  881.487658449747
#
#
# HOMO-LUMO gap: 0.6897308990677287 au
# HOMO-LUMO gap: 18.768 eV
#
#
# Time taken for the previous iteration: 2.64 seconds
#
#
#
# Density matrix difference norm:  177.4118335697765
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994638079426
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3704438294299
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5625483782687
# Coulomb Energy                 12707.6655166373730
# Exchange-Correlation Energy     -589.0109863900273
# --------------------------------------------------
# Total Energy                   -3195.6961127768955
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2084543271485
#
#
# HOMO-LUMO gap: 0.0026210885480666968 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  86.10072559746251
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006718457629
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.0784549166856
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9542974309643
# Coulomb Energy                 10864.6104283856293
# Exchange-Correlation Energy     -358.7264210078175
# --------------------------------------------------
# Total Energy                   -3357.7828976809888
# --------------------------------------------------
#
#
#
# Energy difference :  162.0867849040933
#
#
# HOMO-LUMO gap: 0.0025322925206721462 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  65.13264429193254
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000815955638
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9266970278986
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4589790561758
# Coulomb Energy                 11125.2421950877197
# Exchange-Correlation Energy     -407.6867498868766
# --------------------------------------------------
# Total Energy                   -3374.4550203439576
# --------------------------------------------------
#
#
#
# Energy difference :  16.67212266296883
#
#
# HOMO-LUMO gap: 0.004414389955651465 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  63.85668121088705
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995348429838
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.2877136083407
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.8757373777189
# Coulomb Energy                 12063.6748125281374
# Exchange-Correlation Energy     -415.0710986786240
# --------------------------------------------------
# Total Energy                   -3056.3510099541872
# --------------------------------------------------
#
#
#
# Energy difference :  318.10401038977034
#
#
# HOMO-LUMO gap: 0.006644147346903342 au
# HOMO-LUMO gap: 0.181 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  54.591690612503285
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00026913529405
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.5088611896026
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.3924608738880
# Coulomb Energy                 11512.9997141045642
# Exchange-Correlation Energy     -417.4553406800040
# --------------------------------------------------
# Total Energy                   -3536.1147744642312
# --------------------------------------------------
#
#
#
# Energy difference :  479.763764510044
#
#
# HOMO-LUMO gap: 0.0010123615121154237 au
# HOMO-LUMO gap: 0.028 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  51.11495004965368
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9997429477985
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.1797883195613
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.7800541119409
# Coulomb Energy                 11567.1010376105733
# Exchange-Correlation Energy     -419.4337655483220
# --------------------------------------------------
# Total Energy                   -3074.2752097184475
# --------------------------------------------------
#
#
#
# Energy difference :  461.8395647457837
#
#
# HOMO-LUMO gap: 0.004697471821282023 au
# HOMO-LUMO gap: 0.128 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  44.74482645853477
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996550749726
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.4126884322395
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6364207732595
# Coulomb Energy                 11495.5483932018942
# Exchange-Correlation Energy     -423.7795770213350
# --------------------------------------------------
# Total Energy                   -3532.5501990514986
# --------------------------------------------------
#
#
#
# Energy difference :  458.27498933305105
#
#
# HOMO-LUMO gap: 0.0004633975759954362 au
# HOMO-LUMO gap: 0.013 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  20.712738449210836
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99995454344725
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.2739427416818
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.0351192779094
# Coulomb Energy                 11580.0530322223785
# Exchange-Correlation Energy     -439.2769213817322
# --------------------------------------------------
# Total Energy                   -3535.0054601962056
# --------------------------------------------------
#
#
#
# Energy difference :  2.4552611447070376
#
#
# HOMO-LUMO gap: 0.007602915757841888 au
# HOMO-LUMO gap: 0.207 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  17.82978162900424
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00025109395995
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28135.5805691202695
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3632.4560425047903
# Coulomb Energy                 11640.5650672637421
# Exchange-Correlation Energy     -443.9779461938841
# --------------------------------------------------
# Total Energy                   -3536.0801531187008
# --------------------------------------------------
#
#
#
# Energy difference :  1.07469292249516
#
#
# HOMO-LUMO gap: 0.00433629145308409 au
# HOMO-LUMO gap: 0.118 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  21.750787698000323
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00009764970974
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27873.9019940305661
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3557.6224525897560
# Coulomb Energy                 11493.5519537905275
# Exchange-Correlation Energy     -433.3671342755930
# --------------------------------------------------
# Total Energy                   -3485.6374694989518
# --------------------------------------------------
#
#
#
# Energy difference :  50.442683619749005
#
#
# HOMO-LUMO gap: 0.017999766946443757 au
# HOMO-LUMO gap: 0.490 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  18.30481999643504
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00012189863344
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28089.3481554733953
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3573.7337555053618
# Coulomb Energy                 11601.6672609312081
# Exchange-Correlation Energy     -437.8374210488701
# --------------------------------------------------
# Total Energy                   -3581.3273076587739
# --------------------------------------------------
#
#
#
# Energy difference :  95.6898381598221
#
#
# HOMO-LUMO gap: 0.009809885706080084 au
# HOMO-LUMO gap: 0.267 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  15.603591042407217
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000084455324
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27851.1830292604063
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3504.4630746628281
# Coulomb Energy                 11481.6334508598029
# Exchange-Correlation Energy     -426.3111912974540
# --------------------------------------------------
# Total Energy                   -3520.9404426083056
# --------------------------------------------------
#
#
#
# Energy difference :  60.38686505046826
#
#
# HOMO-LUMO gap: 0.0012824764866173483 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  15.434068747364105
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99987880385254
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27993.2533948975397
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3536.1983115665771
# Coulomb Energy                 11535.6719868362889
# Exchange-Correlation Energy     -432.7365148901596
# --------------------------------------------------
# Total Energy                   -3583.6623589579085
# --------------------------------------------------
#
#
#
# Energy difference :  62.72191634960291
#
#
# HOMO-LUMO gap: 0.004883386793789343 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  4.995178443549156
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00002517039957
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27981.3352856380079
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9571719202113
# Coulomb Energy                 11529.5195165554360
# Exchange-Correlation Energy     -431.6645506069045
# --------------------------------------------------
# Total Energy                   -3583.0658953423426
# --------------------------------------------------
#
#
#
# Energy difference :  0.5964636155658809
#
#
# HOMO-LUMO gap: 0.04720525253435735 au
# HOMO-LUMO gap: 1.285 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  4.20424652142512
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00002943934146
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27999.1239612601457
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.4625382746499
# Coulomb Energy                 11537.2109855380677
# Exchange-Correlation Energy     -433.3658590887728
# --------------------------------------------------
# Total Energy                   -3585.3590441092783
# --------------------------------------------------
#
#
#
# Energy difference :  2.293148766935701
#
#
# HOMO-LUMO gap: 0.1056505979466546 au
# HOMO-LUMO gap: 2.875 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.9287341964485383
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001987442903
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1957112821983
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.6973822737059
# Coulomb Energy                 11540.9990151206694
# Exchange-Correlation Energy     -433.6709891588686
# --------------------------------------------------
# Total Energy                   -3585.7130506197700
# --------------------------------------------------
#
#
#
# Energy difference :  0.3540065104916721
#
#
# HOMO-LUMO gap: 0.08160165888504686 au
# HOMO-LUMO gap: 2.220 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.47099494371856115
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000154375198
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27997.2512028814381
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3537.3766051982793
# Coulomb Energy                 11536.7451407846838
# Exchange-Correlation Energy     -433.0466481344934
# --------------------------------------------------
# Total Energy                   -3585.7188526060454
# --------------------------------------------------
#
#
#
# Energy difference :  0.00580198627540085
#
#
# HOMO-LUMO gap: 0.09622544355504412 au
# HOMO-LUMO gap: 2.618 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.25345671940675835
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001674477835
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.5564277276244
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5447401760298
# Coulomb Energy                 11540.2918413568259
# Exchange-Correlation Energy     -433.4718309736392
# --------------------------------------------------
# Total Energy                   -3585.7344247414858
# --------------------------------------------------
#
#
#
# Energy difference :  0.015572135440379498
#
#
# HOMO-LUMO gap: 0.10308245780938532 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.10396191831929177
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001728845393
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6842550731817
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6972343116595
# Coulomb Energy                 11539.1501753047087
# Exchange-Correlation Energy     -433.3563235950135
# --------------------------------------------------
# Total Energy                   -3585.7359166249062
# --------------------------------------------------
#
#
#
# Energy difference :  0.0014918834203854203
#
#
# HOMO-LUMO gap: 0.10375679497516141 au
# HOMO-LUMO gap: 2.823 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.045809531749850155
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001639994315
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0103514429211
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8692999874993
# Coulomb Energy                 11539.3276463466500
# Exchange-Correlation Energy     -433.3803352098975
# --------------------------------------------------
# Total Energy                   -3585.7364878917488
# --------------------------------------------------
#
#
#
# Energy difference :  0.0005712668425985612
#
#
# HOMO-LUMO gap: 0.10309625407168324 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.029554270006012046
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163506745
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8156486375447
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7421800061093
# Coulomb Energy                 11539.2423486449989
# Exchange-Correlation Energy     -433.3626934152595
# --------------------------------------------------
# Total Energy                   -3585.7365609747740
# --------------------------------------------------
#
#
#
# Energy difference :  7.308302519959398e-05
#
#
# HOMO-LUMO gap: 0.10314551193914914 au
# HOMO-LUMO gap: 2.807 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.017959401864652797
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001612485084
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0456964761834
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8499454148141
# Coulomb Energy                 11539.3793326754803
# Exchange-Correlation Energy     -433.3773972783450
# --------------------------------------------------
# Total Energy                   -3585.7365632373112
# --------------------------------------------------
#
#
#
# Energy difference :  2.2625372366746888e-06
#
#
# HOMO-LUMO gap: 0.10320225757391677 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.010130201431360954
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001623811585
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9409514699764
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096974826449
# Coulomb Energy                 11539.3092433940910
# Exchange-Correlation Energy     -433.3718359075338
# --------------------------------------------------
# Total Energy                   -3585.7365940738546
# --------------------------------------------------
#
#
#
# Energy difference :  3.0836543373879977e-05
#
#
# HOMO-LUMO gap: 0.10326233777170714 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.003065424609071647
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162908748
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9648930033982
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8217790554309
# Coulomb Energy                 11539.3227881147832
# Exchange-Correlation Energy     -433.3735230027059
# --------------------------------------------------
# Total Energy                   -3585.7365964089677
# --------------------------------------------------
#
#
#
# Energy difference :  2.335113094886765e-06
#
#
# HOMO-LUMO gap: 0.10324998830358928 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.0010174353881073005
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162754851
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9526819050043
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8145317816752
# Coulomb Energy                 11539.3168310801284
# Exchange-Correlation Energy     -433.3725300824656
# --------------------------------------------------
# Total Energy                   -3585.7365966987454
# --------------------------------------------------
#
#
#
# Energy difference :  2.8977774491067976e-07
#
#
# HOMO-LUMO gap: 0.1032360609037346 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.0003763316359198755
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162733393
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9484625387122
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8126747647516
# Coulomb Energy                 11539.3142180301329
# Exchange-Correlation Energy     -433.3722793804536
# --------------------------------------------------
# Total Energy                   -3585.7365966973612
# --------------------------------------------------
#
#
#
# Energy difference :  1.3842509360983968e-09
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596697361
# -------------------------------------
#
#
#
# Time taken : 204.07 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           54.68
# Density Fitting                         4.88
#     DF (gamma)                          1.61
#     DF (coeff)                          0.13
#     DF (Jtri)                           2.48
# DIIS                                    0.5
# KS matrix diagonalization               1.99
# One electron Integrals (S, T, Vnuc)     0.16
# Coulomb Integrals (2c2e + 3c2e)         31.62
# Grids construction                      49.26
# Exchange-Correlation Term               55.19
# Misc.                                   5.78
# Complete SCF                            204.07

# %% [markdown]
# ## Dynamic Precision On

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.02 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.03 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0007967650000182402
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.03
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.67 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.3 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.6 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.02 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.00036
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709563
# Exchange-Correlation Energy      -16.0363521575928
# --------------------------------------------------
# Total Energy                     -93.1572674613899
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726746138995
#
#
# HOMO-LUMO gap: 2.6432309075653 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 3.94 seconds
#
#
#
# Density matrix difference norm:  43.34737619555267
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065057091975
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632825304165
# Coulomb Energy                   501.1179471569669
# Exchange-Correlation Energy      -62.5998191833496
# --------------------------------------------------
# Total Energy                    -340.0671181610403
# --------------------------------------------------
#
#
#
# Energy difference :  246.90985069965035
#
#
# HOMO-LUMO gap: 0.004895022244812808 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  28.612235117818123
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000103
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015698821860
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404485376320
# Coulomb Energy                   293.3105498762596
# Exchange-Correlation Energy      -37.4191246032715
# --------------------------------------------------
# Total Energy                    -355.5117190274423
# --------------------------------------------------
#
#
#
# Energy difference :  15.444600866402027
#
#
# HOMO-LUMO gap: 0.04090739403894883 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  21.394359863564837
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6801885014365
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079075502390
# Coulomb Energy                   367.2116009574220
# Exchange-Correlation Energy      -44.5831069946289
# --------------------------------------------------
# Total Energy                    -380.5858099442810
# --------------------------------------------------
#
#
#
# Energy difference :  25.074090916838657
#
#
# HOMO-LUMO gap: 0.018045886670271467 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  5.193654584593986
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853091438205
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987272575178
# Coulomb Energy                   364.3594810690379
# Exchange-Correlation Energy      -44.5593376159668
# --------------------------------------------------
# Total Energy                    -378.6284613891081
# --------------------------------------------------
#
#
#
# Energy difference :  1.9573485551729277
#
#
# HOMO-LUMO gap: 0.08497524067682044 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  4.776043862260644
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113206578897
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536884928380
# Coulomb Energy                   368.1595743595774
# Exchange-Correlation Energy      -45.0864944458008
# --------------------------------------------------
# Total Energy                    -381.1265752071515
# --------------------------------------------------
#
#
#
# Energy difference :  2.498113818043464
#
#
# HOMO-LUMO gap: 0.14153344195296177 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.5199018409376712
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759596179837
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620346900144
# Coulomb Energy                   369.0651771886234
# Exchange-Correlation Energy      -45.1361885070801
# --------------------------------------------------
# Total Energy                    -381.2269592023025
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038399515093488
#
#
# HOMO-LUMO gap: 0.1350577558679653 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.3314180487712926
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685675927237
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352796433414
# Coulomb Energy                   369.6332836147129
# Exchange-Correlation Energy      -45.2082176208496
# --------------------------------------------------
# Total Energy                    -381.2502449113955
# --------------------------------------------------
#
#
#
# Energy difference :  0.02328570909304517
#
#
# HOMO-LUMO gap: 0.019481785628569656 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.5819568575584295
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471003749773
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753305507247
# Coulomb Energy                   374.0875566303237
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611925300
# --------------------------------------------------
#
#
#
# Energy difference :  0.13181628113454735
#
#
# HOMO-LUMO gap: 0.12602060286735978 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.4597218096644731
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167220502266
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482882177709
# Coulomb Energy                   377.3936789835952
# Exchange-Correlation Energy      -46.1032218933105
# --------------------------------------------------
# Total Energy                    -381.4199996980474
# --------------------------------------------------
#
#
#
# Energy difference :  0.03793850551738842
#
#
# HOMO-LUMO gap: 0.16611335836129726 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.14506608198073068
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6773853124485
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4956800494409
# Coulomb Energy                   377.1713347422591
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261849805312
# --------------------------------------------------
#
#
#
# Energy difference :  0.006185282483727406
#
#
# HOMO-LUMO gap: 0.18109759450162044 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.05597222743468441
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466847521823
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5464934880637
# Coulomb Energy                   377.1955765820853
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266051366890
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004201561578156543
#
#
# HOMO-LUMO gap: 0.1809318558186621 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.025624236735680494
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6790963044396
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228702866739
# Coulomb Energy                   377.1480797572130
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267301905502
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012505386126804297
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.1805074010277999 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.00840952773788808
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749483558
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758561710778
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145457199130
# Coulomb Energy                   377.1522579825747
# Exchange-Correlation Energy      -46.0763602020218
# --------------------------------------------------
# Total Energy                    -381.4274356264884
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007054359381299946
#
#
# HOMO-LUMO gap: 0.18055948020359155 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0026420701627113937
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503220885
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547018762963
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032841210961
# Coulomb Energy                   377.1410362410166
# Exchange-Correlation Energy      -46.0750324272110
# --------------------------------------------------
# Total Energy                    -381.4274368972710
# --------------------------------------------------
#
#
#
# Energy difference :  1.2707826044788817e-06
#
#
# HOMO-LUMO gap: 0.18056589277641716 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0017678577827148587
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749796221
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715734084744
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117333671151
# Coulomb Energy                   377.1506245998457
# Exchange-Correlation Energy      -46.0761995168086
# --------------------------------------------------
# Total Energy                    -381.4274379141987
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169277402383159e-06
#
#
# HOMO-LUMO gap: 0.18057813394088867 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.001826320102612386
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007494343414
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890928902585
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201140686538
# Coulomb Energy                   377.1610735625127
# Exchange-Correlation Energy      -46.0775108681122
# --------------------------------------------------
# Total Energy                    -381.4274390830808
# --------------------------------------------------
#
#
#
# Energy difference :  1.1688820791277976e-06
#
#
# HOMO-LUMO gap: 0.18069052411925043 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0015079010412946698
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749797208
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793134395771
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150712631867
# Coulomb Energy                   377.1557639882245
# Exchange-Correlation Energy      -46.0769384184011
# --------------------------------------------------
# Total Energy                    -381.4274395624436
# --------------------------------------------------
#
#
#
# Energy difference :  4.793627681465296e-07
#
#
# HOMO-LUMO gap: 0.18064424269982715 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0004667745457299372
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749830365
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995676843
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900943679
# Coulomb Energy                   377.1550630849261
# Exchange-Correlation Energy      -46.0768702738874
# --------------------------------------------------
# Total Energy                    -381.4274396181542
# --------------------------------------------------
#
#
#
# Energy difference :  5.571064320974983e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396181542
# -------------------------------------
#
#
#
# Time taken : 7.9 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.63
# Density Fitting                         0.21
#     DF (gamma)                          0.07
#     DF (coeff)                          0.06
#     DF (Jtri)                           0.07
# DIIS                                    0.08
# KS matrix diagonalization               0.17
# One electron Integrals (S, T, Vnuc)     0.02
# Coulomb Integrals (2c2e + 3c2e)         0.67
# Grids construction                      0.3
# Exchange-Correlation Term               4.91
# Misc.                                   0.91
# Complete SCF                            7.9

# %% [markdown]
# ### Benchmark #5 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.07 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0025622020000355406
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.06
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  1.56 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.98 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.97 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091871
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371790
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120585
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961205845
#
#
# HOMO-LUMO gap: 1.7655068468538544 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.15 seconds
#
#
#
# Density matrix difference norm:  66.88323621963156
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816190541176
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207667033005
# Coulomb Energy                  1272.5916580546029
# Exchange-Correlation Energy     -125.2197875976562
# --------------------------------------------------
# Total Energy                    -680.0824357766385
# --------------------------------------------------
#
#
#
# Energy difference :  494.63381616458
#
#
# HOMO-LUMO gap: 0.0003950011727911762 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  39.27352499722331
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00123
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671433350924
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861190137736
# Coulomb Energy                   861.6520441624264
# Exchange-Correlation Energy      -75.4418258666992
# --------------------------------------------------
# Total Energy                    -709.3642599083598
# --------------------------------------------------
#
#
#
# Energy difference :  29.28182413172135
#
#
# HOMO-LUMO gap: 0.027815450819139505 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  28.145155581064454
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982803830454
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525456747668
# Coulomb Energy                  1000.6416364367544
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464596249954
# --------------------------------------------------
#
#
#
# Energy difference :  24.38219971663557
#
#
# HOMO-LUMO gap: 0.006873749882662011 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  18.10141834313199
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394527851651
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643187419480
# Coulomb Energy                  1039.7364542095333
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035005987760
# --------------------------------------------------
#
#
#
# Energy difference :  44.14295902621939
#
#
# HOMO-LUMO gap: 0.009401448617137792 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  13.030477987714617
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9282389258633
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4698006523840
# Coulomb Energy                  1004.3617280007113
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228912063173
# --------------------------------------------------
#
#
#
# Energy difference :  60.019390607541254
#
#
# HOMO-LUMO gap: 0.024324072242153563 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  7.651670854476545
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2544021126891
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338936837917
# Coulomb Energy                   997.3405126595263
# Exchange-Correlation Energy      -89.6696014404297
# --------------------------------------------------
# Total Energy                    -755.2430510925691
# --------------------------------------------------
#
#
#
# Energy difference :  5.620159886251827
#
#
# HOMO-LUMO gap: 0.001291144608115427 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  6.531101614786162
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00024
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9936579928235
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455789670887
# Coulomb Energy                  1008.9226915999009
# Exchange-Correlation Energy      -89.8105392456055
# --------------------------------------------------
# Total Energy                    -754.8293805542073
# --------------------------------------------------
#
#
#
# Energy difference :  0.4136705383617709
#
#
# HOMO-LUMO gap: 0.015385831238294234 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  7.342496886643105
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6262628365566
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2044952305429
# Coulomb Energy                  1033.2839481627245
# Exchange-Correlation Energy      -92.8136062622070
# --------------------------------------------------
# Total Energy                    -754.2448795882644
# --------------------------------------------------
#
#
#
# Energy difference :  0.5845009659428797
#
#
# HOMO-LUMO gap: 0.21170875090495186 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  6.051894716701278
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9768666174823
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1052022506739
# Coulomb Energy                  1046.8939531790920
# Exchange-Correlation Energy      -94.6927185058594
# --------------------------------------------------
# Total Energy                    -761.9638835763440
# --------------------------------------------------
#
#
#
# Energy difference :  7.719003988079521
#
#
# HOMO-LUMO gap: 0.0210912975748204 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  4.592875162786314
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186850042817
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7141198630299
# Coulomb Energy                  1016.5841271410977
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8409670782348
# --------------------------------------------------
#
#
#
# Energy difference :  2.1229164981091344
#
#
# HOMO-LUMO gap: 0.08795039594719611 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  4.1999890658245
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5723506665768
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4484782301442
# Coulomb Energy                  1025.9225296362563
# Exchange-Correlation Energy      -92.2370071411133
# --------------------------------------------------
# Total Energy                    -762.7318038240576
# --------------------------------------------------
#
#
#
# Energy difference :  2.890836745822753
#
#
# HOMO-LUMO gap: 0.14484203435547716 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.9087463720580976
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899358166493
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303485613445
# Coulomb Energy                  1024.4799979265526
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263940415982
# --------------------------------------------------
#
#
#
# Energy difference :  0.09459021754059904
#
#
# HOMO-LUMO gap: 0.09120403949057161 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.3386026704281987
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063877160927
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273748083523
# Coulomb Energy                  1024.8155169186834
# Exchange-Correlation Energy      -92.1995697021484
# --------------------------------------------------
# Total Energy                    -762.8565195739734
# --------------------------------------------------
#
#
#
# Energy difference :  0.030125532375222974
#
#
# HOMO-LUMO gap: 0.10812692325551873 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.1334219837312258
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7708257494496
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490595744667
# Coulomb Energy                  1024.3963951080129
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586793808906
# --------------------------------------------------
#
#
#
# Energy difference :  0.002159806917234164
#
#
# HOMO-LUMO gap: 0.11558371304128023 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.05240849832607536
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028455902264
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1554042488697
# Coulomb Energy                  1024.6505267195030
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595503283523
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008709474616352963
#
#
# HOMO-LUMO gap: 0.11553040879634174 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.014069524761206766
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000161955777
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543953362003
# Coulomb Energy                  1024.5347558853568
# Exchange-Correlation Energy      -92.1552658081055
# --------------------------------------------------
# Total Energy                    -762.8595846648941
# --------------------------------------------------
#
#
#
# Energy difference :  3.433654183027102e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.11964641853790486 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.01580796977969736
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745387207
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803980639694
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978093491011
# Coulomb Energy                  1024.5775775458924
# Exchange-Correlation Energy      -92.1624888900901
# --------------------------------------------------
# Total Energy                    -762.8609539418339
# --------------------------------------------------
#
#
#
# Energy difference :  0.001369276939840347
#
#
# HOMO-LUMO gap: 0.11847999991117208 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.008700634939752714
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741300344
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328881559844
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722855518187
# Coulomb Energy                  1024.5524825579350
# Exchange-Correlation Energy      -92.1594115711426
# --------------------------------------------------
# Total Energy                    -762.8609855001414
# --------------------------------------------------
#
#
#
# Energy difference :  3.155830745527055e-05
#
#
# HOMO-LUMO gap: 0.11834733872671752 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0020541791593303355
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739807325
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503355450519
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805124294972
# Coulomb Energy                  1024.5630589622094
# Exchange-Correlation Energy      -92.1607682794137
# --------------------------------------------------
# Total Energy                    -762.8609863155273
# --------------------------------------------------
#
#
#
# Energy difference :  8.153858743753517e-07
#
#
# HOMO-LUMO gap: 0.11844996808182459 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0022801665147838585
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742287193
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365087031496
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734623372364
# Coulomb Energy                  1024.5553051134655
# Exchange-Correlation Energy      -92.1597918737174
# --------------------------------------------------
# Total Energy                    -762.8609870089333
# --------------------------------------------------
#
#
#
# Energy difference :  6.934060365892947e-07
#
#
# HOMO-LUMO gap: 0.1184989672564234 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.002121098219135349
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742172233
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510305030134
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0798004113951
# Coulomb Energy                  1024.5646274363594
# Exchange-Correlation Energy      -92.1609318680543
# --------------------------------------------------
# Total Energy                    -762.8609884060816
# --------------------------------------------------
#
#
#
# Energy difference :  1.3971482530905632e-06
#
#
# HOMO-LUMO gap: 0.11838531399338331 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.0014188750930758554
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741620073
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635537312692
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852198743316
# Coulomb Energy                  1024.5726719852710
# Exchange-Correlation Energy      -92.1618731055452
# --------------------------------------------------
# Total Energy                    -762.8609888599799
# --------------------------------------------------
#
#
#
# Energy difference :  4.538983375823591e-07
#
#
# HOMO-LUMO gap: 0.11838275585667392 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.000322366039965172
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041694
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571690447414
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822984640956
# Coulomb Energy                  1024.5687892567901
# Exchange-Correlation Energy      -92.1614536838628
# --------------------------------------------------
# Total Energy                    -762.8609888904864
# --------------------------------------------------
#
#
#
# Energy difference :  3.0506498660543e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904864
# -------------------------------------
#
#
#
# Time taken : 10.19 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.0
# Density Fitting                         0.42
#     DF (gamma)                          0.14
#     DF (coeff)                          0.07
#     DF (Jtri)                           0.17
# DIIS                                    0.09
# KS matrix diagonalization               0.25
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         1.56
# Grids construction                      0.98
# Exchange-Correlation Term               3.27
# Misc.                                   1.58
# Complete SCF                            10.19

# %% [markdown]
# ### Benchmark #6 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.16 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.04
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.006594317000008232
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.05 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.19
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  5.46 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.52 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.43 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718097
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355663
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929923018
# --------------------------------------------------
#
#
#
# Energy difference :  374.93249299230183
#
#
# HOMO-LUMO gap: 1.8503196838149347 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.36 seconds
#
#
#
# Density matrix difference norm:  107.82808353552346
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99991
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876188968105
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682530428297
# Coulomb Energy                  3537.3220770014091
# Exchange-Correlation Energy     -250.6110534667969
# --------------------------------------------------
# Total Energy                   -1359.8986984887065
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662054964047
#
#
# HOMO-LUMO gap: 0.0021138252470376817 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  57.36505416258295
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4340335139932
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0383080574702
# Coulomb Energy                  2705.4087422792618
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539415194507
# --------------------------------------------------
#
#
#
# Energy difference :  59.15524303074426
#
#
# HOMO-LUMO gap: 0.019742742882144074 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  48.047622929151764
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987116610488
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516938051098
# Coulomb Energy                  3071.8807202138564
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010080594685
# --------------------------------------------------
#
#
#
# Energy difference :  56.65293345998225
#
#
# HOMO-LUMO gap: 0.014679171759189355 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  40.921697102251926
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335723459977
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1621054350685
# Coulomb Energy                  3051.7270375209932
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347977663057
# --------------------------------------------------
#
#
#
# Energy difference :  16.43378970683716
#
#
# HOMO-LUMO gap: 0.012567416565179026 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  26.926762039603986
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983911071242
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494998476550
# Coulomb Energy                  3003.5484964299262
# Exchange-Correlation Energy     -179.3104858398438
# --------------------------------------------------
# Total Energy                   -1523.5012368387256
# --------------------------------------------------
#
#
#
# Energy difference :  144.66643907241996
#
#
# HOMO-LUMO gap: 0.0032182822344580305 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  13.41451370953324
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4197450162446
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319712224522
# Coulomb Energy                  2977.4926659140719
# Exchange-Correlation Energy     -178.1002197265625
# --------------------------------------------------
# Total Energy                   -1499.0856837756210
# --------------------------------------------------
#
#
#
# Energy difference :  24.415553063104653
#
#
# HOMO-LUMO gap: 0.03183004582829187 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  12.43660088375337
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381487304745
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8447146778826
# Coulomb Energy                  3000.9338225407846
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434613334899
# --------------------------------------------------
#
#
#
# Energy difference :  23.65777755786894
#
#
# HOMO-LUMO gap: 0.012963515621581441 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  6.013464067641198
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677593841028
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553343262408
# Coulomb Energy                  3041.7902036695095
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430859805425
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996246470525875
#
#
# HOMO-LUMO gap: 0.021491327716627304 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  6.21663183129403
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4700148050706
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196754588271
# Coulomb Energy                  3063.1283342869347
# Exchange-Correlation Energy     -185.9102478027344
# --------------------------------------------------
# Total Energy                   -1521.9226090313814
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204769491610932
#
#
# HOMO-LUMO gap: 0.07962867718330253 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  4.429026670395218
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505389185000
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1095178537885
# Coulomb Energy                  3048.3900594527076
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820312823180
# --------------------------------------------------
#
#
#
# Energy difference :  3.6594222509365864
#
#
# HOMO-LUMO gap: 0.11947976441731262 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.833269767451263
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524610005592
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100345480308
# Coulomb Energy                  3044.2746781674750
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396901477505
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765886543249508
#
#
# HOMO-LUMO gap: 0.10915544960441753 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.4379672674756558
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333960879238
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380173811332
# Coulomb Energy                  3039.9319363671802
# Exchange-Correlation Energy     -184.3113403320312
# --------------------------------------------------
# Total Energy                   -1525.7651388409795
# --------------------------------------------------
#
#
#
# Energy difference :  0.025448693229009223
#
#
# HOMO-LUMO gap: 0.08049524058171767 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.2802186417473389
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675767535986
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0129080794632
# Coulomb Energy                  3041.4808616310643
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832824751035
# --------------------------------------------------
#
#
#
# Energy difference :  0.018143634124044183
#
#
# HOMO-LUMO gap: 0.035362039786188376 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.38 seconds
#
#
#
# Density matrix difference norm:  0.20216552609507546
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152371903336
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773302525111
# Coulomb Energy                  3040.7150953274968
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864191224371
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031366473335765477
#
#
# HOMO-LUMO gap: 0.04477400075271547 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.0763347369440685
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0313012376646
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161842343563
# Coulomb Energy                  3040.4442108022427
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875166428644
# --------------------------------------------------
#
#
#
# Energy difference :  0.0010975204272654082
#
#
# HOMO-LUMO gap: 0.05279089261856819 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.0284398582508787
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299913480740
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078713245169
# Coulomb Energy                  3040.4514270250347
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877001688375
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018352597317061736
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.04989294257377894 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.012831415282069682
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963122057
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444067139630
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722306044115
# Coulomb Energy                  3040.3964162342527
# Exchange-Correlation Energy     -184.4242561492958
# --------------------------------------------------
# Total Energy                   -1525.7903721939329
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026720250953076174
#
#
# HOMO-LUMO gap: 0.05055298538556817 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.005300263057683458
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960685936
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993367767620
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002779558750
# Coulomb Energy                  3040.4277544117049
# Exchange-Correlation Energy     -184.4287293632992
# --------------------------------------------------
# Total Energy                   -1525.7903899418197
# --------------------------------------------------
#
#
#
# Energy difference :  1.7747886886354536e-05
#
#
# HOMO-LUMO gap: 0.050459033293226055 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  0.0021061793352595524
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961672664
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9999059923630
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3974016763598
# Coulomb Energy                  3040.4311721078348
# Exchange-Correlation Energy     -184.4287047083755
# --------------------------------------------------
# Total Energy                   -1525.7903930858838
# --------------------------------------------------
#
#
#
# Energy difference :  3.1440640668733977e-06
#
#
# HOMO-LUMO gap: 0.05065937609394319 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  0.004881215114244135
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960053846
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796091836346
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345401388928
# Coulomb Energy                  3040.4795287855786
# Exchange-Correlation Energy     -184.4344979560943
# --------------------------------------------------
# Total Energy                   -1525.7903943845949
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987111404072493e-06
#
#
# HOMO-LUMO gap: 0.050633313473825256 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.004003298050659795
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962935546
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308467948998
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102272360797
# Coulomb Energy                  3040.4520266349705
# Exchange-Correlation Energy     -184.4314495098446
# --------------------------------------------------
# Total Energy                   -1525.7903986030319
# --------------------------------------------------
#
#
#
# Energy difference :  4.218436970404582e-06
#
#
# HOMO-LUMO gap: 0.050659217900861836 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.000981162450272424
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962317672
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462831027198
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170936328219
# Coulomb Energy                  3040.4616024630941
# Exchange-Correlation Energy     -184.4324557406262
# --------------------------------------------------
# Total Energy                   -1525.7903989167698
# --------------------------------------------------
#
#
#
# Energy difference :  3.1373792808153667e-07
#
#
# HOMO-LUMO gap: 0.050679422796027385 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.00024608485756836087
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332772
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503258460076
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622980682
# Coulomb Energy                  3040.4641306145058
# Exchange-Correlation Energy     -184.4327098349280
# --------------------------------------------------
# Total Energy                   -1525.7903989377010
# --------------------------------------------------
#
#
#
# Energy difference :  2.093111106660217e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.790398937701
# -------------------------------------
#
#
#
# Time taken : 31.02 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.47
# Density Fitting                         1.1
#     DF (gamma)                          0.38
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.52
# DIIS                                    0.13
# KS matrix diagonalization               0.48
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         5.46
# Grids construction                      4.52
# Exchange-Correlation Term               8.41
# Misc.                                   3.38
# Complete SCF                            31.02

# %% [markdown]
# ### Benchmark #7 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.11 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.29 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.07
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.018009326000083092
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.09 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.45
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  14.24 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.12 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 20.89 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.06 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004606
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456261
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456261
#
#
# HOMO-LUMO gap: 1.345331101589287 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  144.01367435409148
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771597331819
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873905124919
# Coulomb Energy                  7102.3908458305705
# Exchange-Correlation Energy     -401.0388183593750
# --------------------------------------------------
# Total Energy                   -2175.7976205888790
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159029432529
#
#
# HOMO-LUMO gap: 0.003632382935056633 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  71.99222265223769
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00244
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8538170745123
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349319678005
# Coulomb Energy                  5771.7158379632319
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171587709510
# --------------------------------------------------
#
#
#
# Energy difference :  98.71953818207203
#
#
# HOMO-LUMO gap: 0.00497177147628583 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  58.102779210835656
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372961906651
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733437917141
# Coulomb Energy                  6321.7309064315032
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4681384298801
# --------------------------------------------------
#
#
#
# Energy difference :  116.0490203410709
#
#
# HOMO-LUMO gap: 0.01440713890553666 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  53.36864321485543
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5689036930598
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515743247391
# Coulomb Energy                  6361.2923108349141
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5266393161519
# --------------------------------------------------
#
#
#
# Energy difference :  24.05850088627176
#
#
# HOMO-LUMO gap: 0.008931209916307553 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  42.83082854901111
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057612929970
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112621598582
# Coulomb Energy                  6294.4822853307669
# Exchange-Correlation Energy     -283.9661560058594
# --------------------------------------------------
# Total Energy                   -2345.8382486476166
# --------------------------------------------------
#
#
#
# Energy difference :  163.31160933146475
#
#
# HOMO-LUMO gap: 0.006906421491773909 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  32.166210763817
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2174258114228
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029721847107
# Coulomb Energy                  6214.1440995591975
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5590476041662
# --------------------------------------------------
#
#
#
# Energy difference :  2.2792010434504846
#
#
# HOMO-LUMO gap: 0.0024701663728434325 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  33.320209753938954
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828196833896
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271649089709
# Coulomb Energy                  6284.7514293250906
# Exchange-Correlation Energy     -286.3058471679688
# --------------------------------------------------
# Total Energy                   -2352.5699514566813
# --------------------------------------------------
#
#
#
# Energy difference :  9.010903852515185
#
#
# HOMO-LUMO gap: 0.006021337928531045 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  26.099240196231946
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2104683509242
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3782649126124
# Coulomb Energy                  6418.6992506375682
# Exchange-Correlation Energy     -305.3439025878906
# --------------------------------------------------
# Total Energy                   -2411.0367342280206
# --------------------------------------------------
#
#
#
# Energy difference :  58.46678277133924
#
#
# HOMO-LUMO gap: 0.005608887114426975 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  17.53006777507603
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0003
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3138087300213
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3750512738329
# Coulomb Energy                  6329.8756805189114
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3361820950213
# --------------------------------------------------
#
#
#
# Energy difference :  37.70055213299929
#
#
# HOMO-LUMO gap: 0.01713551409403527 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  16.397999077826448
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99976
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4103806477415
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3499029292639
# Coulomb Energy                  6323.6498246823212
# Exchange-Correlation Energy     -296.5716247558594
# --------------------------------------------------
# Total Energy                   -2423.5421566314017
# --------------------------------------------------
#
#
#
# Energy difference :  50.20597453638038
#
#
# HOMO-LUMO gap: 0.006509788220457988 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  17.896838599562027
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006427448148
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1969684513183
# Coulomb Energy                  6269.6532223252298
# Exchange-Correlation Energy     -292.3520202636719
# --------------------------------------------------
# Total Energy                   -2388.4623510713236
# --------------------------------------------------
#
#
#
# Energy difference :  35.07980556007806
#
#
# HOMO-LUMO gap: 0.011360000130646267 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  18.875164387483625
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00092
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4053314765297
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8782938444920
# Coulomb Energy                  6305.1514838483999
# Exchange-Correlation Energy     -292.6976928710938
# --------------------------------------------------
# Total Energy                   -2419.6331254941160
# --------------------------------------------------
#
#
#
# Energy difference :  31.17077442279242
#
#
# HOMO-LUMO gap: 0.0019314778703005825 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  14.237441452093135
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00018
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7533274845027
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6441895663875
# Coulomb Energy                  6277.9122959417591
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7449410305862
# --------------------------------------------------
#
#
#
# Energy difference :  0.11181553647020337
#
#
# HOMO-LUMO gap: 0.008272721609475758 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  12.51147853785069
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8345550654612
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119747044691
# Coulomb Energy                  6304.6096217840604
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9789531389742
# --------------------------------------------------
#
#
#
# Energy difference :  11.234012108388015
#
#
# HOMO-LUMO gap: 0.017657460564249938 au
# HOMO-LUMO gap: 0.480 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  10.321260792450824
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99985
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0495602630162
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2895270694539
# Coulomb Energy                  6320.8568842665973
# Exchange-Correlation Energy     -297.0249023437500
# --------------------------------------------------
# Total Energy                   -2429.4879301101009
# --------------------------------------------------
#
#
#
# Energy difference :  1.4910230288733146
#
#
# HOMO-LUMO gap: 0.006403646075622438 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  8.082503479351116
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4246028663965
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0827966176175
# Coulomb Energy                  6316.7248079779110
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382601668949
# --------------------------------------------------
#
#
#
# Energy difference :  8.450330056793973
#
#
# HOMO-LUMO gap: 0.06629664648939972 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  4.088551170552235
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3820309490293
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5873398342574
# Coulomb Energy                  6313.2562945688996
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039760688514
# --------------------------------------------------
#
#
#
# Energy difference :  3.065715901956537
#
#
# HOMO-LUMO gap: 0.002523034129899404 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  4.342352713158727
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2997239216202
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1404473892944
# Coulomb Energy                  6287.7385281204506
# Exchange-Correlation Energy     -293.7503051757812
# --------------------------------------------------
# Total Energy                   -2439.7309324270418
# --------------------------------------------------
#
#
#
# Energy difference :  1.273043641809636
#
#
# HOMO-LUMO gap: 0.020616688403761636 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 0.75 seconds
#
#
#
# Density matrix difference norm:  4.259482014785636
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7097533373762
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.2005348864454
# Coulomb Energy                  6303.8952574056084
# Exchange-Correlation Energy     -294.9481201171875
# --------------------------------------------------
# Total Energy                   -2441.1219600018949
# --------------------------------------------------
#
#
#
# Energy difference :  1.3910275748530694
#
#
# HOMO-LUMO gap: 0.12298841674249318 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  0.7426945509597501
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0213983206959
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5252479173600
# Coulomb Energy                  6307.0130877779566
# Exchange-Correlation Energy     -295.2851867675781
# --------------------------------------------------
# Total Energy                   -2441.3281282323433
# --------------------------------------------------
#
#
#
# Energy difference :  0.20616823044838384
#
#
# HOMO-LUMO gap: 0.08869774640366127 au
# HOMO-LUMO gap: 2.414 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  0.4773200143002848
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4119932502726
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7993587125029
# Coulomb Energy                  6304.8715246835909
# Exchange-Correlation Energy     -295.0263366699219
# --------------------------------------------------
# Total Energy                   -2441.3273253634870
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008028688562262687
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639331663843665 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.27044233036811116
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011526901113
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5571965492527
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4796988303024
# Coulomb Energy                  6304.2835418274335
# Exchange-Correlation Energy     -294.9927341468290
# --------------------------------------------------
# Total Energy                   -2441.3465688777305
# --------------------------------------------------
#
#
#
# Energy difference :  0.019243514243498794
#
#
# HOMO-LUMO gap: 0.10571399349171137 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.11904788921439453
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011552174425
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9909388503947
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6072535843059
# Coulomb Energy                  6305.7417384171658
# Exchange-Correlation Energy     -295.1471469764329
# --------------------------------------------------
# Total Energy                   -2441.3489726647422
# --------------------------------------------------
#
#
#
# Energy difference :  0.0024037870116444537
#
#
# HOMO-LUMO gap: 0.10236078804338425 au
# HOMO-LUMO gap: 2.785 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0577500979495311
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001161609641
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1769470000345
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2273248770298
# Coulomb Energy                  6305.2554524336056
# Exchange-Correlation Energy     -295.0958123267887
# --------------------------------------------------
# Total Energy                   -2441.3498608555719
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008881908297553309
#
#
# HOMO-LUMO gap: 0.08312442515062013 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.06380956418222591
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001177595462
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6231233306862
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9393700296305
# Coulomb Energy                  6304.9498413985548
# Exchange-Correlation Energy     -295.0561982299331
# --------------------------------------------------
# Total Energy                   -2441.3499889718187
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012811624674213817
#
#
# HOMO-LUMO gap: 0.08543830011994755 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0331916254383606
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171908331
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1939552090953
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2382427906164
# Coulomb Energy                  6305.2623649426205
# Exchange-Correlation Energy     -295.0969194315245
# --------------------------------------------------
# Total Energy                   -2441.3501457467682
# --------------------------------------------------
#
#
#
# Energy difference :  0.00015677494957344607
#
#
# HOMO-LUMO gap: 0.08549154879717275 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 1.06 seconds
#
#
#
# Density matrix difference norm:  0.016475595060855743
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011743763207
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9922239183143
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1354329102583
# Coulomb Energy                  6305.1488832784298
# Exchange-Correlation Energy     -295.0824212284931
# --------------------------------------------------
# Total Energy                   -2441.3502077975054
# --------------------------------------------------
#
#
#
# Energy difference :  6.205073714227183e-05
#
#
# HOMO-LUMO gap: 0.08609918624696913 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.007378444163261781
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173440165
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0613456679475
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745636102796
# Coulomb Energy                  6305.1842264298984
# Exchange-Correlation Energy     -295.0877835472344
# --------------------------------------------------
# Total Energy                   -2441.3502180143887
# --------------------------------------------------
#
#
#
# Energy difference :  1.0216883310931735e-05
#
#
# HOMO-LUMO gap: 0.08618070639713232 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.0029313511066413507
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203849
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0439451685543
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630759318004
# Coulomb Energy                  6305.1767449668178
# Exchange-Correlation Energy     -295.0862173815029
# --------------------------------------------------
# Total Energy                   -2441.3502204908245
# --------------------------------------------------
#
#
#
# Energy difference :  2.476435838616453e-06
#
#
# HOMO-LUMO gap: 0.08626973548013728 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.06 seconds
#
#
#
# Density matrix difference norm:  0.0008019563380551894
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173088265
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357827056814
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591876048246
# Coulomb Energy                  6305.1719547504044
# Exchange-Correlation Energy     -295.0857014056241
# --------------------------------------------------
# Total Energy                   -2441.3502205954619
# --------------------------------------------------
#
#
#
# Energy difference :  1.046373654389754e-07
#
#
# HOMO-LUMO gap: 0.08626926854509459 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.000471349849012598
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000117317098
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0329991463987
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576313879418
# Coulomb Energy                  6305.1705213779323
# Exchange-Correlation Energy     -295.0854953855198
# --------------------------------------------------
# Total Energy                   -2441.3502206054300
# --------------------------------------------------
#
#
#
# Energy difference :  9.968061931431293e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.35022060543
# -------------------------------------
#
#
#
# Time taken : 83.94 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           20.95
# Density Fitting                         3.0
#     DF (gamma)                          1.0
#     DF (coeff)                          0.15
#     DF (Jtri)                           1.49
# DIIS                                    0.23
# KS matrix diagonalization               1.16
# One electron Integrals (S, T, Vnuc)     0.11
# Coulomb Integrals (2c2e + 3c2e)         14.24
# Grids construction                      16.12
# Exchange-Correlation Term               21.96
# Misc.                                   6.17
# Complete SCF                            83.94

# %% [markdown]
# ### Benchmark #8 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.17 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.5 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.12
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04110186600007637
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.16 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.93
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  31.93 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 49.57 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 54.3 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.09 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0009
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182756
# Exchange-Correlation Energy     -158.3137817382812
# --------------------------------------------------
# Total Energy                    -881.4919713840445
# --------------------------------------------------
#
#
#
# Energy difference :  881.4919713840445
#
#
# HOMO-LUMO gap: 0.6897604976023399 au
# HOMO-LUMO gap: 18.769 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  177.41135709998215
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3344840567224
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5272569821218
# Coulomb Energy                 12707.6510784192596
# Exchange-Correlation Energy     -589.0113525390625
# --------------------------------------------------
# Total Energy                   -3195.7102487674820
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2182773834375
#
#
# HOMO-LUMO gap: 0.0026273640109317764 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 1.4 seconds
#
#
#
# Density matrix difference norm:  86.09645329207515
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.1088815602234
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9652342484833
# Coulomb Energy                 10864.6201447244875
# Exchange-Correlation Energy     -358.7289123535156
# --------------------------------------------------
# Total Energy                   -3357.7951625138448
# --------------------------------------------------
#
#
#
# Energy difference :  162.08491374636287
#
#
# HOMO-LUMO gap: 0.0025107183283403396 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  65.1314818190905
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9476793264803
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4635747798156
# Coulomb Energy                 11125.2508229530322
# Exchange-Correlation Energy     -407.6778564453125
# --------------------------------------------------
# Total Energy                   -3374.4538856120216
# --------------------------------------------------
#
#
#
# Energy difference :  16.65872309817678
#
#
# HOMO-LUMO gap: 0.004421926272931753 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 1.4 seconds
#
#
#
# Density matrix difference norm:  63.85793932176286
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99948
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.3725877871620
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.9140511721616
# Coulomb Energy                 12063.8292782874450
# Exchange-Correlation Energy     -415.0684814453125
# --------------------------------------------------
# Total Energy                   -3056.2404873459436
# --------------------------------------------------
#
#
#
# Energy difference :  318.213398266078
#
#
# HOMO-LUMO gap: 0.007367263649120465 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  54.581880869348545
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.6404058440567
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.4169415165020
# Coulomb Energy                 11513.0422461899034
# Exchange-Correlation Energy     -417.4490356445312
# --------------------------------------------------
# Total Energy                   -3536.1730013552606
# --------------------------------------------------
#
#
#
# Energy difference :  479.93251400931695
#
#
# HOMO-LUMO gap: 0.001744028917478881 au
# HOMO-LUMO gap: 0.047 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  51.20538549903766
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99976
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.0687417228582
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.9091679330841
# Coulomb Energy                 11567.9585712303251
# Exchange-Correlation Energy     -419.4385681152344
# --------------------------------------------------
# Total Energy                   -3073.1823182477601
# --------------------------------------------------
#
#
#
# Energy difference :  462.99068310750044
#
#
# HOMO-LUMO gap: 0.0071037268592784725 au
# HOMO-LUMO gap: 0.193 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  44.85215126052865
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.9583327930632
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6779217737894
# Coulomb Energy                 11495.7950944772165
# Exchange-Correlation Energy     -423.7618408203125
# --------------------------------------------------
# Total Energy                   -3532.7899049354473
# --------------------------------------------------
#
#
#
# Energy difference :  459.6075866876872
#
#
# HOMO-LUMO gap: 0.0009114015652937763 au
# HOMO-LUMO gap: 0.025 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  20.64675865179223
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.8278633634109
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.3205721711629
# Coulomb Energy                 11578.8361032506655
# Exchange-Correlation Energy     -439.3337097167969
# --------------------------------------------------
# Total Energy                   -3536.5476452314560
# --------------------------------------------------
#
#
#
# Energy difference :  3.7577402960087056
#
#
# HOMO-LUMO gap: 0.0035939341767989574 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  20.82767376563895
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28136.7931694040526
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3618.6109384456763
# Coulomb Energy                 11689.0065001115217
# Exchange-Correlation Energy     -441.3365173339844
# --------------------------------------------------
# Total Energy                   -3500.0549957539170
# --------------------------------------------------
#
#
#
# Energy difference :  36.49264947753909
#
#
# HOMO-LUMO gap: 0.010383836567500221 au
# HOMO-LUMO gap: 0.283 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  22.195114108066615
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00015
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27870.4742720392351
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3570.0728402066852
# Coulomb Energy                 11460.1691410651438
# Exchange-Correlation Energy     -435.4844665527344
# --------------------------------------------------
# Total Energy                   -3505.2595048932180
# --------------------------------------------------
#
#
#
# Energy difference :  5.204509139301081
#
#
# HOMO-LUMO gap: 0.010546858301069939 au
# HOMO-LUMO gap: 0.287 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  15.724689798393664
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00034
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28102.6568169885068
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3578.5287175446424
# Coulomb Energy                 11610.6806684096628
# Exchange-Correlation Energy     -438.4918518066406
# --------------------------------------------------
# Total Energy                   -3581.4820304139193
# --------------------------------------------------
#
#
#
# Energy difference :  76.22252552070131
#
#
# HOMO-LUMO gap: 0.00017162596835829796 au
# HOMO-LUMO gap: 0.005 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  13.536172981630804
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27853.4980926141761
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3502.7021216173616
# Coulomb Energy                 11468.0491105892761
# Exchange-Correlation Energy     -426.0708618164062
# --------------------------------------------------
# Total Energy                   -3538.3604697970204
# --------------------------------------------------
#
#
#
# Energy difference :  43.12156061689893
#
#
# HOMO-LUMO gap: 0.05018410223526586 au
# HOMO-LUMO gap: 1.366 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  12.95483114387958
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27988.0476973799159
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3531.7566782111408
# Coulomb Energy                 11533.2351835453555
# Exchange-Correlation Energy     -432.4128723144531
# --------------------------------------------------
# Total Energy                   -3585.0114555109521
# --------------------------------------------------
#
#
#
# Energy difference :  46.65098571393173
#
#
# HOMO-LUMO gap: 0.0035872787636654496 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  1.9546763938950167
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27979.4416588377971
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9397798914770
# Coulomb Energy                 11525.5555180082665
# Exchange-Correlation Energy     -431.9874572753906
# --------------------------------------------------
# Total Energy                   -3585.4765657865228
# --------------------------------------------------
#
#
#
# Energy difference :  0.46511027557062334
#
#
# HOMO-LUMO gap: 0.09761029479544092 au
# HOMO-LUMO gap: 2.656 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  1.1228761713787032
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1284498101377
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.5841490631683
# Coulomb Energy                 11540.9990002101622
# Exchange-Correlation Energy     -433.6154785156250
# --------------------------------------------------
# Total Energy                   -3585.7035266255098
# --------------------------------------------------
#
#
#
# Energy difference :  0.22696083898699726
#
#
# HOMO-LUMO gap: 0.08536692124569989 au
# HOMO-LUMO gap: 2.323 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  0.41265864918653916
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99988
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.1878027108760
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6540396769105
# Coulomb Energy                 11539.6998760599599
# Exchange-Correlation Energy     -433.3433837890625
# --------------------------------------------------
# Total Energy                   -3585.7200183361438
# --------------------------------------------------
#
#
#
# Energy difference :  0.0164917106339999
#
#
# HOMO-LUMO gap: 0.10214920315927967 au
# HOMO-LUMO gap: 2.780 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.20172490431840345
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.1506706040891
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.9011413849835
# Coulomb Energy                 11539.4370070179084
# Exchange-Correlation Energy     -433.3742675781250
# --------------------------------------------------
# Total Energy                   -3585.7295373523993
# --------------------------------------------------
#
#
#
# Energy difference :  0.009519016255580937
#
#
# HOMO-LUMO gap: 0.10257236282315621 au
# HOMO-LUMO gap: 2.791 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.05775662617987306
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00003
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8315225976912
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7515346261584
# Coulomb Energy                 11539.2453821603995
# Exchange-Correlation Energy     -433.3528137207031
# --------------------------------------------------
# Total Energy                   -3585.7301671049154
# --------------------------------------------------
#
#
#
# Energy difference :  0.0006297525160334771
#
# Switching to double precision for XC evaluation after 19 iterations!
#
#
# HOMO-LUMO gap: 0.10333565343633189 au
# HOMO-LUMO gap: 2.812 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.015764233596048796
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163679121
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9546484510065
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8365186137407
# Coulomb Energy                 11539.2949108929570
# Exchange-Correlation Energy     -433.3705876768653
# --------------------------------------------------
# Total Energy                   -3585.7365541942509
# --------------------------------------------------
#
#
#
# Energy difference :  0.006387089335476048
#
#
# HOMO-LUMO gap: 0.10329798135403037 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.006444314414536723
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162384082
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0156988071394
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8623553923908
# Coulomb Energy                 11539.3354867227808
# Exchange-Correlation Energy     -433.3759732342657
# --------------------------------------------------
# Total Energy                   -3585.7365774993123
# --------------------------------------------------
#
#
#
# Energy difference :  2.3305061404244043e-05
#
#
# HOMO-LUMO gap: 0.10328752577349873 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.00673238754780188
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001633568587
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8542823251046
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7751677642600
# Coulomb Energy                 11539.2504483181747
# Exchange-Correlation Energy     -433.3651708535850
# --------------------------------------------------
# Total Energy                   -3585.7365846693319
# --------------------------------------------------
#
#
#
# Energy difference :  7.170019671320915e-06
#
#
# HOMO-LUMO gap: 0.10339334014875651 au
# HOMO-LUMO gap: 2.813 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.006383061324661827
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001636620266
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0189867266708
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8511337638556
# Coulomb Energy                 11539.3507114226522
# Exchange-Correlation Energy     -433.3767009888909
# --------------------------------------------------
# Total Energy                   -3585.7365901021312
# --------------------------------------------------
#
#
#
# Energy difference :  5.432799298432656e-06
#
#
# HOMO-LUMO gap: 0.10323532619568265 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.004686549187055784
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162695449
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9570179395632
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8162383070130
# Coulomb Energy                 11539.3195143808261
# Exchange-Correlation Energy     -433.3725835902533
# --------------------------------------------------
# Total Energy                   -3585.7365964150576
# --------------------------------------------------
#
#
#
# Energy difference :  6.312926416285336e-06
#
#
# HOMO-LUMO gap: 0.10324224242729838 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.0011019488195221732
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162791063
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9496004572866
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8136302042617
# Coulomb Energy                 11539.3144531197759
# Exchange-Correlation Energy     -433.3723319654010
# --------------------------------------------------
# Total Energy                   -3585.7365966717280
# --------------------------------------------------
#
#
#
# Energy difference :  2.566703187767416e-07
#
#
# HOMO-LUMO gap: 0.10324195903659927 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.0004532620220923568
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000016268293
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9509918516596
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8139667113392
# Coulomb Energy                 11539.3156271427961
# Exchange-Correlation Energy     -433.3724511365888
# --------------------------------------------------
# Total Energy                   -3585.7365967071892
# --------------------------------------------------
#
#
#
# Energy difference :  3.546119842212647e-08
#
# SCF Converged after 26 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596707189
# -------------------------------------
#
#
#
# Time taken : 186.04 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           54.39
# Density Fitting                         4.68
#     DF (gamma)                          1.54
#     DF (coeff)                          0.11
#     DF (Jtri)                           2.4
# DIIS                                    0.47
# KS matrix diagonalization               1.9
# One electron Integrals (S, T, Vnuc)     0.17
# Coulomb Integrals (2c2e + 3c2e)         31.93
# Grids construction                      49.57
# Exchange-Correlation Term               35.64
# Misc.                                   7.28
# Complete SCF                            186.04
