# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 33.02 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 22.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.5 MB/s eta 0:00:0000:01
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=bc4830dbc36d4643ca4b87219fed50bf79f7b581d0d5022a8fa12d1a0dceb9e1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vu3bpgce/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 16.29 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.4 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  5.8
# Time taken to evaluate the square roots needed:  0.1
# Time for significant indices evaluation:  2.1346160440000403
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 8.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  6.72
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  37.88 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.81 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.09 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.5 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709560
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632573
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325733
#
#
# HOMO-LUMO gap: 2.643107928167083 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.45 seconds
#
#
#
# Density matrix difference norm:  43.34767137041583
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.99999474389981
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709419
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316044
# Coulomb Energy                   501.1198589452467
# Exchange-Correlation Energy      -62.5998011282692
# --------------------------------------------------
# Total Energy                    -340.0652765782363
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851497898
#
#
# HOMO-LUMO gap: 0.004902711060936593 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  28.61247171884578
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00009840286507
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456774
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785942
# Coulomb Energy                   293.3088657954301
# Exchange-Correlation Energy      -37.4191110537733
# --------------------------------------------------
# Total Energy                    -355.5094553813029
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803066563
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# HOMO-LUMO gap: 0.040361476987180844 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  21.394016787365956
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445384
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275505
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458492
# Coulomb Energy                   367.2127830476507
# Exchange-Correlation Energy      -44.5841010136101
# --------------------------------------------------
# Total Energy                    -380.5867878035371
# --------------------------------------------------
#
#
#
# Energy difference :  25.077332422234235
#
#
# HOMO-LUMO gap: 0.018048571143140194 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  5.197480933689679
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000006874740826
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703844
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754545
# Coulomb Energy                   364.3533796551092
# Exchange-Correlation Energy      -44.5594485029987
# --------------------------------------------------
# Total Energy                    -378.6274635986959
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048412094
#
#
# HOMO-LUMO gap: 0.08493582284762889 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  4.779285269952244
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001287711403
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186530
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180453
# Coulomb Energy                   368.1554971681591
# Exchange-Correlation Energy      -45.0868782881900
# --------------------------------------------------
# Total Energy                    -381.1270633765151
# --------------------------------------------------
#
#
#
# Energy difference :  2.499599777819185
#
#
# HOMO-LUMO gap: 0.14183855738595139 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5205766173116946
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089465
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233273
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990146
# Coulomb Energy                   369.0647619107202
# Exchange-Correlation Energy      -45.1368862216101
# --------------------------------------------------
# Total Energy                    -381.2275584910789
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456378468
#
#
# HOMO-LUMO gap: 0.13514723909450863 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.3315886778248091
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000011665971485
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176821
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774517
# Coulomb Energy                   369.6340156607509
# Exchange-Correlation Energy      -45.2090855965860
# --------------------------------------------------
# Total Energy                    -381.2508898319419
# --------------------------------------------------
#
#
#
# Energy difference :  0.023331340863023797
#
#
# HOMO-LUMO gap: 0.019732057382643657 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.5818251308677296
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000861700552
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110876
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893529
# Coulomb Energy                   374.0898923937953
# Exchange-Correlation Energy      -45.7569321945902
# --------------------------------------------------
# Total Energy                    -381.3827647784062
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646433606
#
#
# HOMO-LUMO gap: 0.12604481221456512 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.4584549614614306
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767308
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524633
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358426
# Coulomb Energy                   377.3880704578806
# Exchange-Correlation Energy      -46.1034837100256
# --------------------------------------------------
# Total Energy                    -381.4206849246420
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623581963
#
#
# HOMO-LUMO gap: 0.1662734898620262 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.145068865170786
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007579020874
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358420
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690208
# Coulomb Energy                   377.1736811284870
# Exchange-Correlation Energy      -46.0748895148565
# --------------------------------------------------
# Total Energy                    -381.4268823090672
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384425149721
#
#
# HOMO-LUMO gap: 0.18126074112639745 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0557488499895431
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074251987
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179419
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114327
# Coulomb Energy                   377.1977734128238
# Exchange-Correlation Energy      -46.0810670348479
# --------------------------------------------------
# Total Energy                    -381.4272916844097
# --------------------------------------------------
#
#
#
# Energy difference :  0.00040937534254226193
#
#
# HOMO-LUMO gap: 0.18111025828114274 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.02562530605154798
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000075037254
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006493
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114205
# Coulomb Energy                   377.1502888734876
# Exchange-Correlation Energy      -46.0776486461289
# --------------------------------------------------
# Total Energy                    -381.4274184177466
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333685597754
#
#
# HOMO-LUMO gap: 0.1806839556567792 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.008432526433850906
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750035488
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167551
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298563
# Coulomb Energy                   377.1545462611527
# Exchange-Correlation Energy      -46.0767747067594
# --------------------------------------------------
# Total Energy                    -381.4274393883819
# --------------------------------------------------
#
#
#
# Energy difference :  2.097063531891763e-05
#
#
# HOMO-LUMO gap: 0.1806705357501595 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0018444600034109053
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750025072
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068240
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736995
# Coulomb Energy                   377.1524231958064
# Exchange-Correlation Energy      -46.0765296383170
# --------------------------------------------------
# Total Energy                    -381.4274391315115
# --------------------------------------------------
#
#
#
# Energy difference :  2.5687040761113167e-07
#
#
# HOMO-LUMO gap: 0.18064597252288678 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0011511413608275532
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074989492
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206493
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789376
# Coulomb Energy                   377.1549870542100
# Exchange-Correlation Energy      -46.0768423766162
# --------------------------------------------------
# Total Energy                    -381.4274396199944
# --------------------------------------------------
#
#
#
# Energy difference :  4.884828967988142e-07
#
#
# HOMO-LUMO gap: 0.1806425643884111 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.00010543279337989783
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836627
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081811
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075856
# Coulomb Energy                   377.1556791349416
# Exchange-Correlation Energy      -46.0769272993465
# --------------------------------------------------
# Total Energy                    -381.4274396208769
# --------------------------------------------------
#
#
#
# Energy difference :  8.824940778140444e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396208769
# -------------------------------------
#
#
#
# Time taken : 68.99 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.59
# Density Fitting                         1.72
#     DF (gamma)                          0.69
#     DF (coeff)                          0.15
#     DF (Jtri)                           0.6
# DIIS                                    0.7
# KS matrix diagonalization               0.73
# One electron Integrals (S, T, Vnuc)     16.29
# Coulomb Integrals (2c2e + 3c2e)         37.88
# Grids construction                      0.81
# Exchange-Correlation Term               4.11
# Misc.                                   4.16
# Complete SCF                            68.99

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.08 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.002078516999972635
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.06
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  1.57 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.97 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.87 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00135664103416
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091871
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371782
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645300008
# --------------------------------------------------
#
#
#
# Energy difference :  185.44746453000084
#
#
# HOMO-LUMO gap: 1.7654343749560426 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  66.88358764205427
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084647
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437884
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987505984
# Coulomb Energy                  1272.5954275689564
# Exchange-Correlation Energy     -125.2198694441764
# --------------------------------------------------
# Total Energy                    -680.0789187511778
# --------------------------------------------------
#
#
#
# Energy difference :  494.6314542211769
#
#
# HOMO-LUMO gap: 0.00040456056756288383 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  39.27522964434749
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00120175844562
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692493461
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666726965
# Coulomb Energy                   861.6558693045979
# Exchange-Correlation Energy      -75.4419310839565
# --------------------------------------------------
# Total Energy                    -709.3563182387763
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487598586
#
#
# HOMO-LUMO gap: 0.027815605001243256 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.21 seconds
#
#
#
# Density matrix difference norm:  28.147358564317404
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663975
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672037463
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170660274
# Coulomb Energy                  1000.6400676119473
# Exchange-Correlation Energy      -87.3507096616619
# --------------------------------------------------
# Total Energy                    -733.7433460702015
# --------------------------------------------------
#
#
#
# Energy difference :  24.387027831425144
#
#
# HOMO-LUMO gap: 0.007352227195523253 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  18.10305398307392
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642287
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026564848
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102958210
# Coulomb Energy                  1039.7254935642134
# Exchange-Correlation Energy      -89.9717584581014
# --------------------------------------------------
# Total Energy                    -689.6320111373200
# --------------------------------------------------
#
#
#
# Energy difference :  44.111334932881505
#
#
# HOMO-LUMO gap: 0.010701793703113902 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  13.03426010369089
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576006
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022387576
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597997
# Coulomb Energy                  1004.3417767420137
# Exchange-Correlation Energy      -89.2334391642949
# --------------------------------------------------
# Total Energy                    -749.6400714840070
# --------------------------------------------------
#
#
#
# Energy difference :  60.00806034668699
#
#
# HOMO-LUMO gap: 0.025771351282758148 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  7.653358064505487
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554305
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132844895
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410207
# Coulomb Energy                   997.3319760641210
# Exchange-Correlation Energy      -89.6717481072308
# --------------------------------------------------
# Total Energy                    -755.2352624693468
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985339855
#
#
# HOMO-LUMO gap: 0.0035684795198578784 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  6.3097383350927
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567738
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204414857
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857161328
# Coulomb Energy                  1009.6464766736838
# Exchange-Correlation Energy      -89.9069114779355
# --------------------------------------------------
# Total Energy                    -755.2788234123725
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094302568181
#
#
# HOMO-LUMO gap: 0.009175061886938916 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  8.057132717374955
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0005030016397
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153727062
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119322904
# Coulomb Energy                  1035.0050622425470
# Exchange-Correlation Energy      -92.6658378595354
# --------------------------------------------------
# Total Energy                    -747.5712329401722
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472200309
#
#
# HOMO-LUMO gap: 0.11766237193726428 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  7.715013429014765
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306771
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903699396
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992833251
# Coulomb Energy                  1048.9988443900629
# Exchange-Correlation Energy      -94.9610811404639
# --------------------------------------------------
# Total Energy                    -761.7908817197836
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779611362
#
#
# HOMO-LUMO gap: 0.010925426636527208 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  6.79031574939886
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377906
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412177233
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466859187
# Coulomb Energy                  1013.7508689108686
# Exchange-Correlation Energy      -90.9428726052260
# --------------------------------------------------
# Total Energy                    -756.2816521089298
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229610853708
#
#
# HOMO-LUMO gap: 0.14929732696591416 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  6.534633252764803
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202662
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716108004
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461513300
# Coulomb Energy                  1025.7750806789752
# Exchange-Correlation Energy      -92.2703810888406
# --------------------------------------------------
# Total Energy                    -762.7969797521039
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327643174032
#
#
# HOMO-LUMO gap: 0.1335269786549455 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.5338338749095162
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332058
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534239
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792903040
# Coulomb Energy                  1024.7461321400160
# Exchange-Correlation Energy      -92.1885648748857
# --------------------------------------------------
# Total Energy                    -762.8402252807577
# --------------------------------------------------
#
#
#
# Energy difference :  0.04324552865386977
#
#
# HOMO-LUMO gap: 0.11056223799059567 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.36027133595360034
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916642
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590203864
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517293477
# Coulomb Energy                  1023.6379077074362
# Exchange-Correlation Energy      -92.0697499681874
# --------------------------------------------------
# Total Energy                    -762.8490034345582
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153800449218
#
#
# HOMO-LUMO gap: 0.08600353272991171 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.32529885675739767
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680042
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240862445
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261721671
# Coulomb Energy                  1024.4836887100082
# Exchange-Correlation Energy      -92.1371699397467
# --------------------------------------------------
# Total Energy                    -762.8531330265841
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592025947204
#
#
# HOMO-LUMO gap: 0.11636080747431188 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.15534224616201847
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503608
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117169209
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900056050
# Coulomb Energy                  1024.5663100626321
# Exchange-Correlation Energy      -92.1605267750485
# --------------------------------------------------
# Total Energy                    -762.8605923065002
# --------------------------------------------------
#
#
#
# Energy difference :  0.007459279916020023
#
#
# HOMO-LUMO gap: 0.12269239243457966 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.04060711223154171
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000722186563
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080774
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362773
# Coulomb Energy                  1024.7015706722600
# Exchange-Correlation Energy      -92.1773633390792
# --------------------------------------------------
# Total Energy                    -762.8609189213876
# --------------------------------------------------
#
#
#
# Energy difference :  0.000326614887399046
#
#
# HOMO-LUMO gap: 0.11742913475999248 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.019703163527393833
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471097
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348739369
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569947
# Coulomb Energy                  1024.5590092024240
# Exchange-Correlation Energy      -92.1602830990749
# --------------------------------------------------
# Total Energy                    -762.8609667963615
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497391589568e-05
#
#
# HOMO-LUMO gap: 0.11815573488918407 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.008211499893083606
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163928
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862346
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811708
# Coulomb Energy                  1024.5676148746741
# Exchange-Correlation Energy      -92.1612728329153
# --------------------------------------------------
# Total Energy                    -762.8609882460730
# --------------------------------------------------
#
#
#
# Energy difference :  2.1449711539389682e-05
#
#
# HOMO-LUMO gap: 0.1184257103216913 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0019148361600819458
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786601
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971632
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346162
# Coulomb Energy                  1024.5642249369573
# Exchange-Correlation Energy      -92.1610088236033
# --------------------------------------------------
# Total Energy                    -762.8609886319612
# --------------------------------------------------
#
#
#
# Energy difference :  3.8588814277318306e-07
#
#
# HOMO-LUMO gap: 0.1183577160649669 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.001077639616612894
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816392
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020336
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743340
# Coulomb Energy                  1024.5683629999305
# Exchange-Correlation Energy      -92.1613819110203
# --------------------------------------------------
# Total Energy                    -762.8609888215572
# --------------------------------------------------
#
#
#
# Energy difference :  1.8959599401568994e-07
#
#
# HOMO-LUMO gap: 0.11837118338558245 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.0005041312670936516
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785557
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158240
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323475
# Coulomb Energy                  1024.5701171428821
# Exchange-Correlation Energy      -92.1615907612842
# --------------------------------------------------
# Total Energy                    -762.8609888846465
# --------------------------------------------------
#
#
#
# Energy difference :  6.30893737252336e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846465
# -------------------------------------
#
#
#
# Time taken : 10.46 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           1.9
# Density Fitting                         0.4
#     DF (gamma)                          0.13
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.15
# DIIS                                    0.07
# KS matrix diagonalization               0.23
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         1.57
# Grids construction                      0.97
# Exchange-Correlation Term               3.42
# Misc.                                   1.85
# Complete SCF                            10.46

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.17 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.04
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007535869999969691
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.05 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.19
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  5.57 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.55 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.4 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.04 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718097
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355663
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973828
# --------------------------------------------------
#
#
#
# Energy difference :  374.93033389738275
#
#
# HOMO-LUMO gap: 1.8502864435405049 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 0.5 seconds
#
#
#
# Density matrix difference norm:  107.82844284433405
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99998558772944
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090068636
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391767106
# Coulomb Energy                  3537.3287033060924
# Exchange-Correlation Energy     -250.6110528162099
# --------------------------------------------------
# Total Energy                   -1359.8923755096084
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122257
#
#
# HOMO-LUMO gap: 0.0021139216449359566 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  57.36707021924683
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512904
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256489842
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810812374
# Coulomb Energy                  2705.3966179573895
# Exchange-Correlation Energy     -151.8752804393525
# --------------------------------------------------
# Total Energy                   -1419.0480632190479
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770943946
#
#
# HOMO-LUMO gap: 0.019740723738682353 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  48.047190163869836
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001717849239
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823852514
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892853908
# Coulomb Energy                  3071.8764250115710
# Exchange-Correlation Energy     -174.7460035329272
# --------------------------------------------------
# Total Energy                   -1362.4047277905556
# --------------------------------------------------
#
#
#
# Energy difference :  56.643335428492264
#
#
# HOMO-LUMO gap: 0.014747714725704617 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  40.92570828257132
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158727
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198127628
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571583630
# Coulomb Energy                  3051.7165832284959
# Exchange-Correlation Energy     -176.2007428393859
# --------------------------------------------------
# Total Energy                   -1378.8564784346286
# --------------------------------------------------
#
#
#
# Energy difference :  16.451750644072945
#
#
# HOMO-LUMO gap: 0.012539973801544577 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  26.932582172185402
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863938
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022788796
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850556427
# Coulomb Energy                  3003.5375755726118
# Exchange-Correlation Energy     -179.3125720191555
# --------------------------------------------------
# Total Energy                   -1523.5033698391189
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140449036
#
#
# HOMO-LUMO gap: 0.0030874947630368937 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  13.423370100247858
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488925
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332571066
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671362864
# Coulomb Energy                  2977.4795296023112
# Exchange-Correlation Energy     -178.1026352540068
# --------------------------------------------------
# Total Energy                   -1499.0865279418540
# --------------------------------------------------
#
#
#
# Energy difference :  24.41684189726493
#
#
# HOMO-LUMO gap: 0.0318146127278172 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  12.444575042395195
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146518
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885446465
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462464139
# Coulomb Energy                  3000.9261851729143
# Exchange-Correlation Energy     -180.8962339958107
# --------------------------------------------------
# Total Energy                   -1522.7463472904683
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348614292
#
#
# HOMO-LUMO gap: 0.01295241289961277 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  6.016412544073009
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001219220139
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025157396
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516682562
# Coulomb Energy                  3041.7824359801921
# Exchange-Correlation Energy     -185.1339645332875
# --------------------------------------------------
# Total Energy                   -1523.4476355699176
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794492725
#
#
# HOMO-LUMO gap: 0.021473549810249473 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  6.22275170521667
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99995948810573
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888911440
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569990764
# Coulomb Energy                  3063.1248487682324
# Exchange-Correlation Energy     -185.9132949764480
# --------------------------------------------------
# Total Energy                   -1521.9201342696224
# --------------------------------------------------
#
#
#
# Energy difference :  1.527501300295171
#
#
# HOMO-LUMO gap: 0.07988335372984559 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  4.43484852362186
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846706
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733679642
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444889929
# Coulomb Energy                  3048.3985990983092
# Exchange-Correlation Energy     -185.3448733864794
# --------------------------------------------------
# Total Energy                   -1525.5849593364801
# --------------------------------------------------
#
#
#
# Energy difference :  3.664825066857702
#
#
# HOMO-LUMO gap: 0.11911980736810915 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.8335133099883149
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003812437745
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577372517
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794201
# Coulomb Energy                  3044.2765927793653
# Exchange-Correlation Energy     -184.7849150214355
# --------------------------------------------------
# Total Energy                   -1525.7423647692403
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543276024255
#
#
# HOMO-LUMO gap: 0.1091438515168656 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.43782033360053657
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733324
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238684187
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349361
# Coulomb Energy                  3039.9455617679805
# Exchange-Correlation Energy     -184.3161788613719
# --------------------------------------------------
# Total Energy                   -1525.7678971962114
# --------------------------------------------------
#
#
#
# Energy difference :  0.025532426971039968
#
#
# HOMO-LUMO gap: 0.08055636124743429 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.27956022877674996
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976173
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464905724
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862115682
# Coulomb Energy                  3041.4914846757097
# Exchange-Correlation Energy     -184.5235703798658
# --------------------------------------------------
# Total Energy                   -1525.7860021524989
# --------------------------------------------------
#
#
#
# Energy difference :  0.01810495628751596
#
#
# HOMO-LUMO gap: 0.035533211903430215 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.20188173701249854
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000406842974
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555700412
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365256005
# Coulomb Energy                  3040.7248454918308
# Exchange-Correlation Energy     -184.4775892871706
# --------------------------------------------------
# Total Energy                   -1525.7891190091186
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031168566197266045
#
#
# HOMO-LUMO gap: 0.04487089486670906 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.07625293104140587
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003965723616
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379111048
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103464
# Coulomb Energy                  3040.4560830346627
# Exchange-Correlation Energy     -184.4308753791050
# --------------------------------------------------
# Total Energy                   -1525.7902311145381
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011121054194518365
#
#
# HOMO-LUMO gap: 0.05285664136827291 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.028372083614758594
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000394713102
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669642816
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903981586
# Coulomb Energy                  3040.4602645950272
# Exchange-Correlation Energy     -184.4309026475864
# --------------------------------------------------
# Total Energy                   -1525.7903707880196
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348149890313
#
#
# HOMO-LUMO gap: 0.04994812744084533 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.012785251242533519
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505607
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113930095
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713317488
# Coulomb Energy                  3040.4067159125339
# Exchange-Correlation Energy     -184.4260067735599
# --------------------------------------------------
# Total Energy                   -1525.7903870916248
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303605207212968e-05
#
#
# HOMO-LUMO gap: 0.050833655730684546 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.006040021434417792
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112007
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954297
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920339
# Coulomb Energy                  3040.4581957845112
# Exchange-Correlation Energy     -184.4326037898885
# --------------------------------------------------
# Total Energy                   -1525.7903978781105
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786485745484242e-05
#
#
# HOMO-LUMO gap: 0.05068603589595562 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.001965540750234082
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378537
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801126700
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451390
# Coulomb Energy                  3040.4659355248714
# Exchange-Correlation Energy     -184.4328301188923
# --------------------------------------------------
# Total Energy                   -1525.7903988308899
# --------------------------------------------------
#
#
#
# Energy difference :  9.527793736197054e-07
#
#
# HOMO-LUMO gap: 0.05071262125621322 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.001039432287960088
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780365
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447992
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272611495
# Coulomb Energy                  3040.4701320976264
# Exchange-Correlation Energy     -184.4333553536756
# --------------------------------------------------
# Total Energy                   -1525.7903988090375
# --------------------------------------------------
#
#
#
# Energy difference :  2.1852429199498147e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090375
# -------------------------------------
#
#
#
# Time taken : 32.22 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.44
# Density Fitting                         1.0
#     DF (gamma)                          0.36
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.46
# DIIS                                    0.11
# KS matrix diagonalization               0.41
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         5.57
# Grids construction                      4.55
# Exchange-Correlation Term               9.3
# Misc.                                   3.77
# Complete SCF                            32.22

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.11 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.29 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.07
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.016513460000055602
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.09 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.44
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  14.44 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.01 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 20.58 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.2 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  320.00291984078206
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004570
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513719
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513719
#
#
# HOMO-LUMO gap: 1.3453174761630606 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.02 seconds
#
#
#
# Density matrix difference norm:  144.01406386862672
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99996720715313
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016246376
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642079750
# Coulomb Energy                  7102.4006978646794
# Exchange-Correlation Energy     -401.0386878050766
# --------------------------------------------------
# Total Energy                   -2175.7881061964454
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450734
#
#
# HOMO-LUMO gap: 0.00363265281709374 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.02 seconds
#
#
#
# Density matrix difference norm:  71.9942723964891
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247207
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645627221
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704935937
# Coulomb Energy                  5771.7138319756505
# Exchange-Correlation Energy     -243.8524720616970
# --------------------------------------------------
# Total Energy                   -2274.5129129945599
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679811451
#
#
# HOMO-LUMO gap: 0.004964611535592883 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  58.10070148944777
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00214404156077
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804077483
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573469894
# Coulomb Energy                  6321.7172809554122
# Exchange-Correlation Energy     -278.3781618573671
# --------------------------------------------------
# Total Energy                   -2158.4748828020984
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019246152
#
#
# HOMO-LUMO gap: 0.014474030572471791 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  53.369975491999796
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0018076772096
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768221782
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230016969
# Coulomb Energy                  6361.2336350691849
# Exchange-Correlation Energy     -281.9436333442585
# --------------------------------------------------
# Total Energy                   -2182.5642309349414
# --------------------------------------------------
#
#
#
# Energy difference :  24.089348132843043
#
#
# HOMO-LUMO gap: 0.008841694001840844 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  42.839015094618425
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00099084148945
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446989241
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382083808
# Coulomb Energy                  6294.5110601767019
# Exchange-Correlation Energy     -283.9707682331788
# --------------------------------------------------
# Total Energy                   -2345.8009933864059
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676245146453
#
#
# HOMO-LUMO gap: 0.007160714234104054 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  32.181862600033284
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99978638551795
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019083654
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650758478
# Coulomb Energy                  6214.1516556227762
# Exchange-Correlation Energy     -284.6344014150677
# --------------------------------------------------
# Total Energy                   -2343.5239614641941
# --------------------------------------------------
#
#
#
# Energy difference :  2.2770319222117905
#
#
# HOMO-LUMO gap: 0.0024503750067299684 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  33.32333314013956
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156512
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115029562
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996839019
# Coulomb Energy                  6284.6237010000741
# Exchange-Correlation Energy     -286.3084442723912
# --------------------------------------------------
# Total Energy                   -2352.7413339307577
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372466563575
#
#
# HOMO-LUMO gap: 0.006673318400108624 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  26.09828191619039
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002679784586
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383795080
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896604668
# Coulomb Energy                  6418.8046173146458
# Exchange-Correlation Energy     -305.3162932895825
# --------------------------------------------------
# Total Energy                   -2410.9382035333647
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686960260697
#
#
# HOMO-LUMO gap: 0.007960539525526014 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  17.534698642305447
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057025291
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201728681
# Coulomb Energy                  6329.9135850756011
# Exchange-Correlation Energy     -297.7524519042124
# --------------------------------------------------
# Total Energy                   -2373.3942311976571
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397233570762
#
#
# HOMO-LUMO gap: 0.01399783868445234 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  16.420704644256283
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998237983233
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814378838
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928228726
# Coulomb Energy                  6324.0705156359654
# Exchange-Correlation Energy     -296.6169927406261
# --------------------------------------------------
# Total Energy                   -2423.4444445590580
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021336140089
#
#
# HOMO-LUMO gap: 0.0058017169200579866 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  17.913629073358887
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008255772793
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871578874
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553208961
# Coulomb Energy                  6269.4959589867121
# Exchange-Correlation Energy     -292.3687260429074
# --------------------------------------------------
# Total Energy                   -2388.5334777325716
# --------------------------------------------------
#
#
#
# Energy difference :  34.9109668264864
#
#
# HOMO-LUMO gap: 0.011739724734790902 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  18.86481092929505
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00089534288895
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999708315
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986944248
# Coulomb Energy                  6304.9912271518733
# Exchange-Correlation Energy     -292.7049362976529
# --------------------------------------------------
# Total Energy                   -2419.7690892615701
# --------------------------------------------------
#
#
#
# Energy difference :  31.23561152899856
#
#
# HOMO-LUMO gap: 0.001699592599958652 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  14.268938598112559
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015431500447
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930026788
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204600113
# Coulomb Energy                  6279.2250589181094
# Exchange-Correlation Energy     -293.0502585425019
# --------------------------------------------------
# Total Energy                   -2419.7439510064451
# --------------------------------------------------
#
#
#
# Energy difference :  0.025138255125057185
#
#
# HOMO-LUMO gap: 0.0058464312953153685 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  12.512861010010836
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026512183956
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104144380
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140345409
# Coulomb Energy                  6304.4543925194303
# Exchange-Correlation Energy     -294.2073055525674
# --------------------------------------------------
# Total Energy                   -2431.0698882524193
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937245974274
#
#
# HOMO-LUMO gap: 0.0164523497903256 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  10.313139445361863
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775177
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763742256
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614306953
# Coulomb Energy                  6320.4324015615975
# Exchange-Correlation Energy     -296.9899338067766
# --------------------------------------------------
# Total Energy                   -2429.5155260280962
# --------------------------------------------------
#
#
#
# Energy difference :  1.5543622243230857
#
#
# HOMO-LUMO gap: 0.005064351287493107 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  8.084972670136343
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0000976405893
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466820755
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611281466
# Coulomb Energy                  6316.3510407203139
# Exchange-Correlation Energy     -296.7435745397938
# --------------------------------------------------
# Total Energy                   -2437.9484982127942
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972184697974
#
#
# HOMO-LUMO gap: 0.058930389019684434 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  4.102604849939525
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001181061176
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030028584
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451750933
# Coulomb Energy                  6313.1881517258735
# Exchange-Correlation Energy     -295.9055099899409
# --------------------------------------------------
# Total Energy                   -2441.0025949312185
# --------------------------------------------------
#
#
#
# Energy difference :  3.054096718424262
#
#
# HOMO-LUMO gap: 0.0053372502556451595 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  6.254076480865544
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001236198701
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051425613
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545156488
# Coulomb Energy                  6280.4277633566435
# Exchange-Correlation Energy     -293.2139724471070
# --------------------------------------------------
# Total Energy                   -2436.9286385567611
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956374457339
#
#
# HOMO-LUMO gap: 0.011871840138575764 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  7.413375411581405
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026335587563
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726555269197
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918963423
# Coulomb Energy                  6298.7681987640926
# Exchange-Correlation Energy     -294.0996241364871
# --------------------------------------------------
# Total Energy                   -2439.1315678423571
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292855959284
#
#
# HOMO-LUMO gap: 0.10362999781340992 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  4.188397590387177
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011624361304
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634484980368
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696441283
# Coulomb Energy                  6305.6013415969283
# Exchange-Correlation Energy     -295.1700654127299
# --------------------------------------------------
# Total Energy                   -2441.2043815090947
# --------------------------------------------------
#
#
#
# Energy difference :  2.072813666737602
#
#
# HOMO-LUMO gap: 0.030358347395827295 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  1.0881186802509994
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001058435007
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355888895
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042586952
# Coulomb Energy                  6306.4146008215466
# Exchange-Correlation Energy     -295.1986114173474
# --------------------------------------------------
# Total Energy                   -2441.2281207653796
# --------------------------------------------------
#
#
#
# Energy difference :  0.023739256284898147
#
#
# HOMO-LUMO gap: 0.1015673865651418 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.6147083203190182
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011386478894
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391370734
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706614467
# Coulomb Energy                  6305.3788664323174
# Exchange-Correlation Energy     -295.1059315046042
# --------------------------------------------------
# Total Energy                   -2441.3391123872998
# --------------------------------------------------
#
#
#
# Energy difference :  0.1109916219202205
#
#
# HOMO-LUMO gap: 0.12914420527796922 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  0.2286675314064141
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011297097154
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680216146346
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454932008
# Coulomb Energy                  6306.4753103435633
# Exchange-Correlation Energy     -295.2425453773833
# --------------------------------------------------
# Total Energy                   -2441.3433899946394
# --------------------------------------------------
#
#
#
# Energy difference :  0.0042776073396453285
#
#
# HOMO-LUMO gap: 0.11914092735905588 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.13316828818730997
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924017
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663368321
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009456144
# Coulomb Energy                  6305.4375957462998
# Exchange-Correlation Energy     -295.1178679622989
# --------------------------------------------------
# Total Energy                   -2441.3482164466022
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451962799183
#
#
# HOMO-LUMO gap: 0.07758609962081796 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.16794684494010206
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011918273225
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810381974
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356906468
# Coulomb Energy                  6304.4474549980332
# Exchange-Correlation Energy     -294.9863691577391
# --------------------------------------------------
# Total Energy                   -2441.3482383466417
# --------------------------------------------------
#
#
#
# Energy difference :  2.1900039428146556e-05
#
#
# HOMO-LUMO gap: 0.082204074139992 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.08195634583068494
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001176128903
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560690808
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184241940
# Coulomb Energy                  6305.2666287336406
# Exchange-Correlation Energy     -295.0991774797088
# --------------------------------------------------
# Total Energy                   -2441.3500652303419
# --------------------------------------------------
#
#
#
# Energy difference :  0.001826883700232429
#
#
# HOMO-LUMO gap: 0.0868139324670272 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.03094765018049501
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711136
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449609392
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969467516
# Coulomb Energy                  6305.1999901384006
# Exchange-Correlation Energy     -295.0882138897908
# --------------------------------------------------
# Total Energy                   -2441.3501506049633
# --------------------------------------------------
#
#
#
# Energy difference :  8.537462144886376e-05
#
#
# HOMO-LUMO gap: 0.08605512218846126 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.015359420195197133
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174124387
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082988115
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754510086
# Coulomb Energy                  6305.1611656010218
# Exchange-Correlation Energy     -295.0851653175856
# --------------------------------------------------
# Total Energy                   -2441.3502114037519
# --------------------------------------------------
#
#
#
# Energy difference :  6.0798788581450935e-05
#
#
# HOMO-LUMO gap: 0.08610559554878414 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.00585072833521484
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730802623
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341359133
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624065274
# Coulomb Energy                  6305.1739654234834
# Exchange-Correlation Energy     -295.0859344062426
# --------------------------------------------------
# Total Energy                   -2441.3502195515312
# --------------------------------------------------
#
#
#
# Energy difference :  8.147779226419516e-06
#
#
# HOMO-LUMO gap: 0.0862775338019425 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.06 seconds
#
#
#
# Density matrix difference norm:  0.002268765578786452
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173037932
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171301267
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318469
# Coulomb Energy                  6305.1767750459894
# Exchange-Correlation Energy     -295.0862921108194
# --------------------------------------------------
# Total Energy                   -2441.3502203024964
# --------------------------------------------------
#
#
#
# Energy difference :  7.50965227780398e-07
#
#
# HOMO-LUMO gap: 0.08629954674369794 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.001421623291471776
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161182
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335498999
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841014583
# Coulomb Energy                  6305.1678310987991
# Exchange-Correlation Energy     -295.0851232567455
# --------------------------------------------------
# Total Energy                   -2441.3502204457745
# --------------------------------------------------
#
#
#
# Energy difference :  1.4327815733850002e-07
#
#
# HOMO-LUMO gap: 0.08625864034201643 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0007905213676764923
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731926696
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319690
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598743
# Coulomb Energy                  6305.1716231999235
# Exchange-Correlation Energy     -295.0855737005040
# --------------------------------------------------
# Total Energy                   -2441.3502206120611
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628655430395156e-07
#
#
# HOMO-LUMO gap: 0.08626853544490051 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0002863202133382593
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173138948
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851889628
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651370698
# Coulomb Energy                  6305.1740152927978
# Exchange-Correlation Energy     -295.0859370217321
# --------------------------------------------------
# Total Energy                   -2441.3502206202120
# --------------------------------------------------
#
#
#
# Energy difference :  8.150891517288983e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.350220620212
# -------------------------------------
#
#
#
# Time taken : 93.64 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           20.78
# Density Fitting                         3.47
#     DF (gamma)                          1.13
#     DF (coeff)                          0.13
#     DF (Jtri)                           1.82
# DIIS                                    0.25
# KS matrix diagonalization               1.24
# One electron Integrals (S, T, Vnuc)     0.11
# Coulomb Integrals (2c2e + 3c2e)         14.44
# Grids construction                      16.01
# Exchange-Correlation Term               30.02
# Misc.                                   7.32
# Complete SCF                            93.64

# %% [markdown]
# ### Benchmark #4 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.17 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.47 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.12
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.03876673299998856
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.16 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.93
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  31.53 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 48.73 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 53.26 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.09 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00086590367766
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182483
# Exchange-Correlation Energy     -158.3094688039744
# --------------------------------------------------
# Total Energy                    -881.4876584497651
# --------------------------------------------------
#
#
#
# Energy difference :  881.4876584497651
#
#
# HOMO-LUMO gap: 0.6897308990665345 au
# HOMO-LUMO gap: 18.768 eV
#
#
# Time taken for the previous iteration: 2.63 seconds
#
#
#
# Density matrix difference norm:  177.41183356977106
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994638079403
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3704438291861
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5625483780068
# Coulomb Energy                 12707.6655166373002
# Exchange-Correlation Energy     -589.0109863900113
# --------------------------------------------------
# Total Energy                   -3195.6961127769682
# --------------------------------------------------
#
#
#
# Energy difference :  2314.208454327203
#
#
# HOMO-LUMO gap: 0.0026210885484551083 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  86.10072559742099
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006718457628
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.0784549148084
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9542974309893
# Coulomb Energy                 10864.6104283836721
# Exchange-Correlation Energy     -358.7264210078095
# --------------------------------------------------
# Total Energy                   -3357.7828976810360
# --------------------------------------------------
#
#
#
# Energy difference :  162.08678490406783
#
#
# HOMO-LUMO gap: 0.002532292526978324 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  65.13264429192583
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000815955637
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9266970335630
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4589790570662
# Coulomb Energy                 11125.2421950921962
# Exchange-Correlation Energy     -407.6867498869947
# --------------------------------------------------
# Total Energy                   -3374.4550203443705
# --------------------------------------------------
#
#
#
# Energy difference :  16.67212266333445
#
#
# HOMO-LUMO gap: 0.004414389959319448 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  63.856681210794775
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995348429836
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.2877136077586
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.8757373780018
# Coulomb Energy                 12063.6748125250997
# Exchange-Correlation Energy     -415.0710986786510
# --------------------------------------------------
# Total Energy                   -3056.3510099563846
# --------------------------------------------------
#
#
#
# Energy difference :  318.1040103879859
#
#
# HOMO-LUMO gap: 0.006644147323323371 au
# HOMO-LUMO gap: 0.181 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  54.59169061284104
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00026913529393
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.5088611867723
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.3924608748030
# Coulomb Energy                 11512.9997141031781
# Exchange-Correlation Energy     -417.4553406801222
# --------------------------------------------------
# Total Energy                   -3536.1147744619902
# --------------------------------------------------
#
#
#
# Energy difference :  479.76376450560565
#
#
# HOMO-LUMO gap: 0.0010123614903232029 au
# HOMO-LUMO gap: 0.028 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  51.11495004485849
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99974294779855
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.1797883209620
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.7800541086608
# Coulomb Energy                 11567.1010375636088
# Exchange-Correlation Energy     -419.4337655478879
# --------------------------------------------------
# Total Energy                   -3074.2752097696575
# --------------------------------------------------
#
#
#
# Energy difference :  461.8395646923327
#
#
# HOMO-LUMO gap: 0.0046974716003567035 au
# HOMO-LUMO gap: 0.128 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  44.744826452855804
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996550749722
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.4126884047764
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6364207745869
# Coulomb Energy                 11495.5483931907693
# Exchange-Correlation Energy     -423.7795770221712
# --------------------------------------------------
# Total Energy                   -3532.5501990346693
# --------------------------------------------------
#
#
#
# Energy difference :  458.27498926501175
#
#
# HOMO-LUMO gap: 0.00046339760016647635 au
# HOMO-LUMO gap: 0.013 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  20.71273843113284
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999545434497
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.2739434125760
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.0351193219153
# Coulomb Energy                 11580.0530324802457
# Exchange-Correlation Energy     -439.2769213957939
# --------------------------------------------------
# Total Energy                   -3535.0054605792884
# --------------------------------------------------
#
#
#
# Energy difference :  2.455261544619134
#
#
# HOMO-LUMO gap: 0.00760289474920961 au
# HOMO-LUMO gap: 0.207 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  17.829781634028766
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00025109396745
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28135.5805663306528
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3632.4560408184452
# Coulomb Energy                 11640.5650662674161
# Exchange-Correlation Energy     -443.9779459681910
# --------------------------------------------------
# Total Energy                   -3536.0801527860622
# --------------------------------------------------
#
#
#
# Energy difference :  1.0746922067737614
#
#
# HOMO-LUMO gap: 0.004336284665445389 au
# HOMO-LUMO gap: 0.118 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  21.75078771896249
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000976496997
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27873.9019921783802
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3557.6224522878388
# Coulomb Energy                 11493.5519507822646
# Exchange-Correlation Energy     -433.3671342007542
# --------------------------------------------------
# Total Energy                   -3485.6374708821077
# --------------------------------------------------
#
#
#
# Energy difference :  50.44268190395451
#
#
# HOMO-LUMO gap: 0.01799978551385678 au
# HOMO-LUMO gap: 0.490 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  18.30482001026815
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001218986381
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28089.3481559254287
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3573.7337556977941
# Coulomb Energy                 11601.6672611384165
# Exchange-Correlation Energy     -437.8374210917329
# --------------------------------------------------
# Total Energy                   -3581.3273077540271
# --------------------------------------------------
#
#
#
# Energy difference :  95.6898368719194
#
#
# HOMO-LUMO gap: 0.009809885434575744 au
# HOMO-LUMO gap: 0.267 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  15.603590936322206
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000084455487
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27851.1830273912383
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3504.4630743678440
# Coulomb Energy                 11481.6334488213070
# Exchange-Correlation Energy     -426.3111912507749
# --------------------------------------------------
# Total Energy                   -3520.9404430259401
# --------------------------------------------------
#
#
#
# Energy difference :  60.38686472808695
#
#
# HOMO-LUMO gap: 0.0012824841564652717 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  15.434070160393587
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99987880325557
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27993.2533723774759
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3536.1983075039252
# Coulomb Energy                 11535.6719747927855
# Exchange-Correlation Energy     -432.7365137439497
# --------------------------------------------------
# Total Energy                   -3583.6623513977920
# --------------------------------------------------
#
#
#
# Energy difference :  62.721908371851896
#
#
# HOMO-LUMO gap: 0.004883644217190203 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  4.9951824714123845
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000251701502
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27981.3353376832820
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9571930836623
# Coulomb Energy                 11529.5195497572786
# Exchange-Correlation Energy     -431.6645544940091
# --------------------------------------------------
# Total Energy                   -3583.0658969094275
# --------------------------------------------------
#
#
#
# Energy difference :  0.5964544883645431
#
#
# HOMO-LUMO gap: 0.04720513062549021 au
# HOMO-LUMO gap: 1.285 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  4.204244299768339
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00002943940035
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27999.1239641177199
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.4625401389508
# Coulomb Energy                 11537.2109870391887
# Exchange-Correlation Energy     -433.3658591996259
# --------------------------------------------------
# Total Energy                   -3585.3590437122839
# --------------------------------------------------
#
#
#
# Energy difference :  2.293146802856427
#
#
# HOMO-LUMO gap: 0.10565060716455928 au
# HOMO-LUMO gap: 2.875 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.9287338654655112
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000019874413
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1956976871152
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.6973765165503
# Coulomb Energy                 11540.9990064300437
# Exchange-Correlation Energy     -433.6709883548182
# --------------------------------------------------
# Total Energy                   -3585.7130506684171
# --------------------------------------------------
#
#
#
# Energy difference :  0.354006956133162
#
#
# HOMO-LUMO gap: 0.08160179779991167 au
# HOMO-LUMO gap: 2.220 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.47099492016477434
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001543754206
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27997.2512003712145
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3537.3766040210458
# Coulomb Energy                 11536.7451392599487
# Exchange-Correlation Energy     -433.0466479536952
# --------------------------------------------------
# Total Energy                   -3585.7188526169921
# --------------------------------------------------
#
#
#
# Energy difference :  0.005801948575026472
#
#
# HOMO-LUMO gap: 0.09622540976443686 au
# HOMO-LUMO gap: 2.618 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.2534565429738258
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000167447797
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.5564262062107
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5447393560480
# Coulomb Energy                 11540.2918405162800
# Exchange-Correlation Energy     -433.4718308398776
# --------------------------------------------------
# Total Energy                   -3585.7344247468354
# --------------------------------------------------
#
#
#
# Energy difference :  0.015572129843349103
#
#
# HOMO-LUMO gap: 0.10308245682938427 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.10396159680768452
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000172884528
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6842600152668
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6972366611926
# Coulomb Energy                 11539.1501782098912
# Exchange-Correlation Energy     -433.3563239125724
# --------------------------------------------------
# Total Energy                   -3585.7359166298338
# --------------------------------------------------
#
#
#
# Energy difference :  0.0014918829983798787
#
#
# HOMO-LUMO gap: 0.10375679431319373 au
# HOMO-LUMO gap: 2.823 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.04580931834183525
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163999442
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0103517155221
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8693000560379
# Coulomb Energy                 11539.3276465614417
# Exchange-Correlation Energy     -433.3803352203105
# --------------------------------------------------
# Total Energy                   -3585.7364878914304
# --------------------------------------------------
#
#
#
# Energy difference :  0.0005712615966331214
#
#
# HOMO-LUMO gap: 0.10309625434447864 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.029554329618370106
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001635067485
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8156481374608
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7421797536972
# Coulomb Energy                 11539.2423483648217
# Exchange-Correlation Energy     -433.3626933825393
# --------------------------------------------------
# Total Energy                   -3585.7365609745575
# --------------------------------------------------
#
#
#
# Energy difference :  7.308312706300057e-05
#
#
# HOMO-LUMO gap: 0.1031455108636142 au
# HOMO-LUMO gap: 2.807 eV
#
#
# Time taken for the previous iteration: 2.1 seconds
#
#
#
# Density matrix difference norm:  0.017959399733023303
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001612485136
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0456960596093
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8499452423148
# Coulomb Energy                 11539.3793324090293
# Exchange-Correlation Energy     -433.3773972561090
# --------------------------------------------------
# Total Energy                   -3585.7365632374513
# --------------------------------------------------
#
#
#
# Energy difference :  2.2628937585977837e-06
#
#
# HOMO-LUMO gap: 0.10320225772555676 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 2.14 seconds
#
#
#
# Density matrix difference norm:  0.010130197426671867
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162381156
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9409515459411
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096975135959
# Coulomb Energy                 11539.3092434429727
# Exchange-Correlation Energy     -433.3718359113619
# --------------------------------------------------
# Total Energy                   -3585.7365940738127
# --------------------------------------------------
#
#
#
# Energy difference :  3.083636147493962e-05
#
#
# HOMO-LUMO gap: 0.10326233785922169 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.003065449046546349
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162908747
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9648930425647
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8217790847448
# Coulomb Energy                 11539.3227881285675
# Exchange-Correlation Energy     -433.3735230066394
# --------------------------------------------------
# Total Energy                   -3585.7365964089677
# --------------------------------------------------
#
#
#
# Energy difference :  2.3351549316430464e-06
#
#
# HOMO-LUMO gap: 0.10324998822488966 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0010174389283685397
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000016275485
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9526818455524
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8145317531798
# Coulomb Energy                 11539.3168310452056
# Exchange-Correlation Energy     -433.3725300785018
# --------------------------------------------------
# Total Energy                   -3585.7365966987472
# --------------------------------------------------
#
#
#
# Energy difference :  2.897795639000833e-07
#
#
# HOMO-LUMO gap: 0.1032360610041457 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0003763297475289803
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162733393
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9484625968616
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8126747938863
# Coulomb Energy                 11539.3142180630857
# Exchange-Correlation Energy     -433.3722793844070
# --------------------------------------------------
# Total Energy                   -3585.7365966973721
# --------------------------------------------------
#
#
#
# Energy difference :  1.3751559890806675e-09
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596697372
# -------------------------------------
#
#
#
# Time taken : 201.33 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           53.35
# Density Fitting                         4.95
#     DF (gamma)                          1.62
#     DF (coeff)                          0.15
#     DF (Jtri)                           2.54
# DIIS                                    0.5
# KS matrix diagonalization               1.99
# One electron Integrals (S, T, Vnuc)     0.17
# Coulomb Integrals (2c2e + 3c2e)         31.53
# Grids construction                      48.73
# Exchange-Correlation Term               54.33
# Misc.                                   5.78
# Complete SCF                            201.33

# %% [markdown]
# ## Dynamic Precision On

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.02 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.03 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0008004869999922448
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.03
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.65 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.32 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.55 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.02 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.00036
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709560
# Exchange-Correlation Energy      -16.0363521575928
# --------------------------------------------------
# Total Energy                     -93.1572674613903
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726746139029
#
#
# HOMO-LUMO gap: 2.6432309075653615 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 3.97 seconds
#
#
#
# Density matrix difference norm:  43.34737619555269
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065057091980
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632825304166
# Coulomb Energy                   501.1179471569676
# Exchange-Correlation Energy      -62.5998191833496
# --------------------------------------------------
# Total Energy                    -340.0671181610398
# --------------------------------------------------
#
#
#
# Energy difference :  246.90985069964955
#
#
# HOMO-LUMO gap: 0.00489502224489563 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  28.61223511781101
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000103
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015698822119
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404485376370
# Coulomb Energy                   293.3105498762756
# Exchange-Correlation Energy      -37.4191246032715
# --------------------------------------------------
# Total Energy                    -355.5117190274473
# --------------------------------------------------
#
#
#
# Energy difference :  15.444600866407484
#
#
# HOMO-LUMO gap: 0.04090739403919774 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  21.394359863554822
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6801885014052
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079075502275
# Coulomb Energy                   367.2116009574022
# Exchange-Correlation Energy      -44.5831069946289
# --------------------------------------------------
# Total Energy                    -380.5858099442809
# --------------------------------------------------
#
#
#
# Energy difference :  25.07409091683354
#
#
# HOMO-LUMO gap: 0.018045886670319755 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  5.1936545845964455
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853091437823
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987272575010
# Coulomb Energy                   364.3594810690206
# Exchange-Correlation Energy      -44.5593376159668
# --------------------------------------------------
# Total Energy                    -378.6284613891039
# --------------------------------------------------
#
#
#
# Energy difference :  1.9573485551769636
#
#
# HOMO-LUMO gap: 0.08497524067680126 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  4.776043862262311
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113206578535
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536884928204
# Coulomb Energy                   368.1595743595576
# Exchange-Correlation Energy      -45.0864944458008
# --------------------------------------------------
# Total Energy                    -381.1265752071527
# --------------------------------------------------
#
#
#
# Energy difference :  2.4981138180487505
#
#
# HOMO-LUMO gap: 0.14153344195239448 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.5199018409380881
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759596179480
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620346899972
# Coulomb Energy                   369.0651771886037
# Exchange-Correlation Energy      -45.1361885070801
# --------------------------------------------------
# Total Energy                    -381.2269592023038
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038399515110541
#
#
# HOMO-LUMO gap: 0.13505775586770874 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.3314180487717869
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685675926919
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352796433274
# Coulomb Energy                   369.6332836146942
# Exchange-Correlation Energy      -45.2082176208496
# --------------------------------------------------
# Total Energy                    -381.2502449113964
# --------------------------------------------------
#
#
#
# Energy difference :  0.023285709092590423
#
#
# HOMO-LUMO gap: 0.019481785628368248 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.5819568575617327
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471003749888
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753305507349
# Coulomb Energy                   374.0875566303262
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611925289
# --------------------------------------------------
#
#
#
# Energy difference :  0.13181628113255783
#
#
# HOMO-LUMO gap: 0.12602060286757824 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.4597218096664089
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167220502023
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482882177510
# Coulomb Energy                   377.3936789835889
# Exchange-Correlation Energy      -46.1032218933105
# --------------------------------------------------
# Total Energy                    -381.4199996980494
# --------------------------------------------------
#
#
#
# Energy difference :  0.037938505520457966
#
#
# HOMO-LUMO gap: 0.16611335836195026 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.14506608198109508
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6773853124512
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4956800494393
# Coulomb Energy                   377.1713347422639
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261849805306
# --------------------------------------------------
#
#
#
# Energy difference :  0.006185282481283139
#
#
# HOMO-LUMO gap: 0.18109759450159035 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.055972227431832326
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466847521689
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5464934880549
# Coulomb Energy                   377.1955765820809
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266051366888
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004201561581567148
#
#
# HOMO-LUMO gap: 0.18093185581845753 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.025624236735427477
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6790963044396
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228702866724
# Coulomb Energy                   377.1480797572142
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267301905505
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012505386172279032
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050740102770643 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.00840952773791969
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749483557
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758561710813
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145457199148
# Coulomb Energy                   377.1522579825763
# Exchange-Correlation Energy      -46.0763602020221
# --------------------------------------------------
# Total Energy                    -381.4274356264885
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007054359380163078
#
#
# HOMO-LUMO gap: 0.18055948020357082 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.09 seconds
#
#
#
# Density matrix difference norm:  0.002642070162445777
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503220864
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547018763035
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032841211010
# Coulomb Energy                   377.1410362410197
# Exchange-Correlation Energy      -46.0750324272114
# --------------------------------------------------
# Total Energy                    -381.4274368972708
# --------------------------------------------------
#
#
#
# Energy difference :  1.2707822634183685e-06
#
#
# HOMO-LUMO gap: 0.1805658927763643 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0017678577823615565
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749796218
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715734084746
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117333671152
# Coulomb Energy                   377.1506245998460
# Exchange-Correlation Energy      -46.0761995168087
# --------------------------------------------------
# Total Energy                    -381.4274379141985
# --------------------------------------------------
#
#
#
# Energy difference :  1.016927683394897e-06
#
#
# HOMO-LUMO gap: 0.1805781339407422 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0018263201033136155
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007494343436
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890928902483
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201140686440
# Coulomb Energy                   377.1610735625118
# Exchange-Correlation Energy      -46.0775108681119
# --------------------------------------------------
# Total Energy                    -381.4274390830808
# --------------------------------------------------
#
#
#
# Energy difference :  1.168882306501473e-06
#
#
# HOMO-LUMO gap: 0.18069052411914913 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.0015079010413394228
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749797208
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793134395675
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150712631768
# Coulomb Energy                   377.1557639882251
# Exchange-Correlation Energy      -46.0769384184009
# --------------------------------------------------
# Total Energy                    -381.4274395624431
# --------------------------------------------------
#
#
#
# Energy difference :  4.793622565557598e-07
#
#
# HOMO-LUMO gap: 0.18064424269973434 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.1 seconds
#
#
#
# Density matrix difference norm:  0.00046677454491120637
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749830367
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995676793
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900943622
# Coulomb Energy                   377.1550630849264
# Exchange-Correlation Energy      -46.0768702738873
# --------------------------------------------------
# Total Energy                    -381.4274396181546
# --------------------------------------------------
#
#
#
# Energy difference :  5.5711552704451606e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396181546
# -------------------------------------
#
#
#
# Time taken : 7.77 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.57
# Density Fitting                         0.2
#     DF (gamma)                          0.07
#     DF (coeff)                          0.05
#     DF (Jtri)                           0.07
# DIIS                                    0.08
# KS matrix diagonalization               0.16
# One electron Integrals (S, T, Vnuc)     0.02
# Coulomb Integrals (2c2e + 3c2e)         0.65
# Grids construction                      0.32
# Exchange-Correlation Term               4.89
# Misc.                                   0.88
# Complete SCF                            7.77

# %% [markdown]
# ### Benchmark #5 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.07 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.003262296000002607
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.06
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  1.65 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.95 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.83 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091871
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371784
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120590
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961205902
#
#
# HOMO-LUMO gap: 1.7655068468539108 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.15 seconds
#
#
#
# Density matrix difference norm:  66.8832362196319
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816190541240
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207667033062
# Coulomb Energy                  1272.5916580546063
# Exchange-Correlation Energy     -125.2197875976562
# --------------------------------------------------
# Total Energy                    -680.0824357766355
# --------------------------------------------------
#
#
#
# Energy difference :  494.6338161645765
#
#
# HOMO-LUMO gap: 0.0003950011728404146 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  39.27352499721101
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00123
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671433350873
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861190137724
# Coulomb Energy                   861.6520441623948
# Exchange-Correlation Energy      -75.4418258666992
# --------------------------------------------------
# Total Energy                    -709.3642599083873
# --------------------------------------------------
#
#
#
# Energy difference :  29.28182413175182
#
#
# HOMO-LUMO gap: 0.027815450818873398 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  28.145155581038534
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982803831123
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525456747846
# Coulomb Energy                  1000.6416364367850
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464596250139
# --------------------------------------------------
#
#
#
# Energy difference :  24.382199716626587
#
#
# HOMO-LUMO gap: 0.006873749882307961 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  18.101418343138775
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394527851024
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643187419459
# Coulomb Energy                  1039.7364542095174
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035005987314
# --------------------------------------------------
#
#
#
# Energy difference :  44.14295902628248
#
#
# HOMO-LUMO gap: 0.0094014486152037 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  13.030477987720774
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9282389258765
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4698006523970
# Coulomb Energy                  1004.3617280007360
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228912062926
# --------------------------------------------------
#
#
#
# Energy difference :  60.01939060756115
#
#
# HOMO-LUMO gap: 0.024324072239723653 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  7.651670854473401
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2544021126464
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338936837535
# Coulomb Energy                   997.3405126595027
# Exchange-Correlation Energy      -89.6696014404297
# --------------------------------------------------
# Total Energy                    -755.2430510925882
# --------------------------------------------------
#
#
#
# Energy difference :  5.620159886295596
#
#
# HOMO-LUMO gap: 0.0012911446055909742 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  6.5311016162616795
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00024
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9936579848063
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455789654164
# Coulomb Energy                  1008.9226915959558
# Exchange-Correlation Energy      -89.8105392456055
# --------------------------------------------------
# Total Energy                    -754.8293805518077
# --------------------------------------------------
#
#
#
# Energy difference :  0.4136705407804584
#
#
# HOMO-LUMO gap: 0.015385831867468627 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  7.342496913212936
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6262628841055
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2044952476300
# Coulomb Energy                  1033.2839481756282
# Exchange-Correlation Energy      -92.8136062622070
# --------------------------------------------------
# Total Energy                    -754.2448796058225
# --------------------------------------------------
#
#
#
# Energy difference :  0.584500945985269
#
#
# HOMO-LUMO gap: 0.21170876417766982 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  6.051894740152424
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9768673529838
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1052027415924
# Coulomb Energy                  1046.8939534854039
# Exchange-Correlation Energy      -94.6927185058594
# --------------------------------------------------
# Total Energy                    -761.9638835146152
# --------------------------------------------------
#
#
#
# Energy difference :  7.719003908792729
#
#
# HOMO-LUMO gap: 0.02109129489690046 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  4.592875151559092
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186860622951
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7141200073814
# Coulomb Energy                  1016.5841279964513
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8409671365428
# --------------------------------------------------
#
#
#
# Energy difference :  2.122916378072432
#
#
# HOMO-LUMO gap: 0.0879503899623556 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  4.199989032534646
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5723507754788
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4484783125987
# Coulomb Energy                  1025.9225296612278
# Exchange-Correlation Energy      -92.2370071411133
# --------------------------------------------------
# Total Energy                    -762.7318038255337
# --------------------------------------------------
#
#
#
# Energy difference :  2.8908366889909303
#
#
# HOMO-LUMO gap: 0.1448420317714211 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.9087464104073467
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899357325328
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303483208099
# Coulomb Energy                  1024.4799980785422
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263940460267
# --------------------------------------------------
#
#
#
# Energy difference :  0.09459022049304622
#
#
# HOMO-LUMO gap: 0.0912040301869095 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.3386026842219843
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063893519154
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273755761959
# Coulomb Energy                  1024.8155179198143
# Exchange-Correlation Energy      -92.1995697021484
# --------------------------------------------------
# Total Energy                    -762.8565194408216
# --------------------------------------------------
#
#
#
# Energy difference :  0.03012539479482257
#
#
# HOMO-LUMO gap: 0.10812691642453878 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.13342204052882167
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7708259560213
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490598026748
# Coulomb Energy                  1024.3963950841699
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586793830968
# --------------------------------------------------
#
#
#
# Energy difference :  0.0021599422752842656
#
#
# HOMO-LUMO gap: 0.11558371905094011 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.05240871085651207
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028445194310
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1554039201017
# Coulomb Energy                  1024.6505259075670
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595503982606
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008710151637387753
#
#
# HOMO-LUMO gap: 0.11553039830996754 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.014069463773213413
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000167327671
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543953952920
# Coulomb Energy                  1024.5347563855985
# Exchange-Correlation Energy      -92.1552658081055
# --------------------------------------------------
# Total Energy                    -762.8595846427502
# --------------------------------------------------
#
#
#
# Energy difference :  3.4244489597767824e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.11964641814942423 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.015807912714000096
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745387254
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803973160801
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978083676650
# Coulomb Energy                  1024.5775777882716
# Exchange-Correlation Energy      -92.1624888990587
# --------------------------------------------------
# Total Energy                    -762.8609539419701
# --------------------------------------------------
#
#
#
# Energy difference :  0.00136929921995943
#
#
# HOMO-LUMO gap: 0.11847999365659018 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.008700728254438662
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741300448
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328870848730
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722847017214
# Coulomb Energy                  1024.5524822980085
# Exchange-Correlation Energy      -92.1594115322254
# --------------------------------------------------
# Total Energy                    -762.8609855001366
# --------------------------------------------------
#
#
#
# Energy difference :  3.1558166483591776e-05
#
#
# HOMO-LUMO gap: 0.1183473349117882 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.0020541808392017706
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739807376
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503351135781
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805119874105
# Coulomb Energy                  1024.5630589646100
# Exchange-Correlation Energy      -92.1607682711988
# --------------------------------------------------
# Total Energy                    -762.8609863155245
# --------------------------------------------------
#
#
#
# Energy difference :  8.153879207384307e-07
#
#
# HOMO-LUMO gap: 0.11844996400153322 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.002280158267529467
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742287263
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365081284867
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734618321582
# Coulomb Energy                  1024.5553050275880
# Exchange-Correlation Energy      -92.1597918574335
# --------------------------------------------------
# Total Energy                    -762.8609870089422
# --------------------------------------------------
#
#
#
# Energy difference :  6.934176326467423e-07
#
#
# HOMO-LUMO gap: 0.11849896329138038 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.2 seconds
#
#
#
# Density matrix difference norm:  0.002121137578419441
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742172256
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510302563662
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0798001956437
# Coulomb Energy                  1024.5646274004650
# Exchange-Correlation Energy      -92.1609318630710
# --------------------------------------------------
# Total Energy                    -762.8609884060963
# --------------------------------------------------
#
#
#
# Energy difference :  1.3971541648061248e-06
#
#
# HOMO-LUMO gap: 0.11838531429947145 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0014188448416213684
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741620082
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635536173777
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852198307463
# Coulomb Energy                  1024.5726719071581
# Exchange-Correlation Energy      -92.1618730977409
# --------------------------------------------------
# Total Energy                    -762.8609888599826
# --------------------------------------------------
#
#
#
# Energy difference :  4.538862867775606e-07
#
#
# HOMO-LUMO gap: 0.11838275597880754 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  0.0003223572571683861
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041698
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571690029747
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822984465690
# Coulomb Energy                  1024.5687892301773
# Exchange-Correlation Energy      -92.1614536814900
# --------------------------------------------------
# Total Energy                    -762.8609888904864
# --------------------------------------------------
#
#
#
# Energy difference :  3.0503770176437683e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904864
# -------------------------------------
#
#
#
# Time taken : 10.16 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           1.86
# Density Fitting                         0.43
#     DF (gamma)                          0.15
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.17
# DIIS                                    0.09
# KS matrix diagonalization               0.25
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         1.65
# Grids construction                      0.95
# Exchange-Correlation Term               3.3
# Misc.                                   1.59
# Complete SCF                            10.16

# %% [markdown]
# ### Benchmark #6 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.1 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.16 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.04
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.006979184999977406
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.05 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.19
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  5.57 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.54 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.19 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.03 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718097
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355695
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929922986
# --------------------------------------------------
#
#
#
# Energy difference :  374.93249299229865
#
#
# HOMO-LUMO gap: 1.8503196838149738 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.36 seconds
#
#
#
# Density matrix difference norm:  107.82808353552943
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99991
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876188969833
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682530430053
# Coulomb Energy                  3537.3220770014705
# Exchange-Correlation Energy     -250.6110534667969
# --------------------------------------------------
# Total Energy                   -1359.8986984886433
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662054963446
#
#
# HOMO-LUMO gap: 0.002113825247787249 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.4 seconds
#
#
#
# Density matrix difference norm:  57.365054162573614
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4340335143434
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0383080574022
# Coulomb Energy                  2705.4087422797352
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539415193957
# --------------------------------------------------
#
#
#
# Energy difference :  59.155243030752445
#
#
# HOMO-LUMO gap: 0.01974274287461994 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.41 seconds
#
#
#
# Density matrix difference norm:  48.047622811449884
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987106684499
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516936610284
# Coulomb Energy                  3071.8807191025862
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010083222202
# --------------------------------------------------
#
#
#
# Energy difference :  56.65293319717557
#
#
# HOMO-LUMO gap: 0.014679174012216287 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  40.92169689375758
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335721379626
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1621054877105
# Coulomb Energy                  3051.7270368064974
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347982201240
# --------------------------------------------------
#
#
#
# Energy difference :  16.433789897903807
#
#
# HOMO-LUMO gap: 0.012567417377815693 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  26.92676183337583
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983913127082
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494998774509
# Coulomb Energy                  3003.5484966047316
# Exchange-Correlation Energy     -179.3104858398438
# --------------------------------------------------
# Total Energy                   -1523.5012368397074
# --------------------------------------------------
#
#
#
# Energy difference :  144.66643861958346
#
#
# HOMO-LUMO gap: 0.003218265697529192 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  13.41451435704307
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4197458569070
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319715436798
# Coulomb Energy                  2977.4926667640543
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856681862838
# --------------------------------------------------
#
#
#
# Energy difference :  24.415568653423634
#
#
# HOMO-LUMO gap: 0.0318300460539461 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  12.436601793906682
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381501356411
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8447154710866
# Coulomb Energy                  3000.9338231541474
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434613320879
# --------------------------------------------------
#
#
#
# Energy difference :  23.657793145804135
#
#
# HOMO-LUMO gap: 0.012963510661666525 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.4 seconds
#
#
#
# Density matrix difference norm:  6.013463454091543
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677596323803
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553355680342
# Coulomb Energy                  3041.7902027226201
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430859339163
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996246018284182
#
#
# HOMO-LUMO gap: 0.021491332751299164 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  6.216631319898278
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4700183847999
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196777544093
# Coulomb Energy                  3063.1283354643006
# Exchange-Correlation Energy     -185.9102478027344
# --------------------------------------------------
# Total Energy                   -1521.9226091381620
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204767957543481
#
#
# HOMO-LUMO gap: 0.0796286515660562 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  4.4290271611167045
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505385208535
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1095183863431
# Coulomb Energy                  3048.3900584543026
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820313505210
# --------------------------------------------------
#
#
#
# Energy difference :  3.6594222123590043
#
#
# HOMO-LUMO gap: 0.11947976289755144 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.8332696633785895
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524613929807
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100347660808
# Coulomb Energy                  3044.2746783540379
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396901355596
# --------------------------------------------------
#
#
#
# Energy difference :  0.1576587850386204
#
#
# HOMO-LUMO gap: 0.10915541954634889 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.43796734278715244
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333957803636
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380174955572
# Coulomb Energy                  3039.9319358824664
# Exchange-Correlation Energy     -184.3113555908203
# --------------------------------------------------
# Total Energy                   -1525.7651541624987
# --------------------------------------------------
#
#
#
# Energy difference :  0.025464026939062023
#
#
# HOMO-LUMO gap: 0.08049522591593927 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.28021840176417967
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675742175426
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0129066502911
# Coulomb Energy                  3041.4808603259403
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832826733452
# --------------------------------------------------
#
#
#
# Energy difference :  0.018128510846509016
#
#
# HOMO-LUMO gap: 0.03536204398471027 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.20216542015940273
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152400631581
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773317768149
# Coulomb Energy                  3040.7150969061654
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864188922890
# --------------------------------------------------
#
#
#
# Energy difference :  0.003136218943836866
#
#
# HOMO-LUMO gap: 0.044773997673145646 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.4 seconds
#
#
#
# Density matrix difference norm:  0.0763348459936859
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0313034024093
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161856494725
# Coulomb Energy                  3040.4442116714017
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875165233345
# --------------------------------------------------
#
#
#
# Energy difference :  0.001097631045468006
#
#
# HOMO-LUMO gap: 0.05279087774662437 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.028439745391104696
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299922873419
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078719169127
# Coulomb Energy                  3040.4514274293565
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877001113879
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018358805345997098
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.049892929145885806 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.39 seconds
#
#
#
# Density matrix difference norm:  0.012831440555935748
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963122006
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444081970723
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722319928379
# Coulomb Energy                  3040.3964164650633
# Exchange-Correlation Energy     -184.4242562853111
# --------------------------------------------------
# Total Energy                   -1525.7903721938192
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026720824312178593
#
#
# HOMO-LUMO gap: 0.05055297723687592 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 0.52 seconds
#
#
#
# Density matrix difference norm:  0.0053003118040976654
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960686087
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993371338769
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002785132557
# Coulomb Energy                  3040.4277542474051
# Exchange-Correlation Energy     -184.4287293991958
# --------------------------------------------------
# Total Energy                   -1525.7903899417502
# --------------------------------------------------
#
#
#
# Energy difference :  1.7747930996847572e-05
#
#
# HOMO-LUMO gap: 0.050459027171158174 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.0021062214463681223
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396167271
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9999063193809
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3974021134795
# Coulomb Energy                  3040.4311720289902
# Exchange-Correlation Energy     -184.4287047395814
# --------------------------------------------------
# Total Energy                   -1525.7903930858297
# --------------------------------------------------
#
#
#
# Energy difference :  3.144079528283328e-06
#
#
# HOMO-LUMO gap: 0.050659368031304094 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.004881266181193111
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960053928
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796095881115
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345405065678
# Coulomb Energy                  3040.4795288486366
# Exchange-Correlation Energy     -184.4344979822816
# --------------------------------------------------
# Total Energy                   -1525.7903943845267
# --------------------------------------------------
#
#
#
# Energy difference :  1.2986970432393719e-06
#
#
# HOMO-LUMO gap: 0.050633309569146995 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.004003362868668449
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962935614
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308467767245
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102273277608
# Coulomb Energy                  3040.4520265270030
# Exchange-Correlation Energy     -184.4314495117086
# --------------------------------------------------
# Total Energy                   -1525.7903986030078
# --------------------------------------------------
#
#
#
# Energy difference :  4.218481080897618e-06
#
#
# HOMO-LUMO gap: 0.0506592173052461 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.000981204404373777
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962317652
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462828163545
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170935082884
# Coulomb Energy                  3040.4616022817299
# Exchange-Correlation Energy     -184.4324557210901
# --------------------------------------------------
# Total Energy                   -1525.7903989167644
# --------------------------------------------------
#
#
#
# Energy difference :  3.13756572722923e-07
#
#
# HOMO-LUMO gap: 0.05067942332304817 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 0.53 seconds
#
#
#
# Density matrix difference norm:  0.00024609592113763795
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396233277
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503258335093
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622934164
# Coulomb Energy                  3040.4641306060666
# Exchange-Correlation Energy     -184.4327098343370
# --------------------------------------------------
# Total Energy                   -1525.7903989377019
# --------------------------------------------------
#
#
#
# Energy difference :  2.093747752951458e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989377019
# -------------------------------------
#
#
#
# Time taken : 31.01 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.22
# Density Fitting                         1.09
#     DF (gamma)                          0.38
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.51
# DIIS                                    0.12
# KS matrix diagonalization               0.48
# One electron Integrals (S, T, Vnuc)     0.1
# Coulomb Integrals (2c2e + 3c2e)         5.57
# Grids construction                      4.54
# Exchange-Correlation Term               8.45
# Misc.                                   3.43
# Complete SCF                            31.01

# %% [markdown]
# ### Benchmark #7 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.11 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.29 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.07
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.017942546000085713
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.09 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.45
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  14.11 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 15.86 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 20.44 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.06 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004606
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456261
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456261
#
#
# HOMO-LUMO gap: 1.3453311015888945 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  144.01367435408008
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771597327563
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873905120613
# Coulomb Energy                  7102.3908458304350
# Exchange-Correlation Energy     -401.0388183593750
# --------------------------------------------------
# Total Energy                   -2175.7976205890200
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159029433938
#
#
# HOMO-LUMO gap: 0.00363238317273723 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  71.99222267070941
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00244
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8538160737389
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349318949634
# Coulomb Energy                  5771.7158371303321
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171586759152
# --------------------------------------------------
#
#
#
# Energy difference :  98.71953808689523
#
#
# HOMO-LUMO gap: 0.004971744685540486 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  58.10277930806832
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372912810999
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733423946306
# Coulomb Energy                  6321.7309075786570
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4681337702450
# --------------------------------------------------
#
#
#
# Energy difference :  116.0490249056702
#
#
# HOMO-LUMO gap: 0.014407075765368343 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  53.36864392035566
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688959122781
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515690621922
# Coulomb Energy                  6361.2922988203554
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5266488124762
# --------------------------------------------------
#
#
#
# Energy difference :  24.058515042231193
#
#
# HOMO-LUMO gap: 0.008931168210048246 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  42.83082908216845
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057570631136
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112592383393
# Coulomb Energy                  6294.4822998320069
# Exchange-Correlation Energy     -283.9661560058594
# --------------------------------------------------
# Total Energy                   -2345.8382328380121
# --------------------------------------------------
#
#
#
# Energy difference :  163.31158402553592
#
#
# HOMO-LUMO gap: 0.006906504453882398 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  32.166213393508784
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99985
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2174252408258
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029737445023
# Coulomb Energy                  6214.1441108474719
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5590341855022
# --------------------------------------------------
#
#
#
# Energy difference :  2.2791986525098764
#
#
# HOMO-LUMO gap: 0.0024702336243366957 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  33.32020876123663
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828426188942
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271617004469
# Coulomb Energy                  6284.7514073280454
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5699690801775
# --------------------------------------------------
#
#
#
# Energy difference :  9.010934894675302
#
#
# HOMO-LUMO gap: 0.006021596803723689 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  26.099238028072342
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2103776396543
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3782211107164
# Coulomb Energy                  6418.6992377668530
# Exchange-Correlation Energy     -305.3439025878906
# --------------------------------------------------
# Total Energy                   -2411.0367001893601
# --------------------------------------------------
#
#
#
# Energy difference :  58.46673110918255
#
#
# HOMO-LUMO gap: 0.005609318860355983 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  17.53006779866075
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0003
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3139282201992
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3751233135713
# Coulomb Energy                  6329.8757239324032
# Exchange-Correlation Energy     -297.7131958007812
# --------------------------------------------------
# Total Energy                   -2373.3361556143909
# --------------------------------------------------
#
#
#
# Energy difference :  37.70054457496917
#
#
# HOMO-LUMO gap: 0.017134594040199264 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 0.75 seconds
#
#
#
# Density matrix difference norm:  16.398003288805334
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4105356428190
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3499589339276
# Coulomb Energy                  6323.6499651960848
# Exchange-Correlation Energy     -296.5716247558594
# --------------------------------------------------
# Total Energy                   -2423.5421151080509
# --------------------------------------------------
#
#
#
# Energy difference :  50.205959493659975
#
#
# HOMO-LUMO gap: 0.006509492253677654 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  17.896838349360912
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006553141444
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1969960865722
# Coulomb Energy                  6269.6531939678262
# Exchange-Correlation Energy     -292.3520812988281
# --------------------------------------------------
# Total Energy                   -2388.4624253979600
# --------------------------------------------------
#
#
#
# Energy difference :  35.07968971009086
#
#
# HOMO-LUMO gap: 0.011360444890012575 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  18.875156094916996
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4053272384845
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783053985026
# Coulomb Energy                  6305.1514230671337
# Exchange-Correlation Energy     -292.6976928710938
# --------------------------------------------------
# Total Energy                   -2419.6331704833274
# --------------------------------------------------
#
#
#
# Energy difference :  31.170745085367344
#
#
# HOMO-LUMO gap: 0.0019313961507541333 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  14.237438599266673
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00018
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7536534056744
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6442663434318
# Coulomb Energy                  6277.9125719653366
# Exchange-Correlation Energy     -292.9881896972656
# --------------------------------------------------
# Total Energy                   -2419.7448836335570
# --------------------------------------------------
#
#
#
# Energy difference :  0.11171315022966155
#
#
# HOMO-LUMO gap: 0.008272138294425899 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 0.75 seconds
#
#
#
# Density matrix difference norm:  12.511476548661527
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8345494111290
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119881114151
# Coulomb Energy                  6304.6095858866483
# Exchange-Correlation Energy     -294.2061462402344
# --------------------------------------------------
# Total Energy                   -2430.9790004926854
# --------------------------------------------------
#
#
#
# Energy difference :  11.234116859128335
#
#
# HOMO-LUMO gap: 0.017657678650917594 au
# HOMO-LUMO gap: 0.480 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  10.321258442322984
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0493450692084
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2894716591759
# Coulomb Energy                  6320.8567180042455
# Exchange-Correlation Energy     -297.0249023437500
# --------------------------------------------------
# Total Energy                   -2429.4879365889219
# --------------------------------------------------
#
#
#
# Energy difference :  1.491063903763461
#
#
# HOMO-LUMO gap: 0.006403735350299311 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  8.08250364632716
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4245225663581
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0827657870564
# Coulomb Energy                  6316.7247542577206
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382644176076
# --------------------------------------------------
#
#
#
# Energy difference :  8.450327828685658
#
#
# HOMO-LUMO gap: 0.06629521828574485 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  4.0885531703701234
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3820113483489
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5873330605873
# Coulomb Energy                  6313.2562819331870
# Exchange-Correlation Energy     -295.9056701660156
# --------------------------------------------------
# Total Energy                   -2441.0039453599766
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656809423689992
#
#
# HOMO-LUMO gap: 0.002521130303029348 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  4.342380408413577
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2994058657277
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1403747655118
# Coulomb Energy                  6287.7383070573896
# Exchange-Correlation Energy     -293.7503051757812
# --------------------------------------------------
# Total Energy                   -2439.7309080579935
# --------------------------------------------------
#
#
#
# Energy difference :  1.273037301983095
#
#
# HOMO-LUMO gap: 0.0206149306459964 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  4.259506556067174
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7092865174436
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.2002872086200
# Coulomb Energy                  6303.8950022599165
# Exchange-Correlation Energy     -294.9481201171875
# --------------------------------------------------
# Total Energy                   -2441.1219960054805
# --------------------------------------------------
#
#
#
# Energy difference :  1.3910879474869944
#
#
# HOMO-LUMO gap: 0.12298796079421132 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.7427084096839806
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0211874385532
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5251351315064
# Coulomb Energy                  6307.0129725835804
# Exchange-Correlation Energy     -295.2851562500000
# --------------------------------------------------
# Total Energy                   -2441.3281148128526
# --------------------------------------------------
#
#
#
# Energy difference :  0.2061188073721496
#
#
# HOMO-LUMO gap: 0.08869453820756629 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.47732022122185175
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4118785224091
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7993088445801
# Coulomb Energy                  6304.8714503348801
# Exchange-Correlation Energy     -295.0263061523438
# --------------------------------------------------
# Total Energy                   -2441.3273043346780
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008104781745714718
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639345345902718 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 0.74 seconds
#
#
#
# Density matrix difference norm:  0.27044027466947645
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001152697414
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5571128606316
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4796623288853
# Coulomb Energy                  6304.2834880353194
# Exchange-Correlation Energy     -294.9927281352518
# --------------------------------------------------
# Total Energy                   -2441.3465694710640
# --------------------------------------------------
#
#
#
# Energy difference :  0.01926513638591132
#
#
# HOMO-LUMO gap: 0.10571382307876104 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  0.11904600946431784
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001155222627
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9908586565416
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6072169168747
# Coulomb Energy                  6305.7416887133550
# Exchange-Correlation Energy     -295.1471411460594
# --------------------------------------------------
# Total Energy                   -2441.3489730117562
# --------------------------------------------------
#
#
#
# Energy difference :  0.002403540692284878
#
#
# HOMO-LUMO gap: 0.1023564354930349 au
# HOMO-LUMO gap: 2.785 eV
#
#
# Time taken for the previous iteration: 1.05 seconds
#
#
#
# Density matrix difference norm:  0.0577470604410378
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011616136584
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1768802696479
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2272948100717
# Coulomb Energy                  6305.2554108036984
# Exchange-Correlation Energy     -295.0958075749190
# --------------------------------------------------
# Total Energy                   -2441.3498610701827
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008880584264261415
#
#
# HOMO-LUMO gap: 0.08312518704870507 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.06379010314969989
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001177594353
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6232300871961
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9394256320293
# Coulomb Energy                  6304.9498999326879
# Exchange-Correlation Energy     -295.0562057526269
# --------------------------------------------------
# Total Energy                   -2441.3499891144929
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012804431025870144
#
#
# HOMO-LUMO gap: 0.08543849850303989 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.03318304741586981
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171908399
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1939334388608
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2382320386200
# Coulomb Energy                  6305.2623523557450
# Exchange-Correlation Energy     -295.0969178902841
# --------------------------------------------------
# Total Energy                   -2441.3501457741640
# --------------------------------------------------
#
#
#
# Energy difference :  0.00015665967111999635
#
#
# HOMO-LUMO gap: 0.08549176506937714 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.016471350141663052
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011743758523
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9922510665092
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1354477099671
# Coulomb Energy                  6305.1488976590845
# Exchange-Correlation Energy     -295.0824232728640
# --------------------------------------------------
# Total Energy                   -2441.3502078097081
# --------------------------------------------------
#
#
#
# Energy difference :  6.203554403327871e-05
#
#
# HOMO-LUMO gap: 0.08609923097831762 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  0.007375162623225055
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173440054
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0613338218063
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745566787981
# Coulomb Energy                  6305.1842205768917
# Exchange-Correlation Energy     -295.0877826110255
# --------------------------------------------------
# Total Energy                   -2441.3502180165287
# --------------------------------------------------
#
#
#
# Energy difference :  1.0206820661551319e-05
#
#
# HOMO-LUMO gap: 0.08618073399521674 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 1.03 seconds
#
#
#
# Density matrix difference norm:  0.002930121137331632
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203808
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0439391236014
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630730493871
# Coulomb Energy                  6305.1767414195501
# Exchange-Correlation Energy     -295.0862169969492
# --------------------------------------------------
# Total Energy                   -2441.3502204909992
# --------------------------------------------------
#
#
#
# Energy difference :  2.474470420565922e-06
#
#
# HOMO-LUMO gap: 0.0862697622277059 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.0008015928598338874
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173088261
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357832720092
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591877401506
# Coulomb Energy                  6305.1719552051800
# Exchange-Correlation Energy     -295.0857014294026
# --------------------------------------------------
# Total Energy                   -2441.3502205954665
# --------------------------------------------------
#
#
#
# Energy difference :  1.0446728992974386e-07
#
#
# HOMO-LUMO gap: 0.08626926986254242 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 1.04 seconds
#
#
#
# Density matrix difference norm:  0.00047129159933836
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173170964
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0329993693722
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576315415568
# Coulomb Energy                  6305.1705214680551
# Exchange-Correlation Energy     -295.0854954062942
# --------------------------------------------------
# Total Energy                   -2441.3502206054400
# --------------------------------------------------
#
#
#
# Energy difference :  9.973518899641931e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.35022060544
# -------------------------------------
#
#
#
# Time taken : 83.05 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           20.5
# Density Fitting                         3.03
#     DF (gamma)                          1.0
#     DF (coeff)                          0.14
#     DF (Jtri)                           1.53
# DIIS                                    0.23
# KS matrix diagonalization               1.17
# One electron Integrals (S, T, Vnuc)     0.11
# Coulomb Integrals (2c2e + 3c2e)         14.11
# Grids construction                      15.86
# Exchange-Correlation Term               21.88
# Misc.                                   6.17
# Complete SCF                            83.05

# %% [markdown]
# ### Benchmark #8 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.16 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.47 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.12
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.03739903999996841
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.16 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.93
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  32.03 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 48.79 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 53.43 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.09 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0009
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182574
# Exchange-Correlation Energy     -158.3137817382812
# --------------------------------------------------
# Total Energy                    -881.4919713840627
# --------------------------------------------------
#
#
#
# Energy difference :  881.4919713840627
#
#
# HOMO-LUMO gap: 0.6897604976017639 au
# HOMO-LUMO gap: 18.769 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  177.41135709997846
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3344840565478
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5272569819526
# Coulomb Energy                 12707.6510784192069
# Exchange-Correlation Energy     -589.0113525390625
# --------------------------------------------------
# Total Energy                   -3195.7102487675274
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2182773834647
#
#
# HOMO-LUMO gap: 0.002627364042932845 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  86.09645328865697
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.1088814614559
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9652342515315
# Coulomb Energy                 10864.6201446231717
# Exchange-Correlation Energy     -358.7289123535156
# --------------------------------------------------
# Total Energy                   -3357.7951625133446
# --------------------------------------------------
#
#
#
# Energy difference :  162.08491374581718
#
#
# HOMO-LUMO gap: 0.0025107191649767057 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  65.13148175209379
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9476800390112
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4635756668486
# Coulomb Energy                 11125.2508232145465
# Exchange-Correlation Energy     -407.6778564453125
# --------------------------------------------------
# Total Energy                   -3374.4538851760044
# --------------------------------------------------
#
#
#
# Energy difference :  16.658722662659784
#
#
# HOMO-LUMO gap: 0.004421926152989281 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  63.8579370686409
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99948
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.3725943086029
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.9140525177700
# Coulomb Energy                 12063.8292790888845
# Exchange-Correlation Energy     -415.0684814453125
# --------------------------------------------------
# Total Energy                   -3056.2404917203366
# --------------------------------------------------
#
#
#
# Energy difference :  318.21339345566776
#
#
# HOMO-LUMO gap: 0.007367241736801339 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  54.581878896050036
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00027
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.6404007782112
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.4169414368616
# Coulomb Energy                 11513.0422430739454
# Exchange-Correlation Energy     -417.4490356445312
# --------------------------------------------------
# Total Energy                   -3536.1729994850120
# --------------------------------------------------
#
#
#
# Energy difference :  479.9325077646754
#
#
# HOMO-LUMO gap: 0.00174402190043247 au
# HOMO-LUMO gap: 0.047 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  51.205389388143246
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99976
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.0687653007699
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.9091680614083
# Coulomb Energy                 11567.9585798830922
# Exchange-Correlation Energy     -419.4385681152344
# --------------------------------------------------
# Total Energy                   -3073.1823330445823
# --------------------------------------------------
#
#
#
# Energy difference :  462.9906664404298
#
#
# HOMO-LUMO gap: 0.007103736779034003 au
# HOMO-LUMO gap: 0.193 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  44.85215403674112
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.9583311646420
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6779216840796
# Coulomb Energy                 11495.7950932807144
# Exchange-Correlation Energy     -423.7618408203125
# --------------------------------------------------
# Total Energy                   -3532.7899045932372
# --------------------------------------------------
#
#
#
# Energy difference :  459.60757154865496
#
#
# HOMO-LUMO gap: 0.0009113642863905203 au
# HOMO-LUMO gap: 0.025 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  20.64676119483494
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.8277872771760
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.3205606690181
# Coulomb Energy                 11578.8360931925272
# Exchange-Correlation Energy     -439.3337097167969
# --------------------------------------------------
# Total Energy                   -3536.5475907055061
# --------------------------------------------------
#
#
#
# Energy difference :  3.757686112268857
#
#
# HOMO-LUMO gap: 0.0035938971073893045 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  20.827658548726433
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28136.7937299897676
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3618.6113262874969
# Coulomb Energy                 11689.0065025128461
# Exchange-Correlation Energy     -441.3365478515625
# --------------------------------------------------
# Total Energy                   -3500.0551966140647
# --------------------------------------------------
#
#
#
# Energy difference :  36.49239409144138
#
#
# HOMO-LUMO gap: 0.010380448018723648 au
# HOMO-LUMO gap: 0.282 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  22.195084209494656
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00015
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27870.4744742889525
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3570.0729926462141
# Coulomb Energy                 11460.1693968879244
# Exchange-Correlation Energy     -435.4844970703125
# --------------------------------------------------
# Total Energy                   -3505.2593293982027
# --------------------------------------------------
#
#
#
# Energy difference :  5.2041327841379825
#
#
# HOMO-LUMO gap: 0.010542859301796437 au
# HOMO-LUMO gap: 0.287 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  15.724660227816328
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00037
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28102.6568581147367
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3578.5287518532596
# Coulomb Energy                 11610.6806773637472
# Exchange-Correlation Energy     -438.4918518066406
# --------------------------------------------------
# Total Energy                   -3581.4820282774472
# --------------------------------------------------
#
#
#
# Energy difference :  76.22269887924449
#
#
# HOMO-LUMO gap: 0.0001721445451493206 au
# HOMO-LUMO gap: 0.005 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  13.538470704137112
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27853.4840895618327
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3502.6998286846556
# Coulomb Energy                 11468.0589889030161
# Exchange-Correlation Energy     -426.0703125000000
# --------------------------------------------------
# Total Energy                   -3538.3383320472367
# --------------------------------------------------
#
#
#
# Energy difference :  43.14369623021048
#
#
# HOMO-LUMO gap: 0.05017403477696253 au
# HOMO-LUMO gap: 1.365 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  12.957199965244191
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27988.0376633591259
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3531.7515720594583
# Coulomb Energy                 11533.2297015153963
# Exchange-Correlation Energy     -432.4121704101562
# --------------------------------------------------
# Total Energy                   -3585.0113077675069
# --------------------------------------------------
#
#
#
# Energy difference :  46.67297572027019
#
#
# HOMO-LUMO gap: 0.003611802545699608 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  1.9544068775531704
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27979.4418010641966
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9402921774758
# Coulomb Energy                 11525.5552301080570
# Exchange-Correlation Energy     -431.9875488281250
# --------------------------------------------------
# Total Energy                   -3585.4765751798677
# --------------------------------------------------
#
#
#
# Energy difference :  0.4652674123608449
#
#
# HOMO-LUMO gap: 0.09755859522216584 au
# HOMO-LUMO gap: 2.655 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  1.1222618852023232
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1278412131360
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.5839576258709
# Coulomb Energy                 11540.9985485281377
# Exchange-Correlation Energy     -433.6155700683594
# --------------------------------------------------
# Total Energy                   -3585.7036527005657
# --------------------------------------------------
#
#
#
# Energy difference :  0.22707752069800335
#
#
# HOMO-LUMO gap: 0.085368136841355 au
# HOMO-LUMO gap: 2.323 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.4126295051031557
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99985
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.1876276177900
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6539566755637
# Coulomb Energy                 11539.6997692606383
# Exchange-Correlation Energy     -433.3434448242188
# --------------------------------------------------
# Total Energy                   -3585.7200940788844
# --------------------------------------------------
#
#
#
# Energy difference :  0.016441378318631905
#
#
# HOMO-LUMO gap: 0.102148735860767 au
# HOMO-LUMO gap: 2.780 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.20169967237607728
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.1504942012252
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.9010279245786
# Coulomb Energy                 11539.4369288169000
# Exchange-Correlation Energy     -433.3742370605469
# --------------------------------------------------
# Total Energy                   -3585.7295220933720
# --------------------------------------------------
#
#
#
# Energy difference :  0.009428014487639302
#
#
# HOMO-LUMO gap: 0.10257302928107648 au
# HOMO-LUMO gap: 2.791 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  0.05775281305816173
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00003
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8316704949684
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7515888151884
# Coulomb Energy                 11539.2454833369011
# Exchange-Correlation Energy     -433.3528137207031
# --------------------------------------------------
# Total Energy                   -3585.7301596366578
# --------------------------------------------------
#
#
#
# Energy difference :  0.0006375432858476415
#
# Switching to double precision for XC evaluation after 19 iterations!
#
#
# HOMO-LUMO gap: 0.10333551495371357 au
# HOMO-LUMO gap: 2.812 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  0.015768060210379124
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163677042
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9546091306402
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8364987620280
# Coulomb Energy                 11539.2948893252396
# Exchange-Correlation Energy     -433.3705855822601
# --------------------------------------------------
# Total Energy                   -3585.7365541987110
# --------------------------------------------------
#
#
#
# Energy difference :  0.006394562053174013
#
#
# HOMO-LUMO gap: 0.10329790341274406 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.006445168657633673
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162383479
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0156619020272
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8623394339952
# Coulomb Energy                 11539.3354650315578
# Exchange-Correlation Energy     -433.3759724952932
# --------------------------------------------------
# Total Energy                   -3585.7365775048456
# --------------------------------------------------
#
#
#
# Energy difference :  2.3306134607992135e-05
#
#
# HOMO-LUMO gap: 0.1032874426149242 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.006734422547154623
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001633564136
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8542111435781
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7751275005585
# Coulomb Energy                 11539.2504131117694
# Exchange-Correlation Energy     -433.3651665679249
# --------------------------------------------------
# Total Energy                   -3585.7365846722532
# --------------------------------------------------
#
#
#
# Energy difference :  7.167407602537423e-06
#
#
# HOMO-LUMO gap: 0.10339323919394477 au
# HOMO-LUMO gap: 2.813 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.006381860360931898
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163661573
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0189181185815
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8510999339092
# Coulomb Energy                 11539.3506721921258
# Exchange-Correlation Energy     -433.3766965411000
# --------------------------------------------------
# Total Energy                   -3585.7365901067260
# --------------------------------------------------
#
#
#
# Energy difference :  5.434472768683918e-06
#
#
# HOMO-LUMO gap: 0.10323532457357451 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0046847540338543
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162695186
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9570269476899
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8162412726060
# Coulomb Energy                 11539.3195207849785
# Exchange-Correlation Energy     -433.3725839522813
# --------------------------------------------------
# Total Energy                   -3585.7365964154651
# --------------------------------------------------
#
#
#
# Energy difference :  6.3087391026783735e-06
#
#
# HOMO-LUMO gap: 0.10324224152503533 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0011014542672413347
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162791105
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9495962560177
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8136280779549
# Coulomb Energy                 11539.3144507305733
# Exchange-Correlation Energy     -433.3723316511183
# --------------------------------------------------
# Total Energy                   -3585.7365966716843
# --------------------------------------------------
#
#
#
# Energy difference :  2.5621920940466225e-07
#
#
# HOMO-LUMO gap: 0.10324196337867736 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.0004533692504651475
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162682939
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9509907372376
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8139666430402
# Coulomb Energy                 11539.3156260848737
# Exchange-Correlation Energy     -433.3724511247791
# --------------------------------------------------
# Total Energy                   -3585.7365967071801
# --------------------------------------------------
#
#
#
# Energy difference :  3.549575922079384e-08
#
# SCF Converged after 26 iterations!
#
# -------------------------------------
# Total Energy =  -3585.73659670718
# -------------------------------------
#
#
#
# Time taken : 185.32 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           53.52
# Density Fitting                         4.7
#     DF (gamma)                          1.54
#     DF (coeff)                          0.14
#     DF (Jtri)                           2.41
# DIIS                                    0.47
# KS matrix diagonalization               1.9
# One electron Integrals (S, T, Vnuc)     0.16
# Coulomb Integrals (2c2e + 3c2e)         32.03
# Grids construction                      48.79
# Exchange-Correlation Term               35.65
# Misc.                                   8.1
# Complete SCF                            185.32
