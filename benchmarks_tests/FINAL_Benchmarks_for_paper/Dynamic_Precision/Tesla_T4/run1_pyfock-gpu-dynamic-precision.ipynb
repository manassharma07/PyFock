# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6724, done.
# remote: Counting objects: 100% (270/270), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 6724 (delta 141), reused 218 (delta 115), pack-reused 6454 (from 3)
# Receiving objects: 100% (6724/6724), 372.53 MiB | 35.31 MiB/s, done.
# Resolving deltas: 100% (4000/4000), done.
# Updating files: 100% (3620/3620), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install ase
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting ase
#   Downloading ase-3.29.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from ase) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from ase) (1.16.3)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.12/dist-packages (from ase) (3.10.0)
# Requirement already satisfied: typing_extensions>=4.13.1 in /usr/local/lib/python3.12/dist-packages (from ase) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->ase) (1.17.0)
# Downloading ase-3.29.0-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.6 MB/s eta 0:00:0000:010:01
# Installing collected packages: ase
# Successfully installed ase-3.29.0
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 36.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 14.8 MB/s eta 0:00:0000:010:01
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20330928 sha256=01933dfd59d0b5aedd0649e20f6489ee1399f4cbbbab091c23eb7eb43e9cdeb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1rozkq7r/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 17.92 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 15.98 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  6.64
# Time taken to evaluate the square roots needed:  0.12
# Time for significant indices evaluation:  2.1647306840000056
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 8.92 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.85 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.69 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.56 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709560
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632574
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325736
#
#
# HOMO-LUMO gap: 2.6431079281670184 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 7.14 seconds
#
#
#
# Density matrix difference norm:  43.347671370415334
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  49.99999474389979
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709355
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339315986
# Coulomb Energy                   501.1198589452454
# Exchange-Correlation Energy      -62.5998011282688
# --------------------------------------------------
# Total Energy                    -340.0652765782367
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851497935
#
#
# HOMO-LUMO gap: 0.004902711060944143 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.31 seconds
#
#
#
# Density matrix difference norm:  28.612471718849452
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00009840286507
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456610
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785903
# Coulomb Energy                   293.3088657954201
# Exchange-Correlation Energy      -37.4191110537727
# --------------------------------------------------
# Total Energy                    -355.5094553812997
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803062982
#
#
# HOMO-LUMO gap: 0.04036147698703085 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.18 seconds
#
#
#
# Density matrix difference norm:  21.394016787371747
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445383
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275539
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458483
# Coulomb Energy                   367.2127830476551
# Exchange-Correlation Energy      -44.5841010136104
# --------------------------------------------------
# Total Energy                    -380.5867878035374
# --------------------------------------------------
#
#
#
# Energy difference :  25.07733242223776
#
#
# HOMO-LUMO gap: 0.018048571143110682 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  5.197480933689518
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000687474082
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703910
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754557
# Coulomb Energy                   364.3533796551120
# Exchange-Correlation Energy      -44.5594485029986
# --------------------------------------------------
# Total Energy                    -378.6274635986982
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048392199
#
#
# HOMO-LUMO gap: 0.08493582284758795 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  4.779285269952153
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000012877114045
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186612
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180486
# Coulomb Energy                   368.1554971681646
# Exchange-Correlation Energy      -45.0868782881907
# --------------------------------------------------
# Total Energy                    -381.1270633765153
# --------------------------------------------------
#
#
#
# Energy difference :  2.499599777817025
#
#
# HOMO-LUMO gap: 0.14183855738629625 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.5205766173116569
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089466
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233391
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990192
# Coulomb Energy                   369.0647619107277
# Exchange-Correlation Energy      -45.1368862216109
# --------------------------------------------------
# Total Energy                    -381.2275584910796
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456435312
#
#
# HOMO-LUMO gap: 0.13514723909456833 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.3315886778252612
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597148
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176981
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774615
# Coulomb Energy                   369.6340156607575
# Exchange-Correlation Energy      -45.2090855965869
# --------------------------------------------------
# Total Energy                    -381.2508898319423
# --------------------------------------------------
#
#
#
# Energy difference :  0.02333134086273958
#
#
# HOMO-LUMO gap: 0.01973205738267972 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.5818251308660725
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000086170055
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110876
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893541
# Coulomb Energy                   374.0898923937944
# Exchange-Correlation Energy      -45.7569321945901
# --------------------------------------------------
# Total Energy                    -381.3827647784057
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646336972
#
#
# HOMO-LUMO gap: 0.12604481221459882 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.45845496145945036
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767308
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524515
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358330
# Coulomb Energy                   377.3880704578775
# Exchange-Correlation Energy      -46.1034837100250
# --------------------------------------------------
# Total Energy                    -381.4206849246426
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623684281
#
#
# HOMO-LUMO gap: 0.16627348986171875 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.1450688651697807
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000757902089
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358481
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690253
# Coulomb Energy                   377.1736811284887
# Exchange-Correlation Energy      -46.0748895148568
# --------------------------------------------------
# Total Energy                    -381.4268823090674
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384424808661
#
#
# HOMO-LUMO gap: 0.18126074112642745 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.055748849989639526
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000742519872
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179556
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114419
# Coulomb Energy                   377.1977734128285
# Exchange-Correlation Energy      -46.0810670348486
# --------------------------------------------------
# Total Energy                    -381.4272916844101
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753427127922
#
#
# HOMO-LUMO gap: 0.18111025828118707 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.025625306052257303
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503725406
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006566
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114266
# Coulomb Energy                   377.1502888734896
# Exchange-Correlation Energy      -46.0776486461292
# --------------------------------------------------
# Total Energy                    -381.4274184177460
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333594648284
#
#
# HOMO-LUMO gap: 0.18068395565687692 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.008432526434158545
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750035488
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167658
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298648
# Coulomb Energy                   377.1545462611556
# Exchange-Correlation Energy      -46.0767747067599
# --------------------------------------------------
# Total Energy                    -381.4274393883817
# --------------------------------------------------
#
#
#
# Energy difference :  2.0970635659978143e-05
#
#
# HOMO-LUMO gap: 0.18067053575034786 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.001844460003525147
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000075002507
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068126
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736937
# Coulomb Energy                   377.1524231958003
# Exchange-Correlation Energy      -46.0765296383163
# --------------------------------------------------
# Total Energy                    -381.4274391315114
# --------------------------------------------------
#
#
#
# Energy difference :  2.5687029392429395e-07
#
#
# HOMO-LUMO gap: 0.18064597252300557 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0011511413609747027
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074989492
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206505
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789390
# Coulomb Energy                   377.1549870542099
# Exchange-Correlation Energy      -46.0768423766162
# --------------------------------------------------
# Total Energy                    -381.4274396199942
# --------------------------------------------------
#
#
#
# Energy difference :  4.884828399553953e-07
#
#
# HOMO-LUMO gap: 0.18064256438839837 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0001054327934366528
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836629
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081838
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075879
# Coulomb Energy                   377.1556791349424
# Exchange-Correlation Energy      -46.0769272993466
# --------------------------------------------------
# Total Energy                    -381.4274396208766
# --------------------------------------------------
#
#
#
# Energy difference :  8.823803909763228e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396208766
# -------------------------------------
#
#
#
# Time taken : 77.95 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           3.25
# Density Fitting                         1.62
#     DF (gamma)                          0.4
#     DF (coeff)                          0.16
#     DF (Jtri)                           0.7
# DIIS                                    0.79
# KS matrix diagonalization               0.98
# One electron Integrals (S, T, Vnuc)     17.92
# Coulomb Integrals (2c2e + 3c2e)         42.26
# Grids construction                      0.85
# Exchange-Correlation Term               5.71
# Misc.                                   4.59
# Complete SCF                            77.95

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.1 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0021848989999853075
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.54 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.04 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.06 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  100.00135664103418
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371800
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645299995
# --------------------------------------------------
#
#
#
# Energy difference :  185.44746452999948
#
#
# HOMO-LUMO gap: 1.7654343749558348 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  66.88358764205495
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084647
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217438012
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987506114
# Coulomb Energy                  1272.5954275689592
# Exchange-Correlation Energy     -125.2198694441772
# --------------------------------------------------
# Total Energy                    -680.0789187511759
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422117645
#
#
# HOMO-LUMO gap: 0.0004045605677753805 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  39.2752296443525
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0012017584456
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692493497
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666726852
# Coulomb Energy                   861.6558693046363
# Exchange-Correlation Energy      -75.4419310839572
# --------------------------------------------------
# Total Energy                    -709.3563182387534
# --------------------------------------------------
#
#
#
# Energy difference :  29.27739948757744
#
#
# HOMO-LUMO gap: 0.02781560500080972 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  28.147358564321497
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663975
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672037500
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170660287
# Coulomb Energy                  1000.6400676119640
# Exchange-Correlation Energy      -87.3507096616632
# --------------------------------------------------
# Total Energy                    -733.7433460701884
# --------------------------------------------------
#
#
#
# Energy difference :  24.387027831435034
#
#
# HOMO-LUMO gap: 0.007352227196300923 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  18.103053983069348
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642285
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026565312
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102958164
# Coulomb Energy                  1039.7254935641906
# Exchange-Correlation Energy      -89.9717584581016
# --------------------------------------------------
# Total Energy                    -689.6320111373941
# --------------------------------------------------
#
#
#
# Energy difference :  44.11133493279431
#
#
# HOMO-LUMO gap: 0.010701793705645349 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  13.034260103693294
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576004
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022387340
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597823
# Coulomb Energy                  1004.3417767419787
# Exchange-Correlation Energy      -89.2334391642927
# --------------------------------------------------
# Total Energy                    -749.6400714840333
# --------------------------------------------------
#
#
#
# Energy difference :  60.00806034663924
#
#
# HOMO-LUMO gap: 0.02577135128493658 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.653358064507194
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554304
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132845364
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410523
# Coulomb Energy                   997.3319760641540
# Exchange-Correlation Energy      -89.6717481072356
# --------------------------------------------------
# Total Energy                    -755.2352624693339
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985300519
#
#
# HOMO-LUMO gap: 0.0035684795240240735 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  6.309738335039161
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0001954356774
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204418691
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857162003
# Coulomb Energy                  1009.6464766739082
# Exchange-Correlation Energy      -89.9069114779647
# --------------------------------------------------
# Total Energy                    -755.2788234124937
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094315983228
#
#
# HOMO-LUMO gap: 0.00917506188472289 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  8.057132717448042
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0005030016397
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153725935
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119321981
# Coulomb Energy                  1035.0050622424833
# Exchange-Correlation Energy      -92.6658378595184
# --------------------------------------------------
# Total Energy                    -747.5712329401986
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472295124
#
#
# HOMO-LUMO gap: 0.11766237193995238 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  7.71501342900052
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306776
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903694958
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992831233
# Coulomb Energy                  1048.9988443897616
# Exchange-Correlation Energy      -94.9610811404342
# --------------------------------------------------
# Total Energy                    -761.7908817198129
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779614317
#
#
# HOMO-LUMO gap: 0.01092542663657041 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.790315749274821
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377906
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412179966
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466859608
# Coulomb Energy                  1013.7508689108768
# Exchange-Correlation Energy      -90.9428726052305
# --------------------------------------------------
# Total Energy                    -756.2816521091577
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229610655211
#
#
# HOMO-LUMO gap: 0.1492973269486161 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  6.534633252630334
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000068720266
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716102060
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461510577
# Coulomb Energy                  1025.7750806786205
# Exchange-Correlation Energy      -92.2703810887995
# --------------------------------------------------
# Total Energy                    -762.7969797520957
# --------------------------------------------------
#
#
#
# Energy difference :  6.5153276429380185
#
#
# HOMO-LUMO gap: 0.13352697866998708 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.5338338749038163
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332055
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179533825
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792902896
# Coulomb Energy                  1024.7461321399899
# Exchange-Correlation Energy      -92.1885648748847
# --------------------------------------------------
# Total Energy                    -762.8402252807557
# --------------------------------------------------
#
#
#
# Energy difference :  0.04324552866000886
#
#
# HOMO-LUMO gap: 0.11056223799185311 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.3602713359562497
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000097791664
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590205678
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517294284
# Coulomb Energy                  1023.6379077075499
# Exchange-Correlation Energy      -92.0697499681986
# --------------------------------------------------
# Total Energy                    -762.8490034345564
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153800676591
#
#
# HOMO-LUMO gap: 0.08600353272591214 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.3252988568006101
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680042
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240863277
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261721997
# Coulomb Energy                  1024.4836887100664
# Exchange-Correlation Energy      -92.1371699397509
# --------------------------------------------------
# Total Energy                    -762.8531330265805
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592024128215
#
#
# HOMO-LUMO gap: 0.11636080747591529 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.15534224619076584
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503604
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117168895
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900055889
# Coulomb Energy                  1024.5663100626141
# Exchange-Correlation Energy      -92.1605267750465
# --------------------------------------------------
# Total Energy                    -762.8605923065013
# --------------------------------------------------
#
#
#
# Energy difference :  0.00745927992079487
#
#
# HOMO-LUMO gap: 0.12269239243597702 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.040607112235160434
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000072218656
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080651
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362666
# Coulomb Energy                  1024.7015706722582
# Exchange-Correlation Energy      -92.1773633390785
# --------------------------------------------------
# Total Energy                    -762.8609189213867
# --------------------------------------------------
#
#
#
# Energy difference :  0.0003266148853526829
#
#
# HOMO-LUMO gap: 0.11742913475974123 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.019703163529603513
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471094
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348738932
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569731
# Coulomb Energy                  1024.5590092023981
# Exchange-Correlation Energy      -92.1602830990720
# --------------------------------------------------
# Total Energy                    -762.8609667963619
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497528013773e-05
#
#
# HOMO-LUMO gap: 0.11815573488893066 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.008211499892566781
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163929
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862446
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811779
# Coulomb Energy                  1024.5676148746766
# Exchange-Correlation Energy      -92.1612728329158
# --------------------------------------------------
# Total Energy                    -762.8609882460742
# --------------------------------------------------
#
#
#
# Energy difference :  2.144971222151071e-05
#
#
# HOMO-LUMO gap: 0.11842571032206003 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0019148361630537938
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786601
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971591
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346132
# Coulomb Energy                  1024.5642249369562
# Exchange-Correlation Energy      -92.1610088236031
# --------------------------------------------------
# Total Energy                    -762.8609886319609
# --------------------------------------------------
#
#
#
# Energy difference :  3.858867785311304e-07
#
#
# HOMO-LUMO gap: 0.11835771606515347 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.0010776396191030451
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816393
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020317
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743369
# Coulomb Energy                  1024.5683629999253
# Exchange-Correlation Energy      -92.1613819110199
# --------------------------------------------------
# Total Energy                    -762.8609888215574
# --------------------------------------------------
#
#
#
# Energy difference :  1.8959644876304083e-07
#
#
# HOMO-LUMO gap: 0.11837118338561903 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.0005041312671962994
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785557
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158313
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323530
# Coulomb Energy                  1024.5701171428832
# Exchange-Correlation Energy      -92.1615907612844
# --------------------------------------------------
# Total Energy                    -762.8609888846477
# --------------------------------------------------
#
#
#
# Energy difference :  6.309028321993537e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846477
# -------------------------------------
#
#
#
# Time taken : 19.52 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.2
# Density Fitting                         0.51
#     DF (gamma)                          0.14
#     DF (coeff)                          0.12
#     DF (Jtri)                           0.22
# DIIS                                    0.12
# KS matrix diagonalization               0.54
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.54
# Grids construction                      1.04
# Exchange-Correlation Term               11.09
# Misc.                                   1.43
# Complete SCF                            19.52

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.08 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.25 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007879198000068754
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.07 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.28
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  10.13 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 5.1 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 8.12 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.18 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355709
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973773
# --------------------------------------------------
#
#
#
# Energy difference :  374.9303338973773
#
#
# HOMO-LUMO gap: 1.8502864435408486 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 2.23 seconds
#
#
#
# Density matrix difference norm:  107.82844284432898
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99998558772936
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067108
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391765619
# Coulomb Energy                  3537.3287033060451
# Exchange-Correlation Energy     -250.6110528162012
# --------------------------------------------------
# Total Energy                   -1359.8923755096430
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122657
#
#
# HOMO-LUMO gap: 0.0021139216446703912 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 2.2 seconds
#
#
#
# Density matrix difference norm:  57.36707021916332
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0009269151291
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256493135
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810813056
# Coulomb Energy                  2705.3966179575746
# Exchange-Correlation Energy     -151.8752804393592
# --------------------------------------------------
# Total Energy                   -1419.0480632191302
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770948721
#
#
# HOMO-LUMO gap: 0.019740723740692356 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 2.2 seconds
#
#
#
# Density matrix difference norm:  48.047190163772335
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001717849239
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823852969
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892855556
# Coulomb Energy                  3071.8764250118393
# Exchange-Correlation Energy     -174.7460035329503
# --------------------------------------------------
# Total Energy                   -1362.4047277901909
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542893928
#
#
# HOMO-LUMO gap: 0.01474771472384974 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 2.21 seconds
#
#
#
# Density matrix difference norm:  40.92570828249932
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158718
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198127473
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571582330
# Coulomb Energy                  3051.7165832277674
# Exchange-Correlation Energy     -176.2007428393671
# --------------------------------------------------
# Total Energy                   -1378.8564784354517
# --------------------------------------------------
#
#
#
# Energy difference :  16.451750645260745
#
#
# HOMO-LUMO gap: 0.01253997380247239 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 2.22 seconds
#
#
#
# Density matrix difference norm:  26.932582172157733
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001525386394
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022788578
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850555519
# Coulomb Energy                  3003.5375755726509
# Exchange-Correlation Energy     -179.3125720191484
# --------------------------------------------------
# Total Energy                   -1523.5033698391417
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140369
#
#
# HOMO-LUMO gap: 0.003087494761523467 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 2.23 seconds
#
#
#
# Density matrix difference norm:  13.42337010027203
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488927
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332565373
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671360989
# Coulomb Energy                  2977.4795296018083
# Exchange-Correlation Energy     -178.1026352539816
# --------------------------------------------------
# Total Energy                   -1499.0865279419495
# --------------------------------------------------
#
#
#
# Energy difference :  24.41684189719217
#
#
# HOMO-LUMO gap: 0.031814612726913424 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 2.23 seconds
#
#
#
# Density matrix difference norm:  12.444575042413916
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146527
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885442882
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462462518
# Coulomb Energy                  3000.9261851726860
# Exchange-Correlation Energy     -180.8962339957904
# --------------------------------------------------
# Total Energy                   -1522.7463472904783
# --------------------------------------------------
#
#
#
# Energy difference :  23.6598193485288
#
#
# HOMO-LUMO gap: 0.012952412899884677 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 2.24 seconds
#
#
#
# Density matrix difference norm:  6.016412544057412
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00012192201393
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025155859
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516681612
# Coulomb Energy                  3041.7824359801198
# Exchange-Correlation Energy     -185.1339645332759
# --------------------------------------------------
# Total Energy                   -1523.4476355699189
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794406323
#
#
# HOMO-LUMO gap: 0.021473549809572196 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  6.2227517052247965
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999594881058
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888914296
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569992460
# Coulomb Energy                  3063.1248487683933
# Exchange-Correlation Energy     -185.9132949764661
# --------------------------------------------------
# Total Energy                   -1521.9201342695942
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013003247295
#
#
# HOMO-LUMO gap: 0.07988335373072161 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  4.434848523639492
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846706
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733682261
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444891316
# Coulomb Energy                  3048.3985990984493
# Exchange-Correlation Energy     -185.3448733864971
# --------------------------------------------------
# Total Energy                   -1525.5849593364801
# --------------------------------------------------
#
#
#
# Energy difference :  3.6648250668858964
#
#
# HOMO-LUMO gap: 0.11911980736728728 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.8335133099905044
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000381243774
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577372644
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794406
# Coulomb Energy                  3044.2765927793580
# Exchange-Correlation Energy     -184.7849150214352
# --------------------------------------------------
# Total Energy                   -1525.7423647692385
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543275842356
#
#
# HOMO-LUMO gap: 0.10914385151739198 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.43782033360368655
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733324
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238685079
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349916
# Coulomb Energy                  3039.9455617680114
# Exchange-Correlation Energy     -184.3161788613750
# --------------------------------------------------
# Total Energy                   -1525.7678971962187
# --------------------------------------------------
#
#
#
# Energy difference :  0.025532426980134915
#
#
# HOMO-LUMO gap: 0.08055636124789856 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.2795602287758249
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000385397618
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906497
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116289
# Coulomb Energy                  3041.4914846757301
# Exchange-Correlation Energy     -184.5235703798693
# --------------------------------------------------
# Total Energy                   -1525.7860021524984
# --------------------------------------------------
#
#
#
# Energy difference :  0.018104956279785256
#
#
# HOMO-LUMO gap: 0.03553321190339237 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.2018817370118287
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004068429737
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555702449
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365257494
# Coulomb Energy                  3040.7248454918954
# Exchange-Correlation Energy     -184.4775892871814
# --------------------------------------------------
# Total Energy                   -1525.7891190091214
# --------------------------------------------------
#
#
#
# Energy difference :  0.003116856622909836
#
#
# HOMO-LUMO gap: 0.044870894866495675 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.0762529310464459
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003965723616
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379110602
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103298
# Coulomb Energy                  3040.4560830346322
# Exchange-Correlation Energy     -184.4308753791027
# --------------------------------------------------
# Total Energy                   -1525.7902311145376
# --------------------------------------------------
#
#
#
# Energy difference :  0.001112105416268605
#
#
# HOMO-LUMO gap: 0.0528566413681498 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.028372083618519634
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003947131015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669641370
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980479
# Coulomb Energy                  3040.4602645949831
# Exchange-Correlation Energy     -184.4309026475793
# --------------------------------------------------
# Total Energy                   -1525.7903707880237
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348604637664
#
#
# HOMO-LUMO gap: 0.04994812744098953 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.012785251243721193
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505604
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931460
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318330
# Coulomb Energy                  3040.4067159125971
# Exchange-Correlation Energy     -184.4260067735683
# --------------------------------------------------
# Total Energy                   -1525.7903870916234
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303599750244757e-05
#
#
# HOMO-LUMO gap: 0.05083365573058525 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.0060400214304186005
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112016
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954497
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920528
# Coulomb Energy                  3040.4581957845130
# Exchange-Correlation Energy     -184.4326037898898
# --------------------------------------------------
# Total Energy                   -1525.7903978781123
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786488928715698e-05
#
#
# HOMO-LUMO gap: 0.05068603589626337 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.001965540752193672
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378534
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801127091
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451722
# Coulomb Energy                  3040.4659355248805
# Exchange-Correlation Energy     -184.4328301188941
# --------------------------------------------------
# Total Energy                   -1525.7903988308881
# --------------------------------------------------
#
#
#
# Energy difference :  9.527757356408983e-07
#
#
# HOMO-LUMO gap: 0.05071262125664382 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0010394322822742906
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780368
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466446892
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272610690
# Coulomb Energy                  3040.4701320975901
# Exchange-Correlation Energy     -184.4333553536697
# --------------------------------------------------
# Total Energy                   -1525.7903988090375
# --------------------------------------------------
#
#
#
# Energy difference :  2.18506102100946e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090375
# -------------------------------------
#
#
#
# Time taken : 73.35 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           8.3
# Density Fitting                         1.3
#     DF (gamma)                          0.29
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.81
# DIIS                                    0.56
# KS matrix diagonalization               1.04
# One electron Integrals (S, T, Vnuc)     0.08
# Coulomb Integrals (2c2e + 3c2e)         10.13
# Grids construction                      5.1
# Exchange-Correlation Term               44.14
# Misc.                                   2.7
# Complete SCF                            73.35

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.15 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.54 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.1
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.017778582000005372
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.7
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.88 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 17.49 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 22.81 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.44 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0029198407821
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004643
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513665
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513665
#
#
# HOMO-LUMO gap: 1.3453174761628 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 5.54 seconds
#
#
#
# Density matrix difference norm:  144.01406386863079
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99996720715313
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016248267
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642081532
# Coulomb Energy                  7102.4006978647349
# Exchange-Correlation Energy     -401.0386878050872
# --------------------------------------------------
# Total Energy                   -2175.7881061964117
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450452
#
#
# HOMO-LUMO gap: 0.003632652816727977 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  71.99427239652846
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00238512472066
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645634316
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704937302
# Coulomb Energy                  5771.7138319762671
# Exchange-Correlation Energy     -243.8524720617089
# --------------------------------------------------
# Total Energy                   -2274.5129129945290
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679811724
#
#
# HOMO-LUMO gap: 0.004964611535631741 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 5.67 seconds
#
#
#
# Density matrix difference norm:  58.100701489602145
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00214404156065
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804044250
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573469457
# Coulomb Energy                  6321.7172809539134
# Exchange-Correlation Energy     -278.3781618573384
# --------------------------------------------------
# Total Energy                   -2158.4748828002885
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019424049
#
#
# HOMO-LUMO gap: 0.01447403056503832 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  53.36997549225585
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0018076772095
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768211396
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230008825
# Coulomb Energy                  6361.2336350673395
# Exchange-Correlation Energy     -281.9436333441303
# --------------------------------------------------
# Total Energy                   -2182.5642309364321
# --------------------------------------------------
#
#
#
# Energy difference :  24.0893481361436
#
#
# HOMO-LUMO gap: 0.008841693996933325 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 5.83 seconds
#
#
#
# Density matrix difference norm:  42.83901509480832
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009908414895
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446992952
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382080870
# Coulomb Energy                  6294.5110601791021
# Exchange-Correlation Energy     -283.9707682331550
# --------------------------------------------------
# Total Energy                   -2345.8009933846461
# --------------------------------------------------
#
#
#
# Energy difference :  163.236762448214
#
#
# HOMO-LUMO gap: 0.007160714247455402 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 5.89 seconds
#
#
#
# Density matrix difference norm:  32.18186260023497
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9997863855178
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019079052
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650760260
# Coulomb Energy                  6214.1516556239858
# Exchange-Correlation Energy     -284.6344014151045
# --------------------------------------------------
# Total Energy                   -2343.5239614623842
# --------------------------------------------------
#
#
#
# Energy difference :  2.2770319222618127
#
#
# HOMO-LUMO gap: 0.002450375009866626 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 5.88 seconds
#
#
#
# Density matrix difference norm:  33.323333139844905
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156512
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115030617
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996835235
# Coulomb Energy                  6284.6237009951928
# Exchange-Correlation Energy     -286.3084442723666
# --------------------------------------------------
# Total Energy                   -2352.7413339360974
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372473713112
#
#
# HOMO-LUMO gap: 0.0066733184073325125 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 5.83 seconds
#
#
#
# Density matrix difference norm:  26.098281915811064
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002679784586
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383709969
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896571189
# Coulomb Energy                  6418.8046173133116
# Exchange-Correlation Energy     -305.3162932889213
# --------------------------------------------------
# Total Energy                   -2410.9382035288745
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686959277715
#
#
# HOMO-LUMO gap: 0.007960539556880544 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  17.534698642340175
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057184652
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201814455
# Coulomb Energy                  6329.9135850824350
# Exchange-Correlation Energy     -297.7524519052633
# --------------------------------------------------
# Total Energy                   -2373.3942311992341
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397232964038
#
#
# HOMO-LUMO gap: 0.013997838610478819 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  16.42070464465626
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998237983231
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814550896
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928293336
# Coulomb Energy                  6324.0705156504300
# Exchange-Correlation Energy     -296.6169927417176
# --------------------------------------------------
# Total Energy                   -2423.4444445564295
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335719539
#
#
# HOMO-LUMO gap: 0.005801716902926107 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  17.91362907360169
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082557727933
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871577837
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553233326
# Coulomb Energy                  6269.4959589844475
# Exchange-Correlation Energy     -292.3687260432445
# --------------------------------------------------
# Total Energy                   -2388.5334777326334
# --------------------------------------------------
#
#
#
# Energy difference :  34.910966823796116
#
#
# HOMO-LUMO gap: 0.011739724678176314 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  18.86481092875975
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008953428889
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999710607
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986954534
# Coulomb Energy                  6304.9912271480489
# Exchange-Correlation Energy     -292.7049362976026
# --------------------------------------------------
# Total Energy                   -2419.7690892645469
# --------------------------------------------------
#
#
#
# Energy difference :  31.23561153191349
#
#
# HOMO-LUMO gap: 0.0016995925846794574 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  14.268938600693703
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015431500475
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930397862
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204685396
# Coulomb Energy                  6279.2250589488176
# Exchange-Correlation Energy     -293.0502585442221
# --------------------------------------------------
# Total Energy                   -2419.7439510060376
# --------------------------------------------------
#
#
#
# Energy difference :  0.02513825850928697
#
#
# HOMO-LUMO gap: 0.0058464312421980524 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  12.512861010697868
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026512183956
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104143016
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140344286
# Coulomb Energy                  6304.4543925174630
# Exchange-Correlation Energy     -294.2073055524958
# --------------------------------------------------
# Total Energy                   -2431.0698882542920
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937248254377
#
#
# HOMO-LUMO gap: 0.016452349643082745 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  10.313139444772558
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775194
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763799682
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614227376
# Coulomb Energy                  6320.4324015723059
# Exchange-Correlation Energy     -296.9899338056451
# --------------------------------------------------
# Total Energy                   -2429.5155260299553
# --------------------------------------------------
#
#
#
# Energy difference :  1.554362224336728
#
#
# HOMO-LUMO gap: 0.005064351145358609 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  8.084972669821783
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0000976405892
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466618793
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611238875
# Coulomb Energy                  6316.3510407026642
# Exchange-Correlation Energy     -296.7435745390376
# --------------------------------------------------
# Total Energy                   -2437.9484982137510
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972183795755
#
#
# HOMO-LUMO gap: 0.058930388844150985 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  4.102604850107578
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011810611767
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030009830
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451742207
# Coulomb Energy                  6313.1881517246893
# Exchange-Correlation Energy     -295.9055099898229
# --------------------------------------------------
# Total Energy                   -2441.0025949312821
# --------------------------------------------------
#
#
#
# Energy difference :  3.054096717531138
#
#
# HOMO-LUMO gap: 0.005337250393674373 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  6.254076481035471
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361987
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051590031
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545146761
# Coulomb Energy                  6280.4277633779184
# Exchange-Correlation Energy     -293.2139724472545
# --------------------------------------------------
# Total Energy                   -2436.9286385530486
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956378233561
#
#
# HOMO-LUMO gap: 0.011871839927736869 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  7.413375411276846
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002633558751
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726555038003
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918884434
# Coulomb Energy                  6298.7681987471788
# Exchange-Correlation Energy     -294.0996241353947
# --------------------------------------------------
# Total Energy                   -2439.1315678429582
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292899096617
#
#
# HOMO-LUMO gap: 0.10362999790072483 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  4.188397589943509
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011624361326
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485006216
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696455266
# Coulomb Energy                  6305.6013415981379
# Exchange-Correlation Energy     -295.1700654129312
# --------------------------------------------------
# Total Energy                   -2441.2043815092729
# --------------------------------------------------
#
#
#
# Energy difference :  2.072813666314687
#
#
# HOMO-LUMO gap: 0.030358347402618696 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  1.0881186801725142
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001058435007
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355860464
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042575756
# Coulomb Energy                  6306.4146008196258
# Exchange-Correlation Energy     -295.1986114171769
# --------------------------------------------------
# Total Energy                   -2441.2281207654087
# --------------------------------------------------
#
#
#
# Energy difference :  0.023739256135741016
#
#
# HOMO-LUMO gap: 0.10156738658314747 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  0.614708320382406
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001138647891
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391397292
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706629983
# Coulomb Energy                  6305.3788664336007
# Exchange-Correlation Energy     -295.1059315047952
# --------------------------------------------------
# Total Energy                   -2441.3391123873116
# --------------------------------------------------
#
#
#
# Energy difference :  0.1109916219029401
#
#
# HOMO-LUMO gap: 0.12914420515510516 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  0.22866753102153203
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001129709716
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680216023200
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454875492
# Coulomb Energy                  6306.4753103360981
# Exchange-Correlation Energy     -295.2425453766130
# --------------------------------------------------
# Total Energy                   -2441.3433899946722
# --------------------------------------------------
#
#
#
# Energy difference :  0.004277607360563707
#
#
# HOMO-LUMO gap: 0.11914092721810904 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.1331682879982983
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924006
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663341364
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009443998
# Coulomb Energy                  6305.4375957446437
# Exchange-Correlation Energy     -295.1178679621280
# --------------------------------------------------
# Total Energy                   -2441.3482164466068
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451934604847
#
#
# HOMO-LUMO gap: 0.07758609961654818 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.1679468445398809
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011918273225
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810434761
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356932457
# Coulomb Energy                  6304.4474550010527
# Exchange-Correlation Energy     -294.9863691580896
# --------------------------------------------------
# Total Energy                   -2441.3482383466526
# --------------------------------------------------
#
#
#
# Energy difference :  2.190004579460947e-05
#
#
# HOMO-LUMO gap: 0.0822040741551684 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.08195634563786176
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001176128904
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560676001
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184234810
# Coulomb Energy                  6305.2666287327675
# Exchange-Correlation Energy     -295.0991774796056
# --------------------------------------------------
# Total Energy                   -2441.3500652303419
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836893184925
#
#
# HOMO-LUMO gap: 0.0868139324740861 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.030947650084602436
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711136
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449608264
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969466707
# Coulomb Energy                  6305.1999901383660
# Exchange-Correlation Energy     -295.0882138897816
# --------------------------------------------------
# Total Energy                   -2441.3501506049561
# --------------------------------------------------
#
#
#
# Energy difference :  8.537461417290615e-05
#
#
# HOMO-LUMO gap: 0.08605512219044326 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.015359420149734532
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011741243867
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082987041
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754509341
# Coulomb Energy                  6305.1611656009809
# Exchange-Correlation Energy     -295.0851653175776
# --------------------------------------------------
# Total Energy                   -2441.3502114037528
# --------------------------------------------------
#
#
#
# Energy difference :  6.079879676690325e-05
#
#
# HOMO-LUMO gap: 0.08610559554975351 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  0.00585072830181224
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173080264
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341357842
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624064497
# Coulomb Energy                  6305.1739654234225
# Exchange-Correlation Energy     -295.0859344062360
# --------------------------------------------------
# Total Energy                   -2441.3502195515339
# --------------------------------------------------
#
#
#
# Energy difference :  8.14778104540892e-06
#
#
# HOMO-LUMO gap: 0.08627753380273127 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0022687655701343185
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730379316
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171302250
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927319074
# Coulomb Energy                  6305.1767750460276
# Exchange-Correlation Energy     -295.0862921108245
# --------------------------------------------------
# Total Energy                   -2441.3502203025000
# --------------------------------------------------
#
#
#
# Energy difference :  7.509661372750998e-07
#
#
# HOMO-LUMO gap: 0.08629954674359594 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0014216232825397372
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161182
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335501637
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841016297
# Coulomb Energy                  6305.1678310989118
# Exchange-Correlation Energy     -295.0851232567613
# --------------------------------------------------
# Total Energy                   -2441.3502204457691
# --------------------------------------------------
#
#
#
# Energy difference :  1.432690623914823e-07
#
#
# HOMO-LUMO gap: 0.08625864034176525 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.0007905213652578743
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173192669
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319671
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598893
# Coulomb Energy                  6305.1716231999126
# Exchange-Correlation Energy     -295.0855737005026
# --------------------------------------------------
# Total Energy                   -2441.3502206120520
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628291632514447e-07
#
#
# HOMO-LUMO gap: 0.08626853544512196 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.00028632021528559914
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173138948
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851890356
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651371162
# Coulomb Energy                  6305.1740152928305
# Exchange-Correlation Energy     -295.0859370217361
# --------------------------------------------------
# Total Energy                   -2441.3502206202102
# --------------------------------------------------
#
#
#
# Energy difference :  8.158167474903166e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.35022062021
# -------------------------------------
#
#
#
# Time taken : 270.23 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           23.25
# Density Fitting                         5.76
#     DF (gamma)                          1.07
#     DF (coeff)                          0.18
#     DF (Jtri)                           4.09
# DIIS                                    3.79
# KS matrix diagonalization               3.84
# One electron Integrals (S, T, Vnuc)     0.15
# Coulomb Integrals (2c2e + 3c2e)         29.88
# Grids construction                      17.49
# Exchange-Correlation Term               181.28
# Misc.                                   4.79
# Complete SCF                            270.23

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.03 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.04 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0008975609998742584
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.04
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.84 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.33 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.6 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.05 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000355
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709566
# Exchange-Correlation Energy      -16.0363502502441
# --------------------------------------------------
# Total Energy                     -93.1572655540410
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726555404098
#
#
# HOMO-LUMO gap: 2.643230893268333 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.53 seconds
#
#
#
# Density matrix difference norm:  43.34737695041916
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999992
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065134268101
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632901411597
# Coulomb Energy                   501.1179499873577
# Exchange-Correlation Energy      -62.5998153686523
# --------------------------------------------------
# Total Energy                    -340.0671116228215
# --------------------------------------------------
#
#
#
# Energy difference :  246.9098460687805
#
#
# HOMO-LUMO gap: 0.004895001056166193 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  28.61225137831371
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000107
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015434342904
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404486356355
# Coulomb Energy                   293.3105327789987
# Exchange-Correlation Energy      -37.4191284179688
# --------------------------------------------------
# Total Energy                    -355.5117133935015
# --------------------------------------------------
#
#
#
# Energy difference :  15.444601770680038
#
#
# HOMO-LUMO gap: 0.04090611597249297 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  21.39438043568733
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6802048744935
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079158470808
# Coulomb Energy                   367.2116081156483
# Exchange-Correlation Energy      -44.5831108093262
# --------------------------------------------------
# Total Energy                    -380.5858146769671
# --------------------------------------------------
#
#
#
# Energy difference :  25.074101283465552
#
#
# HOMO-LUMO gap: 0.018045819534129127 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  5.193655309004106
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853211394488
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987312449234
# Coulomb Energy                   364.3594842203969
# Exchange-Correlation Energy      -44.5593338012695
# --------------------------------------------------
# Total Energy                    -378.6284624312746
# --------------------------------------------------
#
#
#
# Energy difference :  1.9573522456925048
#
#
# HOMO-LUMO gap: 0.08497506224154738 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  4.776044383074424
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000023
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113353910970
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536993637291
# Coulomb Energy                   368.1595786044384
# Exchange-Correlation Energy      -45.0864906311035
# --------------------------------------------------
# Total Energy                    -381.1265710099094
# --------------------------------------------------
#
#
#
# Energy difference :  2.498108578634856
#
#
# HOMO-LUMO gap: 0.14153440093829453 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5199018206073651
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759870186160
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620529814582
# Coulomb Energy                   369.0651872518460
# Exchange-Correlation Energy      -45.1361846923828
# --------------------------------------------------
# Total Energy                    -381.2269544335711
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038342366163988
#
#
# HOMO-LUMO gap: 0.13505793051887766 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.33141822112927966
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685883045681
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352932575459
# Coulomb Energy                   369.6332915647434
# Exchange-Correlation Energy      -45.2082252502441
# --------------------------------------------------
# Total Energy                    -381.2502516883995
# --------------------------------------------------
#
#
#
# Energy difference :  0.023297254828435143
#
#
# HOMO-LUMO gap: 0.019481120474573295 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.15 seconds
#
#
#
# Density matrix difference norm:  0.5819574011113114
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471076686398
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753380205172
# Coulomb Energy                   374.0875565365470
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611101767
# --------------------------------------------------
#
#
#
# Energy difference :  0.13180942177717725
#
#
# HOMO-LUMO gap: 0.12602028669925072 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.45972397759800065
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167311182767
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482981739374
# Coulomb Energy                   377.3936785488467
# Exchange-Correlation Energy      -46.1032257080078
# --------------------------------------------------
# Total Energy                    -381.4200030593769
# --------------------------------------------------
#
#
#
# Energy difference :  0.037941949200217095
#
#
# HOMO-LUMO gap: 0.16611333053436667 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.145066702587276
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6774115562346
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4957003907866
# Coulomb Energy                   377.1713417801328
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261838450979
# --------------------------------------------------
#
#
#
# Energy difference :  0.006180785720971471
#
#
# HOMO-LUMO gap: 0.18109750595331803 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.055970387857493815
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466991731310
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5465057500065
# Coulomb Energy                   377.1955793525918
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266045251886
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004206800907127217
#
#
# HOMO-LUMO gap: 0.18093185638011972 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.025624539781156582
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6791043635660
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228770244522
# Coulomb Energy                   377.1480814133165
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267298557950
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001253306064086246
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.1805073066521138 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.00841060120155985
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007494818696
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758646250014
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145535863867
# Coulomb Energy                   377.1522588566510
# Exchange-Correlation Energy      -46.0763604882695
# --------------------------------------------------
# Total Energy                    -381.4274356261097
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007057703147665961
#
#
# HOMO-LUMO gap: 0.18055941774668907 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0026418714065817492
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750320948
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547069029741
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032889737213
# Coulomb Energy                   377.1410365648674
# Exchange-Correlation Energy      -46.0750325767574
# --------------------------------------------------
# Total Energy                    -381.4274368970193
# --------------------------------------------------
#
#
#
# Energy difference :  1.2709095926766167e-06
#
#
# HOMO-LUMO gap: 0.18056583448655167 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0017678391934180411
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749795149
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715784380194
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117381337677
# Coulomb Energy                   377.1506250231068
# Exchange-Correlation Energy      -46.0761996769597
# --------------------------------------------------
# Total Energy                    -381.4274379139811
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169617326027947e-06
#
#
# HOMO-LUMO gap: 0.18057810005489836 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018263944817903386
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749433848
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890954308201
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201163633792
# Coulomb Energy                   377.1610739046053
# Exchange-Correlation Energy      -46.0775109642904
# --------------------------------------------------
# Total Energy                    -381.4274390830025
# --------------------------------------------------
#
#
#
# Energy difference :  1.1690214591908443e-06
#
#
# HOMO-LUMO gap: 0.18069051721673868 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0015078228603729045
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007497971005
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793142630868
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150718660066
# Coulomb Energy                   377.1557642489232
# Exchange-Correlation Energy      -46.0769384584159
# --------------------------------------------------
# Total Energy                    -381.4274395624495
# --------------------------------------------------
#
#
#
# Energy difference :  4.794469532498624e-07
#
#
# HOMO-LUMO gap: 0.18064424248425276 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0004667166781138539
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749830373
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995819634
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900979585
# Coulomb Energy                   377.1550630969091
# Exchange-Correlation Energy      -46.0768702751827
# --------------------------------------------------
# Total Energy                    -381.4274396181549
# --------------------------------------------------
#
#
#
# Energy difference :  5.57054704586335e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743961815495
# -------------------------------------
#
#
#
# Time taken : 9.54 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.66
# Density Fitting                         0.23
#     DF (gamma)                          0.07
#     DF (coeff)                          0.07
#     DF (Jtri)                           0.08
# DIIS                                    0.09
# KS matrix diagonalization               0.36
# One electron Integrals (S, T, Vnuc)     0.03
# Coulomb Integrals (2c2e + 3c2e)         0.84
# Grids construction                      0.33
# Exchange-Correlation Term               6.05
# Misc.                                   0.95
# Complete SCF                            9.54

# %% [markdown]
# ### Benchmark #4 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.1 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0021054669998648023
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.73 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.05 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.03 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371789
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120590
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961205902
#
#
# HOMO-LUMO gap: 1.765506807214487 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.28 seconds
#
#
#
# Density matrix difference norm:  66.88323605808496
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816168858127
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207644691054
# Coulomb Energy                  1272.5916576120460
# Exchange-Correlation Energy     -125.2197723388672
# --------------------------------------------------
# Total Energy                    -680.0824210262965
# --------------------------------------------------
#
#
#
# Energy difference :  494.6338014142375
#
#
# HOMO-LUMO gap: 0.0003950061519720216 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  39.27352432790374
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.001236
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671666175992
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861185032868
# Coulomb Energy                   861.6520702031740
# Exchange-Correlation Energy      -75.4418334960938
# --------------------------------------------------
# Total Energy                    -709.3642652900002
# --------------------------------------------------
#
#
#
# Energy difference :  29.281844263703647
#
#
# HOMO-LUMO gap: 0.02781557634654673 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  28.145163639904677
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99994
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982282479319
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525304346837
# Coulomb Energy                  1000.6416009622251
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464582044943
# --------------------------------------------------
#
#
#
# Energy difference :  24.382192914494112
#
#
# HOMO-LUMO gap: 0.006873881117245642 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  18.101423188537982
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394470587427
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643058398226
# Coulomb Energy                  1039.7364436431981
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035183408144
# --------------------------------------------------
#
#
#
# Energy difference :  44.142939863679885
#
#
# HOMO-LUMO gap: 0.009401599135742747 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  13.030480145152595
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9281985793859
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4697782227058
# Coulomb Energy                  1004.3617050508819
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228962393475
# --------------------------------------------------
#
#
#
# Energy difference :  60.019377898533094
#
#
# HOMO-LUMO gap: 0.024324032085167292 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.651673179633178
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2543707805858
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338780970721
# Coulomb Energy                   997.3404993658399
# Exchange-Correlation Energy      -89.6696014404297
# --------------------------------------------------
# Total Energy                    -755.2430486408713
# --------------------------------------------------
#
#
#
# Energy difference :  5.6201524015237965
#
#
# HOMO-LUMO gap: 0.0012911086004763483 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.531122034443298
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000244
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9935087145304
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455302507195
# Coulomb Energy                  1008.9226260308241
# Exchange-Correlation Energy      -89.8105239868164
# --------------------------------------------------
# Total Energy                    -754.8293303025713
# --------------------------------------------------
#
#
#
# Energy difference :  0.4137183382999865
#
#
# HOMO-LUMO gap: 0.015388890067429786 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  7.34249677633967
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6263351323701
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2045024209493
# Coulomb Energy                  1033.2839552051173
# Exchange-Correlation Energy      -92.8135986328125
# --------------------------------------------------
# Total Energy                    -754.2449300218841
# --------------------------------------------------
#
#
#
# Energy difference :  0.5844002806871913
#
#
# HOMO-LUMO gap: 0.21170745715232225 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.051896129114387
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9762828043295
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1048809118028
# Coulomb Energy                  1046.8936432437335
# Exchange-Correlation Energy      -94.6926879882812
# --------------------------------------------------
# Total Energy                    -761.9639005198424
# --------------------------------------------------
#
#
#
# Energy difference :  7.718970497958253
#
#
# HOMO-LUMO gap: 0.02108735225655571 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  4.59285641783142
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186477778050
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7140596288688
# Coulomb Energy                  1016.5840725520118
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8410446750052
# --------------------------------------------------
#
#
#
# Energy difference :  2.122855844837204
#
#
# HOMO-LUMO gap: 0.08795063967983471 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  4.199972580903989
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5724895003300
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4485457098673
# Coulomb Energy                  1025.9226129556935
# Exchange-Correlation Energy      -92.2370223999023
# --------------------------------------------------
# Total Energy                    -762.7318071174398
# --------------------------------------------------
#
#
#
# Energy difference :  2.890762442434607
#
#
# HOMO-LUMO gap: 0.14484586062659952 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.9087415262846613
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899827865545
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303628910335
# Coulomb Energy                  1024.4800321788657
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263924295015
# --------------------------------------------------
#
#
#
# Energy difference :  0.09458531206178122
#
#
# HOMO-LUMO gap: 0.09120588042478614 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.3385954199392612
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063812557968
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273614182925
# Coulomb Energy                  1024.8155231797580
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565126132683
# --------------------------------------------------
#
#
#
# Energy difference :  0.030120183766712216
#
#
# HOMO-LUMO gap: 0.10812610974714248 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.13342123197973402
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7707740453052
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490276156233
# Coulomb Energy                  1024.3963719045626
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586828390396
# --------------------------------------------------
#
#
#
# Energy difference :  0.0021702257713513973
#
#
# HOMO-LUMO gap: 0.11558372061616265 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.052410342335430446
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028282847123
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1553899109001
# Coulomb Energy                  1024.6505228360134
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595512442971
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008684052575063106
#
#
# HOMO-LUMO gap: 0.1155304251416244 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.014070575532052383
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000169179912
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543955760995
# Coulomb Energy                  1024.5347563472235
# Exchange-Correlation Energy      -92.1552658081055
# --------------------------------------------------
# Total Energy                    -762.8595846855417
# --------------------------------------------------
#
#
#
# Energy difference :  3.344124456816644e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.1196464783958618 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.01580799986152934
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745392808
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803833656164
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978002965821
# Coulomb Energy                  1024.5775707586629
# Exchange-Correlation Energy      -92.1624877479194
# --------------------------------------------------
# Total Energy                    -762.8609539410588
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013692555171473941
#
#
# HOMO-LUMO gap: 0.11847999444528232 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.008700483345260374
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741303613
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328773694259
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722787166950
# Coulomb Energy                  1024.5524778469271
# Exchange-Correlation Energy      -92.1594108114837
# --------------------------------------------------
# Total Energy                    -762.8609855000554
# --------------------------------------------------
#
#
#
# Energy difference :  3.155899662488082e-05
#
#
# HOMO-LUMO gap: 0.11834733975208722 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.002054410999093647
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739809352
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503339703496
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805107525648
# Coulomb Energy                  1024.5630589457783
# Exchange-Correlation Energy      -92.1607681607320
# --------------------------------------------------
# Total Energy                    -762.8609863155066
# --------------------------------------------------
#
#
#
# Energy difference :  8.154511306202039e-07
#
#
# HOMO-LUMO gap: 0.11844992985115464 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.002280409925831228
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742289413
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365049723659
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734594450377
# Coulomb Energy                  1024.5553040222380
# Exchange-Correlation Energy      -92.1597916212961
# --------------------------------------------------
# Total Energy                    -762.8609870091545
# --------------------------------------------------
#
#
#
# Energy difference :  6.936479621799663e-07
#
#
# HOMO-LUMO gap: 0.11849899767933128 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.0021209734870130032
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742173725
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510214858596
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0797957086470
# Coulomb Energy                  1024.5646225409223
# Exchange-Correlation Energy      -92.1609312870312
# --------------------------------------------------
# Total Energy                    -762.8609884060897
# --------------------------------------------------
#
#
#
# Energy difference :  1.396935203956673e-06
#
#
# HOMO-LUMO gap: 0.11838532618648875 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.0014185702958411106
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000074161994
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635539876994
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852199871540
# Coulomb Energy                  1024.5726721439996
# Exchange-Correlation Energy      -92.1618731206747
# --------------------------------------------------
# Total Energy                    -762.8609888599890
# --------------------------------------------------
#
#
#
# Energy difference :  4.5389924707706086e-07
#
#
# HOMO-LUMO gap: 0.1183827542602412 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.00032232916122386076
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041726
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571685695777
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822982336009
# Coulomb Energy                  1024.5687889822475
# Exchange-Correlation Energy      -92.1614536539883
# --------------------------------------------------
# Total Energy                    -762.8609888904857
# --------------------------------------------------
#
#
#
# Energy difference :  3.049672159249894e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904857
# -------------------------------------
#
#
#
# Time taken : 15.46 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.17
# Density Fitting                         0.51
#     DF (gamma)                          0.15
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.25
# DIIS                                    0.14
# KS matrix diagonalization               0.63
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.73
# Grids construction                      1.05
# Exchange-Correlation Term               6.74
# Misc.                                   1.45
# Complete SCF                            15.46

# %% [markdown]
# ### Benchmark #5 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.08 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.26 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007932209000045987
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.07 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.29
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.07 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.93 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 8.05 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355691
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929922982
# --------------------------------------------------
#
#
#
# Energy difference :  374.9324929922982
#
#
# HOMO-LUMO gap: 1.8503196895446359 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  107.82808392765982
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876321744799
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682663137899
# Coulomb Energy                  3537.3220829802081
# Exchange-Correlation Energy     -250.6110687255859
# --------------------------------------------------
# Total Energy                   -1359.8987077754068
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662147831086
#
#
# HOMO-LUMO gap: 0.002113837042747313 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  57.365047491772415
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4339726200915
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0382902509950
# Coulomb Energy                  2705.4087019806611
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539387306253
# --------------------------------------------------
#
#
#
# Energy difference :  59.155230955218485
#
#
# HOMO-LUMO gap: 0.01974261041789839 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  48.04762458069278
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987260321555
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516880410189
# Coulomb Energy                  3071.8807166785032
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010317300194
# --------------------------------------------------
#
#
#
# Energy difference :  56.652907000605865
#
#
# HOMO-LUMO gap: 0.014679275637159081 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  40.92171705438478
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335375163460
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1620892895676
# Coulomb Energy                  3051.7270285260997
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347880770475
# --------------------------------------------------
#
#
#
# Energy difference :  16.433756347028066
#
#
# HOMO-LUMO gap: 0.012567149519513182 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  26.926775909312102
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983163052868
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494773880524
# Coulomb Energy                  3003.5484466731959
# Exchange-Correlation Energy     -179.3104553222656
# --------------------------------------------------
# Total Energy                   -1523.5012037356428
# --------------------------------------------------
#
#
#
# Energy difference :  144.66641565859527
#
#
# HOMO-LUMO gap: 0.003217947191737673 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  13.414502571997144
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00024
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4196922561659
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319358768537
# Coulomb Energy                  2977.4926566555869
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856603608363
# --------------------------------------------------
#
#
#
# Energy difference :  24.415543374806475
#
#
# HOMO-LUMO gap: 0.03182996303248258 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  12.436593801553295
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381473896537
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8446900505551
# Coulomb Energy                  3000.9338456641535
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434614966269
# --------------------------------------------------
#
#
#
# Energy difference :  23.657801135790578
#
#
# HOMO-LUMO gap: 0.012963702180421602 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.0134648620764555
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677652671184
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553158180550
# Coulomb Energy                  3041.7902303797591
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430836614947
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996221648678329
#
#
# HOMO-LUMO gap: 0.021491246711770717 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.216636087609861
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4699663201445
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196379755535
# Coulomb Energy                  3063.1283242933491
# Exchange-Correlation Energy     -185.9102325439453
# --------------------------------------------------
# Total Energy                   -1521.9225927645261
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204908969685675
#
#
# HOMO-LUMO gap: 0.07962874707654935 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  4.429032459721922
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505023342685
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1094877914227
# Coulomb Energy                  3048.3900509776558
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820332355052
# --------------------------------------------------
#
#
#
# Energy difference :  3.659440470979007
#
#
# HOMO-LUMO gap: 0.11947953265856824 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.8332702702064334
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524402069474
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100133859415
# Coulomb Energy                  3044.2746773353629
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396913483408
# --------------------------------------------------
#
#
#
# Energy difference :  0.1576581128356338
#
#
# HOMO-LUMO gap: 0.10915531684778548 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.4379677892518216
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333917109041
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380082601351
# Coulomb Energy                  3039.9319407815583
# Exchange-Correlation Energy     -184.3113403320312
# --------------------------------------------------
# Total Energy                   -1525.7651391705804
# --------------------------------------------------
#
#
#
# Energy difference :  0.02544782223958464
#
#
# HOMO-LUMO gap: 0.08049516883418112 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.2802188648443746
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675670963574
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0128945766437
# Coulomb Energy                  3041.4808649184979
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832830332500
# --------------------------------------------------
#
#
#
# Energy difference :  0.01814386266960355
#
#
# HOMO-LUMO gap: 0.035362088504288264 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.20216527188747224
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152284509444
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773134021377
# Coulomb Energy                  3040.7151028821518
# Exchange-Correlation Energy     -184.4732360839844
# --------------------------------------------------
# Total Energy                   -1525.7864044199778
# --------------------------------------------------
#
#
#
# Energy difference :  0.003121386727798381
#
#
# HOMO-LUMO gap: 0.044773951371614926 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.07633473781106039
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0312890912583
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161688348756
# Coulomb Energy                  3040.4442133356442
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875173625362
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011129425583931152
#
#
# HOMO-LUMO gap: 0.052790808664024386 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.02844018448550093
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299740888577
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078521583983
# Coulomb Energy                  3040.4514279255918
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877011751834
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018381264726485824
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.0498928856780176 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.012831614930845702
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963125354
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444073106843
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722240655686
# Coulomb Energy                  3040.3964234535042
# Exchange-Correlation Energy     -184.4242562321535
# --------------------------------------------------
# Total Energy                   -1525.7903721931043
# --------------------------------------------------
#
#
#
# Energy difference :  0.002671017920874874
#
#
# HOMO-LUMO gap: 0.05055294522802645 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.005300433423432534
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960689395
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993294743035
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002701853990
# Coulomb Energy                  3040.4277543992130
# Exchange-Correlation Energy     -184.4287288816737
# --------------------------------------------------
# Total Energy                   -1525.7903899407038
# --------------------------------------------------
#
#
#
# Energy difference :  1.7747599486028776e-05
#
#
# HOMO-LUMO gap: 0.05045899130227113 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.0021062776293601514
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961675122
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9998982562674
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3973945423973
# Coulomb Energy                  3040.4311709838357
# Exchange-Correlation Energy     -184.4287041855820
# --------------------------------------------------
# Total Energy                   -1525.7903930849543
# --------------------------------------------------
#
#
#
# Energy difference :  3.144250513287261e-06
#
#
# HOMO-LUMO gap: 0.05065933697999497 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.00488145191737237
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960054133
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796141561459
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345417760078
# Coulomb Energy                  3040.4795323687736
# Exchange-Correlation Energy     -184.4344982030154
# --------------------------------------------------
# Total Energy                   -1525.7903943837196
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987652553420048e-06
#
#
# HOMO-LUMO gap: 0.05063328228840021 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.00400391174975827
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.000039629358
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308454145852
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102267625731
# Coulomb Energy                  3040.4520256177966
# Exchange-Correlation Energy     -184.4314493992453
# --------------------------------------------------
# Total Energy                   -1525.7903986027995
# --------------------------------------------------
#
#
#
# Energy difference :  4.2190799831587356e-06
#
#
# HOMO-LUMO gap: 0.05065920534816509 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.36 seconds
#
#
#
# Density matrix difference norm:  0.0009814796880000278
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396231762
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462802263064
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170922951209
# Coulomb Energy                  3040.4616007220638
# Exchange-Correlation Energy     -184.4324555382868
# --------------------------------------------------
# Total Energy                   -1525.7903989167471
# --------------------------------------------------
#
#
#
# Energy difference :  3.139475666102953e-07
#
#
# HOMO-LUMO gap: 0.050679426882839676 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.0002461864924027828
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332747
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503257648525
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622285455
# Coulomb Energy                  3040.4641305951122
# Exchange-Correlation Energy     -184.4327098271667
# --------------------------------------------------
# Total Energy                   -1525.7903989376987
# --------------------------------------------------
#
#
#
# Energy difference :  2.095157469739206e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989376987
# -------------------------------------
#
#
#
# Time taken : 55.01 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           8.22
# Density Fitting                         1.48
#     DF (gamma)                          0.32
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.94
# DIIS                                    0.71
# KS matrix diagonalization               1.22
# One electron Integrals (S, T, Vnuc)     0.08
# Coulomb Integrals (2c2e + 3c2e)         11.07
# Grids construction                      4.93
# Exchange-Correlation Term               24.73
# Misc.                                   2.56
# Complete SCF                            55.01

# %% [markdown]
# ### Benchmark #6 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.15 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.51 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.1
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.019134193000127198
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.69
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.98 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 17.46 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 22.77 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.28 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004615
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456270
# --------------------------------------------------
#
#
#
# Energy difference :  601.181717645627
#
#
# HOMO-LUMO gap: 1.3453310369352578 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.75 seconds
#
#
#
# Density matrix difference norm:  144.0136746268792
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771653634671
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873960288406
# Coulomb Energy                  7102.3908476757333
# Exchange-Correlation Energy     -401.0388488769531
# --------------------------------------------------
# Total Energy                   -2175.7976493752321
# --------------------------------------------------
#
#
#
# Energy difference :  1574.615931729605
#
#
# HOMO-LUMO gap: 0.003632393682962254 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.37 seconds
#
#
#
# Density matrix difference norm:  71.99222142056543
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0024
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8537956300715
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349342493075
# Coulomb Energy                  5771.7158140795536
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171589286811
# --------------------------------------------------
#
#
#
# Energy difference :  98.71950955344892
#
#
# HOMO-LUMO gap: 0.00497160535520029 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.39 seconds
#
#
#
# Density matrix difference norm:  58.10278545024815
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372312940872
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733518957216
# Coulomb Energy                  6321.7308991207938
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4680727400046
# --------------------------------------------------
#
#
#
# Energy difference :  116.04908618867648
#
#
# HOMO-LUMO gap: 0.014406138508216482 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  53.36866413489749
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688656106904
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515407576780
# Coulomb Energy                  6361.2922211399618
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5267244957959
# --------------------------------------------------
#
#
#
# Energy difference :  24.05865175579129
#
#
# HOMO-LUMO gap: 0.008931030832472875 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 1.46 seconds
#
#
#
# Density matrix difference norm:  42.83084093358665
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057601563341
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112456485049
# Coulomb Energy                  6294.4824442892959
# Exchange-Correlation Energy     -283.9661865234375
# --------------------------------------------------
# Total Energy                   -2345.8381355813572
# --------------------------------------------------
#
#
#
# Energy difference :  163.3114110855613
#
#
# HOMO-LUMO gap: 0.006907368456341434 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 1.49 seconds
#
#
#
# Density matrix difference norm:  32.166244471963694
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2173793204784
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029698695465
# Coulomb Energy                  6214.1441891904551
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5589137971283
# --------------------------------------------------
#
#
#
# Energy difference :  2.2792217842288665
#
#
# HOMO-LUMO gap: 0.0024707172091796015 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  33.32021223785604
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828402342991
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271150062013
# Coulomb Energy                  6284.7511440334947
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5702766843788
# --------------------------------------------------
#
#
#
# Energy difference :  9.01136288725047
#
#
# HOMO-LUMO gap: 0.006023024402478344 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  26.09922121712443
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2099076937811
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3779151299368
# Coulomb Energy                  6418.6992912609667
# Exchange-Correlation Energy     -305.3439331054688
# --------------------------------------------------
# Total Energy                   -2411.0365132477318
# --------------------------------------------------
#
#
#
# Energy difference :  58.46623656335305
#
#
# HOMO-LUMO gap: 0.005612052983225813 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  17.530054375032428
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3145708652264
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3755204976524
# Coulomb Energy                  6329.8759503022720
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3362052230477
# --------------------------------------------------
#
#
#
# Energy difference :  37.70030802468409
#
#
# HOMO-LUMO gap: 0.017128837854784917 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  16.39802583882916
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4113870607471
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3502468173110
# Coulomb Energy                  6323.6507850855323
# Exchange-Correlation Energy     -296.5716552734375
# --------------------------------------------------
# Total Energy                   -2423.5418892707276
# --------------------------------------------------
#
#
#
# Energy difference :  50.205684047679824
#
#
# HOMO-LUMO gap: 0.006507556541213766 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  17.89685998404336
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006101860141
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1971040588974
# Coulomb Energy                  6269.6529403751156
# Exchange-Correlation Energy     -292.3520507812500
# --------------------------------------------------
# Total Energy                   -2388.4624953726361
# --------------------------------------------------
#
#
#
# Energy difference :  35.07939389809144
#
#
# HOMO-LUMO gap: 0.011363447268680674 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  18.875112772715518
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4052532181177
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783311062498
# Coulomb Energy                  6305.1510335547146
# Exchange-Correlation Energy     -292.6977233886719
# --------------------------------------------------
# Total Energy                   -2419.6334907852115
# --------------------------------------------------
#
#
#
# Energy difference :  31.170995412575394
#
#
# HOMO-LUMO gap: 0.0019309058839375726 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  14.237403947733696
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7558591980614
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6447020488381
# Coulomb Energy                  6277.9144651607394
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7447910427136
# --------------------------------------------------
#
#
#
# Energy difference :  0.11130025750208006
#
#
# HOMO-LUMO gap: 0.00826812294147762 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  12.511462177245935
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00024
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8343262264734
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119731151358
# Coulomb Energy                  6304.6092497478548
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9790979255249
# --------------------------------------------------
#
#
#
# Energy difference :  11.234306882811325
#
#
# HOMO-LUMO gap: 0.017659052930046562 au
# HOMO-LUMO gap: 0.481 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  10.321247463044086
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0477862727676
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2890409276579
# Coulomb Energy                  6320.8555460580183
# Exchange-Correlation Energy     -297.0248107910156
# --------------------------------------------------
# Total Energy                   -2429.4878889174915
# --------------------------------------------------
#
#
#
# Energy difference :  1.4912090080333655
#
#
# HOMO-LUMO gap: 0.00640443327333895 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  8.082502350911003
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4238707007353
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0824814312559
# Coulomb Energy                  6316.7243561585292
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382950069757
# --------------------------------------------------
#
#
#
# Energy difference :  8.450406089484204
#
#
# HOMO-LUMO gap: 0.06628492717271987 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.088567948135573
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3817879886101
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5872123280437
# Coulomb Energy                  6313.2561777030332
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039774805118
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656824735360715
#
#
# HOMO-LUMO gap: 0.0025081337117276448 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.34255996286522
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2972588129742
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1398534594769
# Coulomb Energy                  6287.7368529786454
# Exchange-Correlation Energy     -293.7501220703125
# --------------------------------------------------
# Total Energy                   -2439.7305532845494
# --------------------------------------------------
#
#
#
# Energy difference :  1.2734241959624342
#
#
# HOMO-LUMO gap: 0.02060403414805808 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.259663724988744
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7060520821378
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.1985447105430
# Coulomb Energy                  6303.8932619908264
# Exchange-Correlation Energy     -294.9478454589844
# --------------------------------------------------
# Total Energy                   -2441.1219696791377
# --------------------------------------------------
#
#
#
# Energy difference :  1.3914163945883047
#
#
# HOMO-LUMO gap: 0.12298447091744288 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  0.7427991084376668
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0196830681562
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5243018966548
# Coulomb Energy                  6307.0121816991059
# Exchange-Correlation Energy     -295.2850036621094
# --------------------------------------------------
# Total Energy                   -2441.3280819738911
# --------------------------------------------------
#
#
#
# Energy difference :  0.20611229475343862
#
#
# HOMO-LUMO gap: 0.0886713886537025 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  0.4773174081479247
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4109703644681
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7988776548555
# Coulomb Energy                  6304.8709022551720
# Exchange-Correlation Energy     -295.0262451171875
# --------------------------------------------------
# Total Energy                   -2441.3273144110135
# --------------------------------------------------
#
#
#
# Energy difference :  0.000767562877626915
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639449092760228 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 1.55 seconds
#
#
#
# Density matrix difference norm:  0.27041960746089294
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001152745347
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5564923362508
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4793584122658
# Coulomb Energy                  6304.2831248705852
# Exchange-Correlation Energy     -294.9926857305752
# --------------------------------------------------
# Total Energy                   -2441.3465736233602
# --------------------------------------------------
#
#
#
# Energy difference :  0.019259212346696586
#
#
# HOMO-LUMO gap: 0.10571264279718237 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 5.89 seconds
#
#
#
# Density matrix difference norm:  0.11903278016090543
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001155256579
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9902599802645
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6069251118747
# Coulomb Energy                  6305.7413371038983
# Exchange-Correlation Energy     -295.1470988269834
# --------------------------------------------------
# Total Energy                   -2441.3489754308594
# --------------------------------------------------
#
#
#
# Energy difference :  0.002401807499154529
#
#
# HOMO-LUMO gap: 0.10232613515436152 au
# HOMO-LUMO gap: 2.784 eV
#
#
# Time taken for the previous iteration: 5.86 seconds
#
#
#
# Density matrix difference norm:  0.05772571772899506
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001161640675
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1764051378741
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2270724742175
# Coulomb Energy                  6305.2551231506568
# Exchange-Correlation Energy     -295.0957742110962
# --------------------------------------------------
# Total Energy                   -2441.3498625634820
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008871326226653764
#
#
# HOMO-LUMO gap: 0.08313043014187858 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  0.0636549576868175
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001177587232
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6239924699512
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9398281763529
# Coulomb Energy                  6304.9503120830022
# Exchange-Correlation Energy     -295.0562590588603
# --------------------------------------------------
# Total Energy                   -2441.3499901088408
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001275453587368247
#
#
# HOMO-LUMO gap: 0.0854398546828862 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.03312303588986663
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011719092515
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1937802664943
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2381603266126
# Coulomb Energy                  6305.2622596443443
# Exchange-Correlation Energy     -295.0969068355629
# --------------------------------------------------
# Total Energy                   -2441.3501459704848
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001558616440888727
#
#
# HOMO-LUMO gap: 0.0854932920907803 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.016441190440935772
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174372544
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9924399345182
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1355510403896
# Coulomb Energy                  6305.1489973352382
# Exchange-Correlation Energy     -295.0824374963674
# --------------------------------------------------
# Total Energy                   -2441.3502078946422
# --------------------------------------------------
#
#
#
# Energy difference :  6.192415730765788e-05
#
#
# HOMO-LUMO gap: 0.08609955721820034 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.007352221844129534
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173439285
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0612513832621
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745083295068
# Coulomb Energy                  6305.1841799539498
# Exchange-Correlation Energy     -295.0877760922937
# --------------------------------------------------
# Total Energy                   -2441.3502180314854
# --------------------------------------------------
#
#
#
# Energy difference :  1.0136843229702208e-05
#
#
# HOMO-LUMO gap: 0.08618092950227457 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  0.0029214855583502065
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203528
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0438967994578
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630528273063
# Coulomb Energy                  6305.1767166245008
# Exchange-Correlation Energy     -295.0862143051317
# --------------------------------------------------
# Total Energy                   -2441.3502204921660
# --------------------------------------------------
#
#
#
# Energy difference :  2.4606806618976407e-06
#
#
# HOMO-LUMO gap: 0.08626994769279402 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  0.000799041290622684
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173088249
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357871199940
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591886175652
# Coulomb Energy                  6305.1719583355243
# Exchange-Correlation Energy     -295.0857015892015
# --------------------------------------------------
# Total Energy                   -2441.3502205954919
# --------------------------------------------------
#
#
#
# Energy difference :  1.0332587407901883e-07
#
#
# HOMO-LUMO gap: 0.0862692786926702 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  0.000470859430230865
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173170845
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0330012700288
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576327764546
# Coulomb Energy                  6305.1705223012686
# Exchange-Correlation Energy     -295.0854955737897
# --------------------------------------------------
# Total Energy                   -2441.3502206054818
# --------------------------------------------------
#
#
#
# Energy difference :  9.989889804273844e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.350220605482
# -------------------------------------
#
#
#
# Time taken : 165.29 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           23.05
# Density Fitting                         5.37
#     DF (gamma)                          0.99
#     DF (coeff)                          0.18
#     DF (Jtri)                           3.8
# DIIS                                    3.58
# KS matrix diagonalization               3.6
# One electron Integrals (S, T, Vnuc)     0.15
# Coulomb Integrals (2c2e + 3c2e)         29.98
# Grids construction                      17.46
# Exchange-Correlation Term               77.8
# Misc.                                   4.3
# Complete SCF                            165.29
