# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 38.89 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 37.3 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.5 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=a27a294737ac277685660975044009c5ff2b8b80668b9542aba33fa6be72b0e8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6q1nqg7l/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 15.54 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.46 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  5.71
# Time taken to evaluate the square roots needed:  0.11
# Time for significant indices evaluation:  2.0584101460000284
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 7.88 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  6.83
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  38.21 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.87 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.42 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.5 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709560
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632574
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325736
#
#
# HOMO-LUMO gap: 2.6431079281670002 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.29 seconds
#
#
#
# Density matrix difference norm:  43.34767137041572
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  49.999994743899805
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709403
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316033
# Coulomb Energy                   501.1198589452459
# Exchange-Correlation Energy      -62.5998011282691
# --------------------------------------------------
# Total Energy                    -340.0652765782367
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851497935
#
#
# HOMO-LUMO gap: 0.0049027110609409785 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  28.612471718845526
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000098402865085
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456667
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785906
# Coulomb Energy                   293.3088657954220
# Exchange-Correlation Energy      -37.4191110537729
# --------------------------------------------------
# Total Energy                    -355.5094553813035
# --------------------------------------------------
#
#
#
# Energy difference :  15.44417880306679
#
#
# HOMO-LUMO gap: 0.04036147698809328 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.19 seconds
#
#
#
# Density matrix difference norm:  21.394016787365356
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445385
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275318
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458380
# Coulomb Energy                   367.2127830476439
# Exchange-Correlation Energy      -44.5841010136091
# --------------------------------------------------
# Total Energy                    -380.5867878035355
# --------------------------------------------------
#
#
#
# Energy difference :  25.07733242223196
#
#
# HOMO-LUMO gap: 0.018048571143158183 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  5.1974809336920345
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000006874740826
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703723
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754509
# Coulomb Energy                   364.3533796551034
# Exchange-Correlation Energy      -44.5594485029985
# --------------------------------------------------
# Total Energy                    -378.6274635986930
# --------------------------------------------------
#
#
#
# Energy difference :  1.95932420484246
#
#
# HOMO-LUMO gap: 0.08493582284753169 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  4.779285269954224
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001287711403
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186451
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180417
# Coulomb Energy                   368.1554971681546
# Exchange-Correlation Energy      -45.0868782881895
# --------------------------------------------------
# Total Energy                    -381.1270633765149
# --------------------------------------------------
#
#
#
# Energy difference :  2.4995997778218566
#
#
# HOMO-LUMO gap: 0.14183855738558282 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5205766173116435
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089467
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233184
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990106
# Coulomb Energy                   369.0647619107153
# Exchange-Correlation Energy      -45.1368862216095
# --------------------------------------------------
# Total Energy                    -381.2275584910786
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456372784
#
#
# HOMO-LUMO gap: 0.1351472390942941 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.3315886778259443
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597147
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176792
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774532
# Coulomb Energy                   369.6340156607462
# Exchange-Correlation Energy      -45.2090855965856
# --------------------------------------------------
# Total Energy                    -381.2508898319418
# --------------------------------------------------
#
#
#
# Energy difference :  0.023331340863194328
#
#
# HOMO-LUMO gap: 0.01973205738286661 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5818251308669056
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000861700552
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110799
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893513
# Coulomb Energy                   374.0898923937887
# Exchange-Correlation Energy      -45.7569321945896
# --------------------------------------------------
# Total Energy                    -381.3827647784060
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646422238
#
#
# HOMO-LUMO gap: 0.12604481221476235 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.4584549614628364
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767309
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524667
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358404
# Coulomb Energy                   377.3880704578866
# Exchange-Correlation Energy      -46.1034837100260
# --------------------------------------------------
# Total Energy                    -381.4206849246423
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623627438
#
#
# HOMO-LUMO gap: 0.1662734898614078 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.1450688651711169
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007579020874
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358484
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690267
# Coulomb Energy                   377.1736811284877
# Exchange-Correlation Energy      -46.0748895148567
# --------------------------------------------------
# Total Energy                    -381.4268823090673
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384424979191
#
#
# HOMO-LUMO gap: 0.18126074112656215 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.05574884999299144
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007425198724
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179581
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114428
# Coulomb Energy                   377.1977734128308
# Exchange-Correlation Energy      -46.0810670348487
# --------------------------------------------------
# Total Energy                    -381.4272916844096
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753423717317
#
#
# HOMO-LUMO gap: 0.18111025828119431 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.02562530605297318
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000075037254
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006539
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114248
# Coulomb Energy                   377.1502888734881
# Exchange-Correlation Energy      -46.0776486461291
# --------------------------------------------------
# Total Energy                    -381.4274184177466
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333696966438
#
#
# HOMO-LUMO gap: 0.1806839556568891 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.008432526434200043
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007500354876
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167636
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298636
# Coulomb Energy                   377.1545462611546
# Exchange-Correlation Energy      -46.0767747067597
# --------------------------------------------------
# Total Energy                    -381.4274393883815
# --------------------------------------------------
#
#
#
# Energy difference :  2.0970634921013698e-05
#
#
# HOMO-LUMO gap: 0.18067053575023134 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0018444600034530749
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750025072
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068108
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736913
# Coulomb Energy                   377.1524231958006
# Exchange-Correlation Energy      -46.0765296383163
# --------------------------------------------------
# Total Energy                    -381.4274391315117
# --------------------------------------------------
#
#
#
# Energy difference :  2.568697823335242e-07
#
#
# HOMO-LUMO gap: 0.18064597252298015 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0011511413607200082
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007498949195
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206477
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789367
# Coulomb Energy                   377.1549870542096
# Exchange-Correlation Energy      -46.0768423766161
# --------------------------------------------------
# Total Energy                    -381.4274396199939
# --------------------------------------------------
#
#
#
# Energy difference :  4.884822146777879e-07
#
#
# HOMO-LUMO gap: 0.18064256438836937 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.00010543279301210812
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836629
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081804
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075855
# Coulomb Energy                   377.1556791349410
# Exchange-Correlation Energy      -46.0769272993465
# --------------------------------------------------
# Total Energy                    -381.4274396208769
# --------------------------------------------------
#
#
#
# Energy difference :  8.829488251649309e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396208769
# -------------------------------------
#
#
#
# Time taken : 69.65 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.92
# Density Fitting                         1.38
#     DF (gamma)                          0.36
#     DF (coeff)                          0.11
#     DF (Jtri)                           0.61
# DIIS                                    0.72
# KS matrix diagonalization               0.81
# One electron Integrals (S, T, Vnuc)     15.54
# Coulomb Integrals (2c2e + 3c2e)         38.21
# Grids construction                      0.87
# Exchange-Correlation Term               5.26
# Misc.                                   3.92
# Complete SCF                            69.65

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.09 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0035697329999493377
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.07
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.66 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.96 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.92 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00135664103418
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371780
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645300015
# --------------------------------------------------
#
#
#
# Energy difference :  185.44746453000153
#
#
# HOMO-LUMO gap: 1.7654343749559396 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.6 seconds
#
#
#
# Density matrix difference norm:  66.88358764205184
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084647
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437471
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987505572
# Coulomb Energy                  1272.5954275689444
# Exchange-Correlation Energy     -125.2198694441741
# --------------------------------------------------
# Total Energy                    -680.0789187511875
# --------------------------------------------------
#
#
#
# Energy difference :  494.631454221186
#
#
# HOMO-LUMO gap: 0.00040456056760485026 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  39.275229644347675
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0012017584456
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692494143
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666727076
# Coulomb Energy                   861.6558693047111
# Exchange-Correlation Energy      -75.4419310839614
# --------------------------------------------------
# Total Energy                    -709.3563182387250
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487537423
#
#
# HOMO-LUMO gap: 0.027815605001552196 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.54 seconds
#
#
#
# Density matrix difference norm:  28.14735856433844
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663972
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672035990
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170659925
# Coulomb Energy                  1000.6400676118758
# Exchange-Correlation Energy      -87.3507096616604
# --------------------------------------------------
# Total Energy                    -733.7433460701593
# --------------------------------------------------
#
#
#
# Energy difference :  24.387027831434352
#
#
# HOMO-LUMO gap: 0.007352227197055264 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  18.10305398306813
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642282
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026565417
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102957878
# Coulomb Energy                  1039.7254935641849
# Exchange-Correlation Energy      -89.9717584580987
# --------------------------------------------------
# Total Energy                    -689.6320111374357
# --------------------------------------------------
#
#
#
# Energy difference :  44.111334932723594
#
#
# HOMO-LUMO gap: 0.01070179370763022 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  13.03426010369348
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576004
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022386749
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597397
# Coulomb Energy                  1004.3417767419367
# Exchange-Correlation Energy      -89.2334391642868
# --------------------------------------------------
# Total Energy                    -749.6400714840531
# --------------------------------------------------
#
#
#
# Energy difference :  60.00806034661741
#
#
# HOMO-LUMO gap: 0.025771351287703123 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  7.653358064505631
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554303
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132844845
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410462
# Coulomb Energy                   997.3319760641220
# Exchange-Correlation Energy      -89.6717481072339
# --------------------------------------------------
# Total Energy                    -755.2352624693181
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985264935
#
#
# HOMO-LUMO gap: 0.0035684795283292825 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  6.309738334978286
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567741
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204422560
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857162555
# Coulomb Energy                  1009.6464766741399
# Exchange-Correlation Energy      -89.9069114779909
# --------------------------------------------------
# Total Energy                    -755.2788234126199
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094330182714
#
#
# HOMO-LUMO gap: 0.009175061881962286 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  8.057132717522673
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00050300163967
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153724670
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119320887
# Coulomb Energy                  1035.0050622424069
# Exchange-Correlation Energy      -92.6658378594958
# --------------------------------------------------
# Total Energy                    -747.5712329402354
# --------------------------------------------------
#
#
#
# Energy difference :  7.7075904723844815
#
#
# HOMO-LUMO gap: 0.11766237194413628 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  7.71501342898732
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306774
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903691588
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992829786
# Coulomb Energy                  1048.9988443895224
# Exchange-Correlation Energy      -94.9610811404124
# --------------------------------------------------
# Total Energy                    -761.7908817198384
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779602949
#
#
# HOMO-LUMO gap: 0.010925426636339039 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  6.790315749138002
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.9999729437791
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412183731
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466860430
# Coulomb Energy                  1013.7508689109171
# Exchange-Correlation Energy      -90.9428726052387
# --------------------------------------------------
# Total Energy                    -756.2816521094197
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229610418629
#
#
# HOMO-LUMO gap: 0.1492973269282181 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  6.534633252481609
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202662
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716095739
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461507833
# Coulomb Energy                  1025.7750806782262
# Exchange-Correlation Energy      -92.2703810887548
# --------------------------------------------------
# Total Energy                    -762.7969797520871
# --------------------------------------------------
#
#
#
# Energy difference :  6.51532764266733
#
#
# HOMO-LUMO gap: 0.13352697868746596 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.5338338748966264
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332058
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534034
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792903213
# Coulomb Energy                  1024.7461321399833
# Exchange-Correlation Energy      -92.1885648748866
# --------------------------------------------------
# Total Energy                    -762.8402252807537
# --------------------------------------------------
#
#
#
# Energy difference :  0.043245528666602695
#
#
# HOMO-LUMO gap: 0.11056223799308833 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.3602713359598097
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916639
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590207252
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517295004
# Coulomb Energy                  1023.6379077076469
# Exchange-Correlation Energy      -92.0697499682084
# --------------------------------------------------
# Total Energy                    -762.8490034345539
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153800221844
#
#
# HOMO-LUMO gap: 0.08600353272175928 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.3252988568498836
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680044
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240864241
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261722360
# Coulomb Energy                  1024.4836887101351
# Exchange-Correlation Energy      -92.1371699397560
# --------------------------------------------------
# Total Energy                    -762.8531330265769
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592022991346
#
#
# HOMO-LUMO gap: 0.11636080747782006 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.15534224622262616
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503608
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117168532
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900055712
# Coulomb Energy                  1024.5663100625943
# Exchange-Correlation Energy      -92.1605267750444
# --------------------------------------------------
# Total Energy                    -762.8605923065002
# --------------------------------------------------
#
#
#
# Energy difference :  0.0074592799232959806
#
#
# HOMO-LUMO gap: 0.12269239243744129 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.04060711223768038
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000722186562
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080483
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362546
# Coulomb Energy                  1024.7015706722520
# Exchange-Correlation Energy      -92.1773633390776
# --------------------------------------------------
# Total Energy                    -762.8609189213873
# --------------------------------------------------
#
#
#
# Energy difference :  0.0003266148871716723
#
#
# HOMO-LUMO gap: 0.11742913475977534 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.019703163533232107
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471097
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348738291
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569370
# Coulomb Energy                  1024.5590092023651
# Exchange-Correlation Energy      -92.1602830990679
# --------------------------------------------------
# Total Energy                    -762.8609667963631
# --------------------------------------------------
#
#
#
# Energy difference :  4.7874975734885084e-05
#
#
# HOMO-LUMO gap: 0.11815573488847109 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.008211499894628039
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000074316393
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862482
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811797
# Coulomb Energy                  1024.5676148746786
# Exchange-Correlation Energy      -92.1612728329160
# --------------------------------------------------
# Total Energy                    -762.8609882460739
# --------------------------------------------------
#
#
#
# Energy difference :  2.1449710857268656e-05
#
#
# HOMO-LUMO gap: 0.11842571032230534 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.0019148361621225208
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786604
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971482
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346067
# Coulomb Energy                  1024.5642249369512
# Exchange-Correlation Energy      -92.1610088236026
# --------------------------------------------------
# Total Energy                    -762.8609886319609
# --------------------------------------------------
#
#
#
# Energy difference :  3.8588700590480585e-07
#
#
# HOMO-LUMO gap: 0.1183577160649193 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.0010776396200363632
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816392
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020017
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743151
# Coulomb Energy                  1024.5683629999169
# Exchange-Correlation Energy      -92.1613819110185
# --------------------------------------------------
# Total Energy                    -762.8609888215562
# --------------------------------------------------
#
#
#
# Energy difference :  1.895953118946636e-07
#
#
# HOMO-LUMO gap: 0.11837118338539315 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.0005041312679280268
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785556
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158286
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323482
# Coulomb Energy                  1024.5701171428855
# Exchange-Correlation Energy      -92.1615907612846
# --------------------------------------------------
# Total Energy                    -762.8609888846472
# --------------------------------------------------
#
#
#
# Energy difference :  6.30909653409617e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846472
# -------------------------------------
#
#
#
# Time taken : 19.0 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.06
# Density Fitting                         0.46
#     DF (gamma)                          0.13
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.21
# DIIS                                    0.12
# KS matrix diagonalization               0.54
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.66
# Grids construction                      0.96
# Exchange-Correlation Term               10.91
# Misc.                                   1.26
# Complete SCF                            19.0

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.08 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.24 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007336336999969717
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.28
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  10.49 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.63 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.62 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355672
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973809
# --------------------------------------------------
#
#
#
# Energy difference :  374.93033389738093
#
#
# HOMO-LUMO gap: 1.8502864435407251 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  107.82844284433196
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999855877294
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067963
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391766470
# Coulomb Energy                  3537.3287033060687
# Exchange-Correlation Energy     -250.6110528162061
# --------------------------------------------------
# Total Energy                   -1359.8923755096248
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122439
#
#
# HOMO-LUMO gap: 0.00211392164443186 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 2.2 seconds
#
#
#
# Density matrix difference norm:  57.36707021915621
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512904
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256491752
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810813019
# Coulomb Energy                  2705.3966179574436
# Exchange-Correlation Energy     -151.8752804393578
# --------------------------------------------------
# Total Energy                   -1419.0480632191266
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770950176
#
#
# HOMO-LUMO gap: 0.019740723739137017 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 2.21 seconds
#
#
#
# Density matrix difference norm:  48.047190163776015
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00017178492388
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823851723
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892853883
# Coulomb Energy                  3071.8764250117233
# Exchange-Correlation Energy     -174.7460035329295
# --------------------------------------------------
# Total Energy                   -1362.4047277903287
# --------------------------------------------------
#
#
#
# Energy difference :  56.643335428797855
#
#
# HOMO-LUMO gap: 0.014747714724819713 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 2.22 seconds
#
#
#
# Density matrix difference norm:  40.92570828259598
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158718
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198127409
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571582593
# Coulomb Energy                  3051.7165832280589
# Exchange-Correlation Energy     -176.2007428393699
# --------------------------------------------------
# Total Energy                   -1378.8564784351311
# --------------------------------------------------
#
#
#
# Energy difference :  16.45175064480236
#
#
# HOMO-LUMO gap: 0.012539973802195542 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 2.24 seconds
#
#
#
# Density matrix difference norm:  26.932582172203748
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001525386394
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022789860
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850556497
# Coulomb Energy                  3003.5375755726886
# Exchange-Correlation Energy     -179.3125720191608
# --------------------------------------------------
# Total Energy                   -1523.5033698391476
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140401651
#
#
# HOMO-LUMO gap: 0.003087494762286024 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 2.26 seconds
#
#
#
# Density matrix difference norm:  13.423370100282483
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488933
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332569302
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671362355
# Coulomb Energy                  2977.4795296021321
# Exchange-Correlation Energy     -178.1026352540005
# --------------------------------------------------
# Total Energy                   -1499.0865279419022
# --------------------------------------------------
#
#
#
# Energy difference :  24.416841897245376
#
#
# HOMO-LUMO gap: 0.03181461272771969 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  12.444575042427834
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146527
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885444673
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462463566
# Coulomb Energy                  3000.9261851727761
# Exchange-Correlation Energy     -180.8962339958011
# --------------------------------------------------
# Total Energy                   -1522.7463472904738
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348571546
#
#
# HOMO-LUMO gap: 0.012952412900283115 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  6.01641254407272
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00012192201385
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025156432
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516682294
# Coulomb Energy                  3041.7824359801075
# Exchange-Correlation Energy     -185.1339645332813
# --------------------------------------------------
# Total Energy                   -1523.4476355699258
# --------------------------------------------------
#
#
#
# Energy difference :  0.701288279452001
#
#
# HOMO-LUMO gap: 0.02147354981011257 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  6.222751705212145
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99995948810576
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888914260
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569992160
# Coulomb Energy                  3063.1248487684006
# Exchange-Correlation Energy     -185.9132949764640
# --------------------------------------------------
# Total Energy                   -1521.9201342696124
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013003133608
#
#
# HOMO-LUMO gap: 0.07988335372993602 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  4.43484852362404
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846703
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733681570
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444891016
# Coulomb Energy                  3048.3985990984056
# Exchange-Correlation Energy     -185.3448733864918
# --------------------------------------------------
# Total Energy                   -1525.5849593364801
# --------------------------------------------------
#
#
#
# Energy difference :  3.6648250668677065
#
#
# HOMO-LUMO gap: 0.11911980736778152 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.83351330998878
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000381243774
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577373044
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794724
# Coulomb Energy                  3044.2765927793689
# Exchange-Correlation Energy     -184.7849150214365
# --------------------------------------------------
# Total Energy                   -1525.7423647692385
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543275842356
#
#
# HOMO-LUMO gap: 0.10914385151725722 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.4378203336025764
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733318
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238685115
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999350044
# Coulomb Energy                  3039.9455617680055
# Exchange-Correlation Energy     -184.3161788613749
# --------------------------------------------------
# Total Energy                   -1525.7678971962155
# --------------------------------------------------
#
#
#
# Energy difference :  0.025532426976951683
#
#
# HOMO-LUMO gap: 0.08055636124778544 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.2795602287774902
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976168
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906670
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116444
# Coulomb Energy                  3041.4914846757297
# Exchange-Correlation Energy     -184.5235703798700
# --------------------------------------------------
# Total Energy                   -1525.7860021525007
# --------------------------------------------------
#
#
#
# Energy difference :  0.018104956285242224
#
#
# HOMO-LUMO gap: 0.03553321190322152 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.20188173700939713
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000406842974
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555703359
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365258017
# Coulomb Energy                  3040.7248454919381
# Exchange-Correlation Energy     -184.4775892871865
# --------------------------------------------------
# Total Energy                   -1525.7891190091204
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031168566197266045
#
#
# HOMO-LUMO gap: 0.0448708948660658 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.0762529310470524
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396572362
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379110738
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103367
# Coulomb Energy                  3040.4560830346381
# Exchange-Correlation Energy     -184.4308753791033
# --------------------------------------------------
# Total Energy                   -1525.7902311145408
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011121054203613312
#
#
# HOMO-LUMO gap: 0.05285664136818577 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.02837208362028047
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000394713102
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669641798
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980822
# Coulomb Energy                  3040.4602645949963
# Exchange-Correlation Energy     -184.4309026475808
# --------------------------------------------------
# Total Energy                   -1525.7903707880196
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967347877041902
#
#
# HOMO-LUMO gap: 0.049948127440745074 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.012785251243057065
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505607
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931032
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318107
# Coulomb Energy                  3040.4067159125693
# Exchange-Correlation Energy     -184.4260067735651
# --------------------------------------------------
# Total Energy                   -1525.7903870916275
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303607935697073e-05
#
#
# HOMO-LUMO gap: 0.05083365573047399 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.006040021432705748
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112016
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954634
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920682
# Coulomb Energy                  3040.4581957845103
# Exchange-Correlation Energy     -184.4326037898902
# --------------------------------------------------
# Total Energy                   -1525.7903978781133
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786485745484242e-05
#
#
# HOMO-LUMO gap: 0.05068603589627459 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.0019655407508588187
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396237854
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801127018
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451697
# Coulomb Energy                  3040.4659355248750
# Exchange-Correlation Energy     -184.4328301188933
# --------------------------------------------------
# Total Energy                   -1525.7903988308881
# --------------------------------------------------
#
#
#
# Energy difference :  9.527748261461966e-07
#
#
# HOMO-LUMO gap: 0.050712621256349746 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.0010394322811080954
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396178037
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447101
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272610824
# Coulomb Energy                  3040.4701320976019
# Exchange-Correlation Energy     -184.4333553536711
# --------------------------------------------------
# Total Energy                   -1525.7903988090347
# --------------------------------------------------
#
#
#
# Energy difference :  2.185333869419992e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090347
# -------------------------------------
#
#
#
# Time taken : 73.29 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.8
# Density Fitting                         1.3
#     DF (gamma)                          0.27
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.83
# DIIS                                    0.57
# KS matrix diagonalization               1.03
# One electron Integrals (S, T, Vnuc)     0.08
# Coulomb Integrals (2c2e + 3c2e)         10.49
# Grids construction                      4.63
# Exchange-Correlation Term               44.87
# Misc.                                   2.53
# Complete SCF                            73.29

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.14 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.5 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.09
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.021369645999925524
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.7
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.78 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.17 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 21.36 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.4 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0029198407821
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004625
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513683
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513683
#
#
# HOMO-LUMO gap: 1.345317476162788 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  144.0140638686302
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99996720715313
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016248049
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642081332
# Coulomb Energy                  7102.4006978647212
# Exchange-Correlation Energy     -401.0386878050859
# --------------------------------------------------
# Total Energy                   -2175.7881061964217
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450534
#
#
# HOMO-LUMO gap: 0.0036326528166029104 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 5.67 seconds
#
#
#
# Density matrix difference norm:  71.99427239659911
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247208
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645627094
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936237
# Coulomb Energy                  5771.7138319757305
# Exchange-Correlation Energy     -243.8524720616941
# --------------------------------------------------
# Total Energy                   -2274.5129129944344
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679801265
#
#
# HOMO-LUMO gap: 0.004964611535143826 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  58.10070148973579
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00214404156077
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804047088
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573470121
# Coulomb Energy                  6321.7172809543963
# Exchange-Correlation Energy     -278.3781618573475
# --------------------------------------------------
# Total Energy                   -2158.4748828000347
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019439965
#
#
# HOMO-LUMO gap: 0.014474030563008028 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 5.83 seconds
#
#
#
# Density matrix difference norm:  53.36997549229432
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00180767720946
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768213797
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230008957
# Coulomb Energy                  6361.2336350674486
# Exchange-Correlation Energy     -281.9436333441363
# --------------------------------------------------
# Total Energy                   -2182.5642309365558
# --------------------------------------------------
#
#
#
# Energy difference :  24.08934813652104
#
#
# HOMO-LUMO gap: 0.00884169399717244 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 5.91 seconds
#
#
#
# Density matrix difference norm:  42.839015094803464
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00099084148945
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446994025
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382081089
# Coulomb Energy                  6294.5110601796187
# Exchange-Correlation Energy     -283.9707682331659
# --------------------------------------------------
# Total Energy                   -2345.8009933842277
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676244767194
#
#
# HOMO-LUMO gap: 0.007160714250181305 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 5.95 seconds
#
#
#
# Density matrix difference norm:  32.18186260033334
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99978638551784
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019080853
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650761347
# Coulomb Energy                  6214.1516556244642
# Exchange-Correlation Energy     -284.6344014151280
# --------------------------------------------------
# Total Energy                   -2343.5239614619986
# --------------------------------------------------
#
#
#
# Energy difference :  2.277031922229071
#
#
# HOMO-LUMO gap: 0.0024503750091918186 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 5.91 seconds
#
#
#
# Density matrix difference norm:  33.32333313980164
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00086081565115
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115036565
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996834098
# Coulomb Energy                  6284.6237009945735
# Exchange-Correlation Energy     -286.3084442723563
# --------------------------------------------------
# Total Energy                   -2352.7413339374152
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372475416596
#
#
# HOMO-LUMO gap: 0.006673318413629475 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 5.85 seconds
#
#
#
# Density matrix difference norm:  26.098281915751922
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026797845874
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383689051
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896551835
# Coulomb Energy                  6418.8046173139801
# Exchange-Correlation Energy     -305.3162932885934
# --------------------------------------------------
# Total Energy                   -2410.9382035277222
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686959030696
#
#
# HOMO-LUMO gap: 0.00796053957540041 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  17.534698642320567
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855086
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057222233
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201842559
# Coulomb Energy                  6329.9135850831744
# Exchange-Correlation Energy     -297.7524519055968
# --------------------------------------------------
# Total Energy                   -2373.3942311997753
# --------------------------------------------------
#
#
#
# Energy difference :  37.5439723279469
#
#
# HOMO-LUMO gap: 0.013997838581186486 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  16.42070464478525
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.999823798323
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814598826
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928315323
# Coulomb Energy                  6324.0705156542044
# Exchange-Correlation Energy     -296.6169927420707
# --------------------------------------------------
# Total Energy                   -2423.4444445556019
# --------------------------------------------------
#
#
#
# Energy difference :  50.0502133558266
#
#
# HOMO-LUMO gap: 0.005801716897357381 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  17.91362907363742
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008255772794
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871580439
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553244013
# Coulomb Energy                  6269.4959589833825
# Exchange-Correlation Energy     -292.3687260433697
# --------------------------------------------------
# Total Energy                   -2388.5334777330145
# --------------------------------------------------
#
#
#
# Energy difference :  34.9109668225874
#
#
# HOMO-LUMO gap: 0.011739724655692424 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  18.86481092855284
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000895342889
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999717955
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986961133
# Coulomb Energy                  6304.9912271470712
# Exchange-Correlation Energy     -292.7049362976231
# --------------------------------------------------
# Total Energy                   -2419.7690892656192
# --------------------------------------------------
#
#
#
# Energy difference :  31.235611532604707
#
#
# HOMO-LUMO gap: 0.0016995925779307863 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  14.26893860169336
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015431500486
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930493013
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204714836
# Coulomb Energy                  6279.2250589571677
# Exchange-Correlation Energy     -293.0502585447679
# --------------------------------------------------
# Total Energy                   -2419.7439510048034
# --------------------------------------------------
#
#
#
# Energy difference :  0.025138260815765534
#
#
# HOMO-LUMO gap: 0.005846431235301736 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  12.512861011094405
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002651218397
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104164425
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140353021
# Coulomb Energy                  6304.4543925181661
# Exchange-Correlation Energy     -294.2073055525648
# --------------------------------------------------
# Total Energy                   -2431.0698882549259
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937250122479
#
#
# HOMO-LUMO gap: 0.016452349579942446 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  10.313139444496418
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775194
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763846793
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614202370
# Coulomb Energy                  6320.4324015784532
# Exchange-Correlation Energy     -296.9899338053031
# --------------------------------------------------
# Total Energy                   -2429.5155260306783
# --------------------------------------------------
#
#
#
# Energy difference :  1.5543622242475976
#
#
# HOMO-LUMO gap: 0.005064351088113872 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  8.084972669720155
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0000976405892
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466556947
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611227283
# Coulomb Energy                  6316.3510406969581
# Exchange-Correlation Energy     -296.7435745388096
# --------------------------------------------------
# Total Energy                   -2437.9484982142039
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972183525635
#
#
# HOMO-LUMO gap: 0.05893038881350489 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  4.102604850129729
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001181061177
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030009812
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451740911
# Coulomb Energy                  6313.1881517247457
# Exchange-Correlation Energy     -295.9055099898196
# --------------------------------------------------
# Total Energy                   -2441.0025949313494
# --------------------------------------------------
#
#
#
# Energy difference :  3.0540967171455122
#
#
# HOMO-LUMO gap: 0.005337250422868187 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  6.254076481045388
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361986995
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051593469
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545140203
# Coulomb Energy                  6280.4277633793045
# Exchange-Correlation Energy     -293.2139724471720
# --------------------------------------------------
# Total Energy                   -2436.9286385525811
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956378768344
#
#
# HOMO-LUMO gap: 0.011871839870565101 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  7.413375411164795
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026335587484
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726555012719
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918875343
# Coulomb Energy                  6298.7681987452543
# Exchange-Correlation Energy     -294.0996241352664
# --------------------------------------------------
# Total Energy                   -2439.1315678431347
# --------------------------------------------------
#
#
#
# Energy difference :  2.202929290553584
#
#
# HOMO-LUMO gap: 0.1036299979575068 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  4.188397589767872
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011624361326
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485020913
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696462437
# Coulomb Energy                  6305.6013415989455
# Exchange-Correlation Energy     -295.1700654130329
# --------------------------------------------------
# Total Energy                   -2441.2043815093202
# --------------------------------------------------
#
#
#
# Energy difference :  2.0728136661855388
#
#
# HOMO-LUMO gap: 0.030358347409143484 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 5.79 seconds
#
#
#
# Density matrix difference norm:  1.0881186800456062
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00010584350065
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355864739
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042578089
# Coulomb Energy                  6306.4146008198268
# Exchange-Correlation Energy     -295.1986114172059
# --------------------------------------------------
# Total Energy                   -2441.2281207654278
# --------------------------------------------------
#
#
#
# Energy difference :  0.02373925610754668
#
#
# HOMO-LUMO gap: 0.10156738658381192 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 5.79 seconds
#
#
#
# Density matrix difference norm:  0.6147083203271884
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000113864789
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391406587
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706634716
# Coulomb Energy                  6305.3788664341073
# Exchange-Correlation Energy     -295.1059315048552
# --------------------------------------------------
# Total Energy                   -2441.3391123873198
# --------------------------------------------------
#
#
#
# Energy difference :  0.11099162189202616
#
#
# HOMO-LUMO gap: 0.1291442051529129 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 5.79 seconds
#
#
#
# Density matrix difference norm:  0.22866753088342553
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001129709716
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680215998771
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454864596
# Coulomb Energy                  6306.4753103345865
# Exchange-Correlation Energy     -295.2425453764578
# --------------------------------------------------
# Total Energy                   -2441.3433899946740
# --------------------------------------------------
#
#
#
# Energy difference :  0.004277607354197244
#
#
# HOMO-LUMO gap: 0.119140927207539 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 5.79 seconds
#
#
#
# Density matrix difference norm:  0.13316828795100072
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924006
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663338654
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009442993
# Coulomb Energy                  6305.4375957444463
# Exchange-Correlation Energy     -295.1178679621063
# --------------------------------------------------
# Total Energy                   -2441.3482164466113
# --------------------------------------------------
#
#
#
# Energy difference :  0.0048264519373333314
#
#
# HOMO-LUMO gap: 0.0775860996125074 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.16794684453555783
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001191827323
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810436980
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356933221
# Coulomb Energy                  6304.4474550012119
# Exchange-Correlation Energy     -294.9863691580970
# --------------------------------------------------
# Total Energy                   -2441.3482383466462
# --------------------------------------------------
#
#
#
# Energy difference :  2.1900034880673047e-05
#
#
# HOMO-LUMO gap: 0.08220407415498525 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 5.79 seconds
#
#
#
# Density matrix difference norm:  0.08195634565345067
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011761289034
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560673309
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184233437
# Coulomb Energy                  6305.2666287326228
# Exchange-Correlation Energy     -295.0991774795898
# --------------------------------------------------
# Total Energy                   -2441.3500652303392
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836929564714
#
#
# HOMO-LUMO gap: 0.0868139324744069 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.030947650083893302
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011717111363
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449609356
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969467171
# Coulomb Energy                  6305.1999901384352
# Exchange-Correlation Energy     -295.0882138897888
# --------------------------------------------------
# Total Energy                   -2441.3501506049579
# --------------------------------------------------
#
#
#
# Energy difference :  8.537461872037966e-05
#
#
# HOMO-LUMO gap: 0.08605512219040712 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  0.015359420150869604
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174124386
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082986478
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754508931
# Coulomb Energy                  6305.1611656009518
# Exchange-Correlation Energy     -295.0851653175738
# --------------------------------------------------
# Total Energy                   -2441.3502114037619
# --------------------------------------------------
#
#
#
# Energy difference :  6.0798804042860866e-05
#
#
# HOMO-LUMO gap: 0.08610559554970476 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.005850728297833449
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730802623
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341357896
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624064474
# Coulomb Energy                  6305.1739654234379
# Exchange-Correlation Energy     -295.0859344062367
# --------------------------------------------------
# Total Energy                   -2441.3502195515275
# --------------------------------------------------
#
#
#
# Energy difference :  8.14776558399899e-06
#
#
# HOMO-LUMO gap: 0.08627753380262118 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.002268765569932948
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173037931
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171301777
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318742
# Coulomb Energy                  6305.1767750460131
# Exchange-Correlation Energy     -295.0862921108222
# --------------------------------------------------
# Total Energy                   -2441.3502203024982
# --------------------------------------------------
#
#
#
# Energy difference :  7.509706847486086e-07
#
#
# HOMO-LUMO gap: 0.08629954674324344 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.0014216232846801524
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731611824
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335500163
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841015192
# Coulomb Energy                  6305.1678310988627
# Exchange-Correlation Energy     -295.0851232567530
# --------------------------------------------------
# Total Energy                   -2441.3502204457727
# --------------------------------------------------
#
#
#
# Energy difference :  1.4327451935969293e-07
#
#
# HOMO-LUMO gap: 0.08625864034172187 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.0007905213660717977
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731926696
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906318962
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598279
# Coulomb Energy                  6305.1716231998980
# Exchange-Correlation Energy     -295.0855737005000
# --------------------------------------------------
# Total Energy                   -2441.3502206120556
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628291632514447e-07
#
#
# HOMO-LUMO gap: 0.08626853544497068 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  0.0002863202178233544
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731389486
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851890410
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651371089
# Coulomb Energy                  6305.1740152928451
# Exchange-Correlation Energy     -295.0859370217369
# --------------------------------------------------
# Total Energy                   -2441.3502206202102
# --------------------------------------------------
#
#
#
# Energy difference :  8.154529496096075e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.35022062021
# -------------------------------------
#
#
#
# Time taken : 268.25 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.76
# Density Fitting                         5.77
#     DF (gamma)                          1.07
#     DF (coeff)                          0.16
#     DF (Jtri)                           4.14
# DIIS                                    3.8
# KS matrix diagonalization               3.83
# One electron Integrals (S, T, Vnuc)     0.14
# Coulomb Integrals (2c2e + 3c2e)         29.78
# Grids construction                      16.17
# Exchange-Correlation Term               182.3
# Misc.                                   4.7
# Complete SCF                            268.25

# %% [markdown]
# ### Benchmark #4 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.21 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.91 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.16
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.044960684999978184
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.21 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  1.48
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  68.0 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 50.17 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 55.88 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.4 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00086590367755
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182483
# Exchange-Correlation Energy     -158.3094688039744
# --------------------------------------------------
# Total Energy                    -881.4876584497651
# --------------------------------------------------
#
#
#
# Energy difference :  881.4876584497651
#
#
# HOMO-LUMO gap: 0.6897308990670843 au
# HOMO-LUMO gap: 18.768 eV
#
#
# Time taken for the previous iteration: 13.98 seconds
#
#
#
# Density matrix difference norm:  177.41183356976438
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99994638079426
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3704438288441
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5625483776730
# Coulomb Energy                 12707.6655166371929
# Exchange-Correlation Energy     -589.0109863899920
# --------------------------------------------------
# Total Energy                   -3195.6961127770501
# --------------------------------------------------
#
#
#
# Energy difference :  2314.208454327285
#
#
# HOMO-LUMO gap: 0.0026210885490095537 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 14.32 seconds
#
#
#
# Density matrix difference norm:  86.10072559735215
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006718457629
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.0784549160235
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9542974309802
# Coulomb Energy                 10864.6104283848836
# Exchange-Correlation Energy     -358.7264210078202
# --------------------------------------------------
# Total Energy                   -3357.7828976810579
# --------------------------------------------------
#
#
#
# Energy difference :  162.0867849040078
#
#
# HOMO-LUMO gap: 0.0025322925277960553 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 14.15 seconds
#
#
#
# Density matrix difference norm:  65.13264429182131
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00008159556376
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9266970299213
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4589790565801
# Coulomb Energy                 11125.2421950893786
# Exchange-Correlation Energy     -407.6867498869209
# --------------------------------------------------
# Total Energy                   -3374.4550203439612
# --------------------------------------------------
#
#
#
# Energy difference :  16.672122662903348
#
#
# HOMO-LUMO gap: 0.004414389956785975 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 13.97 seconds
#
#
#
# Density matrix difference norm:  63.85668121070311
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99953484298385
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.2877136081734
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.8757373779586
# Coulomb Energy                 12063.6748125256963
# Exchange-Correlation Energy     -415.0710986786657
# --------------------------------------------------
# Total Energy                   -3056.3510099562609
# --------------------------------------------------
#
#
#
# Energy difference :  318.1040103877003
#
#
# HOMO-LUMO gap: 0.006644147330571698 au
# HOMO-LUMO gap: 0.181 eV
#
#
# Time taken for the previous iteration: 13.92 seconds
#
#
#
# Density matrix difference norm:  54.59169061261299
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00026913529393
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.5088611891078
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.3924608746056
# Coulomb Energy                 11512.9997141049644
# Exchange-Correlation Energy     -417.4553406801024
# --------------------------------------------------
# Total Energy                   -3536.1147744627178
# --------------------------------------------------
#
#
#
# Energy difference :  479.76376450645694
#
#
# HOMO-LUMO gap: 0.0010123614968667342 au
# HOMO-LUMO gap: 0.028 eV
#
#
# Time taken for the previous iteration: 13.99 seconds
#
#
#
# Density matrix difference norm:  51.11495004627769
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99974294779855
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.1797883161926
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.7800541093311
# Coulomb Energy                 11567.1010375735041
# Exchange-Correlation Energy     -419.4337655479777
# --------------------------------------------------
# Total Energy                   -3074.2752097544144
# --------------------------------------------------
#
#
#
# Energy difference :  461.83956470830344
#
#
# HOMO-LUMO gap: 0.004697471660524796 au
# HOMO-LUMO gap: 0.128 eV
#
#
# Time taken for the previous iteration: 14.05 seconds
#
#
#
# Density matrix difference norm:  44.74482645454006
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996550749723
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.4126884115067
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6364207740003
# Coulomb Energy                 11495.5483931934723
# Exchange-Correlation Energy     -423.7795770219414
# --------------------------------------------------
# Total Energy                   -3532.5501990390530
# --------------------------------------------------
#
#
#
# Energy difference :  458.27498928463865
#
#
# HOMO-LUMO gap: 0.0004633975953907826 au
# HOMO-LUMO gap: 0.013 eV
#
#
# Time taken for the previous iteration: 14.14 seconds
#
#
#
# Density matrix difference norm:  20.71273843492698
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999545434492
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.2739432698218
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.0351193126780
# Coulomb Energy                 11580.0530324228894
# Exchange-Correlation Energy     -439.2769213928692
# --------------------------------------------------
# Total Energy                   -3535.0054605002024
# --------------------------------------------------
#
#
#
# Energy difference :  2.455261461149348
#
#
# HOMO-LUMO gap: 0.007602899100977806 au
# HOMO-LUMO gap: 0.207 eV
#
#
# Time taken for the previous iteration: 14.21 seconds
#
#
#
# Density matrix difference norm:  17.829781633033765
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00025109396597
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28135.5805669111578
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3632.4560411678599
# Coulomb Energy                 11640.5650664767600
# Exchange-Correlation Energy     -443.9779460150031
# --------------------------------------------------
# Total Energy                   -3536.0801528546162
# --------------------------------------------------
#
#
#
# Energy difference :  1.0746923544138554
#
#
# HOMO-LUMO gap: 0.004336286077932766 au
# HOMO-LUMO gap: 0.118 eV
#
#
# Time taken for the previous iteration: 14.21 seconds
#
#
#
# Density matrix difference norm:  21.75078771470108
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000976497017
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27873.9019925607899
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3557.6224523503379
# Coulomb Energy                 11493.5519514034968
# Exchange-Correlation Energy     -433.3671342162402
# --------------------------------------------------
# Total Energy                   -3485.6374705962753
# --------------------------------------------------
#
#
#
# Energy difference :  50.44268225834094
#
#
# HOMO-LUMO gap: 0.017999781665502868 au
# HOMO-LUMO gap: 0.490 eV
#
#
# Time taken for the previous iteration: 14.17 seconds
#
#
#
# Density matrix difference norm:  18.304820007456374
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001218986373
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28089.3481558310268
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3573.7337556578709
# Coulomb Energy                 11601.6672610947517
# Exchange-Correlation Energy     -437.8374210828487
# --------------------------------------------------
# Total Energy                   -3581.3273077343292
# --------------------------------------------------
#
#
#
# Energy difference :  95.68983713805392
#
#
# HOMO-LUMO gap: 0.009809885490249384 au
# HOMO-LUMO gap: 0.267 eV
#
#
# Time taken for the previous iteration: 14.11 seconds
#
#
#
# Density matrix difference norm:  15.6035909583195
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00000844554506
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27851.1830277792542
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3504.4630744290207
# Coulomb Energy                 11481.6334492443548
# Exchange-Correlation Energy     -426.3111912604364
# --------------------------------------------------
# Total Energy                   -3520.9404429393944
# --------------------------------------------------
#
#
#
# Energy difference :  60.38686479493481
#
#
# HOMO-LUMO gap: 0.00128248256762932 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 14.09 seconds
#
#
#
# Density matrix difference norm:  15.434069867745729
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99987880337915
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27993.2533770415357
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3536.1983083453088
# Coulomb Energy                 11535.6719772869255
# Exchange-Correlation Energy     -432.7365139813373
# --------------------------------------------------
# Total Energy                   -3583.6623529637163
# --------------------------------------------------
#
#
#
# Energy difference :  62.721910024321915
#
#
# HOMO-LUMO gap: 0.004883590897068482 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 14.11 seconds
#
#
#
# Density matrix difference norm:  4.995181637154364
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000251702021
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27981.3353269022700
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9571886993535
# Coulomb Energy                 11529.5195428799398
# Exchange-Correlation Energy     -431.6645536888102
# --------------------------------------------------
# Total Energy                   -3583.0658965848634
# --------------------------------------------------
#
#
#
# Energy difference :  0.5964563788529631
#
#
# HOMO-LUMO gap: 0.04720515587815363 au
# HOMO-LUMO gap: 1.285 eV
#
#
# Time taken for the previous iteration: 14.14 seconds
#
#
#
# Density matrix difference norm:  4.204244759940505
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000029439388
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27999.1239635259117
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.4625397527075
# Coulomb Energy                 11537.2109867284453
# Exchange-Correlation Energy     -433.3658591766680
# --------------------------------------------------
# Total Energy                   -3585.3590437945040
# --------------------------------------------------
#
#
#
# Energy difference :  2.293147209640665
#
#
# HOMO-LUMO gap: 0.10565060525552677 au
# HOMO-LUMO gap: 2.875 eV
#
#
# Time taken for the previous iteration: 14.14 seconds
#
#
#
# Density matrix difference norm:  0.9287339340197515
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001987441624
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1957005032673
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.6973777090557
# Coulomb Energy                 11540.9990082303357
# Exchange-Correlation Energy     -433.6709885213838
# --------------------------------------------------
# Total Energy                   -3585.7130506583344
# --------------------------------------------------
#
#
#
# Energy difference :  0.3540068638303637
#
#
# HOMO-LUMO gap: 0.081601769026615 au
# HOMO-LUMO gap: 2.220 eV
#
#
# Time taken for the previous iteration: 14.16 seconds
#
#
#
# Density matrix difference norm:  0.47099492504442564
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000154375377
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27997.2512008911071
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3537.3766042649204
# Coulomb Energy                 11536.7451395756925
# Exchange-Correlation Energy     -433.0466479911406
# --------------------------------------------------
# Total Energy                   -3585.7188526147111
# --------------------------------------------------
#
#
#
# Energy difference :  0.005801956376672024
#
#
# HOMO-LUMO gap: 0.09622541676227048 au
# HOMO-LUMO gap: 2.618 eV
#
#
# Time taken for the previous iteration: 14.15 seconds
#
#
#
# Density matrix difference norm:  0.25345657951682443
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001674477966
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.5564265213143
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5447395259234
# Coulomb Energy                 11540.2918406903118
# Exchange-Correlation Energy     -433.4718308675797
# --------------------------------------------------
# Total Energy                   -3585.7344247457386
# --------------------------------------------------
#
#
#
# Energy difference :  0.015572131027511205
#
#
# HOMO-LUMO gap: 0.10308245703241588 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 14.15 seconds
#
#
#
# Density matrix difference norm:  0.10396166338903487
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000172884528
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6842589919943
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6972361747917
# Coulomb Energy                 11539.1501776082878
# Exchange-Correlation Energy     -433.3563238468165
# --------------------------------------------------
# Total Energy                   -3585.7359166288097
# --------------------------------------------------
#
#
#
# Energy difference :  0.0014918830711394548
#
#
# HOMO-LUMO gap: 0.10375679444990578 au
# HOMO-LUMO gap: 2.823 eV
#
#
# Time taken for the previous iteration: 14.16 seconds
#
#
#
# Density matrix difference norm:  0.045809362544062246
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163999439
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0103516590971
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8693000418225
# Coulomb Energy                 11539.3276465170165
# Exchange-Correlation Energy     -433.3803352181560
# --------------------------------------------------
# Total Energy                   -3585.7364878914941
# --------------------------------------------------
#
#
#
# Energy difference :  0.0005712626843887847
#
#
# HOMO-LUMO gap: 0.10309625428857191 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 14.15 seconds
#
#
#
# Density matrix difference norm:  0.029554317271788498
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001635067485
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8156482407358
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7421798057867
# Coulomb Energy                 11539.2423484227311
# Exchange-Correlation Energy     -433.3626933893050
# --------------------------------------------------
# Total Energy                   -3585.7365609746012
# --------------------------------------------------
#
#
#
# Energy difference :  7.308310705411714e-05
#
#
# HOMO-LUMO gap: 0.10314551108647069 au
# HOMO-LUMO gap: 2.807 eV
#
#
# Time taken for the previous iteration: 14.12 seconds
#
#
#
# Density matrix difference norm:  0.01795940017921044
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000161248513
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0456961456730
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8499452778879
# Coulomb Energy                 11539.3793324641410
# Exchange-Correlation Energy     -433.3773972607028
# --------------------------------------------------
# Total Energy                   -3585.7365632374222
# --------------------------------------------------
#
#
#
# Energy difference :  2.262820999021642e-06
#
#
# HOMO-LUMO gap: 0.103202257694075 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 14.12 seconds
#
#
#
# Density matrix difference norm:  0.01013019825714102
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001623811556
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9409515299267
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096975069730
# Coulomb Energy                 11539.3092434327627
# Exchange-Correlation Energy     -433.3718359105562
# --------------------------------------------------
# Total Energy                   -3585.7365940738255
# --------------------------------------------------
#
#
#
# Energy difference :  3.0836403311695904e-05
#
#
# HOMO-LUMO gap: 0.10326233784129157 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.12 seconds
#
#
#
# Density matrix difference norm:  0.0030654439842334553
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001629087467
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9648930344047
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8217790785784
# Coulomb Energy                 11539.3227881257553
# Exchange-Correlation Energy     -433.3735230058260
# --------------------------------------------------
# Total Energy                   -3585.7365964089749
# --------------------------------------------------
#
#
#
# Energy difference :  2.335149474674836e-06
#
#
# HOMO-LUMO gap: 0.10324998824147139 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.13 seconds
#
#
#
# Density matrix difference norm:  0.0010174382011035193
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162754852
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9526818578670
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8145317590424
# Coulomb Energy                 11539.3168310524816
# Exchange-Correlation Energy     -433.3725300793237
# --------------------------------------------------
# Total Energy                   -3585.7365966987436
# --------------------------------------------------
#
#
#
# Energy difference :  2.8976864996366203e-07
#
#
# HOMO-LUMO gap: 0.10323606098366923 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 14.12 seconds
#
#
#
# Density matrix difference norm:  0.0003763301419038985
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001627333927
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9484625847836
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8126747878650
# Coulomb Energy                 11539.3142180562136
# Exchange-Correlation Energy     -433.3722793835858
# --------------------------------------------------
# Total Energy                   -3585.7365966973684
# --------------------------------------------------
#
#
#
# Energy difference :  1.3751559890806675e-09
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.7365966973684
# -------------------------------------
#
#
#
# Time taken : 559.98 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           56.28
# Density Fitting                         11.84
#     DF (gamma)                          2.49
#     DF (coeff)                          0.19
#     DF (Jtri)                           8.49
# DIIS                                    8.29
# KS matrix diagonalization               6.77
# One electron Integrals (S, T, Vnuc)     0.21
# Coulomb Integrals (2c2e + 3c2e)         68.0
# Grids construction                      50.17
# Exchange-Correlation Term               353.44
# Misc.                                   4.98
# Complete SCF                            559.98

# %% [markdown]
# ## Dynamic Precision On

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.03 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.04 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0008355400000255031
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.04
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.83 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.3 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.56 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.05 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000355
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709561
# Exchange-Correlation Energy      -16.0363502502441
# --------------------------------------------------
# Total Energy                     -93.1572655540415
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726555404154
#
#
# HOMO-LUMO gap: 2.6432308932682975 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.05 seconds
#
#
#
# Density matrix difference norm:  43.347376950418706
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999992
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065134268044
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632901411539
# Coulomb Energy                   501.1179499873556
# Exchange-Correlation Energy      -62.5998153686523
# --------------------------------------------------
# Total Energy                    -340.0671116228236
# --------------------------------------------------
#
#
#
# Energy difference :  246.9098460687821
#
#
# HOMO-LUMO gap: 0.004895001056175685 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  28.61225137831314
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000107
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015434342988
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404486356373
# Coulomb Energy                   293.3105327790037
# Exchange-Correlation Energy      -37.4191284179688
# --------------------------------------------------
# Total Energy                    -355.5117133935030
# --------------------------------------------------
#
#
#
# Energy difference :  15.444601770679355
#
#
# HOMO-LUMO gap: 0.04090611597341923 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.14 seconds
#
#
#
# Density matrix difference norm:  21.394380435687314
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6802048744826
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079158470769
# Coulomb Energy                   367.2116081156428
# Exchange-Correlation Energy      -44.5831108093262
# --------------------------------------------------
# Total Energy                    -380.5858146769656
# --------------------------------------------------
#
#
#
# Energy difference :  25.074101283462596
#
#
# HOMO-LUMO gap: 0.018045819534167083 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  5.193655309007464
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853211394354
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987312449194
# Coulomb Energy                   364.3594842203918
# Exchange-Correlation Energy      -44.5593338012695
# --------------------------------------------------
# Total Energy                    -378.6284624312702
# --------------------------------------------------
#
#
#
# Energy difference :  1.957352245695347
#
#
# HOMO-LUMO gap: 0.0849750622416463 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  4.776044383077249
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000023
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113353910820
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536993637209
# Coulomb Energy                   368.1595786044310
# Exchange-Correlation Energy      -45.0864906311035
# --------------------------------------------------
# Total Energy                    -381.1265710099101
# --------------------------------------------------
#
#
#
# Energy difference :  2.498108578639858
#
#
# HOMO-LUMO gap: 0.14153440093746594 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.5199018206079693
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759870186067
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620529814553
# Coulomb Energy                   369.0651872518389
# Exchange-Correlation Energy      -45.1361846923828
# --------------------------------------------------
# Total Energy                    -381.2269544335717
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038342366163988
#
#
# HOMO-LUMO gap: 0.1350579305185475 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.3314182211292999
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685883045524
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352932575385
# Coulomb Energy                   369.6332915647348
# Exchange-Correlation Energy      -45.2082252502441
# --------------------------------------------------
# Total Energy                    -381.2502516883998
# --------------------------------------------------
#
#
#
# Energy difference :  0.02329725482803724
#
#
# HOMO-LUMO gap: 0.01948112047485348 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.5819574011122615
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471076686416
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753380205180
# Coulomb Energy                   374.0875565365480
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611101766
# --------------------------------------------------
#
#
#
# Energy difference :  0.1318094217768362
#
#
# HOMO-LUMO gap: 0.12602028669953952 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.4597239776004758
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167311183035
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482981739539
# Coulomb Energy                   377.3936785488585
# Exchange-Correlation Energy      -46.1032257080078
# --------------------------------------------------
# Total Energy                    -381.4200030593754
# --------------------------------------------------
#
#
#
# Energy difference :  0.03794194919879601
#
#
# HOMO-LUMO gap: 0.16611333053488977 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.14506670258807747
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6774115562371
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4957003907911
# Coulomb Energy                   377.1713417801308
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261838450979
# --------------------------------------------------
#
#
#
# Energy difference :  0.0061807857225062435
#
#
# HOMO-LUMO gap: 0.18109750595325272 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.14 seconds
#
#
#
# Density matrix difference norm:  0.05597038785645047
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466991731289
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5465057500078
# Coulomb Energy                   377.1955793525879
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266045251891
# --------------------------------------------------
#
#
#
# Energy difference :  0.00042068009116746907
#
#
# HOMO-LUMO gap: 0.18093185637996154 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.02562453978065425
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6791043635553
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228770244454
# Coulomb Energy                   377.1480814133118
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267298557957
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012533060657915485
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050730665205184 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.008410601201032632
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749481869
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758646249923
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145535863807
# Coulomb Energy                   377.1522588566475
# Exchange-Correlation Energy      -46.0763604882690
# --------------------------------------------------
# Total Energy                    -381.4274356261096
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007057703139139448
#
#
# HOMO-LUMO gap: 0.18055941774667875 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0026418714061183955
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503209495
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547069029709
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032889737187
# Coulomb Energy                   377.1410365648671
# Exchange-Correlation Energy      -46.0750325767574
# --------------------------------------------------
# Total Energy                    -381.4274368970189
# --------------------------------------------------
#
#
#
# Energy difference :  1.2709093084595224e-06
#
#
# HOMO-LUMO gap: 0.18056583448654562 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0017678391932895317
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749795148
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715784380226
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117381337681
# Coulomb Energy                   377.1506250231096
# Exchange-Correlation Energy      -46.0761996769599
# --------------------------------------------------
# Total Energy                    -381.4274379139814
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169624715672398e-06
#
#
# HOMO-LUMO gap: 0.18057810005493083 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.001826394481498423
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074943385
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890954308215
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201163633808
# Coulomb Energy                   377.1610739046045
# Exchange-Correlation Energy      -46.0775109642905
# --------------------------------------------------
# Total Energy                    -381.4274390830031
# --------------------------------------------------
#
#
#
# Energy difference :  1.1690217434079386e-06
#
#
# HOMO-LUMO gap: 0.1806905172165675 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0015078228593276071
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007497971
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793142630881
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150718660079
# Coulomb Energy                   377.1557642489230
# Exchange-Correlation Energy      -46.0769384584160
# --------------------------------------------------
# Total Energy                    -381.4274395624496
# --------------------------------------------------
#
#
#
# Energy difference :  4.794464985025115e-07
#
#
# HOMO-LUMO gap: 0.18064424248421415 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0004667166770824588
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007498303724
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995819663
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900979607
# Coulomb Energy                   377.1550630969101
# Exchange-Correlation Energy      -46.0768702751828
# --------------------------------------------------
# Total Energy                    -381.4274396181547
# --------------------------------------------------
#
#
#
# Energy difference :  5.5705129398120334e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396181547
# -------------------------------------
#
#
#
# Time taken : 8.8 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.61
# Density Fitting                         0.22
#     DF (gamma)                          0.07
#     DF (coeff)                          0.06
#     DF (Jtri)                           0.08
# DIIS                                    0.09
# KS matrix diagonalization               0.35
# One electron Integrals (S, T, Vnuc)     0.03
# Coulomb Integrals (2c2e + 3c2e)         0.83
# Grids construction                      0.3
# Exchange-Correlation Term               5.5
# Misc.                                   0.88
# Complete SCF                            8.8

# %% [markdown]
# ### Benchmark #5 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.09 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.00310910299981515
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.67 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.97 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.89 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371791
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120588
# --------------------------------------------------
#
#
#
# Energy difference :  185.4486196120588
#
#
# HOMO-LUMO gap: 1.7655068072142477 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  66.88323605808696
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816168858477
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207644691404
# Coulomb Energy                  1272.5916576120576
# Exchange-Correlation Energy     -125.2197723388672
# --------------------------------------------------
# Total Energy                    -680.0824210262849
# --------------------------------------------------
#
#
#
# Energy difference :  494.6338014142261
#
#
# HOMO-LUMO gap: 0.0003950061522453585 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  39.27352432792838
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.001236
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671666176342
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861185032699
# Coulomb Energy                   861.6520702032431
# Exchange-Correlation Energy      -75.4418334960938
# --------------------------------------------------
# Total Energy                    -709.3642652899830
# --------------------------------------------------
#
#
#
# Energy difference :  29.281844263698076
#
#
# HOMO-LUMO gap: 0.027815576346352795 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  28.14516363991795
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99994
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982282477473
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525304346086
# Coulomb Energy                  1000.6416009621263
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464582044835
# --------------------------------------------------
#
#
#
# Energy difference :  24.38219291450048
#
#
# HOMO-LUMO gap: 0.006873881118446057 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  18.101423188289314
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394470589892
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643058400854
# Coulomb Energy                  1039.7364436431774
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035183408187
# --------------------------------------------------
#
#
#
# Energy difference :  44.142939863664765
#
#
# HOMO-LUMO gap: 0.009401599442255534 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  13.030480146556695
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9281985115313
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4697782000796
# Coulomb Energy                  1004.3617049985215
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228962464796
# --------------------------------------------------
#
#
#
# Energy difference :  60.01937790566092
#
#
# HOMO-LUMO gap: 0.024324031147031168 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  7.651673169631552
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2543708188027
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338780607823
# Coulomb Energy                   997.3404994327468
# Exchange-Correlation Energy      -89.6695938110352
# --------------------------------------------------
# Total Energy                    -755.2430410190766
# --------------------------------------------------
#
#
#
# Energy difference :  5.620144772596973
#
#
# HOMO-LUMO gap: 0.0012911093418549457 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.531121587802802
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000244
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9935106747866
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455305428383
# Coulomb Energy                  1008.9226270435734
# Exchange-Correlation Energy      -89.8105316162109
# --------------------------------------------------
# Total Energy                    -754.8293385873540
# --------------------------------------------------
#
#
#
# Energy difference :  0.41370243172264054
#
#
# HOMO-LUMO gap: 0.015388852133196143 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.342496644732097
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6263328496525
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2045014568066
# Coulomb Energy                  1033.2839547992139
# Exchange-Correlation Energy      -92.8135986328125
# --------------------------------------------------
# Total Energy                    -754.2449291092125
# --------------------------------------------------
#
#
#
# Energy difference :  0.5844094781414242
#
#
# HOMO-LUMO gap: 0.21170747170457765 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.051896159685762
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9762929318399
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1048862681878
# Coulomb Energy                  1046.8936488675101
# Exchange-Correlation Energy      -94.6926879882812
# --------------------------------------------------
# Total Energy                    -761.9638996671913
# --------------------------------------------------
#
#
#
# Energy difference :  7.718970557978764
#
#
# HOMO-LUMO gap: 0.02108740015689619 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  4.592855501423144
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186495906653
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7140612541634
# Coulomb Energy                  1016.5840737882485
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8410436263340
# --------------------------------------------------
#
#
#
# Energy difference :  2.1228560408573003
#
#
# HOMO-LUMO gap: 0.08795066875806012 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  4.19997139311763
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5724883158832
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4485452043850
# Coulomb Energy                  1025.9226122012001
# Exchange-Correlation Energy      -92.2370223999023
# --------------------------------------------------
# Total Energy                    -762.7318071929685
# --------------------------------------------------
#
#
#
# Energy difference :  2.8907635666345186
#
#
# HOMO-LUMO gap: 0.14484579574862597 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.9087415252186107
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899825014357
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303628497482
# Coulomb Energy                  1024.4800319541375
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263924103960
# --------------------------------------------------
#
#
#
# Energy difference :  0.09458521742749326
#
#
# HOMO-LUMO gap: 0.09120587799153183 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.3385954256956449
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063809637517
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273611202843
# Coulomb Energy                  1024.8155231631279
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565126358615
# --------------------------------------------------
#
#
#
# Energy difference :  0.030120225465452677
#
#
# HOMO-LUMO gap: 0.10812612399973884 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.13342106553658747
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7707735849899
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490273624193
# Coulomb Energy                  1024.3963716648864
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586828716047
# --------------------------------------------------
#
#
#
# Energy difference :  0.002170235743278681
#
#
# HOMO-LUMO gap: 0.11558370579221608 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.052410091643968267
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028272952157
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1553897816666
# Coulomb Energy                  1024.6505218875634
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595513324842
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008684608794737869
#
#
# HOMO-LUMO gap: 0.1155304641443497 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.014070108405849291
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000214388779
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543988937344
# Coulomb Energy                  1024.5347578061915
# Exchange-Correlation Energy      -92.1552581787109
# --------------------------------------------------
# Total Energy                    -762.8595768004311
# --------------------------------------------------
#
#
#
# Energy difference :  2.54679468980612e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.1196465256926801 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.01580827948727063
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745389711
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803858802765
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978014725411
# Coulomb Energy                  1024.5775723022944
# Exchange-Correlation Energy      -92.1624879527786
# --------------------------------------------------
# Total Energy                    -762.8609539409877
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013771405565421446
#
#
# HOMO-LUMO gap: 0.11848002428738477 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.008700495553645344
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741302034
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328776644324
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722788041222
# Coulomb Energy                  1024.5524780956612
# Exchange-Correlation Energy      -92.1594108526229
# --------------------------------------------------
# Total Energy                    -762.8609855000400
# --------------------------------------------------
#
#
#
# Energy difference :  3.15590523314313e-05
#
#
# HOMO-LUMO gap: 0.11834736358863629 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.002054322440358407
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739808253
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503341517447
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805108460497
# Coulomb Energy                  1024.5630590552405
# Exchange-Correlation Energy      -92.1607681822721
# --------------------------------------------------
# Total Energy                    -762.8609863154943
# --------------------------------------------------
#
#
#
# Energy difference :  8.154543138516601e-07
#
#
# HOMO-LUMO gap: 0.11844995198059977 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.002280379657081976
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742288303
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365054979638
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734596694958
# Coulomb Energy                  1024.5553043716632
# Exchange-Correlation Energy      -92.1597916695955
# --------------------------------------------------
# Total Energy                    -762.8609870091686
# --------------------------------------------------
#
#
#
# Energy difference :  6.936743375263177e-07
#
#
# HOMO-LUMO gap: 0.11849900364607074 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.002121051793812607
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742173349
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510218077015
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0797958251559
# Coulomb Energy                  1024.5646227813806
# Exchange-Correlation Energy      -92.1609313221883
# --------------------------------------------------
# Total Energy                    -762.8609884061214
# --------------------------------------------------
#
#
#
# Energy difference :  1.396952711729682e-06
#
#
# HOMO-LUMO gap: 0.11838532610447937 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0014185288856883346
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741620026
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635538028619
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852199062422
# Coulomb Energy                  1024.5726720297366
# Exchange-Correlation Energy      -92.1618731103402
# --------------------------------------------------
# Total Energy                    -762.8609888599913
# --------------------------------------------------
#
#
#
# Energy difference :  4.538699158729287e-07
#
#
# HOMO-LUMO gap: 0.11838275478741815 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.00032231769178434213
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041733
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571685473642
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822982242408
# Coulomb Energy                  1024.5687889684000
# Exchange-Correlation Energy      -92.1614536529940
# --------------------------------------------------
# Total Energy                    -762.8609888904857
# --------------------------------------------------
#
#
#
# Energy difference :  3.049444785574451e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904857
# -------------------------------------
#
#
#
# Time taken : 14.99 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.03
# Density Fitting                         0.49
#     DF (gamma)                          0.14
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.24
# DIIS                                    0.14
# KS matrix diagonalization               0.62
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.67
# Grids construction                      0.97
# Exchange-Correlation Term               6.61
# Misc.                                   1.41
# Complete SCF                            14.99

# %% [markdown]
# ### Benchmark #6 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.25 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0074027530001785635
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.3
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.49 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.58 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.48 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.16 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355613
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929923059
# --------------------------------------------------
#
#
#
# Energy difference :  374.9324929923059
#
#
# HOMO-LUMO gap: 1.8503196895447265 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  107.82808392766081
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876321745072
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682663138172
# Coulomb Energy                  3537.3220829802208
# Exchange-Correlation Energy     -250.6110687255859
# --------------------------------------------------
# Total Energy                   -1359.8987077753941
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662147830882
#
#
# HOMO-LUMO gap: 0.0021138370433460008 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  57.3650474917395
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4339726203661
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0382902509875
# Coulomb Energy                  2705.4087019809185
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539387306499
# --------------------------------------------------
#
#
#
# Energy difference :  59.155230955255774
#
#
# HOMO-LUMO gap: 0.019742610398449698 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  48.04762457702338
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987256490000
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516878652022
# Coulomb Energy                  3071.8807164988857
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010317022976
# --------------------------------------------------
#
#
#
# Energy difference :  56.652907028352274
#
#
# HOMO-LUMO gap: 0.014679275044833018 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  40.921716980840515
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335374569961
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1620891227908
# Coulomb Energy                  3051.7270284406795
# Exchange-Correlation Energy     -176.2000274658203
# --------------------------------------------------
# Total Energy                   -1378.8348035286845
# --------------------------------------------------
#
#
#
# Energy difference :  16.433771826386874
#
#
# HOMO-LUMO gap: 0.012567152224204972 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  26.92677578058191
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983168348283
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494775586445
# Coulomb Energy                  3003.5484469937446
# Exchange-Correlation Energy     -179.3104553222656
# --------------------------------------------------
# Total Energy                   -1523.5012037740444
# --------------------------------------------------
#
#
#
# Energy difference :  144.6664002453599
#
#
# HOMO-LUMO gap: 0.0032179539325684313 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.73 seconds
#
#
#
# Density matrix difference norm:  13.414501093913703
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00024
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4196990458604
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319380095404
# Coulomb Energy                  2977.4926619769208
# Exchange-Correlation Energy     -178.1001892089844
# --------------------------------------------------
# Total Energy                   -1499.0856444377227
# --------------------------------------------------
#
#
#
# Energy difference :  24.41555933632162
#
#
# HOMO-LUMO gap: 0.03182997306232903 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  12.436592349367832
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381494945701
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8446903376614
# Coulomb Energy                  3000.9338477904444
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434611881467
# --------------------------------------------------
#
#
#
# Energy difference :  23.65781675042399
#
#
# HOMO-LUMO gap: 0.012963705734781818 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.013464849510729
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677603192735
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553132326696
# Coulomb Energy                  3041.7902279172431
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430837615510
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996225734042127
#
#
# HOMO-LUMO gap: 0.02149124419421458 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.216635920724192
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4699630703490
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196356810357
# Coulomb Energy                  3063.1283230767540
# Exchange-Correlation Energy     -185.9102325439453
# --------------------------------------------------
# Total Energy                   -1521.9225930258426
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204907357083357
#
#
# HOMO-LUMO gap: 0.07962878371236659 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  4.429032513974565
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505028536463
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1094872196873
# Coulomb Energy                  3048.3900520853981
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820332188764
# --------------------------------------------------
#
#
#
# Energy difference :  3.659440193033788
#
#
# HOMO-LUMO gap: 0.11947953135673102 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.8332704060355668
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524441956682
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100154627356
# Coulomb Energy                  3044.2746794826817
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396911129472
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765789407078046
#
#
# HOMO-LUMO gap: 0.1091553224083189 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.43796756498433137
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333916281219
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380085283942
# Coulomb Energy                  3039.9319404357429
# Exchange-Correlation Energy     -184.3113403320312
# --------------------------------------------------
# Total Energy                   -1525.7651391653544
# --------------------------------------------------
#
#
#
# Energy difference :  0.025448052407227806
#
#
# HOMO-LUMO gap: 0.08049517417660537 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.2802186339813191
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675648322831
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0128931361837
# Coulomb Energy                  3041.4808639595485
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832831685846
# --------------------------------------------------
#
#
#
# Energy difference :  0.01814400323019072
#
#
# HOMO-LUMO gap: 0.035362054422585984 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  0.20216512834818973
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152272598920
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773135796244
# Coulomb Energy                  3040.7151014239039
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864197684762
# --------------------------------------------------
#
#
#
# Energy difference :  0.003136599891604419
#
#
# HOMO-LUMO gap: 0.04477398571894867 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.07633483997804602
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0312871069000
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161674765471
# Coulomb Energy                  3040.4442125404030
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875175317486
# --------------------------------------------------
#
#
#
# Energy difference :  0.0010977632723552233
#
#
# HOMO-LUMO gap: 0.052790805818731815 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.0284401692179199
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299737846235
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078516639684
# Coulomb Energy                  3040.4514280916451
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877011993255
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001836675769482099
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.049892891358728084 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.012831563002437502
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963124652
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444054926043
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722230900730
# Coulomb Energy                  3040.3964225016089
# Exchange-Correlation Energy     -184.4242561230035
# --------------------------------------------------
# Total Energy                   -1525.7903721932644
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026709939388638304
#
#
# HOMO-LUMO gap: 0.05055294880321873 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 2.36 seconds
#
#
#
# Density matrix difference norm:  0.0053004386417990785
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960688372
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993300111091
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002703975359
# Coulomb Energy                  3040.4277547715578
# Exchange-Correlation Energy     -184.4287289294184
# --------------------------------------------------
# Total Energy                   -1525.7903899407734
# --------------------------------------------------
#
#
#
# Energy difference :  1.774750899130595e-05
#
#
# HOMO-LUMO gap: 0.05045899401560974 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.0021062776010520967
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961674477
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9998982987727
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3973945127295
# Coulomb Energy                  3040.4311710686975
# Exchange-Correlation Energy     -184.4287041983342
# --------------------------------------------------
# Total Energy                   -1525.7903930850175
# --------------------------------------------------
#
#
#
# Energy difference :  3.1442441468243487e-06
#
#
# HOMO-LUMO gap: 0.05065933939812492 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.39 seconds
#
#
#
# Density matrix difference norm:  0.0048815317433546345
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960053903
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796135751061
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345413975802
# Coulomb Energy                  3040.4795321331230
# Exchange-Correlation Energy     -184.4344981700131
# --------------------------------------------------
# Total Energy                   -1525.7903943837528
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987352420168463e-06
#
#
# HOMO-LUMO gap: 0.05063328458808655 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 2.39 seconds
#
#
#
# Density matrix difference norm:  0.004003855518783929
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962935727
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308456133034
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102268347829
# Coulomb Energy                  3040.4520257606382
# Exchange-Correlation Energy     -184.4314494155981
# --------------------------------------------------
# Total Energy                   -1525.7903986028177
# --------------------------------------------------
#
#
#
# Energy difference :  4.219064976496156e-06
#
#
# HOMO-LUMO gap: 0.050659205937185106 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.0009814583163798788
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396231761
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462805272564
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170924478271
# Coulomb Energy                  3040.4616008910289
# Exchange-Correlation Energy     -184.4324555590073
# --------------------------------------------------
# Total Energy                   -1525.7903989167444
# --------------------------------------------------
#
#
#
# Energy difference :  3.1392664823215455e-07
#
#
# HOMO-LUMO gap: 0.050679426855668286 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.00024618075571019226
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332735
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503257761984
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622275633
# Coulomb Energy                  3040.4641306073013
# Exchange-Correlation Energy     -184.4327098270256
# --------------------------------------------------
# Total Energy                   -1525.7903989376969
# --------------------------------------------------
#
#
#
# Energy difference :  2.0952484192093834e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989376969
# -------------------------------------
#
#
#
# Time taken : 54.46 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.64
# Density Fitting                         1.48
#     DF (gamma)                          0.31
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.96
# DIIS                                    0.74
# KS matrix diagonalization               1.21
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         11.49
# Grids construction                      4.58
# Exchange-Correlation Term               24.8
# Misc.                                   2.47
# Complete SCF                            54.46

# %% [markdown]
# ### Benchmark #7 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.14 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.5 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.09
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.016734157999962918
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.11 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.7
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.14 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.24 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 21.05 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.26 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004725
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456161
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456161
#
#
# HOMO-LUMO gap: 1.3453310369351166 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.72 seconds
#
#
#
# Density matrix difference norm:  144.0136746268794
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771653634634
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873960288356
# Coulomb Energy                  7102.3908476757197
# Exchange-Correlation Energy     -401.0388488769531
# --------------------------------------------------
# Total Energy                   -2175.7976493752458
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159317296297
#
#
# HOMO-LUMO gap: 0.0036323936830697234 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.37 seconds
#
#
#
# Density matrix difference norm:  71.99222142055261
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0024
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8537956301370
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349342493432
# Coulomb Energy                  5771.7158140796128
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171589286529
# --------------------------------------------------
#
#
#
# Energy difference :  98.71950955340708
#
#
# HOMO-LUMO gap: 0.00497160536148486 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.4 seconds
#
#
#
# Density matrix difference norm:  58.10278544856622
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372312917134
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733518965033
# Coulomb Energy                  6321.7308991280697
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4680727295727
# --------------------------------------------------
#
#
#
# Energy difference :  116.0490861990802
#
#
# HOMO-LUMO gap: 0.014406138477483815 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  53.36866418502801
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688653776178
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515406756088
# Coulomb Energy                  6361.2922210323577
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5267244523966
# --------------------------------------------------
#
#
#
# Energy difference :  24.058651722823925
#
#
# HOMO-LUMO gap: 0.008931029739008306 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 1.45 seconds
#
#
#
# Density matrix difference norm:  42.83084112720596
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057586324103
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112451584159
# Coulomb Energy                  6294.4824429260134
# Exchange-Correlation Energy     -283.9661865234375
# --------------------------------------------------
# Total Energy                   -2345.8381359108043
# --------------------------------------------------
#
#
#
# Energy difference :  163.31141145840775
#
#
# HOMO-LUMO gap: 0.006907372742166698 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  32.166244655728754
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2173794092087
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029696448394
# Coulomb Energy                  6214.1441901162643
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5589131847564
# --------------------------------------------------
#
#
#
# Energy difference :  2.2792227260479194
#
#
# HOMO-LUMO gap: 0.002470699557964362 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  33.32021574839558
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828278601344
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271136493061
# Coulomb Energy                  6284.7511436582499
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5702660423540
# --------------------------------------------------
#
#
#
# Energy difference :  9.011352857597558
#
#
# HOMO-LUMO gap: 0.006022982994176168 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  26.099225449035373
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2099485631206
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3779248821143
# Coulomb Energy                  6418.6993131454265
# Exchange-Correlation Energy     -305.3439331054688
# --------------------------------------------------
# Total Energy                   -2411.0365224804327
# --------------------------------------------------
#
#
#
# Energy difference :  58.466256438078744
#
#
# HOMO-LUMO gap: 0.00561208377723571 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  17.53005660659432
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3145335991176
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3755046368638
# Coulomb Energy                  6329.8759283888749
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3362057311233
# --------------------------------------------------
#
#
#
# Energy difference :  37.70031674930942
#
#
# HOMO-LUMO gap: 0.01712894763510059 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  16.39802861619557
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4113544700704
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3502368015425
# Coulomb Energy                  6323.6507582373597
# Exchange-Correlation Energy     -296.5716552734375
# --------------------------------------------------
# Total Energy                   -2423.5418935439902
# --------------------------------------------------
#
#
#
# Energy difference :  50.20568781286693
#
#
# HOMO-LUMO gap: 0.006507605727327309 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  17.896862480750077
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006048163938
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1970983451424
# Coulomb Energy                  6269.6529336287476
# Exchange-Correlation Energy     -292.3520507812500
# --------------------------------------------------
# Total Energy                   -2388.4625024631387
# --------------------------------------------------
#
#
#
# Energy difference :  35.079391080851565
#
#
# HOMO-LUMO gap: 0.011363439439214973 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  18.87511509676355
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4052548160853
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783339006250
# Coulomb Energy                  6305.1510386477776
# Exchange-Correlation Energy     -292.6976928710938
# --------------------------------------------------
# Total Energy                   -2419.6334539781628
# --------------------------------------------------
#
#
#
# Energy difference :  31.17095151502417
#
#
# HOMO-LUMO gap: 0.0019309006773451654 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  14.237404221565253
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7558021766235
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6446940229989
# Coulomb Energy                  6277.9144266578169
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7447805500378
# --------------------------------------------------
#
#
#
# Energy difference :  0.11132657187499717
#
#
# HOMO-LUMO gap: 0.008268447858188782 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  12.511464486942995
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8343499461243
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119842976046
# Coulomb Energy                  6304.6092670104936
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9790932000687
# --------------------------------------------------
#
#
#
# Energy difference :  11.234312650030915
#
#
# HOMO-LUMO gap: 0.017658851975929632 au
# HOMO-LUMO gap: 0.481 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  10.321247183355515
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0478678968993
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2890554790320
# Coulomb Energy                  6320.8556136823163
# Exchange-Correlation Energy     -297.0248107910156
# --------------------------------------------------
# Total Energy                   -2429.4878883659521
# --------------------------------------------------
#
#
#
# Energy difference :  1.4912048341166155
#
#
# HOMO-LUMO gap: 0.006404341843482736 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  8.082501886035704
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4238980528407
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0824912211383
# Coulomb Energy                  6316.7243746827407
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382940449887
# --------------------------------------------------
#
#
#
# Energy difference :  8.450405679036521
#
#
# HOMO-LUMO gap: 0.06628549959474477 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  4.088566575680294
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3817979481028
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5872166330837
# Coulomb Energy                  6313.2561832533320
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039775846653
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656835396766837
#
#
# HOMO-LUMO gap: 0.002508559271841307 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.342554126087836
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2973122238964
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1398620186565
# Coulomb Energy                  6287.7368906787215
# Exchange-Correlation Energy     -293.7501525878906
# --------------------------------------------------
# Total Energy                   -2439.7305909537936
# --------------------------------------------------
#
#
#
# Energy difference :  1.2733866308717552
#
#
# HOMO-LUMO gap: 0.02060407925356849 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 1.55 seconds
#
#
#
# Density matrix difference norm:  4.259658639828935
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7061576866963
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.1986014583931
# Coulomb Energy                  6303.8933191442793
# Exchange-Correlation Energy     -294.9478454589844
# --------------------------------------------------
# Total Energy                   -2441.1219613823941
# --------------------------------------------------
#
#
#
# Energy difference :  1.3913704286005668
#
#
# HOMO-LUMO gap: 0.1229847114949178 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  0.7427967262291324
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0197188222483
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5243232098278
# Coulomb Energy                  6307.0121994347664
# Exchange-Correlation Energy     -295.2850036621094
# --------------------------------------------------
# Total Energy                   -2441.3280786791493
# --------------------------------------------------
#
#
#
# Energy difference :  0.20611729675511015
#
#
# HOMO-LUMO gap: 0.08867235034758417 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 1.56 seconds
#
#
#
# Density matrix difference norm:  0.4773187500019495
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4110253760628
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7989035240394
# Coulomb Energy                  6304.8709352960441
# Exchange-Correlation Energy     -295.0262451171875
# --------------------------------------------------
# Total Energy                   -2441.3273105125527
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007681665965719731
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.106394376885128 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 1.55 seconds
#
#
#
# Density matrix difference norm:  0.2704212459252357
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000115274331
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5565087000741
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4793673894842
# Coulomb Energy                  6304.2831333942249
# Exchange-Correlation Energy     -294.9926867122736
# --------------------------------------------------
# Total Energy                   -2441.3465734680249
# --------------------------------------------------
#
#
#
# Energy difference :  0.01926295547218615
#
#
# HOMO-LUMO gap: 0.10571266851437691 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 5.93 seconds
#
#
#
# Density matrix difference norm:  0.11903342607318296
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011552552115
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9902840398554
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6069378256125
# Coulomb Energy                  6305.7413502039162
# Exchange-Correlation Energy     -295.1471004989260
# --------------------------------------------------
# Total Energy                   -2441.3489753486374
# --------------------------------------------------
#
#
#
# Energy difference :  0.00240188061252411
#
#
# HOMO-LUMO gap: 0.10232717125159077 au
# HOMO-LUMO gap: 2.784 eV
#
#
# Time taken for the previous iteration: 5.91 seconds
#
#
#
# Density matrix difference norm:  0.057726534399081375
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011616396534
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1764217135897
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2270806213328
# Coulomb Energy                  6305.2551327706360
# Exchange-Correlation Energy     -295.0957753495093
# --------------------------------------------------
# Total Energy                   -2441.3498625105158
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008871618783814483
#
#
# HOMO-LUMO gap: 0.08313023376738803 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 5.85 seconds
#
#
#
# Density matrix difference norm:  0.06365964089586479
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011775875447
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6239629404699
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9398124564887
# Coulomb Energy                  6304.9502962580918
# Exchange-Correlation Energy     -295.0562570067834
# --------------------------------------------------
# Total Energy                   -2441.3499900720581
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012756154228554806
#
#
# HOMO-LUMO gap: 0.08543980482411806 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 5.82 seconds
#
#
#
# Density matrix difference norm:  0.03312535124534362
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171909242
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1937875867916
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2381636702776
# Coulomb Energy                  6305.2622641644693
# Exchange-Correlation Energy     -295.0969073704871
# --------------------------------------------------
# Total Energy                   -2441.3501459619174
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001558898593430058
#
#
# HOMO-LUMO gap: 0.08549323367657008 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  0.016442347086846873
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174372667
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9924333368563
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1355473534336
# Coulomb Energy                  6305.1489939242510
# Exchange-Correlation Energy     -295.0824369929927
# --------------------------------------------------
# Total Energy                   -2441.3502078915499
# --------------------------------------------------
#
#
#
# Energy difference :  6.192963246576255e-05
#
#
# HOMO-LUMO gap: 0.08609954309013954 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.007353063436052648
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173439313
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0612539978174
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745099119316
# Coulomb Energy                  6305.1841811995964
# Exchange-Correlation Energy     -295.0877763052659
# --------------------------------------------------
# Total Energy                   -2441.3502180309406
# --------------------------------------------------
#
#
#
# Energy difference :  1.0139390724361874e-05
#
#
# HOMO-LUMO gap: 0.08618092217515283 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.002921801388958688
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011732035375
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0438983487147
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630535791155
# Coulomb Energy                  6305.1767175220848
# Exchange-Correlation Energy     -295.0862144052358
# --------------------------------------------------
# Total Energy                   -2441.3502204921351
# --------------------------------------------------
#
#
#
# Energy difference :  2.4611945264041424e-06
#
#
# HOMO-LUMO gap: 0.08626994217470475 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  0.0007991340815016521
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173088248
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357870057633
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591885960934
# Coulomb Energy                  6305.1719582384221
# Exchange-Correlation Energy     -295.0857015848556
# --------------------------------------------------
# Total Energy                   -2441.3502205954892
# --------------------------------------------------
#
#
#
# Energy difference :  1.0335406841477379e-07
#
#
# HOMO-LUMO gap: 0.08626927836313167 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  0.00047088221973511936
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173170847
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0330011031110
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576326832683
# Coulomb Energy                  6305.1705222148285
# Exchange-Correlation Energy     -295.0854955610870
# --------------------------------------------------
# Total Energy                   -2441.3502206054873
# --------------------------------------------------
#
#
#
# Energy difference :  9.9980752565898e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206054873
# -------------------------------------
#
#
#
# Time taken : 161.79 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.31
# Density Fitting                         5.4
#     DF (gamma)                          0.98
#     DF (coeff)                          0.18
#     DF (Jtri)                           3.86
# DIIS                                    3.62
# KS matrix diagonalization               3.6
# One electron Integrals (S, T, Vnuc)     0.14
# Coulomb Integrals (2c2e + 3c2e)         29.14
# Grids construction                      16.24
# Exchange-Correlation Term               78.11
# Misc.                                   4.23
# Complete SCF                            161.79

# %% [markdown]
# ### Benchmark #8 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.21 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.9 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.17
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04167848599990975
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.21 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  1.48
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  68.15 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 49.9 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 55.78 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.38 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0009
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182574
# Exchange-Correlation Energy     -158.3137817382812
# --------------------------------------------------
# Total Energy                    -881.4919713840627
# --------------------------------------------------
#
#
#
# Energy difference :  881.4919713840627
#
#
# HOMO-LUMO gap: 0.6897605128392486 au
# HOMO-LUMO gap: 18.769 eV
#
#
# Time taken for the previous iteration: 2.98 seconds
#
#
#
# Density matrix difference norm:  177.41135652363798
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3344603663936
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5272337036995
# Coulomb Energy                 12707.6510698511338
# Exchange-Correlation Energy     -589.0113525390625
# --------------------------------------------------
# Total Energy                   -3195.7102569237013
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2182855396386
#
#
# HOMO-LUMO gap: 0.002627327044009309 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 3.06 seconds
#
#
#
# Density matrix difference norm:  86.09643255332108
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.1087798585286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9652414756320
# Coulomb Energy                 10864.6200183274468
# Exchange-Correlation Energy     -358.7289123535156
# --------------------------------------------------
# Total Energy                   -3357.7951799820439
# --------------------------------------------------
#
#
#
# Energy difference :  162.0849230583426
#
#
# HOMO-LUMO gap: 0.002510853069398432 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 3.12 seconds
#
#
#
# Density matrix difference norm:  65.13146239230176
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00012
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9479187393190
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4635717433339
# Coulomb Energy                 11125.2510310504258
# Exchange-Correlation Energy     -407.6779174804688
# --------------------------------------------------
# Total Energy                   -3374.4539809991056
# --------------------------------------------------
#
#
#
# Energy difference :  16.658801017061705
#
#
# HOMO-LUMO gap: 0.0044218642498255745 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 3.21 seconds
#
#
#
# Density matrix difference norm:  63.85792441494417
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.3725392924389
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.9140563048104
# Coulomb Energy                 12063.8293630325279
# Exchange-Correlation Energy     -415.0684814453125
# --------------------------------------------------
# Total Energy                   -3056.2403489734916
# --------------------------------------------------
#
#
#
# Energy difference :  318.21363202561406
#
#
# HOMO-LUMO gap: 0.007368565759644688 au
# HOMO-LUMO gap: 0.201 eV
#
#
# Time taken for the previous iteration: 3.34 seconds
#
#
#
# Density matrix difference norm:  54.581843608092896
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.6403125649776
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.4169001327550
# Coulomb Energy                 11513.0420669268351
# Exchange-Correlation Energy     -417.4490356445312
# --------------------------------------------------
# Total Energy                   -3536.1731287229977
# --------------------------------------------------
#
#
#
# Energy difference :  479.93277974950615
#
#
# HOMO-LUMO gap: 0.0017456543566800103 au
# HOMO-LUMO gap: 0.048 eV
#
#
# Time taken for the previous iteration: 3.45 seconds
#
#
#
# Density matrix difference norm:  51.20557188414463
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9997
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.0683715274427
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.9093082008831
# Coulomb Energy                 11567.9598184913302
# Exchange-Correlation Energy     -419.4386291503906
# --------------------------------------------------
# Total Energy                   -3073.1806215586967
# --------------------------------------------------
#
#
#
# Energy difference :  462.99250716430106
#
#
# HOMO-LUMO gap: 0.0071010442774656485 au
# HOMO-LUMO gap: 0.193 eV
#
#
# Time taken for the previous iteration: 3.48 seconds
#
#
#
# Density matrix difference norm:  44.85234394787192
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.9588235411356
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6778955046575
# Coulomb Energy                 11495.7953395685254
# Exchange-Correlation Energy     -423.7618408203125
# --------------------------------------------------
# Total Energy                   -3532.7901768613428
# --------------------------------------------------
#
#
#
# Energy difference :  459.6095553026462
#
#
# HOMO-LUMO gap: 0.0009143179376474297 au
# HOMO-LUMO gap: 0.025 eV
#
#
# Time taken for the previous iteration: 3.49 seconds
#
#
#
# Density matrix difference norm:  20.64660624123266
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.8309310501900
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.3211855607778
# Coulomb Energy                 11578.8342785485074
# Exchange-Correlation Energy     -439.3337402343750
# --------------------------------------------------
# Total Energy                   -3536.5519547483582
# --------------------------------------------------
#
#
#
# Energy difference :  3.7617778870153415
#
#
# HOMO-LUMO gap: 0.0036001210528023853 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 3.51 seconds
#
#
#
# Density matrix difference norm:  20.82897638104909
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28136.7523636067272
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3618.5807275256093
# Coulomb Energy                 11689.0101148098765
# Exchange-Correlation Energy     -441.3328247070312
# --------------------------------------------------
# Total Energy                   -3500.0370935513511
# --------------------------------------------------
#
#
#
# Energy difference :  36.51486119700712
#
#
# HOMO-LUMO gap: 0.010632703483513417 au
# HOMO-LUMO gap: 0.289 eV
#
#
# Time taken for the previous iteration: 3.47 seconds
#
#
#
# Density matrix difference norm:  22.1975798555872
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00012
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27870.4576922841079
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3570.0606720634760
# Coulomb Energy                 11460.1491634240410
# Exchange-Correlation Energy     -435.4828796386719
# --------------------------------------------------
# Total Energy                   -3505.2734840083413
# --------------------------------------------------
#
#
#
# Energy difference :  5.236390456990193
#
#
# HOMO-LUMO gap: 0.010852774546400684 au
# HOMO-LUMO gap: 0.295 eV
#
#
# Time taken for the previous iteration: 3.42 seconds
#
#
#
# Density matrix difference norm:  15.727052629322973
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0003
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28102.6513562598630
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3578.5252510084965
# Coulomb Energy                 11610.6783789500605
# Exchange-Correlation Energy     -438.4913330078125
# --------------------------------------------------
# Total Energy                   -3581.4818068821951
# --------------------------------------------------
#
#
#
# Energy difference :  76.20832287385383
#
#
# HOMO-LUMO gap: 0.0001600848192601506 au
# HOMO-LUMO gap: 0.004 eV
#
#
# Time taken for the previous iteration: 3.4 seconds
#
#
#
# Density matrix difference norm:  13.370549712123228
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27854.5573800640632
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3502.8838078518647
# Coulomb Energy                 11467.2388641910275
# Exchange-Correlation Energy     -426.1157531738281
# --------------------------------------------------
# Total Energy                   -3540.0932087680776
# --------------------------------------------------
#
#
#
# Energy difference :  41.388598114117485
#
#
# HOMO-LUMO gap: 0.05310990321737655 au
# HOMO-LUMO gap: 1.445 eV
#
#
# Time taken for the previous iteration: 3.38 seconds
#
#
#
# Density matrix difference norm:  12.79434586954796
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27990.3049491376878
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3532.9182127317790
# Coulomb Energy                 11534.4714240499197
# Exchange-Correlation Energy     -432.5692443847656
# --------------------------------------------------
# Total Energy                   -3585.0273043138313
# --------------------------------------------------
#
#
#
# Energy difference :  44.934095545753735
#
#
# HOMO-LUMO gap: 0.004205321334687137 au
# HOMO-LUMO gap: 0.114 eV
#
#
# Time taken for the previous iteration: 3.36 seconds
#
#
#
# Density matrix difference norm:  4.412145011308028
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27977.3915971304741
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3527.9679750216533
# Coulomb Energy                 11526.5916813559270
# Exchange-Correlation Energy     -431.3869018554688
# --------------------------------------------------
# Total Energy                   -3583.7615901814406
# --------------------------------------------------
#
#
#
# Energy difference :  1.2657141323907126
#
#
# HOMO-LUMO gap: 0.05835586468883318 au
# HOMO-LUMO gap: 1.588 eV
#
#
# Time taken for the previous iteration: 3.36 seconds
#
#
#
# Density matrix difference norm:  4.109635365838943
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27998.0908327666257
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3538.5435288191702
# Coulomb Energy                 11536.7458061540619
# Exchange-Correlation Energy     -433.2103271484375
# --------------------------------------------------
# Total Energy                   -3585.5545725149095
# --------------------------------------------------
#
#
#
# Energy difference :  1.792982333468899
#
#
# HOMO-LUMO gap: 0.08676284828364322 au
# HOMO-LUMO gap: 2.361 eV
#
#
# Time taken for the previous iteration: 3.31 seconds
#
#
#
# Density matrix difference norm:  0.7326623137122864
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.8600231795936
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.7691134268434
# Coulomb Energy                 11540.4379706225009
# Exchange-Correlation Energy     -433.5176391601562
# --------------------------------------------------
# Total Energy                   -3585.7133258634840
# --------------------------------------------------
#
#
#
# Energy difference :  0.15875334857446433
#
#
# HOMO-LUMO gap: 0.09405335199355666 au
# HOMO-LUMO gap: 2.559 eV
#
#
# Time taken for the previous iteration: 3.3 seconds
#
#
#
# Density matrix difference norm:  0.28167130443593563
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.1457377877814
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5327238470827
# Coulomb Energy                 11539.8985642711214
# Exchange-Correlation Energy     -433.4659118652344
# --------------------------------------------------
# Total Energy                   -3585.7231091078902
# --------------------------------------------------
#
#
#
# Energy difference :  0.009783244406207814
#
#
# HOMO-LUMO gap: 0.09971801523713929 au
# HOMO-LUMO gap: 2.713 eV
#
#
# Time taken for the previous iteration: 3.3 seconds
#
#
#
# Density matrix difference norm:  0.1683592420974165
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00003
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6091145812825
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.5708631292609
# Coulomb Energy                 11539.1832852512289
# Exchange-Correlation Energy     -433.3303527832031
# --------------------------------------------------
# Total Energy                   -3585.7280665570725
# --------------------------------------------------
#
#
#
# Energy difference :  0.004957449182256823
#
#
# HOMO-LUMO gap: 0.10344517876856642 au
# HOMO-LUMO gap: 2.815 eV
#
#
# Time taken for the previous iteration: 3.3 seconds
#
#
#
# Density matrix difference norm:  0.08025562549400461
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.7157035814234
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7577010707487
# Coulomb Energy                 11539.1256581106391
# Exchange-Correlation Energy     -433.3546447753906
# --------------------------------------------------
# Total Energy                   -3585.7297367485025
# --------------------------------------------------
#
#
#
# Energy difference :  0.001670191430093837
#
# Switching to double precision for XC evaluation after 20 iterations!
#
#
# HOMO-LUMO gap: 0.10344047658011654 au
# HOMO-LUMO gap: 2.815 eV
#
#
# Time taken for the previous iteration: 3.27 seconds
#
#
#
# Density matrix difference norm:  0.04228821288074122
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000160987999
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0595154090188
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8997222891121
# Coulomb Energy                 11539.3454963584682
# Exchange-Correlation Energy     -433.3794748881074
# --------------------------------------------------
# Total Energy                   -3585.7365192226243
# --------------------------------------------------
#
#
#
# Energy difference :  0.006782474121791893
#
#
# HOMO-LUMO gap: 0.10318020996182076 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 14.01 seconds
#
#
#
# Density matrix difference norm:  0.015959261644157372
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162441325
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9453969547394
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8150912325600
# Coulomb Energy                 11539.3069599924092
# Exchange-Correlation Energy     -433.3704921946950
# --------------------------------------------------
# Total Energy                   -3585.7365854975415
# --------------------------------------------------
#
#
#
# Energy difference :  6.627491711697076e-05
#
#
# HOMO-LUMO gap: 0.10328454731473916 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 14.06 seconds
#
#
#
# Density matrix difference norm:  0.009043685126739205
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000161115308
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9178322597218
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7989037234224
# Coulomb Energy                 11539.2954533174907
# Exchange-Correlation Energy     -433.3703680976280
# --------------------------------------------------
# Total Energy                   -3585.7365908895154
# --------------------------------------------------
#
#
#
# Energy difference :  5.3919739002594724e-06
#
#
# HOMO-LUMO gap: 0.10328762157881494 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 14.15 seconds
#
#
#
# Density matrix difference norm:  0.0054998848758471474
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001635576086
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0273476971815
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8530024185516
# Coulomb Energy                 11539.3581738194862
# Exchange-Correlation Energy     -433.3776754902185
# --------------------------------------------------
# Total Energy                   -3585.7365945224374
# --------------------------------------------------
#
#
#
# Energy difference :  3.6329220165498555e-06
#
#
# HOMO-LUMO gap: 0.1032531853806496 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.17 seconds
#
#
#
# Density matrix difference norm:  0.003076751023815128
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001626836297
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9469171946293
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8127613331862
# Coulomb Energy                 11539.3125074576164
# Exchange-Correlation Energy     -433.3722002879760
# --------------------------------------------------
# Total Energy                   -3585.7365962648819
# --------------------------------------------------
#
#
#
# Energy difference :  1.7424445104552433e-06
#
#
# HOMO-LUMO gap: 0.10322401383008276 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 14.17 seconds
#
#
#
# Density matrix difference norm:  0.001295628750860085
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001625896516
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9431164763628
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096037416362
# Coulomb Energy                 11539.3114784908921
# Exchange-Correlation Energy     -433.3718148178154
# --------------------------------------------------
# Total Energy                   -3585.7365966347279
# --------------------------------------------------
#
#
#
# Energy difference :  3.6984602047596127e-07
#
#
# HOMO-LUMO gap: 0.10325134385414497 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.14 seconds
#
#
#
# Density matrix difference norm:  0.0005982258051189229
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001628137596
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9506178693264
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8140485859235
# Coulomb Energy                 11539.3151853864583
# Exchange-Correlation Energy     -433.3724652236614
# --------------------------------------------------
# Total Energy                   -3585.7365966936832
# --------------------------------------------------
#
#
#
# Energy difference :  5.8955265558324754e-08
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596693683
# -------------------------------------
#
#
#
# Time taken : 344.38 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           56.15
# Density Fitting                         11.99
#     DF (gamma)                          2.55
#     DF (coeff)                          0.14
#     DF (Jtri)                           8.61
# DIIS                                    8.46
# KS matrix diagonalization               6.8
# One electron Integrals (S, T, Vnuc)     0.21
# Coulomb Integrals (2c2e + 3c2e)         68.15
# Grids construction                      49.9
# Exchange-Correlation Term               137.18
# Misc.                                   5.53
# Complete SCF                            344.38
