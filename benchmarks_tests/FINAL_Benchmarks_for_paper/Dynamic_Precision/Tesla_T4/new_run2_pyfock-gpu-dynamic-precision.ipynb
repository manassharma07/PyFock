# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 39.01 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 38.4 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.3 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=85c40c45fff618b8c536d739e51423d48e5563fede0dae7d923a6ae4f3d779bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-295otl4y/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 15.42 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.73 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  5.69
# Time taken to evaluate the square roots needed:  0.11
# Time for significant indices evaluation:  2.0885528769999837
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 7.89 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  6.68
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  38.28 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.85 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.37 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.5 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709565
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632568
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325685
#
#
# HOMO-LUMO gap: 2.6431079281670433 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.16 seconds
#
#
#
# Density matrix difference norm:  43.34767137041569
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  49.99999474389979
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709403
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316028
# Coulomb Energy                   501.1198589452459
# Exchange-Correlation Energy      -62.5998011282691
# --------------------------------------------------
# Total Energy                    -340.0652765782371
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851498026
#
#
# HOMO-LUMO gap: 0.004902711060929099 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.28 seconds
#
#
#
# Density matrix difference norm:  28.61247171885184
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00009840286508
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456531
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785880
# Coulomb Energy                   293.3088657954170
# Exchange-Correlation Energy      -37.4191110537726
# --------------------------------------------------
# Total Energy                    -355.5094553812972
# --------------------------------------------------
#
#
#
# Energy difference :  15.44417880306014
#
#
# HOMO-LUMO gap: 0.040361476987117006 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  21.39401678737404
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445385
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275400
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458396
# Coulomb Energy                   367.2127830476495
# Exchange-Correlation Energy      -44.5841010136097
# --------------------------------------------------
# Total Energy                    -380.5867878035370
# --------------------------------------------------
#
#
#
# Energy difference :  25.07733242223975
#
#
# HOMO-LUMO gap: 0.018048571143129643 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  5.1974809336904215
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000687474084
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703848
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754534
# Coulomb Energy                   364.3533796551094
# Exchange-Correlation Energy      -44.5594485029986
# --------------------------------------------------
# Total Energy                    -378.6274635986970
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048400157
#
#
# HOMO-LUMO gap: 0.0849358228476988 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  4.779285269953178
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001287711403
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186592
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180477
# Coulomb Energy                   368.1554971681628
# Exchange-Correlation Energy      -45.0868782881905
# --------------------------------------------------
# Total Energy                    -381.1270633765158
# --------------------------------------------------
#
#
#
# Energy difference :  2.499599777818787
#
#
# HOMO-LUMO gap: 0.14183855738608814 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5205766173111798
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089465
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233323
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990155
# Coulomb Energy                   369.0647619107244
# Exchange-Correlation Energy      -45.1368862216105
# --------------------------------------------------
# Total Energy                    -381.2275584910792
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456344362
#
#
# HOMO-LUMO gap: 0.13514723909450227 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.3315886778250067
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597148
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176876
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774550
# Coulomb Energy                   369.6340156607537
# Exchange-Correlation Energy      -45.2090855965864
# --------------------------------------------------
# Total Energy                    -381.2508898319418
# --------------------------------------------------
#
#
#
# Energy difference :  0.02333134086256905
#
#
# HOMO-LUMO gap: 0.01973205738262033 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5818251308667484
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008617005506
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110828
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893504
# Coulomb Energy                   374.0898923937928
# Exchange-Correlation Energy      -45.7569321945898
# --------------------------------------------------
# Total Energy                    -381.3827647784059
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646416553
#
#
# HOMO-LUMO gap: 0.12604481221474353 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.4584549614613033
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767307
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524549
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358334
# Coulomb Energy                   377.3880704578812
# Exchange-Correlation Energy      -46.1034837100253
# --------------------------------------------------
# Total Energy                    -381.4206849246420
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623610385
#
#
# HOMO-LUMO gap: 0.16627348986173418 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.14506886516869888
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000757902089
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358475
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690247
# Coulomb Energy                   377.1736811284885
# Exchange-Correlation Energy      -46.0748895148568
# --------------------------------------------------
# Total Energy                    -381.4268823090675
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384425433938
#
#
# HOMO-LUMO gap: 0.18126074112633994 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.05574884999006239
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074251987
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179449
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114344
# Coulomb Energy                   377.1977734128257
# Exchange-Correlation Energy      -46.0810670348481
# --------------------------------------------------
# Total Energy                    -381.4272916844093
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753418601409
#
#
# HOMO-LUMO gap: 0.18111025828113564 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.025625306052300942
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503725406
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006521
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114223
# Coulomb Energy                   377.1502888734889
# Exchange-Correlation Energy      -46.0776486461291
# --------------------------------------------------
# Total Energy                    -381.4274184177465
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333714019464
#
#
# HOMO-LUMO gap: 0.18068395565687054 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0084325264344729
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007500354876
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167688
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298664
# Coulomb Energy                   377.1545462611575
# Exchange-Correlation Energy      -46.0767747067600
# --------------------------------------------------
# Total Energy                    -381.4274393883814
# --------------------------------------------------
#
#
#
# Energy difference :  2.0970634921013698e-05
#
#
# HOMO-LUMO gap: 0.18067053575028433 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018444600033746766
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750025073
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068158
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736951
# Coulomb Energy                   377.1524231958022
# Exchange-Correlation Energy      -46.0765296383165
# --------------------------------------------------
# Total Energy                    -381.4274391315116
# --------------------------------------------------
#
#
#
# Energy difference :  2.568697823335242e-07
#
#
# HOMO-LUMO gap: 0.18064597252295664 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0011511413606738454
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749894921
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206486
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789386
# Coulomb Energy                   377.1549870542086
# Exchange-Correlation Energy      -46.0768423766160
# --------------------------------------------------
# Total Energy                    -381.4274396199940
# --------------------------------------------------
#
#
#
# Energy difference :  4.884823852080444e-07
#
#
# HOMO-LUMO gap: 0.1806425643883748 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.00010543279287649501
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836627
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081829
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075866
# Coulomb Energy                   377.1556791349427
# Exchange-Correlation Energy      -46.0769272993466
# --------------------------------------------------
# Total Energy                    -381.4274396208768
# --------------------------------------------------
#
#
#
# Energy difference :  8.827782949083485e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396208768
# -------------------------------------
#
#
#
# Time taken : 69.3 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.87
# Density Fitting                         1.35
#     DF (gamma)                          0.35
#     DF (coeff)                          0.11
#     DF (Jtri)                           0.61
# DIIS                                    0.73
# KS matrix diagonalization               0.79
# One electron Integrals (S, T, Vnuc)     15.42
# Coulomb Integrals (2c2e + 3c2e)         38.28
# Grids construction                      0.85
# Exchange-Correlation Term               5.2
# Misc.                                   3.82
# Complete SCF                            69.3

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.09 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.00327304800003958
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.43 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.95 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.91 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00135664103418
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371791
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645300004
# --------------------------------------------------
#
#
#
# Energy difference :  185.4474645300004
#
#
# HOMO-LUMO gap: 1.7654343749558739 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.61 seconds
#
#
#
# Density matrix difference norm:  66.88358764205354
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084647
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437762
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987505857
# Coulomb Energy                  1272.5954275689533
# Exchange-Correlation Energy     -125.2198694441757
# --------------------------------------------------
# Total Energy                    -680.0789187511809
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422118055
#
#
# HOMO-LUMO gap: 0.0004045605676387676 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  39.27522964436414
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00120175844562
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692492192
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666726602
# Coulomb Energy                   861.6558693044897
# Exchange-Correlation Energy      -75.4419310839500
# --------------------------------------------------
# Total Energy                    -709.3563182387873
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487606317
#
#
# HOMO-LUMO gap: 0.02781560500170769 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  28.14735856432883
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663973
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672038887
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170660519
# Coulomb Energy                  1000.6400676120290
# Exchange-Correlation Energy      -87.3507096616633
# --------------------------------------------------
# Total Energy                    -733.7433460702389
# --------------------------------------------------
#
#
#
# Energy difference :  24.387027831451633
#
#
# HOMO-LUMO gap: 0.007352227194009395 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  18.10305398307984
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642288
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026565066
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102958622
# Coulomb Energy                  1039.7254935642652
# Exchange-Correlation Energy      -89.9717584581067
# --------------------------------------------------
# Total Energy                    -689.6320111372540
# --------------------------------------------------
#
#
#
# Energy difference :  44.111334932984846
#
#
# HOMO-LUMO gap: 0.010701793699551584 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  13.034260103685252
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576003
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022388540
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470598615
# Coulomb Energy                  1004.3417767420915
# Exchange-Correlation Energy      -89.2334391643039
# --------------------------------------------------
# Total Energy                    -749.6400714839733
# --------------------------------------------------
#
#
#
# Energy difference :  60.008060346719276
#
#
# HOMO-LUMO gap: 0.025771351278294115 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.653358064504943
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554303
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132845109
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410026
# Coulomb Energy                   997.3319760641319
# Exchange-Correlation Energy      -89.6717481072290
# --------------------------------------------------
# Total Energy                    -755.2352624693737
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985400336
#
#
# HOMO-LUMO gap: 0.003568479513740508 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.30973833518219
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567743
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204409195
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857160365
# Coulomb Energy                  1009.6464766733554
# Exchange-Correlation Energy      -89.9069114778972
# --------------------------------------------------
# Total Energy                    -755.2788234121929
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094281922651
#
#
# HOMO-LUMO gap: 0.009175061890360395 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  8.057132717270745
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00050300163967
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153729200
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119324396
# Coulomb Energy                  1035.0050622426686
# Exchange-Correlation Energy      -92.6658378595642
# --------------------------------------------------
# Total Energy                    -747.5712329401442
# --------------------------------------------------
#
#
#
# Energy difference :  7.7075904720486506
#
#
# HOMO-LUMO gap: 0.11766237193419213 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.715013429028868
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306774
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903706336
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992836557
# Coulomb Energy                  1048.9988443905131
# Exchange-Correlation Energy      -94.9610811405096
# --------------------------------------------------
# Total Energy                    -761.7908817197426
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779598401
#
#
# HOMO-LUMO gap: 0.010925426636142946 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  6.790315749575923
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377906
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412172799
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466858345
# Coulomb Energy                  1013.7508689108342
# Exchange-Correlation Energy      -90.9428726052161
# --------------------------------------------------
# Total Energy                    -756.2816521085954
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229611147248
#
#
# HOMO-LUMO gap: 0.14929732699086157 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  6.534633252954647
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202662
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716116153
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461516949
# Coulomb Energy                  1025.7750806794695
# Exchange-Correlation Energy      -92.2703810888974
# --------------------------------------------------
# Total Energy                    -762.7969797521166
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327643521232
#
#
# HOMO-LUMO gap: 0.1335269786332695 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.5338338749187144
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332055
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534575
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792903001
# Coulomb Energy                  1024.7461321400510
# Exchange-Correlation Energy      -92.1885648748862
# --------------------------------------------------
# Total Energy                    -762.8402252807609
# --------------------------------------------------
#
#
#
# Energy difference :  0.043245528644320075
#
#
# HOMO-LUMO gap: 0.11056223798906493 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.3602713359513966
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916643
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590201749
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517292619
# Coulomb Energy                  1023.6379077072953
# Exchange-Correlation Energy      -92.0697499681736
# --------------------------------------------------
# Total Energy                    -762.8490034345594
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153798516541
#
#
# HOMO-LUMO gap: 0.08600353273578998 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.3252988566937313
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680042
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240861208
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261721234
# Coulomb Energy                  1024.4836887099161
# Exchange-Correlation Energy      -92.1371699397401
# --------------------------------------------------
# Total Energy                    -762.8531330265894
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592029926243
#
#
# HOMO-LUMO gap: 0.11636080747232105 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.15534224612143094
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503604
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117169550
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900056220
# Coulomb Energy                  1024.5663100626509
# Exchange-Correlation Energy      -92.1605267750504
# --------------------------------------------------
# Total Energy                    -762.8605923065008
# --------------------------------------------------
#
#
#
# Energy difference :  0.007459279911472549
#
#
# HOMO-LUMO gap: 0.12269239243300237 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.04060711222916676
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000072218656
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080933
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362895
# Coulomb Energy                  1024.7015706722646
# Exchange-Correlation Energy      -92.1773633390801
# --------------------------------------------------
# Total Energy                    -762.8609189213871
# --------------------------------------------------
#
#
#
# Energy difference :  0.0003266148862621776
#
#
# HOMO-LUMO gap: 0.11742913476004528 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.019703163523945088
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471097
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348739760
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958570091
# Coulomb Energy                  1024.5590092024509
# Exchange-Correlation Energy      -92.1602830990780
# --------------------------------------------------
# Total Energy                    -762.8609667963619
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497482539038e-05
#
#
# HOMO-LUMO gap: 0.11815573488986464 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.008211499893299905
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163928
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862282
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811666
# Coulomb Energy                  1024.5676148746729
# Exchange-Correlation Energy      -92.1612728329148
# --------------------------------------------------
# Total Energy                    -762.8609882460714
# --------------------------------------------------
#
#
#
# Energy difference :  2.1449709493026603e-05
#
#
# HOMO-LUMO gap: 0.11842571032121077 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0019148361579435797
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786602
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971850
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346319
# Coulomb Energy                  1024.5642249369646
# Exchange-Correlation Energy      -92.1610088236044
# --------------------------------------------------
# Total Energy                    -762.8609886319607
# --------------------------------------------------
#
#
#
# Energy difference :  3.858892796415603e-07
#
#
# HOMO-LUMO gap: 0.11835771606484607 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.001077639615107941
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816395
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020317
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743308
# Coulomb Energy                  1024.5683629999314
# Exchange-Correlation Energy      -92.1613819110202
# --------------------------------------------------
# Total Energy                    -762.8609888215581
# --------------------------------------------------
#
#
#
# Energy difference :  1.895973582577426e-07
#
#
# HOMO-LUMO gap: 0.11837118338566939 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0005041312661475895
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785556
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158467
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323651
# Coulomb Energy                  1024.5701171428861
# Exchange-Correlation Energy      -92.1615907612851
# --------------------------------------------------
# Total Energy                    -762.8609888846483
# --------------------------------------------------
#
#
#
# Energy difference :  6.309028321993537e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846483
# -------------------------------------
#
#
#
# Time taken : 19.13 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.05
# Density Fitting                         0.44
#     DF (gamma)                          0.12
#     DF (coeff)                          0.08
#     DF (Jtri)                           0.21
# DIIS                                    0.12
# KS matrix diagonalization               0.54
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.43
# Grids construction                      0.95
# Exchange-Correlation Term               11.21
# Misc.                                   1.35
# Complete SCF                            19.13

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.24 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.006547649999959049
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.29
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.37 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.53 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.32 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.18 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355700
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973782
# --------------------------------------------------
#
#
#
# Energy difference :  374.9303338973782
#
#
# HOMO-LUMO gap: 1.85028644354108 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  107.82844284432957
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999855877294
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067290
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391765801
# Coulomb Energy                  3537.3287033060496
# Exchange-Correlation Energy     -250.6110528162023
# --------------------------------------------------
# Total Energy                   -1359.8923755096403
# --------------------------------------------------
#
#
#
# Energy difference :  984.962041612262
#
#
# HOMO-LUMO gap: 0.002113921644304795 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  57.36707021915377
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512907
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256491716
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810813019
# Coulomb Energy                  2705.3966179574250
# Exchange-Correlation Energy     -151.8752804393573
# --------------------------------------------------
# Total Energy                   -1419.0480632191397
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770949949
#
#
# HOMO-LUMO gap: 0.01974072374042546 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  48.04719016374658
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00017178492394
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823855206
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892855324
# Coulomb Energy                  3071.8764250118988
# Exchange-Correlation Energy     -174.7460035329473
# --------------------------------------------------
# Total Energy                   -1362.4047277903751
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542876466
#
#
# HOMO-LUMO gap: 0.014747714724284697 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  40.92570828252577
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158718
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198127082
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571582862
# Coulomb Energy                  3051.7165832279902
# Exchange-Correlation Energy     -176.2007428393713
# --------------------------------------------------
# Total Energy                   -1378.8564784351415
# --------------------------------------------------
#
#
#
# Energy difference :  16.451750644766435
#
#
# HOMO-LUMO gap: 0.012539973802182705 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  26.932582172195996
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863944
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022789523
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850556449
# Coulomb Energy                  3003.5375755726586
# Exchange-Correlation Energy     -179.3125720191581
# --------------------------------------------------
# Total Energy                   -1523.5033698391449
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140400333
#
#
# HOMO-LUMO gap: 0.0030874947632617573 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  13.423370100275791
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488927
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332569211
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671362157
# Coulomb Energy                  2977.4795296021612
# Exchange-Correlation Energy     -178.1026352539977
# --------------------------------------------------
# Total Energy                   -1499.0865279418804
# --------------------------------------------------
#
#
#
# Energy difference :  24.416841897264476
#
#
# HOMO-LUMO gap: 0.0318146127276516 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  12.444575042424109
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146524
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885444200
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462463330
# Coulomb Energy                  3000.9261851727492
# Exchange-Correlation Energy     -180.8962339957995
# --------------------------------------------------
# Total Energy                   -1522.7463472904751
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348594738
#
#
# HOMO-LUMO gap: 0.012952412898511984 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 2.36 seconds
#
#
#
# Density matrix difference norm:  6.016412544061762
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00012192201388
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025155886
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516681702
# Coulomb Energy                  3041.7824359801130
# Exchange-Correlation Energy     -185.1339645332755
# --------------------------------------------------
# Total Energy                   -1523.4476355699185
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794433608
#
#
# HOMO-LUMO gap: 0.02147354980955421 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  6.222751705224652
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99995948810573
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888913150
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569992130
# Coulomb Energy                  3063.1248487683106
# Exchange-Correlation Energy     -185.9132949764586
# --------------------------------------------------
# Total Energy                   -1521.9201342695878
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013003306412
#
#
# HOMO-LUMO gap: 0.07988335373135988 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  4.43484852364825
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846706
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733682534
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444891357
# Coulomb Energy                  3048.3985990984688
# Exchange-Correlation Energy     -185.3448733864983
# --------------------------------------------------
# Total Energy                   -1525.5849593364860
# --------------------------------------------------
#
#
#
# Energy difference :  3.6648250668981746
#
#
# HOMO-LUMO gap: 0.11911980736608177 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.8335133099901367
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000381243774
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577372680
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794424
# Coulomb Energy                  3044.2765927793594
# Exchange-Correlation Energy     -184.7849150214345
# --------------------------------------------------
# Total Energy                   -1525.7423647692390
# --------------------------------------------------
#
#
#
# Energy difference :  0.1574054327529666
#
#
# HOMO-LUMO gap: 0.1091438515171565 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.43782033360685435
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733324
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238684333
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349566
# Coulomb Energy                  3039.9455617679696
# Exchange-Correlation Energy     -184.3161788613700
# --------------------------------------------------
# Total Energy                   -1525.7678971962150
# --------------------------------------------------
#
#
#
# Energy difference :  0.02553242697604219
#
#
# HOMO-LUMO gap: 0.08055636124781483 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.27956022877736314
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976176
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906379
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116194
# Coulomb Energy                  3041.4914846757283
# Exchange-Correlation Energy     -184.5235703798686
# --------------------------------------------------
# Total Energy                   -1525.7860021524966
# --------------------------------------------------
#
#
#
# Energy difference :  0.018104956281604245
#
#
# HOMO-LUMO gap: 0.03553321190368865 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.20188173700730694
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004068429737
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555703095
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365257965
# Coulomb Energy                  3040.7248454919149
# Exchange-Correlation Energy     -184.4775892871842
# --------------------------------------------------
# Total Energy                   -1525.7891190091218
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031168566251835728
#
#
# HOMO-LUMO gap: 0.04487089486648302 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.0762529310455037
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003965723616
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379110884
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103526
# Coulomb Energy                  3040.4560830346354
# Exchange-Correlation Energy     -184.4308753791038
# --------------------------------------------------
# Total Energy                   -1525.7902311145417
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011121054199065838
#
#
# HOMO-LUMO gap: 0.0528566413681847 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.028372083618935142
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003947131012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669641506
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980731
# Coulomb Energy                  3040.4602645949676
# Exchange-Correlation Energy     -184.4309026475792
# --------------------------------------------------
# Total Energy                   -1525.7903707880264
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348468213459
#
#
# HOMO-LUMO gap: 0.04994812744063622 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.012785251242885518
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505595
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931496
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318386
# Coulomb Energy                  3040.4067159125952
# Exchange-Correlation Energy     -184.4260067735680
# --------------------------------------------------
# Total Energy                   -1525.7903870916234
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303597021760652e-05
#
#
# HOMO-LUMO gap: 0.050833655730507715 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.006040021432474771
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112013
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954897
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920823
# Coulomb Energy                  3040.4581957845244
# Exchange-Correlation Energy     -184.4326037898919
# --------------------------------------------------
# Total Energy                   -1525.7903978781137
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786490292957751e-05
#
#
# HOMO-LUMO gap: 0.05068603589628108 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.0019655407525173045
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378543
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801126800
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451551
# Coulomb Energy                  3040.4659355248646
# Exchange-Correlation Energy     -184.4328301188920
# --------------------------------------------------
# Total Energy                   -1525.7903988308894
# --------------------------------------------------
#
#
#
# Energy difference :  9.527757356408983e-07
#
#
# HOMO-LUMO gap: 0.050712621256484486 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.0010394322839581114
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780362
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447637
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272611149
# Coulomb Energy                  3040.4701320976224
# Exchange-Correlation Energy     -184.4333553536738
# --------------------------------------------------
# Total Energy                   -1525.7903988090379
# --------------------------------------------------
#
#
#
# Energy difference :  2.1851519704796374e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.790398809038
# -------------------------------------
#
#
#
# Time taken : 74.23 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.5
# Density Fitting                         1.25
#     DF (gamma)                          0.26
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.81
# DIIS                                    0.58
# KS matrix diagonalization               1.03
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         11.37
# Grids construction                      4.53
# Exchange-Correlation Term               45.44
# Misc.                                   2.45
# Complete SCF                            74.23

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.14 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.52 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.09
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.01636537199999566
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.11 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.68
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  28.34 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 15.88 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 20.43 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.43 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0029198407821
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004588
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513719
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513719
#
#
# HOMO-LUMO gap: 1.3453174761624371 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 5.53 seconds
#
#
#
# Density matrix difference norm:  144.01406386863277
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.999967207153
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016248959
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642082269
# Coulomb Energy                  7102.4006978647531
# Exchange-Correlation Energy     -401.0386878050915
# --------------------------------------------------
# Total Energy                   -2175.7881061963935
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450216
#
#
# HOMO-LUMO gap: 0.0036326528168114103 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 5.62 seconds
#
#
#
# Density matrix difference norm:  71.9942723965237
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247207
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645635625
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936840
# Coulomb Energy                  5771.7138319764108
# Exchange-Correlation Energy     -243.8524720617049
# --------------------------------------------------
# Total Energy                   -2274.5129129945581
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679816454
#
#
# HOMO-LUMO gap: 0.004964611534803917 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 5.67 seconds
#
#
#
# Density matrix difference norm:  58.10070148964802
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00214404156077
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804032336
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573468902
# Coulomb Energy                  6321.7172809531858
# Exchange-Correlation Energy     -278.3781618573279
# --------------------------------------------------
# Total Energy                   -2158.4748827998719
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019468614
#
#
# HOMO-LUMO gap: 0.014474030560725104 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  53.369975492391525
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00180767720957
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768209668
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230005960
# Coulomb Energy                  6361.2336350668447
# Exchange-Correlation Energy     -281.9436333440921
# --------------------------------------------------
# Total Energy                   -2182.5642309370032
# --------------------------------------------------
#
#
#
# Energy difference :  24.08934813713131
#
#
# HOMO-LUMO gap: 0.00884169399532192 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  42.839015094873226
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00099084148957
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446994334
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382080052
# Coulomb Energy                  6294.5110601801462
# Exchange-Correlation Energy     -283.9707682331572
# --------------------------------------------------
# Total Energy                   -2345.8009933838239
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676244682065
#
#
# HOMO-LUMO gap: 0.007160714252311948 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 5.82 seconds
#
#
#
# Density matrix difference norm:  32.18186260037507
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99978638551784
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019076815
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650760761
# Coulomb Energy                  6214.1516556244951
# Exchange-Correlation Energy     -284.6344014151225
# --------------------------------------------------
# Total Energy                   -2343.5239614616185
# --------------------------------------------------
#
#
#
# Energy difference :  2.277031922205424
#
#
# HOMO-LUMO gap: 0.002450375010372277 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  33.32333313970424
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156512
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115038202
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996833889
# Coulomb Energy                  6284.6237009936085
# Exchange-Correlation Energy     -286.3084442723677
# --------------------------------------------------
# Total Energy                   -2352.7413339385766
# --------------------------------------------------
#
#
#
# Energy difference :  9.21737247695819
#
#
# HOMO-LUMO gap: 0.006673318413002949 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  26.098281915625748
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002679784588
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383661166
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896545892
# Coulomb Energy                  6418.8046173127914
# Exchange-Correlation Energy     -305.3162932884719
# --------------------------------------------------
# Total Energy                   -2410.9382035265953
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686958801867
#
#
# HOMO-LUMO gap: 0.007960539577338305 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  17.534698642342786
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855115
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057267398
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201862895
# Coulomb Energy                  6329.9135850855309
# Exchange-Correlation Energy     -297.7524519058510
# --------------------------------------------------
# Total Energy                   -2373.3942312001564
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397232643896
#
#
# HOMO-LUMO gap: 0.01399783856606518 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  16.42070464488338
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982379832295
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814645429
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928330616
# Coulomb Energy                  6324.0705156582335
# Exchange-Correlation Energy     -296.6169927423358
# --------------------------------------------------
# Total Energy                   -2423.4444445549689
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335481251
#
#
# HOMO-LUMO gap: 0.0058017168933721525 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 5.68 seconds
#
#
#
# Density matrix difference norm:  17.91362907369547
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082557727933
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871579857
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553249433
# Coulomb Energy                  6269.4959589830223
# Exchange-Correlation Energy     -292.3687260434510
# --------------------------------------------------
# Total Energy                   -2388.5334777328562
# --------------------------------------------------
#
#
#
# Energy difference :  34.91096682211264
#
#
# HOMO-LUMO gap: 0.011739724645369945 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 5.66 seconds
#
#
#
# Density matrix difference norm:  18.86481092841818
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00089534288895
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999715336
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986962301
# Coulomb Energy                  6304.9912271460043
# Exchange-Correlation Energy     -292.7049362975931
# --------------------------------------------------
# Total Energy                   -2419.7690892662768
# --------------------------------------------------
#
#
#
# Energy difference :  31.235611533420524
#
#
# HOMO-LUMO gap: 0.001699592575100009 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 5.63 seconds
#
#
#
# Density matrix difference norm:  14.26893860222186
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000154315005
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930594295
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204733840
# Coulomb Energy                  6279.2250589653768
# Exchange-Correlation Energy     -293.0502585451661
# --------------------------------------------------
# Total Energy                   -2419.7439510052200
# --------------------------------------------------
#
#
#
# Energy difference :  0.02513826105678163
#
#
# HOMO-LUMO gap: 0.005846431219634629 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 5.64 seconds
#
#
#
# Density matrix difference norm:  12.51286101119046
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002651218395
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104152820
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140348892
# Coulomb Energy                  6304.4543925170146
# Exchange-Correlation Energy     -294.2073055525112
# --------------------------------------------------
# Total Energy                   -2431.0698882552733
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937250053357
#
#
# HOMO-LUMO gap: 0.016452349552930873 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 5.64 seconds
#
#
#
# Density matrix difference norm:  10.313139444397107
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775217
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763851032
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614184712
# Coulomb Energy                  6320.4324015799866
# Exchange-Correlation Energy     -296.9899338050403
# --------------------------------------------------
# Total Energy                   -2429.5155260310712
# --------------------------------------------------
#
#
#
# Energy difference :  1.5543622242021229
#
#
# HOMO-LUMO gap: 0.0050643510606497855 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  8.084972669648277
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00009764058916
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466508380
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611216587
# Coulomb Energy                  6316.3510406928453
# Exchange-Correlation Energy     -296.7435745386293
# --------------------------------------------------
# Total Energy                   -2437.9484982143495
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972183278252
#
#
# HOMO-LUMO gap: 0.05893038876116445 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  4.1026048501864185
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001181061176
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030002518
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451737982
# Coulomb Energy                  6313.1881517242746
# Exchange-Correlation Energy     -295.9055099897765
# --------------------------------------------------
# Total Energy                   -2441.0025949313404
# --------------------------------------------------
#
#
#
# Energy difference :  3.054096716990898
#
#
# HOMO-LUMO gap: 0.005337250463427576 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 5.66 seconds
#
#
#
# Density matrix difference norm:  6.2540764811129534
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361986984
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051654387
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545138139
# Coulomb Energy                  6280.4277633869324
# Exchange-Correlation Energy     -293.2139724472589
# --------------------------------------------------
# Total Energy                   -2436.9286385513360
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956380004347
#
#
# HOMO-LUMO gap: 0.011871839815972562 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 5.67 seconds
#
#
#
# Density matrix difference norm:  7.41337541110065
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002633558748
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726554932266
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918847545
# Coulomb Energy                  6298.7681987394717
# Exchange-Correlation Energy     -294.0996241348905
# --------------------------------------------------
# Total Energy                   -2439.1315678432766
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292919405634
#
#
# HOMO-LUMO gap: 0.1036299979617886 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  4.188397589673535
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011624361326
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485023042
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696463661
# Coulomb Energy                  6305.6013415990119
# Exchange-Correlation Energy     -295.1700654130581
# --------------------------------------------------
# Total Energy                   -2441.2043815093703
# --------------------------------------------------
#
#
#
# Energy difference :  2.07281366609368
#
#
# HOMO-LUMO gap: 0.030358347409132354 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  1.088118680079166
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001058435006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355852297
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042573087
# Coulomb Energy                  6306.4146008190110
# Exchange-Correlation Energy     -295.1986114171302
# --------------------------------------------------
# Total Energy                   -2441.2281207654250
# --------------------------------------------------
#
#
#
# Energy difference :  0.023739256054795987
#
#
# HOMO-LUMO gap: 0.10156738659079725 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  0.6147083203776302
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011386478917
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391413735
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706639414
# Coulomb Energy                  6305.3788664343992
# Exchange-Correlation Energy     -295.1059315049073
# --------------------------------------------------
# Total Energy                   -2441.3391123873262
# --------------------------------------------------
#
#
#
# Energy difference :  0.1109916219011211
#
#
# HOMO-LUMO gap: 0.12914420510541164 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  0.22866753079587504
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011297097154
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680215962446
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454847921
# Coulomb Energy                  6306.4753103323856
# Exchange-Correlation Energy     -295.2425453762324
# --------------------------------------------------
# Total Energy                   -2441.3433899946849
# --------------------------------------------------
#
#
#
# Energy difference :  0.004277607358744717
#
#
# HOMO-LUMO gap: 0.11914092715738014 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  0.13316828790065902
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001144292401
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663329468
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009439010
# Coulomb Energy                  6305.4375957438642
# Exchange-Correlation Energy     -295.1178679620500
# --------------------------------------------------
# Total Energy                   -2441.3482164466168
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451931876363
#
#
# HOMO-LUMO gap: 0.07758609961379725 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  0.16794684438216195
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001191827324
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810457881
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356943962
# Coulomb Energy                  6304.4474550023588
# Exchange-Correlation Energy     -294.9863691582348
# --------------------------------------------------
# Total Energy                   -2441.3482383466526
# --------------------------------------------------
#
#
#
# Energy difference :  2.190003579016775e-05
#
#
# HOMO-LUMO gap: 0.08220407416097275 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  0.08195634556848086
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011761289034
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560669416
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184231677
# Coulomb Energy                  6305.2666287323791
# Exchange-Correlation Energy     -295.0991774795590
# --------------------------------------------------
# Total Energy                   -2441.3500652303392
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836865900084
#
#
# HOMO-LUMO gap: 0.08681393247689209 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  0.030947650042408365
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711137
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449608792
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969466848
# Coulomb Energy                  6305.1999901384024
# Exchange-Correlation Energy     -295.0882138897849
# --------------------------------------------------
# Total Energy                   -2441.3501506049615
# --------------------------------------------------
#
#
#
# Energy difference :  8.537462235835847e-05
#
#
# HOMO-LUMO gap: 0.08605512219099319 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 5.68 seconds
#
#
#
# Density matrix difference norm:  0.01535942013165749
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174124385
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082986259
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754508768
# Coulomb Energy                  6305.1611656009445
# Exchange-Correlation Energy     -295.0851653175728
# --------------------------------------------------
# Total Energy                   -2441.3502114037619
# --------------------------------------------------
#
#
#
# Energy difference :  6.079880040488206e-05
#
#
# HOMO-LUMO gap: 0.08610559555000058 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.68 seconds
#
#
#
# Density matrix difference norm:  0.005850728287958381
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730802623
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341357642
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624064319
# Coulomb Energy                  6305.1739654234188
# Exchange-Correlation Energy     -295.0859344062346
# --------------------------------------------------
# Total Energy                   -2441.3502195515321
# --------------------------------------------------
#
#
#
# Energy difference :  8.147770131472498e-06
#
#
# HOMO-LUMO gap: 0.0862775338028681 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.68 seconds
#
#
#
# Density matrix difference norm:  0.0022687655702161766
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173037932
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171301813
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318814
# Coulomb Energy                  6305.1767750460158
# Exchange-Correlation Energy     -295.0862921108214
# --------------------------------------------------
# Total Energy                   -2441.3502203024918
# --------------------------------------------------
#
#
#
# Energy difference :  7.509597708121873e-07
#
#
# HOMO-LUMO gap: 0.08629954674345985 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.67 seconds
#
#
#
# Density matrix difference norm:  0.0014216232819947042
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161182
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335500909
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841015765
# Coulomb Energy                  6305.1678310988791
# Exchange-Correlation Energy     -295.0851232567571
# --------------------------------------------------
# Total Energy                   -2441.3502204457782
# --------------------------------------------------
#
#
#
# Energy difference :  1.4328634279081598e-07
#
#
# HOMO-LUMO gap: 0.08625864034200609 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.67 seconds
#
#
#
# Density matrix difference norm:  0.000790521365968544
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173192671
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319235
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598465
# Coulomb Energy                  6305.1716231999053
# Exchange-Correlation Energy     -295.0855737005015
# --------------------------------------------------
# Total Energy                   -2441.3502206120593
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628109733574092e-07
#
#
# HOMO-LUMO gap: 0.08626853544517904 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  0.000286320217459449
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173138948
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851890228
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651371021
# Coulomb Energy                  6305.1740152928323
# Exchange-Correlation Energy     -295.0859370217365
# --------------------------------------------------
# Total Energy                   -2441.3502206202102
# --------------------------------------------------
#
#
#
# Energy difference :  8.150891517288983e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.35022062021
# -------------------------------------
#
#
#
# Time taken : 262.1 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           20.86
# Density Fitting                         5.58
#     DF (gamma)                          1.04
#     DF (coeff)                          0.16
#     DF (Jtri)                           4.0
# DIIS                                    3.78
# KS matrix diagonalization               3.8
# One electron Integrals (S, T, Vnuc)     0.14
# Coulomb Integrals (2c2e + 3c2e)         28.34
# Grids construction                      15.88
# Exchange-Correlation Term               179.69
# Misc.                                   4.04
# Complete SCF                            262.1

# %% [markdown]
# ### Benchmark #4 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.22 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.92 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.17
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04516452000007121
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.23 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  1.46
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  66.44 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 50.72 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 55.01 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.41 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00086590367755
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182683
# Exchange-Correlation Energy     -158.3094688039744
# --------------------------------------------------
# Total Energy                    -881.4876584497451
# --------------------------------------------------
#
#
#
# Energy difference :  881.4876584497451
#
#
# HOMO-LUMO gap: 0.6897308990674156 au
# HOMO-LUMO gap: 18.768 eV
#
#
# Time taken for the previous iteration: 13.78 seconds
#
#
#
# Density matrix difference norm:  177.41183356976833
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999463807943
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3704438290588
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5625483778804
# Coulomb Energy                 12707.6655166372548
# Exchange-Correlation Energy     -589.0109863900053
# --------------------------------------------------
# Total Energy                   -3195.6961127770101
# --------------------------------------------------
#
#
#
# Energy difference :  2314.208454327265
#
#
# HOMO-LUMO gap: 0.0026210885491978475 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 14.06 seconds
#
#
#
# Density matrix difference norm:  86.10072559739262
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006718457629
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.0784549163945
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9542974309948
# Coulomb Energy                 10864.6104283852219
# Exchange-Correlation Energy     -358.7264210078262
# --------------------------------------------------
# Total Energy                   -3357.7828976810797
# --------------------------------------------------
#
#
#
# Energy difference :  162.08678490406965
#
#
# HOMO-LUMO gap: 0.002532292525701231 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 13.91 seconds
#
#
#
# Density matrix difference norm:  65.13264429189617
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000815955638
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9266970285826
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4589790561572
# Coulomb Energy                 11125.2421950881817
# Exchange-Correlation Energy     -407.6867498868726
# --------------------------------------------------
# Total Energy                   -3374.4550203441941
# --------------------------------------------------
#
#
#
# Energy difference :  16.67212266311435
#
#
# HOMO-LUMO gap: 0.0044143899569700495 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 13.8 seconds
#
#
#
# Density matrix difference norm:  63.85668121077735
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995348429838
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.2877136077441
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.8757373775370
# Coulomb Energy                 12063.6748125258600
# Exchange-Correlation Energy     -415.0710986786185
# --------------------------------------------------
# Total Energy                   -3056.3510099560426
# --------------------------------------------------
#
#
#
# Energy difference :  318.10401038815144
#
#
# HOMO-LUMO gap: 0.006644147332959496 au
# HOMO-LUMO gap: 0.181 eV
#
#
# Time taken for the previous iteration: 13.76 seconds
#
#
#
# Density matrix difference norm:  54.591690612609206
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002691352939
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.5088611894316
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.3924608743018
# Coulomb Energy                 11512.9997141053100
# Exchange-Correlation Energy     -417.4553406800684
# --------------------------------------------------
# Total Energy                   -3536.1147744629652
# --------------------------------------------------
#
#
#
# Energy difference :  479.7637645069226
#
#
# HOMO-LUMO gap: 0.001012361499700935 au
# HOMO-LUMO gap: 0.028 eV
#
#
# Time taken for the previous iteration: 13.84 seconds
#
#
#
# Density matrix difference norm:  51.11495004684808
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99974294779867
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.1797883155887
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.7800541096717
# Coulomb Energy                 11567.1010375790756
# Exchange-Correlation Energy     -419.4337655480275
# --------------------------------------------------
# Total Energy                   -3074.2752097479442
# --------------------------------------------------
#
#
#
# Energy difference :  461.83956471502097
#
#
# HOMO-LUMO gap: 0.004697471687304083 au
# HOMO-LUMO gap: 0.128 eV
#
#
# Time taken for the previous iteration: 13.88 seconds
#
#
#
# Density matrix difference norm:  44.744826455186626
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99965507497257
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.4126884143698
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6364207737088
# Coulomb Energy                 11495.5483931942872
# Exchange-Correlation Energy     -423.7795770218116
# --------------------------------------------------
# Total Energy                   -3532.5501990412613
# --------------------------------------------------
#
#
#
# Energy difference :  458.27498929331705
#
#
# HOMO-LUMO gap: 0.000463397593153822 au
# HOMO-LUMO gap: 0.013 eV
#
#
# Time taken for the previous iteration: 13.94 seconds
#
#
#
# Density matrix difference norm:  20.712738436619652
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99995454344906
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.2739432053495
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.0351193086044
# Coulomb Energy                 11580.0530323967832
# Exchange-Correlation Energy     -439.2769213915549
# --------------------------------------------------
# Total Energy                   -3535.0054604645939
# --------------------------------------------------
#
#
#
# Energy difference :  2.4552614233325585
#
#
# HOMO-LUMO gap: 0.007602901056502409 au
# HOMO-LUMO gap: 0.207 eV
#
#
# Time taken for the previous iteration: 13.98 seconds
#
#
#
# Density matrix difference norm:  17.82978163264534
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00025109396506
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28135.5805671730413
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3632.4560413248159
# Coulomb Energy                 11640.5650665720423
# Exchange-Correlation Energy     -443.9779460360385
# --------------------------------------------------
# Total Energy                   -3536.0801528852990
# --------------------------------------------------
#
#
#
# Energy difference :  1.0746924207051052
#
#
# HOMO-LUMO gap: 0.004336286716245447 au
# HOMO-LUMO gap: 0.118 eV
#
#
# Time taken for the previous iteration: 13.98 seconds
#
#
#
# Density matrix difference norm:  21.750787712799692
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000976497027
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27873.9019927328482
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3557.6224523782553
# Coulomb Energy                 11493.5519516829736
# Exchange-Correlation Energy     -433.3671342231762
# --------------------------------------------------
# Total Energy                   -3485.6374704678728
# --------------------------------------------------
#
#
#
# Energy difference :  50.44268241742611
#
#
# HOMO-LUMO gap: 0.017999779935561705 au
# HOMO-LUMO gap: 0.490 eV
#
#
# Time taken for the previous iteration: 13.98 seconds
#
#
#
# Density matrix difference norm:  18.3048200061851
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001218986369
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28089.3481557879386
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3573.7337556396815
# Coulomb Energy                 11601.6672610746555
# Exchange-Correlation Energy     -437.8374210788215
# --------------------------------------------------
# Total Energy                   -3581.3273077254998
# --------------------------------------------------
#
#
#
# Energy difference :  95.689837257627
#
#
# HOMO-LUMO gap: 0.009809885515320763 au
# HOMO-LUMO gap: 0.267 eV
#
#
# Time taken for the previous iteration: 13.95 seconds
#
#
#
# Density matrix difference norm:  15.60359096816343
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00000844554376
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27851.1830279530332
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3504.4630744563692
# Coulomb Energy                 11481.6334494337498
# Exchange-Correlation Energy     -426.3111912647728
# --------------------------------------------------
# Total Energy                   -3520.9404429007645
# --------------------------------------------------
#
#
#
# Energy difference :  60.38686482473531
#
#
# HOMO-LUMO gap: 0.001282481854389339 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 13.93 seconds
#
#
#
# Density matrix difference norm:  15.434069736317175
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9998788034346
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27993.2533791355672
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3536.1983087229009
# Coulomb Energy                 11535.6719784069064
# Exchange-Correlation Energy     -432.7365140879126
# --------------------------------------------------
# Total Energy                   -3583.6623536667485
# --------------------------------------------------
#
#
#
# Energy difference :  62.72191076598392
#
#
# HOMO-LUMO gap: 0.004883566959553998 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 13.91 seconds
#
#
#
# Density matrix difference norm:  4.9951812625399015
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000251702252
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27981.3353220632052
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9571867317691
# Coulomb Energy                 11529.5195397927400
# Exchange-Correlation Energy     -431.6645533273921
# --------------------------------------------------
# Total Energy                   -3583.0658964391660
# --------------------------------------------------
#
#
#
# Energy difference :  0.5964572275825049
#
#
# HOMO-LUMO gap: 0.047205167216128094 au
# HOMO-LUMO gap: 1.285 eV
#
#
# Time taken for the previous iteration: 13.95 seconds
#
#
#
# Density matrix difference norm:  4.204244966505816
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000294393827
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27999.1239632603101
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.4625395793664
# Coulomb Energy                 11537.2109865889397
# Exchange-Correlation Energy     -433.3658591663625
# --------------------------------------------------
# Total Energy                   -3585.3590438314441
# --------------------------------------------------
#
#
#
# Energy difference :  2.293147392278115
#
#
# HOMO-LUMO gap: 0.10565060439816276 au
# HOMO-LUMO gap: 2.875 eV
#
#
# Time taken for the previous iteration: 13.94 seconds
#
#
#
# Density matrix difference norm:  0.9287339647937248
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001987441766
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1957017676541
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.6973782444852
# Coulomb Energy                 11540.9990090386109
# Exchange-Correlation Energy     -433.6709885961665
# --------------------------------------------------
# Total Energy                   -3585.7130506538051
# --------------------------------------------------
#
#
#
# Energy difference :  0.3540068223610433
#
#
# HOMO-LUMO gap: 0.08160175610987358 au
# HOMO-LUMO gap: 2.220 eV
#
#
# Time taken for the previous iteration: 13.98 seconds
#
#
#
# Density matrix difference norm:  0.4709949272385319
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000154375355
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27997.2512011245090
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3537.3766043743244
# Coulomb Energy                 11536.7451397175137
# Exchange-Correlation Energy     -433.0466480079534
# --------------------------------------------------
# Total Energy                   -3585.7188526137015
# --------------------------------------------------
#
#
#
# Energy difference :  0.00580195989641652
#
#
# HOMO-LUMO gap: 0.09622541990549524 au
# HOMO-LUMO gap: 2.618 eV
#
#
# Time taken for the previous iteration: 13.97 seconds
#
#
#
# Density matrix difference norm:  0.2534565959302062
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000167447794
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.5564266628135
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5447396021777
# Coulomb Energy                 11540.2918407684956
# Exchange-Correlation Energy     -433.4718308800191
# --------------------------------------------------
# Total Energy                   -3585.7344247452365
# --------------------------------------------------
#
#
#
# Energy difference :  0.015572131535009248
#
#
# HOMO-LUMO gap: 0.10308245712344007 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 13.95 seconds
#
#
#
# Density matrix difference norm:  0.10396169328191911
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000172884529
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6842585323138
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6972359562005
# Coulomb Energy                 11539.1501773381133
# Exchange-Correlation Energy     -433.3563238172795
# --------------------------------------------------
# Total Energy                   -3585.7359166283550
# --------------------------------------------------
#
#
#
# Energy difference :  0.0014918831184331793
#
#
# HOMO-LUMO gap: 0.10375679451149246 au
# HOMO-LUMO gap: 2.823 eV
#
#
# Time taken for the previous iteration: 13.96 seconds
#
#
#
# Density matrix difference norm:  0.04580938239369785
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000016399944
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0103516336603
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8693000353755
# Coulomb Energy                 11539.3276464970186
# Exchange-Correlation Energy     -433.3803352171810
# --------------------------------------------------
# Total Energy                   -3585.7364878915268
# --------------------------------------------------
#
#
#
# Energy difference :  0.0005712631718779448
#
#
# HOMO-LUMO gap: 0.10309625426339622 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 13.92 seconds
#
#
#
# Density matrix difference norm:  0.02955431172737183
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163506747
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8156482878985
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7421798296955
# Coulomb Energy                 11539.2423484490464
# Exchange-Correlation Energy     -433.3626933923828
# --------------------------------------------------
# Total Energy                   -3585.7365609746175
# --------------------------------------------------
#
#
#
# Energy difference :  7.30830906832125e-05
#
#
# HOMO-LUMO gap: 0.10314551118660345 au
# HOMO-LUMO gap: 2.807 eV
#
#
# Time taken for the previous iteration: 13.92 seconds
#
#
#
# Density matrix difference norm:  0.01795940037528319
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001612485124
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0456961848031
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8499452942301
# Coulomb Energy                 11539.3793324890248
# Exchange-Correlation Energy     -433.3773972627867
# --------------------------------------------------
# Total Energy                   -3585.7365632374112
# --------------------------------------------------
#
#
#
# Energy difference :  2.2627937141805887e-06
#
#
# HOMO-LUMO gap: 0.10320225768006014 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 13.94 seconds
#
#
#
# Density matrix difference norm:  0.010130198633040838
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162381155
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9409515230436
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096975042572
# Coulomb Energy                 11539.3092434282335
# Exchange-Correlation Energy     -433.3718359102043
# --------------------------------------------------
# Total Energy                   -3585.7365940738364
# --------------------------------------------------
#
#
#
# Energy difference :  3.0836425139568746e-05
#
#
# HOMO-LUMO gap: 0.10326233783275197 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 13.95 seconds
#
#
#
# Density matrix difference norm:  0.0030654417134931334
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162908748
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9648930305411
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8217790757317
# Coulomb Energy                 11539.3227881243656
# Exchange-Correlation Energy     -433.3735230054420
# --------------------------------------------------
# Total Energy                   -3585.7365964089640
# --------------------------------------------------
#
#
#
# Energy difference :  2.3351276468019933e-06
#
#
# HOMO-LUMO gap: 0.10324998824846127 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 13.97 seconds
#
#
#
# Density matrix difference norm:  0.0010174378672095686
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001627548505
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9526818633421
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8145317616563
# Coulomb Energy                 11539.3168310557085
# Exchange-Correlation Energy     -433.3725300796875
# --------------------------------------------------
# Total Energy                   -3585.7365966987436
# --------------------------------------------------
#
#
#
# Energy difference :  2.897795639000833e-07
#
#
# HOMO-LUMO gap: 0.10323606097421037 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 13.97 seconds
#
#
#
# Density matrix difference norm:  0.0003763303096460281
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162733393
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9484625791083
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8126747849692
# Coulomb Energy                 11539.3142180530558
# Exchange-Correlation Energy     -433.3722793832038
# --------------------------------------------------
# Total Energy                   -3585.7365966973612
# --------------------------------------------------
#
#
#
# Energy difference :  1.382431946694851e-09
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596697361
# -------------------------------------
#
#
#
# Time taken : 552.83 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           55.41
# Density Fitting                         11.58
#     DF (gamma)                          2.41
#     DF (coeff)                          0.18
#     DF (Jtri)                           8.33
# DIIS                                    8.22
# KS matrix diagonalization               6.7
# One electron Integrals (S, T, Vnuc)     0.22
# Coulomb Integrals (2c2e + 3c2e)         66.44
# Grids construction                      50.72
# Exchange-Correlation Term               348.7
# Misc.                                   4.84
# Complete SCF                            552.83

# %% [markdown]
# ## Dynamic Precision On

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.03 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.04 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0008107639998797822
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.04
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.83 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.3 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.55 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.05 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000355
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709559
# Exchange-Correlation Energy      -16.0363502502441
# --------------------------------------------------
# Total Energy                     -93.1572655540417
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726555404169
#
#
# HOMO-LUMO gap: 2.6432308932682718 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.36 seconds
#
#
#
# Density matrix difference norm:  43.34737695041879
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999992
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065134268055
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632901411555
# Coulomb Energy                   501.1179499873564
# Exchange-Correlation Energy      -62.5998153686523
# --------------------------------------------------
# Total Energy                    -340.0671116228224
# --------------------------------------------------
#
#
#
# Energy difference :  246.9098460687807
#
#
# HOMO-LUMO gap: 0.004895001056144599 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  28.61225137831246
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000107
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015434342908
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404486356327
# Coulomb Energy                   293.3105327789991
# Exchange-Correlation Energy      -37.4191284179688
# --------------------------------------------------
# Total Energy                    -355.5117133935042
# --------------------------------------------------
#
#
#
# Energy difference :  15.444601770681857
#
#
# HOMO-LUMO gap: 0.04090611597480312 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  21.394380435686642
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6802048744885
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079158470806
# Coulomb Energy                   367.2116081156464
# Exchange-Correlation Energy      -44.5831108093262
# --------------------------------------------------
# Total Energy                    -380.5858146769642
# --------------------------------------------------
#
#
#
# Energy difference :  25.074101283459925
#
#
# HOMO-LUMO gap: 0.018045819534207946 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  5.193655309010103
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853211394331
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987312449205
# Coulomb Energy                   364.3594842203922
# Exchange-Correlation Energy      -44.5593338012695
# --------------------------------------------------
# Total Energy                    -378.6284624312664
# --------------------------------------------------
#
#
#
# Energy difference :  1.9573522456977912
#
#
# HOMO-LUMO gap: 0.08497506224154512 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  4.776044383079372
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000023
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113353910722
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536993637145
# Coulomb Energy                   368.1595786044275
# Exchange-Correlation Energy      -45.0864906311035
# --------------------------------------------------
# Total Energy                    -381.1265710099102
# --------------------------------------------------
#
#
#
# Energy difference :  2.49810857864378
#
#
# HOMO-LUMO gap: 0.14153440093652558 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.5199018206092223
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759870185921
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620529814470
# Coulomb Energy                   369.0651872518328
# Exchange-Correlation Energy      -45.1361846923828
# --------------------------------------------------
# Total Energy                    -381.2269544335716
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038342366146935
#
#
# HOMO-LUMO gap: 0.13505793051822784 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.33141822113047503
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685883045481
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352932575375
# Coulomb Energy                   369.6332915647312
# Exchange-Correlation Energy      -45.2082252502441
# --------------------------------------------------
# Total Energy                    -381.2502516883999
# --------------------------------------------------
#
#
#
# Energy difference :  0.023297254828321456
#
#
# HOMO-LUMO gap: 0.019481120475621103 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.5819574011104968
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471076686418
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753380205184
# Coulomb Energy                   374.0875565365481
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611101764
# --------------------------------------------------
#
#
#
# Energy difference :  0.13180942177643828
#
#
# HOMO-LUMO gap: 0.12602028670022153 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.4597239775987981
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167311182976
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482981739477
# Coulomb Energy                   377.3936785488589
# Exchange-Correlation Energy      -46.1032257080078
# --------------------------------------------------
# Total Energy                    -381.4200030593753
# --------------------------------------------------
#
#
#
# Energy difference :  0.03794194919896654
#
#
# HOMO-LUMO gap: 0.1661133305350013 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.14506670258611015
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6774115562346
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4957003907873
# Coulomb Energy                   377.1713417801320
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261838450980
# --------------------------------------------------
#
#
#
# Energy difference :  0.00618078572261993
#
#
# HOMO-LUMO gap: 0.1810975059533216 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.0559703878538576
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466991731310
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5465057500087
# Coulomb Energy                   377.1955793525890
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266045251891
# --------------------------------------------------
#
#
#
# Energy difference :  0.00042068009111062565
#
#
# HOMO-LUMO gap: 0.18093185637999554 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.025624539780115373
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6791043635676
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228770244524
# Coulomb Energy                   377.1480814133174
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267298557953
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012533060623809433
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050730665207737 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.008410601201208866
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749481871
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758646249905
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145535863795
# Coulomb Energy                   377.1522588566468
# Exchange-Correlation Energy      -46.0763604882690
# --------------------------------------------------
# Total Energy                    -381.4274356261097
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007057703143686922
#
#
# HOMO-LUMO gap: 0.1805594177466572 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0026418714066564677
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750320948
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547069029627
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032889737137
# Coulomb Energy                   377.1410365648634
# Exchange-Correlation Energy      -46.0750325767569
# --------------------------------------------------
# Total Energy                    -381.4274368970189
# --------------------------------------------------
#
#
#
# Energy difference :  1.2709092516161036e-06
#
#
# HOMO-LUMO gap: 0.1805658344865481 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0017678391939483181
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749795147
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715784380231
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117381337695
# Coulomb Energy                   377.1506250231093
# Exchange-Correlation Energy      -46.0761996769600
# --------------------------------------------------
# Total Energy                    -381.4274379139806
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169616757593758e-06
#
#
# HOMO-LUMO gap: 0.18057810005504224 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018263944807509467
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749433851
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890954308228
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201163633823
# Coulomb Energy                   377.1610739046047
# Exchange-Correlation Energy      -46.0775109642904
# --------------------------------------------------
# Total Energy                    -381.4274390830027
# --------------------------------------------------
#
#
#
# Energy difference :  1.1690220844684518e-06
#
#
# HOMO-LUMO gap: 0.1806905172166366 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0015078228593775485
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749797102
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793142630904
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150718660101
# Coulomb Energy                   377.1557642489232
# Exchange-Correlation Energy      -46.0769384584160
# --------------------------------------------------
# Total Energy                    -381.4274395624495
# --------------------------------------------------
#
#
#
# Energy difference :  4.794468395630247e-07
#
#
# HOMO-LUMO gap: 0.18064424248422953 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.00046671667798427505
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007498303745
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995819634
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900979589
# Coulomb Energy                   377.1550630969084
# Exchange-Correlation Energy      -46.0768702751826
# --------------------------------------------------
# Total Energy                    -381.4274396181549
# --------------------------------------------------
#
#
#
# Energy difference :  5.570541361521464e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743961815495
# -------------------------------------
#
#
#
# Time taken : 9.07 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.6
# Density Fitting                         0.21
#     DF (gamma)                          0.07
#     DF (coeff)                          0.06
#     DF (Jtri)                           0.08
# DIIS                                    0.09
# KS matrix diagonalization               0.35
# One electron Integrals (S, T, Vnuc)     0.03
# Coulomb Integrals (2c2e + 3c2e)         0.83
# Grids construction                      0.3
# Exchange-Correlation Term               5.79
# Misc.                                   0.86
# Complete SCF                            9.07

# %% [markdown]
# ### Benchmark #5 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.09 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.002109757999960493
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.65 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.96 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.88 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371793
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120586
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961205856
#
#
# HOMO-LUMO gap: 1.7655068072142086 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.26 seconds
#
#
#
# Density matrix difference norm:  66.88323605808887
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816168858859
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207644691764
# Coulomb Energy                  1272.5916576120733
# Exchange-Correlation Energy     -125.2197723388672
# --------------------------------------------------
# Total Energy                    -680.0824210262715
# --------------------------------------------------
#
#
#
# Energy difference :  494.63380141421294
#
#
# HOMO-LUMO gap: 0.00039500615201254474 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  39.27352432791386
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.001236
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671666174769
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861185032387
# Coulomb Energy                   861.6520702030650
# Exchange-Correlation Energy      -75.4418334960938
# --------------------------------------------------
# Total Energy                    -709.3642652900351
# --------------------------------------------------
#
#
#
# Energy difference :  29.28184426376356
#
#
# HOMO-LUMO gap: 0.027815576347002657 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  28.145163639898595
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99994
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982282480074
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525304346800
# Coulomb Energy                  1000.6416009622635
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464582045350
# --------------------------------------------------
#
#
#
# Energy difference :  24.38219291449991
#
#
# HOMO-LUMO gap: 0.006873881114358743 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  18.10142318855316
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394470586190
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643058398342
# Coulomb Energy                  1039.7364436432256
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035183406514
# --------------------------------------------------
#
#
#
# Energy difference :  44.14293986388361
#
#
# HOMO-LUMO gap: 0.009401599128479238 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  13.030480145153327
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9281985794214
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4697782227483
# Coulomb Energy                  1004.3617050509599
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228962392622
# --------------------------------------------------
#
#
#
# Energy difference :  60.019377898610855
#
#
# HOMO-LUMO gap: 0.024324032075457587 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.651673179631909
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2543707804984
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338780969630
# Coulomb Energy                   997.3404993657963
# Exchange-Correlation Energy      -89.6696014404297
# --------------------------------------------------
# Total Energy                    -755.2430486409368
# --------------------------------------------------
#
#
#
# Energy difference :  5.620152401674545
#
#
# HOMO-LUMO gap: 0.0012911085900988856 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  6.531122040499436
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000244
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9935086818268
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455302439670
# Coulomb Energy                  1008.9226260147494
# Exchange-Correlation Energy      -89.8105239868164
# --------------------------------------------------
# Total Energy                    -754.8293302926949
# --------------------------------------------------
#
#
#
# Energy difference :  0.41371834824190046
#
#
# HOMO-LUMO gap: 0.01538888868037909 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  7.342497021897908
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6263350085665
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2045023099211
# Coulomb Energy                  1033.2839552340160
# Exchange-Correlation Energy      -92.8135986328125
# --------------------------------------------------
# Total Energy                    -754.2449299802101
# --------------------------------------------------
#
#
#
# Energy difference :  0.5844003124847177
#
#
# HOMO-LUMO gap: 0.21170746070316293 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  6.051896179678861
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9762828568055
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1048809542780
# Coulomb Energy                  1046.8936432591688
# Exchange-Correlation Energy      -94.6926879882812
# --------------------------------------------------
# Total Energy                    -761.9639005144079
# --------------------------------------------------
#
#
#
# Energy difference :  7.7189705341977515
#
#
# HOMO-LUMO gap: 0.021087323133074938 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  4.592855192224971
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186487142335
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7140597059300
# Coulomb Energy                  1016.5840729422825
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8410451441014
# --------------------------------------------------
#
#
#
# Energy difference :  2.1228553703065245
#
#
# HOMO-LUMO gap: 0.0879506475763756 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  4.199971223143636
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5724896774118
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4485454852966
# Coulomb Energy                  1025.9226134104306
# Exchange-Correlation Energy      -92.2370223999023
# --------------------------------------------------
# Total Energy                    -762.7318070643551
# --------------------------------------------------
#
#
#
# Energy difference :  2.8907619202536807
#
#
# HOMO-LUMO gap: 0.14484585083486323 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.9087413590071575
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899830321690
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303629912871
# Coulomb Energy                  1024.4800323358647
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263924178634
# --------------------------------------------------
#
#
#
# Energy difference :  0.09458535350836428
#
#
# HOMO-LUMO gap: 0.09120590655809123 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.3385952183714997
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063816114315
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273615568724
# Coulomb Energy                  1024.8155234211893
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565125888920
# --------------------------------------------------
#
#
#
# Energy difference :  0.030120171028556797
#
#
# HOMO-LUMO gap: 0.10812607740892526 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.13342124307218592
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7707738574936
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490277404786
# Coulomb Energy                  1024.3963715751370
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586828557986
# --------------------------------------------------
#
#
#
# Energy difference :  0.00217026690665989
#
#
# HOMO-LUMO gap: 0.11558370500658591 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.05241026326611632
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028273596616
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1553897453787
# Coulomb Energy                  1024.6505220208492
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595512999323
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008684441336299642
#
#
# HOMO-LUMO gap: 0.11553043490869772 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.014070139466205655
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000196179371
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543968436400
# Coulomb Energy                  1024.5347579270322
# Exchange-Correlation Energy      -92.1552581787109
# --------------------------------------------------
# Total Energy                    -762.8595769087440
# --------------------------------------------------
#
#
#
# Energy difference :  2.5608811711208546e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.11964651756867692 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.0158083944354415
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745389734
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803836032619
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978008307192
# Coulomb Energy                  1024.5775704994439
# Exchange-Correlation Energy      -92.1624877846731
# --------------------------------------------------
# Total Energy                    -762.8609539405397
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013770317957551015
#
#
# HOMO-LUMO gap: 0.11848001472677505 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.008700575028839579
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741301983
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328775438538
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722790404070
# Coulomb Energy                  1024.5524777186806
# Exchange-Correlation Energy      -92.1594108325009
# --------------------------------------------------
# Total Energy                    -762.8609855000350
# --------------------------------------------------
#
#
#
# Energy difference :  3.1559495255351067e-05
#
#
# HOMO-LUMO gap: 0.11834735615354369 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0020543608215243475
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739808189
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503341291687
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805109755635
# Coulomb Energy                  1024.5630588928439
# Exchange-Correlation Energy      -92.1607681719772
# --------------------------------------------------
# Total Energy                    -762.8609863155066
# --------------------------------------------------
#
#
#
# Energy difference :  8.154715942509938e-07
#
#
# HOMO-LUMO gap: 0.11844994244850858 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.002280385435828338
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742288267
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365055276834
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734598557117
# Coulomb Energy                  1024.5553042118825
# Exchange-Correlation Energy      -92.1597916663269
# --------------------------------------------------
# Total Energy                    -762.8609870091839
# --------------------------------------------------
#
#
#
# Energy difference :  6.936772933840984e-07
#
#
# HOMO-LUMO gap: 0.11849900339979078 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.002121043317762554
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742173371
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510212415015
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0797956324531
# Coulomb Energy                  1024.5646223691251
# Exchange-Correlation Energy      -92.1609312834230
# --------------------------------------------------
# Total Energy                    -762.8609884061143
# --------------------------------------------------
#
#
#
# Energy difference :  1.3969304291094886e-06
#
#
# HOMO-LUMO gap: 0.11838532738287744 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0014185455693975883
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741620018
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635537467042
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852198633615
# Coulomb Energy                  1024.5726720128400
# Exchange-Correlation Energy      -92.1618731067197
# --------------------------------------------------
# Total Energy                    -762.8609888599904
# --------------------------------------------------
#
#
#
# Energy difference :  4.5387605496216565e-07
#
#
# HOMO-LUMO gap: 0.11838275460556272 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.00032231655939606523
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041736
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571685174868
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822982141108
# Coulomb Energy                  1024.5687889469211
# Exchange-Correlation Energy      -92.1614536512613
# --------------------------------------------------
# Total Energy                    -762.8609888904841
# --------------------------------------------------
#
#
#
# Energy difference :  3.049376573471818e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904841
# -------------------------------------
#
#
#
# Time taken : 14.83 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.02
# Density Fitting                         0.47
#     DF (gamma)                          0.13
#     DF (coeff)                          0.07
#     DF (Jtri)                           0.23
# DIIS                                    0.14
# KS matrix diagonalization               0.61
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.65
# Grids construction                      0.96
# Exchange-Correlation Term               6.57
# Misc.                                   1.36
# Complete SCF                            14.83

# %% [markdown]
# ### Benchmark #6 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.24 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.006813708999970913
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.29
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.29 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.51 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.48 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355682
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929922991
# --------------------------------------------------
#
#
#
# Energy difference :  374.9324929922991
#
#
# HOMO-LUMO gap: 1.8503196895446523 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  107.82808392766086
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876321745091
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682663138195
# Coulomb Energy                  3537.3220829802190
# Exchange-Correlation Energy     -250.6110687255859
# --------------------------------------------------
# Total Energy                   -1359.8987077753941
# --------------------------------------------------
#
#
#
# Energy difference :  984.966214783095
#
#
# HOMO-LUMO gap: 0.0021138370429849007 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  57.365047491733385
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4339726204726
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0382902510112
# Coulomb Energy                  2705.4087019810154
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539387306367
# --------------------------------------------------
#
#
#
# Energy difference :  59.15523095524259
#
#
# HOMO-LUMO gap: 0.01974261041701887 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  48.047624580386945
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987260327049
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516880409141
# Coulomb Energy                  3071.8807166781844
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010317309912
# --------------------------------------------------
#
#
#
# Energy difference :  56.65290699964544
#
#
# HOMO-LUMO gap: 0.01467927547266959 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  40.92171705794277
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335375070792
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1620892976312
# Coulomb Energy                  3051.7270285282148
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347880576030
# --------------------------------------------------
#
#
#
# Energy difference :  16.43375632661173
#
#
# HOMO-LUMO gap: 0.012567149018568924 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  26.926775903133393
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983162148466
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494773573262
# Coulomb Energy                  3003.5484466257326
# Exchange-Correlation Energy     -179.3104553222656
# --------------------------------------------------
# Total Energy                   -1523.5012037233923
# --------------------------------------------------
#
#
#
# Energy difference :  144.66641566578937
#
#
# HOMO-LUMO gap: 0.0032179418440772684 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  13.414503203473439
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00024
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4196972108775
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319374791724
# Coulomb Energy                  2977.4926611830469
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856591857682
# --------------------------------------------------
#
#
#
# Energy difference :  24.4155445376241
#
#
# HOMO-LUMO gap: 0.03182996595226387 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  12.436594548024528
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381492201610
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8446914127057
# Coulomb Energy                  3000.9338462589753
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434613701621
# --------------------------------------------------
#
#
#
# Energy difference :  23.65780218439386
#
#
# HOMO-LUMO gap: 0.012963714230626242 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  6.0134652107911295
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677668752560
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553178105630
# Coulomb Energy                  3041.7902302003768
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430834565064
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996220863443341
#
#
# HOMO-LUMO gap: 0.021491249817123734 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  6.216636199681129
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4699708398457
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196395960584
# Coulomb Energy                  3063.1283276073264
# Exchange-Correlation Energy     -185.9102325439453
# --------------------------------------------------
# Total Energy                   -1521.9225923497452
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204911067612557
#
#
# HOMO-LUMO gap: 0.07962877372733299 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  4.429032371162371
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505041165725
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1094884550648
# Coulomb Energy                  3048.3900522062568
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820331255663
# --------------------------------------------------
#
#
#
# Energy difference :  3.6594407758211673
#
#
# HOMO-LUMO gap: 0.11947951843228867 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.8332701958387335
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524404478034
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100136713103
# Coulomb Energy                  3044.2746772915934
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396913475977
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765822203138669
#
#
# HOMO-LUMO gap: 0.1091553222077043 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.43796735207189513
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333912503114
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380075800022
# Coulomb Energy                  3039.9319409915138
# Exchange-Correlation Energy     -184.3113403320312
# --------------------------------------------------
# Total Energy                   -1525.7651391801642
# --------------------------------------------------
#
#
#
# Energy difference :  0.02544783256644223
#
#
# HOMO-LUMO gap: 0.0804951466721203 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  0.2802187016602807
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675649478671
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0128925774984
# Coulomb Energy                  3041.4808646595088
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832831428927
# --------------------------------------------------
#
#
#
# Energy difference :  0.01814396272857266
#
#
# HOMO-LUMO gap: 0.03536207030656312 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.2021656140833683
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152330793384
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773169118104
# Coulomb Energy                  3040.7151042804021
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864193992368
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031362563440779923
#
#
# HOMO-LUMO gap: 0.04477397562397205 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  0.07633488371293483
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0312922300536
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161717268298
# Coulomb Energy                  3040.4442136794451
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875172655795
# --------------------------------------------------
#
#
#
# Energy difference :  0.0010978663426612911
#
#
# HOMO-LUMO gap: 0.05279081861476323 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.028440169195563112
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299749163751
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078531129228
# Coulomb Energy                  3040.4514277483959
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877012253721
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018395979259366868
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.049892902240152165 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.012831408656338595
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963124647
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444098429522
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722259463173
# Coulomb Energy                  3040.3964242222710
# Exchange-Correlation Energy     -184.4242563496028
# --------------------------------------------------
# Total Energy                   -1525.7903721933044
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026709679323175806
#
#
# HOMO-LUMO gap: 0.05055295466144312 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.005300485923312898
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396068834
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993315135980
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002716060913
# Coulomb Energy                  3040.4277551231025
# Exchange-Correlation Energy     -184.4287289869919
# --------------------------------------------------
# Total Energy                   -1525.7903899407338
# --------------------------------------------------
#
#
#
# Energy difference :  1.7747429410519544e-05
#
#
# HOMO-LUMO gap: 0.0504590007927293 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.0021062706831467045
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396167442
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9998994958842
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3973955029276
# Coulomb Energy                  3040.4311713222351
# Exchange-Correlation Energy     -184.4287042449089
# --------------------------------------------------
# Total Energy                   -1525.7903930849689
# --------------------------------------------------
#
#
#
# Energy difference :  3.144235051877331e-06
#
#
# HOMO-LUMO gap: 0.050659341217853246 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.004881594712359865
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960053976
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796148101490
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345421796206
# Coulomb Energy                  3040.4795326608096
# Exchange-Correlation Energy     -184.4344982446602
# --------------------------------------------------
# Total Energy                   -1525.7903943837168
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987479749426711e-06
#
#
# HOMO-LUMO gap: 0.05063328413018309 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.004003880059397007
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962935745
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308462411758
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102271563161
# Coulomb Energy                  3040.4520261063562
# Exchange-Correlation Energy     -184.4314494549826
# --------------------------------------------------
# Total Energy                   -1525.7903986028259
# --------------------------------------------------
#
#
#
# Energy difference :  4.219109086989192e-06
#
#
# HOMO-LUMO gap: 0.050659206097633816 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.0009814521693309814
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.000039623176
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462805751649
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170924693221
# Coulomb Energy                  3040.4616009204365
# Exchange-Correlation Energy     -184.4324555620016
# --------------------------------------------------
# Total Energy                   -1525.7903989167462
# --------------------------------------------------
#
#
#
# Energy difference :  3.1392028176924214e-07
#
#
# HOMO-LUMO gap: 0.05067942657745547 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.000246178961684856
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332747
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503257746041
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622278798
# Coulomb Energy                  3040.4641306053172
# Exchange-Correlation Energy     -184.4327098269523
# --------------------------------------------------
# Total Energy                   -1525.7903989376964
# --------------------------------------------------
#
#
#
# Energy difference :  2.0950210455339402e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989376964
# -------------------------------------
#
#
#
# Time taken : 53.73 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.66
# Density Fitting                         1.43
#     DF (gamma)                          0.3
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.93
# DIIS                                    0.72
# KS matrix diagonalization               1.2
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         11.29
# Grids construction                      4.51
# Exchange-Correlation Term               24.31
# Misc.                                   2.54
# Complete SCF                            53.73

# %% [markdown]
# ### Benchmark #7 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.14 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.49 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.09
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.017780053000024054
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.68
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.39 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.06 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 21.52 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.28 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004561
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456325
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456325
#
#
# HOMO-LUMO gap: 1.3453310369353453 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.39 seconds
#
#
#
# Density matrix difference norm:  144.01367462687924
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771653634598
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873960288311
# Coulomb Energy                  7102.3908476757260
# Exchange-Correlation Energy     -401.0388488769531
# --------------------------------------------------
# Total Energy                   -2175.7976493752412
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159317296087
#
#
# HOMO-LUMO gap: 0.0036323937556237418 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.36 seconds
#
#
#
# Density matrix difference norm:  71.99222141375834
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0024
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8537956008331
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349342695959
# Coulomb Energy                  5771.7158140106312
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171589480778
# --------------------------------------------------
#
#
#
# Energy difference :  98.71950957283661
#
#
# HOMO-LUMO gap: 0.0049716072970081016 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.39 seconds
#
#
#
# Density matrix difference norm:  58.10278506303217
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372299069568
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733515768296
# Coulomb Energy                  6321.7308966037326
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4680741888260
# --------------------------------------------------
#
#
#
# Energy difference :  116.04908475925185
#
#
# HOMO-LUMO gap: 0.014406141167310121 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  53.36866684290288
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688648305950
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515404927858
# Coulomb Energy                  6361.2922202700101
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5267248505443
# --------------------------------------------------
#
#
#
# Energy difference :  24.058650661718275
#
#
# HOMO-LUMO gap: 0.008931040204726015 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 1.45 seconds
#
#
#
# Density matrix difference norm:  42.830844917192884
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00095
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057597765583
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112452412877
# Coulomb Energy                  6294.4824454808877
# Exchange-Correlation Energy     -283.9661865234375
# --------------------------------------------------
# Total Energy                   -2345.8381344172067
# --------------------------------------------------
#
#
#
# Energy difference :  163.3114095666624
#
#
# HOMO-LUMO gap: 0.006907360354599504 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 1.48 seconds
#
#
#
# Density matrix difference norm:  32.166243256383886
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2173813715708
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029702969926
# Coulomb Energy                  6214.1441909113473
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5589136998824
# --------------------------------------------------
#
#
#
# Energy difference :  2.2792207173242787
#
#
# HOMO-LUMO gap: 0.0024707055893349594 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.48 seconds
#
#
#
# Density matrix difference norm:  33.32021485641647
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828165753424
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271107191093
# Coulomb Energy                  6284.7511327787961
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5702685672131
# --------------------------------------------------
#
#
#
# Energy difference :  9.011354867330738
#
#
# HOMO-LUMO gap: 0.006022929408777106 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 1.47 seconds
#
#
#
# Density matrix difference norm:  26.099225488748335
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2099747953471
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3779314121825
# Coulomb Energy                  6418.6993211991312
# Exchange-Correlation Energy     -305.3439025878906
# --------------------------------------------------
# Total Energy                   -2411.0365036113099
# --------------------------------------------------
#
#
#
# Energy difference :  58.46623504409672
#
#
# HOMO-LUMO gap: 0.005611999254674177 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 1.48 seconds
#
#
#
# Density matrix difference norm:  17.530055428021583
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3144874516074
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3754828442911
# Coulomb Energy                  6329.8759046227806
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3362051422810
# --------------------------------------------------
#
#
#
# Energy difference :  37.700298469028894
#
#
# HOMO-LUMO gap: 0.017129195878463524 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  16.39802602335326
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4113034536458
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3502195481051
# Coulomb Energy                  6323.6507138396537
# Exchange-Correlation Energy     -296.5716552734375
# --------------------------------------------------
# Total Energy                   -2423.5419041787100
# --------------------------------------------------
#
#
#
# Energy difference :  50.205699036428996
#
#
# HOMO-LUMO gap: 0.006507678127640706 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  17.896856900032866
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00085
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006098114078
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1970942208845
# Coulomb Energy                  6269.6529456559365
# Exchange-Correlation Energy     -292.3520507812500
# --------------------------------------------------
# Total Energy                   -2388.4624995552222
# --------------------------------------------------
#
#
#
# Energy difference :  35.07940462348779
#
#
# HOMO-LUMO gap: 0.011363350544227893 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  18.87511272277414
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4052534743969
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783310396125
# Coulomb Energy                  6305.1510520926568
# Exchange-Correlation Energy     -292.6977233886719
# --------------------------------------------------
# Total Energy                   -2419.6334725701854
# --------------------------------------------------
#
#
#
# Energy difference :  31.170973014963238
#
#
# HOMO-LUMO gap: 0.001930927418800965 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  14.237404933656837
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7556688728091
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6446701230043
# Coulomb Energy                  6277.9143155744478
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7447822295871
# --------------------------------------------------
#
#
#
# Energy difference :  0.11130965940174065
#
#
# HOMO-LUMO gap: 0.00826866145692945 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  12.51146555322937
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8343688014484
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119872167666
# Coulomb Energy                  6304.6092915589597
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9790845877633
# --------------------------------------------------
#
#
#
# Energy difference :  11.234302358176137
#
#
# HOMO-LUMO gap: 0.017658709679865325 au
# HOMO-LUMO gap: 0.481 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  10.321248854291369
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0479580771171
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2890783705252
# Coulomb Energy                  6320.8556829986346
# Exchange-Correlation Energy     -297.0248107910156
# --------------------------------------------------
# Total Energy                   -2429.4878863383574
# --------------------------------------------------
#
#
#
# Energy difference :  1.4911982494058975
#
#
# HOMO-LUMO gap: 0.006404271114390209 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 1.5 seconds
#
#
#
# Density matrix difference norm:  8.082502536170754
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4239371627227
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0825064872893
# Coulomb Energy                  6316.7243997345622
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382928368968
# --------------------------------------------------
#
#
#
# Energy difference :  8.45040649853945
#
#
# HOMO-LUMO gap: 0.06628620948205466 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  4.088565718305303
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3818124703394
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5872221912055
# Coulomb Energy                  6313.2561922484874
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039775536261
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656847167292653
#
#
# HOMO-LUMO gap: 0.002509332846356044 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  4.342542557877635
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2974299220259
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1398869764753
# Coulomb Energy                  6287.7369724478212
# Exchange-Correlation Energy     -293.7501525878906
# --------------------------------------------------
# Total Energy                   -2439.7306019250063
# --------------------------------------------------
#
#
#
# Energy difference :  1.2733756286197604
#
#
# HOMO-LUMO gap: 0.020604678925712126 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  4.259648415467976
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7063437615852
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.1987005935025
# Coulomb Energy                  6303.8934206678568
# Exchange-Correlation Energy     -294.9478454589844
# --------------------------------------------------
# Total Energy                   -2441.1219467985957
# --------------------------------------------------
#
#
#
# Energy difference :  1.3913448735893326
#
#
# HOMO-LUMO gap: 0.1229849249657691 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  0.7427916698191734
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0198049831270
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5243696938433
# Coulomb Energy                  6307.0122461123228
# Exchange-Correlation Energy     -295.2850036621094
# --------------------------------------------------
# Total Energy                   -2441.3280716784557
# --------------------------------------------------
#
#
#
# Energy difference :  0.20612487985999906
#
#
# HOMO-LUMO gap: 0.08867375303685188 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  0.47731922835092855
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4110676243909
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7989198882888
# Coulomb Energy                  6304.8709651319223
# Exchange-Correlation Energy     -295.0262451171875
# --------------------------------------------------
# Total Energy                   -2441.3273065607518
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007651177038496826
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639432565520007 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  0.2704226500418232
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001152740339
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5565477056407
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4793836629442
# Coulomb Energy                  6304.2831590227261
# Exchange-Correlation Energy     -294.9926893611448
# --------------------------------------------------
# Total Energy                   -2441.3465732205013
# --------------------------------------------------
#
#
#
# Energy difference :  0.01926665974951902
#
#
# HOMO-LUMO gap: 0.10571276113658838 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 5.83 seconds
#
#
#
# Density matrix difference norm:  0.1190340849675788
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001155253177
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9903178308268
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6069530474315
# Coulomb Energy                  6305.7413713785427
# Exchange-Correlation Energy     -295.1471029578874
# --------------------------------------------------
# Total Energy                   -2441.3489752021251
# --------------------------------------------------
#
#
#
# Energy difference :  0.002401981623734173
#
#
# HOMO-LUMO gap: 0.10232900246568294 au
# HOMO-LUMO gap: 2.785 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  0.05772781221856374
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011616380215
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1764484892992
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2270924676918
# Coulomb Energy                  6305.2551497111754
# Exchange-Correlation Energy     -295.0957772711757
# --------------------------------------------------
# Total Energy                   -2441.3498624209924
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008872188673194614
#
#
# HOMO-LUMO gap: 0.08312991882402215 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.06366787495473436
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001177587971
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6239174931088
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9397888744602
# Coulomb Energy                  6304.9502712708327
# Exchange-Correlation Energy     -295.0562538251267
# --------------------------------------------------
# Total Energy                   -2441.3499900123279
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012759133551298873
#
#
# HOMO-LUMO gap: 0.08543972069293275 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.03312893815470568
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171909195
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1937970483741
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2381683639287
# Coulomb Energy                  6305.2622696175922
# Exchange-Correlation Energy     -295.0969080439738
# --------------------------------------------------
# Total Energy                   -2441.3501459502122
# --------------------------------------------------
#
#
#
# Energy difference :  0.00015593788430123823
#
#
# HOMO-LUMO gap: 0.08549314215915826 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  0.01644416298499654
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174372864
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9924219707555
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1355411207219
# Coulomb Energy                  6305.1489879409983
# Exchange-Correlation Energy     -295.0824361380446
# --------------------------------------------------
# Total Energy                   -2441.3502078864640
# --------------------------------------------------
#
#
#
# Energy difference :  6.193625176820206e-05
#
#
# HOMO-LUMO gap: 0.08609952367374096 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.7 seconds
#
#
#
# Density matrix difference norm:  0.007354439020779717
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011734393576
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0612590062847
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745128239327
# Coulomb Energy                  6305.1841836899157
# Exchange-Correlation Energy     -295.0877766982254
# --------------------------------------------------
# Total Energy                   -2441.3502180300466
# --------------------------------------------------
#
#
#
# Energy difference :  1.0143582585442346e-05
#
#
# HOMO-LUMO gap: 0.08618091040618528 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 5.69 seconds
#
#
#
# Density matrix difference norm:  0.0029223206636360337
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203555
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0439009556740
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630548193307
# Coulomb Energy                  6305.1767190541796
# Exchange-Correlation Energy     -295.0862145705054
# --------------------------------------------------
# Total Energy                   -2441.3502204920533
# --------------------------------------------------
#
#
#
# Energy difference :  2.4620067051728256e-06
#
#
# HOMO-LUMO gap: 0.08626993086637788 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  0.0007992921851182194
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173088249
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357868074789
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591885597354
# Coulomb Energy                  6305.1719580691451
# Exchange-Correlation Energy     -295.0857015775105
# --------------------------------------------------
# Total Energy                   -2441.3502205954946
# --------------------------------------------------
#
#
#
# Energy difference :  1.0344137990614399e-07
#
#
# HOMO-LUMO gap: 0.08626927782205698 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.66 seconds
#
#
#
# Density matrix difference norm:  0.0004709102008432538
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731708565
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0330009483332
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576325904925
# Coulomb Energy                  6305.1705221402244
# Exchange-Correlation Energy     -295.0854955484807
# --------------------------------------------------
# Total Energy                   -2441.3502206054836
# --------------------------------------------------
#
#
#
# Energy difference :  9.988980309572071e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206054836
# -------------------------------------
#
#
#
# Time taken : 161.01 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.8
# Density Fitting                         5.3
#     DF (gamma)                          0.99
#     DF (coeff)                          0.16
#     DF (Jtri)                           3.76
# DIIS                                    3.59
# KS matrix diagonalization               3.59
# One electron Integrals (S, T, Vnuc)     0.14
# Coulomb Integrals (2c2e + 3c2e)         29.39
# Grids construction                      16.06
# Exchange-Correlation Term               76.87
# Misc.                                   4.28
# Complete SCF                            161.01

# %% [markdown]
# ### Benchmark #8 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.23 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.92 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.17
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04434913299996879
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.22 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  1.46
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  66.85 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 49.65 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 55.06 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.39 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0009
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182465
# Exchange-Correlation Energy     -158.3137817382812
# --------------------------------------------------
# Total Energy                    -881.4919713840736
# --------------------------------------------------
#
#
#
# Energy difference :  881.4919713840736
#
#
# HOMO-LUMO gap: 0.6897605128399338 au
# HOMO-LUMO gap: 18.769 eV
#
#
# Time taken for the previous iteration: 2.95 seconds
#
#
#
# Density matrix difference norm:  177.41135652363633
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3344603663136
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5272337036158
# Coulomb Energy                 12707.6510698510665
# Exchange-Correlation Energy     -589.0113525390625
# --------------------------------------------------
# Total Energy                   -3195.7102569237722
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2182855396986
#
#
# HOMO-LUMO gap: 0.0026273270447605412 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 2.98 seconds
#
#
#
# Density matrix difference norm:  86.09643255337791
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.1087798593835
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9652414756570
# Coulomb Energy                 10864.6200183283436
# Exchange-Correlation Energy     -358.7289123535156
# --------------------------------------------------
# Total Energy                   -3357.7951799819766
# --------------------------------------------------
#
#
#
# Energy difference :  162.08492305820437
#
#
# HOMO-LUMO gap: 0.0025108530712168956 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 3.05 seconds
#
#
#
# Density matrix difference norm:  65.13146239694788
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00012
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9479188104087
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4635717581000
# Coulomb Energy                 11125.2510311243714
# Exchange-Correlation Energy     -407.6779174804688
# --------------------------------------------------
# Total Energy                   -3374.4539809814833
# --------------------------------------------------
#
#
#
# Energy difference :  16.65880099950664
#
#
# HOMO-LUMO gap: 0.004421866555635173 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 3.15 seconds
#
#
#
# Density matrix difference norm:  63.85792404296158
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.3725389659958
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.9140568630482
# Coulomb Energy                 12063.8293625072874
# Exchange-Correlation Energy     -415.0684814453125
# --------------------------------------------------
# Total Energy                   -3056.2403486140520
# --------------------------------------------------
#
#
#
# Energy difference :  318.2136323674313
#
#
# HOMO-LUMO gap: 0.007368555534609439 au
# HOMO-LUMO gap: 0.201 eV
#
#
# Time taken for the previous iteration: 3.26 seconds
#
#
#
# Density matrix difference norm:  54.581843417655236
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.6403098525407
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.4169003272273
# Coulomb Energy                 11513.0420648721556
# Exchange-Correlation Energy     -417.4490356445312
# --------------------------------------------------
# Total Energy                   -3536.1731278707684
# --------------------------------------------------
#
#
#
# Energy difference :  479.93277925671646
#
#
# HOMO-LUMO gap: 0.0017456519261696635 au
# HOMO-LUMO gap: 0.048 eV
#
#
# Time taken for the previous iteration: 3.39 seconds
#
#
#
# Density matrix difference norm:  51.20557602225183
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9997
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.0683834780393
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.9093067970184
# Coulomb Energy                 11567.9598172827482
# Exchange-Correlation Energy     -419.4386291503906
# --------------------------------------------------
# Total Energy                   -3073.1806361217423
# --------------------------------------------------
#
#
#
# Energy difference :  462.99249174902616
#
#
# HOMO-LUMO gap: 0.0071010437047312885 au
# HOMO-LUMO gap: 0.193 eV
#
#
# Time taken for the previous iteration: 3.38 seconds
#
#
#
# Density matrix difference norm:  44.85234724160645
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.9588257599498
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6778951979004
# Coulomb Energy                 11495.7953423012004
# Exchange-Correlation Energy     -423.7618408203125
# --------------------------------------------------
# Total Energy                   -3532.7901766542400
# --------------------------------------------------
#
#
#
# Energy difference :  459.6095405324977
#
#
# HOMO-LUMO gap: 0.0009142854309314996 au
# HOMO-LUMO gap: 0.025 eV
#
#
# Time taken for the previous iteration: 3.38 seconds
#
#
#
# Density matrix difference norm:  20.646608646003045
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.8308714060440
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.3211837207377
# Coulomb Energy                 11578.8342749484273
# Exchange-Correlation Energy     -439.3337402343750
# --------------------------------------------------
# Total Energy                   -3536.5519005443311
# --------------------------------------------------
#
#
#
# Energy difference :  3.7617238900911616
#
#
# HOMO-LUMO gap: 0.003600089789845551 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 3.37 seconds
#
#
#
# Density matrix difference norm:  20.828958848201466
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00064
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28136.7529047082353
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3618.5811039363862
# Coulomb Energy                 11689.0101214287261
# Exchange-Correlation Energy     -441.3328552246094
# --------------------------------------------------
# Total Energy                   -3500.0372821408091
# --------------------------------------------------
#
#
#
# Energy difference :  36.514618403522036
#
#
# HOMO-LUMO gap: 0.010629539349138045 au
# HOMO-LUMO gap: 0.289 eV
#
#
# Time taken for the previous iteration: 3.34 seconds
#
#
#
# Density matrix difference norm:  22.197547435995002
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00018
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27870.4578874477920
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3570.0608319421099
# Coulomb Energy                 11460.1494027671179
# Exchange-Correlation Energy     -435.4828186035156
# --------------------------------------------------
# Total Energy                   -3505.2732189151557
# --------------------------------------------------
#
#
#
# Energy difference :  5.2359367743465555
#
#
# HOMO-LUMO gap: 0.01084899711326831 au
# HOMO-LUMO gap: 0.295 eV
#
#
# Time taken for the previous iteration: 3.31 seconds
#
#
#
# Density matrix difference norm:  15.727022040588471
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0003
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28102.6514155338591
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3578.5252942469369
# Coulomb Energy                 11610.6783982285233
# Exchange-Correlation Energy     -438.4913330078125
# --------------------------------------------------
# Total Energy                   -3581.4818036392880
# --------------------------------------------------
#
#
#
# Energy difference :  76.20858472413238
#
#
# HOMO-LUMO gap: 0.0001599850427952132 au
# HOMO-LUMO gap: 0.004 eV
#
#
# Time taken for the previous iteration: 3.3 seconds
#
#
#
# Density matrix difference norm:  13.372044509047697
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27854.5470761773031
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3502.8819889219358
# Coulomb Energy                 11467.2469354040113
# Exchange-Correlation Energy     -426.1153564453125
# --------------------------------------------------
# Total Energy                   -3540.0762558697443
# --------------------------------------------------
#
#
#
# Energy difference :  41.40554776954377
#
#
# HOMO-LUMO gap: 0.053063855819698316 au
# HOMO-LUMO gap: 1.444 eV
#
#
# Time taken for the previous iteration: 3.28 seconds
#
#
#
# Density matrix difference norm:  12.795666606755626
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27990.2673880910515
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3532.8987480348574
# Coulomb Energy                 11534.4508687803100
# Exchange-Correlation Energy     -432.5666809082031
# --------------------------------------------------
# Total Energy                   -3585.0271997571635
# --------------------------------------------------
#
#
#
# Energy difference :  44.95094388741927
#
#
# HOMO-LUMO gap: 0.004062785717470527 au
# HOMO-LUMO gap: 0.111 eV
#
#
# Time taken for the previous iteration: 3.27 seconds
#
#
#
# Density matrix difference norm:  4.411372057616598
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00018
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27977.3834690860895
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3527.9686579205109
# Coulomb Energy                 11526.5811190083368
# Exchange-Correlation Energy     -431.3870544433594
# --------------------------------------------------
# Total Energy                   -3583.7634941736778
# --------------------------------------------------
#
#
#
# Energy difference :  1.2637055834857165
#
#
# HOMO-LUMO gap: 0.05833556330306081 au
# HOMO-LUMO gap: 1.587 eV
#
#
# Time taken for the previous iteration: 3.26 seconds
#
#
#
# Density matrix difference norm:  4.108634837321827
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99988
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27998.0757676028079
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3538.5364013246012
# Coulomb Energy                 11536.7365390425621
# Exchange-Correlation Energy     -433.2093505859375
# --------------------------------------------------
# Total Energy                   -3585.5549253946610
# --------------------------------------------------
#
#
#
# Energy difference :  1.7914312209832133
#
#
# HOMO-LUMO gap: 0.0867596794004723 au
# HOMO-LUMO gap: 2.361 eV
#
#
# Time taken for the previous iteration: 3.27 seconds
#
#
#
# Density matrix difference norm:  0.7327540988764255
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00006
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.8467664803211
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.7627335035468
# Coulomb Energy                 11540.4301288648821
# Exchange-Correlation Energy     -433.5166931152344
# --------------------------------------------------
# Total Energy                   -3585.7133448002041
# --------------------------------------------------
#
#
#
# Energy difference :  0.15841940554309986
#
#
# HOMO-LUMO gap: 0.09408389008060815 au
# HOMO-LUMO gap: 2.560 eV
#
#
# Time taken for the previous iteration: 3.26 seconds
#
#
#
# Density matrix difference norm:  0.2816118840785276
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.1397838376179
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5295261561791
# Coulomb Energy                 11539.8952985066935
# Exchange-Correlation Energy     -433.4653015136719
# --------------------------------------------------
# Total Energy                   -3585.7230082614933
# --------------------------------------------------
#
#
#
# Energy difference :  0.009663461289164843
#
#
# HOMO-LUMO gap: 0.09973835481521873 au
# HOMO-LUMO gap: 2.714 eV
#
#
# Time taken for the previous iteration: 3.27 seconds
#
#
#
# Density matrix difference norm:  0.16830553293067596
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6072478750066
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.5695976966967
# Coulomb Energy                 11539.1824678638986
# Exchange-Correlation Energy     -433.3301391601562
# --------------------------------------------------
# Total Energy                   -3585.7280690476455
# --------------------------------------------------
#
#
#
# Energy difference :  0.005060786152171204
#
#
# HOMO-LUMO gap: 0.10344832476473706 au
# HOMO-LUMO gap: 2.815 eV
#
#
# Time taken for the previous iteration: 3.27 seconds
#
#
#
# Density matrix difference norm:  0.08011373747207517
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99988
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.7153569689472
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7573177273498
# Coulomb Energy                 11539.1256265741285
# Exchange-Correlation Energy     -433.3545837402344
# --------------------------------------------------
# Total Energy                   -3585.7297439807789
# --------------------------------------------------
#
#
#
# Energy difference :  0.0016749331334722228
#
# Switching to double precision for XC evaluation after 20 iterations!
#
#
# HOMO-LUMO gap: 0.1034395506007428 au
# HOMO-LUMO gap: 2.815 eV
#
#
# Time taken for the previous iteration: 3.24 seconds
#
#
#
# Density matrix difference norm:  0.04205403488072708
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001609813285
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0582062259055
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8989664749197
# Coulomb Energy                 11539.3448338974795
# Exchange-Correlation Energy     -433.3793667240420
# --------------------------------------------------
# Total Energy                   -3585.7365201506254
# --------------------------------------------------
#
#
#
# Energy difference :  0.006776169846489211
#
#
# HOMO-LUMO gap: 0.10318109198112434 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 13.85 seconds
#
#
#
# Density matrix difference norm:  0.015806410875896744
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001624418513
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9448220379891
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8149005352871
# Coulomb Energy                 11539.3065424568649
# Exchange-Correlation Energy     -433.3704588860371
# --------------------------------------------------
# Total Energy                   -3585.7365855049538
# --------------------------------------------------
#
#
#
# Energy difference :  6.53543283988256e-05
#
#
# HOMO-LUMO gap: 0.10328499759680002 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 13.91 seconds
#
#
#
# Density matrix difference norm:  0.009030635310800578
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000161099172
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9192116956256
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7996041028291
# Coulomb Energy                 11539.2962253690330
# Exchange-Correlation Energy     -433.3704610835841
# --------------------------------------------------
# Total Energy                   -3585.7365908804240
# --------------------------------------------------
#
#
#
# Energy difference :  5.375470209401101e-06
#
#
# HOMO-LUMO gap: 0.10328781721224138 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 13.98 seconds
#
#
#
# Density matrix difference norm:  0.0055016133083954375
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163566204
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0266687488220
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8526753695924
# Coulomb Energy                 11539.3577760900680
# Exchange-Correlation Energy     -433.3776296643029
# --------------------------------------------------
# Total Energy                   -3585.7365945265446
# --------------------------------------------------
#
#
#
# Energy difference :  3.646120603661984e-06
#
#
# HOMO-LUMO gap: 0.10325310011885697 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 13.99 seconds
#
#
#
# Density matrix difference norm:  0.0030751472999954585
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001626844056
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9469551704060
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8127820687223
# Coulomb Energy                 11539.3125269020493
# Exchange-Correlation Energy     -433.3722024910708
# --------------------------------------------------
# Total Energy                   -3585.7365962637832
# --------------------------------------------------
#
#
#
# Energy difference :  1.737238562782295e-06
#
#
# HOMO-LUMO gap: 0.10322399195834168 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 13.97 seconds
#
#
#
# Density matrix difference norm:  0.0012971483608854816
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162589254
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9431060793868
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096008511702
# Coulomb Energy                 11539.3114704512554
# Exchange-Correlation Energy     -433.3718142846183
# --------------------------------------------------
# Total Energy                   -3585.7365966346570
# --------------------------------------------------
#
#
#
# Energy difference :  3.708737494889647e-07
#
#
# HOMO-LUMO gap: 0.10325135220833825 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 13.96 seconds
#
#
#
# Density matrix difference norm:  0.0005981864539235201
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001628133276
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9506105305663
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8140467854505
# Coulomb Energy                 11539.3151795935737
# Exchange-Correlation Energy     -433.3724649690874
# --------------------------------------------------
# Total Energy                   -3585.7365966937086
# --------------------------------------------------
#
#
#
# Energy difference :  5.9051671996712685e-08
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.7365966937086
# -------------------------------------
#
#
#
# Time taken : 339.6 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           55.46
# Density Fitting                         11.69
#     DF (gamma)                          2.44
#     DF (coeff)                          0.21
#     DF (Jtri)                           8.39
# DIIS                                    8.35
# KS matrix diagonalization               6.73
# One electron Integrals (S, T, Vnuc)     0.23
# Coulomb Integrals (2c2e + 3c2e)         66.85
# Grids construction                      49.65
# Exchange-Correlation Term               134.91
# Misc.                                   5.73
# Complete SCF                            339.6
