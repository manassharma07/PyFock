# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 35.85 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 33.9 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.8 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=d5112c1e0c4eb448e240cc992f7326a60465004a54e0b8978c1d79a37eb0c098
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s4em9icv/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 17.34 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 15.76 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  6.16
# Time taken to evaluate the square roots needed:  0.1
# Time for significant indices evaluation:  2.3193862860000536
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 8.59 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  7.3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  41.15 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.35 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.25 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.52 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709563
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632571
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325707
#
#
# HOMO-LUMO gap: 2.6431079281670593 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 7.31 seconds
#
#
#
# Density matrix difference norm:  43.34767137041553
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  49.99999474389977
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709371
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316006
# Coulomb Energy                   501.1198589452450
# Exchange-Correlation Energy      -62.5998011282689
# --------------------------------------------------
# Total Energy                    -340.0652765782366
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851497957
#
#
# HOMO-LUMO gap: 0.0049027110609506375 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.28 seconds
#
#
#
# Density matrix difference norm:  28.61247171884546
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00009840286509
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456797
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785955
# Coulomb Energy                   293.3088657954294
# Exchange-Correlation Energy      -37.4191110537734
# --------------------------------------------------
# Total Energy                    -355.5094553813046
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803067985
#
#
# HOMO-LUMO gap: 0.04036147698826789 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  21.394016787365768
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445384
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275241
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458363
# Coulomb Energy                   367.2127830476380
# Exchange-Correlation Energy      -44.5841010136085
# --------------------------------------------------
# Total Energy                    -380.5867878035347
# --------------------------------------------------
#
#
#
# Energy difference :  25.077332422230086
#
#
# HOMO-LUMO gap: 0.018048571143195333 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  5.19748093369489
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000687474081
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703555
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754436
# Coulomb Energy                   364.3533796550956
# Exchange-Correlation Energy      -44.5594485029981
# --------------------------------------------------
# Total Energy                    -378.6274635986908
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048439379
#
#
# HOMO-LUMO gap: 0.0849358228474651 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  4.779285269956675
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000012877114045
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186255
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180301
# Coulomb Energy                   368.1554971681454
# Exchange-Correlation Energy      -45.0868782881883
# --------------------------------------------------
# Total Energy                    -381.1270633765147
# --------------------------------------------------
#
#
#
# Energy difference :  2.49959977782396
#
#
# HOMO-LUMO gap: 0.14183855738523746 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.5205766173130721
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001212089465
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233102
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990071
# Coulomb Energy                   369.0647619107102
# Exchange-Correlation Energy      -45.1368862216088
# --------------------------------------------------
# Total Energy                    -381.2275584910782
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456350047
#
#
# HOMO-LUMO gap: 0.1351472390941425 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.3315886778255531
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597147
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176630
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774450
# Coulomb Energy                   369.6340156607378
# Exchange-Correlation Energy      -45.2090855965846
# --------------------------------------------------
# Total Energy                    -381.2508898319413
# --------------------------------------------------
#
#
#
# Energy difference :  0.023331340863023797
#
#
# HOMO-LUMO gap: 0.019732057383204705 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.581825130865691
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000861700552
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110787
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893508
# Coulomb Energy                   374.0898923937880
# Exchange-Correlation Energy      -45.7569321945896
# --------------------------------------------------
# Total Energy                    -381.3827647784059
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646467712
#
#
# HOMO-LUMO gap: 0.12604481221496255 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.4584549614624577
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007227673095
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524719
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358419
# Coulomb Energy                   377.3880704578908
# Exchange-Correlation Energy      -46.1034837100264
# --------------------------------------------------
# Total Energy                    -381.4206849246423
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623633122
#
#
# HOMO-LUMO gap: 0.16627348986142548 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.1450688651691369
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007579020895
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358381
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690190
# Coulomb Energy                   377.1736811284846
# Exchange-Correlation Energy      -46.0748895148563
# --------------------------------------------------
# Total Energy                    -381.4268823090673
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384425036034
#
#
# HOMO-LUMO gap: 0.18126074112642912 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.05574884999145816
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000742519869
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179449
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114332
# Coulomb Energy                   377.1977734128268
# Exchange-Correlation Energy      -46.0810670348481
# --------------------------------------------------
# Total Energy                    -381.4272916844095
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753422012014
#
#
# HOMO-LUMO gap: 0.18111025828119834 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.02562530605199774
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000075037254
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006534
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114222
# Coulomb Energy                   377.1502888734902
# Exchange-Correlation Energy      -46.0776486461292
# --------------------------------------------------
# Total Energy                    -381.4274184177465
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012673333696966438
#
#
# HOMO-LUMO gap: 0.18068395565686574 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.008432526434118464
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750035487
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167672
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298650
# Coulomb Energy                   377.1545462611568
# Exchange-Correlation Energy      -46.0767747067600
# --------------------------------------------------
# Total Energy                    -381.4274393883818
# --------------------------------------------------
#
#
#
# Energy difference :  2.097063531891763e-05
#
#
# HOMO-LUMO gap: 0.18067053575031966 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0018444600039578315
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750025072
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068181
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736969
# Coulomb Energy                   377.1524231958032
# Exchange-Correlation Energy      -46.0765296383166
# --------------------------------------------------
# Total Energy                    -381.4274391315112
# --------------------------------------------------
#
#
#
# Energy difference :  2.568706349848071e-07
#
#
# HOMO-LUMO gap: 0.18064597252293474 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0011511413610417237
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074989492
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206457
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789362
# Coulomb Energy                   377.1549870542074
# Exchange-Correlation Energy      -46.0768423766159
# --------------------------------------------------
# Total Energy                    -381.4274396199946
# --------------------------------------------------
#
#
#
# Energy difference :  4.884834083895839e-07
#
#
# HOMO-LUMO gap: 0.18064256438834966 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.00010543279365747561
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836627
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081854
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075883
# Coulomb Energy                   377.1556791349440
# Exchange-Correlation Energy      -46.0769272993468
# --------------------------------------------------
# Total Energy                    -381.4274396208765
# --------------------------------------------------
#
#
#
# Energy difference :  8.819256436254364e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.4274396208765
# -------------------------------------
#
#
#
# Time taken : 76.39 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.78
# Density Fitting                         1.88
#     DF (gamma)                          0.74
#     DF (coeff)                          0.16
#     DF (Jtri)                           0.65
# DIIS                                    0.78
# KS matrix diagonalization               0.91
# One electron Integrals (S, T, Vnuc)     17.34
# Coulomb Integrals (2c2e + 3c2e)         41.15
# Grids construction                      1.35
# Exchange-Correlation Term               5.63
# Misc.                                   4.56
# Complete SCF                            76.39

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.1 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.003638452000018333
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.6 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.03 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.04 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  100.00135664103418
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371800
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645299995
# --------------------------------------------------
#
#
#
# Energy difference :  185.44746452999948
#
#
# HOMO-LUMO gap: 1.7654343749559254 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  66.88358764205745
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.9999898408465
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217438494
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987506575
# Coulomb Energy                  1272.5954275689794
# Exchange-Correlation Energy     -125.2198694441799
# --------------------------------------------------
# Total Energy                    -680.0789187511602
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422116077
#
#
# HOMO-LUMO gap: 0.00040456056768900517 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  39.275229644368395
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00120175844562
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692492597
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666726636
# Coulomb Energy                   861.6558693045740
# Exchange-Correlation Energy      -75.4419310839536
# --------------------------------------------------
# Total Energy                    -709.3563182387434
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487583125
#
#
# HOMO-LUMO gap: 0.027815605001376052 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  28.147358564337047
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663972
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672037013
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170659880
# Coulomb Energy                  1000.6400676119403
# Exchange-Correlation Energy      -87.3507096616582
# --------------------------------------------------
# Total Energy                    -733.7433460701990
# --------------------------------------------------
#
#
#
# Energy difference :  24.38702783145561
#
#
# HOMO-LUMO gap: 0.00735222719533557 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  18.103053983075345
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642285
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026565135
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102958173
# Coulomb Energy                  1039.7254935642309
# Exchange-Correlation Energy      -89.9717584581022
# --------------------------------------------------
# Total Energy                    -689.6320111373357
# --------------------------------------------------
#
#
#
# Energy difference :  44.111334932863315
#
#
# HOMO-LUMO gap: 0.010701793703244089 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  13.034260103684222
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022387413
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597905
# Coulomb Energy                  1004.3417767420030
# Exchange-Correlation Energy      -89.2334391642943
# --------------------------------------------------
# Total Energy                    -749.6400714840099
# --------------------------------------------------
#
#
#
# Energy difference :  60.008060346674256
#
#
# HOMO-LUMO gap: 0.025771351282669247 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.653358064506021
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554305
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132844522
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767409916
# Coulomb Energy                   997.3319760641085
# Exchange-Correlation Energy      -89.6717481072287
# --------------------------------------------------
# Total Energy                    -755.2352624693489
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985338945
#
#
# HOMO-LUMO gap: 0.003568479520084128 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.309738335092843
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567738
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204414771
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857161133
# Coulomb Energy                  1009.6464766736909
# Exchange-Correlation Energy      -89.9069114779369
# --------------------------------------------------
# Total Energy                    -755.2788234123776
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094302875135
#
#
# HOMO-LUMO gap: 0.009175061886799334 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  8.05713271738134
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00050300163969
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153726867
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119322808
# Coulomb Energy                  1035.0050622425335
# Exchange-Correlation Energy      -92.6658378595346
# --------------------------------------------------
# Total Energy                    -747.5712329401752
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472202469
#
#
# HOMO-LUMO gap: 0.1176623719369069 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.715013429016828
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306771
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903699378
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992833296
# Coulomb Energy                  1048.9988443900552
# Exchange-Correlation Energy      -94.9610811404635
# --------------------------------------------------
# Total Energy                    -761.7908817197849
# --------------------------------------------------
#
#
#
# Energy difference :  14.21964877960977
#
#
# HOMO-LUMO gap: 0.010925426636227031 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.790315749393939
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377907
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412177460
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466859250
# Coulomb Energy                  1013.7508689108779
# Exchange-Correlation Energy      -90.9428726052272
# --------------------------------------------------
# Total Energy                    -756.2816521089383
# --------------------------------------------------
#
#
#
# Energy difference :  5.50922961084666
#
#
# HOMO-LUMO gap: 0.14929732696492667 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.534633252759115
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202662
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716107649
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461513078
# Coulomb Energy                  1025.7750806789597
# Exchange-Correlation Energy      -92.2703810888386
# --------------------------------------------------
# Total Energy                    -762.7969797521043
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327643166074
#
#
# HOMO-LUMO gap: 0.1335269786555327 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.5338338749081099
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332058
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534034
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792902872
# Coulomb Energy                  1024.7461321400110
# Exchange-Correlation Energy      -92.1885648748850
# --------------------------------------------------
# Total Energy                    -762.8402252807582
# --------------------------------------------------
#
#
#
# Energy difference :  0.04324552865386977
#
#
# HOMO-LUMO gap: 0.11056223799065501 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.36027133595315386
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916643
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590204209
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517293661
# Coulomb Energy                  1023.6379077074548
# Exchange-Correlation Energy      -92.0697499681895
# --------------------------------------------------
# Total Energy                    -762.8490034345577
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153799539723
#
#
# HOMO-LUMO gap: 0.08600353272967445 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.3252988567625615
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680048
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240863013
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261722005
# Coulomb Energy                  1024.4836887100350
# Exchange-Correlation Energy      -92.1371699397500
# --------------------------------------------------
# Total Energy                    -762.8531330265841
# --------------------------------------------------
#
#
#
# Energy difference :  0.0041295920264019514
#
#
# HOMO-LUMO gap: 0.11636080747441274 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.1553422461642015
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503608
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117169232
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900056066
# Coulomb Energy                  1024.5663100626327
# Exchange-Correlation Energy      -92.1605267750484
# --------------------------------------------------
# Total Energy                    -762.8605923065004
# --------------------------------------------------
#
#
#
# Energy difference :  0.007459279916247397
#
#
# HOMO-LUMO gap: 0.1226923924346369 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.04060711223175272
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000722186562
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080474
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362579
# Coulomb Energy                  1024.7015706722470
# Exchange-Correlation Energy      -92.1773633390774
# --------------------------------------------------
# Total Energy                    -762.8609189213878
# --------------------------------------------------
#
#
#
# Energy difference :  0.000326614887399046
#
#
# HOMO-LUMO gap: 0.11742913475999245 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.01970316352732906
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471096
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348739064
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569741
# Coulomb Energy                  1024.5590092024122
# Exchange-Correlation Energy      -92.1602830990732
# --------------------------------------------------
# Total Energy                    -762.8609667963615
# --------------------------------------------------
#
#
#
# Energy difference :  4.7874973688522005e-05
#
#
# HOMO-LUMO gap: 0.11815573488921731 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.00821149989362024
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163932
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862505
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811809
# Coulomb Energy                  1024.5676148746800
# Exchange-Correlation Energy      -92.1612728329160
# --------------------------------------------------
# Total Energy                    -762.8609882460735
# --------------------------------------------------
#
#
#
# Energy difference :  2.1449711994137033e-05
#
#
# HOMO-LUMO gap: 0.11842571032175749 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.00191483616098916
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786605
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971573
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346136
# Coulomb Energy                  1024.5642249369535
# Exchange-Correlation Energy      -92.1610088236028
# --------------------------------------------------
# Total Energy                    -762.8609886319614
# --------------------------------------------------
#
#
#
# Energy difference :  3.858879153995076e-07
#
#
# HOMO-LUMO gap: 0.11835771606491771 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.0010776396170498117
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816393
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020090
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743185
# Coulomb Energy                  1024.5683629999196
# Exchange-Correlation Energy      -92.1613819110188
# --------------------------------------------------
# Total Energy                    -762.8609888215581
# --------------------------------------------------
#
#
#
# Energy difference :  1.8959667613671627e-07
#
#
# HOMO-LUMO gap: 0.11837118338568553 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.0005041312678387241
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785558
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158377
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323570
# Coulomb Energy                  1024.5701171428861
# Exchange-Correlation Energy      -92.1615907612848
# --------------------------------------------------
# Total Energy                    -762.8609888846474
# --------------------------------------------------
#
#
#
# Energy difference :  6.30893737252336e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846474
# -------------------------------------
#
#
#
# Time taken : 19.55 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.18
# Density Fitting                         0.48
#     DF (gamma)                          0.13
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.22
# DIIS                                    0.12
# KS matrix diagonalization               0.54
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.6
# Grids construction                      1.03
# Exchange-Correlation Term               11.08
# Misc.                                   1.47
# Complete SCF                            19.55

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.08 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.25 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.008311251000009179
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.28
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.15 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 5.05 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.85 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.18 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355691
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973791
# --------------------------------------------------
#
#
#
# Energy difference :  374.9303338973791
#
#
# HOMO-LUMO gap: 1.8502864435408068 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 2.26 seconds
#
#
#
# Density matrix difference norm:  107.82844284432912
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99998558772938
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067145
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391765678
# Coulomb Energy                  3537.3287033060415
# Exchange-Correlation Energy     -250.6110528162014
# --------------------------------------------------
# Total Energy                   -1359.8923755096448
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122657
#
#
# HOMO-LUMO gap: 0.0021139216445846265 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 2.21 seconds
#
#
#
# Density matrix difference norm:  57.36707021915665
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512904
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256493844
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810813301
# Coulomb Energy                  2705.3966179576141
# Exchange-Correlation Energy     -151.8752804393605
# --------------------------------------------------
# Total Energy                   -1419.0480632191397
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770949494
#
#
# HOMO-LUMO gap: 0.01974072373920073 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 2.22 seconds
#
#
#
# Density matrix difference norm:  48.04719016376726
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00017178492382
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823849859
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892854979
# Coulomb Energy                  3071.8764250115951
# Exchange-Correlation Energy     -174.7460035329362
# --------------------------------------------------
# Total Energy                   -1362.4047277901677
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542897202
#
#
# HOMO-LUMO gap: 0.0147477147249373 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 2.24 seconds
#
#
#
# Density matrix difference norm:  40.925708282581475
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0011009615872
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198128028
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571582225
# Coulomb Energy                  3051.7165832278947
# Exchange-Correlation Energy     -176.2007428393638
# --------------------------------------------------
# Total Energy                   -1378.8564784353880
# --------------------------------------------------
#
#
#
# Energy difference :  16.451750645220272
#
#
# HOMO-LUMO gap: 0.012539973802364726 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 2.24 seconds
#
#
#
# Density matrix difference norm:  26.932582172217327
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863933
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022789323
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850555860
# Coulomb Energy                  3003.5375755726918
# Exchange-Correlation Energy     -179.3125720191538
# --------------------------------------------------
# Total Energy                   -1523.5033698391480
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140376004
#
#
# HOMO-LUMO gap: 0.003087494761466124 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  13.423370100268865
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488933
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332566537
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671361518
# Coulomb Energy                  2977.4795296018733
# Exchange-Correlation Energy     -178.1026352539872
# --------------------------------------------------
# Total Energy                   -1499.0865279419536
# --------------------------------------------------
#
#
#
# Energy difference :  24.416841897194445
#
#
# HOMO-LUMO gap: 0.03181461272724301 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 2.26 seconds
#
#
#
# Density matrix difference norm:  12.444575042411259
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146515
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885443091
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462462793
# Coulomb Energy                  3000.9261851726883
# Exchange-Correlation Energy     -180.8962339957913
# --------------------------------------------------
# Total Energy                   -1522.7463472904706
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348516976
#
#
# HOMO-LUMO gap: 0.012952412900557604 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 2.26 seconds
#
#
#
# Density matrix difference norm:  6.016412544057699
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00012192201385
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025155486
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516681623
# Coulomb Energy                  3041.7824359800761
# Exchange-Correlation Energy     -185.1339645332755
# --------------------------------------------------
# Total Energy                   -1523.4476355699244
# --------------------------------------------------
#
#
#
# Energy difference :  0.70128827945382
#
#
# HOMO-LUMO gap: 0.021473549809976067 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  6.222751705207238
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999594881057
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888915315
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569992535
# Coulomb Energy                  3063.1248487684811
# Exchange-Correlation Energy     -185.9132949764710
# --------------------------------------------------
# Total Energy                   -1521.9201342696065
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013003179083
#
#
# HOMO-LUMO gap: 0.07988335372989425 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  4.434848523622052
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846703
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733681752
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444891070
# Coulomb Energy                  3048.3985990984202
# Exchange-Correlation Energy     -185.3448733864943
# --------------------------------------------------
# Total Energy                   -1525.5849593364801
# --------------------------------------------------
#
#
#
# Energy difference :  3.664825066873618
#
#
# HOMO-LUMO gap: 0.11911980736774436 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.8335133099907933
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003812437743
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577372735
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794519
# Coulomb Energy                  3044.2765927793553
# Exchange-Correlation Energy     -184.7849150214356
# --------------------------------------------------
# Total Energy                   -1525.7423647692394
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543275933305
#
#
# HOMO-LUMO gap: 0.1091438515173127 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.4378203336031708
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000400773332
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238684979
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349878
# Coulomb Energy                  3039.9455617680051
# Exchange-Correlation Energy     -184.3161788613740
# --------------------------------------------------
# Total Energy                   -1525.7678971962177
# --------------------------------------------------
#
#
#
# Energy difference :  0.025532426978315925
#
#
# HOMO-LUMO gap: 0.08055636124770321 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  0.27956022877882863
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976176
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906451
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116258
# Coulomb Energy                  3041.4914846757279
# Exchange-Correlation Energy     -184.5235703798688
# --------------------------------------------------
# Total Energy                   -1525.7860021524971
# --------------------------------------------------
#
#
#
# Energy difference :  0.01810495627933051
#
#
# HOMO-LUMO gap: 0.03553321190298611 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 2.31 seconds
#
#
#
# Density matrix difference norm:  0.20188173701006876
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004068429737
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555703668
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365258226
# Coulomb Energy                  3040.7248454919518
# Exchange-Correlation Energy     -184.4775892871880
# --------------------------------------------------
# Total Energy                   -1525.7891190091177
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031168566206360993
#
#
# HOMO-LUMO gap: 0.04487089486606087 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.07625293104757622
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003965723613
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379110902
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103510
# Coulomb Energy                  3040.4560830346454
# Exchange-Correlation Energy     -184.4308753791040
# --------------------------------------------------
# Total Energy                   -1525.7902311145372
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011121054194518365
#
#
# HOMO-LUMO gap: 0.05285664136843221 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.028372083621699615
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003947131012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669640988
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980372
# Coulomb Energy                  3040.4602645949535
# Exchange-Correlation Energy     -184.4309026475763
# --------------------------------------------------
# Total Energy                   -1525.7903707880223
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348513688194
#
#
# HOMO-LUMO gap: 0.04994812744088761 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.012785251243062077
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.000039685056
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931405
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318348
# Coulomb Energy                  3040.4067159125852
# Exchange-Correlation Energy     -184.4260067735675
# --------------------------------------------------
# Total Energy                   -1525.7903870916261
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303603842970915e-05
#
#
# HOMO-LUMO gap: 0.05083365573054292 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.006040021432323895
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112007
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856955207
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519921060
# Coulomb Energy                  3040.4581957845321
# Exchange-Correlation Energy     -184.4326037898931
# --------------------------------------------------
# Total Energy                   -1525.7903978781151
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786488928715698e-05
#
#
# HOMO-LUMO gap: 0.05068603589630219 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.001965540750470745
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378537
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801127027
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451697
# Coulomb Energy                  3040.4659355248768
# Exchange-Correlation Energy     -184.4328301188933
# --------------------------------------------------
# Total Energy                   -1525.7903988308863
# --------------------------------------------------
#
#
#
# Energy difference :  9.527711881673895e-07
#
#
# HOMO-LUMO gap: 0.050712621256358545 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.0010394322782245823
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780368
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466446901
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272610674
# Coulomb Energy                  3040.4701320975946
# Exchange-Correlation Energy     -184.4333553536699
# --------------------------------------------------
# Total Energy                   -1525.7903988090366
# --------------------------------------------------
#
#
#
# Energy difference :  2.1849700715392828e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090366
# -------------------------------------
#
#
#
# Time taken : 74.77 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           8.03
# Density Fitting                         1.3
#     DF (gamma)                          0.28
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.82
# DIIS                                    0.57
# KS matrix diagonalization               1.04
# One electron Integrals (S, T, Vnuc)     0.08
# Coulomb Integrals (2c2e + 3c2e)         11.15
# Grids construction                      5.05
# Exchange-Correlation Term               44.98
# Misc.                                   2.57
# Complete SCF                            74.77

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.15 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.51 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.1
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.019331666999960362
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.69
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  30.54 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 17.09 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 22.56 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.41 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0029198407821
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004752
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513556
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513556
#
#
# HOMO-LUMO gap: 1.3453174761624846 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  144.01406386863056
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99996720715313
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016248049
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642081350
# Coulomb Energy                  7102.4006978647276
# Exchange-Correlation Energy     -401.0386878050859
# --------------------------------------------------
# Total Energy                   -2175.7881061964117
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450562
#
#
# HOMO-LUMO gap: 0.0036326528168963423 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  71.99427239655235
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00238512472066
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645631187
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936749
# Coulomb Energy                  5771.7138319760506
# Exchange-Correlation Energy     -243.8524720617013
# --------------------------------------------------
# Total Energy                   -2274.5129129944798
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679806813
#
#
# HOMO-LUMO gap: 0.0049646115351440895 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 5.71 seconds
#
#
#
# Density matrix difference norm:  58.10070148969162
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00214404156077
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804037356
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573469389
# Coulomb Energy                  6321.7172809537051
# Exchange-Correlation Energy     -278.3781618573321
# --------------------------------------------------
# Total Energy                   -2158.4748827998092
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019467068
#
#
# HOMO-LUMO gap: 0.01447403056052679 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  53.369975492401956
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00180767720957
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768208322
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230005855
# Coulomb Energy                  6361.2336350668047
# Exchange-Correlation Energy     -281.9436333440912
# --------------------------------------------------
# Total Energy                   -2182.5642309369196
# --------------------------------------------------
#
#
#
# Energy difference :  24.08934813711039
#
#
# HOMO-LUMO gap: 0.008841693995430222 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 5.84 seconds
#
#
#
# Density matrix difference norm:  42.83901509487013
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009908414894
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446995498
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382080657
# Coulomb Energy                  6294.5110601802808
# Exchange-Correlation Energy     -283.9707682331645
# --------------------------------------------------
# Total Energy                   -2345.8009933837529
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676244683338
#
#
# HOMO-LUMO gap: 0.007160714253432593 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 5.92 seconds
#
#
#
# Density matrix difference norm:  32.18186260038419
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99978638551784
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019078943
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650761666
# Coulomb Energy                  6214.1516556247198
# Exchange-Correlation Energy     -284.6344014151342
# --------------------------------------------------
# Total Energy                   -2343.5239614615284
# --------------------------------------------------
#
#
#
# Energy difference :  2.2770319222245234
#
#
# HOMO-LUMO gap: 0.002450375010718195 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 5.87 seconds
#
#
#
# Density matrix difference norm:  33.32333313972385
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156514
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115037384
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996833643
# Coulomb Energy                  6284.6237009932393
# Exchange-Correlation Energy     -286.3084442723667
# --------------------------------------------------
# Total Energy                   -2352.7413339388877
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372477359277
#
#
# HOMO-LUMO gap: 0.0066733184130935985 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 5.84 seconds
#
#
#
# Density matrix difference norm:  26.09828191565601
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002679784587
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383643049
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896544432
# Coulomb Energy                  6418.8046173113407
# Exchange-Correlation Energy     -305.3162932884613
# --------------------------------------------------
# Total Energy                   -2410.9382035263689
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686958748116
#
#
# HOMO-LUMO gap: 0.007960539573718547 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  17.534698642377272
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057275966
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201863900
# Coulomb Energy                  6329.9135850863013
# Exchange-Correlation Energy     -297.7524519058717
# --------------------------------------------------
# Total Energy                   -2373.3942312001627
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397232620613
#
#
# HOMO-LUMO gap: 0.013997838566454854 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  16.420704644912927
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.999823798323
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814653123
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928330748
# Coulomb Energy                  6324.0705156590129
# Exchange-Correlation Energy     -296.6169927423509
# --------------------------------------------------
# Total Energy                   -2423.4444445549607
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335479796
#
#
# HOMO-LUMO gap: 0.005801716892759462 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  17.91362907375778
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082557727933
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871577110
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553247482
# Coulomb Energy                  6269.4959589831160
# Exchange-Correlation Energy     -292.3687260434446
# --------------------------------------------------
# Total Energy                   -2388.5334777326771
# --------------------------------------------------
#
#
#
# Energy difference :  34.910966822283626
#
#
# HOMO-LUMO gap: 0.01173972464508273 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  18.864810928452172
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008953428889
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999711443
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986959532
# Coulomb Energy                  6304.9912271458516
# Exchange-Correlation Energy     -292.7049362975683
# --------------------------------------------------
# Total Energy                   -2419.7690892662931
# --------------------------------------------------
#
#
#
# Energy difference :  31.235611533616066
#
#
# HOMO-LUMO gap: 0.0016995925760880937 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  14.268938602207333
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015431500503
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930621925
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204735209
# Coulomb Energy                  6279.2250589673040
# Exchange-Correlation Energy     -293.0502585452323
# --------------------------------------------------
# Total Energy                   -2419.7439510059849
# --------------------------------------------------
#
#
#
# Energy difference :  0.02513826030826749
#
#
# HOMO-LUMO gap: 0.005846431210974987 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  12.512861011094842
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026512183956
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104138650
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140342371
# Coulomb Energy                  6304.4543925160924
# Exchange-Correlation Energy     -294.2073055524384
# --------------------------------------------------
# Total Energy                   -2431.0698882553588
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937249373965
#
#
# HOMO-LUMO gap: 0.01645234956096646 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  10.313139444445355
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.999915997752
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763828804
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614181342
# Coulomb Energy                  6320.4324015781021
# Exchange-Correlation Energy     -296.9899338049873
# --------------------------------------------------
# Total Energy                   -2429.5155260310166
# --------------------------------------------------
#
#
#
# Energy difference :  1.554362224342185
#
#
# HOMO-LUMO gap: 0.005064351063460232 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  8.08497266965086
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0000976405892
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466500340
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611214041
# Coulomb Energy                  6316.3510406923097
# Exchange-Correlation Energy     -296.7435745385956
# --------------------------------------------------
# Total Energy                   -2437.9484982143013
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972183284619
#
#
# HOMO-LUMO gap: 0.05893038873836576 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  4.102604850217864
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011810611767
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611029998316
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451736722
# Coulomb Energy                  6313.1881517239799
# Exchange-Correlation Energy     -295.9055099897516
# --------------------------------------------------
# Total Energy                   -2441.0025949313167
# --------------------------------------------------
#
#
#
# Energy difference :  3.0540967170154545
#
#
# HOMO-LUMO gap: 0.0053372504783274766 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  6.25407648112142
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361986995
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051689694
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545140080
# Coulomb Energy                  6280.4277633908932
# Exchange-Correlation Energy     -293.2139724473416
# --------------------------------------------------
# Total Energy                   -2436.9286385507949
# --------------------------------------------------
#
#
#
# Energy difference :  4.0739563805218495
#
#
# HOMO-LUMO gap: 0.011871839802334597 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  7.413375411080851
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002633558748
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726554897086
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918835798
# Coulomb Energy                  6298.7681987369378
# Exchange-Correlation Energy     -294.0996241347303
# --------------------------------------------------
# Total Energy                   -2439.1315678433075
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292925126356
#
#
# HOMO-LUMO gap: 0.10362999795155976 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  4.188397589678307
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011624361326
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485021787
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696463270
# Coulomb Energy                  6305.6013415989000
# Exchange-Correlation Energy     -295.1700654130541
# --------------------------------------------------
# Total Energy                   -2441.2043815093912
# --------------------------------------------------
#
#
#
# Energy difference :  2.0728136660836753
#
#
# HOMO-LUMO gap: 0.03035834740672607 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  1.088118680132429
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001058435007
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355843948
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042569344
# Coulomb Energy                  6306.4146008185044
# Exchange-Correlation Energy     -295.1986114170776
# --------------------------------------------------
# Total Energy                   -2441.2281207654187
# --------------------------------------------------
#
#
#
# Energy difference :  0.023739256027511146
#
#
# HOMO-LUMO gap: 0.10156738659373832 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.6147083204261625
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011386478906
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391412389
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706638832
# Coulomb Energy                  6305.3788664343137
# Exchange-Correlation Energy     -295.1059315049041
# --------------------------------------------------
# Total Energy                   -2441.3391123873316
# --------------------------------------------------
#
#
#
# Energy difference :  0.11099162191294454
#
#
# HOMO-LUMO gap: 0.12914420508135482 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.22866753080201602
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001129709716
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680215952914
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454843273
# Coulomb Energy                  6306.4753103318399
# Exchange-Correlation Energy     -295.2425453761734
# --------------------------------------------------
# Total Energy                   -2441.3433899946831
# --------------------------------------------------
#
#
#
# Energy difference :  0.00427760735146876
#
#
# HOMO-LUMO gap: 0.1191409271346986 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.13316828789238713
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924017
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663327776
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009438218
# Coulomb Energy                  6305.4375957437633
# Exchange-Correlation Energy     -295.1178679620396
# --------------------------------------------------
# Total Energy                   -2441.3482164466159
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451932785858
#
#
# HOMO-LUMO gap: 0.07758609961440546 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.16794684431281953
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011918273236
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810461919
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356945490
# Coulomb Energy                  6304.4474550026471
# Exchange-Correlation Energy     -294.9863691582706
# --------------------------------------------------
# Total Energy                   -2441.3482383466517
# --------------------------------------------------
#
#
#
# Energy difference :  2.190003579016775e-05
#
#
# HOMO-LUMO gap: 0.08220407416437767 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.08195634552437019
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001176128904
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560666197
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184229685
# Coulomb Energy                  6305.2666287322336
# Exchange-Correlation Energy     -295.0991774795386
# --------------------------------------------------
# Total Energy                   -2441.3500652303410
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836893184925
#
#
# HOMO-LUMO gap: 0.08681393247860103 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.030947650024909543
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011717111374
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449607209
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969465816
# Coulomb Energy                  6305.1999901383351
# Exchange-Correlation Energy     -295.0882138897753
# --------------------------------------------------
# Total Energy                   -2441.3501506049652
# --------------------------------------------------
#
#
#
# Energy difference :  8.537462417734787e-05
#
#
# HOMO-LUMO gap: 0.08605512219150144 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0153594201249872
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011741243867
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082986114
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754508540
# Coulomb Energy                  6305.1611656009591
# Exchange-Correlation Energy     -295.0851653175713
# --------------------------------------------------
# Total Energy                   -2441.3502114037547
# --------------------------------------------------
#
#
#
# Energy difference :  6.079878949094564e-05
#
#
# HOMO-LUMO gap: 0.0861055955503135 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.005850728280270622
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173080263
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341357605
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624064297
# Coulomb Energy                  6305.1739654234188
# Exchange-Correlation Energy     -295.0859344062352
# --------------------------------------------------
# Total Energy                   -2441.3502195515339
# --------------------------------------------------
#
#
#
# Energy difference :  8.147779226419516e-06
#
#
# HOMO-LUMO gap: 0.08627753380283268 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0022687655621753274
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730379333
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171300994
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318196
# Coulomb Energy                  6305.1767750459876
# Exchange-Correlation Energy     -295.0862921108176
# --------------------------------------------------
# Total Energy                   -2441.3502203024964
# --------------------------------------------------
#
#
#
# Energy difference :  7.509624992962927e-07
#
#
# HOMO-LUMO gap: 0.08629954674337881 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.0014216232819243158
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161183
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335501764
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841016197
# Coulomb Energy                  6305.1678310989255
# Exchange-Correlation Energy     -295.0851232567624
# --------------------------------------------------
# Total Energy                   -2441.3502204457791
# --------------------------------------------------
#
#
#
# Energy difference :  1.432827048120089e-07
#
#
# HOMO-LUMO gap: 0.08625864034184444 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.000790521364088315
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173192671
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319417
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598611
# Coulomb Energy                  6305.1716231999053
# Exchange-Correlation Energy     -295.0855737005027
# --------------------------------------------------
# Total Energy                   -2441.3502206120629
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628382581984624e-07
#
#
# HOMO-LUMO gap: 0.08626853544505195 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.000286320214351821
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731389475
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851889701
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651370634
# Coulomb Energy                  6305.1740152928123
# Exchange-Correlation Energy     -295.0859370217332
# --------------------------------------------------
# Total Energy                   -2441.3502206202138
# --------------------------------------------------
#
#
#
# Energy difference :  8.150891517288983e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.350220620214
# -------------------------------------
#
#
#
# Time taken : 270.44 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           22.97
# Density Fitting                         5.77
#     DF (gamma)                          1.07
#     DF (coeff)                          0.17
#     DF (Jtri)                           4.1
# DIIS                                    3.79
# KS matrix diagonalization               3.86
# One electron Integrals (S, T, Vnuc)     0.15
# Coulomb Integrals (2c2e + 3c2e)         30.54
# Grids construction                      17.09
# Exchange-Correlation Term               181.76
# Misc.                                   4.52
# Complete SCF                            270.44

# %% [markdown]
# ### Benchmark #4 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.23 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.93 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.17
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04819147000011981
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.22 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  1.46
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  67.67 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 54.39 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 59.65 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.37 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00086590367755
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182392
# Exchange-Correlation Energy     -158.3094688039744
# --------------------------------------------------
# Total Energy                    -881.4876584497742
# --------------------------------------------------
#
#
#
# Energy difference :  881.4876584497742
#
#
# HOMO-LUMO gap: 0.6897308990672384 au
# HOMO-LUMO gap: 18.768 eV
#
#
# Time taken for the previous iteration: 13.6 seconds
#
#
#
# Density matrix difference norm:  177.4118335697648
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999463807942
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3704438288987
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5625483777221
# Coulomb Energy                 12707.6655166372329
# Exchange-Correlation Energy     -589.0109863899961
# --------------------------------------------------
# Total Energy                   -3195.6961127770173
# --------------------------------------------------
#
#
#
# Energy difference :  2314.208454327243
#
#
# HOMO-LUMO gap: 0.0026210885487775726 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 13.9 seconds
#
#
#
# Density matrix difference norm:  86.10072559736405
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0006718457629
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.0784549159434
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9542974310398
# Coulomb Energy                 10864.6104283847053
# Exchange-Correlation Energy     -358.7264210078229
# --------------------------------------------------
# Total Energy                   -3357.7828976811015
# --------------------------------------------------
#
#
#
# Energy difference :  162.0867849040842
#
#
# HOMO-LUMO gap: 0.002532292523600913 au
# HOMO-LUMO gap: 0.069 eV
#
#
# Time taken for the previous iteration: 14.15 seconds
#
#
#
# Density matrix difference norm:  65.1326442919063
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00008159556376
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9266970290082
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4589790561754
# Coulomb Energy                 11125.2421950887256
# Exchange-Correlation Energy     -407.6867498868747
# --------------------------------------------------
# Total Energy                   -3374.4550203440576
# --------------------------------------------------
#
#
#
# Energy difference :  16.6721226629561
#
#
# HOMO-LUMO gap: 0.004414389957738268 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 14.08 seconds
#
#
#
# Density matrix difference norm:  63.85668121077765
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99953484298385
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.2877136079842
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.8757373777134
# Coulomb Energy                 12063.6748125265185
# Exchange-Correlation Energy     -415.0710986786435
# --------------------------------------------------
# Total Energy                   -3056.3510099554751
# --------------------------------------------------
#
#
#
# Energy difference :  318.10401038858254
#
#
# HOMO-LUMO gap: 0.006644147335901504 au
# HOMO-LUMO gap: 0.181 eV
#
#
# Time taken for the previous iteration: 14.0 seconds
#
#
#
# Density matrix difference norm:  54.591690612615594
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002691352941
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.5088611889805
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.3924608741277
# Coulomb Energy                 11512.9997141048152
# Exchange-Correlation Energy     -417.4553406800409
# --------------------------------------------------
# Total Energy                   -3536.1147744631544
# --------------------------------------------------
#
#
#
# Energy difference :  479.7637645076793
#
#
# HOMO-LUMO gap: 0.00101236149957183 au
# HOMO-LUMO gap: 0.028 eV
#
#
# Time taken for the previous iteration: 14.0 seconds
#
#
#
# Density matrix difference norm:  51.11495004700882
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99974294779855
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.1797883156542
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.7800541097454
# Coulomb Energy                 11567.1010375799015
# Exchange-Correlation Energy     -419.4337655480267
# --------------------------------------------------
# Total Energy                   -3074.2752097471111
# --------------------------------------------------
#
#
#
# Energy difference :  461.83956471604324
#
#
# HOMO-LUMO gap: 0.0046974716831033325 au
# HOMO-LUMO gap: 0.128 eV
#
#
# Time taken for the previous iteration: 13.99 seconds
#
#
#
# Density matrix difference norm:  44.744826455358115
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996550749725
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.4126884142825
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6364207736710
# Coulomb Energy                 11495.5483931944800
# Exchange-Correlation Energy     -423.7795770218079
# --------------------------------------------------
# Total Energy                   -3532.5501990410175
# --------------------------------------------------
#
#
#
# Energy difference :  458.2749892939064
#
#
# HOMO-LUMO gap: 0.0004633975957847314 au
# HOMO-LUMO gap: 0.013 eV
#
#
# Time taken for the previous iteration: 14.07 seconds
#
#
#
# Density matrix difference norm:  20.712738435018974
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999545434494
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.2739432619637
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.0351193128654
# Coulomb Energy                 11580.0530324150386
# Exchange-Correlation Energy     -439.2769213928576
# --------------------------------------------------
# Total Energy                   -3535.0054604999950
# --------------------------------------------------
#
#
#
# Energy difference :  2.455261458977475
#
#
# HOMO-LUMO gap: 0.007602899144372455 au
# HOMO-LUMO gap: 0.207 eV
#
#
# Time taken for the previous iteration: 14.11 seconds
#
#
#
# Density matrix difference norm:  17.82978163320207
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00025109396574
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28135.5805669245674
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3632.4560411715925
# Coulomb Energy                 11640.5650664872646
# Exchange-Correlation Energy     -443.9779460155972
# --------------------------------------------------
# Total Energy                   -3536.0801528543852
# --------------------------------------------------
#
#
#
# Energy difference :  1.0746923543902085
#
#
# HOMO-LUMO gap: 0.004336286106107395 au
# HOMO-LUMO gap: 0.118 eV
#
#
# Time taken for the previous iteration: 14.12 seconds
#
#
#
# Density matrix difference norm:  21.75078771481584
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00009764970173
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27873.9019925608591
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3557.6224523504120
# Coulomb Energy                 11493.5519514048246
# Exchange-Correlation Energy     -433.3671342162859
# --------------------------------------------------
# Total Energy                   -3485.6374705949838
# --------------------------------------------------
#
#
#
# Energy difference :  50.44268225940141
#
#
# HOMO-LUMO gap: 0.01799978162641802 au
# HOMO-LUMO gap: 0.490 eV
#
#
# Time taken for the previous iteration: 14.09 seconds
#
#
#
# Density matrix difference norm:  18.304820007460467
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0001218986372
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28089.3481558272579
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3573.7337556568355
# Coulomb Energy                 11601.6672610918995
# Exchange-Correlation Energy     -437.8374210826740
# --------------------------------------------------
# Total Energy                   -3581.3273077342747
# --------------------------------------------------
#
#
#
# Energy difference :  95.68983713929083
#
#
# HOMO-LUMO gap: 0.009809885488671274 au
# HOMO-LUMO gap: 0.267 eV
#
#
# Time taken for the previous iteration: 14.06 seconds
#
#
#
# Density matrix difference norm:  15.6035909586621
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.000008445545
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27851.1830277839545
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3504.4630744292458
# Coulomb Energy                 11481.6334492499009
# Exchange-Correlation Energy     -426.3111912604938
# --------------------------------------------------
# Total Energy                   -3520.9404429383812
# --------------------------------------------------
#
#
#
# Energy difference :  60.386864795893416
#
#
# HOMO-LUMO gap: 0.00128248255294236 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 14.05 seconds
#
#
#
# Density matrix difference norm:  15.43406986520316
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99987880338034
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27993.2533770828013
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3536.1983083522778
# Coulomb Energy                 11535.6719773090008
# Exchange-Correlation Energy     -432.7365139834263
# --------------------------------------------------
# Total Energy                   -3583.6623529780245
# --------------------------------------------------
#
#
#
# Energy difference :  62.72191003964326
#
#
# HOMO-LUMO gap: 0.004883590411540281 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 14.07 seconds
#
#
#
# Density matrix difference norm:  4.995181629427549
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000251702026
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27981.3353268028877
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3529.9571886589438
# Coulomb Energy                 11529.5195428164916
# Exchange-Correlation Energy     -431.6645536814084
# --------------------------------------------------
# Total Energy                   -3583.0658965819366
# --------------------------------------------------
#
#
#
# Energy difference :  0.5964563960878877
#
#
# HOMO-LUMO gap: 0.047205156115635694 au
# HOMO-LUMO gap: 1.285 eV
#
#
# Time taken for the previous iteration: 14.1 seconds
#
#
#
# Density matrix difference norm:  4.204244764130848
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00002943938796
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27999.1239635204111
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.4625397489681
# Coulomb Energy                 11537.2109867256713
# Exchange-Correlation Energy     -433.3658591764405
# --------------------------------------------------
# Total Energy                   -3585.3590437952880
# --------------------------------------------------
#
#
#
# Energy difference :  2.2931472133514035
#
#
# HOMO-LUMO gap: 0.10565060523768215 au
# HOMO-LUMO gap: 2.875 eV
#
#
# Time taken for the previous iteration: 14.1 seconds
#
#
#
# Density matrix difference norm:  0.9287339346379804
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000198744164
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28005.1957005299009
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3541.6973777204121
# Coulomb Energy                 11540.9990082473032
# Exchange-Correlation Energy     -433.6709885229753
# --------------------------------------------------
# Total Energy                   -3585.7130506582398
# --------------------------------------------------
#
#
#
# Energy difference :  0.35400686295179185
#
#
# HOMO-LUMO gap: 0.08160176876697896 au
# HOMO-LUMO gap: 2.220 eV
#
#
# Time taken for the previous iteration: 14.11 seconds
#
#
#
# Density matrix difference norm:  0.47099492512022834
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001543753734
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27997.2512008951126
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3537.3766042667207
# Coulomb Energy                 11536.7451395782155
# Exchange-Correlation Energy     -433.0466479914365
# --------------------------------------------------
# Total Energy                   -3585.7188526146911
# --------------------------------------------------
#
#
#
# Energy difference :  0.0058019564512505895
#
#
# HOMO-LUMO gap: 0.09622541682487998 au
# HOMO-LUMO gap: 2.618 eV
#
#
# Time taken for the previous iteration: 14.07 seconds
#
#
#
# Density matrix difference norm:  0.2534565798731599
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001674477966
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.5564265241192
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5447395274600
# Coulomb Energy                 11540.2918406918307
# Exchange-Correlation Energy     -433.4718308678237
# --------------------------------------------------
# Total Energy                   -3585.7344247457295
# --------------------------------------------------
#
#
#
# Energy difference :  0.015572131038425141
#
#
# HOMO-LUMO gap: 0.10308245703459377 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 14.07 seconds
#
#
#
# Density matrix difference norm:  0.10396166398872284
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001728845297
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6842589829466
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.6972361705461
# Coulomb Energy                 11539.1501776028963
# Exchange-Correlation Energy     -433.3563238462326
# --------------------------------------------------
# Total Energy                   -3585.7359166288170
# --------------------------------------------------
#
#
#
# Energy difference :  0.0014918830875103595
#
#
# HOMO-LUMO gap: 0.10375679445124701 au
# HOMO-LUMO gap: 2.823 eV
#
#
# Time taken for the previous iteration: 14.07 seconds
#
#
#
# Density matrix difference norm:  0.04580936294281119
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001639994383
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0103516585950
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8693000417288
# Coulomb Energy                 11539.3276465165836
# Exchange-Correlation Energy     -433.3803352181346
# --------------------------------------------------
# Total Energy                   -3585.7364878914941
# --------------------------------------------------
#
#
#
# Energy difference :  0.0005712626771128271
#
#
# HOMO-LUMO gap: 0.10309625428832123 au
# HOMO-LUMO gap: 2.805 eV
#
#
# Time taken for the previous iteration: 14.08 seconds
#
#
#
# Density matrix difference norm:  0.029554317152876187
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001635067497
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.8156482418999
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7421798063547
# Coulomb Energy                 11539.2423484233805
# Exchange-Correlation Energy     -433.3626933893798
# --------------------------------------------------
# Total Energy                   -3585.7365609746212
# --------------------------------------------------
#
#
#
# Energy difference :  7.308312706300057e-05
#
#
# HOMO-LUMO gap: 0.10314551108864166 au
# HOMO-LUMO gap: 2.807 eV
#
#
# Time taken for the previous iteration: 14.1 seconds
#
#
#
# Density matrix difference norm:  0.017959400179832993
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000161248514
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0456961465934
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8499452783044
# Coulomb Energy                 11539.3793324646958
# Exchange-Correlation Energy     -433.3773972607564
# --------------------------------------------------
# Total Energy                   -3585.7365632374276
# --------------------------------------------------
#
#
#
# Energy difference :  2.2628064471064135e-06
#
#
# HOMO-LUMO gap: 0.10320225769363597 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 14.1 seconds
#
#
#
# Density matrix difference norm:  0.010130198267808723
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001623811556
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9409515298794
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096975070057
# Coulomb Energy                 11539.3092434326863
# Exchange-Correlation Energy     -433.3718359105554
# --------------------------------------------------
# Total Energy                   -3585.7365940738218
# --------------------------------------------------
#
#
#
# Energy difference :  3.0836394216748886e-05
#
#
# HOMO-LUMO gap: 0.10326233784098351 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.09 seconds
#
#
#
# Density matrix difference norm:  0.0030654439365543637
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001629087456
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9648930342410
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8217790785166
# Coulomb Energy                 11539.3227881256335
# Exchange-Correlation Energy     -433.3735230058130
# --------------------------------------------------
# Total Energy                   -3585.7365964089804
# --------------------------------------------------
#
#
#
# Energy difference :  2.3351585696218535e-06
#
#
# HOMO-LUMO gap: 0.10324998824142076 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.07 seconds
#
#
#
# Density matrix difference norm:  0.0010174381908089434
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001627548517
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9526818581326
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8145317592175
# Coulomb Energy                 11539.3168310526016
# Exchange-Correlation Energy     -433.3725300793377
# --------------------------------------------------
# Total Energy                   -3585.7365966987290
# --------------------------------------------------
#
#
#
# Energy difference :  2.89748641080223e-07
#
#
# HOMO-LUMO gap: 0.10323606098322113 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 14.06 seconds
#
#
#
# Density matrix difference norm:  0.00037633014759512495
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001627333927
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9484625842961
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8126747875453
# Coulomb Energy                 11539.3142180560153
# Exchange-Correlation Energy     -433.3722793835563
# --------------------------------------------------
# Total Energy                   -3585.7365966973666
# --------------------------------------------------
#
#
#
# Energy difference :  1.3624230632558465e-09
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.7365966973666
# -------------------------------------
#
#
#
# Time taken : 565.92 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           60.02
# Density Fitting                         11.75
#     DF (gamma)                          2.45
#     DF (coeff)                          0.19
#     DF (Jtri)                           8.39
# DIIS                                    8.25
# KS matrix diagonalization               6.79
# One electron Integrals (S, T, Vnuc)     0.23
# Coulomb Integrals (2c2e + 3c2e)         67.67
# Grids construction                      54.39
# Exchange-Correlation Term               351.67
# Misc.                                   5.16
# Complete SCF                            565.92

# %% [markdown]
# ## Dynamic Precision On

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.03 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.04 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0008898739999949612
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.04
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.84 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.34 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.6 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.06 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000355
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709560
# Exchange-Correlation Energy      -16.0363502502441
# --------------------------------------------------
# Total Energy                     -93.1572655540416
# --------------------------------------------------
#
#
#
# Energy difference :  93.1572655540416
#
#
# HOMO-LUMO gap: 2.643230893268374 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.69 seconds
#
#
#
# Density matrix difference norm:  43.347376950419495
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999992
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065134268144
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632901411638
# Coulomb Energy                   501.1179499873590
# Exchange-Correlation Energy      -62.5998153686523
# --------------------------------------------------
# Total Energy                    -340.0671116228204
# --------------------------------------------------
#
#
#
# Energy difference :  246.90984606877885
#
#
# HOMO-LUMO gap: 0.004895001056082204 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  28.6122513783187
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000107
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015434342769
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404486356321
# Coulomb Energy                   293.3105327789885
# Exchange-Correlation Energy      -37.4191284179688
# --------------------------------------------------
# Total Energy                    -355.5117133935016
# --------------------------------------------------
#
#
#
# Energy difference :  15.444601770681118
#
#
# HOMO-LUMO gap: 0.04090611597423416 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.15 seconds
#
#
#
# Density matrix difference norm:  21.394380435693648
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6802048745126
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079158470891
# Coulomb Energy                   367.2116081156610
# Exchange-Correlation Energy      -44.5831108093262
# --------------------------------------------------
# Total Energy                    -380.5858146769651
# --------------------------------------------------
#
#
#
# Energy difference :  25.074101283463563
#
#
# HOMO-LUMO gap: 0.018045819534172183 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  5.193655309005816
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853211394645
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987312449324
# Coulomb Energy                   364.3594842204063
# Exchange-Correlation Energy      -44.5593338012695
# --------------------------------------------------
# Total Energy                    -378.6284624312718
# --------------------------------------------------
#
#
#
# Energy difference :  1.9573522456933574
#
#
# HOMO-LUMO gap: 0.08497506224169701 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  4.776044383076168
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000023
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113353911058
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536993637312
# Coulomb Energy                   368.1595786044458
# Exchange-Correlation Energy      -45.0864906311035
# --------------------------------------------------
# Total Energy                    -381.1265710099088
# --------------------------------------------------
#
#
#
# Energy difference :  2.4981085786370727
#
#
# HOMO-LUMO gap: 0.14153440093739736 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5199018206072212
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759870186244
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620529814623
# Coulomb Energy                   369.0651872518501
# Exchange-Correlation Energy      -45.1361846923828
# --------------------------------------------------
# Total Energy                    -381.2269544335712
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038342366237885
#
#
# HOMO-LUMO gap: 0.1350579305186217 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.33141822112922986
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685883045736
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352932575489
# Coulomb Energy                   369.6332915647458
# Exchange-Correlation Energy      -45.2082252502441
# --------------------------------------------------
# Total Energy                    -381.2502516883994
# --------------------------------------------------
#
#
#
# Energy difference :  0.02329725482820777
#
#
# HOMO-LUMO gap: 0.01948112047548613 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5819574011097002
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471076686568
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753380205271
# Coulomb Energy                   374.0875565365552
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611101756
# --------------------------------------------------
#
#
#
# Energy difference :  0.13180942177615407
#
#
# HOMO-LUMO gap: 0.12602028669997345 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  0.4597239775963388
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167311182921
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482981739471
# Coulomb Energy                   377.3936785488535
# Exchange-Correlation Energy      -46.1032257080078
# --------------------------------------------------
# Total Energy                    -381.4200030593757
# --------------------------------------------------
#
#
#
# Energy difference :  0.03794194920010341
#
#
# HOMO-LUMO gap: 0.16611333053473643 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  0.14506670258709686
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6774115562218
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4957003907792
# Coulomb Energy                   377.1713417801269
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261838450984
# --------------------------------------------------
#
#
#
# Energy difference :  0.006180785722733617
#
#
# HOMO-LUMO gap: 0.18109750595326532 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.05597038785669171
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466991731235
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5465057500018
# Coulomb Energy                   377.1955793525887
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266045251887
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004206800903148178
#
#
# HOMO-LUMO gap: 0.18093185638001524 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.025624539781222314
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6791043635653
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228770244511
# Coulomb Energy                   377.1480814133166
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267298557952
# --------------------------------------------------
#
#
#
# Energy difference :  0.000125330606465468
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050730665211767 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  0.008410601201382366
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007494818696
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758646249996
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145535863858
# Coulomb Energy                   377.1522588566500
# Exchange-Correlation Energy      -46.0763604882694
# --------------------------------------------------
# Total Energy                    -381.4274356261096
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007057703144255356
#
#
# HOMO-LUMO gap: 0.1805594177467029 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0026418714064215918
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750320948
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547069029748
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032889737221
# Coulomb Energy                   377.1410365648679
# Exchange-Correlation Energy      -46.0750325767575
# --------------------------------------------------
# Total Energy                    -381.4274368970188
# --------------------------------------------------
#
#
#
# Energy difference :  1.2709091947726847e-06
#
#
# HOMO-LUMO gap: 0.18056583448658547 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0017678391935565887
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749795147
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715784380247
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117381337710
# Coulomb Energy                   377.1506250231095
# Exchange-Correlation Energy      -46.0761996769600
# --------------------------------------------------
# Total Energy                    -381.4274379139807
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169619031330512e-06
#
#
# HOMO-LUMO gap: 0.18057810005494554 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018263944814313764
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749433851
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890954308228
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201163633820
# Coulomb Energy                   377.1610739046047
# Exchange-Correlation Energy      -46.0775109642904
# --------------------------------------------------
# Total Energy                    -381.4274390830030
# --------------------------------------------------
#
#
#
# Energy difference :  1.1690223118421272e-06
#
#
# HOMO-LUMO gap: 0.18069051721659188 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0015078228592289627
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007497971
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793142630952
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150718660137
# Coulomb Energy                   377.1557642489247
# Exchange-Correlation Energy      -46.0769384584163
# --------------------------------------------------
# Total Energy                    -381.4274395624494
# --------------------------------------------------
#
#
#
# Energy difference :  4.794463848156738e-07
#
#
# HOMO-LUMO gap: 0.18064424248409638 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.00046671667749325035
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007498303745
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995819657
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900979609
# Coulomb Energy                   377.1550630969091
# Exchange-Correlation Energy      -46.0768702751827
# --------------------------------------------------
# Total Energy                    -381.4274396181549
# --------------------------------------------------
#
#
#
# Energy difference :  5.570552730205236e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743961815495
# -------------------------------------
#
#
#
# Time taken : 9.79 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.65
# Density Fitting                         0.24
#     DF (gamma)                          0.08
#     DF (coeff)                          0.07
#     DF (Jtri)                           0.09
# DIIS                                    0.1
# KS matrix diagonalization               0.36
# One electron Integrals (S, T, Vnuc)     0.03
# Coulomb Integrals (2c2e + 3c2e)         0.84
# Grids construction                      0.34
# Exchange-Correlation Term               6.22
# Misc.                                   1.0
# Complete SCF                            9.79

# %% [markdown]
# ### Benchmark #5 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.1 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.002163287000030323
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.74 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.07 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.07 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371784
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120595
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961205947
#
#
# HOMO-LUMO gap: 1.765506807214472 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.28 seconds
#
#
#
# Density matrix difference norm:  66.88323605808803
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816168858704
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207644691607
# Coulomb Energy                  1272.5916576120674
# Exchange-Correlation Energy     -125.2197723388672
# --------------------------------------------------
# Total Energy                    -680.0824210262774
# --------------------------------------------------
#
#
#
# Energy difference :  494.63380141421794
#
#
# HOMO-LUMO gap: 0.00039500615221571556 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  39.27352432793015
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.001236
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671666176169
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861185032717
# Coulomb Energy                   861.6520702032593
# Exchange-Correlation Energy      -75.4418334960938
# --------------------------------------------------
# Total Energy                    -709.3642652899476
# --------------------------------------------------
#
#
#
# Energy difference :  29.281844263670223
#
#
# HOMO-LUMO gap: 0.027815576345771198 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  28.14516363992176
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99994
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982282476345
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525304345678
# Coulomb Energy                  1000.6416009620770
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464582044610
# --------------------------------------------------
#
#
#
# Energy difference :  24.382192914513325
#
#
# HOMO-LUMO gap: 0.006873881120066788 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  18.101423188291406
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394470590110
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643058400542
# Coulomb Energy                  1039.7364436431365
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035183409124
# --------------------------------------------------
#
#
#
# Energy difference :  44.14293986354858
#
#
# HOMO-LUMO gap: 0.009401599447634329 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  13.030480146563596
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9281985114967
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4697782000410
# Coulomb Energy                  1004.3617049984615
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228962465433
# --------------------------------------------------
#
#
#
# Energy difference :  60.019377905630904
#
#
# HOMO-LUMO gap: 0.024324031154654153 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.651673169640044
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2543708188323
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338780608370
# Coulomb Energy                   997.3404994327673
# Exchange-Correlation Energy      -89.6695938110352
# --------------------------------------------------
# Total Energy                    -755.2430410190311
# --------------------------------------------------
#
#
#
# Energy difference :  5.6201447724878335
#
#
# HOMO-LUMO gap: 0.001291109349469452 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.531121583370914
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000244
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9935106987405
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455305477804
# Coulomb Energy                  1008.9226270553519
# Exchange-Correlation Energy      -89.8105316162109
# --------------------------------------------------
# Total Energy                    -754.8293385945871
# --------------------------------------------------
#
#
#
# Energy difference :  0.41370242444406813
#
#
# HOMO-LUMO gap: 0.01538885760104941 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  7.342496805327134
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6263327388406
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2045013210484
# Coulomb Energy                  1033.2839548468755
# Exchange-Correlation Energy      -92.8135986328125
# --------------------------------------------------
# Total Energy                    -754.2449290864975
# --------------------------------------------------
#
#
#
# Energy difference :  0.5844095080896068
#
#
# HOMO-LUMO gap: 0.21170748018592617 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  6.051896195943051
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9762924851552
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1048859013216
# Coulomb Energy                  1046.8936487685846
# Exchange-Correlation Energy      -94.6926879882812
# --------------------------------------------------
# Total Energy                    -761.9638996862982
# --------------------------------------------------
#
#
#
# Energy difference :  7.718970599800741
#
#
# HOMO-LUMO gap: 0.021087415279443786 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  4.592855662337799
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186501134238
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7140612736667
# Coulomb Energy                  1016.5840743563463
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8410435614915
# --------------------------------------------------
#
#
#
# Energy difference :  2.122856124806731
#
#
# HOMO-LUMO gap: 0.0879506699274952 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  4.199971620490387
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5724881101287
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4485448152059
# Coulomb Energy                  1025.9226123577102
# Exchange-Correlation Energy      -92.2370223999023
# --------------------------------------------------
# Total Energy                    -762.7318072198830
# --------------------------------------------------
#
#
#
# Energy difference :  2.8907636583915064
#
#
# HOMO-LUMO gap: 0.1448458036829383 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.908741468490855
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899823019053
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303628206565
# Coulomb Energy                  1024.4800317487955
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263924452997
# --------------------------------------------------
#
#
#
# Energy difference :  0.0945852254167221
#
#
# HOMO-LUMO gap: 0.09120587560654567 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.33859541303832263
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063809186289
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273613849725
# Coulomb Energy                  1024.8155228560122
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565126331659
# --------------------------------------------------
#
#
#
# Energy difference :  0.030120187866259585
#
#
# HOMO-LUMO gap: 0.10812611071951866 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.13342117559561995
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7707736800239
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490273985191
# Coulomb Energy                  1024.3963717403387
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586828550863
# --------------------------------------------------
#
#
#
# Energy difference :  0.0021702219203234563
#
#
# HOMO-LUMO gap: 0.11558372543635183 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.05241036518535716
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028259107756
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1553881607493
# Coulomb Energy                  1024.6505220937797
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595513627452
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008685076588790253
#
#
# HOMO-LUMO gap: 0.11553042817248896 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.014070335573470765
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000189420807
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543970412224
# Coulomb Energy                  1024.5347569979715
# Exchange-Correlation Energy      -92.1552581787109
# --------------------------------------------------
# Total Energy                    -762.8595769643659
# --------------------------------------------------
#
#
#
# Energy difference :  2.5601620791348978e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.11964649559155477 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.015808004964944306
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745390447
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803858424533
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978022803620
# Coulomb Energy                  1024.5775713766354
# Exchange-Correlation Energy      -92.1624878732933
# --------------------------------------------------
# Total Energy                    -762.8609539415172
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013769771512670559
#
#
# HOMO-LUMO gap: 0.11848000844329484 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.008700517091913265
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741302456
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328784912731
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722796171490
# Coulomb Energy                  1024.5524781237416
# Exchange-Correlation Energy      -92.1594108669276
# --------------------------------------------------
# Total Energy                    -762.8609855000784
# --------------------------------------------------
#
#
#
# Energy difference :  3.1558561204292346e-05
#
#
# HOMO-LUMO gap: 0.11834735112412967 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.002054349852740067
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739808539
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503347613030
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805113875501
# Coulomb Energy                  1024.5630591377376
# Exchange-Correlation Energy      -92.1607681967690
# --------------------------------------------------
# Total Energy                    -762.8609863155521
# --------------------------------------------------
#
#
#
# Energy difference :  8.154736406140728e-07
#
#
# HOMO-LUMO gap: 0.11844994151105079 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.002280387783761308
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742288624
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365054834792
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734599404645
# Coulomb Energy                  1024.5553040577440
# Exchange-Correlation Energy      -92.1597916411433
# --------------------------------------------------
# Total Energy                    -762.8609870091821
# --------------------------------------------------
#
#
#
# Energy difference :  6.936299996596063e-07
#
#
# HOMO-LUMO gap: 0.11849899824915358 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.0021210149912717522
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742173381
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510228906332
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0797964656214
# Coulomb Energy                  1024.5646232823249
# Exchange-Correlation Energy      -92.1609313806811
# --------------------------------------------------
# Total Energy                    -762.8609884061364
# --------------------------------------------------
#
#
#
# Energy difference :  1.3969543033454102e-06
#
#
# HOMO-LUMO gap: 0.11838532415996164 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.0014185148352024105
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741619994
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635537488311
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852198661626
# Coulomb Energy                  1024.5726720120060
# Exchange-Correlation Energy      -92.1618731065617
# --------------------------------------------------
# Total Energy                    -762.8609888599922
# --------------------------------------------------
#
#
#
# Energy difference :  4.538558187050512e-07
#
#
# HOMO-LUMO gap: 0.11838275421698558 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.0003223116528462894
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041733
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571685091950
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822982069920
# Coulomb Energy                  1024.5687889449564
# Exchange-Correlation Energy      -92.1614536504708
# --------------------------------------------------
# Total Energy                    -762.8609888904853
# --------------------------------------------------
#
#
#
# Energy difference :  3.049308361369185e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904853
# -------------------------------------
#
#
#
# Time taken : 15.68 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.21
# Density Fitting                         0.52
#     DF (gamma)                          0.15
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.25
# DIIS                                    0.14
# KS matrix diagonalization               0.64
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.74
# Grids construction                      1.07
# Exchange-Correlation Term               6.81
# Misc.                                   1.51
# Complete SCF                            15.68

# %% [markdown]
# ### Benchmark #6 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.09 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.26 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.008393299999852388
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.07 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.29
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.49 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 5.14 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 8.21 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355645
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929923027
# --------------------------------------------------
#
#
#
# Energy difference :  374.93249299230274
#
#
# HOMO-LUMO gap: 1.8503196895447749 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  107.82808392765959
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876321744690
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682663137804
# Coulomb Energy                  3537.3220829802062
# Exchange-Correlation Energy     -250.6110687255859
# --------------------------------------------------
# Total Energy                   -1359.8987077754068
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662147831041
#
#
# HOMO-LUMO gap: 0.002113837042772959 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  57.365047491756705
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4339726200678
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0382902509875
# Coulomb Energy                  2705.4087019806498
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539387306203
# --------------------------------------------------
#
#
#
# Energy difference :  59.15523095521348
#
#
# HOMO-LUMO gap: 0.019742610415533268 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  48.04762458039998
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987260331187
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516880408518
# Coulomb Energy                  3071.8807166781944
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010317314578
# --------------------------------------------------
#
#
#
# Energy difference :  56.6529069991625
#
#
# HOMO-LUMO gap: 0.014679275479660608 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  40.92171705743782
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335375174711
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1620893001893
# Coulomb Energy                  3051.7270285181421
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347880755100
# --------------------------------------------------
#
#
#
# Energy difference :  16.4337563440522
#
#
# HOMO-LUMO gap: 0.012567148583277163 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  26.926775904390993
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983161758921
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494773336139
# Coulomb Energy                  3003.5484466182270
# Exchange-Correlation Energy     -179.3104553222656
# --------------------------------------------------
# Total Energy                   -1523.5012037156566
# --------------------------------------------------
#
#
#
# Energy difference :  144.66641564014662
#
#
# HOMO-LUMO gap: 0.0032179385135384236 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  13.414502826469311
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00024
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4196981816203
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319374466266
# Coulomb Energy                  2977.4926628925068
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856584795993
# --------------------------------------------------
#
#
#
# Energy difference :  24.41554523605737
#
#
# HOMO-LUMO gap: 0.031829980009679404 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  12.4365941789211
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381499799292
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8446914813978
# Coulomb Energy                  3000.9338470998309
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434612203824
# --------------------------------------------------
#
#
#
# Energy difference :  23.657802740783154
#
#
# HOMO-LUMO gap: 0.012963726138270015 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.013465136943172
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677648701294
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553162888504
# Coulomb Energy                  3041.7902296256507
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430835478179
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996223274354634
#
#
# HOMO-LUMO gap: 0.021491235519818394 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  6.216637323675255
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4699618704290
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196354534567
# Coulomb Energy                  3063.1283227281083
# Exchange-Correlation Energy     -185.9102325439453
# --------------------------------------------------
# Total Energy                   -1521.9225924021475
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204911456703485
#
#
# HOMO-LUMO gap: 0.07962879021178032 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  4.429034472351883
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505044624661
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1094884862182
# Coulomb Energy                  3048.3900525250674
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820331214954
# --------------------------------------------------
#
#
#
# Energy difference :  3.659440719347913
#
#
# HOMO-LUMO gap: 0.11947952494731753 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.8332702799415014
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524417473258
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100139522593
# Coulomb Energy                  3044.2746783731054
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396912846580
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765816316252312
#
#
# HOMO-LUMO gap: 0.1091553576104142 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.43796773648597365
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333897776221
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380071287733
# Coulomb Energy                  3039.9319398537364
# Exchange-Correlation Energy     -184.3113403320312
# --------------------------------------------------
# Total Energy                   -1525.7651392964826
# --------------------------------------------------
#
#
#
# Energy difference :  0.025448011824664718
#
#
# HOMO-LUMO gap: 0.08049518697027405 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.2802189755949238
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675636799733
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0128924076873
# Coulomb Energy                  3041.4808635143709
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832831899486
# --------------------------------------------------
#
#
#
# Energy difference :  0.018143893466003647
#
#
# HOMO-LUMO gap: 0.0353620812920747 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.2021650369042349
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152321002701
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773167148359
# Coulomb Energy                  3040.7151033795235
# Exchange-Correlation Energy     -184.4732360839844
# --------------------------------------------------
# Total Energy                   -1525.7864042592337
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031210692850436317
#
#
# HOMO-LUMO gap: 0.044773962673242226 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  0.07633483475334224
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0312914207370
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161705917204
# Coulomb Energy                  3040.4442140047895
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875172660270
# --------------------------------------------------
#
#
#
# Energy difference :  0.0011130067932754173
#
#
# HOMO-LUMO gap: 0.0527907900486661 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  0.028440223964326806
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299736071065
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078515625802
# Coulomb Energy                  3040.4514280078565
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877012069839
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018394095695839496
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.049892871247739445 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  0.01283141728570622
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963123487
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444075717238
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722243982863
# Coulomb Energy                  3040.3964233895299
# Exchange-Correlation Energy     -184.4242562400248
# --------------------------------------------------
# Total Energy                   -1525.7903721932703
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026709862863754097
#
#
# HOMO-LUMO gap: 0.050552932384958005 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 2.36 seconds
#
#
#
# Density matrix difference norm:  0.005300439996718747
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960687673
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993300492188
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002706676015
# Coulomb Energy                  3040.4277545193740
# Exchange-Correlation Energy     -184.4287289091164
# --------------------------------------------------
# Total Energy                   -1525.7903899406979
# --------------------------------------------------
#
#
#
# Energy difference :  1.774742759153014e-05
#
#
# HOMO-LUMO gap: 0.05045898230372617 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.0021062658993239434
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396167391
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9998985336588
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3973948333323
# Coulomb Energy                  3040.4311709819126
# Exchange-Correlation Energy     -184.4287041971776
# --------------------------------------------------
# Total Energy                   -1525.7903930849311
# --------------------------------------------------
#
#
#
# Energy difference :  3.1442332328879274e-06
#
#
# HOMO-LUMO gap: 0.0506593337240728 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.004881655424155075
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396005372
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796139246340
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345416855497
# Coulomb Energy                  3040.4795322210043
# Exchange-Correlation Energy     -184.4344981963233
# --------------------------------------------------
# Total Energy                   -1525.7903943837432
# --------------------------------------------------
#
#
#
# Energy difference :  1.2988120943191461e-06
#
#
# HOMO-LUMO gap: 0.05063328294704243 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.004003858296411293
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962935665
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308460727956
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102270760395
# Coulomb Energy                  3040.4520260086529
# Exchange-Correlation Energy     -184.4314494453869
# --------------------------------------------------
# Total Energy                   -1525.7903986028277
# --------------------------------------------------
#
#
#
# Energy difference :  4.219084530632244e-06
#
#
# HOMO-LUMO gap: 0.050659206547798166 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.000981447287672453
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.000039623176
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462805607458
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170924567036
# Coulomb Energy                  3040.4616009178094
# Exchange-Correlation Energy     -184.4324555611790
# --------------------------------------------------
# Total Energy                   -1525.7903989167503
# --------------------------------------------------
#
#
#
# Energy difference :  3.1392255550599657e-07
#
#
# HOMO-LUMO gap: 0.05067942658643647 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.0002461756979411162
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332744
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503257738492
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622307788
# Coulomb Energy                  3040.4641306021940
# Exchange-Correlation Energy     -184.4327098274823
# --------------------------------------------------
# Total Energy                   -1525.7903989376964
# --------------------------------------------------
#
#
#
# Energy difference :  2.0946117729181424e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989376964
# -------------------------------------
#
#
#
# Time taken : 56.15 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           8.37
# Density Fitting                         1.49
#     DF (gamma)                          0.32
#     DF (coeff)                          0.11
#     DF (Jtri)                           0.93
# DIIS                                    0.71
# KS matrix diagonalization               1.23
# One electron Integrals (S, T, Vnuc)     0.09
# Coulomb Integrals (2c2e + 3c2e)         11.49
# Grids construction                      5.14
# Exchange-Correlation Term               24.8
# Misc.                                   2.81
# Complete SCF                            56.15

# %% [markdown]
# ### Benchmark #7 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.15 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.51 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.1
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.02015622300018549
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.69
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.33 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 18.09 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 23.45 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.26 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004570
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456316
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456316
#
#
# HOMO-LUMO gap: 1.3453310369351428 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.38 seconds
#
#
#
# Density matrix difference norm:  144.01367462687838
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771653634234
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873960287956
# Coulomb Energy                  7102.3908476757133
# Exchange-Correlation Energy     -401.0388488769531
# --------------------------------------------------
# Total Energy                   -2175.7976493752521
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159317296206
#
#
# HOMO-LUMO gap: 0.003632393682728219 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.39 seconds
#
#
#
# Density matrix difference norm:  71.99222142056533
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0024
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8537956299333
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349342492796
# Coulomb Energy                  5771.7158140794672
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171589286583
# --------------------------------------------------
#
#
#
# Energy difference :  98.71950955340617
#
#
# HOMO-LUMO gap: 0.004971605358965819 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  58.10278545163036
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372313012795
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733518968184
# Coulomb Energy                  6321.7308991299724
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4680727369214
# --------------------------------------------------
#
#
#
# Energy difference :  116.04908619173693
#
#
# HOMO-LUMO gap: 0.014406138520729167 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  53.36866412144723
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688656337079
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515407629016
# Coulomb Energy                  6361.2922211438263
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5267245097248
# --------------------------------------------------
#
#
#
# Energy difference :  24.058651772803387
#
#
# HOMO-LUMO gap: 0.008931031032852504 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 1.47 seconds
#
#
#
# Density matrix difference norm:  42.83084116249755
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057600111242
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112454484738
# Coulomb Energy                  6294.4824443028356
# Exchange-Correlation Energy     -283.9661865234375
# --------------------------------------------------
# Total Energy                   -2345.8381356226382
# --------------------------------------------------
#
#
#
# Energy difference :  163.31141111291345
#
#
# HOMO-LUMO gap: 0.006907358607230463 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  32.16624467917451
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2173792892208
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029696218124
# Coulomb Energy                  6214.1441884064552
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5589147976043
# --------------------------------------------------
#
#
#
# Energy difference :  2.279220825033917
#
#
# HOMO-LUMO gap: 0.002470704918998118 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  33.320213963302514
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00085
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828292468119
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271133383594
# Coulomb Energy                  6284.7511394835819
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5702719146466
# --------------------------------------------------
#
#
#
# Energy difference :  9.01135711704228
#
#
# HOMO-LUMO gap: 0.006022972203512111 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  26.09922325536457
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2099395898495
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3779258329928
# Coulomb Energy                  6418.6993033165018
# Exchange-Correlation Energy     -305.3439331054688
# --------------------------------------------------
# Total Energy                   -2411.0365223852077
# --------------------------------------------------
#
#
#
# Energy difference :  58.466250470561135
#
#
# HOMO-LUMO gap: 0.005612014147952413 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  17.530055553611245
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3145332693657
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3755010159721
# Coulomb Energy                  6329.8759334177439
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3362039933954
# --------------------------------------------------
#
#
#
# Energy difference :  37.70031839181229
#
#
# HOMO-LUMO gap: 0.017129017768363286 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  16.3980274742122
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4113494919093
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3502340305254
# Coulomb Energy                  6323.6507528334869
# Exchange-Correlation Energy     -296.5716552734375
# --------------------------------------------------
# Total Energy                   -2423.5418967407195
# --------------------------------------------------
#
#
#
# Energy difference :  50.205692747324065
#
#
# HOMO-LUMO gap: 0.006507618752902455 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  17.896861669427746
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006058417090
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1970977071815
# Coulomb Energy                  6269.6529407283433
# Exchange-Correlation Energy     -292.3520507812500
# --------------------------------------------------
# Total Energy                   -2388.4624970268196
# --------------------------------------------------
#
#
#
# Energy difference :  35.079399713899875
#
#
# HOMO-LUMO gap: 0.01136337531939434 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  18.875115333109246
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4052591973414
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783316808672
# Coulomb Energy                  6305.1510495834109
# Exchange-Correlation Energy     -292.6977233886719
# --------------------------------------------------
# Total Energy                   -2419.6334801611201
# --------------------------------------------------
#
#
#
# Energy difference :  31.170983134300513
#
#
# HOMO-LUMO gap: 0.001930917247056213 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  14.237405470497906
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7557357870373
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6446822146440
# Coulomb Energy                  6277.9143676112508
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7447850153712
# --------------------------------------------------
#
#
#
# Energy difference :  0.11130485425110237
#
#
# HOMO-LUMO gap: 0.008268387437650973 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  12.511464784741658
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00024
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8343545984262
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119824848693
# Coulomb Energy                  6304.6092770965297
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9790895790684
# --------------------------------------------------
#
#
#
# Energy difference :  11.234304563697151
#
#
# HOMO-LUMO gap: 0.017658809225393382 au
# HOMO-LUMO gap: 0.481 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  10.321248238449078
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0478811404864
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2890606680958
# Coulomb Energy                  6320.8556221775107
# Exchange-Correlation Energy     -297.0248107910156
# --------------------------------------------------
# Total Energy                   -2429.4878879252810
# --------------------------------------------------
#
#
#
# Energy difference :  1.491201653787357
#
#
# HOMO-LUMO gap: 0.006404345267400663 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 1.55 seconds
#
#
#
# Density matrix difference norm:  8.082502759077913
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4239091242416
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0824944384531
# Coulomb Energy                  6316.7243827119964
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382938698182
# --------------------------------------------------
#
#
#
# Energy difference :  8.450405944537124
#
#
# HOMO-LUMO gap: 0.06628574623727049 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  4.088566640106076
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3818026354165
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5872180678080
# Coulomb Energy                  6313.2561866747274
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039774158595
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656835460413276
#
#
# HOMO-LUMO gap: 0.00250885698274321 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.3425499831480066
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2973639684933
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1398732632833
# Coulomb Energy                  6287.7369272589303
# Exchange-Correlation Energy     -293.7501525878906
# --------------------------------------------------
# Total Energy                   -2439.7305948735548
# --------------------------------------------------
#
#
#
# Energy difference :  1.2733825423047165
#
#
# HOMO-LUMO gap: 0.020604288812593054 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.259654987819647
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7062285662287
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.1986391045593
# Coulomb Energy                  6303.8933580575249
# Exchange-Correlation Energy     -294.9478454589844
# --------------------------------------------------
# Total Energy                   -2441.1219557025142
# --------------------------------------------------
#
#
#
# Energy difference :  1.3913608289594777
#
#
# HOMO-LUMO gap: 0.12298478203552449 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  0.7427948915212437
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0197507955054
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5243400426316
# Coulomb Energy                  6307.0122171531402
# Exchange-Correlation Energy     -295.2850036621094
# --------------------------------------------------
# Total Energy                   -2441.3280761012284
# --------------------------------------------------
#
#
#
# Energy difference :  0.2061203987141198
#
#
# HOMO-LUMO gap: 0.08867284226105401 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  0.4773185921632652
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4110392989514
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7989073703893
# Coulomb Energy                  6304.8709468540137
# Exchange-Correlation Energy     -295.0262451171875
# --------------------------------------------------
# Total Energy                   -2441.3273090311222
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007670701061215368
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639434727415127 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 1.55 seconds
#
#
#
# Density matrix difference norm:  0.2704214838765764
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001152742426
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5565229956137
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4793719923919
# Coulomb Energy                  6304.2831442250372
# Exchange-Correlation Energy     -294.9926877597849
# --------------------------------------------------
# Total Energy                   -2441.3465733773555
# --------------------------------------------------
#
#
#
# Energy difference :  0.019264346233285323
#
#
# HOMO-LUMO gap: 0.10571269630267782 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 5.87 seconds
#
#
#
# Density matrix difference norm:  0.11903357533964487
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001155254571
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9902960723721
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6069425176788
# Coulomb Energy                  6305.7413585290751
# Exchange-Correlation Energy     -295.1471014285677
# --------------------------------------------------
# Total Energy                   -2441.3489752935702
# --------------------------------------------------
#
#
#
# Energy difference :  0.002401916214694211
#
#
# HOMO-LUMO gap: 0.10232786924680304 au
# HOMO-LUMO gap: 2.784 eV
#
#
# Time taken for the previous iteration: 5.91 seconds
#
#
#
# Density matrix difference norm:  0.05772694463586193
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011616390896
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1764317074376
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2270846838646
# Coulomb Energy                  6305.2551394782049
# Exchange-Correlation Energy     -295.0957760918335
# --------------------------------------------------
# Total Energy                   -2441.3498624765880
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008871830177668016
#
#
# HOMO-LUMO gap: 0.08313012301312889 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 5.87 seconds
#
#
#
# Density matrix difference norm:  0.06366280573816112
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001177587667
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6239463696311
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9398040402875
# Coulomb Energy                  6304.9502869475136
# Exchange-Correlation Energy     -295.0562558285959
# --------------------------------------------------
# Total Energy                   -2441.3499900498127
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012757322474499233
#
#
# HOMO-LUMO gap: 0.085439776803418 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 5.83 seconds
#
#
#
# Density matrix difference norm:  0.0331266675834886
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171909202
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1937908003456
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2381654179167
# Coulomb Energy                  6305.2622658529244
# Exchange-Correlation Energy     -295.0969075889894
# --------------------------------------------------
# Total Energy                   -2441.3501459578792
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001559080665174406
#
#
# HOMO-LUMO gap: 0.08549320070862325 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  0.01644300553320447
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174372735
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9924292343330
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1355451149338
# Coulomb Energy                  6305.1489917531726
# Exchange-Correlation Energy     -295.0824366840405
# --------------------------------------------------
# Total Energy                   -2441.3502078896527
# --------------------------------------------------
#
#
#
# Energy difference :  6.193177341629053e-05
#
#
# HOMO-LUMO gap: 0.08609953604639503 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.007353568957077618
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011734393286
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0612558634712
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745109913604
# Coulomb Energy                  6305.1841821321486
# Exchange-Correlation Energy     -295.0877764512584
# --------------------------------------------------
# Total Energy                   -2441.3502180306059
# --------------------------------------------------
#
#
#
# Energy difference :  1.014095323625952e-05
#
#
# HOMO-LUMO gap: 0.08618091780565426 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.0029219945956874454
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203545
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0438993161861
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630540362294
# Coulomb Energy                  6305.1767180935394
# Exchange-Correlation Energy     -295.0862144663066
# --------------------------------------------------
# Total Energy                   -2441.3502204921087
# --------------------------------------------------
#
#
#
# Energy difference :  2.4615028451080434e-06
#
#
# HOMO-LUMO gap: 0.0862699374875344 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0007991933954903243
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730882505
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357869286563
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591885810481
# Coulomb Energy                  6305.1719581734824
# Exchange-Correlation Energy     -295.0857015819743
# --------------------------------------------------
# Total Energy                   -2441.3502205954856
# --------------------------------------------------
#
#
#
# Energy difference :  1.0337680578231812e-07
#
#
# HOMO-LUMO gap: 0.08626927815303398 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  0.0004708901780771448
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173170851
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0330010725011
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576326613958
# Coulomb Energy                  6305.1705222031487
# Exchange-Correlation Energy     -295.0854955581445
# --------------------------------------------------
# Total Energy                   -2441.3502206054873
# --------------------------------------------------
#
#
#
# Energy difference :  1.0001713235396892e-08
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206054873
# -------------------------------------
#
#
#
# Time taken : 166.41 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           23.71
# Density Fitting                         5.43
#     DF (gamma)                          1.0
#     DF (coeff)                          0.2
#     DF (Jtri)                           3.82
# DIIS                                    3.58
# KS matrix diagonalization               3.63
# One electron Integrals (S, T, Vnuc)     0.15
# Coulomb Integrals (2c2e + 3c2e)         29.33
# Grids construction                      18.09
# Exchange-Correlation Term               77.82
# Misc.                                   4.68
# Complete SCF                            166.41

# %% [markdown]
# ### Benchmark #8 Water_47 (H2O_47)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_47.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  141
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  1175
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  3995
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.022
# done!
# Time taken 0.23 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.92 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.17
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.04458351900007074
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.016581608
# No. of elements in the standard three-centered two electron ERI tensor:  5515596875
# No. of elements in the triangular three-centered two electron ERI tensor:  2760145500
# No. of significant triplets based on Schwarz inequality and triangularity: 443113415 or 8.0% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.22 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  1.47
# Two Center Two electron ERI size in GB  0.1276802
# Three Center Two electron ERI size in GB  3.54490732
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  66.69 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 56.14 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 61.58 seconds.
#
#
# Deleted 296619 grid points.
#
# No. of supplied/generated grid points (after pruning):  1287189
# Size (in GB) for storing the coordinates of grid:       0.031
# Size (in GB) for storing the weights of grid:           0.01
# Size (in GB) for storing the density at gridpoints:     0.01
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  63
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.4 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    754
# Average no. of basis functions contributing to a batch of grid points:    600
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0009
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -20596.2109945087286
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                   252.2442213177687
# Coulomb Energy                  9850.3313311182374
# Exchange-Correlation Energy     -158.3137817382812
# --------------------------------------------------
# Total Energy                    -881.4919713840827
# --------------------------------------------------
#
#
#
# Energy difference :  881.4919713840827
#
#
# HOMO-LUMO gap: 0.6897605128394444 au
# HOMO-LUMO gap: 18.769 eV
#
#
# Time taken for the previous iteration: 2.93 seconds
#
#
#
# Density matrix difference norm:  177.4113565236402
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -30111.3344603665100
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  5026.5272337038132
# Coulomb Energy                 12707.6510698511483
# Exchange-Correlation Energy     -589.0113525390625
# --------------------------------------------------
# Total Energy                   -3195.7102569236904
# --------------------------------------------------
#
#
#
# Energy difference :  2314.2182855396077
#
#
# HOMO-LUMO gap: 0.002627327045134964 au
# HOMO-LUMO gap: 0.071 eV
#
#
# Time taken for the previous iteration: 2.99 seconds
#
#
#
# Density matrix difference norm:  86.09643255340825
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00058
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -26617.1087798581830
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  2982.9652414755019
# Coulomb Energy                 10864.6200183272958
# Exchange-Correlation Energy     -358.7289123535156
# --------------------------------------------------
# Total Energy                   -3357.7951799819803
# --------------------------------------------------
#
#
#
# Energy difference :  162.08492305828986
#
#
# HOMO-LUMO gap: 0.002510853040005888 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 3.05 seconds
#
#
#
# Density matrix difference norm:  65.1314623966756
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00012
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27208.9479187299148
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3346.4635717125989
# Coulomb Energy                 11125.2510310668804
# Exchange-Correlation Energy     -407.6779174804688
# --------------------------------------------------
# Total Energy                   -3374.4539810039805
# --------------------------------------------------
#
#
#
# Energy difference :  16.65880102200026
#
#
# HOMO-LUMO gap: 0.004421865588147805 au
# HOMO-LUMO gap: 0.120 eV
#
#
# Time taken for the previous iteration: 3.11 seconds
#
#
#
# Density matrix difference norm:  63.85792416210479
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9995
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27877.3725384330792
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3401.9140560550040
# Coulomb Energy                 12063.8293607518463
# Exchange-Correlation Energy     -415.0684814453125
# --------------------------------------------------
# Total Energy                   -3056.2403506446190
# --------------------------------------------------
#
#
#
# Energy difference :  318.21363035936156
#
#
# HOMO-LUMO gap: 0.007368546645470986 au
# HOMO-LUMO gap: 0.201 eV
#
#
# Time taken for the previous iteration: 3.21 seconds
#
#
#
# Density matrix difference norm:  54.581843513451595
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27817.6403122459451
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3415.4169002332119
# Coulomb Energy                 11513.0420680346178
# Exchange-Correlation Energy     -417.4490356445312
# --------------------------------------------------
# Total Energy                   -3536.1731271957233
# --------------------------------------------------
#
#
#
# Energy difference :  479.9327765511043
#
#
# HOMO-LUMO gap: 0.0017456459933724803 au
# HOMO-LUMO gap: 0.048 eV
#
#
# Time taken for the previous iteration: 3.33 seconds
#
#
#
# Density matrix difference norm:  51.20556536975194
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99966
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27449.0683778597850
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3456.9093101814947
# Coulomb Energy                 11567.9598146777098
# Exchange-Correlation Energy     -419.4386291503906
# --------------------------------------------------
# Total Energy                   -3073.1806297240491
# --------------------------------------------------
#
#
#
# Energy difference :  462.99249747167414
#
#
# HOMO-LUMO gap: 0.007101063737707941 au
# HOMO-LUMO gap: 0.193 eV
#
#
# Time taken for the previous iteration: 3.32 seconds
#
#
#
# Density matrix difference norm:  44.85233864563323
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9996
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27847.9588211974224
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3472.6778967520804
# Coulomb Energy                 11495.7953381126608
# Exchange-Correlation Energy     -423.7618408203125
# --------------------------------------------------
# Total Energy                   -3532.7901747260712
# --------------------------------------------------
#
#
#
# Energy difference :  459.60954500202206
#
#
# HOMO-LUMO gap: 0.0009143200106397631 au
# HOMO-LUMO gap: 0.025 eV
#
#
# Time taken for the previous iteration: 3.34 seconds
#
#
#
# Density matrix difference norm:  20.646603767539094
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.9999
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28047.8310180149274
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3601.3211873227478
# Coulomb Energy                 11578.8343483493009
# Exchange-Correlation Energy     -439.3337402343750
# --------------------------------------------------
# Total Energy                   -3536.5519701503308
# --------------------------------------------------
#
#
#
# Energy difference :  3.761795424259617
#
#
# HOMO-LUMO gap: 0.003600027552215973 au
# HOMO-LUMO gap: 0.098 eV
#
#
# Time taken for the previous iteration: 3.38 seconds
#
#
#
# Density matrix difference norm:  20.828980114200746
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00055
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28136.7521289268952
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3618.5806125418831
# Coulomb Energy                 11689.0100066573941
# Exchange-Correlation Energy     -441.3327636718750
# --------------------------------------------------
# Total Energy                   -3500.0370209725716
# --------------------------------------------------
#
#
#
# Energy difference :  36.51494917775926
#
#
# HOMO-LUMO gap: 0.010634350076619933 au
# HOMO-LUMO gap: 0.289 eV
#
#
# Time taken for the previous iteration: 3.36 seconds
#
#
#
# Density matrix difference norm:  22.197588047033314
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00018
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27870.4576905582580
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3570.0606339683118
# Coulomb Energy                 11460.1491117163350
# Exchange-Correlation Energy     -435.4829101562500
# --------------------------------------------------
# Total Energy                   -3505.2736026029397
# --------------------------------------------------
#
#
#
# Energy difference :  5.236581630368164
#
#
# HOMO-LUMO gap: 0.010854268016874863 au
# HOMO-LUMO gap: 0.295 eV
#
#
# Time taken for the previous iteration: 3.41 seconds
#
#
#
# Density matrix difference norm:  15.727062431458927
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0003
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28102.6514040063303
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3578.5252588302237
# Coulomb Energy                 11610.6784218843313
# Exchange-Correlation Energy     -438.4913635253906
# --------------------------------------------------
# Total Energy                   -3581.4818343902425
# --------------------------------------------------
#
#
#
# Energy difference :  76.2082317873028
#
#
# HOMO-LUMO gap: 0.00015980618047960887 au
# HOMO-LUMO gap: 0.004 eV
#
#
# Time taken for the previous iteration: 3.4 seconds
#
#
#
# Density matrix difference norm:  13.370411508803732
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27854.5584619511246
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3502.8839695855327
# Coulomb Energy                 11467.2383202441379
# Exchange-Correlation Energy     -426.1158447265625
# --------------------------------------------------
# Total Energy                   -3540.0947644210955
# --------------------------------------------------
#
#
#
# Energy difference :  41.38706996914698
#
#
# HOMO-LUMO gap: 0.05311290827904247 au
# HOMO-LUMO gap: 1.445 eV
#
#
# Time taken for the previous iteration: 3.4 seconds
#
#
#
# Density matrix difference norm:  12.794224018042064
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27990.3081483087662
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3532.9198679114547
# Coulomb Energy                 11534.4731795739335
# Exchange-Correlation Energy     -432.5695190429688
# --------------------------------------------------
# Total Energy                   -3585.0273674394230
# --------------------------------------------------
#
#
#
# Energy difference :  44.93260301832743
#
#
# HOMO-LUMO gap: 0.004217985346016168 au
# HOMO-LUMO gap: 0.115 eV
#
#
# Time taken for the previous iteration: 3.4 seconds
#
#
#
# Density matrix difference norm:  4.412210584129885
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00018
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27977.3922392278109
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3527.9678826602467
# Coulomb Energy                 11526.5925625984200
# Exchange-Correlation Energy     -431.3869018554688
# --------------------------------------------------
# Total Energy                   -3583.7614433976905
# --------------------------------------------------
#
#
#
# Energy difference :  1.2659240417324327
#
#
# HOMO-LUMO gap: 0.05835741029846597 au
# HOMO-LUMO gap: 1.588 eV
#
#
# Time taken for the previous iteration: 3.39 seconds
#
#
#
# Density matrix difference norm:  4.109718568552619
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -27998.0921124816668
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3538.5441326098658
# Coulomb Energy                 11536.7465947336677
# Exchange-Correlation Energy     -433.2103881835938
# --------------------------------------------------
# Total Energy                   -3585.5545208948042
# --------------------------------------------------
#
#
#
# Energy difference :  1.7930774971136998
#
#
# HOMO-LUMO gap: 0.08676275679371123 au
# HOMO-LUMO gap: 2.361 eV
#
#
# Time taken for the previous iteration: 3.38 seconds
#
#
#
# Density matrix difference norm:  0.7326562621335881
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.8611589975990
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.7696526527629
# Coulomb Energy                 11540.4386496381885
# Exchange-Correlation Energy     -433.5176696777344
# --------------------------------------------------
# Total Energy                   -3585.7132739574608
# --------------------------------------------------
#
#
#
# Energy difference :  0.15875306265661493
#
#
# HOMO-LUMO gap: 0.09405075334205787 au
# HOMO-LUMO gap: 2.559 eV
#
#
# Time taken for the previous iteration: 3.36 seconds
#
#
#
# Density matrix difference norm:  0.2816795601885695
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28003.1462697449388
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3540.5330131611736
# Coulomb Energy                 11539.8988526372996
# Exchange-Correlation Energy     -433.4659729003906
# --------------------------------------------------
# Total Energy                   -3585.7231244199338
# --------------------------------------------------
#
#
#
# Energy difference :  0.009850462472968502
#
#
# HOMO-LUMO gap: 0.09971627797602838 au
# HOMO-LUMO gap: 2.713 eV
#
#
# Time taken for the previous iteration: 3.37 seconds
#
#
#
# Density matrix difference norm:  0.16836513904388087
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.6092888152780
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.5709765589054
# Coulomb Energy                 11539.1833655135379
# Exchange-Correlation Energy     -433.3303527832031
# --------------------------------------------------
# Total Energy                   -3585.7280470991154
# --------------------------------------------------
#
#
#
# Energy difference :  0.00492267918161815
#
#
# HOMO-LUMO gap: 0.10344492384624529 au
# HOMO-LUMO gap: 2.815 eV
#
#
# Time taken for the previous iteration: 3.33 seconds
#
#
#
# Density matrix difference norm:  0.08026777441722732
#
#
#
#
#
# XC algo 3
# Number of electrons:  469.99997
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.7157203939314
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7577263071739
# Coulomb Energy                 11539.1256547389112
# Exchange-Correlation Energy     -433.3546752929688
# --------------------------------------------------
# Total Energy                   -3585.7297622138940
# --------------------------------------------------
#
#
#
# Energy difference :  0.0017151147785625653
#
# Switching to double precision for XC evaluation after 20 iterations!
#
#
# HOMO-LUMO gap: 0.10344055718905035 au
# HOMO-LUMO gap: 2.815 eV
#
#
# Time taken for the previous iteration: 3.31 seconds
#
#
#
# Density matrix difference norm:  0.042308032887201565
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000160988735
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0596253749536
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8997883087468
# Coulomb Energy                 11539.3455495038615
# Exchange-Correlation Energy     -433.3794840068025
# --------------------------------------------------
# Total Energy                   -3585.7365191422268
# --------------------------------------------------
#
#
#
# Energy difference :  0.0067569283328339225
#
#
# HOMO-LUMO gap: 0.10318014262102382 au
# HOMO-LUMO gap: 2.808 eV
#
#
# Time taken for the previous iteration: 14.06 seconds
#
#
#
# Density matrix difference norm:  0.015972566672441974
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001624412624
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9454528813330
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8151124211176
# Coulomb Energy                 11539.3069980051041
# Exchange-Correlation Energy     -433.3704954685909
# --------------------------------------------------
# Total Energy                   -3585.7365854967811
# --------------------------------------------------
#
#
#
# Energy difference :  6.63545542920474e-05
#
#
# HOMO-LUMO gap: 0.10328449197426534 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 14.03 seconds
#
#
#
# Density matrix difference norm:  0.009044726558303892
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001611167716
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9177061289884
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.7988395091479
# Coulomb Energy                 11539.2953828626705
# Exchange-Correlation Energy     -433.3703595599498
# --------------------------------------------------
# Total Energy                   -3585.7365908901975
# --------------------------------------------------
#
#
#
# Energy difference :  5.393416358856484e-06
#
#
# HOMO-LUMO gap: 0.1032876097718361 au
# HOMO-LUMO gap: 2.811 eV
#
#
# Time taken for the previous iteration: 14.06 seconds
#
#
#
# Density matrix difference norm:  0.005499760536625951
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000163556829
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28002.0274086950594
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8530318869912
# Coulomb Energy                 11539.3582094719168
# Exchange-Correlation Energy     -433.3776796128265
# --------------------------------------------------
# Total Energy                   -3585.7365945220536
# --------------------------------------------------
#
#
#
# Energy difference :  3.6318560887593776e-06
#
#
# HOMO-LUMO gap: 0.10325319343073608 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.08 seconds
#
#
#
# Density matrix difference norm:  0.0030769231942412052
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162683564
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9469143892711
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8127598912001
# Coulomb Energy                 11539.3125059417434
# Exchange-Correlation Energy     -433.3722001355819
# --------------------------------------------------
# Total Energy                   -3585.7365962649874
# --------------------------------------------------
#
#
#
# Energy difference :  1.7429338186047971e-06
#
#
# HOMO-LUMO gap: 0.10322401612445306 au
# HOMO-LUMO gap: 2.809 eV
#
#
# Time taken for the previous iteration: 14.13 seconds
#
#
#
# Density matrix difference norm:  0.0012954960902040627
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.00001625896857
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9431174469282
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8096040837190
# Coulomb Energy                 11539.3114791718399
# Exchange-Correlation Energy     -433.3718148703013
# --------------------------------------------------
# Total Energy                   -3585.7365966347479
# --------------------------------------------------
#
#
#
# Energy difference :  3.697605279739946e-07
#
#
# HOMO-LUMO gap: 0.10325134318284117 au
# HOMO-LUMO gap: 2.810 eV
#
#
# Time taken for the previous iteration: 14.09 seconds
#
#
#
# Density matrix difference norm:  0.0005982209399304362
#
#
#
#
#
# XC algo 3
# Number of electrons:  470.0000162813799
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -28001.9506184279307
# Nuclear repulsion Energy        9770.4572524269224
# Kinetic Energy                  3539.8140487078763
# Coulomb Energy                 11539.3151858402671
# Exchange-Correlation Energy     -433.3724652408097
# --------------------------------------------------
# Total Energy                   -3585.7365966936759
# --------------------------------------------------
#
#
#
# Energy difference :  5.8927980717271566e-08
#
# SCF Converged after 27 iterations!
#
# -------------------------------------
# Total Energy =  -3585.736596693676
# -------------------------------------
#
#
#
# Time taken : 354.51 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           61.98
# Density Fitting                         11.84
#     DF (gamma)                          2.48
#     DF (coeff)                          0.16
#     DF (Jtri)                           8.44
# DIIS                                    8.36
# KS matrix diagonalization               6.82
# One electron Integrals (S, T, Vnuc)     0.23
# Coulomb Integrals (2c2e + 3c2e)         66.69
# Grids construction                      56.14
# Exchange-Correlation Term               136.35
# Misc.                                   6.09
# Complete SCF                            354.51
