# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6728, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 6728 (delta 144), reused 210 (delta 109), pack-reused 6454 (from 3)
# Receiving objects: 100% (6728/6728), 372.53 MiB | 27.09 MiB/s, done.
# Resolving deltas: 100% (4003/4003), done.
# Updating files: 100% (3645/3645), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install ase
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting ase
#   Downloading ase-3.29.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from ase) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from ase) (1.16.3)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.12/dist-packages (from ase) (3.10.0)
# Requirement already satisfied: typing_extensions>=4.13.1 in /usr/local/lib/python3.12/dist-packages (from ase) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->ase) (1.17.0)
# Downloading ase-3.29.0-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: ase
# Successfully installed ase-3.29.0
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 30.1 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20369131 sha256=ded5c65ef6d0d6c6ce80fed50d7775c77f9097f4aeebf401b4a217a7fcf6abdc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yfzuy0w2/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 15.82 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.77 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  5.81
# Time taken to evaluate the square roots needed:  0.11
# Time for significant indices evaluation:  2.009152825000001
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 7.93 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  7.01
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  39.07 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.79 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.5 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.5 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709562
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632572
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325716
#
#
# HOMO-LUMO gap: 2.64310792816703 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.33 seconds
#
#
#
# Density matrix difference norm:  43.34767137041613
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  49.99999474389982
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709458
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316081
# Coulomb Energy                   501.1198589452484
# Exchange-Correlation Energy      -62.5998011282694
# --------------------------------------------------
# Total Energy                    -340.0652765782351
# --------------------------------------------------
#
#
#
# Energy difference :  246.90846851497795
#
#
# HOMO-LUMO gap: 0.004902711060902398 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.28 seconds
#
#
#
# Density matrix difference norm:  28.612471718853406
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000984028651
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456444
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785852
# Coulomb Energy                   293.3088657954106
# Exchange-Correlation Energy      -37.4191110537720
# --------------------------------------------------
# Total Energy                    -355.5094553812971
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803062016
#
#
# HOMO-LUMO gap: 0.04036147698761805 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  21.394016787375147
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445384
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275489
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458430
# Coulomb Energy                   367.2127830476554
# Exchange-Correlation Energy      -44.5841010136103
# --------------------------------------------------
# Total Energy                    -380.5867878035372
# --------------------------------------------------
#
#
#
# Energy difference :  25.07733242224009
#
#
# HOMO-LUMO gap: 0.018048571143150706 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  5.1974809336901275
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000687474083
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703905
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754554
# Coulomb Energy                   364.3533796551132
# Exchange-Correlation Energy      -44.5594485029992
# --------------------------------------------------
# Total Energy                    -378.6274635986976
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048396178
#
#
# HOMO-LUMO gap: 0.08493582284759588 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  4.779285269952895
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001287711405
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186628
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180478
# Coulomb Energy                   368.1554971681664
# Exchange-Correlation Energy      -45.0868782881908
# --------------------------------------------------
# Total Energy                    -381.1270633765159
# --------------------------------------------------
#
#
#
# Energy difference :  2.4995997778182755
#
#
# HOMO-LUMO gap: 0.14183855738599205 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5205766173115731
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000012120894674
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233398
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990190
# Coulomb Energy                   369.0647619107290
# Exchange-Correlation Energy      -45.1368862216109
# --------------------------------------------------
# Total Energy                    -381.2275584910792
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456332993
#
#
# HOMO-LUMO gap: 0.1351472390945272 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.3315886778249215
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597149
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176967
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774603
# Coulomb Energy                   369.6340156607571
# Exchange-Correlation Energy      -45.2090855965868
# --------------------------------------------------
# Total Energy                    -381.2508898319426
# --------------------------------------------------
#
#
#
# Energy difference :  0.0233313408634217
#
#
# HOMO-LUMO gap: 0.01973205738300652 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.5818251308650467
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008617005534
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110896
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893548
# Coulomb Energy                   374.0898923937948
# Exchange-Correlation Energy      -45.7569321945901
# --------------------------------------------------
# Total Energy                    -381.3827647784065
# --------------------------------------------------
#
#
#
# Energy difference :  0.13187494646382447
#
#
# HOMO-LUMO gap: 0.12604481221480912 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.4584549614594719
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767309
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524583
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358362
# Coulomb Energy                   377.3880704578816
# Exchange-Correlation Energy      -46.1034837100255
# --------------------------------------------------
# Total Energy                    -381.4206849246426
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623616069
#
#
# HOMO-LUMO gap: 0.16627348986176382 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.145068865168436
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000757902086
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358347
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690164
# Coulomb Energy                   377.1736811284837
# Exchange-Correlation Energy      -46.0748895148562
# --------------------------------------------------
# Total Energy                    -381.4268823090671
# --------------------------------------------------
#
#
#
# Energy difference :  0.0061973844244676
#
#
# HOMO-LUMO gap: 0.1812607411262963 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.05574884998964566
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074251987
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179399
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114303
# Coulomb Energy                   377.1977734128245
# Exchange-Correlation Energy      -46.0810670348479
# --------------------------------------------------
# Total Energy                    -381.4272916844093
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753422012014
#
#
# HOMO-LUMO gap: 0.18111025828110827 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.02562530605169698
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503725406
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006523
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114214
# Coulomb Energy                   377.1502888734898
# Exchange-Correlation Energy      -46.0776486461291
# --------------------------------------------------
# Total Energy                    -381.4274184177467
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001267333373675683
#
#
# HOMO-LUMO gap: 0.1806839556568764 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.008432526434276185
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750035487
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167661
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298639
# Coulomb Energy                   377.1545462611571
# Exchange-Correlation Energy      -46.0767747067600
# --------------------------------------------------
# Total Energy                    -381.4274393883816
# --------------------------------------------------
#
#
#
# Energy difference :  2.0970634921013698e-05
#
#
# HOMO-LUMO gap: 0.18067053575036496 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018444600029144831
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007500250724
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068213
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736977
# Coulomb Energy                   377.1524231958048
# Exchange-Correlation Energy      -46.0765296383168
# --------------------------------------------------
# Total Energy                    -381.4274391315120
# --------------------------------------------------
#
#
#
# Energy difference :  2.568696118032676e-07
#
#
# HOMO-LUMO gap: 0.18064597252299372 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0011511413608289566
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749894919
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206461
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789368
# Coulomb Energy                   377.1549870542079
# Exchange-Correlation Energy      -46.0768423766159
# --------------------------------------------------
# Total Energy                    -381.4274396199939
# --------------------------------------------------
#
#
#
# Energy difference :  4.884819304606935e-07
#
#
# HOMO-LUMO gap: 0.18064256438838225 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.00010543279302703296
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749836627
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081818
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075854
# Coulomb Energy                   377.1556791349424
# Exchange-Correlation Energy      -46.0769272993466
# --------------------------------------------------
# Total Energy                    -381.4274396208770
# --------------------------------------------------
#
#
#
# Energy difference :  8.831193554215133e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.427439620877
# -------------------------------------
#
#
#
# Time taken : 70.96 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           3.0
# Density Fitting                         1.37
#     DF (gamma)                          0.36
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.62
# DIIS                                    0.73
# KS matrix diagonalization               0.81
# One electron Integrals (S, T, Vnuc)     15.82
# Coulomb Integrals (2c2e + 3c2e)         39.07
# Grids construction                      0.79
# Exchange-Correlation Term               5.39
# Misc.                                   3.99
# Complete SCF                            70.96

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.1 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0022919819999742685
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.46 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.03 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.96 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00135664103418
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371802
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645299993
# --------------------------------------------------
#
#
#
# Energy difference :  185.44746452999925
#
#
# HOMO-LUMO gap: 1.7654343749561927 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.64 seconds
#
#
#
# Density matrix difference norm:  66.8835876420547
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084647
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437994
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987506093
# Coulomb Energy                  1272.5954275689594
# Exchange-Correlation Energy     -125.2198694441771
# --------------------------------------------------
# Total Energy                    -680.0789187511757
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422117645
#
#
# HOMO-LUMO gap: 0.0004045605677370778 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  39.275229644349245
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0012017584456
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692493160
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666726738
# Coulomb Energy                   861.6558693045765
# Exchange-Correlation Energy      -75.4419310839532
# --------------------------------------------------
# Total Energy                    -709.3563182387868
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487611092
#
#
# HOMO-LUMO gap: 0.027815605001146146 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  28.147358564309734
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663975
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672038145
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170660426
# Coulomb Energy                  1000.6400676119843
# Exchange-Correlation Energy      -87.3507096616636
# --------------------------------------------------
# Total Energy                    -733.7433460702196
# --------------------------------------------------
#
#
#
# Energy difference :  24.38702783143276
#
#
# HOMO-LUMO gap: 0.007352227195061456 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  18.1030539830701
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00060553642281
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026565385
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102958626
# Coulomb Energy                  1039.7254935642479
# Exchange-Correlation Energy      -89.9717584581058
# --------------------------------------------------
# Total Energy                    -689.6320111373018
# --------------------------------------------------
#
#
#
# Energy difference :  44.11133493291777
#
#
# HOMO-LUMO gap: 0.010701793701477447 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  13.034260103680596
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576002
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022388331
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470598521
# Coulomb Energy                  1004.3417767420584
# Exchange-Correlation Energy      -89.2334391643006
# --------------------------------------------------
# Total Energy                    -749.6400714839914
# --------------------------------------------------
#
#
#
# Energy difference :  60.008060346689604
#
#
# HOMO-LUMO gap: 0.02577135128040875 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.653358064502381
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554301
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132845109
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410143
# Coulomb Energy                   997.3319760641348
# Exchange-Correlation Energy      -89.6717481072305
# --------------------------------------------------
# Total Energy                    -755.2352624693604
# --------------------------------------------------
#
#
#
# Energy difference :  5.5951909853689585
#
#
# HOMO-LUMO gap: 0.0035684795166347344 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.309738335136682
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567741
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204411988
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857160802
# Coulomb Energy                  1009.6464766735236
# Exchange-Correlation Energy      -89.9069114779158
# --------------------------------------------------
# Total Energy                    -755.2788234122789
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094291858881
#
#
# HOMO-LUMO gap: 0.009175061888765448 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  8.057132717318696
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00050300163969
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153728336
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119323795
# Coulomb Energy                  1035.0050622426190
# Exchange-Correlation Energy      -92.6658378595528
# --------------------------------------------------
# Total Energy                    -747.5712329401561
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472122888
#
#
# HOMO-LUMO gap: 0.1176623719354356 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  7.715013429019134
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.9999884330677
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903702898
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992834952
# Coulomb Energy                  1048.9988443902869
# Exchange-Correlation Energy      -94.9610811404867
# --------------------------------------------------
# Total Energy                    -761.7908817197624
# --------------------------------------------------
#
#
#
# Energy difference :  14.21964877960636
#
#
# HOMO-LUMO gap: 0.01092542663641638 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  6.790315749492145
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377908
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412174636
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466858621
# Coulomb Energy                  1013.7508689108399
# Exchange-Correlation Energy      -90.9428726052192
# --------------------------------------------------
# Total Energy                    -756.2816521087489
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229611013552
#
#
# HOMO-LUMO gap: 0.1492973269795217 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  6.534633252864861
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202663
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716112310
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461515227
# Coulomb Energy                  1025.7750806792360
# Exchange-Correlation Energy      -92.2703810888709
# --------------------------------------------------
# Total Energy                    -762.7969797521114
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327643362525
#
#
# HOMO-LUMO gap: 0.13352697864346613 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.5338338749134139
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332058
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534425
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792903046
# Coulomb Energy                  1024.7461321400322
# Exchange-Correlation Energy      -92.1885648748856
# --------------------------------------------------
# Total Energy                    -762.8402252807598
# --------------------------------------------------
#
#
#
# Energy difference :  0.0432455286484128
#
#
# HOMO-LUMO gap: 0.11056223798996144 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.36027133595096256
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000097791664
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590202622
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517292967
# Coulomb Energy                  1023.6379077073540
# Exchange-Correlation Energy      -92.0697499681793
# --------------------------------------------------
# Total Energy                    -762.8490034345585
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153798743915
#
#
# HOMO-LUMO gap: 0.08600353273299918 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.32529885672406134
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680042
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240861644
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261721328
# Coulomb Energy                  1024.4836887099557
# Exchange-Correlation Energy      -92.1371699397428
# --------------------------------------------------
# Total Energy                    -762.8531330265866
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592028107254
#
#
# HOMO-LUMO gap: 0.11636080747327204 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.15534224614066416
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503605
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117169287
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900056053
# Coulomb Energy                  1024.5663100626407
# Exchange-Correlation Energy      -92.1605267750491
# --------------------------------------------------
# Total Energy                    -762.8605923065002
# --------------------------------------------------
#
#
#
# Energy difference :  0.0074592799135189125
#
#
# HOMO-LUMO gap: 0.12269239243372677 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.04060711223051102
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000722186564
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080506
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362554
# Coulomb Energy                  1024.7015706722543
# Exchange-Correlation Energy      -92.1773633390779
# --------------------------------------------------
# Total Energy                    -762.8609189213869
# --------------------------------------------------
#
#
#
# Energy difference :  0.00032661488671692496
#
#
# HOMO-LUMO gap: 0.11742913476005667 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.019703163524974688
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000740471101
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348739783
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958570148
# Coulomb Energy                  1024.5590092024474
# Exchange-Correlation Energy      -92.1602830990776
# --------------------------------------------------
# Total Energy                    -762.8609667963617
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497482539038e-05
#
#
# HOMO-LUMO gap: 0.11815573488960998 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.008211499893293547
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743163933
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862528
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811822
# Coulomb Energy                  1024.5676148746829
# Exchange-Correlation Energy      -92.1612728329161
# --------------------------------------------------
# Total Energy                    -762.8609882460714
# --------------------------------------------------
#
#
#
# Energy difference :  2.144970972040028e-05
#
#
# HOMO-LUMO gap: 0.11842571032151963 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.0019148361607577498
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786604
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971673
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346196
# Coulomb Energy                  1024.5642249369580
# Exchange-Correlation Energy      -92.1610088236034
# --------------------------------------------------
# Total Energy                    -762.8609886319609
# --------------------------------------------------
#
#
#
# Energy difference :  3.858895070152357e-07
#
#
# HOMO-LUMO gap: 0.11835771606507384 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.001077639616908619
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000074181639
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020358
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743373
# Coulomb Energy                  1024.5683629999294
# Exchange-Correlation Energy      -92.1613819110202
# --------------------------------------------------
# Total Energy                    -762.8609888215574
# --------------------------------------------------
#
#
#
# Energy difference :  1.8959644876304083e-07
#
#
# HOMO-LUMO gap: 0.1183711833856343 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0005041312662150144
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785554
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158236
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323486
# Coulomb Energy                  1024.5701171428805
# Exchange-Correlation Energy      -92.1615907612841
# --------------------------------------------------
# Total Energy                    -762.8609888846468
# --------------------------------------------------
#
#
#
# Energy difference :  6.30893737252336e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846468
# -------------------------------------
#
#
#
# Time taken : 19.42 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.1
# Density Fitting                         0.47
#     DF (gamma)                          0.13
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.22
# DIIS                                    0.12
# KS matrix diagonalization               0.54
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.46
# Grids construction                      1.03
# Exchange-Correlation Term               11.2
# Misc.                                   1.45
# Complete SCF                            19.42

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.08 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.25 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007724250000023858
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.28
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.16 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.88 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 8.0 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.18 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355682
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973800
# --------------------------------------------------
#
#
#
# Energy difference :  374.93033389738
#
#
# HOMO-LUMO gap: 1.850286443540813 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 2.26 seconds
#
#
#
# Density matrix difference norm:  107.82844284433018
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99998558772944
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090067436
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391765974
# Coulomb Energy                  3537.3287033060546
# Exchange-Correlation Energy     -250.6110528162031
# --------------------------------------------------
# Total Energy                   -1359.8923755096316
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122516
#
#
# HOMO-LUMO gap: 0.0021139216439988173 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 2.23 seconds
#
#
#
# Density matrix difference norm:  57.36707021917927
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0009269151291
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256489488
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810812719
# Coulomb Energy                  2705.3966179572749
# Exchange-Correlation Energy     -151.8752804393536
# --------------------------------------------------
# Total Energy                   -1419.0480632190934
# --------------------------------------------------
#
#
#
# Energy difference :  59.155687709461745
#
#
# HOMO-LUMO gap: 0.01974072373891178 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 2.24 seconds
#
#
#
# Density matrix difference norm:  48.04719016381011
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001717849239
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823855388
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892854265
# Coulomb Energy                  3071.8764250120644
# Exchange-Correlation Energy     -174.7460035329392
# --------------------------------------------------
# Total Energy                   -1362.4047277903260
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542876739
#
#
# HOMO-LUMO gap: 0.014747714724665753 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  40.92570828260396
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158718
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198128328
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571583289
# Coulomb Energy                  3051.7165832283290
# Exchange-Correlation Energy     -176.2007428393799
# --------------------------------------------------
# Total Energy                   -1378.8564784348937
# --------------------------------------------------
#
#
#
# Energy difference :  16.45175064456771
#
#
# HOMO-LUMO gap: 0.012539973802118534 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  26.932582172228674
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863936
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022790960
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850557195
# Coulomb Energy                  3003.5375755727327
# Exchange-Correlation Energy     -179.3125720191724
# --------------------------------------------------
# Total Energy                   -1523.5033698391544
# --------------------------------------------------
#
#
#
# Energy difference :  144.6468914042607
#
#
# HOMO-LUMO gap: 0.0030874947615472607 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  13.423370100277957
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488933
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332572540
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671363101
# Coulomb Energy                  2977.4795296023926
# Exchange-Correlation Energy     -178.1026352540126
# --------------------------------------------------
# Total Energy                   -1499.0865279419017
# --------------------------------------------------
#
#
#
# Energy difference :  24.416841897252652
#
#
# HOMO-LUMO gap: 0.03181461272824397 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  12.444575042424017
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146524
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885446201
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462464226
# Coulomb Energy                  3000.9261851728756
# Exchange-Correlation Energy     -180.8962339958102
# --------------------------------------------------
# Total Energy                   -1522.7463472904706
# --------------------------------------------------
#
#
#
# Energy difference :  23.659819348568817
#
#
# HOMO-LUMO gap: 0.012952412900515735 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  6.016412544078944
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001219220139
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025156132
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516682032
# Coulomb Energy                  3041.7824359801039
# Exchange-Correlation Energy     -185.1339645332799
# --------------------------------------------------
# Total Energy                   -1523.4476355699239
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794533652
#
#
# HOMO-LUMO gap: 0.02147354981024789 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  6.22275170520168
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999594881057
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888914605
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569992244
# Coulomb Energy                  3063.1248487684074
# Exchange-Correlation Energy     -185.9132949764673
# --------------------------------------------------
# Total Energy                   -1521.9201342696347
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013002892592
#
#
# HOMO-LUMO gap: 0.07988335372925774 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 2.3 seconds
#
#
#
# Density matrix difference norm:  4.434848523613081
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003551846706
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733681243
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444890845
# Coulomb Energy                  3048.3985990983856
# Exchange-Correlation Energy     -185.3448733864899
# --------------------------------------------------
# Total Energy                   -1525.5849593364819
# --------------------------------------------------
#
#
#
# Energy difference :  3.664825066847243
#
#
# HOMO-LUMO gap: 0.11911980736822025 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 2.32 seconds
#
#
#
# Density matrix difference norm:  0.8335133099877633
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003812437734
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577371962
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713793996
# Coulomb Energy                  3044.2765927793262
# Exchange-Correlation Energy     -184.7849150214316
# --------------------------------------------------
# Total Energy                   -1525.7423647692412
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543275933305
#
#
# HOMO-LUMO gap: 0.10914385151716866 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.4378203336019344
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733318
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238684542
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349618
# Coulomb Energy                  3039.9455617679860
# Exchange-Correlation Energy     -184.3161788613722
# --------------------------------------------------
# Total Energy                   -1525.7678971962168
# --------------------------------------------------
#
#
#
# Energy difference :  0.02553242697558744
#
#
# HOMO-LUMO gap: 0.08055636124761666 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.27956022877628667
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976173
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116073
# Coulomb Energy                  3041.4914846757097
# Exchange-Correlation Energy     -184.5235703798666
# --------------------------------------------------
# Total Energy                   -1525.7860021524971
# --------------------------------------------------
#
#
#
# Energy difference :  0.018104956280240003
#
#
# HOMO-LUMO gap: 0.03553321190342107 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 2.33 seconds
#
#
#
# Density matrix difference norm:  0.20188173700913023
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004068429737
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555703322
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365257972
# Coulomb Energy                  3040.7248454919409
# Exchange-Correlation Energy     -184.4775892871866
# --------------------------------------------------
# Total Energy                   -1525.7891190091177
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031168566206360993
#
#
# HOMO-LUMO gap: 0.04487089486599795 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.07625293104627734
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396572362
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379111066
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103533
# Coulomb Energy                  3040.4560830346568
# Exchange-Correlation Energy     -184.4308753791053
# --------------------------------------------------
# Total Energy                   -1525.7902311145403
# --------------------------------------------------
#
#
#
# Energy difference :  0.001112105422635068
#
#
# HOMO-LUMO gap: 0.05285664136853209 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.028372083619469433
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000394713102
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669641234
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980474
# Coulomb Energy                  3040.4602645949708
# Exchange-Correlation Energy     -184.4309026475779
# --------------------------------------------------
# Total Energy                   -1525.7903707880214
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348104415578
#
#
# HOMO-LUMO gap: 0.04994812744074545 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 2.35 seconds
#
#
#
# Density matrix difference norm:  0.01278525124380149
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505598
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931223
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318243
# Coulomb Energy                  3040.4067159125807
# Exchange-Correlation Energy     -184.4260067735668
# --------------------------------------------------
# Total Energy                   -1525.7903870916216
# --------------------------------------------------
#
#
#
# Energy difference :  1.6303600204992108e-05
#
#
# HOMO-LUMO gap: 0.050833655730281854 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 2.36 seconds
#
#
#
# Density matrix difference norm:  0.006040021432040772
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112007
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954424
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920537
# Coulomb Energy                  3040.4581957845048
# Exchange-Correlation Energy     -184.4326037898896
# --------------------------------------------------
# Total Energy                   -1525.7903978781114
# --------------------------------------------------
#
#
#
# Energy difference :  1.07864898382104e-05
#
#
# HOMO-LUMO gap: 0.050686035896291434 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.0019655407514103367
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378534
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801127009
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451667
# Coulomb Energy                  3040.4659355248773
# Exchange-Correlation Energy     -184.4328301188934
# --------------------------------------------------
# Total Energy                   -1525.7903988308876
# --------------------------------------------------
#
#
#
# Energy difference :  9.527761903882492e-07
#
#
# HOMO-LUMO gap: 0.05071262125658982 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.0010394322798023632
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780368
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447274
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272610917
# Coulomb Energy                  3040.4701320976092
# Exchange-Correlation Energy     -184.4333553536721
# --------------------------------------------------
# Total Energy                   -1525.7903988090366
# --------------------------------------------------
#
#
#
# Energy difference :  2.1851064957445487e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090366
# -------------------------------------
#
#
#
# Time taken : 75.14 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           8.18
# Density Fitting                         1.29
#     DF (gamma)                          0.28
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.81
# DIIS                                    0.58
# KS matrix diagonalization               1.04
# One electron Integrals (S, T, Vnuc)     0.08
# Coulomb Integrals (2c2e + 3c2e)         11.16
# Grids construction                      4.88
# Exchange-Correlation Term               45.39
# Misc.                                   2.55
# Complete SCF                            75.14

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.15 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.52 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.1
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.018059904999972787
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.69
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.33 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 17.02 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 22.25 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.46 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0029198407821
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004615
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513692
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513692
#
#
# HOMO-LUMO gap: 1.3453174761627622 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  144.01406386863272
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999672071531
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016248886
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642082223
# Coulomb Energy                  7102.4006978647503
# Exchange-Correlation Energy     -401.0386878050911
# --------------------------------------------------
# Total Energy                   -2175.7881061963926
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6095705450234
#
#
# HOMO-LUMO gap: 0.003632652816661752 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 5.63 seconds
#
#
#
# Density matrix difference norm:  71.99427239658293
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247206
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645630059
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936490
# Coulomb Energy                  5771.7138319759715
# Exchange-Correlation Energy     -243.8524720616975
# --------------------------------------------------
# Total Energy                   -2274.5129129944680
# --------------------------------------------------
#
#
#
# Energy difference :  98.7248067980754
#
#
# HOMO-LUMO gap: 0.004964611535140259 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 5.68 seconds
#
#
#
# Density matrix difference norm:  58.10070148971643
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0021440415607
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804038284
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573468470
# Coulomb Energy                  6321.7172809537415
# Exchange-Correlation Energy     -278.3781618573295
# --------------------------------------------------
# Total Energy                   -2158.4748827999547
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019451334
#
#
# HOMO-LUMO gap: 0.014474030560942153 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  53.36997549236149
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0018076772094
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768213524
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230008020
# Coulomb Energy                  6361.2336350674204
# Exchange-Correlation Energy     -281.9436333441268
# --------------------------------------------------
# Total Energy                   -2182.5642309366422
# --------------------------------------------------
#
#
#
# Energy difference :  24.089348136687477
#
#
# HOMO-LUMO gap: 0.00884169399663376 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 5.86 seconds
#
#
#
# Density matrix difference norm:  42.839015094838196
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00099084148945
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446994407
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382081648
# Coulomb Energy                  6294.5110601799388
# Exchange-Correlation Energy     -283.9707682331749
# --------------------------------------------------
# Total Energy                   -2345.8009933838985
# --------------------------------------------------
#
#
#
# Energy difference :  163.2367624472563
#
#
# HOMO-LUMO gap: 0.007160714250969383 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 5.93 seconds
#
#
#
# Density matrix difference norm:  32.18186260039497
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9997863855179
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019081362
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650762334
# Coulomb Energy                  6214.1516556246506
# Exchange-Correlation Energy     -284.6344014151408
# --------------------------------------------------
# Total Energy                   -2343.5239614617776
# --------------------------------------------------
#
#
#
# Energy difference :  2.277031922120841
#
#
# HOMO-LUMO gap: 0.002450375009548131 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 5.9 seconds
#
#
#
# Density matrix difference norm:  33.323333139751135
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008608156512
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115044350
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996834635
# Coulomb Energy                  6284.6237009942870
# Exchange-Correlation Energy     -286.3084442723688
# --------------------------------------------------
# Total Energy                   -2352.7413339384384
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372476660785
#
#
# HOMO-LUMO gap: 0.00667331841546559 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 5.85 seconds
#
#
#
# Density matrix difference norm:  26.098281915691867
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026797845874
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383662021
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896540085
# Coulomb Energy                  6418.8046173132134
# Exchange-Correlation Energy     -305.3162932883750
# --------------------------------------------------
# Total Energy                   -2410.9382035267390
# --------------------------------------------------
#
#
#
# Energy difference :  58.196869588300615
#
#
# HOMO-LUMO gap: 0.0079605395852919 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  17.534698642340928
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057267143
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201866660
# Coulomb Energy                  6329.9135850850444
# Exchange-Correlation Energy     -297.7524519058906
# --------------------------------------------------
# Total Energy                   -2373.3942312002791
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397232645988
#
#
# HOMO-LUMO gap: 0.013997838561191939 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  16.420704644892247
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982379832295
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814646011
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928333982
# Coulomb Energy                  6324.0705156579770
# Exchange-Correlation Energy     -296.6169927423721
# --------------------------------------------------
# Total Energy                   -2423.4444445549834
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335470428
#
#
# HOMO-LUMO gap: 0.005801716893622716 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  17.91362907368263
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008255772792
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871581475
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553251589
# Coulomb Energy                  6269.4959589827840
# Exchange-Correlation Energy     -292.3687260434705
# --------------------------------------------------
# Total Energy                   -2388.5334777330600
# --------------------------------------------------
#
#
#
# Energy difference :  34.910966821923466
#
#
# HOMO-LUMO gap: 0.011739724643274788 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  18.864810928421647
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008953428889
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999720648
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986964816
# Coulomb Energy                  6304.9912271462981
# Exchange-Correlation Energy     -292.7049362976261
# --------------------------------------------------
# Total Energy                   -2419.7690892662977
# --------------------------------------------------
#
#
#
# Energy difference :  31.235611533237716
#
#
# HOMO-LUMO gap: 0.0016995925738702844 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  14.26893860236506
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001543150049
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930586873
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204736482
# Coulomb Energy                  6279.2250589649830
# Exchange-Correlation Energy     -293.0502585451959
# --------------------------------------------------
# Total Energy                   -2419.7439510046370
# --------------------------------------------------
#
#
#
# Energy difference :  0.025138261660686112
#
#
# HOMO-LUMO gap: 0.0058464312241608 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 5.72 seconds
#
#
#
# Density matrix difference norm:  12.512861011280314
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026512183945
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104166372
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140353840
# Coulomb Energy                  6304.4543925178414
# Exchange-Correlation Energy     -294.2073055525592
# --------------------------------------------------
# Total Energy                   -2431.0698882553561
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937250719107
#
#
# HOMO-LUMO gap: 0.016452349542679323 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  10.313139444345378
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775205
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763862364
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614181602
# Coulomb Energy                  6320.4324015812763
# Exchange-Correlation Energy     -296.9899338050051
# --------------------------------------------------
# Total Energy                   -2429.5155260311913
# --------------------------------------------------
#
#
#
# Energy difference :  1.5543622241648336
#
#
# HOMO-LUMO gap: 0.005064351052767591 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  8.084972669652112
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00009764058933
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466507070
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611216969
# Coulomb Energy                  6316.3510406925834
# Exchange-Correlation Energy     -296.7435745386247
# --------------------------------------------------
# Total Energy                   -2437.9484982144368
# --------------------------------------------------
#
#
#
# Energy difference :  8.43297218324551
#
#
# HOMO-LUMO gap: 0.058930388772398715 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  4.102604850182793
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001181061176
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030005137
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451738846
# Coulomb Energy                  6313.1881517244447
# Exchange-Correlation Energy     -295.9055099897925
# --------------------------------------------------
# Total Energy                   -2441.0025949313613
# --------------------------------------------------
#
#
#
# Energy difference :  3.054096716924505
#
#
# HOMO-LUMO gap: 0.005337250456768444 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  6.254076481090103
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361987007
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051630467
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545136647
# Coulomb Energy                  6280.4277633842830
# Exchange-Correlation Energy     -293.2139724471971
# --------------------------------------------------
# Total Energy                   -2436.9286385516807
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956379680567
#
#
# HOMO-LUMO gap: 0.011871839819207974 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  7.413375411093758
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026335587484
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726554956622
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918855684
# Coulomb Energy                  6298.7681987412006
# Exchange-Correlation Energy     -294.0996241349995
# --------------------------------------------------
# Total Energy                   -2439.1315678432793
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292915985934
#
#
# HOMO-LUMO gap: 0.10362999798007105 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  4.1883975896574075
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001162436133
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485027207
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696465584
# Coulomb Energy                  6305.6013415992738
# Exchange-Correlation Energy     -295.1700654130826
# --------------------------------------------------
# Total Energy                   -2441.2043815093557
# --------------------------------------------------
#
#
#
# Energy difference :  2.0728136660763994
#
#
# HOMO-LUMO gap: 0.03035834741212535 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  1.0881186800180251
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001058435007
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355858482
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042575538
# Coulomb Energy                  6306.4146008194130
# Exchange-Correlation Energy     -295.1986114171698
# --------------------------------------------------
# Total Energy                   -2441.2281207654378
# --------------------------------------------------
#
#
#
# Energy difference :  0.02373925608208083
#
#
# HOMO-LUMO gap: 0.10156738658842848 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  0.6147083203367267
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000113864789
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391414063
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706639091
# Coulomb Energy                  6305.3788664344629
# Exchange-Correlation Energy     -295.1059315049071
# --------------------------------------------------
# Total Energy                   -2441.3391123873280
# --------------------------------------------------
#
#
#
# Energy difference :  0.11099162189020717
#
#
# HOMO-LUMO gap: 0.12914420512333236 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 5.8 seconds
#
#
#
# Density matrix difference norm:  0.22866753078847032
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011297097166
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680215968358
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454850645
# Coulomb Energy                  6306.4753103327403
# Exchange-Correlation Energy     -295.2425453762672
# --------------------------------------------------
# Total Energy                   -2441.3433899946849
# --------------------------------------------------
#
#
#
# Energy difference :  0.004277607356925728
#
#
# HOMO-LUMO gap: 0.11914092717430448 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 5.79 seconds
#
#
#
# Density matrix difference norm:  0.1331682879002239
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924017
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663333087
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009440847
# Coulomb Energy                  6305.4375957440670
# Exchange-Correlation Energy     -295.1178679620699
# --------------------------------------------------
# Total Energy                   -2441.3482164466122
# --------------------------------------------------
#
#
#
# Energy difference :  0.00482645192732889
#
#
# HOMO-LUMO gap: 0.07758609961172368 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.16794684445103122
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001191827322
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810450386
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356940256
# Coulomb Energy                  6304.4474550019286
# Exchange-Correlation Energy     -294.9863691581788
# --------------------------------------------------
# Total Energy                   -2441.3482383466499
# --------------------------------------------------
#
#
#
# Energy difference :  2.1900037609157152e-05
#
#
# HOMO-LUMO gap: 0.0822040741581608 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.08195634560942382
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011761289034
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560671090
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184232700
# Coulomb Energy                  6305.2666287324510
# Exchange-Correlation Energy     -295.0991774795692
# --------------------------------------------------
# Total Energy                   -2441.3500652303419
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836920469766
#
#
# HOMO-LUMO gap: 0.08681393247578788 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.030947650063549048
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711135
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449607028
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969465743
# Coulomb Energy                  6305.1999901383333
# Exchange-Correlation Energy     -295.0882138897737
# --------------------------------------------------
# Total Energy                   -2441.3501506049543
# --------------------------------------------------
#
#
#
# Energy difference :  8.537461235391675e-05
#
#
# HOMO-LUMO gap: 0.08605512219069922 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.015359420139108427
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011741243867
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082985604
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754508195
# Coulomb Energy                  6305.1611656009381
# Exchange-Correlation Energy     -295.0851653175702
# --------------------------------------------------
# Total Energy                   -2441.3502114037592
# --------------------------------------------------
#
#
#
# Energy difference :  6.079880495235557e-05
#
#
# HOMO-LUMO gap: 0.08610559554989416 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.76 seconds
#
#
#
# Density matrix difference norm:  0.005850728288654681
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173080263
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341356496
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624063524
# Coulomb Energy                  6305.1739654233825
# Exchange-Correlation Energy     -295.0859344062297
# --------------------------------------------------
# Total Energy                   -2441.3502195515302
# --------------------------------------------------
#
#
#
# Energy difference :  8.1477710409672e-06
#
#
# HOMO-LUMO gap: 0.08627753380284835 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.002268765569800213
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730379316
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171301995
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318833
# Coulomb Energy                  6305.1767750460203
# Exchange-Correlation Energy     -295.0862921108234
# --------------------------------------------------
# Total Energy                   -2441.3502203025055
# --------------------------------------------------
#
#
#
# Energy difference :  7.509752322221175e-07
#
#
# HOMO-LUMO gap: 0.08629954674334939 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.0014216232841745898
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731611835
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335501054
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841015683
# Coulomb Energy                  6305.1678310989082
# Exchange-Correlation Energy     -295.0851232567589
# --------------------------------------------------
# Total Energy                   -2441.3502204457727
# --------------------------------------------------
#
#
#
# Energy difference :  1.4326724340207875e-07
#
#
# HOMO-LUMO gap: 0.08625864034175133 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.77 seconds
#
#
#
# Density matrix difference norm:  0.0007905213661659529
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731926696
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319217
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598420
# Coulomb Energy                  6305.1716231999044
# Exchange-Correlation Energy     -295.0855737005008
# --------------------------------------------------
# Total Energy                   -2441.3502206120602
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628746379865333e-07
#
#
# HOMO-LUMO gap: 0.08626853544497443 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.00028632021439833
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173138948
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851890501
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651371180
# Coulomb Energy                  6305.1740152928478
# Exchange-Correlation Energy     -295.0859370217383
# --------------------------------------------------
# Total Energy                   -2441.3502206202074
# --------------------------------------------------
#
#
#
# Energy difference :  8.147253538481891e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206202074
# -------------------------------------
#
#
#
# Time taken : 269.59 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           22.7
# Density Fitting                         5.76
#     DF (gamma)                          1.06
#     DF (coeff)                          0.17
#     DF (Jtri)                           4.12
# DIIS                                    4.05
# KS matrix diagonalization               3.85
# One electron Integrals (S, T, Vnuc)     0.15
# Coulomb Integrals (2c2e + 3c2e)         29.33
# Grids construction                      17.02
# Exchange-Correlation Term               182.15
# Misc.                                   4.58
# Complete SCF                            269.59

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.03 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.04 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0007920509999621572
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.04
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.84 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.33 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.58 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.05 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000355
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709563
# Exchange-Correlation Energy      -16.0363502502441
# --------------------------------------------------
# Total Energy                     -93.1572655540413
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726555404132
#
#
# HOMO-LUMO gap: 2.643230893268289 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.33 seconds
#
#
#
# Density matrix difference norm:  43.3473769504189
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999992
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065134268076
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632901411569
# Coulomb Energy                   501.1179499873575
# Exchange-Correlation Energy      -62.5998153686523
# --------------------------------------------------
# Total Energy                    -340.0671116228219
# --------------------------------------------------
#
#
#
# Energy difference :  246.9098460687806
#
#
# HOMO-LUMO gap: 0.004895001056189008 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  28.612251378315346
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000107
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015434342856
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404486356344
# Coulomb Energy                   293.3105327789956
# Exchange-Correlation Energy      -37.4191284179688
# --------------------------------------------------
# Total Energy                    -355.5117133935007
# --------------------------------------------------
#
#
#
# Energy difference :  15.444601770678787
#
#
# HOMO-LUMO gap: 0.04090611597344718 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.14 seconds
#
#
#
# Density matrix difference norm:  21.39438043568992
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6802048744876
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079158470793
# Coulomb Energy                   367.2116081156456
# Exchange-Correlation Energy      -44.5831108093262
# --------------------------------------------------
# Total Energy                    -380.5858146769653
# --------------------------------------------------
#
#
#
# Energy difference :  25.074101283464586
#
#
# HOMO-LUMO gap: 0.018045819534149937 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  5.193655309006805
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853211394395
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987312449210
# Coulomb Energy                   364.3594842203941
# Exchange-Correlation Energy      -44.5593338012695
# --------------------------------------------------
# Total Energy                    -378.6284624312704
# --------------------------------------------------
#
#
#
# Energy difference :  1.9573522456948922
#
#
# HOMO-LUMO gap: 0.08497506224162539 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  4.776044383076637
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000023
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113353910842
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536993637218
# Coulomb Energy                   368.1595786044325
# Exchange-Correlation Energy      -45.0864906311035
# --------------------------------------------------
# Total Energy                    -381.1265710099099
# --------------------------------------------------
#
#
#
# Energy difference :  2.498108578639517
#
#
# HOMO-LUMO gap: 0.14153440093749597 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5199018206079626
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759870186035
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620529814521
# Coulomb Energy                   369.0651872518384
# Exchange-Correlation Energy      -45.1361846923828
# --------------------------------------------------
# Total Energy                    -381.2269544335721
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038342366220832
#
#
# HOMO-LUMO gap: 0.13505793051862272 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.3314182211294337
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685883045522
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352932575375
# Coulomb Energy                   369.6332915647355
# Exchange-Correlation Energy      -45.2082252502441
# --------------------------------------------------
# Total Energy                    -381.2502516883999
# --------------------------------------------------
#
#
#
# Energy difference :  0.023297254827753022
#
#
# HOMO-LUMO gap: 0.01948112047503911 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5819574011120894
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471076686509
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753380205230
# Coulomb Energy                   374.0875565365531
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611101760
# --------------------------------------------------
#
#
#
# Energy difference :  0.13180942177609722
#
#
# HOMO-LUMO gap: 0.12602028669960091 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.45972397759929057
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167311182999
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482981739534
# Coulomb Energy                   377.3936785488552
# Exchange-Correlation Energy      -46.1032257080078
# --------------------------------------------------
# Total Energy                    -381.4200030593756
# --------------------------------------------------
#
#
#
# Energy difference :  0.03794194919959182
#
#
# HOMO-LUMO gap: 0.1661133305345429 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.14506670258870244
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6774115562152
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4957003907749
# Coulomb Energy                   377.1713417801245
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261838450986
# --------------------------------------------------
#
#
#
# Energy difference :  0.006180785723017834
#
#
# HOMO-LUMO gap: 0.1810975059532616 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.05597038785771394
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466991731173
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5465057499969
# Coulomb Energy                   377.1955793525869
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266045251893
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004206800907127217
#
#
# HOMO-LUMO gap: 0.1809318563800403 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.025624539781267313
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6791043635631
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228770244490
# Coulomb Energy                   377.1480814133165
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267298557952
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012533060589703382
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050730665205655 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.008410601201575659
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074948187
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758646249918
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145535863795
# Coulomb Energy                   377.1522588566483
# Exchange-Correlation Energy      -46.0763604882691
# --------------------------------------------------
# Total Energy                    -381.4274356261096
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007057703143686922
#
#
# HOMO-LUMO gap: 0.18055941774668682 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.002641871406522696
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750320948
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547069029714
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032889737188
# Coulomb Energy                   377.1410365648675
# Exchange-Correlation Energy      -46.0750325767574
# --------------------------------------------------
# Total Energy                    -381.4274368970190
# --------------------------------------------------
#
#
#
# Energy difference :  1.2709094221463602e-06
#
#
# HOMO-LUMO gap: 0.18056583448652913 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.001767839193906364
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749795149
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715784380217
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117381337678
# Coulomb Energy                   377.1506250231091
# Exchange-Correlation Energy      -46.0761996769599
# --------------------------------------------------
# Total Energy                    -381.4274379139813
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169623010369833e-06
#
#
# HOMO-LUMO gap: 0.18057810005489325 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018263944815766306
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074943385
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890954308174
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201163633777
# Coulomb Energy                   377.1610739046037
# Exchange-Correlation Energy      -46.0775109642903
# --------------------------------------------------
# Total Energy                    -381.4274390830027
# --------------------------------------------------
#
#
#
# Energy difference :  1.1690214023474255e-06
#
#
# HOMO-LUMO gap: 0.1806905172165293 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0015078228594069501
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749797101
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793142630854
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150718660052
# Coulomb Energy                   377.1557642489224
# Exchange-Correlation Energy      -46.0769384584159
# --------------------------------------------------
# Total Energy                    -381.4274395624503
# --------------------------------------------------
#
#
#
# Energy difference :  4.794475785274699e-07
#
#
# HOMO-LUMO gap: 0.18064424248414343 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.00046671667696552053
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749830375
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995819631
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900979578
# Coulomb Energy                   377.1550630969089
# Exchange-Correlation Energy      -46.0768702751827
# --------------------------------------------------
# Total Energy                    -381.4274396181556
# --------------------------------------------------
#
#
#
# Energy difference :  5.570535677179578e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743961815563
# -------------------------------------
#
#
#
# Time taken : 9.3 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.64
# Density Fitting                         0.23
#     DF (gamma)                          0.07
#     DF (coeff)                          0.06
#     DF (Jtri)                           0.08
# DIIS                                    0.1
# KS matrix diagonalization               0.36
# One electron Integrals (S, T, Vnuc)     0.03
# Coulomb Integrals (2c2e + 3c2e)         0.84
# Grids construction                      0.33
# Exchange-Correlation Term               5.83
# Misc.                                   0.96
# Complete SCF                            9.3

# %% [markdown]
# ### Benchmark #4 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#   ____       _                     _ _
#  / ___|  ___| |__  _ __ ___   __| (_)_ __   __ _  ___ _ __
#  \___ \ / __| '_ \| '__/ _ \ / _` | | '_ \ / _` |/ _ \ '__|
#   ___) | (__| | | | | | (_) | (_| | | | | | (_| |  __/ |
#  |____/ \___|_| |_|_|  \___/ \__,_|_|_| |_|\__, |\___|_|
#                                            |___/
# ======================================================================
#
#
#                                   :-----;.
#                          ::::;;;;;;;;;;;;;;;;;:::;,
#                        .,;;;;:::;;:,,,,,,,,,,::;;:,..
#                     .-------;;;;;;,.,,.,;,..,;;;;;;;;;;;
#                   ,:;;;;;;;;;;:::::,... :..,:::::::::..;;
#                   :----;---;;:,,,,,,..  ,...,,,,,:--;..::.
#                 .;-------+,                        .;+--;--;
#                  ;;;;;;;:    .                       ,;:::::,
#                  ;-;;;;::    ..                       ,-;;;;;.
#                  ;-----:.. .  .                         ,;---.
#                  .:;;;;:,,..                            .:;;,
#                   :;-----;;,                            .;+-.
#                   :------;::;                           ;;;;
#                   :;;;;;:,,,.                          .:::.
#                   ;+-+-;;;;:.,:::-:,,.      ,-;;:,.    .--:.
#                  ..;--+-,...--:;-:. .;,:: .;;:;-:. .:  .:,.
#                  ,;,:-;,,;+*-,.,;. ..+*-,.+-...;,   ;+-:. ..
#                  -; .+: . .,;.      .+;   .;        ;,. ;...
#                  ...;;. ,,. .,     ,:,,,   .,     .,.   .
#                  ..:+  ,::.   ..,,,,..:,     ..,,..      .
#                   ....,:::,        .. ,.                  .
#                    .  ,:,,...      :....
#                      ..,;;:::.     .,;*-,  .          ..,.
#                         .,,,,  .      . ..            .
#                         .,,,: ... ,..,,. .           ..
#                         -;;;;.    ;;;:,,,,......    ,.
#                       .,;...,..     ..              .
#                      .:;-  ;;,,.                    .
#                    ,;:::;  .-;::::.             ,         ,
#                .,...,,,,,   ,;-;:,,...          .         .
#              .;;;;;;;;;;;,.  .:+++-,.,,.... .  .   .      ,
#         ,,,:,::.,,,,::,,:,,.    .;:;;:....   .     .
#     .. .,:;;:,:,,;;;;;::::.,      .::;.     ..    ..
#               ,    ,-;;;;;;;,                 ,;-:.,          .
#               .     ..,,... ....+-,,,,...::,,,,,,.,.
#              .,         ,   .:;;+%;;--;;;;;---;;;::,
#              ,               .:;;?;;:;;:;:;-+;;;:;,
#             ..                ,;::-:,,,,,,::;;;::,.
#               ,,.              ,;::.  .         ...
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  The task is not so much to see what no one has yet seen, but to     ║
#    ║ think what nobody has yet thought about that which everybody sees.   ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                      ~ schrodinger   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.1 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0029628029999457794
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.08
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.94 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.01 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.98 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371779
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120600
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961206004
#
#
# HOMO-LUMO gap: 1.765506807214702 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.29 seconds
#
#
#
# Density matrix difference norm:  66.88323605808642
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816168858395
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207644691320
# Coulomb Energy                  1272.5916576120549
# Exchange-Correlation Energy     -125.2197723388672
# --------------------------------------------------
# Total Energy                    -680.0824210262881
# --------------------------------------------------
#
#
#
# Energy difference :  494.63380141422806
#
#
# HOMO-LUMO gap: 0.0003950061521029169 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  39.27352432790812
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.001236
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671666176060
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861185032871
# Coulomb Energy                   861.6520702031819
# Exchange-Correlation Energy      -75.4418334960938
# --------------------------------------------------
# Total Energy                    -709.3642652899987
# --------------------------------------------------
#
#
#
# Energy difference :  29.281844263710582
#
#
# HOMO-LUMO gap: 0.027815576346514964 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  28.1451636398849
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99994
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982282478842
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525304346410
# Coulomb Energy                  1000.6416009622185
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464582044959
# --------------------------------------------------
#
#
#
# Energy difference :  24.382192914497182
#
#
# HOMO-LUMO gap: 0.006873881118743264 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  18.101423188276996
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394470589519
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643058400874
# Coulomb Energy                  1039.7364436431692
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035183407878
# --------------------------------------------------
#
#
#
# Energy difference :  44.14293986370808
#
#
# HOMO-LUMO gap: 0.009401599441258277 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  13.030480146546369
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9281985115117
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4697782000823
# Coulomb Energy                  1004.3617049985122
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228962464667
# --------------------------------------------------
#
#
#
# Energy difference :  60.01937790567888
#
#
# HOMO-LUMO gap: 0.02432403114569094 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.651673169636417
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2543708187400
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338780607409
# Coulomb Energy                   997.3404994327127
# Exchange-Correlation Energy      -89.6695938110352
# --------------------------------------------------
# Total Energy                    -755.2430410190898
# --------------------------------------------------
#
#
#
# Energy difference :  5.620144772623121
#
#
# HOMO-LUMO gap: 0.001291109340041341 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.531121588873639
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000244
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9935106690077
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455305416422
# Coulomb Energy                  1008.9226270407427
# Exchange-Correlation Energy      -89.8105316162109
# --------------------------------------------------
# Total Energy                    -754.8293385856017
# --------------------------------------------------
#
#
#
# Energy difference :  0.41370243348808344
#
#
# HOMO-LUMO gap: 0.015388853079648795 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  7.342496641016125
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6263327872966
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2045014011031
# Coulomb Energy                  1033.2839547793164
# Exchange-Correlation Energy      -92.8135986328125
# --------------------------------------------------
# Total Energy                    -754.2449291224575
# --------------------------------------------------
#
#
#
# Energy difference :  0.5844094631441976
#
#
# HOMO-LUMO gap: 0.21170747408309065 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  6.051896151149853
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9762929000985
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1048862021058
# Coulomb Energy                  1046.8936488981942
# Exchange-Correlation Energy      -94.6926879882812
# --------------------------------------------------
# Total Energy                    -761.9638996708479
# --------------------------------------------------
#
#
#
# Energy difference :  7.718970548390416
#
#
# HOMO-LUMO gap: 0.021087402491366723 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  4.592855580378824
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186486361102
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7140605171439
# Coulomb Energy                  1016.5840734732752
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8410437237716
# --------------------------------------------------
#
#
#
# Energy difference :  2.1228559470763457
#
#
# HOMO-LUMO gap: 0.08795066459014038 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  4.199971386773878
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5724881553156
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4485454174259
# Coulomb Energy                  1025.9226118000479
# Exchange-Correlation Energy      -92.2370223999023
# --------------------------------------------------
# Total Energy                    -762.7318072205121
# --------------------------------------------------
#
#
#
# Energy difference :  2.890763496740533
#
#
# HOMO-LUMO gap: 0.14484578546948687 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.25 seconds
#
#
#
# Density matrix difference norm:  0.9087416740688204
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899819547789
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303626706452
# Coulomb Energy                  1024.4800315460263
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263924509536
# --------------------------------------------------
#
#
#
# Energy difference :  0.09458523044145295
#
#
# HOMO-LUMO gap: 0.09120588408271368 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.3385955534420915
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063825801903
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273623295544
# Coulomb Energy                  1024.8155236633440
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565125428138
# --------------------------------------------------
#
#
#
# Energy difference :  0.03012009186022624
#
#
# HOMO-LUMO gap: 0.10812611458542255 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.13342117804812598
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7707747996810
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490286405373
# Coulomb Energy                  1024.3963716585731
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586828144912
# --------------------------------------------------
#
#
#
# Energy difference :  0.0021702716774143482
#
#
# HOMO-LUMO gap: 0.11558372831621362 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.05241030795928132
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028299167041
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1553917286758
# Coulomb Energy                  1024.6505227126754
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595511818517
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008683673604537034
#
#
# HOMO-LUMO gap: 0.11553043603753843 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.014070500271824419
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000181233286
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543964968327
# Coulomb Energy                  1024.5347566847086
# Exchange-Correlation Energy      -92.1552581787109
# --------------------------------------------------
# Total Energy                    -762.8595770032662
# --------------------------------------------------
#
#
#
# Energy difference :  2.582141451057396e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.1196465041480298 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.015808354037076075
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745390483
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803837366980
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978003138933
# Coulomb Energy                  1024.5775711720075
# Exchange-Correlation Energy      -92.1624878070080
# --------------------------------------------------
# Total Energy                    -762.8609539405729
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013769373067589186
#
#
# HOMO-LUMO gap: 0.11848000858462751 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.58 seconds
#
#
#
# Density matrix difference norm:  0.008700591388780862
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741302362
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328776179094
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722787931807
# Coulomb Energy                  1024.5524780488172
# Exchange-Correlation Energy      -92.1594108413819
# --------------------------------------------------
# Total Energy                    -762.8609855000614
# --------------------------------------------------
#
#
#
# Energy difference :  3.15594884341408e-05
#
#
# HOMO-LUMO gap: 0.11834734756616147 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.002054406381068985
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000739808445
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503343643331
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805108850338
# Coulomb Energy                  1024.5630592429191
# Exchange-Correlation Energy      -92.1607681963925
# --------------------------------------------------
# Total Energy                    -762.8609863155409
# --------------------------------------------------
#
#
#
# Energy difference :  8.154795523296343e-07
#
#
# HOMO-LUMO gap: 0.11844993935400697 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.0022804134526450766
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742288557
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365054211111
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734595997584
# Coulomb Energy                  1024.5553043604700
# Exchange-Correlation Energy      -92.1597916655597
# --------------------------------------------------
# Total Energy                    -762.8609870092105
# --------------------------------------------------
#
#
#
# Energy difference :  6.936695626791334e-07
#
#
# HOMO-LUMO gap: 0.11849899934366784 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.0021210086240594944
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742173422
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510218449017
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0797958362064
# Coulomb Energy                  1024.5646228090575
# Exchange-Correlation Energy      -92.1609313237232
# --------------------------------------------------
# Total Energy                    -762.8609884061291
# --------------------------------------------------
#
#
#
# Energy difference :  1.3969186056783656e-06
#
#
# HOMO-LUMO gap: 0.11838532608764127 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.0014185112514443839
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741620009
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635537595094
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852198816519
# Coulomb Energy                  1024.5726720080695
# Exchange-Correlation Energy      -92.1618731074354
# --------------------------------------------------
# Total Energy                    -762.8609888599915
# --------------------------------------------------
#
#
#
# Energy difference :  4.5386241254163906e-07
#
#
# HOMO-LUMO gap: 0.11838275505882184 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.59 seconds
#
#
#
# Density matrix difference norm:  0.00032231420899867484
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742041739
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571685556574
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822982334614
# Coulomb Energy                  1024.5687889683002
# Exchange-Correlation Energy      -92.1614536538210
# --------------------------------------------------
# Total Energy                    -762.8609888904846
# --------------------------------------------------
#
#
#
# Energy difference :  3.049308361369185e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904846
# -------------------------------------
#
#
#
# Time taken : 15.61 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.12
# Density Fitting                         0.52
#     DF (gamma)                          0.15
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.25
# DIIS                                    0.14
# KS matrix diagonalization               0.63
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.94
# Grids construction                      1.01
# Exchange-Correlation Term               6.83
# Misc.                                   1.38
# Complete SCF                            15.61

# %% [markdown]
# ### Benchmark #5 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.08 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.25 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.007369845999960489
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.3
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  11.1 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.95 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.89 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355631
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929923041
# --------------------------------------------------
#
#
#
# Energy difference :  374.9324929923041
#
#
# HOMO-LUMO gap: 1.8503196895447287 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  107.82808392766077
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876321745054
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682663138154
# Coulomb Energy                  3537.3220829802171
# Exchange-Correlation Energy     -250.6110687255859
# --------------------------------------------------
# Total Energy                   -1359.8987077753977
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662147830936
#
#
# HOMO-LUMO gap: 0.0021138370435723752 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  57.36504749175553
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4339726205089
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0382902510005
# Coulomb Energy                  2705.4087019810304
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539387306671
# --------------------------------------------------
#
#
#
# Energy difference :  59.15523095526942
#
#
# HOMO-LUMO gap: 0.01974261040622663 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  48.04762457734294
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987256026849
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516878377807
# Coulomb Energy                  3071.8807164604232
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010317218663
# --------------------------------------------------
#
#
#
# Energy difference :  56.65290700880087
#
#
# HOMO-LUMO gap: 0.014679275663330396 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  40.92171708740575
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335371408612
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1620890232832
# Coulomb Energy                  3051.7270282117815
# Exchange-Correlation Energy     -176.2000274658203
# --------------------------------------------------
# Total Energy                   -1378.8348035409554
# --------------------------------------------------
#
#
#
# Energy difference :  16.43377181908909
#
#
# HOMO-LUMO gap: 0.012567148693864258 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  26.92677598825476
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983162535829
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494774113352
# Coulomb Energy                  3003.5484465990712
# Exchange-Correlation Energy     -179.3104553222656
# --------------------------------------------------
# Total Energy                   -1523.5012037347797
# --------------------------------------------------
#
#
#
# Energy difference :  144.6664001938243
#
#
# HOMO-LUMO gap: 0.0032179324809878274 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.71 seconds
#
#
#
# Density matrix difference norm:  13.414502531621165
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00024
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4196950395508
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319364187805
# Coulomb Energy                  2977.4926588531762
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856604047058
# --------------------------------------------------
#
#
#
# Energy difference :  24.415543330073888
#
#
# HOMO-LUMO gap: 0.031829964058750895 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  12.436593849916855
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381490363485
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8446906797681
# Coulomb Energy                  3000.9338467183215
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434614599415
# --------------------------------------------------
#
#
#
# Energy difference :  23.657801055235723
#
#
# HOMO-LUMO gap: 0.012963683011304739 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.013464919341682
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677645466003
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553162376063
# Coulomb Energy                  3041.7902292605368
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430836406473
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996221807057736
#
#
# HOMO-LUMO gap: 0.021491236302206035 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  6.2166373306980915
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4699653924472
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196382913243
# Coulomb Energy                  3063.1283238723299
# Exchange-Correlation Energy     -185.9102325439453
# --------------------------------------------------
# Total Energy                   -1521.9225919420769
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204916985703676
#
#
# HOMO-LUMO gap: 0.07962880877715878 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  4.429033755936274
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505052580811
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1094888675098
# Coulomb Energy                  3048.3900529990260
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820330618608
# --------------------------------------------------
#
#
#
# Energy difference :  3.659441119783878
#
#
# HOMO-LUMO gap: 0.1194795090991317 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.8332704103376459
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00008
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524414210209
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100143750798
# Coulomb Energy                  3044.2746775906280
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396913180100
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765825614926143
#
#
# HOMO-LUMO gap: 0.10915532323197347 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.4379675882809742
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333907947719
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380079253824
# Coulomb Energy                  3039.9319401053272
# Exchange-Correlation Energy     -184.3113403320312
# --------------------------------------------------
# Total Energy                   -1525.7651392654316
# --------------------------------------------------
#
#
#
# Energy difference :  0.025447947421525896
#
#
# HOMO-LUMO gap: 0.08049514984887843 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  0.28021884722203644
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675651210004
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0128936963351
# Coulomb Energy                  3041.4808637412762
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832831154219
# --------------------------------------------------
#
#
#
# Energy difference :  0.018143849990337912
#
#
# HOMO-LUMO gap: 0.03536211092145111 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.20216529822620363
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152288048997
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773143752906
# Coulomb Energy                  3040.7151022755488
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864196661712
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031365507493319456
#
#
# HOMO-LUMO gap: 0.044774007854681774 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.69 seconds
#
#
#
# Density matrix difference norm:  0.0763347873399535
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0312896386913
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161696493959
# Coulomb Energy                  3040.4442130494431
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875173816515
# --------------------------------------------------
#
#
#
# Energy difference :  0.0010977154802276345
#
#
# HOMO-LUMO gap: 0.05279080600016191 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.7 seconds
#
#
#
# Density matrix difference norm:  0.02844034525935235
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299747009867
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078529717156
# Coulomb Energy                  3040.4514277167300
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877011828559
# --------------------------------------------------
#
#
#
# Energy difference :  0.00018380120445726789
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.049892897858283713 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  0.012831657702490104
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963125798
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444128896521
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722277413465
# Coulomb Energy                  3040.3964256795216
# Exchange-Correlation Energy     -184.4242565548065
# --------------------------------------------------
# Total Energy                   -1525.7903721929297
# --------------------------------------------------
#
#
#
# Energy difference :  0.002671010073754587
#
#
# HOMO-LUMO gap: 0.050552958931367575 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 2.34 seconds
#
#
#
# Density matrix difference norm:  0.00530050142897741
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396068968
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993328770961
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002725475621
# Coulomb Energy                  3040.4277556350753
# Exchange-Correlation Energy     -184.4287290768839
# --------------------------------------------------
# Total Energy                   -1525.7903899406811
# --------------------------------------------------
#
#
#
# Energy difference :  1.774775137164397e-05
#
#
# HOMO-LUMO gap: 0.05045900355491076 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 2.36 seconds
#
#
#
# Density matrix difference norm:  0.00210623177990818
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961675364
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9999006853941
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3973962848645
# Coulomb Energy                  3040.4311718083914
# Exchange-Correlation Energy     -184.4287043234164
# --------------------------------------------------
# Total Energy                   -1525.7903930848920
# --------------------------------------------------
#
#
#
# Energy difference :  3.144210950267734e-06
#
#
# HOMO-LUMO gap: 0.05065933994490282 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.004881535162382298
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396005415
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796155698781
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345426413688
# Coulomb Energy                  3040.4795329978865
# Exchange-Correlation Energy     -184.4344982837202
# --------------------------------------------------
# Total Energy                   -1525.7903943836805
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987884474569e-06
#
#
# HOMO-LUMO gap: 0.050633282626629764 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.004003907794798075
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396293581
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308458480376
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102270365161
# Coulomb Energy                  3040.4520258054108
# Exchange-Correlation Energy     -184.4314494273438
# --------------------------------------------------
# Total Energy                   -1525.7903986027923
# --------------------------------------------------
#
#
#
# Energy difference :  4.219111815473298e-06
#
#
# HOMO-LUMO gap: 0.05065920467280628 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.38 seconds
#
#
#
# Density matrix difference norm:  0.0009814926388735973
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.000039623176
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462801756239
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170922878425
# Coulomb Energy                  3040.4616006754691
# Exchange-Correlation Energy     -184.4324555350947
# --------------------------------------------------
# Total Energy                   -1525.7903989167448
# --------------------------------------------------
#
#
#
# Energy difference :  3.139525688311551e-07
#
#
# HOMO-LUMO gap: 0.05067942688085847 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.37 seconds
#
#
#
# Density matrix difference norm:  0.00024619033637861406
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332747
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503257906776
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622418262
# Coulomb Energy                  3040.4641306093190
# Exchange-Correlation Energy     -184.4327098288267
# --------------------------------------------------
# Total Energy                   -1525.7903989376964
# --------------------------------------------------
#
#
#
# Energy difference :  2.095157469739206e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903989376964
# -------------------------------------
#
#
#
# Time taken : 54.84 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           8.06
# Density Fitting                         1.46
#     DF (gamma)                          0.31
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.92
# DIIS                                    0.72
# KS matrix diagonalization               1.21
# One electron Integrals (S, T, Vnuc)     0.08
# Coulomb Integrals (2c2e + 3c2e)         11.1
# Grids construction                      4.95
# Exchange-Correlation Term               24.74
# Misc.                                   2.53
# Complete SCF                            54.84

# %% [markdown]
# ### Benchmark #6 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.15 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.54 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.1
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.017885564000039267
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.69
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  29.41 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 17.36 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 22.36 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.27 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004588
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456298
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456298
#
#
# HOMO-LUMO gap: 1.3453310369351446 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.73 seconds
#
#
#
# Density matrix difference norm:  144.01367462687938
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771653634634
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873960288311
# Coulomb Energy                  7102.3908476757315
# Exchange-Correlation Energy     -401.0388488769531
# --------------------------------------------------
# Total Energy                   -2175.7976493752394
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159317296097
#
#
# HOMO-LUMO gap: 0.0036323936827508674 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.38 seconds
#
#
#
# Density matrix difference norm:  71.99222142061329
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0024
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8537956295877
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349342492934
# Coulomb Energy                  5771.7158140791171
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171589286483
# --------------------------------------------------
#
#
#
# Energy difference :  98.7195095534089
#
#
# HOMO-LUMO gap: 0.0049716053625467604 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  58.102785451354904
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372312832515
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733518993173
# Coulomb Energy                  6321.7308991248829
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4680727214836
# --------------------------------------------------
#
#
#
# Energy difference :  116.04908620716469
#
#
# HOMO-LUMO gap: 0.014406138258259316 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 1.44 seconds
#
#
#
# Density matrix difference norm:  53.368664134148084
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688654841888
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515407289497
# Coulomb Energy                  6361.2922209370354
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5267246009480
# --------------------------------------------------
#
#
#
# Energy difference :  24.058651879464378
#
#
# HOMO-LUMO gap: 0.00893103253312505 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 1.45 seconds
#
#
#
# Density matrix difference norm:  42.83084127096077
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057592135374
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112449537719
# Coulomb Energy                  6294.4824445621562
# Exchange-Correlation Energy     -283.9661865234375
# --------------------------------------------------
# Total Energy                   -2345.8381350604323
# --------------------------------------------------
#
#
#
# Energy difference :  163.31141045948425
#
#
# HOMO-LUMO gap: 0.0069073967492473964 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  32.16624575797539
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2173785164796
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029700329258
# Coulomb Energy                  6214.1441910597696
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5589109604352
# --------------------------------------------------
#
#
#
# Energy difference :  2.279224099997009
#
#
# HOMO-LUMO gap: 0.002470709750213171 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  33.32021754503569
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828116799235
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271103337159
# Coulomb Energy                  6284.7511275238003
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5702693121830
# --------------------------------------------------
#
#
#
# Energy difference :  9.011358351747731
#
#
# HOMO-LUMO gap: 0.006022955025383692 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  26.099226956806042
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2099372011817
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3779269789843
# Coulomb Energy                  6418.6993011367285
# Exchange-Correlation Energy     -305.3439331054688
# --------------------------------------------------
# Total Energy                   -2411.0365210303207
# --------------------------------------------------
#
#
#
# Energy difference :  58.466251718137755
#
#
# HOMO-LUMO gap: 0.005611937117123697 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 1.51 seconds
#
#
#
# Density matrix difference norm:  17.53005626882309
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3145303327001
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3754992813319
# Coulomb Energy                  6329.8759325704841
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3362036386288
# --------------------------------------------------
#
#
#
# Energy difference :  37.7003173916919
#
#
# HOMO-LUMO gap: 0.017129088733618583 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  16.398026567121512
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4113425424785
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3502308843326
# Coulomb Energy                  6323.6507444485360
# Exchange-Correlation Energy     -296.5716552734375
# --------------------------------------------------
# Total Energy                   -2423.5419013224328
# --------------------------------------------------
#
#
#
# Energy difference :  50.20569768380392
#
#
# HOMO-LUMO gap: 0.006507637523108123 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  17.896860067723885
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006167628413
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1970988870435
# Coulomb Energy                  6269.6529555214365
# Exchange-Correlation Energy     -292.3520507812500
# --------------------------------------------------
# Total Energy                   -2388.4624919749967
# --------------------------------------------------
#
#
#
# Energy difference :  35.07940934743601
#
#
# HOMO-LUMO gap: 0.011363300514777658 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  18.875114133916323
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4052630435290
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783308824181
# Coulomb Energy                  6305.1510571326326
# Exchange-Correlation Energy     -292.6977233886719
# --------------------------------------------------
# Total Energy                   -2419.6334772565351
# --------------------------------------------------
#
#
#
# Energy difference :  31.17098528153838
#
#
# HOMO-LUMO gap: 0.0019309240608485073 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  14.237403062259233
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7557327351387
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6446802640571
# Coulomb Energy                  6277.9143579198717
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7447936054396
# --------------------------------------------------
#
#
#
# Energy difference :  0.1113163489044382
#
#
# HOMO-LUMO gap: 0.008268329526294457 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 1.52 seconds
#
#
#
# Density matrix difference norm:  12.511462218740466
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00024
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8343482720375
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119781401531
# Coulomb Energy                  6304.6092732282114
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9790914657142
# --------------------------------------------------
#
#
#
# Energy difference :  11.234297860274637
#
#
# HOMO-LUMO gap: 0.01765890502191929 au
# HOMO-LUMO gap: 0.481 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  10.321246876349814
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9999
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0478688719559
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2890631287173
# Coulomb Energy                  6320.8556086714352
# Exchange-Correlation Energy     -297.0248413085938
# --------------------------------------------------
# Total Energy                   -2429.4879172197825
# --------------------------------------------------
#
#
#
# Energy difference :  1.4911742459316883
#
#
# HOMO-LUMO gap: 0.006404339358826977 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  8.082501869832399
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4239061084900
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0824953830552
# Coulomb Energy                  6316.7243785495812
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382940718806
# --------------------------------------------------
#
#
#
# Energy difference :  8.450376852098088
#
#
# HOMO-LUMO gap: 0.06628554899938809 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  4.088566928311084
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3817995940481
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5872181580280
# Coulomb Energy                  6313.2561833405071
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039776184931
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656835466124903
#
#
# HOMO-LUMO gap: 0.00250885819676748 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  4.342550156160001
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2973780794182
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1398810761521
# Coulomb Energy                  6287.7369348131524
# Exchange-Correlation Energy     -293.7501525878906
# --------------------------------------------------
# Total Energy                   -2439.7305936173907
# --------------------------------------------------
#
#
#
# Energy difference :  1.2733840011023858
#
#
# HOMO-LUMO gap: 0.02060458545798554 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 1.56 seconds
#
#
#
# Density matrix difference norm:  4.259655119959024
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7062331701982
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.1986417553508
# Coulomb Energy                  6303.8933600438395
# Exchange-Correlation Energy     -294.9478454589844
# --------------------------------------------------
# Total Energy                   -2441.1219556693777
# --------------------------------------------------
#
#
#
# Energy difference :  1.3913620519870165
#
#
# HOMO-LUMO gap: 0.12298467530274898 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 1.53 seconds
#
#
#
# Density matrix difference norm:  0.7427939737474312
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0197608746566
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5243439714668
# Coulomb Energy                  6307.0122238272324
# Exchange-Correlation Energy     -295.2850036621094
# --------------------------------------------------
# Total Energy                   -2441.3280755774522
# --------------------------------------------------
#
#
#
# Energy difference :  0.20611990807447
#
#
# HOMO-LUMO gap: 0.08867272130152803 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 1.54 seconds
#
#
#
# Density matrix difference norm:  0.4773173898027645
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4110267237593
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7989040690836
# Coulomb Energy                  6304.8709366275461
# Exchange-Correlation Energy     -295.0262756347656
# --------------------------------------------------
# Total Energy                   -2441.3273405012797
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007350761725319899
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639439162469967 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 1.56 seconds
#
#
#
# Density matrix difference norm:  0.27042095721528525
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011527423504
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5565279349394
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4793760445532
# Coulomb Energy                  6304.2831454946345
# Exchange-Correlation Energy     -294.9926881546274
# --------------------------------------------------
# Total Energy                   -2441.3465733897638
# --------------------------------------------------
#
#
#
# Energy difference :  0.019232888484111754
#
#
# HOMO-LUMO gap: 0.10571269187269818 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 5.93 seconds
#
#
#
# Density matrix difference norm:  0.11903356054828518
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001155254493
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9902937364805
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6069417426361
# Coulomb Energy                  6305.7413567500171
# Exchange-Correlation Energy     -295.1471012121820
# --------------------------------------------------
# Total Energy                   -2441.3489752953938
# --------------------------------------------------
#
#
#
# Energy difference :  0.0024019056299948716
#
#
# HOMO-LUMO gap: 0.10232783482622909 au
# HOMO-LUMO gap: 2.784 eV
#
#
# Time taken for the previous iteration: 5.88 seconds
#
#
#
# Density matrix difference norm:  0.05772691124969207
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001161639075
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1764317176530
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2270850383175
# Coulomb Energy                  6305.2551391139932
# Exchange-Correlation Energy     -295.0957760744736
# --------------------------------------------------
# Total Energy                   -2441.3498624792010
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008871838072082028
#
#
# HOMO-LUMO gap: 0.08313013335199011 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 5.82 seconds
#
#
#
# Density matrix difference norm:  0.06366263432312032
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011775876857
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6239495880927
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9398055328593
# Coulomb Energy                  6304.9502888970619
# Exchange-Correlation Energy     -295.0562560549394
# --------------------------------------------------
# Total Energy                   -2441.3499900524948
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012757329386658967
#
#
# HOMO-LUMO gap: 0.08543977961731461 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 5.81 seconds
#
#
#
# Density matrix difference norm:  0.03312646691959303
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011719092333
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1937893522372
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2381645601567
# Coulomb Energy                  6305.2622651631928
# Exchange-Correlation Energy     -295.0969074907179
# --------------------------------------------------
# Total Energy                   -2441.3501459589907
# --------------------------------------------------
#
#
#
# Energy difference :  0.00015590649582009064
#
#
# HOMO-LUMO gap: 0.08549320507119759 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 5.78 seconds
#
#
#
# Density matrix difference norm:  0.016442889797833586
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011743727316
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9924292131836
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1355451610939
# Coulomb Energy                  6305.1489916919245
# Exchange-Correlation Energy     -295.0824366902730
# --------------------------------------------------
# Total Energy                   -2441.3502078898227
# --------------------------------------------------
#
#
#
# Energy difference :  6.193083208927419e-05
#
#
# HOMO-LUMO gap: 0.08609953795063971 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.75 seconds
#
#
#
# Density matrix difference norm:  0.0073535286409668705
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173439329
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0612560308109
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745110646375
# Coulomb Energy                  6305.1841822361312
# Exchange-Correlation Energy     -295.0877764612025
# --------------------------------------------------
# Total Energy                   -2441.3502180306314
# --------------------------------------------------
#
#
#
# Energy difference :  1.0140808626601938e-05
#
#
# HOMO-LUMO gap: 0.08618091833780532 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 5.74 seconds
#
#
#
# Density matrix difference norm:  0.0029219804662737768
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173203543
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0438991899446
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630539723001
# Coulomb Energy                  6305.1767180225324
# Exchange-Correlation Energy     -295.0862144576023
# --------------------------------------------------
# Total Energy                   -2441.3502204921006
# --------------------------------------------------
#
#
#
# Energy difference :  2.461469193804078e-06
#
#
# HOMO-LUMO gap: 0.08626993755883294 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0007991855865220307
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730882505
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357869115996
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591885725707
# Coulomb Energy                  6305.1719581637317
# Exchange-Correlation Energy     -295.0857015808070
# --------------------------------------------------
# Total Energy                   -2441.3502205954901
# --------------------------------------------------
#
#
#
# Energy difference :  1.0338953870814294e-07
#
#
# HOMO-LUMO gap: 0.08626927821132352 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.73 seconds
#
#
#
# Density matrix difference norm:  0.0004708862016907413
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000117317085
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0330011316491
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576326916947
# Coulomb Energy                  6305.1705222361215
# Exchange-Correlation Energy     -295.0854955622688
# --------------------------------------------------
# Total Energy                   -2441.3502206054873
# --------------------------------------------------
#
#
#
# Energy difference :  9.997165761888027e-09
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206054873
# -------------------------------------
#
#
#
# Time taken : 164.49 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           22.63
# Density Fitting                         5.33
#     DF (gamma)                          0.99
#     DF (coeff)                          0.16
#     DF (Jtri)                           3.81
# DIIS                                    3.79
# KS matrix diagonalization               3.62
# One electron Integrals (S, T, Vnuc)     0.15
# Coulomb Integrals (2c2e + 3c2e)         29.41
# Grids construction                      17.36
# Exchange-Correlation Term               78.1
# Misc.                                   4.1
# Complete SCF                            164.49
