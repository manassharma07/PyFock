# %% [markdown]
# # Install PyFock and required libraries for benchmarking the acceleration in the XC term evaluation with dynamic precision

# %% [markdown]
# ### Clone latest development version of PyFock from GitHub repo

# %%
# !git clone https://github.com/manassharma07/PyFock.git
# Out:
# Cloning into 'PyFock'...
# remote: Enumerating objects: 6724, done.
# remote: Counting objects: 100% (270/270), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 6724 (delta 141), reused 218 (delta 115), pack-reused 6454 (from 3)
# Receiving objects: 100% (6724/6724), 372.53 MiB | 38.30 MiB/s, done.
# Resolving deltas: 100% (4000/4000), done.
# Updating files: 100% (3620/3620), done.

# %% [markdown]
# ### Install ase and pyscf

# %%
# !pip3 install ase
# !pip3 install pyscf # for generating grids using pyscf
# Out:
# Collecting ase
#   Downloading ase-3.29.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from ase) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from ase) (1.16.3)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.12/dist-packages (from ase) (3.10.0)
# Requirement already satisfied: typing_extensions>=4.13.1 in /usr/local/lib/python3.12/dist-packages (from ase) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->ase) (1.17.0)
# Downloading ase-3.29.0-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 30.5 MB/s eta 0:00:00
# Installing collected packages: ase
# Successfully installed ase-3.29.0
# Collecting pyscf
#   Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.12/dist-packages (from pyscf) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyscf) (1.16.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf) (3.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf) (81.0.0)
# Downloading pyscf-2.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 35.9 MB/s eta 0:00:00
# Installing collected packages: pyscf
# Successfully installed pyscf-2.14.0

# %% [markdown]
# ### Go inside the repo

# %%
import os
os.chdir('PyFock')

# %% [markdown]
# ### and install it using pip

# %%
# !pip3 install .
# Out:
# Processing /kaggle/working/PyFock
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.60.0)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (2.0.2)
# Requirement already satisfied: llvmlite>=0.40.0rc1 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (0.43.0)
# Requirement already satisfied: opt_einsum>=v3.3.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (3.6.0)
# Collecting numgrid (from pyfock==0.1.4)
#   Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pyfock==0.1.4) (5.9.5)
# Downloading numgrid-2.1.2-cp312-cp312-manylinux_2_34_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.0 MB/s eta 0:00:00
# Building wheels for collected packages: pyfock
#   Building wheel for pyfock (setup.py) ... done
#   Created wheel for pyfock: filename=pyfock-0.1.4-py3-none-any.whl size=20330928 sha256=9dd38c67d0f6a7230dd382b524f8d000361e52070d40051d04e8caacaf1efe03
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zw1snzru/wheels/b8/d0/ca/6d432daf38d95a1e34aee145f95b35c8e489dbb9d2b7fbe5fd
# Successfully built pyfock
# Installing collected packages: numgrid, pyfock
# Successfully installed numgrid-2.1.2 pyfock-0.1.4

# %% [markdown]
# ### Go to the benchmark directory

# %%
os.chdir('benchmarks_tests/FINAL_Benchmarks_for_paper')

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 30
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Core H size in GB  0.0002
# done!
# Time taken 15.79 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 14.82 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  6.33
# Time taken to evaluate the square roots needed:  0.11
# Time for significant indices evaluation:  1.8534835719999876
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 8.3 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  6.94
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  39.51 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.8 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 2.5 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.51 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  50.00036147879429
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709562
# Exchange-Correlation Energy      -16.0358927594599
# --------------------------------------------------
# Total Energy                     -93.1568080632572
# --------------------------------------------------
#
#
#
# Energy difference :  93.15680806325719
#
#
# HOMO-LUMO gap: 2.64310792816701 au
# HOMO-LUMO gap: 71.922 eV
#
#
# Time taken for the previous iteration: 6.36 seconds
#
#
#
# Density matrix difference norm:  43.34767137041552
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  49.999994743899805
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4115453709378
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1682339316010
# Coulomb Energy                   501.1198589452455
# Exchange-Correlation Energy      -62.5998011282690
# --------------------------------------------------
# Total Energy                    -340.0652765782369
# --------------------------------------------------
#
#
#
# Energy difference :  246.9084685149797
#
#
# HOMO-LUMO gap: 0.004902711060931486 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.26 seconds
#
#
#
# Density matrix difference norm:  28.612471718852312
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000984028651
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.2969241456572
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2397369785906
# Coulomb Energy                   293.3088657954171
# Exchange-Correlation Energy      -37.4191110537726
# --------------------------------------------------
# Total Energy                    -355.5094553812986
# --------------------------------------------------
#
#
#
# Energy difference :  15.444178803061732
#
#
# HOMO-LUMO gap: 0.04036147698745465 au
# HOMO-LUMO gap: 1.098 eV
#
#
# Time taken for the previous iteration: 0.18 seconds
#
#
#
# Density matrix difference norm:  21.394016787374944
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002252445385
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6809937275436
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8075468458428
# Coulomb Energy                   367.2127830476509
# Exchange-Correlation Energy      -44.5841010136098
# --------------------------------------------------
# Total Energy                    -380.5867878035363
# --------------------------------------------------
#
#
#
# Energy difference :  25.077332422237646
#
#
# HOMO-LUMO gap: 0.018048571143146043 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  5.197480933691112
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000687474082
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2715070703880
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1921352754567
# Coulomb Energy                   364.3533796551110
# Exchange-Correlation Energy      -44.5594485029990
# --------------------------------------------------
# Total Energy                    -378.6274635986958
# --------------------------------------------------
#
#
#
# Energy difference :  1.9593242048404704
#
#
# HOMO-LUMO gap: 0.08493582284763422 au
# HOMO-LUMO gap: 2.311 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  4.779285269953553
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000012877114045
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0032566186580
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1495973180476
# Coulomb Energy                   368.1554971681617
# Exchange-Correlation Energy      -45.0868782881904
# --------------------------------------------------
# Total Energy                    -381.1270633765155
# --------------------------------------------------
#
#
#
# Energy difference :  2.4995997778196966
#
#
# HOMO-LUMO gap: 0.14183855738593065 au
# HOMO-LUMO gap: 3.860 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5205766173115361
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000012120894674
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2731679233304
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4597566990155
# Coulomb Energy                   369.0647619107229
# Exchange-Correlation Energy      -45.1368862216103
# --------------------------------------------------
# Total Energy                    -381.2275584910789
# --------------------------------------------------
#
#
#
# Energy difference :  0.10049511456344362
#
#
# HOMO-LUMO gap: 0.13514723909442236 au
# HOMO-LUMO gap: 3.678 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.33158867782485413
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001166597149
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4678173176831
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1340203774527
# Coulomb Energy                   369.6340156607506
# Exchange-Correlation Energy      -45.2090855965860
# --------------------------------------------------
# Total Energy                    -381.2508898319421
# --------------------------------------------------
#
#
#
# Energy difference :  0.023331340863194328
#
#
# HOMO-LUMO gap: 0.019732057382665744 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.5818251308672289
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000861700551
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9487138110833
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5750117893517
# Coulomb Energy                   374.0898923937916
# Exchange-Correlation Energy      -45.7569321945897
# --------------------------------------------------
# Total Energy                    -381.3827647784062
# --------------------------------------------------
#
#
#
# Energy difference :  0.1318749464641087
#
#
# HOMO-LUMO gap: 0.1260448122148523 au
# HOMO-LUMO gap: 3.430 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.45845496146359976
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000722767309
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1047085524776
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7414598358479
# Coulomb Energy                   377.3880704578903
# Exchange-Correlation Energy      -46.1034837100265
# --------------------------------------------------
# Total Energy                    -381.4206849246423
# --------------------------------------------------
#
#
#
# Energy difference :  0.03792014623610385
#
#
# HOMO-LUMO gap: 0.16627348986151372 au
# HOMO-LUMO gap: 4.525 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.1450688651703624
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000757902089
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6786083358315
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4949573690149
# Coulomb Energy                   377.1736811284812
# Exchange-Correlation Energy      -46.0748895148559
# --------------------------------------------------
# Total Energy                    -381.4268823090678
# --------------------------------------------------
#
#
#
# Energy difference :  0.006197384425490782
#
#
# HOMO-LUMO gap: 0.181260741126397 au
# HOMO-LUMO gap: 4.932 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.05574884999172545
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074251987
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7476716179433
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5456965114325
# Coulomb Energy                   377.1977734128254
# Exchange-Correlation Energy      -46.0810670348480
# --------------------------------------------------
# Total Energy                    -381.4272916844100
# --------------------------------------------------
#
#
#
# Energy difference :  0.0004093753422012014
#
#
# HOMO-LUMO gap: 0.18111025828112523 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.025625306052612245
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503725406
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6799623006527
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5219266114227
# Coulomb Energy                   377.1502888734891
# Exchange-Correlation Energy      -46.0776486461291
# --------------------------------------------------
# Total Energy                    -381.4274184177465
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001267333364580736
#
#
# HOMO-LUMO gap: 0.1806839556568257 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.00843252643419813
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007500354855
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6768926167631
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5137046298629
# Coulomb Energy                   377.1545462611550
# Exchange-Correlation Energy      -46.0767747067598
# --------------------------------------------------
# Total Energy                    -381.4274393883815
# --------------------------------------------------
#
#
#
# Energy difference :  2.0970635034700535e-05
#
#
# HOMO-LUMO gap: 0.18067053575022085 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.001844460003736406
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000750025072
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6731835068119
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5118737736919
# Coulomb Energy                   377.1524231958011
# Exchange-Correlation Energy      -46.0765296383164
# --------------------------------------------------
# Total Energy                    -381.4274391315118
# --------------------------------------------------
#
#
#
# Energy difference :  2.5686972549010534e-07
#
#
# HOMO-LUMO gap: 0.1806459725229298 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.001151141360911518
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074989492
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6776925206480
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5141311789367
# Coulomb Energy                   377.1549870542096
# Exchange-Correlation Energy      -46.0768423766161
# --------------------------------------------------
# Total Energy                    -381.4274396199942
# --------------------------------------------------
#
#
#
# Energy difference :  4.884823852080444e-07
#
#
# HOMO-LUMO gap: 0.18064256438842996 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.00010543279284349652
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007498366266
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6789385081834
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5147700075881
# Coulomb Energy                   377.1556791349420
# Exchange-Correlation Energy      -46.0769272993466
# --------------------------------------------------
# Total Energy                    -381.4274396208763
# --------------------------------------------------
#
#
#
# Energy difference :  8.820961738820188e-10
#
# SCF Converged after 17 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743962087627
# -------------------------------------
#
#
#
# Time taken : 71.32 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           3.01
# Density Fitting                         1.43
#     DF (gamma)                          0.4
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.63
# DIIS                                    0.73
# KS matrix diagonalization               0.81
# One electron Integrals (S, T, Vnuc)     15.79
# Coulomb Integrals (2c2e + 3c2e)         39.51
# Grids construction                      0.8
# Exchange-Correlation Term               5.31
# Misc.                                   3.94
# Complete SCF                            71.32

# %% [markdown]
# ### Benchmark #1 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.09 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.003347473000019363
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.04 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.07
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.53 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.98 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.93 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00135664103418
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371788
# Exchange-Correlation Energy      -32.4188087546116
# --------------------------------------------------
# Total Energy                    -185.4474645300007
# --------------------------------------------------
#
#
#
# Energy difference :  185.44746453000073
#
#
# HOMO-LUMO gap: 1.7654343749557908 au
# HOMO-LUMO gap: 48.040 eV
#
#
# Time taken for the previous iteration: 0.6 seconds
#
#
#
# Density matrix difference norm:  66.88358764205466
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998984084648
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6912217437971
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5301987506066
# Coulomb Energy                  1272.5954275689614
# Exchange-Correlation Energy     -125.2198694441769
# --------------------------------------------------
# Total Energy                    -680.0789187511737
# --------------------------------------------------
#
#
#
# Energy difference :  494.63145422117293
#
#
# HOMO-LUMO gap: 0.000404560567795087 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  39.27522964435253
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00120175844566
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3634692493947
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0866666727048
# Coulomb Energy                   861.6558693046842
# Exchange-Correlation Energy      -75.4419310839600
# --------------------------------------------------
# Total Energy                    -709.3563182387337
# --------------------------------------------------
#
#
#
# Energy difference :  29.277399487560047
#
#
# HOMO-LUMO gap: 0.027815605001193622 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  28.14735856432931
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99992522663976
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8894672036122
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1502170659935
# Coulomb Energy                  1000.6400676118848
# Exchange-Correlation Energy      -87.3507096616607
# --------------------------------------------------
# Total Energy                    -733.7433460701626
# --------------------------------------------------
#
#
#
# Energy difference :  24.387027831428895
#
#
# HOMO-LUMO gap: 0.007352227197396616 au
# HOMO-LUMO gap: 0.200 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  18.10305398307266
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0006055364229
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3444026565180
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2521102957872
# Coulomb Energy                  1039.7254935641763
# Exchange-Correlation Energy      -89.9717584580982
# --------------------------------------------------
# Total Energy                    -689.6320111374207
# --------------------------------------------------
#
#
#
# Energy difference :  44.1113349327419
#
#
# HOMO-LUMO gap: 0.010701793706983154 au
# HOMO-LUMO gap: 0.291 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  13.034260103697125
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00038320576006
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9065022386644
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4515470597366
# Coulomb Energy                  1004.3417767419335
# Exchange-Correlation Energy      -89.2334391642867
# --------------------------------------------------
# Total Energy                    -749.6400714840490
# --------------------------------------------------
#
#
#
# Energy difference :  60.008060346628326
#
#
# HOMO-LUMO gap: 0.025771351287265612 au
# HOMO-LUMO gap: 0.701 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.653358064508543
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00016509554303
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2384132844845
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6363767410348
# Coulomb Energy                   997.3319760641308
# Exchange-Correlation Energy      -89.6717481072339
# --------------------------------------------------
# Total Energy                    -755.2352624693207
# --------------------------------------------------
#
#
#
# Energy difference :  5.595190985271643
#
#
# HOMO-LUMO gap: 0.003568479527134974 au
# HOMO-LUMO gap: 0.097 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.3097383349901035
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00019543567737
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3061.3398204421669
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.6148857162450
# Coulomb Energy                  1009.6464766740896
# Exchange-Correlation Energy      -89.9069114779842
# --------------------------------------------------
# Total Energy                    -755.2788234125846
# --------------------------------------------------
#
#
#
# Energy difference :  0.04356094326396942
#
#
# HOMO-LUMO gap: 0.009175061882956664 au
# HOMO-LUMO gap: 0.250 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  8.057132717495223
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00050300163969
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3098.5145153725616
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   760.8975119321638
# Coulomb Energy                  1035.0050622424615
# Exchange-Correlation Energy      -92.6658378595079
# --------------------------------------------------
# Total Energy                    -747.5712329402127
# --------------------------------------------------
#
#
#
# Energy difference :  7.707590472371976
#
#
# HOMO-LUMO gap: 0.11766237194144735 au
# HOMO-LUMO gap: 3.202 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  7.715013428987715
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99998843306777
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3136.6063903691802
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   773.0711992829854
# Coulomb Energy                  1048.9988443895413
# Exchange-Correlation Energy      -94.9610811404126
# --------------------------------------------------
# Total Energy                    -761.7908817198340
# --------------------------------------------------
#
#
#
# Energy difference :  14.219648779621366
#
#
# HOMO-LUMO gap: 0.010925426636536353 au
# HOMO-LUMO gap: 0.297 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.790315749179786
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99997294377906
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3074.4474412182535
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.6512466860272
# Coulomb Energy                  1013.7508689109064
# Exchange-Correlation Energy      -90.9428726052371
# --------------------------------------------------
# Total Energy                    -756.2816521093249
# --------------------------------------------------
#
#
#
# Energy difference :  5.509229610509124
#
#
# HOMO-LUMO gap: 0.14929732693563497 au
# HOMO-LUMO gap: 4.063 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  6.534633252529055
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000687202663
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.4902716098150
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4820461508918
# Coulomb Energy                  1025.7750806783733
# Exchange-Correlation Energy      -92.2703810887718
# --------------------------------------------------
# Total Energy                    -762.7969797520896
# --------------------------------------------------
#
#
#
# Energy difference :  6.515327642764646
#
#
# HOMO-LUMO gap: 0.13352697868055166 au
# HOMO-LUMO gap: 3.633 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.5338338749000924
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000634332058
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.4590179534143
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.3546792903223
# Coulomb Energy                  1024.7461321399919
# Exchange-Correlation Energy      -92.1885648748866
# --------------------------------------------------
# Total Energy                    -762.8402252807546
# --------------------------------------------------
#
#
#
# Energy difference :  0.04324552866501108
#
#
# HOMO-LUMO gap: 0.11056223799222012 au
# HOMO-LUMO gap: 3.009 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.36027133595901495
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000977916642
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3094.5875590207093
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.4638517295054
# Coulomb Energy                  1023.6379077076228
# Exchange-Correlation Energy      -92.0697499682068
# --------------------------------------------------
# Total Energy                    -762.8490034345562
# --------------------------------------------------
#
#
#
# Energy difference :  0.008778153801586086
#
#
# HOMO-LUMO gap: 0.08600353272305802 au
# HOMO-LUMO gap: 2.340 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.3252988568324093
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000701680047
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.8003240864182
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8941261722476
# Coulomb Energy                  1024.4836887101146
# Exchange-Correlation Energy      -92.1371699397554
# --------------------------------------------------
# Total Energy                    -762.8531330265796
# --------------------------------------------------
#
#
#
# Energy difference :  0.004129592023446094
#
#
# HOMO-LUMO gap: 0.1163608074771787 au
# HOMO-LUMO gap: 3.166 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.15534224621115608
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000743503605
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0406117168568
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0676900055754
# Coulomb Energy                  1024.5663100625939
# Exchange-Correlation Energy      -92.1605267750443
# --------------------------------------------------
# Total Energy                    -762.8605923064997
# --------------------------------------------------
#
#
#
# Energy difference :  0.007459279920112749
#
#
# HOMO-LUMO gap: 0.12269239243705304 au
# HOMO-LUMO gap: 3.339 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.040607112238112954
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000722186562
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2918576080601
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.2001852362613
# Coulomb Energy                  1024.7015706722577
# Exchange-Correlation Energy      -92.1773633390781
# --------------------------------------------------
# Total Energy                    -762.8609189213871
# --------------------------------------------------
#
#
#
# Energy difference :  0.000326614887399046
#
#
# HOMO-LUMO gap: 0.1174291347598585 au
# HOMO-LUMO gap: 3.195 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.01970316353177592
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000007404711
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0385348738364
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722958569389
# Coulomb Energy                  1024.5590092023717
# Exchange-Correlation Energy      -92.1602830990686
# --------------------------------------------------
# Total Energy                    -762.8609667963624
# --------------------------------------------------
#
#
#
# Energy difference :  4.787497528013773e-05
#
#
# HOMO-LUMO gap: 0.11815573488877573 au
# HOMO-LUMO gap: 3.215 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.008211499893876897
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000074316393
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0549130862382
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0810366811711
# Coulomb Energy                  1024.5676148746788
# Exchange-Correlation Energy      -92.1612728329155
# --------------------------------------------------
# Total Energy                    -762.8609882460719
# --------------------------------------------------
#
#
#
# Energy difference :  2.1449709493026603e-05
#
#
# HOMO-LUMO gap: 0.11842571032247592 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.0019148361630203605
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742786602
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0498843971482
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0791335346057
# Coulomb Energy                  1024.5642249369514
# Exchange-Correlation Energy      -92.1610088236026
# --------------------------------------------------
# Total Energy                    -762.8609886319616
# --------------------------------------------------
#
#
#
# Energy difference :  3.8588973438891117e-07
#
#
# HOMO-LUMO gap: 0.11835771606522796 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.0010776396200240298
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741816395
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0562968020449
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0817807743429
# Coulomb Energy                  1024.5683629999348
# Exchange-Correlation Energy      -92.1613819110208
# --------------------------------------------------
# Total Energy                    -762.8609888215560
# --------------------------------------------------
#
#
#
# Energy difference :  1.8959440239996184e-07
#
#
# HOMO-LUMO gap: 0.11837118338566097 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.55 seconds
#
#
#
# Density matrix difference norm:  0.0005041312676847399
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741785558
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0593591158245
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0832977323480
# Coulomb Energy                  1024.5701171428811
# Exchange-Correlation Energy      -92.1615907612842
# --------------------------------------------------
# Total Energy                    -762.8609888846474
# --------------------------------------------------
#
#
#
# Energy difference :  6.309142008831259e-08
#
# SCF Converged after 22 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888846474
# -------------------------------------
#
#
#
# Time taken : 19.14 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.08
# Density Fitting                         0.47
#     DF (gamma)                          0.14
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.21
# DIIS                                    0.12
# KS matrix diagonalization               0.54
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.53
# Grids construction                      0.98
# Exchange-Correlation Term               10.96
# Misc.                                   1.42
# Complete SCF                            19.14

# %% [markdown]
# ### Benchmark #2 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _   _               __               _
# |  _ \ _   _| |_| |__   ___ _ __ / _| ___  _ __ __| |
# | |_) | | | | __| '_ \ / _ \ '__| |_ / _ \| '__/ _` |
# |  _ <| |_| | |_| | | |  __/ |  |  _| (_) | | | (_| |
# |_| \_\\__,_|\__|_| |_|\___|_|  |_|  \___/|_|  \__,_|
# ======================================================================
#
#
#
#                                 ........
#                              ....  .   .,.,,,..
#                          ..      ....,,:,,,::,::,
#                       .,     ....,:::,..,::,::::::,
#                      .,   .....           .,:::;:;;..
#                      :.....                 .......,:,
#                     :,...                       ..:::::
#                     ...                     ....   :::;,
#                     ..                       ...   .::::
#                     ..                        ...  ..;:;
#                    . .                       ....  ..,:;.
#                      .                 ,.    ...,  ...,:.
#                     ,.;-;--:.     :--+--;-;:....:, ....:
#                     ,,.,;++-:    ,**+++;,,,,....,, ....-.
#                      . -++:.,.  .,;:;,:;,;:,.  ..: .,:,:,
#                      .   .      ...       .    ..:.,,:.:;.
#                     ..          ..             ...,,:  ,:.
#                     .            ..           .....,-, .,
#                     .      .    .  ,          .....,:,.,.
#                      .      ,,,;-;.:          .....  .,.
#                      ,    ..::,,;++;.         ....;..,
#                      ..   ,.,.;,,.:-;:,.     ....,+,.
#                       : ..,:;;:,,:;;-;;+;    ....:-.
#                       ..,+**-,,::;--+++++,  ....::;.
#                        ,.,:.  ...........   ...::.;;,
#                         .     .,,,.        ...;,.,:,..
#                         .,                ..,;,.., , .,.
#                           ..            .,,::.,:,  ,    .,..
#                           .,,     ..,,:;;:,,,::,  ..     ,......
#                        ..,. .,.::;;;;;:,,,,::,    ,      ..    .....
#                    .... ..   ,  ...  .,,::,      ,        ,
#                .....   ..    ,.    .,.:,.      .:         ..
#             ...        .     .,..   .::      .,,,          ,
#          ..          ..       -;....  ,    ,,.,:            .
#                               :;:...,.....,;:,:            ..
#                     .         ,. ...     .;, ..        .,.
#                      .        .,    ,   ,-.  ,          ..
#                       .       ...   ,  ,;,  ,            .
#                               ..,   ,..:;   .             ,
#                                 .. ,    :. ,             ,
#
#
#                       :;--+-:;;, ;-;;;;+;--;;---;
#                        .......   ... . .... ....
#
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║         All science is either physics or stamp collecting.           ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                       ~ rutherford   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.23 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.06
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0069853840000178025
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.07 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.29
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  10.47 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.54 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.51 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0012873091312
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355659
# Exchange-Correlation Energy      -66.5470810173854
# --------------------------------------------------
# Total Energy                    -374.9303338973823
# --------------------------------------------------
#
#
#
# Energy difference :  374.9303338973823
#
#
# HOMO-LUMO gap: 1.8502864435404187 au
# HOMO-LUMO gap: 50.349 eV
#
#
# Time taken for the previous iteration: 2.22 seconds
#
#
#
# Density matrix difference norm:  107.82844284432804
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99998558772938
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.1040090066799
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6843391765324
# Coulomb Energy                  3537.3287033060337
# Exchange-Correlation Energy     -250.6110528161994
# --------------------------------------------------
# Total Energy                   -1359.8923755096507
# --------------------------------------------------
#
#
#
# Energy difference :  984.9620416122684
#
#
# HOMO-LUMO gap: 0.002113921644592176 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 2.19 seconds
#
#
#
# Density matrix difference norm:  57.367070219181755
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00092691512907
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4125256492662
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0334810813204
# Coulomb Energy                  2705.3966179575232
# Exchange-Correlation Energy     -151.8752804393584
# --------------------------------------------------
# Total Energy                   -1419.0480632191197
# --------------------------------------------------
#
#
#
# Energy difference :  59.15568770946902
#
#
# HOMO-LUMO gap: 0.019740723740205676 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 2.2 seconds
#
#
#
# Density matrix difference norm:  48.04719016382816
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00017178492396
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8889823851641
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5441892854255
# Coulomb Energy                  3071.8764250117779
# Exchange-Correlation Energy     -174.7460035329337
# --------------------------------------------------
# Total Energy                   -1362.4047277902323
# --------------------------------------------------
#
#
#
# Energy difference :  56.64333542888744
#
#
# HOMO-LUMO gap: 0.014747714724080138 au
# HOMO-LUMO gap: 0.401 eV
#
#
# Time taken for the previous iteration: 2.21 seconds
#
#
#
# Density matrix difference norm:  40.925708282611
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00110096158718
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3305198126163
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1485571581918
# Coulomb Energy                  3051.7165832278761
# Exchange-Correlation Energy     -176.2007428393613
# --------------------------------------------------
# Total Energy                   -1378.8564784352484
# --------------------------------------------------
#
#
#
# Energy difference :  16.45175064501609
#
#
# HOMO-LUMO gap: 0.012539973802255577 au
# HOMO-LUMO gap: 0.341 eV
#
#
# Time taken for the previous iteration: 2.21 seconds
#
#
#
# Density matrix difference norm:  26.93258217222524
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00015253863944
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2741022788396
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7360850555622
# Coulomb Energy                  3003.5375755726222
# Exchange-Correlation Energy     -179.3125720191499
# --------------------------------------------------
# Total Energy                   -1523.5033698391430
# --------------------------------------------------
#
#
#
# Energy difference :  144.64689140389464
#
#
# HOMO-LUMO gap: 0.003087494759884688 au
# HOMO-LUMO gap: 0.084 eV
#
#
# Time taken for the previous iteration: 2.22 seconds
#
#
#
# Density matrix difference norm:  13.423370100266132
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00026803488927
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.3869332567410
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1138671361896
# Coulomb Energy                  2977.4795296019147
# Exchange-Correlation Energy     -178.1026352539894
# --------------------------------------------------
# Total Energy                   -1499.0865279419650
# --------------------------------------------------
#
#
#
# Energy difference :  24.416841897178074
#
#
# HOMO-LUMO gap: 0.03181461272709328 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 2.22 seconds
#
#
#
# Density matrix difference norm:  12.444575042410209
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00011721146524
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4152885443682
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8293462463000
# Coulomb Energy                  3000.9261851727242
# Exchange-Correlation Energy     -180.8962339957917
# --------------------------------------------------
# Total Energy                   -1522.7463472904747
# --------------------------------------------------
#
#
#
# Energy difference :  23.6598193485097
#
#
# HOMO-LUMO gap: 0.012952412901913193 au
# HOMO-LUMO gap: 0.352 eV
#
#
# Time taken for the previous iteration: 2.24 seconds
#
#
#
# Density matrix difference norm:  6.016412544053244
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00012192201388
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5454025156641
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6396516682271
# Coulomb Energy                  3041.7824359801311
# Exchange-Correlation Energy     -185.1339645332821
# --------------------------------------------------
# Total Energy                   -1523.4476355699258
# --------------------------------------------------
#
#
#
# Energy difference :  0.7012882794510915
#
#
# HOMO-LUMO gap: 0.021473549810064885 au
# HOMO-LUMO gap: 0.584 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  6.222751705205543
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.9999594881058
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4503888915788
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5090569992735
# Coulomb Energy                  3063.1248487685098
# Exchange-Correlation Energy     -185.9132949764733
# --------------------------------------------------
# Total Energy                   -1521.9201342696069
# --------------------------------------------------
#
#
#
# Energy difference :  1.5275013003188178
#
#
# HOMO-LUMO gap: 0.07988335372957717 au
# HOMO-LUMO gap: 2.174 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  4.4348485236172435
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000355184671
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5525733681516
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1042444891111
# Coulomb Energy                  3048.3985990983938
# Exchange-Correlation Energy     -185.3448733864920
# --------------------------------------------------
# Total Energy                   -1525.5849593364774
# --------------------------------------------------
#
#
#
# Energy difference :  3.664825066870435
#
#
# HOMO-LUMO gap: 0.11911980736800722 au
# HOMO-LUMO gap: 3.241 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.833513309989695
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000381243773
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9427577372480
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.8990713794374
# Coulomb Energy                  3044.2765927793398
# Exchange-Correlation Energy     -184.7849150214342
# --------------------------------------------------
# Total Energy                   -1525.7423647692422
# --------------------------------------------------
#
#
#
# Energy difference :  0.15740543276479002
#
#
# HOMO-LUMO gap: 0.10914385151709044 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.4378203335993789
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004007733327
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6452238685088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4382999349898
# Coulomb Energy                  3039.9455617680137
# Exchange-Correlation Energy     -184.3161788613749
# --------------------------------------------------
# Total Energy                   -1525.7678971962182
# --------------------------------------------------
#
#
#
# Energy difference :  0.02553242697604219
#
#
# HOMO-LUMO gap: 0.08055636124784533 au
# HOMO-LUMO gap: 2.192 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.2795602287759978
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003853976173
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5737464906397
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0101862116301
# Coulomb Energy                  3041.4914846757179
# Exchange-Correlation Energy     -184.5235703798682
# --------------------------------------------------
# Total Energy                   -1525.7860021524980
# --------------------------------------------------
#
#
#
# Energy difference :  0.018104956279785256
#
#
# HOMO-LUMO gap: 0.03553321190348201 au
# HOMO-LUMO gap: 0.967 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.2018817370079258
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00004068429737
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6198555703650
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7738365258258
# Coulomb Energy                  3040.7248454919477
# Exchange-Correlation Energy     -184.4775892871878
# --------------------------------------------------
# Total Energy                   -1525.7891190091182
# --------------------------------------------------
#
#
#
# Energy difference :  0.003116856620181352
#
#
# HOMO-LUMO gap: 0.04487089486639423 au
# HOMO-LUMO gap: 1.221 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.07625293104682625
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003965723616
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0398379111266
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4147553103774
# Coulomb Energy                  3040.4560830346541
# Exchange-Correlation Energy     -184.4308753791059
# --------------------------------------------------
# Total Energy                   -1525.7902311145394
# --------------------------------------------------
#
#
#
# Energy difference :  0.001112105421270826
#
#
# HOMO-LUMO gap: 0.05285664136839818 au
# HOMO-LUMO gap: 1.438 eV
#
#
# Time taken for the previous iteration: 2.26 seconds
#
#
#
# Density matrix difference norm:  0.02837208362334915
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000394713102
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0334669641716
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4040903980872
# Coulomb Energy                  3040.4602645949813
# Exchange-Correlation Energy     -184.4309026475798
# --------------------------------------------------
# Total Energy                   -1525.7903707880200
# --------------------------------------------------
#
#
#
# Energy difference :  0.00013967348058940843
#
#
# HOMO-LUMO gap: 0.049948127440661294 au
# HOMO-LUMO gap: 1.359 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.01278525124369608
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003968505612
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9503113931551
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3695713318459
# Coulomb Energy                  3040.4067159125902
# Exchange-Correlation Energy     -184.4260067735683
# --------------------------------------------------
# Total Energy                   -1525.7903870916266
# --------------------------------------------------
#
#
#
# Energy difference :  1.630360657145502e-05
#
#
# HOMO-LUMO gap: 0.050833655730579005 au
# HOMO-LUMO gap: 1.383 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.006040021432807614
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003963112016
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0438856954825
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4182519920789
# Coulomb Energy                  3040.4581957845176
# Exchange-Correlation Energy     -184.4326037898912
# --------------------------------------------------
# Total Energy                   -1525.7903978781169
# --------------------------------------------------
#
#
#
# Energy difference :  1.0786490292957751e-05
#
#
# HOMO-LUMO gap: 0.05068603589639145 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.0019655407506146473
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962378534
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0527801127246
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4196320451829
# Coulomb Energy                  3040.4659355248864
# Exchange-Correlation Energy     -184.4328301188945
# --------------------------------------------------
# Total Energy                   -1525.7903988308876
# --------------------------------------------------
#
#
#
# Energy difference :  9.527707334200386e-07
#
#
# HOMO-LUMO gap: 0.050712621256460644 au
# HOMO-LUMO gap: 1.380 eV
#
#
# Time taken for the previous iteration: 2.27 seconds
#
#
#
# Density matrix difference norm:  0.0010394322843813154
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961780368
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0603466447146
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4235272610863
# Coulomb Energy                  3040.4701320976001
# Exchange-Correlation Energy     -184.4333553536714
# --------------------------------------------------
# Total Energy                   -1525.7903988090384
# --------------------------------------------------
#
#
#
# Energy difference :  2.184924596804194e-08
#
# SCF Converged after 21 iterations!
#
# -------------------------------------
# Total Energy =  -1525.7903988090384
# -------------------------------------
#
#
#
# Time taken : 72.18 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.68
# Density Fitting                         1.29
#     DF (gamma)                          0.28
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.82
# DIIS                                    0.57
# KS matrix diagonalization               1.03
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         10.47
# Grids construction                      4.54
# Exchange-Correlation Term               43.95
# Misc.                                   2.57
# Complete SCF                            72.18

# %% [markdown]
# ### Benchmark #3 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = False
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____  _
# |  _ \(_)_ __ __ _  ___
# | | | | | '__/ _` |/ __|
# | |_| | | | | (_| | (__
# |____/|_|_|  \__,_|\___|
# ======================================================================
#
#
#              ..,.,,.,,,,,,......         ,-
#           ..,,::::::,,,,,::;:,,,:,       ,-
#          .,:::::,,,....,,,,::,.,::,.     ,-
#        ,:;::,:;:,::,,,,,,,,,..,:-:;;     .-
#      .,:;::;:,,,::;:,,,;,,:,..,:;;::;    .+
#     :,:::::;---::;-+::::+::;..,:--::;,   .%
#    ,::::::::;;,,...;-;:;;+;:..;::.,--:.. .?
#    ,:::::::,.       .,,::::,..,.   .;;, .,*
#    :::::;;,                          :+, ,+
#    ::::-;                             ,-,:*
#    ;;:;-.                              :--?
#    ;;:;:                                ;+?
#    ::--,                                .+*
#    ;-+:.                                 -?
#    :;:,                                  ;*
#    :;::,.                                -*
#    ;;;;;,      .,;;:-;:,.           .,,, ;*
#    ::::;       .. .:-??*?;.     .;+**;,, ,*
#    --;;-        .:-+++--;;,    ,-**+;;: .;*
#    .,;:-.      .,,;??;,;,,.   .++;*%*:;..:+
#    . ,;;.          .. ...      ,,.,,.   ,,+
#    :;                ..        ....     ,,-
#    ..                           ,       ,,-
#                                  .      ,.-
#                         .        .      ..-
#    .                    .,:-;:,:::.    ...+
#    .,;:,                 ,::,,;-;.     , ,+
#     .:.:             .,,,;-;-++--::.   , ,-
#    ,.:  ,            :;:,,::,,,,,,::  ,. ,-
#    . ,  .,           ,:::::::::,,,.   ,  ,-
#     .:,  ,:.              ..,,,,.    ,.  ,-
#      ,..  .:,.            ,;;;;,    ..   ,-
#      : ,    ,,,.                   ,.    ,-
#      ,. .    ......               ,....  ,-
#      .,  ,.   ....::,.       .  .,.   ..,:-
#       .,   .  .......,:::::,::::,        ,-
#        ,    ..  ..........:,,            ,+
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║       God used beautiful mathematics in creating the world.          ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                            ~ dirac   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.14 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.49 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.09
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.01740814900000487
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.11 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.66
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  28.16 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 16.3 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 21.21 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.42 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0029198407821
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004625
# Exchange-Correlation Energy     -107.4038004276163
# --------------------------------------------------
# Total Energy                    -601.1785356513683
# --------------------------------------------------
#
#
#
# Energy difference :  601.1785356513683
#
#
# HOMO-LUMO gap: 1.3453174761627253 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 5.39 seconds
#
#
#
# Density matrix difference norm:  144.01406386863016
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.999967207153
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17398.0013016247904
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.4110642081268
# Coulomb Energy                  7102.4006978647176
# Exchange-Correlation Energy     -401.0386878050853
# --------------------------------------------------
# Total Energy                   -2175.7881061964163
# --------------------------------------------------
#
#
#
# Energy difference :  1574.609570545048
#
#
# HOMO-LUMO gap: 0.0036326528166095162 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 5.43 seconds
#
#
#
# Density matrix difference norm:  71.99427239658158
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0023851247207
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8416645632387
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0272704936767
# Coulomb Energy                  5771.7138319761934
# Exchange-Correlation Energy     -243.8524720617004
# --------------------------------------------------
# Total Energy                   -2274.5129129944553
# --------------------------------------------------
#
#
#
# Energy difference :  98.72480679803903
#
#
# HOMO-LUMO gap: 0.004964611535091618 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 5.46 seconds
#
#
#
# Density matrix difference norm:  58.10070148972918
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0021440415607
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5190804036865
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2649573469303
# Coulomb Energy                  6321.7172809536978
# Exchange-Correlation Energy     -278.3781618573335
# --------------------------------------------------
# Total Energy                   -2158.4748827997782
# --------------------------------------------------
#
#
#
# Energy difference :  116.03803019467705
#
#
# HOMO-LUMO gap: 0.014474030561845763 au
# HOMO-LUMO gap: 0.394 eV
#
#
# Time taken for the previous iteration: 5.53 seconds
#
#
#
# Density matrix difference norm:  53.36997549239289
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0018076772095
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5172768209668
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2229230006305
# Coulomb Energy                  6361.2336350668602
# Exchange-Correlation Energy     -281.9436333440966
# --------------------------------------------------
# Total Energy                   -2182.5642309369587
# --------------------------------------------------
#
#
#
# Energy difference :  24.089348137180423
#
#
# HOMO-LUMO gap: 0.008841693995181782 au
# HOMO-LUMO gap: 0.241 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  42.8390150948738
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00099084148957
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.2679446995080
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.4865382080516
# Coulomb Energy                  6294.5110601801080
# Exchange-Correlation Energy     -283.9707682331629
# --------------------------------------------------
# Total Energy                   -2345.8009933838966
# --------------------------------------------------
#
#
#
# Energy difference :  163.23676244693797
#
#
# HOMO-LUMO gap: 0.007160714252010758 au
# HOMO-LUMO gap: 0.195 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  32.18186260037927
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9997863855179
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.1605019077851
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.6791650760802
# Coulomb Energy                  6214.1516556245242
# Exchange-Correlation Energy     -284.6344014151254
# --------------------------------------------------
# Total Energy                   -2343.5239614616912
# --------------------------------------------------
#
#
#
# Energy difference :  2.277031922205424
#
#
# HOMO-LUMO gap: 0.002450375010392858 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  33.32333313978321
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00086081565127
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4825115035183
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2355.9857996833534
# Coulomb Energy                  6284.6237009938905
# Exchange-Correlation Energy     -286.3084442723599
# --------------------------------------------------
# Total Energy                   -2352.7413339380182
# --------------------------------------------------
#
#
#
# Energy difference :  9.217372476327
#
#
# HOMO-LUMO gap: 0.0066733184121238465 au
# HOMO-LUMO gap: 0.182 eV
#
#
# Time taken for the previous iteration: 5.63 seconds
#
#
#
# Density matrix difference norm:  26.098281915701786
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026797845874
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.0487383670261
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.1820896551362
# Coulomb Energy                  6418.8046173126513
# Exchange-Correlation Energy     -305.3162932885706
# --------------------------------------------------
# Total Energy                   -2410.9382035271956
# --------------------------------------------------
#
#
#
# Energy difference :  58.19686958917737
#
#
# HOMO-LUMO gap: 0.007960539573559133 au
# HOMO-LUMO gap: 0.217 eV
#
#
# Time taken for the previous iteration: 5.61 seconds
#
#
#
# Density matrix difference norm:  17.53469864236444
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00025283855103
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.6331057250227
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.6376201852177
# Coulomb Energy                  6329.9135850849189
# Exchange-Correlation Energy     -297.7524519057237
# --------------------------------------------------
# Total Energy                   -2373.3942311999954
# --------------------------------------------------
#
#
#
# Energy difference :  37.54397232720021
#
#
# HOMO-LUMO gap: 0.013997838576895169 au
# HOMO-LUMO gap: 0.381 eV
#
#
# Time taken for the previous iteration: 5.61 seconds
#
#
#
# Density matrix difference norm:  16.42070464487425
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998237983229
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.8989814627039
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.5608928322699
# Coulomb Energy                  6324.0705156567647
# Exchange-Correlation Energy     -296.6169927422070
# --------------------------------------------------
# Total Energy                   -2423.4444445552626
# --------------------------------------------------
#
#
#
# Energy difference :  50.05021335526726
#
#
# HOMO-LUMO gap: 0.0058017168956708415 au
# HOMO-LUMO gap: 0.158 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  17.913629073720625
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0008255772793
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.3834871576801
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.2826553245100
# Coulomb Energy                  6269.4959589831506
# Exchange-Correlation Energy     -292.3687260433993
# --------------------------------------------------
# Total Energy                   -2388.5334777328044
# --------------------------------------------------
#
#
#
# Energy difference :  34.91096682245825
#
#
# HOMO-LUMO gap: 0.01173972465252425 au
# HOMO-LUMO gap: 0.319 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  18.86481092851746
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00089534288884
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4270999714045
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.9315986960187
# Coulomb Energy                  6304.9912271465128
# Exchange-Correlation Energy     -292.7049362975951
# --------------------------------------------------
# Total Energy                   -2419.7690892658538
# --------------------------------------------------
#
#
#
# Energy difference :  31.23561153304945
#
#
# HOMO-LUMO gap: 0.001699592576632561 au
# HOMO-LUMO gap: 0.046 eV
#
#
# Time taken for the previous iteration: 5.55 seconds
#
#
#
# Density matrix difference norm:  14.268938601955236
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015431500503
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15907.3124930548001
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.9536204723281
# Coulomb Energy                  6279.2250589616306
# Exchange-Correlation Energy     -293.0502585449573
# --------------------------------------------------
# Total Energy                   -2419.7439510051845
# --------------------------------------------------
#
#
#
# Energy difference :  0.025138260669336887
#
#
# HOMO-LUMO gap: 0.005846431225599524 au
# HOMO-LUMO gap: 0.159 eV
#
#
# Time taken for the previous iteration: 5.53 seconds
#
#
#
# Density matrix difference norm:  12.512861011155138
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026512183956
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.7539104152238
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2408.9968140348460
# Coulomb Energy                  6304.4543925172329
# Exchange-Correlation Energy     -294.2073055525171
# --------------------------------------------------
# Total Energy                   -2431.0698882550478
# --------------------------------------------------
#
#
#
# Energy difference :  11.325937249863273
#
#
# HOMO-LUMO gap: 0.016452349569539976 au
# HOMO-LUMO gap: 0.448 eV
#
#
# Time taken for the previous iteration: 5.54 seconds
#
#
#
# Density matrix difference norm:  10.31313944448499
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99991599775205
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15981.3818763844538
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2429.9837614194062
# Coulomb Energy                  6320.4324015787315
# Exchange-Correlation Energy     -296.9899338051731
# --------------------------------------------------
# Total Energy                   -2429.5155260308748
# --------------------------------------------------
#
#
#
# Energy difference :  1.554362224173019
#
#
# HOMO-LUMO gap: 0.005064351076870782 au
# HOMO-LUMO gap: 0.138 eV
#
#
# Time taken for the previous iteration: 5.54 seconds
#
#
#
# Density matrix difference norm:  8.084972669680084
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00009764058933
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15979.9037466533227
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2423.9076611222281
# Coulomb Energy                  6316.3510406949645
# Exchange-Correlation Energy     -296.7435745387263
# --------------------------------------------------
# Total Energy                   -2437.9484982142421
# --------------------------------------------------
#
#
#
# Energy difference :  8.432972183367383
#
#
# HOMO-LUMO gap: 0.058930388783553195 au
# HOMO-LUMO gap: 1.604 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  4.102604850164073
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011810611755
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.2611030005373
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5357451739387
# Coulomb Energy                  6313.1881517244401
# Exchange-Correlation Energy     -295.9055099897936
# --------------------------------------------------
# Total Energy                   -2441.0025949313385
# --------------------------------------------------
#
#
#
# Energy difference :  3.0540967170963995
#
#
# HOMO-LUMO gap: 0.0053372504429227835 au
# HOMO-LUMO gap: 0.145 eV
#
#
# Time taken for the previous iteration: 5.55 seconds
#
#
#
# Density matrix difference norm:  6.2540764810644225
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012361986995
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15923.8925051639526
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2401.3099545140817
# Coulomb Energy                  6280.4277633847223
# Exchange-Correlation Energy     -293.2139724472630
# --------------------------------------------------
# Total Energy                   -2436.9286385517980
# --------------------------------------------------
#
#
#
# Energy difference :  4.073956379540505
#
#
# HOMO-LUMO gap: 0.011871839843087095 au
# HOMO-LUMO gap: 0.323 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  7.413375411112839
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00026335587467
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15947.6726554957968
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2405.4323918856330
# Coulomb Energy                  6298.7681987413471
# Exchange-Correlation Energy     -294.0996241350106
# --------------------------------------------------
# Total Energy                   -2439.1315678432129
# --------------------------------------------------
#
#
#
# Energy difference :  2.2029292914148755
#
#
# HOMO-LUMO gap: 0.10362999794803321 au
# HOMO-LUMO gap: 2.820 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  4.188397589732935
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001162436132
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.6634485017275
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.5876696461046
# Coulomb Energy                  6305.6013415986818
# Exchange-Correlation Energy     -295.1700654130163
# --------------------------------------------------
# Total Energy                   -2441.2043815093439
# --------------------------------------------------
#
#
#
# Energy difference :  2.072813666130969
#
#
# HOMO-LUMO gap: 0.03035834740787703 au
# HOMO-LUMO gap: 0.826 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  1.088118680098876
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00010584350065
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15961.8547355853407
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.9705042573109
# Coulomb Energy                  6306.4146008191283
# Exchange-Correlation Energy     -295.1986114171364
# --------------------------------------------------
# Total Energy                   -2441.2281207654223
# --------------------------------------------------
#
#
#
# Energy difference :  0.02373925607844285
#
#
# HOMO-LUMO gap: 0.10156738658912144 au
# HOMO-LUMO gap: 2.764 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  0.6147083203735785
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000113864789
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2470391409861
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1948706636954
# Coulomb Energy                  6305.3788664342392
# Exchange-Correlation Energy     -295.1059315048823
# --------------------------------------------------
# Total Energy                   -2441.3391123873189
# --------------------------------------------------
#
#
#
# Energy difference :  0.11099162189657363
#
#
# HOMO-LUMO gap: 0.12914420511563332 au
# HOMO-LUMO gap: 3.514 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  0.22866753084109212
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011297097166
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15962.2680215975306
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.2517454853937
# Coulomb Energy                  6306.4753103331514
# Exchange-Correlation Energy     -295.2425453763108
# --------------------------------------------------
# Total Energy                   -2441.3433899946831
# --------------------------------------------------
#
#
#
# Energy difference :  0.004277607364201685
#
#
# HOMO-LUMO gap: 0.11914092717051333 au
# HOMO-LUMO gap: 3.242 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  0.13316828791646526
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011442924006
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.4637663332724
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.3557009440547
# Coulomb Energy                  6305.4375957440607
# Exchange-Correlation Energy     -295.1178679620688
# --------------------------------------------------
# Total Energy                   -2441.3482164466095
# --------------------------------------------------
#
#
#
# Energy difference :  0.004826451926419395
#
#
# HOMO-LUMO gap: 0.07758609961453453 au
# HOMO-LUMO gap: 2.111 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  0.16794684441615856
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011918273236
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.6944810451660
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4450356940606
# Coulomb Energy                  6304.4474550020313
# Exchange-Correlation Energy     -294.9863691581973
# --------------------------------------------------
# Total Energy                   -2441.3482383466562
# --------------------------------------------------
#
#
#
# Energy difference :  2.190004670410417e-05
#
#
# HOMO-LUMO gap: 0.08220407415987623 au
# HOMO-LUMO gap: 2.237 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  0.08195634558059847
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001176128904
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.2173560670562
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2597184232150
# Coulomb Energy                  6305.2666287324482
# Exchange-Correlation Energy     -295.0991774795672
# --------------------------------------------------
# Total Energy                   -2441.3500652303464
# --------------------------------------------------
#
#
#
# Energy difference :  0.0018268836902279872
#
#
# HOMO-LUMO gap: 0.086813932476389 au
# HOMO-LUMO gap: 2.362 eV
#
#
# Time taken for the previous iteration: 5.57 seconds
#
#
#
# Density matrix difference norm:  0.03094765004868834
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171711136
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0798449608028
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1777969466320
# Coulomb Energy                  6305.1999901383797
# Exchange-Correlation Energy     -295.0882138897798
# --------------------------------------------------
# Total Energy                   -2441.3501506049552
# --------------------------------------------------
#
#
#
# Energy difference :  8.537460871593794e-05
#
#
# HOMO-LUMO gap: 0.08605512219093304 au
# HOMO-LUMO gap: 2.342 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  0.01535942013793622
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174124386
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0219082985441
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1555754508140
# Coulomb Energy                  6305.1611656009291
# Exchange-Correlation Energy     -295.0851653175688
# --------------------------------------------------
# Total Energy                   -2441.3502114037556
# --------------------------------------------------
#
#
#
# Energy difference :  6.079880040488206e-05
#
#
# HOMO-LUMO gap: 0.08610559555008832 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  0.005850728287680341
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730802635
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0394341357369
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1610624063997
# Coulomb Energy                  6305.1739654234298
# Exchange-Correlation Energy     -295.0859344062346
# --------------------------------------------------
# Total Energy                   -2441.3502195515266
# --------------------------------------------------
#
#
#
# Energy difference :  8.1477710409672e-06
#
#
# HOMO-LUMO gap: 0.08627753380301659 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  0.0022687655686156796
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173037932
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0443171301886
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1634927318910
# Coulomb Energy                  6305.1767750460131
# Exchange-Correlation Energy     -295.0862921108220
# --------------------------------------------------
# Total Energy                   -2441.3502203024927
# --------------------------------------------------
#
#
#
# Energy difference :  7.509661372750998e-07
#
#
# HOMO-LUMO gap: 0.0862995467434936 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  0.0014216232818636788
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173161183
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0279335501018
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1548841015838
# Coulomb Energy                  6305.1678310988900
# Exchange-Correlation Energy     -295.0851232567580
# --------------------------------------------------
# Total Energy                   -2441.3502204457709
# --------------------------------------------------
#
#
#
# Energy difference :  1.4327815733850002e-07
#
#
# HOMO-LUMO gap: 0.08625864034201014 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  0.0007905213667356108
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173192669
#
#
#
# ------Iteration 33--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0345906319508
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1581993598793
# Coulomb Energy                  6305.1716231999044
# Exchange-Correlation Energy     -295.0855737005022
# --------------------------------------------------
# Total Energy                   -2441.3502206120547
# --------------------------------------------------
#
#
#
# Energy difference :  1.6628382581984624e-07
#
#
# HOMO-LUMO gap: 0.0862685354451696 au
# HOMO-LUMO gap: 2.347 eV
#
#
# Time taken for the previous iteration: 5.56 seconds
#
#
#
# Density matrix difference norm:  0.0002863202172580288
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011731389475
#
#
#
# ------Iteration 34--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0392851890247
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1608651371143
# Coulomb Energy                  6305.1740152928269
# Exchange-Correlation Energy     -295.0859370217358
# --------------------------------------------------
# Total Energy                   -2441.3502206202065
# --------------------------------------------------
#
#
#
# Energy difference :  8.151801011990756e-09
#
# SCF Converged after 34 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206202065
# -------------------------------------
#
#
#
# Time taken : 259.51 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.63
# Density Fitting                         5.51
#     DF (gamma)                          1.06
#     DF (coeff)                          0.16
#     DF (Jtri)                           3.89
# DIIS                                    3.76
# KS matrix diagonalization               3.79
# One electron Integrals (S, T, Vnuc)     0.14
# Coulomb Integrals (2c2e + 3c2e)         28.16
# Grids construction                      16.3
# Exchange-Correlation Term               175.55
# Misc.                                   4.68
# Complete SCF                            259.51

# %% [markdown]
# ## Dynamic Precision Off

# %% [markdown]
# ### Warm up run Water_5 (H2O_5)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_5.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  15
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  125
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  425
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0002
# done!
# Time taken 0.03 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.03 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.01
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0007749689999627662
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.000189008
# No. of elements in the standard three-centered two electron ERI tensor:  6640625
# No. of elements in the triangular three-centered two electron ERI tensor:  3346875
# No. of significant triplets based on Schwarz inequality and triangularity: 2001750 or 30.1% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.02 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 48 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.04
# Two Center Two electron ERI size in GB  0.001445
# Three Center Two electron ERI size in GB  0.016014
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  0.82 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 0.31 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 0.56 seconds.
#
#
# Deleted 19719 grid points.
#
# No. of supplied/generated grid points (after pruning):  148777
# Size (in GB) for storing the coordinates of grid:       0.004
# Size (in GB) for storing the weights of grid:           0.001
# Size (in GB) for storing the density at gridpoints:     0.001
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  8
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.05 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    110
# Average no. of basis functions contributing to a batch of grid points:    87
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000355
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy         -514.1344354091849
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                    24.8556156903078
# Coulomb Energy                   223.4999273709563
# Exchange-Correlation Energy      -16.0363502502441
# --------------------------------------------------
# Total Energy                     -93.1572655540413
# --------------------------------------------------
#
#
#
# Energy difference :  93.15726555404135
#
#
# HOMO-LUMO gap: 2.643230893268255 au
# HOMO-LUMO gap: 71.926 eV
#
#
# Time taken for the previous iteration: 4.16 seconds
#
#
#
# Density matrix difference norm:  43.34737695041908
#
#
#
#
#
# XC algo 3
# Number of electrons:  49.999992
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1501.4065134268094
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   534.1632901411591
# Coulomb Energy                   501.1179499873581
# Exchange-Correlation Energy      -62.5998153686523
# --------------------------------------------------
# Total Energy                    -340.0671116228211
# --------------------------------------------------
#
#
#
# Energy difference :  246.90984606877979
#
#
# HOMO-LUMO gap: 0.004895001056111847 au
# HOMO-LUMO gap: 0.133 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  28.612251378321993
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  50.000107
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1116.3015434342635
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   316.2404486356294
# Coulomb Energy                   293.3105327789852
# Exchange-Correlation Energy      -37.4191284179688
# --------------------------------------------------
# Total Energy                    -355.5117133934941
# --------------------------------------------------
#
#
#
# Energy difference :  15.444601770672989
#
#
# HOMO-LUMO gap: 0.04090611597191432 au
# HOMO-LUMO gap: 1.113 eV
#
#
# Time taken for the previous iteration: 0.13 seconds
#
#
#
# Density matrix difference norm:  21.394380435698572
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00003
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1253.6802048745037
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   361.8079158470831
# Coulomb Energy                   367.2116081156570
# Exchange-Correlation Energy      -44.5831108093262
# --------------------------------------------------
# Total Energy                    -380.5858146769662
# --------------------------------------------------
#
#
#
# Energy difference :  25.07410128347209
#
#
# HOMO-LUMO gap: 0.018045819534088705 au
# HOMO-LUMO gap: 0.491 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  5.193655309001722
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000008
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1254.2853211394679
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   367.1987312449297
# Coulomb Energy                   364.3594842204068
# Exchange-Correlation Energy      -44.5593338012695
# --------------------------------------------------
# Total Energy                    -378.6284624312774
# --------------------------------------------------
#
#
#
# Energy difference :  1.95735224568881
#
#
# HOMO-LUMO gap: 0.08497506224154416 au
# HOMO-LUMO gap: 2.312 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  4.776044383072403
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000023
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1262.0113353911170
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.1536993637387
# Coulomb Energy                   368.1595786044496
# Exchange-Correlation Energy      -45.0864906311035
# --------------------------------------------------
# Total Energy                    -381.1265710099087
# --------------------------------------------------
#
#
#
# Energy difference :  2.4981085786312747
#
#
# HOMO-LUMO gap: 0.14153440093888509 au
# HOMO-LUMO gap: 3.851 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5199018206077006
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1263.2759870186460
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   369.4620529814741
# Coulomb Energy                   369.0651872518613
# Exchange-Correlation Energy      -45.1361846923828
# --------------------------------------------------
# Total Energy                    -381.2269544335699
# --------------------------------------------------
#
#
#
# Energy difference :  0.10038342366124198
#
#
# HOMO-LUMO gap: 0.13505793051912848 au
# HOMO-LUMO gap: 3.675 eV
#
#
# Time taken for the previous iteration: 0.11 seconds
#
#
#
# Density matrix difference norm:  0.33141822112862707
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00002
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1264.4685883045931
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   370.1352932575581
# Coulomb Energy                   369.6332915647571
# Exchange-Correlation Energy      -45.2082252502441
# --------------------------------------------------
# Total Energy                    -381.2502516883986
# --------------------------------------------------
#
#
#
# Energy difference :  0.02329725482871936
#
#
# HOMO-LUMO gap: 0.019481120474638833 au
# HOMO-LUMO gap: 0.530 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.5819574011085011
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1272.9471076686407
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   374.5753380205153
# Coulomb Energy                   374.0875565365495
# Exchange-Correlation Energy      -45.7558250427246
# --------------------------------------------------
# Total Energy                    -381.3820611101769
# --------------------------------------------------
#
#
#
# Energy difference :  0.13180942177831412
#
#
# HOMO-LUMO gap: 0.12602028669898205 au
# HOMO-LUMO gap: 3.429 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.45972397759417805
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1278.1167311182683
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.7482981739331
# Coulomb Energy                   377.3936785488426
# Exchange-Correlation Energy      -46.1032257080078
# --------------------------------------------------
# Total Energy                    -381.4200030593769
# --------------------------------------------------
#
#
#
# Energy difference :  0.03794194919993288
#
#
# HOMO-LUMO gap: 0.1661133305344462 au
# HOMO-LUMO gap: 4.520 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.1450667025879913
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6774115562357
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.4957003907874
# Coulomb Energy                   377.1713417801332
# Exchange-Correlation Energy      -46.0737915039062
# --------------------------------------------------
# Total Energy                    -381.4261838450980
# --------------------------------------------------
#
#
#
# Energy difference :  0.006180785721085158
#
#
# HOMO-LUMO gap: 0.18109750595334842 au
# HOMO-LUMO gap: 4.928 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.055970387856940765
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00001
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.7466991731337
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5465057500087
# Coulomb Energy                   377.1955793525923
# Exchange-Correlation Energy      -46.0799674987793
# --------------------------------------------------
# Total Energy                    -381.4266045251885
# --------------------------------------------------
#
#
#
# Energy difference :  0.00042068009048534805
#
#
# HOMO-LUMO gap: 0.18093185638010162 au
# HOMO-LUMO gap: 4.923 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.025624539781025833
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6791043635617
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5228770244493
# Coulomb Energy                   377.1480814133143
# Exchange-Correlation Energy      -46.0765609741211
# --------------------------------------------------
# Total Energy                    -381.4267298557956
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012533060714758903
#
# Switching to double precision for XC evaluation after 13 iterations!
#
#
# HOMO-LUMO gap: 0.18050730665208045 au
# HOMO-LUMO gap: 4.912 eV
#
#
# Time taken for the previous iteration: 0.12 seconds
#
#
#
# Density matrix difference norm:  0.008410601201020853
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749481868
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6758646249928
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5145535863805
# Coulomb Energy                   377.1522588566479
# Exchange-Correlation Energy      -46.0763604882691
# --------------------------------------------------
# Total Energy                    -381.4274356261099
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007057703142550054
#
#
# HOMO-LUMO gap: 0.1805594177466545 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0026418714067102866
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007503209495
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6547069029666
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5032889737157
# Coulomb Energy                   377.1410365648654
# Exchange-Correlation Energy      -46.0750325767571
# --------------------------------------------------
# Total Energy                    -381.4274368970192
# --------------------------------------------------
#
#
#
# Energy difference :  1.2709093084595224e-06
#
#
# HOMO-LUMO gap: 0.18056583448655875 au
# HOMO-LUMO gap: 4.913 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0017678391938500799
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749795146
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6715784380226
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5117381337692
# Coulomb Energy                   377.1506250231089
# Exchange-Correlation Energy      -46.0761996769600
# --------------------------------------------------
# Total Energy                    -381.4274379139810
# --------------------------------------------------
#
#
#
# Energy difference :  1.0169617894462135e-06
#
#
# HOMO-LUMO gap: 0.18057810005497435 au
# HOMO-LUMO gap: 4.914 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.0018263944810032189
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.0000074943385
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6890954308308
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5201163633865
# Coulomb Energy                   377.1610739046091
# Exchange-Correlation Energy      -46.0775109642909
# --------------------------------------------------
# Total Energy                    -381.4274390830026
# --------------------------------------------------
#
#
#
# Energy difference :  1.1690216865645198e-06
#
#
# HOMO-LUMO gap: 0.18069051721660845 au
# HOMO-LUMO gap: 4.917 eV
#
#
# Time taken for the previous iteration: 0.17 seconds
#
#
#
# Density matrix difference norm:  0.001507822860003074
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.00000749797098
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6793142630920
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5150718660104
# Coulomb Energy                   377.1557642489249
# Exchange-Correlation Energy      -46.0769384584162
# --------------------------------------------------
# Total Energy                    -381.4274395624493
# --------------------------------------------------
#
#
#
# Energy difference :  4.794466690327681e-07
#
#
# HOMO-LUMO gap: 0.18064424248414906 au
# HOMO-LUMO gap: 4.916 eV
#
#
# Time taken for the previous iteration: 0.16 seconds
#
#
#
# Density matrix difference norm:  0.0004667166779405766
#
#
#
#
#
# XC algo 3
# Number of electrons:  50.000007498303724
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1277.6779995819634
# Nuclear repulsion Energy         188.6579770441236
# Kinetic Energy                   376.5143900979587
# Coulomb Energy                   377.1550630969090
# Exchange-Correlation Energy      -46.0768702751827
# --------------------------------------------------
# Total Energy                    -381.4274396181549
# --------------------------------------------------
#
#
#
# Energy difference :  5.570564098889008e-08
#
# SCF Converged after 19 iterations!
#
# -------------------------------------
# Total Energy =  -381.42743961815495
# -------------------------------------
#
#
#
# Time taken : 9.01 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           0.61
# Density Fitting                         0.22
#     DF (gamma)                          0.07
#     DF (coeff)                          0.06
#     DF (Jtri)                           0.08
# DIIS                                    0.1
# KS matrix diagonalization               0.36
# One electron Integrals (S, T, Vnuc)     0.03
# Coulomb Integrals (2c2e + 3c2e)         0.82
# Grids construction                      0.31
# Exchange-Correlation Term               5.61
# Misc.                                   0.95
# Complete SCF                            9.01

# %% [markdown]
# ### Benchmark #4 Water_10 (H2O_10)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_10.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____       _
# | __ )  ___| |__  _ __
# |  _ \ / _ \ '_ \| '__|
# | |_) | (_) | | | | |
# |____/ \___/|_| |_|_|
# ======================================================================
#
#
#
#                                   .,   ......
#                              ..,,..,., ,,.,.,,,,..
#                            ,:,. ..., ,. ,.,., .,:,,...
#                          .,,.    .,   .,,,..,,,..,.,,:
#                        .,,,..,... .. .. .. ....,,,....,.
#                      .,,....,,.       .       ..,,,,,,,,.
#                      ::,   ..                      .,.,,:,
#                     ;,,.....                         .,,,:,
#                     :,,:,.                            ,,:::
#                     :::,,                             .:,::.
#                     ;,,. .                             ,,:;;
#                     ,..,,.                           ..::::,
#                    ..,.. ...                         ..,:::.
#                     ,.......           .       ..     ..::,
#                     .  .,,:.   .,...,:;;::,   .;+::::::,:,.
#                     .....,.    . .,:;::,...  .-:-+++;,..:;,,
#                    ..:...:,     .:::;:.:.    .-;:::,,;,..::,.
#                    ,,, . ,,     .   .  .      ,,      ...:.,.
#                    .,.  ,             .       .:     .  .,,,
#                     ,. ,                       ..       .::
#                      ..                         ,      .,,,
#                       ,                 .      ,;:      ::.
#                        ,  .              .;:.,:-;,    ..,
#                          ...                ..,,.      .,
#                            .                .         ..,
#                            ,           ..,,,,,:;::,.  .,,
#                           .,.        .:,,,..,,..,,,.  .,
#                           ....               ...,... .,.
#                        ., ..  ..           .,,,,.....,
#                      .,.   ,    ,                 .,,
#                    ...     ..      .            ..::..
#                  ...        ,.             .....,;:., ..,...
#                .     .        ,         .,,,..,;;. .,    .. .
#            .                  ..           .:::.   .,          ..
#                                 ,           ;:,.   .,               .
#                                  ,.        .. .:,  .,
#                                   ..      .,   ,: ..,
#                                    ,      ,....,,., ..
#                                     ,.     .,  .:   .,
#                                            .    .    .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║  An expert is a person who has made all the mistakes that can be     ║
#    ║                    made in a very narrow field.                      ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                             ~ bohr   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  30
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  250
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  850
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.001
# done!
# Time taken 0.04 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.09 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.03
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.00203903299996
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.0007530079999999999
# No. of elements in the standard three-centered two electron ERI tensor:  53125000
# No. of elements in the triangular three-centered two electron ERI tensor:  26668750
# No. of significant triplets based on Schwarz inequality and triangularity: 11252300 or 21.2% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.03 seconds.
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 64 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.07
# Two Center Two electron ERI size in GB  0.00578
# Three Center Two electron ERI size in GB  0.0900184
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  2.72 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 1.0 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 1.86 seconds.
#
#
# Deleted 46774 grid points.
#
# No. of supplied/generated grid points (after pruning):  290210
# Size (in GB) for storing the coordinates of grid:       0.007
# Size (in GB) for storing the weights of grid:           0.002
# Size (in GB) for storing the density at gridpoints:     0.002
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  15
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.14 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    225
# Average no. of basis functions contributing to a batch of grid points:    177
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 8 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# Number of electrons:  100.00139
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -1559.0104576091876
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                    50.5721898793877
# Coulomb Energy                   707.7030658371779
# Exchange-Correlation Energy      -32.4199638366699
# --------------------------------------------------
# Total Energy                    -185.4486196120600
# --------------------------------------------------
#
#
#
# Energy difference :  185.44861961206004
#
#
# HOMO-LUMO gap: 1.765506807214618 au
# HOMO-LUMO gap: 48.042 eV
#
#
# Time taken for the previous iteration: 0.27 seconds
#
#
#
# Density matrix difference norm:  66.88323605808718
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3543.6816168858559
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                  1068.5207644691473
# Coulomb Energy                  1272.5916576120612
# Exchange-Correlation Energy     -125.2197723388672
# --------------------------------------------------
# Total Energy                    -680.0824210262826
# --------------------------------------------------
#
#
#
# Energy difference :  494.6338014142226
#
#
# HOMO-LUMO gap: 0.0003950061521098558 au
# HOMO-LUMO gap: 0.011 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  39.273524327922516
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.001236
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -2776.3671666175633
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   633.0861185032788
# Coulomb Energy                   861.6520702031823
# Exchange-Correlation Energy      -75.4418334960938
# --------------------------------------------------
# Total Energy                    -709.3642652899637
# --------------------------------------------------
#
#
#
# Energy difference :  29.281844263681023
#
#
# HOMO-LUMO gap: 0.027815576346578615 au
# HOMO-LUMO gap: 0.757 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  28.14516363990707
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99994
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3010.8982282478232
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   716.1525304346198
# Coulomb Energy                  1000.6416009621962
# Exchange-Correlation Energy      -87.3489074707031
# --------------------------------------------------
# Total Energy                    -733.7464582044781
# --------------------------------------------------
#
#
#
# Energy difference :  24.382192914514462
#
#
# HOMO-LUMO gap: 0.006873881119369457 au
# HOMO-LUMO gap: 0.187 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  18.101423188280272
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00064
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3026.3394470590165
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   739.2643058400853
# Coulomb Energy                  1039.7364436431681
# Exchange-Correlation Energy      -89.9713668823242
# --------------------------------------------------
# Total Energy                    -689.6035183408553
# --------------------------------------------------
#
#
#
# Energy difference :  44.142939863622814
#
#
# HOMO-LUMO gap: 0.009401599444313957 au
# HOMO-LUMO gap: 0.256 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  13.030480146552359
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000404
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3044.9281985115294
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   732.4697782000786
# Coulomb Energy                  1004.3617049984948
# Exchange-Correlation Energy      -89.2327270507812
# --------------------------------------------------
# Total Energy                    -749.6228962465054
# --------------------------------------------------
#
#
#
# Energy difference :  60.01937790565012
#
#
# HOMO-LUMO gap: 0.024324031149995755 au
# HOMO-LUMO gap: 0.662 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.651673169637812
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00018
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3046.2543708188264
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   735.6338780608095
# Coulomb Energy                   997.3404994327593
# Exchange-Correlation Energy      -89.6695938110352
# --------------------------------------------------
# Total Energy                    -755.2430410190609
# --------------------------------------------------
#
#
#
# Energy difference :  5.620144772555477
#
#
# HOMO-LUMO gap: 0.0012911093446474342 au
# HOMO-LUMO gap: 0.035 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  6.531121586194937
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000244
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3059.9935106834687
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   738.3455305446316
# Coulomb Energy                  1008.9226270478331
# Exchange-Correlation Energy      -89.8105316162109
# --------------------------------------------------
# Total Energy                    -754.8293385899827
# --------------------------------------------------
#
#
#
# Energy difference :  0.413702429078171
#
#
# HOMO-LUMO gap: 0.015388859282741293 au
# HOMO-LUMO gap: 0.419 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  7.342496801804467
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00051
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3103.6263327395491
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   761.2045013100856
# Coulomb Energy                  1033.2839548387635
# Exchange-Correlation Energy      -92.8135986328125
# --------------------------------------------------
# Total Energy                    -754.2449291062806
# --------------------------------------------------
#
#
#
# Energy difference :  0.5844094837021885
#
#
# HOMO-LUMO gap: 0.21170747981216076 au
# HOMO-LUMO gap: 5.761 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  6.051896196086843
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.999985
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3132.9762921855227
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   771.1048857445531
# Coulomb Energy                  1046.8936485934105
# Exchange-Correlation Energy      -94.6926879882812
# --------------------------------------------------
# Total Energy                    -761.9638997186084
# --------------------------------------------------
#
#
#
# Energy difference :  7.718970612327894
#
#
# HOMO-LUMO gap: 0.02108741763940173 au
# HOMO-LUMO gap: 0.574 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  4.592855629948168
#
#
#
#
#
# XC algo 3
# Number of electrons:  99.99999
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3080.7186505234358
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   747.7140613467755
# Coulomb Energy                  1016.5840747715764
# Exchange-Correlation Energy      -91.1270751953125
# --------------------------------------------------
# Total Energy                    -759.8410434831645
# --------------------------------------------------
#
#
#
# Energy difference :  2.122856235443919
#
#
# HOMO-LUMO gap: 0.08795066563974052 au
# HOMO-LUMO gap: 2.393 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  4.199971565473776
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3097.5724873388290
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4485442351906
# Coulomb Energy                  1025.9226121031140
# Exchange-Correlation Energy      -92.2370223999023
# --------------------------------------------------
# Total Energy                    -762.7318072831947
# --------------------------------------------------
#
#
#
# Energy difference :  2.890763800030186
#
#
# HOMO-LUMO gap: 0.14484581447645115 au
# HOMO-LUMO gap: 3.941 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.9087415966696631
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.6899810769132
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.8303619909786
# Coulomb Energy                  1024.4800313060587
# Exchange-Correlation Energy      -92.1533508300781
# --------------------------------------------------
# Total Energy                    -762.8263924927219
# --------------------------------------------------
#
#
#
# Energy difference :  0.09458520952716754
#
#
# HOMO-LUMO gap: 0.09120586888604602 au
# HOMO-LUMO gap: 2.482 eV
#
#
# Time taken for the previous iteration: 0.24 seconds
#
#
#
# Density matrix difference norm:  0.33859546309077326
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00002
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.6063800834636
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.4273607122186
# Coulomb Energy                  1024.8155226743870
# Exchange-Correlation Energy      -92.1995620727539
# --------------------------------------------------
# Total Energy                    -762.8565126523799
# --------------------------------------------------
#
#
#
# Energy difference :  0.030120159658054035
#
#
# HOMO-LUMO gap: 0.10812612700572787 au
# HOMO-LUMO gap: 2.942 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.13342123443019693
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3095.7707756176201
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   752.9490289674707
# Coulomb Energy                  1024.3963722046478
# Exchange-Correlation Energy      -92.1398544311523
# --------------------------------------------------
# Total Energy                    -762.8586827594218
# --------------------------------------------------
#
#
#
# Energy difference :  0.0021701070418203017
#
#
# HOMO-LUMO gap: 0.11558372185859134 au
# HOMO-LUMO gap: 3.145 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.05241024654050003
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00001
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.2028288807023
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.1553904578511
# Coulomb Energy                  1024.6505229111501
# Exchange-Correlation Energy      -92.1691818237305
# --------------------------------------------------
# Total Energy                    -762.8595512181994
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008684587776315311
#
#
# HOMO-LUMO gap: 0.11553044870694035 au
# HOMO-LUMO gap: 3.144 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.014070234734500624
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.000015
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0000206551767
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0543984693184
# Coulomb Energy                  1024.5347573513984
# Exchange-Correlation Energy      -92.1552581787109
# --------------------------------------------------
# Total Energy                    -762.8595768959387
# --------------------------------------------------
#
#
#
# Energy difference :  2.5677739358798135e-05
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.11964648747701578 au
# HOMO-LUMO gap: 3.256 eV
#
#
# Time taken for the previous iteration: 0.23 seconds
#
#
#
# Density matrix difference norm:  0.01580823431433741
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000745391999
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0803864472000
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0978029281813
# Coulomb Energy                  1024.5775713915250
# Exchange-Correlation Energy      -92.1624879307368
# --------------------------------------------------
# Total Energy                    -762.8609539409986
# --------------------------------------------------
#
#
#
# Energy difference :  0.0013770450598258321
#
#
# HOMO-LUMO gap: 0.11848000100248701 au
# HOMO-LUMO gap: 3.224 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.008700602046135267
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741303143
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0328787247709
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0722799329527
# Coulomb Energy                  1024.5524780617438
# Exchange-Correlation Energy      -92.1594108871975
# --------------------------------------------------
# Total Energy                    -762.8609855000395
# --------------------------------------------------
#
#
#
# Energy difference :  3.155904096274753e-05
#
#
# HOMO-LUMO gap: 0.11834734248977476 au
# HOMO-LUMO gap: 3.220 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.00205442649261109
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000073980904
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0503352058395
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0805117385639
# Coulomb Energy                  1024.5630592657894
# Exchange-Correlation Energy      -92.1607682312716
# --------------------------------------------------
# Total Energy                    -762.8609863155257
# --------------------------------------------------
#
#
#
# Energy difference :  8.154861461662222e-07
#
#
# HOMO-LUMO gap: 0.11844993607041523 au
# HOMO-LUMO gap: 3.223 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.0022804148226951496
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742289123
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0365058118964
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0734602211317
# Coulomb Energy                  1024.5553041336232
# Exchange-Correlation Energy      -92.1597916692709
# --------------------------------------------------
# Total Energy                    -762.8609870091802
# --------------------------------------------------
#
#
#
# Energy difference :  6.936545560165541e-07
#
#
# HOMO-LUMO gap: 0.11849899546565004 au
# HOMO-LUMO gap: 3.225 eV
#
#
# Time taken for the previous iteration: 0.57 seconds
#
#
#
# Density matrix difference norm:  0.0021210223923010083
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000742173579
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0510228583480
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0797964991802
# Coulomb Energy                  1024.5646232175723
# Exchange-Correlation Energy      -92.1609313817803
# --------------------------------------------------
# Total Energy                    -762.8609884061439
# --------------------------------------------------
#
#
#
# Energy difference :  1.3969636256661033e-06
#
#
# HOMO-LUMO gap: 0.11838532517278955 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.001418536595999048
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.00000741619978
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0635539014829
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0852199402907
# Coulomb Energy                  1024.5726721011240
# Exchange-Correlation Energy      -92.1618731171539
# --------------------------------------------------
# Total Energy                    -762.8609888599901
# --------------------------------------------------
#
#
#
# Energy difference :  4.538462690106826e-07
#
#
# HOMO-LUMO gap: 0.11838275447330726 au
# HOMO-LUMO gap: 3.221 eV
#
#
# Time taken for the previous iteration: 0.56 seconds
#
#
#
# Density matrix difference norm:  0.000322319888064315
#
#
#
#
#
# XC algo 3
# Number of electrons:  100.0000074204173
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -3096.0571685783416
# Nuclear repulsion Energy         647.7065461172319
# Kinetic Energy                   753.0822982401296
# Coulomb Energy                  1024.5687889855567
# Exchange-Correlation Energy      -92.1614536550627
# --------------------------------------------------
# Total Energy                    -762.8609888904862
# --------------------------------------------------
#
#
#
# Energy difference :  3.0496039471472614e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -762.8609888904862
# -------------------------------------
#
#
#
# Time taken : 14.95 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           2.0
# Density Fitting                         0.51
#     DF (gamma)                          0.15
#     DF (coeff)                          0.09
#     DF (Jtri)                           0.24
# DIIS                                    0.14
# KS matrix diagonalization               0.61
# One electron Integrals (S, T, Vnuc)     0.04
# Coulomb Integrals (2c2e + 3c2e)         2.72
# Grids construction                      1.0
# Exchange-Correlation Term               6.51
# Misc.                                   1.42
# Complete SCF                            14.95

# %% [markdown]
# ### Benchmark #5 Water_20 (H2O_20)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_20.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  60
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  500
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  1700
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.004
# done!
# Time taken 0.07 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.24 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.05
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.0072578219999286375
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.003006008
# No. of elements in the standard three-centered two electron ERI tensor:  425000000
# No. of elements in the triangular three-centered two electron ERI tensor:  212925000
# No. of significant triplets based on Schwarz inequality and triangularity: 65324200 or 15.4% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.06 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.28
# Two Center Two electron ERI size in GB  0.02312
# Three Center Two electron ERI size in GB  0.5225936
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  10.95 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 4.65 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 7.5 seconds.
#
#
# Deleted 113258 grid points.
#
# No. of supplied/generated grid points (after pruning):  560702
# Size (in GB) for storing the coordinates of grid:       0.013
# Size (in GB) for storing the weights of grid:           0.004
# Size (in GB) for storing the density at gridpoints:     0.004
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  28
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# done!
# Time taken 0.17 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    413
# Average no. of basis functions contributing to a batch of grid points:    321
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 28 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# XC algo 3
# Number of electrons:  200.0013
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -5072.5620647718088
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                   105.4953055255844
# Coulomb Energy                  2371.8738625355641
# Exchange-Correlation Energy      -66.5492401123047
# --------------------------------------------------
# Total Energy                    -374.9324929923032
# --------------------------------------------------
#
#
#
# Energy difference :  374.9324929923032
#
#
# HOMO-LUMO gap: 1.8503196895449938 au
# HOMO-LUMO gap: 50.350 eV
#
#
# Time taken for the previous iteration: 0.65 seconds
#
#
#
# Density matrix difference norm:  107.8280839276587
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -9072.0876321744472
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  2138.6682663137581
# Coulomb Energy                  3537.3220829802012
# Exchange-Correlation Energy     -250.6110687255859
# --------------------------------------------------
# Total Energy                   -1359.8987077754118
# --------------------------------------------------
#
#
#
# Energy difference :  984.9662147831086
#
#
# HOMO-LUMO gap: 0.0021138370435851983 au
# HOMO-LUMO gap: 0.058 eV
#
#
# Time taken for the previous iteration: 0.65 seconds
#
#
#
# Density matrix difference norm:  57.36504749177916
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00099
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7527.4339726203943
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1268.0382902509646
# Coulomb Energy                  2705.4087019809913
# Exchange-Correlation Energy     -151.8766021728516
# --------------------------------------------------
# Total Energy                   -1419.0539387306280
# --------------------------------------------------
#
#
#
# Energy difference :  59.15523095521621
#
#
# HOMO-LUMO gap: 0.019742610418247236 au
# HOMO-LUMO gap: 0.537 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  48.04762458071913
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0002
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7979.8987260314771
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1433.5516880410771
# Coulomb Energy                  3071.8807166781266
# Exchange-Correlation Energy     -174.7443542480469
# --------------------------------------------------
# Total Energy                   -1362.4010317296593
# --------------------------------------------------
#
#
#
# Energy difference :  56.65290700096875
#
#
# HOMO-LUMO gap: 0.014679275632366665 au
# HOMO-LUMO gap: 0.399 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  40.921717052805185
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00111
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -7991.3335375186525
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1450.1620892906044
# Coulomb Energy                  3051.7270285238219
# Exchange-Correlation Energy     -176.2000122070312
# --------------------------------------------------
# Total Energy                   -1378.8347880805950
# --------------------------------------------------
#
#
#
# Energy difference :  16.43375635093571
#
#
# HOMO-LUMO gap: 0.012567149564388369 au
# HOMO-LUMO gap: 0.342 eV
#
#
# Time taken for the previous iteration: 0.66 seconds
#
#
#
# Density matrix difference norm:  26.9267759063645
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00014
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8093.2983163193230
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1458.7494773961853
# Coulomb Energy                  3003.5484466793096
# Exchange-Correlation Energy     -179.3104553222656
# --------------------------------------------------
# Total Energy                   -1523.5012037354336
# --------------------------------------------------
#
#
#
# Energy difference :  144.6664156548386
#
#
# HOMO-LUMO gap: 0.003217943870703904 au
# HOMO-LUMO gap: 0.088 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  13.414502569451582
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00024
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8053.4196961121133
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1468.1319363975447
# Coulomb Energy                  2977.4926608597325
# Exchange-Correlation Energy     -178.1002044677734
# --------------------------------------------------
# Total Energy                   -1499.0856594919478
# --------------------------------------------------
#
#
#
# Energy difference :  24.415544243485783
#
#
# HOMO-LUMO gap: 0.03182997835743218 au
# HOMO-LUMO gap: 0.866 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  12.436593791527777
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0001
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8111.4381473620278
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1481.8446903484873
# Coulomb Energy                  3000.9338454642034
# Exchange-Correlation Energy     -180.8934936523438
# --------------------------------------------------
# Total Energy                   -1522.7434613710179
# --------------------------------------------------
#
#
#
# Energy difference :  23.65780187907012
#
#
# HOMO-LUMO gap: 0.012963702335542955 au
# HOMO-LUMO gap: 0.353 eV
#
#
# Time taken for the previous iteration: 0.72 seconds
#
#
#
# Density matrix difference norm:  6.013464771844282
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00009
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8182.5677663775141
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1515.6553164150907
# Coulomb Energy                  3041.7902309767051
# Exchange-Correlation Energy     -185.1305084228516
# --------------------------------------------------
# Total Energy                   -1523.4430835779076
# --------------------------------------------------
#
#
#
# Energy difference :  0.6996222068896714
#
#
# HOMO-LUMO gap: 0.02149123690272861 au
# HOMO-LUMO gap: 0.585 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  6.2166358822457175
#
#
#
#
#
# XC algo 3
# Number of electrons:  199.99994
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8206.4699649111935
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1520.5196370943436
# Coulomb Energy                  3063.1283235034089
# Exchange-Correlation Energy     -185.9102325439453
# --------------------------------------------------
# Total Energy                   -1521.9225930267248
# --------------------------------------------------
#
#
#
# Energy difference :  1.5204905511827747
#
#
# HOMO-LUMO gap: 0.07962877977229384 au
# HOMO-LUMO gap: 2.167 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  4.429032928837741
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8188.5505039494838
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1513.1094883467504
# Coulomb Energy                  3048.3900521555834
# Exchange-Correlation Energy     -185.3407135009766
# --------------------------------------------------
# Total Energy                   -1525.5820331174646
# --------------------------------------------------
#
#
#
# Energy difference :  3.6594400907397358
#
#
# HOMO-LUMO gap: 0.11947955160064716 au
# HOMO-LUMO gap: 3.251 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  0.8332705174511809
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8180.9524420650068
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1508.9100144144868
# Coulomb Energy                  3044.2746782949225
# Exchange-Correlation Energy     -184.7815856933594
# --------------------------------------------------
# Total Energy                   -1525.7396912182949
# --------------------------------------------------
#
#
#
# Energy difference :  0.15765810083030374
#
#
# HOMO-LUMO gap: 0.10915534346586292 au
# HOMO-LUMO gap: 2.970 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.4379677905215541
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00006
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8173.6333880274997
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1505.4380061120582
# Coulomb Energy                  3039.9319389823545
# Exchange-Correlation Energy     -184.3113555908203
# --------------------------------------------------
# Total Energy                   -1525.7651546932461
# --------------------------------------------------
#
#
#
# Energy difference :  0.025463474951266107
#
#
# HOMO-LUMO gap: 0.0804951576521469 au
# HOMO-LUMO gap: 2.190 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.2802189703933438
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8176.5675642036740
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1507.0128926126915
# Coulomb Energy                  3041.4808638508666
# Exchange-Correlation Energy     -184.5191192626953
# --------------------------------------------------
# Total Energy                   -1525.7832831721489
# --------------------------------------------------
#
#
#
# Energy difference :  0.018128478902781353
#
#
# HOMO-LUMO gap: 0.0353620460907898 au
# HOMO-LUMO gap: 0.962 eV
#
#
# Time taken for the previous iteration: 0.67 seconds
#
#
#
# Density matrix difference norm:  0.20216527764250547
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.6152305307041
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.7773165524859
# Coulomb Energy                  3040.7151018400964
# Exchange-Correlation Energy     -184.4732513427734
# --------------------------------------------------
# Total Energy                   -1525.7864196502342
# --------------------------------------------------
#
#
#
# Energy difference :  0.0031364780852527474
#
#
# HOMO-LUMO gap: 0.04477396379251822 au
# HOMO-LUMO gap: 1.218 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.07633480124611207
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0312888748458
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4161692745261
# Coulomb Energy                  3040.4442126079239
# Exchange-Correlation Energy     -184.4262542724609
# --------------------------------------------------
# Total Energy                   -1525.7875174341943
# --------------------------------------------------
#
#
#
# Energy difference :  0.0010977839601764572
#
#
# HOMO-LUMO gap: 0.05279080789300618 au
# HOMO-LUMO gap: 1.437 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.028440149176864844
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00005
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0299710465297
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4078505957400
# Coulomb Energy                  3040.4514262775633
# Exchange-Correlation Energy     -184.4266510009766
# --------------------------------------------------
# Total Energy                   -1525.7877013435404
# --------------------------------------------------
#
#
#
# Energy difference :  0.0001839093461057928
#
# Switching to double precision for XC evaluation after 17 iterations!
#
#
# HOMO-LUMO gap: 0.04989287794596893 au
# HOMO-LUMO gap: 1.358 eV
#
#
# Time taken for the previous iteration: 0.68 seconds
#
#
#
# Density matrix difference norm:  0.0128315992954244
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396312664
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9444070057452
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3722236082608
# Coulomb Energy                  3040.3964236041925
# Exchange-Correlation Energy     -184.4242562303787
# --------------------------------------------------
# Total Energy                   -1525.7903721930084
# --------------------------------------------------
#
#
#
# Energy difference :  0.0026708494679041905
#
#
# HOMO-LUMO gap: 0.05055294135695271 au
# HOMO-LUMO gap: 1.376 eV
#
#
# Time taken for the previous iteration: 2.25 seconds
#
#
#
# Density matrix difference norm:  0.005300444412022353
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960689776
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9993301922932
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4002703308518
# Coulomb Energy                  3040.4277550307424
# Exchange-Correlation Energy     -184.4287289407305
# --------------------------------------------------
# Total Energy                   -1525.7903899407693
# --------------------------------------------------
#
#
#
# Energy difference :  1.774776092133834e-05
#
#
# HOMO-LUMO gap: 0.05045899496187535 au
# HOMO-LUMO gap: 1.373 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.002106280613168771
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003961675472
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8174.9998985828297
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.3973945593943
# Coulomb Energy                  3040.4311713285979
# Exchange-Correlation Energy     -184.4287042208055
# --------------------------------------------------
# Total Energy                   -1525.7903930849816
# --------------------------------------------------
#
#
#
# Energy difference :  3.1442123145097867e-06
#
#
# HOMO-LUMO gap: 0.05065933483542899 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.004881562537611629
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003960054428
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0796144332853
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4345418587186
# Coulomb Energy                  3040.4795325847936
# Exchange-Correlation Energy     -184.4344982245759
# --------------------------------------------------
# Total Energy                   -1525.7903943836882
# --------------------------------------------------
#
#
#
# Energy difference :  1.2987065929337405e-06
#
#
# HOMO-LUMO gap: 0.050633281029498295 au
# HOMO-LUMO gap: 1.378 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.004003891762820703
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.0000396293591
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0308456470666
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4102268758472
# Coulomb Energy                  3040.4520257518670
# Exchange-Correlation Energy     -184.4314494141049
# --------------------------------------------------
# Total Energy                   -1525.7903986027959
# --------------------------------------------------
#
#
#
# Energy difference :  4.21910772274714e-06
#
#
# HOMO-LUMO gap: 0.050659204463994134 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.28 seconds
#
#
#
# Density matrix difference norm:  0.0009815045519132332
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.000039623176
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0462801941158
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4170922777121
# Coulomb Energy                  3040.4616007047553
# Exchange-Correlation Energy     -184.4324555357617
# --------------------------------------------------
# Total Energy                   -1525.7903989167480
# --------------------------------------------------
#
#
#
# Energy difference :  3.139521140838042e-07
#
#
# HOMO-LUMO gap: 0.050679426680870804 au
# HOMO-LUMO gap: 1.379 eV
#
#
# Time taken for the previous iteration: 2.29 seconds
#
#
#
# Density matrix difference norm:  0.000246190184264213
#
#
#
#
#
# XC algo 3
# Number of electrons:  200.00003962332758
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy        -8175.0503257509199
# Nuclear repulsion Energy        2286.8096438306616
# Kinetic Energy                  1506.4188622221586
# Coulomb Energy                  3040.4641305866662
# Exchange-Correlation Energy     -184.4327098262677
# --------------------------------------------------
# Total Energy                   -1525.7903989377010
# --------------------------------------------------
#
#
#
# Energy difference :  2.095293893944472e-08
#
# SCF Converged after 24 iterations!
#
# -------------------------------------
# Total Energy =  -1525.790398937701
# -------------------------------------
#
#
#
# Time taken : 52.96 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           7.67
# Density Fitting                         1.42
#     DF (gamma)                          0.32
#     DF (coeff)                          0.1
#     DF (Jtri)                           0.89
# DIIS                                    0.71
# KS matrix diagonalization               1.2
# One electron Integrals (S, T, Vnuc)     0.07
# Coulomb Integrals (2c2e + 3c2e)         10.95
# Grids construction                      4.65
# Exchange-Correlation Term               23.77
# Misc.                                   2.52
# Complete SCF                            52.96

# %% [markdown]
# ### Benchmark #6 Water_32 (H2O_32)

# %%
import os

ncores = 4
os.environ['OMP_NUM_THREADS'] = str(ncores)
os.environ["OPENBLAS_NUM_THREADS"] = str(ncores) # or export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = str(ncores) #  or export MKL_NUM_THREADS=4
os.environ["VECLIB_MAXIMUM_THREADS"] = str(ncores)  # or  export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = str(ncores) # or  export NUMEXPR_NUM_THREADS=4


# Run your tasks here
from pyfock import Basis
from pyfock import Mol
from pyfock import DFT

# DFT functional 
# Natively implemented GGA functionals
funcidpyfock = 'PBE' # [101, 130]

basis_set_name = 'def2-SVP'

auxbasis_name = 'def2-universal-jfit'

xyzFilename = 'Structures/water_cluster_32.xyz'

# Initialize a Mol object 
mol = Mol(coordfile=xyzFilename)

#Initialize a Basis object 
basis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=basis_set_name)})
#Initialize an auxiliary basis object for density fitting
auxbasis = Basis(mol, {'all':Basis.load(mol=mol, basis_name=auxbasis_name)})

dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock, use_pyscf_grids=True, gridsLevel=3)
#dftObj = DFT(mol, basis, auxbasis, xc=funcidpyfock)

dftObj.conv_crit = 1e-7
dftObj.max_itr = 50
dftObj.ncores = ncores
dftObj.save_ao_values = False # Requires more memory but is faster
dftObj.use_gpu = True
dftObj.blocksize = 20480
dftObj.dynamic_precision = True
energyCrysX, dmat = dftObj.scf()
# Out:
# ======================================================================
# PyFock Python Program for Quantum Chemistry Simulations
#                                         by Manas Sharma
# ======================================================================
# ██████  ██    ██ ███████  ██████   ██████ ██   ██
# ██░░░██ ░██  ██░ ██░░░░░ ██░░░░██ ██░░░░░ ██  ██░
# ██████   ░████░  █████   ██    ██ ██      █████░
# ██░░░░    ░██░   ██░░░   ██    ██ ██      ██░░██
# ██         ██    ██      ░██████░ ░██████ ██  ░██
# ░░         ░░    ░░       ░░░░░░   ░░░░░░ ░░   ░░
#
# ======================================================================
#
# Version:  0.1.4
# Citation: M. Sharma and M. Sierka, PyFock: A Just-In-Time Compiled
# Gaussian Basis DFT Python Code for CPU and GPU Architectures
#
# ======================================================================
#
# 📧 Contact Information:
#    Developer: Dr. Manas Sharma (PhD Physics)
#    Email: manas.sharma@uni-jena.de
#    Website: https://manas.bragitoff.com/
#
# 📚 Resources:
#    Documentation: https://pyfock-docs.bragitoff.com
#    Official Website: https://pyfock.bragitoff.com/
#    GitHub Repo: https://github.com/manassharma07/pyfock
#    Web GUI: https://pyfock-gui.bragitoff.com/
#
# ======================================================================
#
#
#
#  Time to get inspired by a great quantum chemist :)
#
#
# ======================================================================
#  ____        _ _
# |  _ \  __ _| | |_ ___  _ __
# | | | |/ _` | | __/ _ \| '_ \
# | |_| | (_| | | || (_) | | | |
# |____/ \__,_|_|\__\___/|_| |_|
# ======================================================================
#
#
#    ......................................................................
#    ...............              .,,,,,,...                    ...........
#    ........ .             ......         ..,,.                     ......
#    ......              .,,..                ......                    ...
#    ....                .   ...   ....   .. ..  ....
#    .                 ....   ,. .,,,,.    ,..,   , .,
#                     .    ..,.                .   ,
#                    .,.  .,,,.                 .. .,.
#                   ,.    ,.                          ,,:
#                   ,.   ..                           .,,
#                   ,.                                ,.
#                         .        ..   .  ,  ..   .. ,.
#                         ,      ... .:;+;,.  :-;,.,..:.
#                      ,;-;,..    .,,;;:,:,...,-;,;:,,;,,
#                    .....::;;;-;.;; ,,.. :.  .-. :..,+:,
#                   :.,.,.,    ., .:,    .,    ::.   :, ,
#                   ..    ,         .,....      .....  ..
#                    .,  ..,.                   .,    .,:
#                     ..                  ,,,   :,   .,..
#                      ,   .  .        .    .,,::,.  :;.
#                         ,,               ..  .,.   ..
#                        .,,,          .........,.. .,
#                       .  .....            ....     .;:..
#                      .,  :.,,,.    .              .:;:,;,
#                     .    , .  ,.                ..::;:,::,
#                     :    : :   ... .   .      .,,:;:;:,,.,.
#                    .     ,   .   ..     .,,:;;:,,::::.    ..
#                   ,      :   ,..    ...,,::,:,,,:,:::.     ,
#                  ,.       ,     ,, ,..,,.   . . ,,:::.     .....
#               ...,        ,.     . ...        .,,,,,,.      ,   .....
#             ....:         ,,.      .,.         ,.,.,..      ..     .
#         .,...   ,         ,..       ,..  ..   ,    ,,        ,
#          .      ,   .,     ..        ,      ,,     ,      ,. ,
#                 ,   ,       ,        ..     ,     ..      ., ,
#                              ,         ,.  ,     ,.        .,
#                              ..         , ..     .          ..
#    ..                         .,         ,.    .:
#    ....                        .         .     .
#
#
#
#    ╔══════════════════════════════════════════════════════════════════════╗
#    ║ If I have succeeded better than many who surround me, it has been    ║
#    ║ chiefly - nay, I may say, almost solely - by universal assiduity.    ║
#    ╠══════════════════════════════════════════════════════════════════════╣
#    ║                                                           ~ dalton   ║
#    ╚══════════════════════════════════════════════════════════════════════╝
#
#
#
# Number of atoms:  96
#
#
# Number of basis functions or Cartesian atomic orbitals (6d, 10f, 15g and so on):  800
#
#
# Number of auxiliary basis functions (in Cartesian atomic orbital basis):  2720
#
# ======================================================================
#
#
# ============= System Information =============
# Operating System: Linux 6.12.90+
# System Type: 64bit
# CPU Model: Intel(R) Xeon(R) CPU @ 2.00GHz
# Number of Cores: 2
# Number of Threads: 4
# Memory (GB): 31.35
#
# ======================================================================
#
# Running DFT using 4 threads for Numba.
#
#
# GPU acceleration is enabled.
# GPU(s) information:
# Max threads per block supported by the GPU:  1024
# The user has specified to use 1 GPU(s).
# Threads per block configuration for the XC term:  (64, 16)
# Threads per block configuration for the all other calculations:  (32, 32)
#
#
# Will use dynamic precision.
# This means that the XC term will be evaluated in single precision until the
# relative energy difference b/w successive iterations is less than 5.0E-6.
# Warning: The Cholesky decomposition of 2c2e integrals is only compatible with CPU version, so turning it off.
#
#
# Cartesian Atomic Orbitals (6d, 10f, 15g...) are being used!
#
#
#
# Calculating overlap and kinetic integrals...
#
#
# Core H size in GB  0.0102
# done!
# Time taken 0.14 seconds.
#
#
#
# User requested to use Rys Quadrature Algorithm for the evaluation of ERIs
# Stricter version of Schwarz screening:  True
#
# Calculating three centered two electron and two-centered two-electron integrals...
#
#
# Time taken for two-centered two-electron integrals 0.49 seconds.
#
#
#
# Performing Schwarz screening...
# Threshold  1e-09
# Time taken to evaluate the "diagonal" of 4c2e ERI tensor:  0.09
# Time taken to evaluate the square roots needed:  0.0
# Time for significant indices evaluation:  0.018997422999973423
# Size of permanent array storing the significant indices of 3c2e ERI in GB  0.007689608
# No. of elements in the standard three-centered two electron ERI tensor:  1740800000
# No. of elements in the triangular three-centered two electron ERI tensor:  871488000
# No. of significant triplets based on Schwarz inequality and triangularity: 189200480 or 10.9% of original
# Schwarz screening done!
# Total time taken for Schwarz screening 0.12 seconds.
#
# Time taken to evaluate the nuclear potential matrix with strict Schwarz screening:  0.66
# Two Center Two electron ERI size in GB  0.0591872
# Three Center Two electron ERI size in GB  1.51360384
# Three-centered two electron evaluation done!
# Time taken for Coulomb term related calculations (integrals, screening, prelims..) with the density fitting approximation  28.24 seconds.
#
#
#
# ------------------------------------------------------
# Numerical Integration for XC Term
# ------------------------------------------------------
#
#
# Generating grids...
#
#
# Grids level:  3
# Using PySCF to generate the DFT grids.
# done!
# Time taken 15.96 seconds.
#
#
# Pruning generated grids by rho...
#
#
# done!
# Time taken 20.93 seconds.
#
#
# Deleted 193720 grid points.
#
# No. of supplied/generated grid points (after pruning):  884616
# Size (in GB) for storing the coordinates of grid:       0.021
# Size (in GB) for storing the weights of grid:           0.007
# Size (in GB) for storing the density at gridpoints:     0.007
#
# Sorting grids ....
# done!
#
# Will use batching to evaluate the XC term for memory efficiency.
# Batch size:  20480
# No. of batches:  44
#
# Preliminary processing for XC term evaluations...
# Calculating the value of basis functions (atomic orbitals) and get the indices of siginificantly contributing functions...
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 77 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# done!
# Time taken 0.24 seconds.
#
# Maximum no. of basis functions contributing to a batch of grid points:    546
# Average no. of basis functions contributing to a batch of grid points:    422
#
#
# ------------------------------------------------------
# Exchange-Correlation Functional
# ------------------------------------------------------
#
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# J. P. Perdew, K. Burke, and M. Ernzerhof, Phys. Rev. Lett. 77, 3865 (1996).
# ------------------------------------------------------
#
#
#
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00284
#
#
#
# ------Iteration 1--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -10957.3224322910428
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                   171.2658578062144
# Coulomb Energy                  5193.8417181004706
# Exchange-Correlation Energy     -107.4069824218750
# --------------------------------------------------
# Total Energy                    -601.1817176456179
# --------------------------------------------------
#
#
#
# Energy difference :  601.1817176456179
#
#
# HOMO-LUMO gap: 1.3453310369352351 au
# HOMO-LUMO gap: 36.608 eV
#
#
# Time taken for the previous iteration: 1.68 seconds
#
#
#
# Density matrix difference norm:  144.01367462687867
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99988
#
#
#
# ------Iteration 2--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -17397.9771653634307
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  3422.3873960288006
# Coulomb Energy                  7102.3908476757206
# Exchange-Correlation Energy     -401.0388488769531
# --------------------------------------------------
# Total Energy                   -2175.7976493752485
# --------------------------------------------------
#
#
#
# Energy difference :  1574.6159317296306
#
#
# HOMO-LUMO gap: 0.0036323936827828973 au
# HOMO-LUMO gap: 0.099 eV
#
#
# Time taken for the previous iteration: 1.32 seconds
#
#
#
# Density matrix difference norm:  71.99222142054745
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0024
#
#
#
# ------Iteration 3--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -14930.8537956295750
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2030.0349342492821
# Coulomb Energy                  5771.7158140790925
# Exchange-Correlation Energy     -243.8542327880859
# --------------------------------------------------
# Total Energy                   -2274.5171589286711
# --------------------------------------------------
#
#
#
# Energy difference :  98.71950955342254
#
#
# HOMO-LUMO gap: 0.004971605352714528 au
# HOMO-LUMO gap: 0.135 eV
#
#
# Time taken for the previous iteration: 1.34 seconds
#
#
#
# Density matrix difference norm:  58.10278545161682
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00217
#
#
#
# ------Iteration 4--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15586.5372312708569
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2286.2733518963369
# Coulomb Energy                  6321.7308991228711
# Exchange-Correlation Energy     -278.3752136230469
# --------------------------------------------------
# Total Energy                   -2158.4680727140822
# --------------------------------------------------
#
#
#
# Energy difference :  116.0490862145889
#
#
# HOMO-LUMO gap: 0.014406138165056426 au
# HOMO-LUMO gap: 0.392 eV
#
#
# Time taken for the previous iteration: 1.36 seconds
#
#
#
# Density matrix difference norm:  53.3686640297769
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00177
#
#
#
# ------Iteration 5--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15675.5688655949798
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2315.2515407952633
# Coulomb Energy                  6361.2922210769166
# Exchange-Correlation Energy     -281.9417419433594
# --------------------------------------------------
# Total Energy                   -2182.5267245055447
# --------------------------------------------------
#
#
#
# Energy difference :  24.05865179146258
#
#
# HOMO-LUMO gap: 0.00893103077274457 au
# HOMO-LUMO gap: 0.243 eV
#
#
# Time taken for the previous iteration: 1.39 seconds
#
#
#
# Density matrix difference norm:  42.830841310021114
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00098
#
#
#
# ------Iteration 6--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15786.3057581219564
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2331.5112448405457
# Coulomb Energy                  6294.4824430037716
# Exchange-Correlation Energy     -283.9661865234375
# --------------------------------------------------
# Total Energy                   -2345.8381356404625
# --------------------------------------------------
#
#
#
# Energy difference :  163.31141113491776
#
#
# HOMO-LUMO gap: 0.006907374930176291 au
# HOMO-LUMO gap: 0.188 eV
#
#
# Time taken for the previous iteration: 1.41 seconds
#
#
#
# Density matrix difference norm:  32.16624462361193
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.9998
#
#
#
# ------Iteration 7--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15712.2173793311813
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2340.7029699995246
# Coulomb Energy                  6214.1441890234555
# Exchange-Correlation Energy     -284.6288146972656
# --------------------------------------------------
# Total Energy                   -2343.5589138448513
# --------------------------------------------------
#
#
#
# Energy difference :  2.2792217956111926
#
#
# HOMO-LUMO gap: 0.002470696993037383 au
# HOMO-LUMO gap: 0.067 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  33.32021518576414
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 8--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15805.4828177605705
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2356.0271124797860
# Coulomb Energy                  6284.7511375283366
# Exchange-Correlation Energy     -286.3058166503906
# --------------------------------------------------
# Total Energy                   -2352.5702632422244
# --------------------------------------------------
#
#
#
# Energy difference :  9.011349397373124
#
#
# HOMO-LUMO gap: 0.006022952486261779 au
# HOMO-LUMO gap: 0.164 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  26.09922518979527
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 9--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -16121.2099617275999
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2498.3779349470765
# Coulomb Energy                  6418.6993132317366
# Exchange-Correlation Energy     -305.3439331054688
# --------------------------------------------------
# Total Energy                   -2411.0365254936405
# --------------------------------------------------
#
#
#
# Energy difference :  58.46626225141608
#
#
# HOMO-LUMO gap: 0.005611896603387623 au
# HOMO-LUMO gap: 0.153 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  17.530055326970764
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00027
#
#
#
# ------Iteration 10--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15943.3144961917642
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2439.3754841988584
# Coulomb Energy                  6329.8759153418832
# Exchange-Correlation Energy     -297.7132263183594
# --------------------------------------------------
# Total Energy                   -2373.3362018087664
# --------------------------------------------------
#
#
#
# Energy difference :  37.70032368487409
#
#
# HOMO-LUMO gap: 0.017129216565227826 au
# HOMO-LUMO gap: 0.466 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  16.398024725801182
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99982
#
#
#
# ------Iteration 11--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15977.4113064228695
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2428.3502205128320
# Coulomb Energy                  6323.6507126137421
# Exchange-Correlation Energy     -296.5716552734375
# --------------------------------------------------
# Total Energy                   -2423.5419074091187
# --------------------------------------------------
#
#
#
# Energy difference :  50.2057056003523
#
#
# HOMO-LUMO gap: 0.006507665666795628 au
# HOMO-LUMO gap: 0.177 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  17.896858960530537
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00082
#
#
#
# ------Iteration 12--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15866.4006156225387
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.1970941908608
# Coulomb Energy                  6269.6529587468394
# Exchange-Correlation Energy     -292.3520507812500
# --------------------------------------------------
# Total Energy                   -2388.4624923054744
# --------------------------------------------------
#
#
#
# Energy difference :  35.07941510364435
#
#
# HOMO-LUMO gap: 0.011363315128916904 au
# HOMO-LUMO gap: 0.309 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  18.875114608076174
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0009
#
#
#
# ------Iteration 13--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15931.4052622263462
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2400.8783287635929
# Coulomb Energy                  6305.1510629367376
# Exchange-Correlation Energy     -292.6976928710938
# --------------------------------------------------
# Total Energy                   -2419.6334422364953
# --------------------------------------------------
#
#
#
# Energy difference :  31.170949931020914
#
#
# HOMO-LUMO gap: 0.00193093965354596 au
# HOMO-LUMO gap: 0.053 eV
#
#
# Time taken for the previous iteration: 1.42 seconds
#
#
#
# Density matrix difference norm:  14.237405103919329
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 14--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15905.7556804715205
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2402.6446665930530
# Coulomb Energy                  6277.9143136658631
# Exchange-Correlation Energy     -292.9882202148438
# --------------------------------------------------
# Total Energy                   -2419.7447992668340
# --------------------------------------------------
#
#
#
# Energy difference :  0.11135703033869504
#
#
# HOMO-LUMO gap: 0.008268420606064628 au
# HOMO-LUMO gap: 0.225 eV
#
#
# Time taken for the previous iteration: 1.44 seconds
#
#
#
# Density matrix difference norm:  12.511464500416194
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0002
#
#
#
# ------Iteration 15--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15948.8343453111083
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.0119717726852
# Coulomb Energy                  6304.6092790280236
# Exchange-Correlation Energy     -294.2061157226562
# --------------------------------------------------
# Total Energy                   -2430.9790890724416
# --------------------------------------------------
#
#
#
# Energy difference :  11.23428980560766
#
#
# HOMO-LUMO gap: 0.01765892422278502 au
# HOMO-LUMO gap: 0.481 eV
#
#
# Time taken for the previous iteration: 1.43 seconds
#
#
#
# Density matrix difference norm:  10.321250531740153
#
#
#
#
#
# XC algo 3
# Number of electrons:  319.99994
#
#
#
# ------Iteration 16--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15982.0478896232944
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2430.2890686210030
# Coulomb Energy                  6320.8556257845230
# Exchange-Correlation Energy     -297.0248413085938
# --------------------------------------------------
# Total Energy                   -2429.4879153657475
# --------------------------------------------------
#
#
#
# Energy difference :  1.4911737066940987
#
#
# HOMO-LUMO gap: 0.006404337314238562 au
# HOMO-LUMO gap: 0.174 eV
#
#
# Time taken for the previous iteration: 1.44 seconds
#
#
#
# Density matrix difference norm:  8.082502872354759
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 17--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15980.4239163874463
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2424.0824970313961
# Coulomb Energy                  6316.7243877171632
# Exchange-Correlation Energy     -296.7613830566406
# --------------------------------------------------
# Total Energy                   -2437.9382935349122
# --------------------------------------------------
#
#
#
# Energy difference :  8.450378169164651
#
#
# HOMO-LUMO gap: 0.0662856931054516 au
# HOMO-LUMO gap: 1.804 eV
#
#
# Time taken for the previous iteration: 1.44 seconds
#
#
#
# Density matrix difference norm:  4.088565624887358
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 18--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15972.3818009503084
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2415.5872166797753
# Coulomb Energy                  6313.2561861147706
# Exchange-Correlation Energy     -295.9057006835938
# --------------------------------------------------
# Total Energy                   -2441.0039776787426
# --------------------------------------------------
#
#
#
# Energy difference :  3.0656841438303672
#
#
# HOMO-LUMO gap: 0.002509054707945782 au
# HOMO-LUMO gap: 0.068 eV
#
#
# Time taken for the previous iteration: 1.44 seconds
#
#
#
# Density matrix difference norm:  4.342546214287859
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00012
#
#
#
# ------Iteration 19--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15935.2974058867003
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2403.1398843594170
# Coulomb Energy                  6287.7369562877902
# Exchange-Correlation Energy     -293.7501525878906
# --------------------------------------------------
# Total Energy                   -2439.7305966667682
# --------------------------------------------------
#
#
#
# Energy difference :  1.2733810119743794
#
#
# HOMO-LUMO gap: 0.020604826015637116 au
# HOMO-LUMO gap: 0.561 eV
#
#
# Time taken for the previous iteration: 1.44 seconds
#
#
#
# Density matrix difference norm:  4.259651420620832
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 20--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15957.7062818214617
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.1986673955298
# Coulomb Energy                  6303.8933868133527
# Exchange-Correlation Energy     -294.9478454589844
# --------------------------------------------------
# Total Energy                   -2441.1219519109500
# --------------------------------------------------
#
#
#
# Energy difference :  1.3913552441817956
#
#
# HOMO-LUMO gap: 0.12298472131534596 au
# HOMO-LUMO gap: 3.347 eV
#
#
# Time taken for the previous iteration: 1.47 seconds
#
#
#
# Density matrix difference norm:  0.7427923615898744
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00015
#
#
#
# ------Iteration 21--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15963.0197853029294
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2411.5243571311089
# Coulomb Energy                  6307.0122370011522
# Exchange-Correlation Energy     -295.2850036621094
# --------------------------------------------------
# Total Energy                   -2441.3280736721626
# --------------------------------------------------
#
#
#
# Energy difference :  0.20612176121267112
#
#
# HOMO-LUMO gap: 0.0886730536617483 au
# HOMO-LUMO gap: 2.413 eV
#
#
# Time taken for the previous iteration: 1.45 seconds
#
#
#
# Density matrix difference norm:  0.4773172169153914
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00006
#
#
#
# ------Iteration 22--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.4110345424342
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.7989042724480
# Coulomb Energy                  6304.8709450062079
# Exchange-Correlation Energy     -295.0262756347656
# --------------------------------------------------
# Total Energy                   -2441.3273397379298
# --------------------------------------------------
#
#
#
# Energy difference :  0.0007339342328123166
#
# Switching to double precision for XC evaluation after 22 iterations!
#
#
# HOMO-LUMO gap: 0.10639436712283162 au
# HOMO-LUMO gap: 2.895 eV
#
#
# Time taken for the previous iteration: 1.45 seconds
#
#
#
# Density matrix difference norm:  0.27042128417841493
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011527413534
#
#
#
# ------Iteration 23--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15958.5565330243426
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.4793766848547
# Coulomb Energy                  6304.2831504056594
# Exchange-Correlation Energy     -294.9926885547523
# --------------------------------------------------
# Total Energy                   -2441.3465733279663
# --------------------------------------------------
#
#
#
# Energy difference :  0.019233590036492387
#
#
# HOMO-LUMO gap: 0.1057127207582598 au
# HOMO-LUMO gap: 2.877 eV
#
#
# Time taken for the previous iteration: 5.63 seconds
#
#
#
# Density matrix difference norm:  0.11903358133864247
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011552538433
#
#
#
# ------Iteration 24--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.9903009762274
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.6069442548865
# Coulomb Energy                  6305.7413620786938
# Exchange-Correlation Energy     -295.1471017784302
# --------------------------------------------------
# Total Energy                   -2441.3489752604619
# --------------------------------------------------
#
#
#
# Energy difference :  0.0024019324955588672
#
#
# HOMO-LUMO gap: 0.10232828972605196 au
# HOMO-LUMO gap: 2.784 eV
#
#
# Time taken for the previous iteration: 5.65 seconds
#
#
#
# Density matrix difference norm:  0.05772725526269541
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001161638595
#
#
#
# ------Iteration 25--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1764378701155
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2270873589755
# Coulomb Energy                  6305.2551434287052
# Exchange-Correlation Energy     -295.0957765350576
# --------------------------------------------------
# Total Energy                   -2441.3498624568783
# --------------------------------------------------
#
#
#
# Energy difference :  0.0008871964164427482
#
#
# HOMO-LUMO gap: 0.08313005084103195 au
# HOMO-LUMO gap: 2.262 eV
#
#
# Time taken for the previous iteration: 5.64 seconds
#
#
#
# Density matrix difference norm:  0.06366463691203472
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001177587838
#
#
#
# ------Iteration 26--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.6239380826664
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2409.9397998056220
# Coulomb Energy                  6304.9502823279709
# Exchange-Correlation Energy     -295.0562552489375
# --------------------------------------------------
# Total Energy                   -2441.3499900373972
# --------------------------------------------------
#
#
#
# Energy difference :  0.00012758051889250055
#
#
# HOMO-LUMO gap: 0.085439755144435 au
# HOMO-LUMO gap: 2.325 eV
#
#
# Time taken for the previous iteration: 5.61 seconds
#
#
#
# Density matrix difference norm:  0.03312737397257542
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001171909252
#
#
#
# ------Iteration 27--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.1937919654338
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.2381660094429
# Coulomb Energy                  6305.2622665080971
# Exchange-Correlation Energy     -295.0969076687857
# --------------------------------------------------
# Total Energy                   -2441.3501459560639
# --------------------------------------------------
#
#
#
# Energy difference :  0.00015591866667818977
#
#
# HOMO-LUMO gap: 0.08549318214734258 au
# HOMO-LUMO gap: 2.326 eV
#
#
# Time taken for the previous iteration: 5.59 seconds
#
#
#
# Density matrix difference norm:  0.016443334038099857
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001174372777
#
#
#
# ------Iteration 28--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15959.9924263921603
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1355436027575
# Coulomb Energy                  6305.1489902156172
# Exchange-Correlation Energy     -295.0824364753914
# --------------------------------------------------
# Total Energy                   -2441.3502078885631
# --------------------------------------------------
#
#
#
# Energy difference :  6.193249919306254e-05
#
#
# HOMO-LUMO gap: 0.0860995337056262 au
# HOMO-LUMO gap: 2.343 eV
#
#
# Time taken for the previous iteration: 5.58 seconds
#
#
#
# Density matrix difference norm:  0.007353864865399607
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.000117343934
#
#
#
# ------Iteration 29--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0612572615664
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1745117760779
# Coulomb Energy                  6305.1841828518009
# Exchange-Correlation Energy     -295.0877765573396
# --------------------------------------------------
# Total Energy                   -2441.3502180304131
# --------------------------------------------------
#
#
#
# Energy difference :  1.0141849998035468e-05
#
#
# HOMO-LUMO gap: 0.08618091539194218 au
# HOMO-LUMO gap: 2.345 eV
#
#
# Time taken for the previous iteration: 5.55 seconds
#
#
#
# Density matrix difference norm:  0.0029221067369396307
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011732035483
#
#
#
# ------Iteration 30--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0438998730515
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1630542957000
# Coulomb Energy                  6305.1767184255496
# Exchange-Correlation Energy     -295.0862145008963
# --------------------------------------------------
# Total Energy                   -2441.3502204920842
# --------------------------------------------------
#
#
#
# Energy difference :  2.4616711016278714e-06
#
#
# HOMO-LUMO gap: 0.08626993474269824 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.55 seconds
#
#
#
# Density matrix difference norm:  0.000799225623058675
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.00011730882494
#
#
#
# ------Iteration 31--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0357868609863
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1591885621974
# Coulomb Energy                  6305.1719581215621
# Exchange-Correlation Energy     -295.0857015788705
# --------------------------------------------------
# Total Energy                   -2441.3502205954810
# --------------------------------------------------
#
#
#
# Energy difference :  1.0339681466575712e-07
#
#
# HOMO-LUMO gap: 0.08626927803539788 au
# HOMO-LUMO gap: 2.348 eV
#
#
# Time taken for the previous iteration: 5.54 seconds
#
#
#
# Density matrix difference norm:  0.00047089293902240697
#
#
#
#
#
# XC algo 3
# Number of electrons:  320.0001173170852
#
#
#
# ------Iteration 32--------
#
#
# Energies (in Hartrees)
#
# Electron-Nuclear Energy       -15960.0330010877533
# Nuclear repulsion Energy        5098.4401211606146
# Kinetic Energy                  2410.1576326658605
# Coulomb Energy                  6305.1705222145565
# Exchange-Correlation Energy     -295.0854955587650
# --------------------------------------------------
# Total Energy                   -2441.3502206054864
# --------------------------------------------------
#
#
#
# Energy difference :  1.0005351214203984e-08
#
# SCF Converged after 32 iterations!
#
# -------------------------------------
# Total Energy =  -2441.3502206054864
# -------------------------------------
#
#
#
# Time taken : 156.22 seconds.
#
#
#
# -------------------------------------------------------------
# Profiling (Wall times in seconds)
# -------------------------------------------------------------
# Preprocessing                           21.18
# Density Fitting                         5.14
#     DF (gamma)                          0.99
#     DF (coeff)                          0.15
#     DF (Jtri)                           3.62
# DIIS                                    3.55
# KS matrix diagonalization               3.57
# One electron Integrals (S, T, Vnuc)     0.14
# Coulomb Integrals (2c2e + 3c2e)         28.24
# Grids construction                      15.96
# Exchange-Correlation Term               74.59
# Misc.                                   3.84
# Complete SCF                            156.22
